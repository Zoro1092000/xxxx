# %% [markdown]
# <a href="https://colab.research.google.com/github/Zoro1092000/xxxx/blob/main/GENConv_p2p_normalization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # I. Pip & Import.

# %%
import os
import os.path as osp
import torch
import sys

os.environ['TORCH'] = torch.__version__

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install torch-geometric
# !pip install torch-cluster -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install deepdish==0.3.5
# !pip install torch-optimizer

import torch.nn as nn
from torch.nn import Parameter
from torch_geometric.utils import scatter
from torch_geometric.nn.inits import glorot, zeros
from torch_scatter import scatter_add
from torch.utils.data import DataLoader, Dataset
import torch_optimizer as optimization


from itertools import chain
import pickle
import h5py
import deepdish as dd
import numpy as np
from tqdm import tqdm
import inspect
import time
import math
import random
# Out:
#      |████████████████████████████████| 7.9 MB 5.2 MB/s
#      |████████████████████████████████| 3.5 MB 14.1 MB/s
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch-geometric
#   Downloading torch_geometric-2.1.0.post1.tar.gz (467 kB)
#      |████████████████████████████████| 467 kB 13.7 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (4.64.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.7.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.23.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (3.0.9)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.0.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->torch-geometric) (2.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (3.0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric) (1.2.0)
# Building wheels for collected packages: torch-geometric
#   Building wheel for torch-geometric (setup.py) ... done
#   Created wheel for torch-geometric: filename=torch_geometric-2.1.0.post1-py3-none-any.whl size=689859 sha256=d156a4415b61bc9191defb125c8697a468313971b6f60330f21e9d2fd7c0d0f1
#   Stored in directory: /root/.cache/pip/wheels/d1/cb/43/f7f2e472de4d7cff31bceddadc36d634e1e545fbc17961c282
# Successfully built torch-geometric
# Installing collected packages: torch-geometric
# Successfully installed torch-geometric-2.1.0.post1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://data.pyg.org/whl/torch-1.12.1+cu113.html
# Collecting torch-cluster
#   Downloading https://data.pyg.org/whl/torch-1.12.0%2Bcu113/torch_cluster-1.6.0-cp37-cp37m-linux_x86_64.whl (2.4 MB)
#      |████████████████████████████████| 2.4 MB 15.6 MB/s
# Installing collected packages: torch-cluster
# Successfully installed torch-cluster-1.6.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting deepdish==0.3.5
#   Downloading deepdish-0.3.5-py2.py3-none-any.whl (37 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.7.3)
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (3.7.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.21.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (21.3)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (2.8.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tables->deepdish==0.3.5) (3.0.9)
# Installing collected packages: deepdish
# Successfully installed deepdish-0.3.5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch-optimizer
#   Downloading torch_optimizer-0.3.0-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 429 kB/s
# Collecting pytorch-ranger>=0.1.1
#   Downloading pytorch_ranger-0.1.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: torch>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from torch-optimizer) (1.12.1+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.5.0->torch-optimizer) (4.1.1)
# Installing collected packages: pytorch-ranger, torch-optimizer
# Successfully installed pytorch-ranger-0.1.1 torch-optimizer-0.3.0

# %%
def time_since(start):
    now = time.time()
    s = now - start
    m = math.floor(s / 60)
    s -= m * 60
    h = math.floor(m / 60)
    m -= h * 60
    if h == 0:
        if m == 0:
            return '%ds' % s
        else:
            return '%dm %ds' % (m, s)
    else:
        return '%dh %dm %ds' % (h, m, s)

# %% [markdown]
# # II. Data

# %%
# Data utils
def h5group_to_dict(h5group):
    group_dict = {k: v[()] for k, v in chain(h5group.items(), h5group.attrs.items())}
    return group_dict

def sub_dict(full_dict, *keys, to_tensor):
    return {k: torch.tensor(full_dict[k]) if to_tensor else full_dict[k] for k in keys if k in full_dict}

def build_graph_from_dict_pyg(graph_dict, to_tensor=True):
    from torch_geometric.data import Data

    g = Data(**sub_dict(graph_dict, 'edge_index', 'x', 'y', 'edge_attr', 'edge_y', to_tensor=to_tensor))
    return g

# Data loader
class GraphDataLoader(DataLoader):
    def __init__(self, dataset, batch_size=128, shuffle=False, num_workers=0):

        def collate_graph(graph_obj_list):
            from torch_geometric.data import Batch
            batch = Batch.from_data_list(graph_obj_list)
            return batch

        super().__init__(
            dataset,
            batch_size=batch_size,
            shuffle=shuffle,
            collate_fn=collate_graph,
            num_workers=num_workers)

# BotnetDataset
class BotnetDataset(Dataset):

    def __init__(self, name='chord', root='data/botnet', split='train', graph_format='pyg', split_idx=None, add_nfeat_ones=True,
                 in_memory=True):
        super().__init__()
        assert name in ['chord', 'debru', 'kadem', 'leet', 'c2', 'p2p']
        assert split in ['train', 'val', 'test']

        if isinstance(root, str):
            root = osp.expanduser(osp.normpath(root))

        self.name = name
        self.root = root
        self.split = split
        self.split_idx = split_idx
        self.add_nfeat_ones = add_nfeat_ones

        self._graph_format = graph_format
        if split == 'train':
            self.path = self.processed_paths[0]
            self.num_graphs = 768
        elif split == 'val':
            self.path = self.processed_paths[1]
            self.num_graphs = 96
        elif split == 'test':
            self.path = self.processed_paths[2]
            self.num_graphs = 96

        if in_memory:
            self.data = dd.io.load(self.path)  # dictionary
            self.data_type = 'dict'
        else:
            # self.data = h5py.File(self.path, 'r')
            self.data = None    # defer opening file in each process to make multiprocessing work
            self.data_type = 'file'
            
    @property
    def processed_dir(self):
        return osp.join(self.root, 'processed')

    @property
    def processed_file_names(self):
        return [self.name + '_' + s + '.hdf5' for s in ('train', 'val', 'test')]

    @property
    def processed_paths(self):
        return [osp.join(self.processed_dir, f) for f in self.processed_file_names]

    def __len__(self):
        return self.num_graphs

    def __getitem__(self, index):
        if self.data_type == 'dict':
            graph_dict = self.data[str(index)]
        elif self.data_type == 'file':
            if self.data is None:
                # only open once in each process
                self.data = h5py.File(self.path, 'r')
            graph_dict = h5group_to_dict(self.data[str(index)])
        else:
            raise ValueError

        # graph_format == 'pyg':
        return build_graph_from_dict_pyg(graph_dict)


    def __iter__(self):
        for i in range(self.num_graphs):
            yield self[i]

    def __repr__(self):
        return f'{self.__class__.__name__}(topology: {self.name} | split: {self.split} | ' \
               f'#graphs: {len(self)} | graph format: {self.graph_format})'

# %% [markdown]
# # III. Measure Performancce

# %% [markdown]
# ## 3.1. Metrics

# %%
def f1(target, pred, label):
    # F1 = 2 * (precision * recall) / (precision + recall)
    tp = np.sum((target==label) & (pred==label))
    fp = np.sum((target!=label) & (pred==label))
    fn = np.sum((pred!=label) & (target==label))
    
    if tp+fp==0 or tp+fn==0:
      return np.nan

    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    
    if precision+recall==0:
      return np.nan
      
    f1 = 2 * (precision * recall) / (precision + recall)
    return f1

def f1_macro(pred, target):
    return np.mean([f1(target, pred, label) for label in range(0, 2)])


def accuracy(pred, target):
    return (pred == target).sum().item() / len(target)


def true_positive(pred, target):
    return (target[pred == 1] == 1).sum().item()


def false_positive(pred, target):
    return (target[pred == 1] == 0).sum().item()


def true_negative(pred, target):
    return (target[pred == 0] == 0).sum().item()


def false_negative(pred, target):
    return (target[pred == 0] == 1).sum().item()


def recall(pred, target):
    try:
        return true_positive(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1


def precision(pred, target):
    try:
        prec = true_positive(pred, target) / (pred == 1).sum().item()
        return prec
    except:  # divide by zero
        return -1


def f1_score(pred, target):
    prec = precision(pred, target)
    rec = recall(pred, target)
    try:
        return 2 * (prec * rec) / (prec + rec)
    except:
        return 0


def false_positive_rate(pred, target):
    try:
        return false_positive(pred, target) / (target == 0).sum().item()
    except:  # divide by zero
        return -1


def false_negative_rate(pred, target):
    try:
        return false_negative(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1

# %% [markdown]
# ## 3.2. Evaluation

# %%
def eval_metrics(target, pred_prob, threshold=0.5):
    if isinstance(target, torch.Tensor):
        target = target.cpu().numpy()
    if isinstance(pred_prob, torch.Tensor):
        pred_prob = pred_prob.cpu().numpy()

    pred = (pred_prob >= threshold).astype(int)

    acc = accuracy(pred, target)
    fpr = false_positive_rate(pred, target)
    fnr = false_negative_rate(pred, target)
    rec = recall(pred, target)
    prc = precision(pred, target)
    f1 = f1_score(pred, target)
    f1macro = f1_macro(pred, target)
    result_dict = {'acc': acc, 'fpr': fpr, 'fnr': fnr, 'rec': rec, 'prc': prc, 'f1': f1, 'f1_macro': f1macro}

    return result_dict


def dict_value_add(dict1, dict2):
    result = {key: dict1.get(key, 0) + dict2.get(key, 0)
              for key in set(dict1) | set(dict2)}
    return result


def dict_value_div(dict, n):
    result = {key: value / n for key, value in dict.items()}
    return result


def eval_predictor(dataset, predictor):
    result_dict_avg = {}
    loss_avg = 0

    for data in dataset:
        # prediction
        try:
            pred_prob, loss = predictor(data)
            loss_avg += loss
        except ValueError:  # if "too many values to unpack"
            pred_prob = predictor(data)

        # get the ground truth target
        # graph_format == 'pyg':
        target = data.y

        # compute the evaluation metrics
        result_dict = eval_metrics(target, pred_prob)

        result_dict_avg = dict_value_add(result_dict_avg, result_dict)

    # average the metrics across all graphs in the dataset as final results
    result_dict_avg = dict_value_div(result_dict_avg, len(dataset))
    loss_avg = loss_avg / len(dataset)

    return result_dict_avg, loss_avg


# =================================================================================================================
# some examples of the 'predictor' model wrapper to be fed into the above evaluation function (for PyG Data format)
# =================================================================================================================
class PygRandomPredictor:
    def __init__(self):
        # torch.manual_seed(0)
        pass

    def __call__(self, data):
        pred_prob = torch.rand(len(data.y))
        return pred_prob


class PygModelPredictor:
    def __init__(self, model, loss_fcn=torch.nn.CrossEntropyLoss()):
        self.model = model
        self.loss_fcn = loss_fcn
        self.device = next(model.parameters()).device

    def __call__(self, data):
        self.model.eval()
        data = data.to(self.device)
        with torch.no_grad():
            # custom the below line to adjust to your model's input format for forward pass
            out = self.model(data.x, data.edge_index)
            loss = self.loss_fcn(out, data.y.long())
            pred_prob = torch.softmax(out, dim=1)[:, 1]
        return pred_prob, loss.float()

# %% [markdown]
# # IV. Model

# %% [markdown]
# ## 5.1. Activation

# %%
def activation(act, negative_slope=0.2):
    activations = nn.ModuleDict([
        ['lrelu', nn.LeakyReLU(negative_slope)],
        ['relu', nn.ReLU()],
        ['elu', nn.ELU()],
        ['none', nn.Identity()],
    ])
    return activations[act]

# %% [markdown]
# ## 5.2. GIN model

# %%
from torch.nn.modules.activation import LeakyReLU
import torch.nn as nn

class GINModel(nn.Module):
    def __init__(self, dim_input_feature, dim_hidden_feature, num_layers, num_classes, non_linear='relu', dropout=0.2):
        super().__init__()

        self.dim_input_feature = dim_input_feature
        self.dim_hidden_feature = dim_hidden_feature

        self.num_layers = num_layers
        self.num_classes = num_classes
        
        from torch.nn import Linear, Sequential, BatchNorm1d, ReLU, Dropout
        from torch_geometric.nn import GATv2Conv, GINConv, TransformerConv, GENConv
        
        self.gin_net = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.gin_net.append(GENConv(self.dim_input_feature, self.dim_hidden_feature, aggr='powermean'))
          else:
            self.gin_net.append(GENConv(self.dim_hidden_feature, self.dim_hidden_feature, aggr='powermean'))


        self.dropout = nn.Dropout(dropout)

        self.residuals = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.residuals.append(nn.Linear(self.dim_input_feature, self.dim_hidden_feature, bias=True))
          else:
            self.residuals.append(nn.Identity())

        self.num_residuals = len(self.residuals)

        self.non_linear = activation(non_linear)

        # self.final_type == 'proj':
        self.final = nn.Linear(self.dim_hidden_feature, num_classes)

    def reset_parameters(self):
        for net in self.gin_net:
            net.reset_parameters()
        # self.residual_hop = 1
        for net in self.residuals:
            net.reset_parameters()
        # self.final_type != 'none':
        self.final.reset_parameters()

    def forward(self, x, edge_index):
        xr = None
        add_xr_at = -1

        for n, net in enumerate(self.gin_net):
            # pass to a GIN layer with non-linear activation
            xo = net(x, edge_index)
            xo = self.dropout(xo)
            # deal with residual connections
            # self.residual_hop = 1
            if n < self.num_residuals:
                xr = self.residuals[n](x)
                xo = self.non_linear(xo + xr)

            x = xo
        # size of x: (B * N, dim_hidden_feature) -> (B * N, num_classes)
        x = self.final(x)

        return x

# %% [markdown]
# # V. Load data

# %%
data_dir = '/content/drive/Shareddrives/botnetdata/p2p_normalization'
data_name = 'p2p' # 'chord', 'debru', 'kadem', 'leet', 'c2', 'p2p'
shuffle = False

# ========== load the dataset
print('loading dataset...')

train_ds = BotnetDataset(name=data_name, root=data_dir, split='train',
                         in_memory=False, graph_format='pyg')
val_ds = BotnetDataset(name=data_name, root=data_dir, split='val',
                       in_memory=False, graph_format='pyg')
test_ds = BotnetDataset(name=data_name, root=data_dir, split='test',
                        in_memory=False, graph_format='pyg')
# Out:
# loading dataset...

# %%
batch_size = 1
train_loader = GraphDataLoader(train_ds, batch_size=batch_size, shuffle=bool(shuffle), num_workers=0)

# %% [markdown]
# # VI. Train

# %%
# ============== some default parameters =============
devid = 0
seed = 0
logmode = 'w'
log_interval = 96

dim_input_feature = 1
dim_hidden_feature = 32
act = 'relu' # 'none', 'lrelu', 'relu', 'elu'

num_layers = 12
num_classes = 2 

dropout = 0.0
bias = True

lr = 0.005 # learning rate
weight_decay = 5e-4
epochs = 50
save_dir = './saved_models'
save_name = "GIN_model.pt"
# ====================================================

def train(model, train_loader, val_dataset, test_dataset, optimizer, scheduler=None):
    device = next(model.parameters()).device
    predictor = PygModelPredictor(model)

    best_epoch = 0
    max_f1_score = 0
    start = time.time()
    for ep in range(epochs):
        loss_avg_train = 0
        num_train_graph = 0
        model.train()
        for n, batch in enumerate(train_loader):
            batch.to(device)

            optimizer.zero_grad()

            x = model(batch.x, batch.edge_index)
            loss = criterion(x, batch.y.long())

            loss_avg_train += float(loss)
            num_train_graph += batch.num_graphs

            loss.backward()
            optimizer.step()

            if num_train_graph % log_interval == 0 or n == len(train_loader) - 1:
                with torch.no_grad():
                    # pred = x.argmax(dim=1)
                    pred_prob = torch.softmax(x, dim=1)[:, 1]
                    y = batch.y.long()
                    result_dict = eval_metrics(y, pred_prob)
                print(f'epoch: {ep + 1}, passed number of graphs: {num_train_graph}, '
                        f'train running loss: {loss_avg_train / num_train_graph:.5f} (passed time: {time_since(start)})')
                print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict.items()]))

        result_dict_avg, loss_avg = eval_predictor(val_dataset, predictor)
        print(f'Validation --- epoch: {ep + 1}, loss: {loss_avg:.5f}')
        print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))

        if scheduler is not None:
            scheduler.step(loss_avg)

        if result_dict_avg['f1'] > max_f1_score:
            save_name = f"GIN_{ep}: {result_dict_avg['f1']}.pt"
            torch.save(model, os.path.join(save_dir, save_name))
            print(f'Better model saved at {os.path.join(save_dir, save_name)}.')
            best_epoch = ep
            max_f1_score = result_dict_avg['f1']

    best_model = torch.load(os.path.join(save_dir, save_name))
    print('*' * 12 + f' best model obtained after epoch {best_epoch + 1}, '
                       f'saved at {os.path.join(save_dir, save_name)} ' + '*' * 12)
    
    predictor = PygModelPredictor(best_model)

    result_dict_avg, loss_avg = eval_predictor(test_dataset, predictor)
    print(f'Testing --- loss: {loss_avg:.5f}')
    print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))


if __name__ == '__main__':
    os.makedirs(save_dir, exist_ok=True)

    # ========== random seeds and device
    random.seed(seed)
    torch.manual_seed(seed)

    device = torch.device(f'cuda:{devid}') if devid > -1 else torch.device('cpu')

    # ========== logging setup
    log_name = os.path.splitext(save_name)[0]
    # logger = logging_config(__name__, folder=save_dir, name=log_name, filemode=logmode)
    # logger = logging_config(os.path.basename(__file__), folder=save_dir, name=log_name, filemode=logmode)

    print('python ' + ' '.join(sys.argv))
    print('-' * 30)
    #logger.info(args)
    print('-' * 30)
    print(time.ctime())
    print('-' * 30)

    # ========== define the model, optimizer, and loss

    model = GINModel(dim_input_feature,
                     dim_hidden_feature,
                     num_layers,
                     num_classes,
                     non_linear=act,
                     dropout=dropout)

    print('model ' + '-' * 10)
    print(repr(model))
    model.to(device)

    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.25, patience=1)

    # ========== train the model
    print(f"Batch size: {batch_size}")
    train(model, train_loader, val_ds, test_ds, optimizer, scheduler)
# Out:
# python /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-aa6fd58f-0539-4cb5-9121-b7963142c3bf.json
# ------------------------------
# ------------------------------
# Fri Nov  4 01:43:44 2022
# ------------------------------
# model ----------
# GINModel(
#   (gin_net): ModuleList(
#     (0): GENConv(1, 32, aggr=powermean)
#     (1): GENConv(32, 32, aggr=powermean)
#     (2): GENConv(32, 32, aggr=powermean)
#     (3): GENConv(32, 32, aggr=powermean)
#     (4): GENConv(32, 32, aggr=powermean)
#     (5): GENConv(32, 32, aggr=powermean)
#     (6): GENConv(32, 32, aggr=powermean)
#     (7): GENConv(32, 32, aggr=powermean)
#     (8): GENConv(32, 32, aggr=powermean)
#     (9): GENConv(32, 32, aggr=powermean)
#     (10): GENConv(32, 32, aggr=powermean)
#     (11): GENConv(32, 32, aggr=powermean)
#   )
#   (dropout): Dropout(p=0.0, inplace=False)
#   (residuals): ModuleList(
#     (0): Linear(in_features=1, out_features=32, bias=True)
#     (1): Identity()
#     (2): Identity()
#     (3): Identity()
#     (4): Identity()
#     (5): Identity()
#     (6): Identity()
#     (7): Identity()
#     (8): Identity()
#     (9): Identity()
#     (10): Identity()
#     (11): Identity()
#   )
#   (non_linear): ReLU()
#   (final): Linear(in_features=32, out_features=2, bias=True)
# )
# Batch size: 1
# epoch: 1, passed number of graphs: 96, train running loss: 0.09033 (passed time: 1m 57s)
#           acc: 0.97869, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 192, train running loss: 0.05871 (passed time: 2m 30s)
#           acc: 0.99525, fpr: 0.00200, fnr: 0.13215, rec: 0.86785, prc: 0.90380, f1: 0.88546, f1_macro: 0.94152
# epoch: 1, passed number of graphs: 288, train running loss: 0.04430 (passed time: 3m 1s)
#           acc: 0.99746, fpr: 0.00017, fnr: 0.11450, rec: 0.88550, prc: 0.99119, f1: 0.93537, f1_macro: 0.96704
# epoch: 1, passed number of graphs: 384, train running loss: 0.04168 (passed time: 3m 34s)
#           acc: 0.99341, fpr: 0.00469, fnr: 0.09041, rec: 0.90959, prc: 0.81440, f1: 0.85937, f1_macro: 0.92800
# epoch: 1, passed number of graphs: 480, train running loss: 0.03869 (passed time: 4m 7s)
#           acc: 0.99345, fpr: 0.00007, fnr: 0.29984, rec: 0.70016, prc: 0.99536, f1: 0.82206, f1_macro: 0.90936
# epoch: 1, passed number of graphs: 576, train running loss: 0.03427 (passed time: 4m 39s)
#           acc: 0.99298, fpr: 0.00616, fnr: 0.04603, rec: 0.95397, prc: 0.77244, f1: 0.85366, f1_macro: 0.92503
# epoch: 1, passed number of graphs: 672, train running loss: 0.03146 (passed time: 5m 12s)
#           acc: 0.99044, fpr: 0.00054, fnr: 0.42650, rec: 0.57350, prc: 0.95860, f1: 0.71765, f1_macro: 0.85639
# epoch: 1, passed number of graphs: 768, train running loss: 0.02921 (passed time: 5m 41s)
#           acc: 0.99274, fpr: 0.00501, fnr: 0.11002, rec: 0.88998, prc: 0.79568, f1: 0.84019, f1_macro: 0.91824
# Validation --- epoch: 1, loss: 0.15569
#           fpr: 0.00483, fnr: 0.99818, acc: 0.97379, prc: -0.50535, rec: 0.00182, f1: 0.00087, f1_macro: nan
# Better model saved at ./saved_models/GIN_0: 0.0008698344175494597.pt.
# epoch: 2, passed number of graphs: 96, train running loss: 0.00756 (passed time: 6m 42s)
#           acc: 0.98935, fpr: 0.00940, fnr: 0.06809, rec: 0.93191, prc: 0.68331, f1: 0.78848, f1_macro: 0.89151
# epoch: 2, passed number of graphs: 192, train running loss: 0.00868 (passed time: 7m 9s)
#           acc: 0.99936, fpr: 0.00001, fnr: 0.02991, rec: 0.97009, prc: 0.99966, f1: 0.98465, f1_macro: 0.99216
# epoch: 2, passed number of graphs: 288, train running loss: 0.01269 (passed time: 7m 36s)
#           acc: 0.98250, fpr: 0.01191, fnr: 0.28084, rec: 0.71916, prc: 0.56133, f1: 0.63052, f1_macro: 0.81078
# epoch: 2, passed number of graphs: 384, train running loss: 0.01709 (passed time: 8m 3s)
#           acc: 0.97791, fpr: 0.00882, fnr: 0.60865, rec: 0.39135, prc: 0.50103, f1: 0.43945, f1_macro: 0.71409
# epoch: 2, passed number of graphs: 480, train running loss: 0.01861 (passed time: 8m 30s)
#           acc: 0.99695, fpr: 0.00053, fnr: 0.11746, rec: 0.88254, prc: 0.97372, f1: 0.92589, f1_macro: 0.96217
# epoch: 2, passed number of graphs: 576, train running loss: 0.01855 (passed time: 8m 58s)
#           acc: 0.98802, fpr: 0.00827, fnr: 0.18152, rec: 0.81848, prc: 0.68465, f1: 0.74561, f1_macro: 0.86974
# epoch: 2, passed number of graphs: 672, train running loss: 0.01815 (passed time: 9m 25s)
#           acc: 0.99767, fpr: 0.00089, fnr: 0.06883, rec: 0.93117, prc: 0.95766, f1: 0.94423, f1_macro: 0.97152
# epoch: 2, passed number of graphs: 768, train running loss: 0.01731 (passed time: 9m 52s)
#           acc: 0.98661, fpr: 0.00781, fnr: 0.26804, rec: 0.73196, prc: 0.67267, f1: 0.70106, f1_macro: 0.84711
# Validation --- epoch: 2, loss: 20.45537
#           fpr: 0.92375, fnr: 0.00021, acc: 0.09611, prc: 0.02329, rec: 0.99979, f1: 0.04552, f1_macro: 0.09256
# Better model saved at ./saved_models/GIN_1: 0.04551941025907505.pt.
# epoch: 3, passed number of graphs: 96, train running loss: 0.01402 (passed time: 10m 45s)
#           acc: 0.99080, fpr: 0.00739, fnr: 0.09207, rec: 0.90793, prc: 0.72783, f1: 0.80797, f1_macro: 0.90163
# epoch: 3, passed number of graphs: 192, train running loss: 0.01916 (passed time: 11m 12s)
#           acc: 0.99343, fpr: 0.00485, fnr: 0.08580, rec: 0.91420, prc: 0.80283, f1: 0.85490, f1_macro: 0.92577
# epoch: 3, passed number of graphs: 288, train running loss: 0.01733 (passed time: 11m 39s)
#           acc: 0.99804, fpr: 0.00015, fnr: 0.08727, rec: 0.91273, prc: 0.99215, f1: 0.95079, f1_macro: 0.97489
# epoch: 3, passed number of graphs: 384, train running loss: 0.01523 (passed time: 12m 7s)
#           acc: 0.99272, fpr: 0.00672, fnr: 0.03197, rec: 0.96803, prc: 0.76519, f1: 0.85474, f1_macro: 0.92550
# epoch: 3, passed number of graphs: 480, train running loss: 0.01354 (passed time: 12m 35s)
#           acc: 0.99861, fpr: 0.00004, fnr: 0.06264, rec: 0.93736, prc: 0.99826, f1: 0.96685, f1_macro: 0.98307
# epoch: 3, passed number of graphs: 576, train running loss: 0.01331 (passed time: 13m 2s)
#           acc: 0.99943, fpr: 0.00009, fnr: 0.02237, rec: 0.97763, prc: 0.99571, f1: 0.98659, f1_macro: 0.99315
# epoch: 3, passed number of graphs: 672, train running loss: 0.01867 (passed time: 13m 30s)
#           acc: 0.99267, fpr: 0.00370, fnr: 0.17498, rec: 0.82502, prc: 0.82822, f1: 0.82662, f1_macro: 0.91144
# epoch: 3, passed number of graphs: 768, train running loss: 0.01925 (passed time: 13m 58s)
#           acc: 0.99253, fpr: 0.00563, fnr: 0.09141, rec: 0.90859, prc: 0.77955, f1: 0.83914, f1_macro: 0.91766
# Validation --- epoch: 3, loss: 2.04491
#           fpr: 0.66401, fnr: 0.00318, acc: 0.35021, prc: 0.03201, rec: 0.99682, f1: 0.06202, f1_macro: 0.28225
# Better model saved at ./saved_models/GIN_2: 0.06201881356305255.pt.
# epoch: 4, passed number of graphs: 96, train running loss: 0.01030 (passed time: 14m 52s)
#           acc: 0.99532, fpr: 0.00011, fnr: 0.21451, rec: 0.78549, prc: 0.99353, f1: 0.87734, f1_macro: 0.93748
# epoch: 4, passed number of graphs: 192, train running loss: 0.01082 (passed time: 15m 19s)
#           acc: 0.99363, fpr: 0.00308, fnr: 0.15878, rec: 0.84122, prc: 0.85528, f1: 0.84819, f1_macro: 0.92247
# epoch: 4, passed number of graphs: 288, train running loss: 0.01315 (passed time: 15m 46s)
#           acc: 0.99845, fpr: 0.00008, fnr: 0.07054, rec: 0.92946, prc: 0.99578, f1: 0.96148, f1_macro: 0.98035
# epoch: 4, passed number of graphs: 384, train running loss: 0.01185 (passed time: 16m 13s)
#           acc: 0.99846, fpr: 0.00055, fnr: 0.04521, rec: 0.95479, prc: 0.97526, f1: 0.96492, f1_macro: 0.98207
# epoch: 4, passed number of graphs: 480, train running loss: 0.01089 (passed time: 16m 41s)
#           acc: 0.99907, fpr: 0.00008, fnr: 0.03948, rec: 0.96052, prc: 0.99628, f1: 0.97807, f1_macro: 0.98880
# epoch: 4, passed number of graphs: 576, train running loss: 0.00981 (passed time: 17m 9s)
#           acc: 0.99929, fpr: 0.00013, fnr: 0.02723, rec: 0.97277, prc: 0.99404, f1: 0.98329, f1_macro: 0.99146
# epoch: 4, passed number of graphs: 672, train running loss: 0.00944 (passed time: 17m 38s)
#           acc: 0.99879, fpr: 0.00058, fnr: 0.03056, rec: 0.96944, prc: 0.97320, f1: 0.97132, f1_macro: 0.98535
# epoch: 4, passed number of graphs: 768, train running loss: 0.00885 (passed time: 18m 5s)
#           acc: 0.99901, fpr: 0.00034, fnr: 0.03102, rec: 0.96898, prc: 0.98441, f1: 0.97664, f1_macro: 0.98806
# Validation --- epoch: 4, loss: 0.01051
#           fpr: 0.00144, fnr: 0.02720, acc: 0.99800, prc: 0.95398, rec: 0.97280, f1: 0.95933, f1_macro: 0.97915
# Better model saved at ./saved_models/GIN_3: 0.9593292840636528.pt.
# epoch: 5, passed number of graphs: 96, train running loss: 0.00660 (passed time: 18m 58s)
#           acc: 0.99918, fpr: 0.00004, fnr: 0.03676, rec: 0.96324, prc: 0.99801, f1: 0.98032, f1_macro: 0.98995
# epoch: 5, passed number of graphs: 192, train running loss: 0.00577 (passed time: 19m 26s)
#           acc: 0.99940, fpr: 0.00011, fnr: 0.02301, rec: 0.97699, prc: 0.99465, f1: 0.98574, f1_macro: 0.99272
# epoch: 5, passed number of graphs: 288, train running loss: 0.00508 (passed time: 19m 53s)
#           acc: 0.99964, fpr: 0.00002, fnr: 0.01640, rec: 0.98360, prc: 0.99900, f1: 0.99124, f1_macro: 0.99553
# epoch: 5, passed number of graphs: 384, train running loss: 0.00514 (passed time: 20m 21s)
#           acc: 0.99418, fpr: 0.00435, fnr: 0.07104, rec: 0.92896, prc: 0.82863, f1: 0.87593, f1_macro: 0.93648
# epoch: 5, passed number of graphs: 480, train running loss: 0.00561 (passed time: 20m 48s)
#           acc: 0.99939, fpr: 0.00006, fnr: 0.02512, rec: 0.97488, prc: 0.99700, f1: 0.98581, f1_macro: 0.99275
# epoch: 5, passed number of graphs: 576, train running loss: 0.00526 (passed time: 21m 15s)
#           acc: 0.99362, fpr: 0.00571, fnr: 0.03695, rec: 0.96305, prc: 0.78702, f1: 0.86618, f1_macro: 0.93146
# epoch: 5, passed number of graphs: 672, train running loss: 0.00555 (passed time: 21m 43s)
#           acc: 0.99755, fpr: 0.00205, fnr: 0.02091, rec: 0.97909, prc: 0.91165, f1: 0.94417, f1_macro: 0.97146
# epoch: 5, passed number of graphs: 768, train running loss: 0.00545 (passed time: 22m 11s)
#           acc: 0.99896, fpr: 0.00051, fnr: 0.02547, rec: 0.97453, prc: 0.97677, f1: 0.97565, f1_macro: 0.98756
# Validation --- epoch: 5, loss: 0.01027
#           fpr: 0.00010, fnr: 0.09589, acc: 0.99784, prc: 0.99479, rec: 0.90411, f1: 0.94436, f1_macro: 0.97163
# epoch: 6, passed number of graphs: 96, train running loss: 0.00429 (passed time: 23m 4s)
#           acc: 0.99956, fpr: 0.00006, fnr: 0.01822, rec: 0.98178, prc: 0.99740, f1: 0.98953, f1_macro: 0.99465
# epoch: 6, passed number of graphs: 192, train running loss: 0.03303 (passed time: 23m 31s)
#           acc: 0.98961, fpr: 0.00343, fnr: 0.33202, rec: 0.66798, prc: 0.80795, f1: 0.73133, f1_macro: 0.86302
# epoch: 6, passed number of graphs: 288, train running loss: 0.02742 (passed time: 23m 59s)
#           acc: 0.99834, fpr: 0.00023, fnr: 0.06923, rec: 0.93077, prc: 0.98850, f1: 0.95877, f1_macro: 0.97896
# epoch: 6, passed number of graphs: 384, train running loss: 0.02272 (passed time: 24m 26s)
#           acc: 0.99541, fpr: 0.00377, fnr: 0.04101, rec: 0.95899, prc: 0.85198, f1: 0.90232, f1_macro: 0.94999
# epoch: 6, passed number of graphs: 480, train running loss: 0.01920 (passed time: 24m 53s)
#           acc: 0.99934, fpr: 0.00008, fnr: 0.02708, rec: 0.97292, prc: 0.99632, f1: 0.98448, f1_macro: 0.99207
# epoch: 6, passed number of graphs: 576, train running loss: 0.01676 (passed time: 25m 20s)
#           acc: 0.99937, fpr: 0.00019, fnr: 0.02075, rec: 0.97925, prc: 0.99114, f1: 0.98516, f1_macro: 0.99242
# epoch: 6, passed number of graphs: 672, train running loss: 0.01513 (passed time: 25m 48s)
#           acc: 0.99903, fpr: 0.00062, fnr: 0.01737, rec: 0.98263, prc: 0.97169, f1: 0.97713, f1_macro: 0.98832
# epoch: 6, passed number of graphs: 768, train running loss: 0.01370 (passed time: 26m 15s)
#           acc: 0.99930, fpr: 0.00031, fnr: 0.01861, rec: 0.98139, prc: 0.98590, f1: 0.98364, f1_macro: 0.99164
# Validation --- epoch: 6, loss: 0.00526
#           fpr: 0.00021, fnr: 0.03483, acc: 0.99904, prc: 0.99110, rec: 0.96517, f1: 0.97637, f1_macro: 0.98794
# Better model saved at ./saved_models/GIN_5: 0.9763706152751599.pt.
# epoch: 7, passed number of graphs: 96, train running loss: 0.00584 (passed time: 27m 10s)
#           acc: 0.99914, fpr: 0.00040, fnr: 0.02174, rec: 0.97826, prc: 0.98140, f1: 0.97983, f1_macro: 0.98969
# epoch: 7, passed number of graphs: 192, train running loss: 0.00527 (passed time: 27m 37s)
#           acc: 0.99951, fpr: 0.00012, fnr: 0.01742, rec: 0.98258, prc: 0.99434, f1: 0.98843, f1_macro: 0.99409
# epoch: 7, passed number of graphs: 288, train running loss: 0.00458 (passed time: 28m 5s)
#           acc: 0.99945, fpr: 0.00009, fnr: 0.02231, rec: 0.97769, prc: 0.99566, f1: 0.98659, f1_macro: 0.99316
# epoch: 7, passed number of graphs: 384, train running loss: 0.00417 (passed time: 28m 32s)
#           acc: 0.99961, fpr: 0.00004, fnr: 0.01582, rec: 0.98418, prc: 0.99804, f1: 0.99106, f1_macro: 0.99543
# epoch: 7, passed number of graphs: 480, train running loss: 0.00396 (passed time: 28m 59s)
#           acc: 0.99967, fpr: 0.00006, fnr: 0.01272, rec: 0.98728, prc: 0.99736, f1: 0.99229, f1_macro: 0.99606
# epoch: 7, passed number of graphs: 576, train running loss: 0.00382 (passed time: 29m 27s)
#           acc: 0.99841, fpr: 0.00063, fnr: 0.04506, rec: 0.95494, prc: 0.97068, f1: 0.96275, f1_macro: 0.98097
# epoch: 7, passed number of graphs: 672, train running loss: 0.00412 (passed time: 29m 55s)
#           acc: 0.99905, fpr: 0.00060, fnr: 0.01737, rec: 0.98263, prc: 0.97262, f1: 0.97760, f1_macro: 0.98856
# epoch: 7, passed number of graphs: 768, train running loss: 0.00401 (passed time: 30m 22s)
#           acc: 0.99940, fpr: 0.00032, fnr: 0.01339, rec: 0.98661, prc: 0.98533, f1: 0.98597, f1_macro: 0.99283
# Validation --- epoch: 7, loss: 0.00790
#           fpr: 0.00021, fnr: 0.03019, acc: 0.99914, prc: 0.99092, rec: 0.96981, f1: 0.97881, f1_macro: 0.98919
# Better model saved at ./saved_models/GIN_6: 0.9788066881583047.pt.
# epoch: 8, passed number of graphs: 96, train running loss: 0.00550 (passed time: 31m 16s)
#           acc: 0.99300, fpr: 0.00251, fnr: 0.21324, rec: 0.78676, prc: 0.87208, f1: 0.82723, f1_macro: 0.91183
# epoch: 8, passed number of graphs: 192, train running loss: 0.00699 (passed time: 31m 43s)
#           acc: 0.99930, fpr: 0.00011, fnr: 0.02794, rec: 0.97206, prc: 0.99495, f1: 0.98337, f1_macro: 0.99151
# epoch: 8, passed number of graphs: 288, train running loss: 0.00562 (passed time: 32m 11s)
#           acc: 0.99973, fpr: 0.00003, fnr: 0.01148, rec: 0.98852, prc: 0.99834, f1: 0.99341, f1_macro: 0.99663
# epoch: 8, passed number of graphs: 384, train running loss: 0.00478 (passed time: 32m 38s)
#           acc: 0.99973, fpr: 0.00002, fnr: 0.01130, rec: 0.98870, prc: 0.99902, f1: 0.99383, f1_macro: 0.99685
# epoch: 8, passed number of graphs: 480, train running loss: 0.00421 (passed time: 33m 5s)
#           acc: 0.99973, fpr: 0.00004, fnr: 0.01077, rec: 0.98923, prc: 0.99803, f1: 0.99361, f1_macro: 0.99673
# epoch: 8, passed number of graphs: 576, train running loss: 0.00404 (passed time: 33m 33s)
#           acc: 0.99906, fpr: 0.00020, fnr: 0.03468, rec: 0.96532, prc: 0.99069, f1: 0.97784, f1_macro: 0.98868
# epoch: 8, passed number of graphs: 672, train running loss: 0.00431 (passed time: 34m 1s)
#           acc: 0.99905, fpr: 0.00070, fnr: 0.01287, rec: 0.98713, prc: 0.96844, f1: 0.97770, f1_macro: 0.98861
# epoch: 8, passed number of graphs: 768, train running loss: 0.00415 (passed time: 34m 28s)
#           acc: 0.99957, fpr: 0.00019, fnr: 0.01110, rec: 0.98890, prc: 0.99116, f1: 0.99003, f1_macro: 0.99491
# Validation --- epoch: 8, loss: 0.00546
#           fpr: 0.00021, fnr: 0.03798, acc: 0.99898, prc: 0.99246, rec: 0.96202, f1: 0.97447, f1_macro: 0.98698
# epoch: 9, passed number of graphs: 96, train running loss: 0.00237 (passed time: 35m 21s)
#           acc: 0.99975, fpr: 0.00009, fnr: 0.00767, rec: 0.99233, prc: 0.99583, f1: 0.99408, f1_macro: 0.99697
# epoch: 9, passed number of graphs: 192, train running loss: 0.00222 (passed time: 35m 49s)
#           acc: 0.99976, fpr: 0.00003, fnr: 0.00986, rec: 0.99014, prc: 0.99867, f1: 0.99439, f1_macro: 0.99713
# epoch: 9, passed number of graphs: 288, train running loss: 0.00200 (passed time: 36m 16s)
#           acc: 0.99981, fpr: 0.00005, fnr: 0.00689, rec: 0.99311, prc: 0.99769, f1: 0.99540, f1_macro: 0.99765
# epoch: 9, passed number of graphs: 384, train running loss: 0.00192 (passed time: 36m 44s)
#           acc: 0.99974, fpr: 0.00004, fnr: 0.01001, rec: 0.98999, prc: 0.99837, f1: 0.99416, f1_macro: 0.99702
# epoch: 9, passed number of graphs: 480, train running loss: 0.00190 (passed time: 37m 11s)
#           acc: 0.99982, fpr: 0.00005, fnr: 0.00620, rec: 0.99380, prc: 0.99771, f1: 0.99575, f1_macro: 0.99783
# epoch: 9, passed number of graphs: 576, train running loss: 0.00184 (passed time: 37m 39s)
#           acc: 0.99986, fpr: 0.00004, fnr: 0.00454, rec: 0.99546, prc: 0.99805, f1: 0.99675, f1_macro: 0.99834
# epoch: 9, passed number of graphs: 672, train running loss: 0.00214 (passed time: 38m 6s)
#           acc: 0.99922, fpr: 0.00065, fnr: 0.00675, rec: 0.99325, prc: 0.97046, f1: 0.98172, f1_macro: 0.99066
# epoch: 9, passed number of graphs: 768, train running loss: 0.00225 (passed time: 38m 33s)
#           acc: 0.99959, fpr: 0.00017, fnr: 0.01110, rec: 0.98890, prc: 0.99214, f1: 0.99052, f1_macro: 0.99515
# Validation --- epoch: 9, loss: 0.01141
#           fpr: 0.00011, fnr: 0.09053, acc: 0.99796, prc: 0.99497, rec: 0.90947, f1: 0.94262, f1_macro: 0.97079
# epoch: 10, passed number of graphs: 96, train running loss: 0.00209 (passed time: 39m 26s)
#           acc: 0.99980, fpr: 0.00008, fnr: 0.00543, rec: 0.99457, prc: 0.99616, f1: 0.99536, f1_macro: 0.99763
# epoch: 10, passed number of graphs: 192, train running loss: 0.00204 (passed time: 39m 53s)
#           acc: 0.99978, fpr: 0.00001, fnr: 0.00953, rec: 0.99047, prc: 0.99934, f1: 0.99488, f1_macro: 0.99739
# epoch: 10, passed number of graphs: 288, train running loss: 0.00181 (passed time: 40m 21s)
#           acc: 0.99983, fpr: 0.00003, fnr: 0.00656, rec: 0.99344, prc: 0.99835, f1: 0.99589, f1_macro: 0.99790
# epoch: 10, passed number of graphs: 384, train running loss: 0.00174 (passed time: 40m 48s)
#           acc: 0.99976, fpr: 0.00003, fnr: 0.00969, rec: 0.99031, prc: 0.99870, f1: 0.99449, f1_macro: 0.99718
# epoch: 10, passed number of graphs: 480, train running loss: 0.00170 (passed time: 41m 15s)
#           acc: 0.99973, fpr: 0.00004, fnr: 0.01077, rec: 0.98923, prc: 0.99803, f1: 0.99361, f1_macro: 0.99673
# epoch: 10, passed number of graphs: 576, train running loss: 0.00166 (passed time: 41m 43s)
#           acc: 0.99989, fpr: 0.00005, fnr: 0.00292, rec: 0.99708, prc: 0.99773, f1: 0.99741, f1_macro: 0.99867
# epoch: 10, passed number of graphs: 672, train running loss: 0.00191 (passed time: 42m 10s)
#           acc: 0.99920, fpr: 0.00067, fnr: 0.00675, rec: 0.99325, prc: 0.96954, f1: 0.98125, f1_macro: 0.99042
# epoch: 10, passed number of graphs: 768, train running loss: 0.00197 (passed time: 42m 37s)
#           acc: 0.99975, fpr: 0.00007, fnr: 0.00849, rec: 0.99151, prc: 0.99672, f1: 0.99411, f1_macro: 0.99699
# Validation --- epoch: 10, loss: 0.00493
#           fpr: 0.00074, fnr: 0.01526, acc: 0.99894, prc: 0.97798, rec: 0.98474, f1: 0.97864, f1_macro: 0.98905
# epoch: 11, passed number of graphs: 96, train running loss: 0.00172 (passed time: 43m 30s)
#           acc: 0.99983, fpr: 0.00007, fnr: 0.00480, rec: 0.99520, prc: 0.99680, f1: 0.99600, f1_macro: 0.99796
# epoch: 11, passed number of graphs: 192, train running loss: 0.00173 (passed time: 43m 58s)
#           acc: 0.99979, fpr: 0.00001, fnr: 0.00920, rec: 0.99080, prc: 0.99934, f1: 0.99505, f1_macro: 0.99747
# epoch: 11, passed number of graphs: 288, train running loss: 0.00164 (passed time: 44m 25s)
#           acc: 0.99982, fpr: 0.00004, fnr: 0.00689, rec: 0.99311, prc: 0.99802, f1: 0.99556, f1_macro: 0.99773
# epoch: 11, passed number of graphs: 384, train running loss: 0.00180 (passed time: 44m 52s)
#           acc: 0.99971, fpr: 0.00003, fnr: 0.01195, rec: 0.98805, prc: 0.99869, f1: 0.99335, f1_macro: 0.99660
# epoch: 11, passed number of graphs: 480, train running loss: 0.00176 (passed time: 45m 19s)
#           acc: 0.99973, fpr: 0.00004, fnr: 0.01077, rec: 0.98923, prc: 0.99803, f1: 0.99361, f1_macro: 0.99673
# epoch: 11, passed number of graphs: 576, train running loss: 0.00171 (passed time: 45m 46s)
#           acc: 0.99990, fpr: 0.00005, fnr: 0.00259, rec: 0.99741, prc: 0.99773, f1: 0.99757, f1_macro: 0.99876
# epoch: 11, passed number of graphs: 672, train running loss: 0.00199 (passed time: 46m 14s)
#           acc: 0.99920, fpr: 0.00061, fnr: 0.00965, rec: 0.99035, prc: 0.97252, f1: 0.98135, f1_macro: 0.99047
# epoch: 11, passed number of graphs: 768, train running loss: 0.00211 (passed time: 46m 41s)
#           acc: 0.99966, fpr: 0.00011, fnr: 0.01045, rec: 0.98955, prc: 0.99475, f1: 0.99214, f1_macro: 0.99599
# Validation --- epoch: 11, loss: 0.00673
#           fpr: 0.00068, fnr: 0.02859, acc: 0.99872, prc: 0.98261, rec: 0.97141, f1: 0.97331, f1_macro: 0.98632
# epoch: 12, passed number of graphs: 96, train running loss: 0.00218 (passed time: 47m 34s)
#           acc: 0.99982, fpr: 0.00007, fnr: 0.00512, rec: 0.99488, prc: 0.99680, f1: 0.99584, f1_macro: 0.99787
# epoch: 12, passed number of graphs: 192, train running loss: 0.00202 (passed time: 48m 2s)
#           acc: 0.99982, fpr: 0.00004, fnr: 0.00690, rec: 0.99310, prc: 0.99835, f1: 0.99572, f1_macro: 0.99781
# epoch: 12, passed number of graphs: 288, train running loss: 0.00178 (passed time: 48m 29s)
#           acc: 0.99986, fpr: 0.00005, fnr: 0.00459, rec: 0.99541, prc: 0.99770, f1: 0.99655, f1_macro: 0.99824
# epoch: 12, passed number of graphs: 384, train running loss: 0.00169 (passed time: 48m 56s)
#           acc: 0.99976, fpr: 0.00004, fnr: 0.00904, rec: 0.99096, prc: 0.99805, f1: 0.99449, f1_macro: 0.99718
# epoch: 12, passed number of graphs: 480, train running loss: 0.00165 (passed time: 49m 23s)
#           acc: 0.99974, fpr: 0.00001, fnr: 0.01175, rec: 0.98825, prc: 0.99967, f1: 0.99393, f1_macro: 0.99690
# epoch: 12, passed number of graphs: 576, train running loss: 0.00163 (passed time: 49m 51s)
#           acc: 0.99987, fpr: 0.00005, fnr: 0.00357, rec: 0.99643, prc: 0.99773, f1: 0.99708, f1_macro: 0.99851
# epoch: 12, passed number of graphs: 672, train running loss: 0.00174 (passed time: 50m 18s)
#           acc: 0.99922, fpr: 0.00066, fnr: 0.00643, rec: 0.99357, prc: 0.97016, f1: 0.98173, f1_macro: 0.99066
# epoch: 12, passed number of graphs: 768, train running loss: 0.00179 (passed time: 50m 47s)
#           acc: 0.99980, fpr: 0.00009, fnr: 0.00555, rec: 0.99445, prc: 0.99608, f1: 0.99526, f1_macro: 0.99758
# Validation --- epoch: 12, loss: 0.00758
#           fpr: 0.00108, fnr: 0.01665, acc: 0.99858, prc: 0.97596, rec: 0.98335, f1: 0.97588, f1_macro: 0.98757
# epoch: 13, passed number of graphs: 96, train running loss: 0.00146 (passed time: 51m 40s)
#           acc: 0.99989, fpr: 0.00003, fnr: 0.00352, rec: 0.99648, prc: 0.99840, f1: 0.99744, f1_macro: 0.99869
# epoch: 13, passed number of graphs: 192, train running loss: 0.00149 (passed time: 52m 6s)
#           acc: 0.99985, fpr: 0.00004, fnr: 0.00526, rec: 0.99474, prc: 0.99835, f1: 0.99654, f1_macro: 0.99823
# epoch: 13, passed number of graphs: 288, train running loss: 0.00139 (passed time: 52m 33s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00394, rec: 0.99606, prc: 0.99803, f1: 0.99704, f1_macro: 0.99849
# epoch: 13, passed number of graphs: 384, train running loss: 0.00134 (passed time: 53m 0s)
#           acc: 0.99979, fpr: 0.00006, fnr: 0.00678, rec: 0.99322, prc: 0.99741, f1: 0.99531, f1_macro: 0.99760
# epoch: 13, passed number of graphs: 480, train running loss: 0.00134 (passed time: 53m 27s)
#           acc: 0.99985, fpr: 0.00000, fnr: 0.00685, rec: 0.99315, prc: 1.00000, f1: 0.99656, f1_macro: 0.99824
# epoch: 13, passed number of graphs: 576, train running loss: 0.00132 (passed time: 53m 54s)
#           acc: 0.99990, fpr: 0.00005, fnr: 0.00227, rec: 0.99773, prc: 0.99773, f1: 0.99773, f1_macro: 0.99884
# epoch: 13, passed number of graphs: 672, train running loss: 0.00140 (passed time: 54m 22s)
#           acc: 0.99921, fpr: 0.00070, fnr: 0.00482, rec: 0.99518, prc: 0.96839, f1: 0.98160, f1_macro: 0.99060
# epoch: 13, passed number of graphs: 768, train running loss: 0.00148 (passed time: 54m 50s)
#           acc: 0.99980, fpr: 0.00008, fnr: 0.00555, rec: 0.99445, prc: 0.99640, f1: 0.99542, f1_macro: 0.99766
# Validation --- epoch: 13, loss: 0.00401
#           fpr: 0.00021, fnr: 0.02429, acc: 0.99927, prc: 0.99267, rec: 0.97571, f1: 0.98230, f1_macro: 0.99096
# Better model saved at ./saved_models/GIN_12: 0.9823031374624173.pt.
# epoch: 14, passed number of graphs: 96, train running loss: 0.00127 (passed time: 55m 44s)
#           acc: 0.99987, fpr: 0.00006, fnr: 0.00352, rec: 0.99648, prc: 0.99744, f1: 0.99696, f1_macro: 0.99845
# epoch: 14, passed number of graphs: 192, train running loss: 0.00157 (passed time: 56m 11s)
#           acc: 0.99984, fpr: 0.00004, fnr: 0.00592, rec: 0.99408, prc: 0.99835, f1: 0.99621, f1_macro: 0.99806
# epoch: 14, passed number of graphs: 288, train running loss: 0.00143 (passed time: 56m 39s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00394, rec: 0.99606, prc: 0.99803, f1: 0.99704, f1_macro: 0.99849
# epoch: 14, passed number of graphs: 384, train running loss: 0.00139 (passed time: 57m 6s)
#           acc: 0.99980, fpr: 0.00004, fnr: 0.00710, rec: 0.99290, prc: 0.99805, f1: 0.99547, f1_macro: 0.99768
# epoch: 14, passed number of graphs: 480, train running loss: 0.00140 (passed time: 57m 33s)
#           acc: 0.99986, fpr: 0.00001, fnr: 0.00620, rec: 0.99380, prc: 0.99967, f1: 0.99673, f1_macro: 0.99833
# epoch: 14, passed number of graphs: 576, train running loss: 0.00136 (passed time: 58m 1s)
#           acc: 0.99992, fpr: 0.00004, fnr: 0.00194, rec: 0.99806, prc: 0.99806, f1: 0.99806, f1_macro: 0.99901
# epoch: 14, passed number of graphs: 672, train running loss: 0.00149 (passed time: 58m 28s)
#           acc: 0.99921, fpr: 0.00070, fnr: 0.00482, rec: 0.99518, prc: 0.96839, f1: 0.98160, f1_macro: 0.99060
# epoch: 14, passed number of graphs: 768, train running loss: 0.00155 (passed time: 58m 55s)
#           acc: 0.99980, fpr: 0.00008, fnr: 0.00555, rec: 0.99445, prc: 0.99640, f1: 0.99542, f1_macro: 0.99766
# Validation --- epoch: 14, loss: 0.00409
#           fpr: 0.00049, fnr: 0.01830, acc: 0.99912, prc: 0.98596, rec: 0.98170, f1: 0.98124, f1_macro: 0.99040
# epoch: 15, passed number of graphs: 96, train running loss: 0.00127 (passed time: 59m 49s)
#           acc: 0.99986, fpr: 0.00005, fnr: 0.00416, rec: 0.99584, prc: 0.99776, f1: 0.99680, f1_macro: 0.99837
# epoch: 15, passed number of graphs: 192, train running loss: 0.00133 (passed time: 1h 0m 17s)
#           acc: 0.99986, fpr: 0.00003, fnr: 0.00526, rec: 0.99474, prc: 0.99868, f1: 0.99671, f1_macro: 0.99832
# epoch: 15, passed number of graphs: 288, train running loss: 0.00126 (passed time: 1h 0m 44s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00394, rec: 0.99606, prc: 0.99803, f1: 0.99704, f1_macro: 0.99849
# epoch: 15, passed number of graphs: 384, train running loss: 0.00124 (passed time: 1h 1m 11s)
#           acc: 0.99980, fpr: 0.00005, fnr: 0.00678, rec: 0.99322, prc: 0.99773, f1: 0.99547, f1_macro: 0.99768
# epoch: 15, passed number of graphs: 480, train running loss: 0.00124 (passed time: 1h 1m 38s)
#           acc: 0.99984, fpr: 0.00000, fnr: 0.00718, rec: 0.99282, prc: 1.00000, f1: 0.99640, f1_macro: 0.99816
# epoch: 15, passed number of graphs: 576, train running loss: 0.00123 (passed time: 1h 2m 5s)
#           acc: 0.99989, fpr: 0.00007, fnr: 0.00194, rec: 0.99806, prc: 0.99676, f1: 0.99741, f1_macro: 0.99868
# epoch: 15, passed number of graphs: 672, train running loss: 0.00138 (passed time: 1h 2m 31s)
#           acc: 0.99922, fpr: 0.00070, fnr: 0.00482, rec: 0.99518, prc: 0.96869, f1: 0.98175, f1_macro: 0.99068
# epoch: 15, passed number of graphs: 768, train running loss: 0.00145 (passed time: 1h 2m 58s)
#           acc: 0.99980, fpr: 0.00008, fnr: 0.00588, rec: 0.99412, prc: 0.99640, f1: 0.99526, f1_macro: 0.99758
# Validation --- epoch: 15, loss: 0.00379
#           fpr: 0.00033, fnr: 0.01935, acc: 0.99926, prc: 0.98944, rec: 0.98065, f1: 0.98295, f1_macro: 0.99128
# Better model saved at ./saved_models/GIN_14: 0.9829450210051869.pt.
# epoch: 16, passed number of graphs: 96, train running loss: 0.00119 (passed time: 1h 3m 50s)
#           acc: 0.99987, fpr: 0.00005, fnr: 0.00384, rec: 0.99616, prc: 0.99776, f1: 0.99696, f1_macro: 0.99845
# epoch: 16, passed number of graphs: 192, train running loss: 0.00128 (passed time: 1h 4m 18s)
#           acc: 0.99987, fpr: 0.00002, fnr: 0.00493, rec: 0.99507, prc: 0.99901, f1: 0.99704, f1_macro: 0.99849
# epoch: 16, passed number of graphs: 288, train running loss: 0.00121 (passed time: 1h 4m 46s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00394, rec: 0.99606, prc: 0.99803, f1: 0.99704, f1_macro: 0.99849
# epoch: 16, passed number of graphs: 384, train running loss: 0.00118 (passed time: 1h 5m 13s)
#           acc: 0.99981, fpr: 0.00005, fnr: 0.00646, rec: 0.99354, prc: 0.99773, f1: 0.99563, f1_macro: 0.99777
# epoch: 16, passed number of graphs: 480, train running loss: 0.00123 (passed time: 1h 5m 40s)
#           acc: 0.99987, fpr: 0.00003, fnr: 0.00489, rec: 0.99511, prc: 0.99869, f1: 0.99689, f1_macro: 0.99841
# epoch: 16, passed number of graphs: 576, train running loss: 0.00122 (passed time: 1h 6m 7s)
#           acc: 0.99991, fpr: 0.00005, fnr: 0.00194, rec: 0.99806, prc: 0.99773, f1: 0.99789, f1_macro: 0.99892
# epoch: 16, passed number of graphs: 672, train running loss: 0.00142 (passed time: 1h 6m 34s)
#           acc: 0.99920, fpr: 0.00072, fnr: 0.00418, rec: 0.99582, prc: 0.96750, f1: 0.98146, f1_macro: 0.99052
# epoch: 16, passed number of graphs: 768, train running loss: 0.00148 (passed time: 1h 7m 2s)
#           acc: 0.99973, fpr: 0.00017, fnr: 0.00490, rec: 0.99510, prc: 0.99219, f1: 0.99364, f1_macro: 0.99675
# Validation --- epoch: 16, loss: 0.00428
#           fpr: 0.00068, fnr: 0.01206, acc: 0.99907, prc: 0.98296, rec: 0.98794, f1: 0.98263, f1_macro: 0.99107
# epoch: 17, passed number of graphs: 96, train running loss: 0.00128 (passed time: 1h 7m 54s)
#           acc: 0.99988, fpr: 0.00006, fnr: 0.00288, rec: 0.99712, prc: 0.99712, f1: 0.99712, f1_macro: 0.99853
# epoch: 17, passed number of graphs: 192, train running loss: 0.00135 (passed time: 1h 8m 21s)
#           acc: 0.99986, fpr: 0.00004, fnr: 0.00460, rec: 0.99540, prc: 0.99802, f1: 0.99671, f1_macro: 0.99832
# epoch: 17, passed number of graphs: 288, train running loss: 0.00126 (passed time: 1h 8m 48s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00394, rec: 0.99606, prc: 0.99803, f1: 0.99704, f1_macro: 0.99849
# epoch: 17, passed number of graphs: 384, train running loss: 0.00123 (passed time: 1h 9m 16s)
#           acc: 0.99980, fpr: 0.00006, fnr: 0.00646, rec: 0.99354, prc: 0.99741, f1: 0.99547, f1_macro: 0.99768
# epoch: 17, passed number of graphs: 480, train running loss: 0.00124 (passed time: 1h 9m 42s)
#           acc: 0.99986, fpr: 0.00001, fnr: 0.00620, rec: 0.99380, prc: 0.99967, f1: 0.99673, f1_macro: 0.99833
# epoch: 17, passed number of graphs: 576, train running loss: 0.00123 (passed time: 1h 10m 9s)
#           acc: 0.99987, fpr: 0.00009, fnr: 0.00194, rec: 0.99806, prc: 0.99612, f1: 0.99709, f1_macro: 0.99851
# epoch: 17, passed number of graphs: 672, train running loss: 0.00132 (passed time: 1h 10m 36s)
#           acc: 0.99921, fpr: 0.00072, fnr: 0.00386, rec: 0.99614, prc: 0.96751, f1: 0.98162, f1_macro: 0.99061
# epoch: 17, passed number of graphs: 768, train running loss: 0.00144 (passed time: 1h 11m 3s)
#           acc: 0.99980, fpr: 0.00007, fnr: 0.00620, rec: 0.99380, prc: 0.99673, f1: 0.99526, f1_macro: 0.99758
# Validation --- epoch: 17, loss: 0.01380
#           fpr: 0.00004, fnr: 0.08750, acc: 0.99808, prc: 0.99803, rec: 0.91250, f1: 0.94535, f1_macro: 0.97218
# epoch: 18, passed number of graphs: 96, train running loss: 0.00125 (passed time: 1h 11m 56s)
#           acc: 0.99987, fpr: 0.00006, fnr: 0.00320, rec: 0.99680, prc: 0.99712, f1: 0.99696, f1_macro: 0.99845
# epoch: 18, passed number of graphs: 192, train running loss: 0.00219 (passed time: 1h 12m 23s)
#           acc: 0.99987, fpr: 0.00001, fnr: 0.00559, rec: 0.99441, prc: 0.99934, f1: 0.99687, f1_macro: 0.99840
# epoch: 18, passed number of graphs: 288, train running loss: 0.00182 (passed time: 1h 12m 50s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00394, rec: 0.99606, prc: 0.99803, f1: 0.99704, f1_macro: 0.99849
# epoch: 18, passed number of graphs: 384, train running loss: 0.00166 (passed time: 1h 13m 18s)
#           acc: 0.99980, fpr: 0.00006, fnr: 0.00646, rec: 0.99354, prc: 0.99741, f1: 0.99547, f1_macro: 0.99768
# epoch: 18, passed number of graphs: 480, train running loss: 0.00159 (passed time: 1h 13m 46s)
#           acc: 0.99989, fpr: 0.00004, fnr: 0.00359, rec: 0.99641, prc: 0.99837, f1: 0.99739, f1_macro: 0.99866
# epoch: 18, passed number of graphs: 576, train running loss: 0.00151 (passed time: 1h 14m 13s)
#           acc: 0.99991, fpr: 0.00004, fnr: 0.00227, rec: 0.99773, prc: 0.99805, f1: 0.99789, f1_macro: 0.99892
# epoch: 18, passed number of graphs: 672, train running loss: 0.00165 (passed time: 1h 14m 40s)
#           acc: 0.99923, fpr: 0.00071, fnr: 0.00354, rec: 0.99646, prc: 0.96813, f1: 0.98209, f1_macro: 0.99085
# epoch: 18, passed number of graphs: 768, train running loss: 0.00168 (passed time: 1h 15m 8s)
#           acc: 0.99980, fpr: 0.00008, fnr: 0.00555, rec: 0.99445, prc: 0.99640, f1: 0.99542, f1_macro: 0.99766
# Validation --- epoch: 18, loss: 0.00414
#           fpr: 0.00047, fnr: 0.01830, acc: 0.99914, prc: 0.98660, rec: 0.98170, f1: 0.98165, f1_macro: 0.99060
# epoch: 19, passed number of graphs: 96, train running loss: 0.00117 (passed time: 1h 16m 0s)
#           acc: 0.99987, fpr: 0.00007, fnr: 0.00288, rec: 0.99712, prc: 0.99680, f1: 0.99696, f1_macro: 0.99845
# epoch: 19, passed number of graphs: 192, train running loss: 0.00127 (passed time: 1h 16m 27s)
#           acc: 0.99987, fpr: 0.00003, fnr: 0.00460, rec: 0.99540, prc: 0.99868, f1: 0.99704, f1_macro: 0.99849
# epoch: 19, passed number of graphs: 288, train running loss: 0.00120 (passed time: 1h 16m 54s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00394, rec: 0.99606, prc: 0.99803, f1: 0.99704, f1_macro: 0.99849
# epoch: 19, passed number of graphs: 384, train running loss: 0.00119 (passed time: 1h 17m 21s)
#           acc: 0.99980, fpr: 0.00006, fnr: 0.00646, rec: 0.99354, prc: 0.99741, f1: 0.99547, f1_macro: 0.99768
# epoch: 19, passed number of graphs: 480, train running loss: 0.00121 (passed time: 1h 17m 49s)
#           acc: 0.99989, fpr: 0.00004, fnr: 0.00359, rec: 0.99641, prc: 0.99837, f1: 0.99739, f1_macro: 0.99866
# epoch: 19, passed number of graphs: 576, train running loss: 0.00119 (passed time: 1h 18m 17s)
#           acc: 0.99992, fpr: 0.00004, fnr: 0.00194, rec: 0.99806, prc: 0.99806, f1: 0.99806, f1_macro: 0.99901
# epoch: 19, passed number of graphs: 672, train running loss: 0.00135 (passed time: 1h 18m 44s)
#           acc: 0.99923, fpr: 0.00071, fnr: 0.00354, rec: 0.99646, prc: 0.96813, f1: 0.98209, f1_macro: 0.99085
# epoch: 19, passed number of graphs: 768, train running loss: 0.00141 (passed time: 1h 19m 11s)
#           acc: 0.99981, fpr: 0.00007, fnr: 0.00555, rec: 0.99445, prc: 0.99673, f1: 0.99559, f1_macro: 0.99775
# Validation --- epoch: 19, loss: 0.00407
#           fpr: 0.00048, fnr: 0.01741, acc: 0.99915, prc: 0.98656, rec: 0.98259, f1: 0.98210, f1_macro: 0.99083
# epoch: 20, passed number of graphs: 96, train running loss: 0.00117 (passed time: 1h 20m 3s)
#           acc: 0.99986, fpr: 0.00008, fnr: 0.00288, rec: 0.99712, prc: 0.99649, f1: 0.99680, f1_macro: 0.99837
# epoch: 20, passed number of graphs: 192, train running loss: 0.00126 (passed time: 1h 20m 30s)
#           acc: 0.99987, fpr: 0.00003, fnr: 0.00460, rec: 0.99540, prc: 0.99868, f1: 0.99704, f1_macro: 0.99849
# epoch: 20, passed number of graphs: 288, train running loss: 0.00120 (passed time: 1h 20m 57s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00394, rec: 0.99606, prc: 0.99803, f1: 0.99704, f1_macro: 0.99849
# epoch: 20, passed number of graphs: 384, train running loss: 0.00118 (passed time: 1h 21m 24s)
#           acc: 0.99980, fpr: 0.00006, fnr: 0.00646, rec: 0.99354, prc: 0.99741, f1: 0.99547, f1_macro: 0.99768
# epoch: 20, passed number of graphs: 480, train running loss: 0.00120 (passed time: 1h 21m 51s)
#           acc: 0.99989, fpr: 0.00004, fnr: 0.00359, rec: 0.99641, prc: 0.99837, f1: 0.99739, f1_macro: 0.99866
# epoch: 20, passed number of graphs: 576, train running loss: 0.00118 (passed time: 1h 22m 18s)
#           acc: 0.99990, fpr: 0.00006, fnr: 0.00194, rec: 0.99806, prc: 0.99709, f1: 0.99757, f1_macro: 0.99876
# epoch: 20, passed number of graphs: 672, train running loss: 0.00131 (passed time: 1h 22m 47s)
#           acc: 0.99924, fpr: 0.00070, fnr: 0.00354, rec: 0.99646, prc: 0.96873, f1: 0.98240, f1_macro: 0.99101
# epoch: 20, passed number of graphs: 768, train running loss: 0.00137 (passed time: 1h 23m 14s)
#           acc: 0.99980, fpr: 0.00007, fnr: 0.00588, rec: 0.99412, prc: 0.99673, f1: 0.99542, f1_macro: 0.99766
# Validation --- epoch: 20, loss: 0.00449
#           fpr: 0.00047, fnr: 0.02229, acc: 0.99906, prc: 0.98678, rec: 0.97771, f1: 0.97935, f1_macro: 0.98944
# epoch: 21, passed number of graphs: 96, train running loss: 0.00114 (passed time: 1h 24m 6s)
#           acc: 0.99986, fpr: 0.00008, fnr: 0.00288, rec: 0.99712, prc: 0.99649, f1: 0.99680, f1_macro: 0.99837
# epoch: 21, passed number of graphs: 192, train running loss: 0.00124 (passed time: 1h 24m 34s)
#           acc: 0.99987, fpr: 0.00003, fnr: 0.00460, rec: 0.99540, prc: 0.99868, f1: 0.99704, f1_macro: 0.99849
# epoch: 21, passed number of graphs: 288, train running loss: 0.00118 (passed time: 1h 25m 0s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00394, rec: 0.99606, prc: 0.99803, f1: 0.99704, f1_macro: 0.99849
# epoch: 21, passed number of graphs: 384, train running loss: 0.00117 (passed time: 1h 25m 28s)
#           acc: 0.99980, fpr: 0.00006, fnr: 0.00646, rec: 0.99354, prc: 0.99741, f1: 0.99547, f1_macro: 0.99768
# epoch: 21, passed number of graphs: 480, train running loss: 0.00118 (passed time: 1h 25m 55s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00359, rec: 0.99641, prc: 0.99804, f1: 0.99722, f1_macro: 0.99858
# epoch: 21, passed number of graphs: 576, train running loss: 0.00116 (passed time: 1h 26m 22s)
#           acc: 0.99988, fpr: 0.00008, fnr: 0.00194, rec: 0.99806, prc: 0.99644, f1: 0.99725, f1_macro: 0.99859
# epoch: 21, passed number of graphs: 672, train running loss: 0.00130 (passed time: 1h 26m 49s)
#           acc: 0.99924, fpr: 0.00070, fnr: 0.00354, rec: 0.99646, prc: 0.96843, f1: 0.98224, f1_macro: 0.99093
# epoch: 21, passed number of graphs: 768, train running loss: 0.00136 (passed time: 1h 27m 15s)
#           acc: 0.99980, fpr: 0.00007, fnr: 0.00588, rec: 0.99412, prc: 0.99673, f1: 0.99542, f1_macro: 0.99766
# Validation --- epoch: 21, loss: 0.00451
#           fpr: 0.00042, fnr: 0.02306, acc: 0.99910, prc: 0.98767, rec: 0.97694, f1: 0.97952, f1_macro: 0.98953
# epoch: 22, passed number of graphs: 96, train running loss: 0.00113 (passed time: 1h 28m 8s)
#           acc: 0.99986, fpr: 0.00008, fnr: 0.00288, rec: 0.99712, prc: 0.99649, f1: 0.99680, f1_macro: 0.99837
# epoch: 22, passed number of graphs: 192, train running loss: 0.00123 (passed time: 1h 28m 34s)
#           acc: 0.99987, fpr: 0.00003, fnr: 0.00460, rec: 0.99540, prc: 0.99868, f1: 0.99704, f1_macro: 0.99849
# epoch: 22, passed number of graphs: 288, train running loss: 0.00118 (passed time: 1h 29m 1s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00394, rec: 0.99606, prc: 0.99803, f1: 0.99704, f1_macro: 0.99849
# epoch: 22, passed number of graphs: 384, train running loss: 0.00116 (passed time: 1h 29m 29s)
#           acc: 0.99981, fpr: 0.00006, fnr: 0.00613, rec: 0.99387, prc: 0.99741, f1: 0.99563, f1_macro: 0.99777
# epoch: 22, passed number of graphs: 480, train running loss: 0.00117 (passed time: 1h 29m 55s)
#           acc: 0.99989, fpr: 0.00004, fnr: 0.00326, rec: 0.99674, prc: 0.99804, f1: 0.99739, f1_macro: 0.99867
# epoch: 22, passed number of graphs: 576, train running loss: 0.00115 (passed time: 1h 30m 23s)
#           acc: 0.99988, fpr: 0.00008, fnr: 0.00194, rec: 0.99806, prc: 0.99644, f1: 0.99725, f1_macro: 0.99859
# epoch: 22, passed number of graphs: 672, train running loss: 0.00128 (passed time: 1h 30m 50s)
#           acc: 0.99924, fpr: 0.00070, fnr: 0.00322, rec: 0.99678, prc: 0.96844, f1: 0.98241, f1_macro: 0.99101
# epoch: 22, passed number of graphs: 768, train running loss: 0.00135 (passed time: 1h 31m 16s)
#           acc: 0.99980, fpr: 0.00007, fnr: 0.00588, rec: 0.99412, prc: 0.99673, f1: 0.99542, f1_macro: 0.99766
# Validation --- epoch: 22, loss: 0.00452
#           fpr: 0.00041, fnr: 0.02324, acc: 0.99910, prc: 0.98774, rec: 0.97676, f1: 0.97946, f1_macro: 0.98950
# epoch: 23, passed number of graphs: 96, train running loss: 0.00113 (passed time: 1h 32m 9s)
#           acc: 0.99987, fpr: 0.00007, fnr: 0.00288, rec: 0.99712, prc: 0.99680, f1: 0.99696, f1_macro: 0.99845
# epoch: 23, passed number of graphs: 192, train running loss: 0.00123 (passed time: 1h 32m 36s)
#           acc: 0.99987, fpr: 0.00003, fnr: 0.00460, rec: 0.99540, prc: 0.99868, f1: 0.99704, f1_macro: 0.99849
# epoch: 23, passed number of graphs: 288, train running loss: 0.00117 (passed time: 1h 33m 3s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00394, rec: 0.99606, prc: 0.99803, f1: 0.99704, f1_macro: 0.99849
# epoch: 23, passed number of graphs: 384, train running loss: 0.00116 (passed time: 1h 33m 31s)
#           acc: 0.99980, fpr: 0.00006, fnr: 0.00646, rec: 0.99354, prc: 0.99741, f1: 0.99547, f1_macro: 0.99768
# epoch: 23, passed number of graphs: 480, train running loss: 0.00117 (passed time: 1h 33m 58s)
#           acc: 0.99989, fpr: 0.00004, fnr: 0.00326, rec: 0.99674, prc: 0.99804, f1: 0.99739, f1_macro: 0.99867
# epoch: 23, passed number of graphs: 576, train running loss: 0.00115 (passed time: 1h 34m 25s)
#           acc: 0.99988, fpr: 0.00008, fnr: 0.00194, rec: 0.99806, prc: 0.99644, f1: 0.99725, f1_macro: 0.99859
# epoch: 23, passed number of graphs: 672, train running loss: 0.00128 (passed time: 1h 34m 52s)
#           acc: 0.99924, fpr: 0.00070, fnr: 0.00322, rec: 0.99678, prc: 0.96844, f1: 0.98241, f1_macro: 0.99101
# epoch: 23, passed number of graphs: 768, train running loss: 0.00134 (passed time: 1h 35m 20s)
#           acc: 0.99980, fpr: 0.00007, fnr: 0.00588, rec: 0.99412, prc: 0.99673, f1: 0.99542, f1_macro: 0.99766
# Validation --- epoch: 23, loss: 0.00451
#           fpr: 0.00040, fnr: 0.02330, acc: 0.99910, prc: 0.98787, rec: 0.97670, f1: 0.97951, f1_macro: 0.98953
# epoch: 24, passed number of graphs: 96, train running loss: 0.00112 (passed time: 1h 36m 13s)
#           acc: 0.99987, fpr: 0.00007, fnr: 0.00288, rec: 0.99712, prc: 0.99680, f1: 0.99696, f1_macro: 0.99845
# epoch: 24, passed number of graphs: 192, train running loss: 0.00122 (passed time: 1h 36m 40s)
#           acc: 0.99987, fpr: 0.00003, fnr: 0.00460, rec: 0.99540, prc: 0.99868, f1: 0.99704, f1_macro: 0.99849
# epoch: 24, passed number of graphs: 288, train running loss: 0.00117 (passed time: 1h 37m 8s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00394, rec: 0.99606, prc: 0.99803, f1: 0.99704, f1_macro: 0.99849
# epoch: 24, passed number of graphs: 384, train running loss: 0.00116 (passed time: 1h 37m 35s)
#           acc: 0.99980, fpr: 0.00006, fnr: 0.00646, rec: 0.99354, prc: 0.99741, f1: 0.99547, f1_macro: 0.99768
# epoch: 24, passed number of graphs: 480, train running loss: 0.00117 (passed time: 1h 38m 3s)
#           acc: 0.99989, fpr: 0.00004, fnr: 0.00326, rec: 0.99674, prc: 0.99804, f1: 0.99739, f1_macro: 0.99867
# epoch: 24, passed number of graphs: 576, train running loss: 0.00115 (passed time: 1h 38m 30s)
#           acc: 0.99988, fpr: 0.00008, fnr: 0.00194, rec: 0.99806, prc: 0.99644, f1: 0.99725, f1_macro: 0.99859
# epoch: 24, passed number of graphs: 672, train running loss: 0.00128 (passed time: 1h 38m 57s)
#           acc: 0.99924, fpr: 0.00070, fnr: 0.00322, rec: 0.99678, prc: 0.96844, f1: 0.98241, f1_macro: 0.99101
# epoch: 24, passed number of graphs: 768, train running loss: 0.00134 (passed time: 1h 39m 25s)
#           acc: 0.99980, fpr: 0.00007, fnr: 0.00588, rec: 0.99412, prc: 0.99673, f1: 0.99542, f1_macro: 0.99766
# Validation --- epoch: 24, loss: 0.00453
#           fpr: 0.00041, fnr: 0.02341, acc: 0.99910, prc: 0.98784, rec: 0.97659, f1: 0.97942, f1_macro: 0.98948
# epoch: 25, passed number of graphs: 96, train running loss: 0.00112 (passed time: 1h 40m 18s)
#           acc: 0.99987, fpr: 0.00007, fnr: 0.00288, rec: 0.99712, prc: 0.99680, f1: 0.99696, f1_macro: 0.99845
# epoch: 25, passed number of graphs: 192, train running loss: 0.00122 (passed time: 1h 40m 46s)
#           acc: 0.99987, fpr: 0.00003, fnr: 0.00460, rec: 0.99540, prc: 0.99868, f1: 0.99704, f1_macro: 0.99849
# epoch: 25, passed number of graphs: 288, train running loss: 0.00117 (passed time: 1h 41m 13s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00394, rec: 0.99606, prc: 0.99803, f1: 0.99704, f1_macro: 0.99849
# epoch: 25, passed number of graphs: 384, train running loss: 0.00115 (passed time: 1h 41m 41s)
#           acc: 0.99980, fpr: 0.00006, fnr: 0.00646, rec: 0.99354, prc: 0.99741, f1: 0.99547, f1_macro: 0.99768
# epoch: 25, passed number of graphs: 480, train running loss: 0.00117 (passed time: 1h 42m 8s)
#           acc: 0.99989, fpr: 0.00004, fnr: 0.00326, rec: 0.99674, prc: 0.99804, f1: 0.99739, f1_macro: 0.99867
# epoch: 25, passed number of graphs: 576, train running loss: 0.00115 (passed time: 1h 42m 36s)
#           acc: 0.99988, fpr: 0.00008, fnr: 0.00194, rec: 0.99806, prc: 0.99644, f1: 0.99725, f1_macro: 0.99859
# epoch: 25, passed number of graphs: 672, train running loss: 0.00128 (passed time: 1h 43m 3s)
#           acc: 0.99924, fpr: 0.00070, fnr: 0.00322, rec: 0.99678, prc: 0.96844, f1: 0.98241, f1_macro: 0.99101
# epoch: 25, passed number of graphs: 768, train running loss: 0.00134 (passed time: 1h 43m 31s)
#           acc: 0.99980, fpr: 0.00007, fnr: 0.00588, rec: 0.99412, prc: 0.99673, f1: 0.99542, f1_macro: 0.99766
# Validation --- epoch: 25, loss: 0.00453
#           fpr: 0.00040, fnr: 0.02343, acc: 0.99910, prc: 0.98786, rec: 0.97657, f1: 0.97942, f1_macro: 0.98948
# epoch: 26, passed number of graphs: 96, train running loss: 0.00112 (passed time: 1h 44m 23s)
#           acc: 0.99987, fpr: 0.00007, fnr: 0.00288, rec: 0.99712, prc: 0.99680, f1: 0.99696, f1_macro: 0.99845
# epoch: 26, passed number of graphs: 192, train running loss: 0.00122 (passed time: 1h 44m 50s)
#           acc: 0.99987, fpr: 0.00003, fnr: 0.00460, rec: 0.99540, prc: 0.99868, f1: 0.99704, f1_macro: 0.99849
# epoch: 26, passed number of graphs: 288, train running loss: 0.00117 (passed time: 1h 45m 18s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00394, rec: 0.99606, prc: 0.99803, f1: 0.99704, f1_macro: 0.99849
# epoch: 26, passed number of graphs: 384, train running loss: 0.00115 (passed time: 1h 45m 46s)
#           acc: 0.99980, fpr: 0.00006, fnr: 0.00646, rec: 0.99354, prc: 0.99741, f1: 0.99547, f1_macro: 0.99768
# epoch: 26, passed number of graphs: 480, train running loss: 0.00117 (passed time: 1h 46m 13s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00359, rec: 0.99641, prc: 0.99804, f1: 0.99722, f1_macro: 0.99858
# epoch: 26, passed number of graphs: 576, train running loss: 0.00115 (passed time: 1h 46m 41s)
#           acc: 0.99988, fpr: 0.00008, fnr: 0.00194, rec: 0.99806, prc: 0.99644, f1: 0.99725, f1_macro: 0.99859
# epoch: 26, passed number of graphs: 672, train running loss: 0.00128 (passed time: 1h 47m 8s)
#           acc: 0.99924, fpr: 0.00070, fnr: 0.00322, rec: 0.99678, prc: 0.96844, f1: 0.98241, f1_macro: 0.99101
# epoch: 26, passed number of graphs: 768, train running loss: 0.00134 (passed time: 1h 47m 35s)
#           acc: 0.99980, fpr: 0.00007, fnr: 0.00588, rec: 0.99412, prc: 0.99673, f1: 0.99542, f1_macro: 0.99766
# Validation --- epoch: 26, loss: 0.00454
# ...
# epoch: 42, passed number of graphs: 288, train running loss: 0.00117 (passed time: 2h 50m 4s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00394, rec: 0.99606, prc: 0.99803, f1: 0.99704, f1_macro: 0.99849
# epoch: 42, passed number of graphs: 384, train running loss: 0.00115 (passed time: 2h 50m 32s)
#           acc: 0.99980, fpr: 0.00006, fnr: 0.00646, rec: 0.99354, prc: 0.99741, f1: 0.99547, f1_macro: 0.99768
# epoch: 42, passed number of graphs: 480, train running loss: 0.00116 (passed time: 2h 50m 59s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00359, rec: 0.99641, prc: 0.99804, f1: 0.99722, f1_macro: 0.99858
# epoch: 42, passed number of graphs: 576, train running loss: 0.00114 (passed time: 2h 51m 26s)
#           acc: 0.99988, fpr: 0.00008, fnr: 0.00194, rec: 0.99806, prc: 0.99644, f1: 0.99725, f1_macro: 0.99859
# epoch: 42, passed number of graphs: 672, train running loss: 0.00127 (passed time: 2h 51m 53s)
#           acc: 0.99924, fpr: 0.00070, fnr: 0.00322, rec: 0.99678, prc: 0.96844, f1: 0.98241, f1_macro: 0.99101
# epoch: 42, passed number of graphs: 768, train running loss: 0.00134 (passed time: 2h 52m 21s)
#           acc: 0.99980, fpr: 0.00007, fnr: 0.00588, rec: 0.99412, prc: 0.99673, f1: 0.99542, f1_macro: 0.99766
# Validation --- epoch: 42, loss: 0.00454
#           fpr: 0.00041, fnr: 0.02348, acc: 0.99910, prc: 0.98786, rec: 0.97652, f1: 0.97939, f1_macro: 0.98946
# epoch: 43, passed number of graphs: 96, train running loss: 0.00112 (passed time: 2h 53m 13s)
#           acc: 0.99987, fpr: 0.00007, fnr: 0.00288, rec: 0.99712, prc: 0.99680, f1: 0.99696, f1_macro: 0.99845
# epoch: 43, passed number of graphs: 192, train running loss: 0.00122 (passed time: 2h 53m 40s)
#           acc: 0.99987, fpr: 0.00003, fnr: 0.00460, rec: 0.99540, prc: 0.99868, f1: 0.99704, f1_macro: 0.99849
# epoch: 43, passed number of graphs: 288, train running loss: 0.00117 (passed time: 2h 54m 8s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00394, rec: 0.99606, prc: 0.99803, f1: 0.99704, f1_macro: 0.99849
# epoch: 43, passed number of graphs: 384, train running loss: 0.00115 (passed time: 2h 54m 36s)
#           acc: 0.99980, fpr: 0.00006, fnr: 0.00646, rec: 0.99354, prc: 0.99741, f1: 0.99547, f1_macro: 0.99768
# epoch: 43, passed number of graphs: 480, train running loss: 0.00116 (passed time: 2h 55m 3s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00359, rec: 0.99641, prc: 0.99804, f1: 0.99722, f1_macro: 0.99858
# epoch: 43, passed number of graphs: 576, train running loss: 0.00114 (passed time: 2h 55m 31s)
#           acc: 0.99988, fpr: 0.00008, fnr: 0.00194, rec: 0.99806, prc: 0.99644, f1: 0.99725, f1_macro: 0.99859
# epoch: 43, passed number of graphs: 672, train running loss: 0.00127 (passed time: 2h 55m 59s)
#           acc: 0.99924, fpr: 0.00070, fnr: 0.00322, rec: 0.99678, prc: 0.96844, f1: 0.98241, f1_macro: 0.99101
# epoch: 43, passed number of graphs: 768, train running loss: 0.00134 (passed time: 2h 56m 26s)
#           acc: 0.99980, fpr: 0.00007, fnr: 0.00588, rec: 0.99412, prc: 0.99673, f1: 0.99542, f1_macro: 0.99766
# Validation --- epoch: 43, loss: 0.00454
#           fpr: 0.00041, fnr: 0.02348, acc: 0.99910, prc: 0.98786, rec: 0.97652, f1: 0.97939, f1_macro: 0.98946
# epoch: 44, passed number of graphs: 96, train running loss: 0.00112 (passed time: 2h 57m 19s)
#           acc: 0.99987, fpr: 0.00007, fnr: 0.00288, rec: 0.99712, prc: 0.99680, f1: 0.99696, f1_macro: 0.99845
# epoch: 44, passed number of graphs: 192, train running loss: 0.00122 (passed time: 2h 57m 46s)
#           acc: 0.99987, fpr: 0.00003, fnr: 0.00460, rec: 0.99540, prc: 0.99868, f1: 0.99704, f1_macro: 0.99849
# epoch: 44, passed number of graphs: 288, train running loss: 0.00117 (passed time: 2h 58m 13s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00394, rec: 0.99606, prc: 0.99803, f1: 0.99704, f1_macro: 0.99849
# epoch: 44, passed number of graphs: 384, train running loss: 0.00115 (passed time: 2h 58m 41s)
#           acc: 0.99980, fpr: 0.00006, fnr: 0.00646, rec: 0.99354, prc: 0.99741, f1: 0.99547, f1_macro: 0.99768
# epoch: 44, passed number of graphs: 480, train running loss: 0.00116 (passed time: 2h 59m 8s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00359, rec: 0.99641, prc: 0.99804, f1: 0.99722, f1_macro: 0.99858
# epoch: 44, passed number of graphs: 576, train running loss: 0.00114 (passed time: 2h 59m 36s)
#           acc: 0.99988, fpr: 0.00008, fnr: 0.00194, rec: 0.99806, prc: 0.99644, f1: 0.99725, f1_macro: 0.99859
# epoch: 44, passed number of graphs: 672, train running loss: 0.00127 (passed time: 3h 0m 4s)
#           acc: 0.99924, fpr: 0.00070, fnr: 0.00322, rec: 0.99678, prc: 0.96844, f1: 0.98241, f1_macro: 0.99101
# epoch: 44, passed number of graphs: 768, train running loss: 0.00134 (passed time: 3h 0m 31s)
#           acc: 0.99980, fpr: 0.00007, fnr: 0.00588, rec: 0.99412, prc: 0.99673, f1: 0.99542, f1_macro: 0.99766
# Validation --- epoch: 44, loss: 0.00454
#           fpr: 0.00041, fnr: 0.02348, acc: 0.99910, prc: 0.98786, rec: 0.97652, f1: 0.97939, f1_macro: 0.98946
# epoch: 45, passed number of graphs: 96, train running loss: 0.00112 (passed time: 3h 1m 24s)
#           acc: 0.99987, fpr: 0.00007, fnr: 0.00288, rec: 0.99712, prc: 0.99680, f1: 0.99696, f1_macro: 0.99845
# epoch: 45, passed number of graphs: 192, train running loss: 0.00122 (passed time: 3h 1m 51s)
#           acc: 0.99987, fpr: 0.00003, fnr: 0.00460, rec: 0.99540, prc: 0.99868, f1: 0.99704, f1_macro: 0.99849
# epoch: 45, passed number of graphs: 288, train running loss: 0.00117 (passed time: 3h 2m 19s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00394, rec: 0.99606, prc: 0.99803, f1: 0.99704, f1_macro: 0.99849
# epoch: 45, passed number of graphs: 384, train running loss: 0.00115 (passed time: 3h 2m 46s)
#           acc: 0.99980, fpr: 0.00006, fnr: 0.00646, rec: 0.99354, prc: 0.99741, f1: 0.99547, f1_macro: 0.99768
# epoch: 45, passed number of graphs: 480, train running loss: 0.00116 (passed time: 3h 3m 14s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00359, rec: 0.99641, prc: 0.99804, f1: 0.99722, f1_macro: 0.99858
# epoch: 45, passed number of graphs: 576, train running loss: 0.00114 (passed time: 3h 3m 41s)
#           acc: 0.99988, fpr: 0.00008, fnr: 0.00194, rec: 0.99806, prc: 0.99644, f1: 0.99725, f1_macro: 0.99859
# epoch: 45, passed number of graphs: 672, train running loss: 0.00127 (passed time: 3h 4m 10s)
#           acc: 0.99924, fpr: 0.00070, fnr: 0.00322, rec: 0.99678, prc: 0.96844, f1: 0.98241, f1_macro: 0.99101
# epoch: 45, passed number of graphs: 768, train running loss: 0.00134 (passed time: 3h 4m 37s)
#           acc: 0.99980, fpr: 0.00007, fnr: 0.00588, rec: 0.99412, prc: 0.99673, f1: 0.99542, f1_macro: 0.99766
# Validation --- epoch: 45, loss: 0.00454
#           fpr: 0.00041, fnr: 0.02348, acc: 0.99910, prc: 0.98786, rec: 0.97652, f1: 0.97939, f1_macro: 0.98946
# epoch: 46, passed number of graphs: 96, train running loss: 0.00112 (passed time: 3h 5m 30s)
#           acc: 0.99987, fpr: 0.00007, fnr: 0.00288, rec: 0.99712, prc: 0.99680, f1: 0.99696, f1_macro: 0.99845
# epoch: 46, passed number of graphs: 192, train running loss: 0.00122 (passed time: 3h 5m 57s)
#           acc: 0.99987, fpr: 0.00003, fnr: 0.00460, rec: 0.99540, prc: 0.99868, f1: 0.99704, f1_macro: 0.99849
# epoch: 46, passed number of graphs: 288, train running loss: 0.00117 (passed time: 3h 6m 24s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00394, rec: 0.99606, prc: 0.99803, f1: 0.99704, f1_macro: 0.99849
# epoch: 46, passed number of graphs: 384, train running loss: 0.00115 (passed time: 3h 6m 52s)
#           acc: 0.99980, fpr: 0.00006, fnr: 0.00646, rec: 0.99354, prc: 0.99741, f1: 0.99547, f1_macro: 0.99768
# epoch: 46, passed number of graphs: 480, train running loss: 0.00116 (passed time: 3h 7m 19s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00359, rec: 0.99641, prc: 0.99804, f1: 0.99722, f1_macro: 0.99858
# epoch: 46, passed number of graphs: 576, train running loss: 0.00114 (passed time: 3h 7m 47s)
#           acc: 0.99988, fpr: 0.00008, fnr: 0.00194, rec: 0.99806, prc: 0.99644, f1: 0.99725, f1_macro: 0.99859
# epoch: 46, passed number of graphs: 672, train running loss: 0.00127 (passed time: 3h 8m 15s)
#           acc: 0.99924, fpr: 0.00070, fnr: 0.00322, rec: 0.99678, prc: 0.96844, f1: 0.98241, f1_macro: 0.99101
# epoch: 46, passed number of graphs: 768, train running loss: 0.00134 (passed time: 3h 8m 42s)
#           acc: 0.99980, fpr: 0.00007, fnr: 0.00588, rec: 0.99412, prc: 0.99673, f1: 0.99542, f1_macro: 0.99766
# Validation --- epoch: 46, loss: 0.00454
#           fpr: 0.00041, fnr: 0.02348, acc: 0.99910, prc: 0.98786, rec: 0.97652, f1: 0.97939, f1_macro: 0.98946
# epoch: 47, passed number of graphs: 96, train running loss: 0.00112 (passed time: 3h 9m 35s)
#           acc: 0.99987, fpr: 0.00007, fnr: 0.00288, rec: 0.99712, prc: 0.99680, f1: 0.99696, f1_macro: 0.99845
# epoch: 47, passed number of graphs: 192, train running loss: 0.00122 (passed time: 3h 10m 2s)
#           acc: 0.99987, fpr: 0.00003, fnr: 0.00460, rec: 0.99540, prc: 0.99868, f1: 0.99704, f1_macro: 0.99849
# epoch: 47, passed number of graphs: 288, train running loss: 0.00117 (passed time: 3h 10m 29s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00394, rec: 0.99606, prc: 0.99803, f1: 0.99704, f1_macro: 0.99849
# epoch: 47, passed number of graphs: 384, train running loss: 0.00115 (passed time: 3h 10m 56s)
#           acc: 0.99980, fpr: 0.00006, fnr: 0.00646, rec: 0.99354, prc: 0.99741, f1: 0.99547, f1_macro: 0.99768
# epoch: 47, passed number of graphs: 480, train running loss: 0.00116 (passed time: 3h 11m 23s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00359, rec: 0.99641, prc: 0.99804, f1: 0.99722, f1_macro: 0.99858
# epoch: 47, passed number of graphs: 576, train running loss: 0.00114 (passed time: 3h 11m 51s)
#           acc: 0.99988, fpr: 0.00008, fnr: 0.00194, rec: 0.99806, prc: 0.99644, f1: 0.99725, f1_macro: 0.99859
# epoch: 47, passed number of graphs: 672, train running loss: 0.00127 (passed time: 3h 12m 18s)
#           acc: 0.99924, fpr: 0.00070, fnr: 0.00322, rec: 0.99678, prc: 0.96844, f1: 0.98241, f1_macro: 0.99101
# epoch: 47, passed number of graphs: 768, train running loss: 0.00134 (passed time: 3h 12m 46s)
#           acc: 0.99980, fpr: 0.00007, fnr: 0.00588, rec: 0.99412, prc: 0.99673, f1: 0.99542, f1_macro: 0.99766
# Validation --- epoch: 47, loss: 0.00454
#           fpr: 0.00041, fnr: 0.02348, acc: 0.99910, prc: 0.98786, rec: 0.97652, f1: 0.97939, f1_macro: 0.98946
# epoch: 48, passed number of graphs: 96, train running loss: 0.00112 (passed time: 3h 13m 40s)
#           acc: 0.99987, fpr: 0.00007, fnr: 0.00288, rec: 0.99712, prc: 0.99680, f1: 0.99696, f1_macro: 0.99845
# epoch: 48, passed number of graphs: 192, train running loss: 0.00122 (passed time: 3h 14m 8s)
#           acc: 0.99987, fpr: 0.00003, fnr: 0.00460, rec: 0.99540, prc: 0.99868, f1: 0.99704, f1_macro: 0.99849
# epoch: 48, passed number of graphs: 288, train running loss: 0.00117 (passed time: 3h 14m 35s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00394, rec: 0.99606, prc: 0.99803, f1: 0.99704, f1_macro: 0.99849
# epoch: 48, passed number of graphs: 384, train running loss: 0.00115 (passed time: 3h 15m 2s)
#           acc: 0.99980, fpr: 0.00006, fnr: 0.00646, rec: 0.99354, prc: 0.99741, f1: 0.99547, f1_macro: 0.99768
# epoch: 48, passed number of graphs: 480, train running loss: 0.00116 (passed time: 3h 15m 29s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00359, rec: 0.99641, prc: 0.99804, f1: 0.99722, f1_macro: 0.99858
# epoch: 48, passed number of graphs: 576, train running loss: 0.00114 (passed time: 3h 15m 56s)
#           acc: 0.99988, fpr: 0.00008, fnr: 0.00194, rec: 0.99806, prc: 0.99644, f1: 0.99725, f1_macro: 0.99859
# epoch: 48, passed number of graphs: 672, train running loss: 0.00127 (passed time: 3h 16m 24s)
#           acc: 0.99924, fpr: 0.00070, fnr: 0.00322, rec: 0.99678, prc: 0.96844, f1: 0.98241, f1_macro: 0.99101
# epoch: 48, passed number of graphs: 768, train running loss: 0.00134 (passed time: 3h 16m 51s)
#           acc: 0.99980, fpr: 0.00007, fnr: 0.00588, rec: 0.99412, prc: 0.99673, f1: 0.99542, f1_macro: 0.99766
# Validation --- epoch: 48, loss: 0.00454
#           fpr: 0.00041, fnr: 0.02348, acc: 0.99910, prc: 0.98786, rec: 0.97652, f1: 0.97938, f1_macro: 0.98946
# epoch: 49, passed number of graphs: 96, train running loss: 0.00112 (passed time: 3h 17m 45s)
#           acc: 0.99987, fpr: 0.00007, fnr: 0.00288, rec: 0.99712, prc: 0.99680, f1: 0.99696, f1_macro: 0.99845
# epoch: 49, passed number of graphs: 192, train running loss: 0.00122 (passed time: 3h 18m 13s)
#           acc: 0.99987, fpr: 0.00003, fnr: 0.00460, rec: 0.99540, prc: 0.99868, f1: 0.99704, f1_macro: 0.99849
# epoch: 49, passed number of graphs: 288, train running loss: 0.00117 (passed time: 3h 18m 41s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00394, rec: 0.99606, prc: 0.99803, f1: 0.99704, f1_macro: 0.99849
# epoch: 49, passed number of graphs: 384, train running loss: 0.00115 (passed time: 3h 19m 8s)
#           acc: 0.99980, fpr: 0.00006, fnr: 0.00646, rec: 0.99354, prc: 0.99741, f1: 0.99547, f1_macro: 0.99768
# epoch: 49, passed number of graphs: 480, train running loss: 0.00116 (passed time: 3h 19m 35s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00359, rec: 0.99641, prc: 0.99804, f1: 0.99722, f1_macro: 0.99858
# epoch: 49, passed number of graphs: 576, train running loss: 0.00114 (passed time: 3h 20m 2s)
#           acc: 0.99988, fpr: 0.00008, fnr: 0.00194, rec: 0.99806, prc: 0.99644, f1: 0.99725, f1_macro: 0.99859
# epoch: 49, passed number of graphs: 672, train running loss: 0.00127 (passed time: 3h 20m 30s)
#           acc: 0.99924, fpr: 0.00070, fnr: 0.00322, rec: 0.99678, prc: 0.96844, f1: 0.98241, f1_macro: 0.99101
# epoch: 49, passed number of graphs: 768, train running loss: 0.00134 (passed time: 3h 20m 57s)
#           acc: 0.99980, fpr: 0.00007, fnr: 0.00588, rec: 0.99412, prc: 0.99673, f1: 0.99542, f1_macro: 0.99766
# Validation --- epoch: 49, loss: 0.00454
#           fpr: 0.00041, fnr: 0.02348, acc: 0.99910, prc: 0.98786, rec: 0.97652, f1: 0.97939, f1_macro: 0.98946
# epoch: 50, passed number of graphs: 96, train running loss: 0.00112 (passed time: 3h 21m 50s)
#           acc: 0.99987, fpr: 0.00007, fnr: 0.00288, rec: 0.99712, prc: 0.99680, f1: 0.99696, f1_macro: 0.99845
# epoch: 50, passed number of graphs: 192, train running loss: 0.00122 (passed time: 3h 22m 18s)
#           acc: 0.99987, fpr: 0.00003, fnr: 0.00460, rec: 0.99540, prc: 0.99868, f1: 0.99704, f1_macro: 0.99849
# epoch: 50, passed number of graphs: 288, train running loss: 0.00117 (passed time: 3h 22m 46s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00394, rec: 0.99606, prc: 0.99803, f1: 0.99704, f1_macro: 0.99849
# epoch: 50, passed number of graphs: 384, train running loss: 0.00115 (passed time: 3h 23m 13s)
#           acc: 0.99980, fpr: 0.00006, fnr: 0.00646, rec: 0.99354, prc: 0.99741, f1: 0.99547, f1_macro: 0.99768
# epoch: 50, passed number of graphs: 480, train running loss: 0.00116 (passed time: 3h 23m 40s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00359, rec: 0.99641, prc: 0.99804, f1: 0.99722, f1_macro: 0.99858
# epoch: 50, passed number of graphs: 576, train running loss: 0.00114 (passed time: 3h 24m 8s)
#           acc: 0.99988, fpr: 0.00008, fnr: 0.00194, rec: 0.99806, prc: 0.99644, f1: 0.99725, f1_macro: 0.99859
# epoch: 50, passed number of graphs: 672, train running loss: 0.00127 (passed time: 3h 24m 36s)
#           acc: 0.99924, fpr: 0.00070, fnr: 0.00322, rec: 0.99678, prc: 0.96844, f1: 0.98241, f1_macro: 0.99101
# epoch: 50, passed number of graphs: 768, train running loss: 0.00134 (passed time: 3h 25m 3s)
#           acc: 0.99980, fpr: 0.00007, fnr: 0.00588, rec: 0.99412, prc: 0.99673, f1: 0.99542, f1_macro: 0.99766
# Validation --- epoch: 50, loss: 0.00454
#           fpr: 0.00041, fnr: 0.02348, acc: 0.99910, prc: 0.98786, rec: 0.97652, f1: 0.97939, f1_macro: 0.98946
# ************ best model obtained after epoch 15, saved at ./saved_models/GIN_14: 0.9829450210051869.pt ************
# Testing --- loss: 0.00318
#           fpr: 0.00019, fnr: 0.02040, acc: 0.99937, prc: 0.99188, rec: 0.97960, f1: 0.98466, f1_macro: 0.99217

# %%
# !zip -r /content/GENConv_p2p_normalization.zip /content/saved_models
# Out:
#   adding: content/saved_models/ (stored 0%)
#   adding: content/saved_models/GIN_3: 0.9593292840636528.pt (deflated 20%)
#   adding: content/saved_models/GIN_14: 0.9829450210051869.pt (deflated 25%)
#   adding: content/saved_models/GIN_5: 0.9763706152751599.pt (deflated 21%)
#   adding: content/saved_models/GIN_1: 0.04551941025907505.pt (deflated 20%)
#   adding: content/saved_models/GIN_6: 0.9788066881583047.pt (deflated 21%)
#   adding: content/saved_models/GIN_2: 0.06201881356305255.pt (deflated 20%)
#   adding: content/saved_models/GIN_12: 0.9823031374624173.pt (deflated 24%)
#   adding: content/saved_models/GIN_0: 0.0008698344175494597.pt (deflated 22%)

# %%
from google.colab import files
files.download("/content/GENConv_p2p_normalization.zip")
