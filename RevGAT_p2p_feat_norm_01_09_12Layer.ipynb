# %% [markdown]
# <a href="https://colab.research.google.com/github/Zoro1092000/xxxx/blob/main/RevGAT_p2p_feat_norm_01_09_12Layer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # I. Pip & Import.

# %%
import os
import os.path as osp
import torch
import sys

os.environ['TORCH'] = torch.__version__

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install torch-geometric
# !pip install torch-cluster -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install deepdish==0.3.5
# !pip install torch-optimizer

import torch.nn as nn
from torch.nn import Parameter
from torch_geometric.nn.inits import glorot, zeros
from torch_scatter import scatter_add
from torch.utils.data import DataLoader, Dataset
import torch_optimizer as optimization
from torch.nn import Linear, Sequential, BatchNorm1d, ReLU, Dropout, LayerNorm
from torch_geometric.nn import GINConv, GroupAddRev, GATv2Conv
import torch.nn.functional as F

from itertools import chain
import pickle
import h5py
import deepdish as dd
import numpy as np
from tqdm import tqdm
import inspect
import time
import math
import random
# Out:
#      |████████████████████████████████| 7.9 MB 2.7 MB/s
#      |████████████████████████████████| 3.5 MB 2.7 MB/s
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch-geometric
#   Downloading torch_geometric-2.1.0.post1.tar.gz (467 kB)
#      |████████████████████████████████| 467 kB 5.0 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (4.64.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.7.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.23.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (3.0.9)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.0.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->torch-geometric) (2.0.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (2022.9.24)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric) (1.2.0)
# Building wheels for collected packages: torch-geometric
#   Building wheel for torch-geometric (setup.py) ... done
#   Created wheel for torch-geometric: filename=torch_geometric-2.1.0.post1-py3-none-any.whl size=689859 sha256=fc5a4b17443557874c775f52d8499d12fbe9b7466574df59d22e879de7d04bf4
#   Stored in directory: /root/.cache/pip/wheels/d1/cb/43/f7f2e472de4d7cff31bceddadc36d634e1e545fbc17961c282
# Successfully built torch-geometric
# Installing collected packages: torch-geometric
# Successfully installed torch-geometric-2.1.0.post1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://data.pyg.org/whl/torch-1.12.1+cu113.html
# Collecting torch-cluster
#   Downloading https://data.pyg.org/whl/torch-1.12.0%2Bcu113/torch_cluster-1.6.0-cp37-cp37m-linux_x86_64.whl (2.4 MB)
#      |████████████████████████████████| 2.4 MB 541 kB/s
# Installing collected packages: torch-cluster
# Successfully installed torch-cluster-1.6.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting deepdish==0.3.5
#   Downloading deepdish-0.3.5-py2.py3-none-any.whl (37 kB)
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (3.7.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.7.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (21.3)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (2.8.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tables->deepdish==0.3.5) (3.0.9)
# Installing collected packages: deepdish
# Successfully installed deepdish-0.3.5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch-optimizer
#   Downloading torch_optimizer-0.3.0-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 445 kB/s
# Collecting pytorch-ranger>=0.1.1
#   Downloading pytorch_ranger-0.1.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: torch>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from torch-optimizer) (1.12.1+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.5.0->torch-optimizer) (4.1.1)
# Installing collected packages: pytorch-ranger, torch-optimizer
# Successfully installed pytorch-ranger-0.1.1 torch-optimizer-0.3.0

# %%
def time_since(start):
    now = time.time()
    s = now - start
    m = math.floor(s / 60)
    s -= m * 60
    h = math.floor(m / 60)
    m -= h * 60
    if h == 0:
        if m == 0:
            return '%ds' % s
        else:
            return '%dm %ds' % (m, s)
    else:
        return '%dh %dm %ds' % (h, m, s)

# %% [markdown]
# # II. Data

# %%
# Data utils
def h5group_to_dict(h5group):
    group_dict = {k: v[()] for k, v in chain(h5group.items(), h5group.attrs.items())}
    return group_dict

def sub_dict(full_dict, *keys, to_tensor):
    return {k: torch.tensor(full_dict[k]) if to_tensor else full_dict[k] for k in keys if k in full_dict}

def build_graph_from_dict_pyg(graph_dict, to_tensor=True):
    from torch_geometric.data import Data

    g = Data(**sub_dict(graph_dict, 'edge_index', 'x', 'y', 'edge_attr', 'edge_y', to_tensor=to_tensor))
    return g

# Data loader
class GraphDataLoader(DataLoader):
    def __init__(self, dataset, batch_size=128, shuffle=False, num_workers=0):

        def collate_graph(graph_obj_list):
            from torch_geometric.data import Batch
            batch = Batch.from_data_list(graph_obj_list)
            return batch

        super().__init__(
            dataset,
            batch_size=batch_size,
            shuffle=shuffle,
            collate_fn=collate_graph,
            num_workers=num_workers)

# BotnetDataset
class BotnetDataset(Dataset):

    def __init__(self, name='chord', root='data/botnet', split='train', graph_format='pyg', split_idx=None, add_nfeat_ones=True,
                 in_memory=True):
        super().__init__()
        assert name in ['chord', 'debru', 'kadem', 'leet', 'c2', 'p2p']
        assert split in ['train', 'val', 'test']

        if isinstance(root, str):
            root = osp.expanduser(osp.normpath(root))

        self.name = name
        self.root = root
        self.split = split
        self.split_idx = split_idx
        self.add_nfeat_ones = add_nfeat_ones

        self._graph_format = graph_format
        if split == 'train':
            self.path = self.processed_paths[0]
            self.num_graphs = 768
        elif split == 'val':
            self.path = self.processed_paths[1]
            self.num_graphs = 96
        elif split == 'test':
            self.path = self.processed_paths[2]
            self.num_graphs = 96

        if in_memory:
            self.data = dd.io.load(self.path)  # dictionary
            self.data_type = 'dict'
        else:
            # self.data = h5py.File(self.path, 'r')
            self.data = None    # defer opening file in each process to make multiprocessing work
            self.data_type = 'file'
            
    @property
    def processed_dir(self):
        return osp.join(self.root, 'processed')

    @property
    def processed_file_names(self):
        return [self.name + '_' + s + '.hdf5' for s in ('train', 'val', 'test')]

    @property
    def processed_paths(self):
        return [osp.join(self.processed_dir, f) for f in self.processed_file_names]

    def __len__(self):
        return self.num_graphs

    def __getitem__(self, index):
        if self.data_type == 'dict':
            graph_dict = self.data[str(index)]
        elif self.data_type == 'file':
            if self.data is None:
                # only open once in each process
                self.data = h5py.File(self.path, 'r')
            graph_dict = h5group_to_dict(self.data[str(index)])
        else:
            raise ValueError

        # graph_format == 'pyg':
        return build_graph_from_dict_pyg(graph_dict)


    def __iter__(self):
        for i in range(self.num_graphs):
            yield self[i]

    def __repr__(self):
        return f'{self.__class__.__name__}(topology: {self.name} | split: {self.split} | ' \
               f'#graphs: {len(self)} | graph format: {self.graph_format})'

# %% [markdown]
# # III. Measure Performancce

# %% [markdown]
# ## 3.1. Metrics

# %%
def f1(target, pred, label):
    # F1 = 2 * (precision * recall) / (precision + recall)
    tp = np.sum((target==label) & (pred==label))
    fp = np.sum((target!=label) & (pred==label))
    fn = np.sum((pred!=label) & (target==label))
    
    if tp+fp==0 or tp+fn==0:
      return np.nan

    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    
    if precision+recall==0:
      return np.nan
      
    f1 = 2 * (precision * recall) / (precision + recall)
    return f1

def f1_macro(pred, target):
    return np.mean([f1(target, pred, label) for label in range(0, 2)])


def accuracy(pred, target):
    return (pred == target).sum().item() / len(target)


def true_positive(pred, target):
    return (target[pred == 1] == 1).sum().item()


def false_positive(pred, target):
    return (target[pred == 1] == 0).sum().item()


def true_negative(pred, target):
    return (target[pred == 0] == 0).sum().item()


def false_negative(pred, target):
    return (target[pred == 0] == 1).sum().item()


def recall(pred, target):
    try:
        return true_positive(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1


def precision(pred, target):
    try:
        prec = true_positive(pred, target) / (pred == 1).sum().item()
        return prec
    except:  # divide by zero
        return -1


def f1_score(pred, target):
    prec = precision(pred, target)
    rec = recall(pred, target)
    try:
        return 2 * (prec * rec) / (prec + rec)
    except:
        return 0


def false_positive_rate(pred, target):
    try:
        return false_positive(pred, target) / (target == 0).sum().item()
    except:  # divide by zero
        return -1


def false_negative_rate(pred, target):
    try:
        return false_negative(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1

# %% [markdown]
# ## 3.2. Evaluation

# %%
def eval_metrics(target, pred_prob, threshold=0.5):
    if isinstance(target, torch.Tensor):
        target = target.cpu().numpy()
    if isinstance(pred_prob, torch.Tensor):
        pred_prob = pred_prob.cpu().numpy()

    pred = (pred_prob >= threshold).astype(int)

    acc = accuracy(pred, target)
    fpr = false_positive_rate(pred, target)
    fnr = false_negative_rate(pred, target)
    rec = recall(pred, target)
    prc = precision(pred, target)
    f1 = f1_score(pred, target)
    f1macro = f1_macro(pred, target)
    result_dict = {'acc': acc, 'fpr': fpr, 'fnr': fnr, 'rec': rec, 'prc': prc, 'f1': f1, 'f1_macro': f1macro}

    return result_dict


def dict_value_add(dict1, dict2):
    result = {key: dict1.get(key, 0) + dict2.get(key, 0)
              for key in set(dict1) | set(dict2)}
    return result


def dict_value_div(dict, n):
    result = {key: value / n for key, value in dict.items()}
    return result


def eval_predictor(dataset, predictor):
    result_dict_avg = {}
    loss_avg = 0

    for data in dataset:
        # prediction
        try:
            pred_prob, loss = predictor(data)
            loss_avg += loss
        except ValueError:  # if "too many values to unpack"
            pred_prob = predictor(data)

        # get the ground truth target
        # graph_format == 'pyg':
        target = data.y

        # compute the evaluation metrics
        result_dict = eval_metrics(target, pred_prob)

        result_dict_avg = dict_value_add(result_dict_avg, result_dict)

    # average the metrics across all graphs in the dataset as final results
    result_dict_avg = dict_value_div(result_dict_avg, len(dataset))
    loss_avg = loss_avg / len(dataset)

    return result_dict_avg, loss_avg


# =================================================================================================================
# some examples of the 'predictor' model wrapper to be fed into the above evaluation function (for PyG Data format)
# =================================================================================================================
class PygRandomPredictor:
    def __init__(self):
        # torch.manual_seed(0)
        pass

    def __call__(self, data):
        pred_prob = torch.rand(len(data.y))
        return pred_prob


class PygModelPredictor:
    def __init__(self, model, loss_fcn=torch.nn.CrossEntropyLoss()):
        self.model = model
        self.loss_fcn = loss_fcn
        self.device = next(model.parameters()).device

    def __call__(self, data):
        self.model.eval()
        data = data.to(self.device)
        with torch.no_grad():
            # custom the below line to adjust to your model's input format for forward pass
            out = self.model(data.x, data.edge_index)
            loss = self.loss_fcn(out, data.y.long())
            pred_prob = torch.softmax(out, dim=1)[:, 1]
        return pred_prob, loss.float()

# %% [markdown]
# # IV. Model

# %% [markdown]
# ## 5.1. Activation

# %%
def activation(act, negative_slope=0.2):
    activations = nn.ModuleDict([
        ['lrelu', nn.LeakyReLU(negative_slope)],
        ['relu', nn.ReLU()],
        ['elu', nn.ELU()],
        ['none', nn.Identity()],
    ])
    return activations[act]

# %% [markdown]
# ## 5.2. GIN model

# %%
class RevGINModel(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, num_layers,
                 dropout, num_groups=2):
        super().__init__()

        self.dropout = dropout

        self.lin1 = Linear(in_channels, hidden_channels)
        self.lin2 = Linear(hidden_channels, out_channels)
        self.norm = LayerNorm(hidden_channels, elementwise_affine=True)

        assert hidden_channels % num_groups == 0
        self.GATLayers = torch.nn.ModuleList()
        for layer in range(num_layers):
          GATLayer = GATv2Conv(hidden_channels // num_groups, hidden_channels // num_groups, heads=1, concat=False)
          self.GATLayers.append(GroupAddRev(GATLayer, num_groups=num_groups))

    def reset_parameters(self):
        self.lin1.reset_parameters()
        self.lin2.reset_parameters()
        self.norm.reset_parameters()
        for Layer in self.GINLayers:
            Layer.reset_parameters()

    def forward(self, x, edge_index):
        x = self.lin1(x)

        for Layer in self.GATLayers:
            x = Layer(x, edge_index)
        x = self.norm(x).relu()
        x = F.dropout(x, p=self.dropout, training=self.training)
        return self.lin2(x)

# %% [markdown]
# # V. Load data

# %%
data_dir = '/content/drive/Shareddrives/botnetdata/p2p_6k_feat_norm'
data_name = 'p2p' # 'chord', 'debru', 'kadem', 'leet', 'c2', 'p2p'
shuffle = False

# ========== load the dataset
print('loading dataset...')

train_ds = BotnetDataset(name=data_name, root=data_dir, split='train',
                         in_memory=True, graph_format='pyg')
val_ds = BotnetDataset(name=data_name, root=data_dir, split='val',
                       in_memory=False, graph_format='pyg')
test_ds = BotnetDataset(name=data_name, root=data_dir, split='test',
                        in_memory=False, graph_format='pyg')
# Out:
# loading dataset...

# %%
torch.cuda.empty_cache()

# %%
batch_size = 4
train_loader = GraphDataLoader(train_ds, batch_size=batch_size, shuffle=bool(shuffle), num_workers=0)

# %% [markdown]
# # VI. Train

# %%
# ============== some default parameters =============
devid = 0
seed = 0
logmode = 'w'
log_interval = 96

dim_input_feature = 1
dim_hidden_feature = 32
dim_output_feature = 2
act = 'relu' # 'none', 'lrelu', 'relu', 'elu'

num_layers = 6
num_classes = 2 

dropout = 0.5
bias = True

lr = 0.005 # learning rate
weight_decay = 5e-4
epochs = 50
save_dir = './saved_models'
save_name = "GIN_model.pt"
# ====================================================

def train(model, train_loader, val_dataset, test_dataset, optimizer, scheduler=None):
    device = next(model.parameters()).device
    predictor = PygModelPredictor(model)

    best_epoch = 0
    max_f1_score = 0
    start = time.time()
    for ep in range(epochs):
        loss_avg_train = 0
        num_train_graph = 0
        model.train()
        for n, batch in enumerate(train_loader):
            batch.to(device)

            optimizer.zero_grad()

            x = model(batch.x, batch.edge_index)
            loss = criterion(x, batch.y.long())

            loss_avg_train += float(loss)
            num_train_graph += batch.num_graphs

            loss.backward()
            optimizer.step()

            if num_train_graph % log_interval == 0 or n == len(train_loader) - 1:
                with torch.no_grad():
                    # pred = x.argmax(dim=1)
                    pred_prob = torch.softmax(x, dim=1)[:, 1]
                    y = batch.y.long()
                    result_dict = eval_metrics(y, pred_prob)
                print(f'epoch: {ep + 1}, passed number of graphs: {num_train_graph}, '
                        f'train running loss: {loss_avg_train / num_train_graph:.5f} (passed time: {time_since(start)})')
                print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict.items()]))

        result_dict_avg, loss_avg = eval_predictor(val_dataset, predictor)
        print(f'Validation --- epoch: {ep + 1}, loss: {loss_avg:.5f}')
        print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))

        if scheduler is not None:
            scheduler.step(loss_avg)

        if result_dict_avg['f1'] > max_f1_score:
            save_name = f"GIN_{ep}: {result_dict_avg['f1']}.pt"
            torch.save(model, os.path.join(save_dir, save_name))
            print(f'Better model saved at {os.path.join(save_dir, save_name)}.')
            best_epoch = ep
            max_f1_score = result_dict_avg['f1']

    best_model = torch.load(os.path.join(save_dir, save_name))
    print('*' * 12 + f' best model obtained after epoch {best_epoch + 1}, '
                       f'saved at {os.path.join(save_dir, save_name)} ' + '*' * 12)
    
    predictor = PygModelPredictor(best_model)

    result_dict_avg, loss_avg = eval_predictor(test_dataset, predictor)
    print(f'Testing --- loss: {loss_avg:.5f}')
    print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))


if __name__ == '__main__':
    os.makedirs(save_dir, exist_ok=True)

    # ========== random seeds and device
    random.seed(seed)
    torch.manual_seed(seed)

    device = torch.device(f'cuda:{devid}') if devid > -1 else torch.device('cpu')

    # ========== logging setup
    log_name = os.path.splitext(save_name)[0]
    # logger = logging_config(__name__, folder=save_dir, name=log_name, filemode=logmode)
    # logger = logging_config(os.path.basename(__file__), folder=save_dir, name=log_name, filemode=logmode)

    print('python ' + ' '.join(sys.argv))
    print('-' * 30)
    #logger.info(args)
    print('-' * 30)
    print(time.ctime())
    print('-' * 30)

    # ========== define the model, optimizer, and loss

    model = RevGINModel(in_channels = dim_input_feature,
                        hidden_channels = dim_hidden_feature,
                        out_channels = dim_output_feature,
                        num_layers = num_layers,
                        dropout = dropout)

    print('model ' + '-' * 10)
    print(repr(model))
    model.to(device)
    
    class_weight = torch.Tensor([0.1, 0.9])
    class_weight = class_weight.cuda(device=0)
    criterion = torch.nn.CrossEntropyLoss(weight=class_weight)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.25, patience=1)

    # ========== train the model
    print(f"Batch size: {batch_size}")
    train(model, train_loader, val_ds, test_ds, optimizer, scheduler)
# Out:
# python /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-579e1454-7543-4c43-af52-5f1c3041db96.json
# ------------------------------
# ------------------------------
# Sat Nov  5 07:53:04 2022
# ------------------------------
# model ----------
# RevGINModel(
#   (lin1): Linear(in_features=1, out_features=32, bias=True)
#   (lin2): Linear(in_features=32, out_features=2, bias=True)
#   (norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#   (GATLayers): ModuleList(
#     (0): GroupAddRev(GATv2Conv(16, 16, heads=1), num_groups=2)
#     (1): GroupAddRev(GATv2Conv(16, 16, heads=1), num_groups=2)
#     (2): GroupAddRev(GATv2Conv(16, 16, heads=1), num_groups=2)
#     (3): GroupAddRev(GATv2Conv(16, 16, heads=1), num_groups=2)
#     (4): GroupAddRev(GATv2Conv(16, 16, heads=1), num_groups=2)
#     (5): GroupAddRev(GATv2Conv(16, 16, heads=1), num_groups=2)
#   )
# )
# Batch size: 4
# epoch: 1, passed number of graphs: 96, train running loss: 0.15271 (passed time: 51s)
#           acc: 0.95754, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 192, train running loss: 0.15136 (passed time: 1m 43s)
#           acc: 0.95804, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 288, train running loss: 0.15084 (passed time: 2m 35s)
#           acc: 0.95790, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 384, train running loss: 0.15053 (passed time: 3m 27s)
#           acc: 0.95738, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 480, train running loss: 0.15031 (passed time: 4m 18s)
#           acc: 0.95750, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 576, train running loss: 0.15014 (passed time: 5m 10s)
#           acc: 0.95742, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 672, train running loss: 0.15004 (passed time: 6m 2s)
#           acc: 0.95773, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 768, train running loss: 0.14993 (passed time: 6m 54s)
#           acc: 0.95822, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# Validation --- epoch: 1, loss: 0.35464
#           acc: 0.97848, f1: 0.00000, f1_macro: nan, fpr: 0.00000, prc: -1.00000, rec: 0.00000, fnr: 1.00000
# epoch: 2, passed number of graphs: 96, train running loss: 0.14918 (passed time: 8m 10s)
#           acc: 0.95754, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 2, passed number of graphs: 192, train running loss: 0.14913 (passed time: 9m 1s)
#           acc: 0.95804, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 2, passed number of graphs: 288, train running loss: 0.14916 (passed time: 9m 53s)
#           acc: 0.95790, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 2, passed number of graphs: 384, train running loss: 0.14911 (passed time: 10m 45s)
#           acc: 0.95738, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 2, passed number of graphs: 480, train running loss: 0.14887 (passed time: 11m 36s)
#           acc: 0.95750, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 2, passed number of graphs: 576, train running loss: 0.14879 (passed time: 12m 28s)
#           acc: 0.95742, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 2, passed number of graphs: 672, train running loss: 0.14852 (passed time: 13m 20s)
#           acc: 0.95773, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 2, passed number of graphs: 768, train running loss: 0.14811 (passed time: 14m 12s)
#           acc: 0.95822, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# Validation --- epoch: 2, loss: 0.35443
#           acc: 0.97848, f1: 0.00000, f1_macro: nan, fpr: 0.00000, prc: -1.00000, rec: 0.00000, fnr: 1.00000
# epoch: 3, passed number of graphs: 96, train running loss: 0.14584 (passed time: 15m 28s)
#           acc: 0.95754, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 3, passed number of graphs: 192, train running loss: 0.14216 (passed time: 16m 20s)
#           acc: 0.95700, fpr: 0.00123, fnr: 0.99682, rec: 0.00318, prc: 0.10145, f1: 0.00617, f1_macro: 0.49209
# epoch: 3, passed number of graphs: 288, train running loss: 0.13904 (passed time: 17m 11s)
#           acc: 0.88513, fpr: 0.09399, fnr: 0.58994, rec: 0.41006, prc: 0.16088, f1: 0.23109, f1_macro: 0.58451
# epoch: 3, passed number of graphs: 384, train running loss: 0.13499 (passed time: 18m 3s)
#           acc: 0.95738, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 3, passed number of graphs: 480, train running loss: 0.13507 (passed time: 18m 55s)
#           acc: 0.95750, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 3, passed number of graphs: 576, train running loss: 0.13695 (passed time: 19m 47s)
#           acc: 0.95742, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 3, passed number of graphs: 672, train running loss: 0.13138 (passed time: 20m 38s)
#           acc: 0.71239, fpr: 0.29580, fnr: 0.10197, rec: 0.89803, prc: 0.11816, f1: 0.20884, f1_macro: 0.51655
# epoch: 3, passed number of graphs: 768, train running loss: 0.12150 (passed time: 21m 30s)
#           acc: 0.98812, fpr: 0.00818, fnr: 0.09674, rec: 0.90326, prc: 0.82808, f1: 0.86404, f1_macro: 0.92892
# Validation --- epoch: 3, loss: 0.03000
#           acc: 0.99108, f1: 0.82799, f1_macro: 0.91170, fpr: 0.00861, prc: 0.72250, rec: 0.97687, fnr: 0.02313
# Better model saved at ./saved_models/GIN_2: 0.8279887851233291.pt.
# epoch: 4, passed number of graphs: 96, train running loss: 0.01704 (passed time: 22m 47s)
#           acc: 0.99121, fpr: 0.00806, fnr: 0.02509, rec: 0.97491, prc: 0.84280, f1: 0.90406, f1_macro: 0.94973
# epoch: 4, passed number of graphs: 192, train running loss: 0.02490 (passed time: 23m 39s)
#           acc: 0.99173, fpr: 0.00513, fnr: 0.07982, rec: 0.92018, prc: 0.88699, f1: 0.90328, f1_macro: 0.94948
# epoch: 4, passed number of graphs: 288, train running loss: 0.02427 (passed time: 24m 31s)
#           acc: 0.98297, fpr: 0.01666, fnr: 0.02531, rec: 0.97469, prc: 0.71992, f1: 0.82815, f1_macro: 0.90960
# epoch: 4, passed number of graphs: 384, train running loss: 0.02142 (passed time: 25m 22s)
#           acc: 0.99026, fpr: 0.00929, fnr: 0.01981, rec: 0.98019, prc: 0.82446, f1: 0.89561, f1_macro: 0.94525
# epoch: 4, passed number of graphs: 480, train running loss: 0.01958 (passed time: 26m 14s)
#           acc: 0.99441, fpr: 0.00503, fnr: 0.01812, rec: 0.98188, prc: 0.89644, f1: 0.93722, f1_macro: 0.96715
# epoch: 4, passed number of graphs: 576, train running loss: 0.01813 (passed time: 27m 6s)
#           acc: 0.99053, fpr: 0.00100, fnr: 0.19983, rec: 0.80017, prc: 0.97264, f1: 0.87801, f1_macro: 0.93655
# epoch: 4, passed number of graphs: 672, train running loss: 0.01936 (passed time: 27m 58s)
#           acc: 0.99705, fpr: 0.00131, fnr: 0.03990, rec: 0.96010, prc: 0.96990, f1: 0.96498, f1_macro: 0.98172
# epoch: 4, passed number of graphs: 768, train running loss: 0.01858 (passed time: 28m 49s)
#           acc: 0.99338, fpr: 0.00599, fnr: 0.02104, rec: 0.97896, prc: 0.87697, f1: 0.92516, f1_macro: 0.96085
# Validation --- epoch: 4, loss: 0.00788
#           acc: 0.99799, f1: 0.95515, f1_macro: 0.97706, fpr: 0.00173, prc: 0.93065, rec: 0.98498, fnr: 0.01502
# Better model saved at ./saved_models/GIN_3: 0.9551525769510719.pt.
# epoch: 5, passed number of graphs: 96, train running loss: 0.01012 (passed time: 30m 6s)
#           acc: 0.98908, fpr: 0.01060, fnr: 0.01807, rec: 0.98193, prc: 0.80422, f1: 0.88424, f1_macro: 0.93925
# epoch: 5, passed number of graphs: 192, train running loss: 0.01048 (passed time: 30m 58s)
#           acc: 0.99599, fpr: 0.00082, fnr: 0.07689, rec: 0.92311, prc: 0.98018, f1: 0.95079, f1_macro: 0.97435
# epoch: 5, passed number of graphs: 288, train running loss: 0.00964 (passed time: 31m 49s)
#           acc: 0.99286, fpr: 0.00667, fnr: 0.01802, rec: 0.98198, prc: 0.86618, f1: 0.92045, f1_macro: 0.95836
# epoch: 5, passed number of graphs: 384, train running loss: 0.00928 (passed time: 32m 41s)
#           acc: 0.99782, fpr: 0.00105, fnr: 0.02764, rec: 0.97236, prc: 0.97632, f1: 0.97434, f1_macro: 0.98660
# epoch: 5, passed number of graphs: 480, train running loss: 0.01073 (passed time: 33m 33s)
#           acc: 0.97216, fpr: 0.02827, fnr: 0.01808, rec: 0.98192, prc: 0.60657, f1: 0.74990, f1_macro: 0.86758
# epoch: 5, passed number of graphs: 576, train running loss: 0.01103 (passed time: 34m 25s)
#           acc: 0.99715, fpr: 0.00094, fnr: 0.04563, rec: 0.95437, prc: 0.97822, f1: 0.96615, f1_macro: 0.98233
# epoch: 5, passed number of graphs: 672, train running loss: 0.01098 (passed time: 35m 16s)
#           acc: 0.99753, fpr: 0.00165, fnr: 0.02107, rec: 0.97893, prc: 0.96330, f1: 0.97105, f1_macro: 0.98488
# epoch: 5, passed number of graphs: 768, train running loss: 0.01100 (passed time: 36m 8s)
#           acc: 0.99079, fpr: 0.00953, fnr: 0.00182, rec: 0.99818, prc: 0.82039, f1: 0.90060, f1_macro: 0.94789
# Validation --- epoch: 5, loss: 0.01192
#           acc: 0.99673, f1: 0.93502, f1_macro: 0.96667, fpr: 0.00316, prc: 0.89312, rec: 0.99192, fnr: 0.00808
# epoch: 6, passed number of graphs: 96, train running loss: 0.00940 (passed time: 37m 25s)
#           acc: 0.99054, fpr: 0.00976, fnr: 0.00269, rec: 0.99731, prc: 0.81923, f1: 0.89954, f1_macro: 0.94729
# epoch: 6, passed number of graphs: 192, train running loss: 0.00967 (passed time: 38m 17s)
#           acc: 0.99641, fpr: 0.00096, fnr: 0.06359, rec: 0.93641, prc: 0.97716, f1: 0.95635, f1_macro: 0.97724
# epoch: 6, passed number of graphs: 288, train running loss: 0.00894 (passed time: 39m 8s)
#           acc: 0.99418, fpr: 0.00593, fnr: 0.00340, rec: 0.99660, prc: 0.88082, f1: 0.93514, f1_macro: 0.96605
# epoch: 6, passed number of graphs: 384, train running loss: 0.00865 (passed time: 40m 0s)
#           acc: 0.99801, fpr: 0.00175, fnr: 0.00746, rec: 0.99254, prc: 0.96200, f1: 0.97703, f1_macro: 0.98800
# epoch: 6, passed number of graphs: 480, train running loss: 0.01106 (passed time: 40m 52s)
#           acc: 0.93115, fpr: 0.07188, fnr: 0.00058, rec: 0.99942, prc: 0.38163, f1: 0.55235, f1_macro: 0.75753
# epoch: 6, passed number of graphs: 576, train running loss: 0.01210 (passed time: 41m 44s)
#           acc: 0.99250, fpr: 0.00773, fnr: 0.00228, rec: 0.99772, prc: 0.85167, f1: 0.91893, f1_macro: 0.95750
# epoch: 6, passed number of graphs: 672, train running loss: 0.01223 (passed time: 42m 35s)
#           acc: 0.99678, fpr: 0.00332, fnr: 0.00098, rec: 0.99902, prc: 0.93004, f1: 0.96330, f1_macro: 0.98081
# epoch: 6, passed number of graphs: 768, train running loss: 0.01191 (passed time: 43m 27s)
#           acc: 0.99716, fpr: 0.00289, fnr: 0.00169, rec: 0.99831, prc: 0.93779, f1: 0.96710, f1_macro: 0.98281
# Validation --- epoch: 6, loss: 0.00510
#           acc: 0.99876, f1: 0.97174, f1_macro: 0.98555, fpr: 0.00102, prc: 0.95875, rec: 0.98867, fnr: 0.01133
# Better model saved at ./saved_models/GIN_5: 0.9717382163471308.pt.
# epoch: 7, passed number of graphs: 96, train running loss: 0.00759 (passed time: 44m 44s)
#           acc: 0.99626, fpr: 0.00386, fnr: 0.00102, rec: 0.99898, prc: 0.91980, f1: 0.95776, f1_macro: 0.97790
# epoch: 7, passed number of graphs: 192, train running loss: 0.00856 (passed time: 45m 35s)
#           acc: 0.99657, fpr: 0.00064, fnr: 0.06706, rec: 0.93294, prc: 0.98457, f1: 0.95806, f1_macro: 0.97814
# epoch: 7, passed number of graphs: 288, train running loss: 0.00804 (passed time: 46m 27s)
#           acc: 0.99277, fpr: 0.00752, fnr: 0.00062, rec: 0.99938, prc: 0.85385, f1: 0.92090, f1_macro: 0.95856
# epoch: 7, passed number of graphs: 384, train running loss: 0.00766 (passed time: 47m 19s)
#           acc: 0.99878, fpr: 0.00116, fnr: 0.00250, rec: 0.99750, prc: 0.97448, f1: 0.98585, f1_macro: 0.99261
# epoch: 7, passed number of graphs: 480, train running loss: 0.00784 (passed time: 48m 11s)
#           acc: 0.99731, fpr: 0.00275, fnr: 0.00121, rec: 0.99879, prc: 0.94153, f1: 0.96932, f1_macro: 0.98396
# epoch: 7, passed number of graphs: 576, train running loss: 0.00735 (passed time: 49m 3s)
#           acc: 0.99711, fpr: 0.00300, fnr: 0.00057, rec: 0.99943, prc: 0.93681, f1: 0.96711, f1_macro: 0.98280
# epoch: 7, passed number of graphs: 672, train running loss: 0.00750 (passed time: 49m 54s)
#           acc: 0.99532, fpr: 0.00487, fnr: 0.00033, rec: 0.99967, prc: 0.90061, f1: 0.94756, f1_macro: 0.97256
# epoch: 7, passed number of graphs: 768, train running loss: 0.00753 (passed time: 50m 46s)
#           acc: 0.99856, fpr: 0.00140, fnr: 0.00232, rec: 0.99768, prc: 0.96889, f1: 0.98307, f1_macro: 0.99116
# Validation --- epoch: 7, loss: 0.00354
#           acc: 0.99916, f1: 0.98004, f1_macro: 0.98980, fpr: 0.00063, prc: 0.97339, rec: 0.98928, fnr: 0.01072
# Better model saved at ./saved_models/GIN_6: 0.9800384044076771.pt.
# epoch: 8, passed number of graphs: 96, train running loss: 0.00614 (passed time: 52m 2s)
#           acc: 0.99685, fpr: 0.00327, fnr: 0.00057, rec: 0.99943, prc: 0.93134, f1: 0.96418, f1_macro: 0.98127
# epoch: 8, passed number of graphs: 192, train running loss: 0.00721 (passed time: 52m 54s)
#           acc: 0.99698, fpr: 0.00064, fnr: 0.05719, rec: 0.94281, prc: 0.98465, f1: 0.96327, f1_macro: 0.98085
# epoch: 8, passed number of graphs: 288, train running loss: 0.00698 (passed time: 53m 46s)
#           acc: 0.99781, fpr: 0.00217, fnr: 0.00257, rec: 0.99743, prc: 0.95283, f1: 0.97462, f1_macro: 0.98674
# epoch: 8, passed number of graphs: 384, train running loss: 0.00668 (passed time: 54m 38s)
#           acc: 0.99908, fpr: 0.00076, fnr: 0.00463, rec: 0.99537, prc: 0.98323, f1: 0.98926, f1_macro: 0.99439
# epoch: 8, passed number of graphs: 480, train running loss: 0.00687 (passed time: 55m 29s)
#           acc: 0.99732, fpr: 0.00277, fnr: 0.00083, rec: 0.99917, prc: 0.94129, f1: 0.96937, f1_macro: 0.98398
# epoch: 8, passed number of graphs: 576, train running loss: 0.00643 (passed time: 56m 21s)
#           acc: 0.99759, fpr: 0.00250, fnr: 0.00033, rec: 0.99967, prc: 0.94678, f1: 0.97251, f1_macro: 0.98562
# epoch: 8, passed number of graphs: 672, train running loss: 0.00658 (passed time: 57m 13s)
#           acc: 0.99596, fpr: 0.00421, fnr: 0.00033, rec: 0.99967, prc: 0.91294, f1: 0.95434, f1_macro: 0.97611
# epoch: 8, passed number of graphs: 768, train running loss: 0.00659 (passed time: 58m 5s)
#           acc: 0.99876, fpr: 0.00122, fnr: 0.00174, rec: 0.99826, prc: 0.97277, f1: 0.98535, f1_macro: 0.99235
# Validation --- epoch: 8, loss: 0.00330
#           acc: 0.99922, f1: 0.98148, f1_macro: 0.99054, fpr: 0.00056, prc: 0.97610, rec: 0.98934, fnr: 0.01066
# Better model saved at ./saved_models/GIN_7: 0.9814762066017986.pt.
# epoch: 9, passed number of graphs: 96, train running loss: 0.00549 (passed time: 59m 21s)
#           acc: 0.99662, fpr: 0.00352, fnr: 0.00020, rec: 0.99980, prc: 0.92640, f1: 0.96170, f1_macro: 0.97996
# epoch: 9, passed number of graphs: 192, train running loss: 0.00661 (passed time: 1h 0m 13s)
#           acc: 0.99711, fpr: 0.00059, fnr: 0.05542, rec: 0.94458, prc: 0.98595, f1: 0.96482, f1_macro: 0.98166
# epoch: 9, passed number of graphs: 288, train running loss: 0.00635 (passed time: 1h 1m 5s)
#           acc: 0.99881, fpr: 0.00119, fnr: 0.00099, rec: 0.99901, prc: 0.97352, f1: 0.98610, f1_macro: 0.99274
# epoch: 9, passed number of graphs: 384, train running loss: 0.00608 (passed time: 1h 1m 57s)
#           acc: 0.99907, fpr: 0.00078, fnr: 0.00435, rec: 0.99565, prc: 0.98272, f1: 0.98914, f1_macro: 0.99433
# epoch: 9, passed number of graphs: 480, train running loss: 0.00621 (passed time: 1h 2m 48s)
#           acc: 0.99795, fpr: 0.00212, fnr: 0.00058, rec: 0.99942, prc: 0.95449, f1: 0.97644, f1_macro: 0.98768
# epoch: 9, passed number of graphs: 576, train running loss: 0.00580 (passed time: 1h 3m 40s)
#           acc: 0.99793, fpr: 0.00215, fnr: 0.00012, rec: 0.99988, prc: 0.95382, f1: 0.97631, f1_macro: 0.98761
# epoch: 9, passed number of graphs: 672, train running loss: 0.00590 (passed time: 1h 4m 32s)
#           acc: 0.99589, fpr: 0.00429, fnr: 0.00004, rec: 0.99996, prc: 0.91137, f1: 0.95361, f1_macro: 0.97573
# epoch: 9, passed number of graphs: 768, train running loss: 0.00592 (passed time: 1h 5m 24s)
#           acc: 0.99920, fpr: 0.00075, fnr: 0.00194, rec: 0.99806, prc: 0.98314, f1: 0.99054, f1_macro: 0.99506
# Validation --- epoch: 9, loss: 0.00275
#           acc: 0.99941, f1: 0.98548, f1_macro: 0.99259, fpr: 0.00036, prc: 0.98396, rec: 0.98909, fnr: 0.01091
# Better model saved at ./saved_models/GIN_8: 0.9854781613281934.pt.
# epoch: 10, passed number of graphs: 96, train running loss: 0.00488 (passed time: 1h 6m 40s)
#           acc: 0.99708, fpr: 0.00305, fnr: 0.00008, rec: 0.99992, prc: 0.93567, f1: 0.96673, f1_macro: 0.98260
# epoch: 10, passed number of graphs: 192, train running loss: 0.00556 (passed time: 1h 7m 32s)
#           acc: 0.99725, fpr: 0.00058, fnr: 0.05228, rec: 0.94772, prc: 0.98612, f1: 0.96654, f1_macro: 0.98255
# epoch: 10, passed number of graphs: 288, train running loss: 0.00551 (passed time: 1h 8m 24s)
#           acc: 0.99818, fpr: 0.00189, fnr: 0.00037, rec: 0.99963, prc: 0.95879, f1: 0.97878, f1_macro: 0.98892
# epoch: 10, passed number of graphs: 384, train running loss: 0.00537 (passed time: 1h 9m 15s)
#           acc: 0.99910, fpr: 0.00079, fnr: 0.00332, rec: 0.99668, prc: 0.98242, f1: 0.98950, f1_macro: 0.99451
# epoch: 10, passed number of graphs: 480, train running loss: 0.00552 (passed time: 1h 10m 7s)
#           acc: 0.99813, fpr: 0.00192, fnr: 0.00058, rec: 0.99942, prc: 0.95842, f1: 0.97849, f1_macro: 0.98876
# epoch: 10, passed number of graphs: 576, train running loss: 0.00522 (passed time: 1h 10m 59s)
#           acc: 0.99694, fpr: 0.00318, fnr: 0.00037, rec: 0.99963, prc: 0.93322, f1: 0.96529, f1_macro: 0.98184
# epoch: 10, passed number of graphs: 672, train running loss: 0.00531 (passed time: 1h 11m 51s)
#           acc: 0.99711, fpr: 0.00301, fnr: 0.00012, rec: 0.99988, prc: 0.93609, f1: 0.96693, f1_macro: 0.98271
# epoch: 10, passed number of graphs: 768, train running loss: 0.00545 (passed time: 1h 12m 42s)
#           acc: 0.99793, fpr: 0.00214, fnr: 0.00045, rec: 0.99955, prc: 0.95320, f1: 0.97582, f1_macro: 0.98737
# Validation --- epoch: 10, loss: 0.00608
#           acc: 0.99859, f1: 0.96943, f1_macro: 0.98435, fpr: 0.00126, prc: 0.95197, rec: 0.99180, fnr: 0.00820
# epoch: 11, passed number of graphs: 96, train running loss: 0.00416 (passed time: 1h 13m 59s)
#           acc: 0.99910, fpr: 0.00093, fnr: 0.00029, rec: 0.99971, prc: 0.97942, f1: 0.98946, f1_macro: 0.99449
# epoch: 11, passed number of graphs: 192, train running loss: 0.00459 (passed time: 1h 14m 51s)
#           acc: 0.99702, fpr: 0.00052, fnr: 0.05901, rec: 0.94099, prc: 0.98743, f1: 0.96365, f1_macro: 0.98105
# epoch: 11, passed number of graphs: 288, train running loss: 0.00477 (passed time: 1h 15m 42s)
#           acc: 0.99420, fpr: 0.00605, fnr: 0.00021, rec: 0.99979, prc: 0.87900, f1: 0.93551, f1_macro: 0.96624
# epoch: 11, passed number of graphs: 384, train running loss: 0.00484 (passed time: 1h 16m 34s)
#           acc: 0.99930, fpr: 0.00066, fnr: 0.00156, rec: 0.99844, prc: 0.98539, f1: 0.99187, f1_macro: 0.99575
# epoch: 11, passed number of graphs: 480, train running loss: 0.00506 (passed time: 1h 17m 26s)
#           acc: 0.99813, fpr: 0.00193, fnr: 0.00050, rec: 0.99950, prc: 0.95827, f1: 0.97845, f1_macro: 0.98874
# epoch: 11, passed number of graphs: 576, train running loss: 0.00472 (passed time: 1h 18m 18s)
#           acc: 0.99877, fpr: 0.00125, fnr: 0.00073, rec: 0.99927, prc: 0.97261, f1: 0.98576, f1_macro: 0.99256
# epoch: 11, passed number of graphs: 672, train running loss: 0.00482 (passed time: 1h 19m 9s)
#           acc: 0.99750, fpr: 0.00260, fnr: 0.00020, rec: 0.99980, prc: 0.94441, f1: 0.97131, f1_macro: 0.98500
# epoch: 11, passed number of graphs: 768, train running loss: 0.00493 (passed time: 1h 20m 1s)
#           acc: 0.99726, fpr: 0.00286, fnr: 0.00000, rec: 1.00000, prc: 0.93847, f1: 0.96826, f1_macro: 0.98341
# Validation --- epoch: 11, loss: 0.00469
#           acc: 0.99887, f1: 0.97460, f1_macro: 0.98701, fpr: 0.00096, prc: 0.96128, rec: 0.99121, fnr: 0.00879
# epoch: 12, passed number of graphs: 96, train running loss: 0.00371 (passed time: 1h 21m 18s)
#           acc: 0.99937, fpr: 0.00062, fnr: 0.00065, rec: 0.99935, prc: 0.98611, f1: 0.99269, f1_macro: 0.99618
# epoch: 12, passed number of graphs: 192, train running loss: 0.00383 (passed time: 1h 22m 9s)
#           acc: 0.99720, fpr: 0.00083, fnr: 0.04778, rec: 0.95222, prc: 0.98044, f1: 0.96613, f1_macro: 0.98233
# epoch: 12, passed number of graphs: 288, train running loss: 0.00340 (passed time: 1h 23m 1s)
#           acc: 0.99864, fpr: 0.00141, fnr: 0.00021, rec: 0.99979, prc: 0.96889, f1: 0.98410, f1_macro: 0.99169
# epoch: 12, passed number of graphs: 384, train running loss: 0.00342 (passed time: 1h 23m 53s)
#           acc: 0.99740, fpr: 0.00271, fnr: 0.00029, rec: 0.99971, prc: 0.94269, f1: 0.97037, f1_macro: 0.98450
# epoch: 12, passed number of graphs: 480, train running loss: 0.00353 (passed time: 1h 24m 45s)
#           acc: 0.99920, fpr: 0.00078, fnr: 0.00108, rec: 0.99892, prc: 0.98263, f1: 0.99070, f1_macro: 0.99514
# epoch: 12, passed number of graphs: 576, train running loss: 0.00340 (passed time: 1h 25m 37s)
#           acc: 0.99842, fpr: 0.00164, fnr: 0.00024, rec: 0.99976, prc: 0.96451, f1: 0.98182, f1_macro: 0.99050
# epoch: 12, passed number of graphs: 672, train running loss: 0.00339 (passed time: 1h 26m 28s)
#           acc: 0.99875, fpr: 0.00127, fnr: 0.00077, rec: 0.99923, prc: 0.97205, f1: 0.98545, f1_macro: 0.99240
# epoch: 12, passed number of graphs: 768, train running loss: 0.00342 (passed time: 1h 27m 20s)
#           acc: 0.99832, fpr: 0.00175, fnr: 0.00008, rec: 0.99992, prc: 0.96148, f1: 0.98032, f1_macro: 0.98972
# Validation --- epoch: 12, loss: 0.00400
#           acc: 0.99911, f1: 0.98040, f1_macro: 0.98997, fpr: 0.00081, prc: 0.96897, rec: 0.99533, fnr: 0.00467
# epoch: 13, passed number of graphs: 96, train running loss: 0.00252 (passed time: 1h 28m 36s)
#           acc: 0.99933, fpr: 0.00068, fnr: 0.00049, rec: 0.99951, prc: 0.98492, f1: 0.99216, f1_macro: 0.99591
# epoch: 13, passed number of graphs: 192, train running loss: 0.00290 (passed time: 1h 29m 28s)
#           acc: 0.99734, fpr: 0.00075, fnr: 0.04613, rec: 0.95387, prc: 0.98231, f1: 0.96788, f1_macro: 0.98325
# epoch: 13, passed number of graphs: 288, train running loss: 0.00274 (passed time: 1h 30m 20s)
#           acc: 0.99898, fpr: 0.00104, fnr: 0.00050, rec: 0.99950, prc: 0.97680, f1: 0.98802, f1_macro: 0.99374
# epoch: 13, passed number of graphs: 384, train running loss: 0.00283 (passed time: 1h 31m 12s)
#           acc: 0.99702, fpr: 0.00310, fnr: 0.00029, rec: 0.99971, prc: 0.93492, f1: 0.96623, f1_macro: 0.98234
# epoch: 13, passed number of graphs: 480, train running loss: 0.00297 (passed time: 1h 32m 3s)
#           acc: 0.99905, fpr: 0.00094, fnr: 0.00100, rec: 0.99900, prc: 0.97918, f1: 0.98899, f1_macro: 0.99425
# epoch: 13, passed number of graphs: 576, train running loss: 0.00295 (passed time: 1h 32m 55s)
#           acc: 0.99520, fpr: 0.00500, fnr: 0.00012, rec: 0.99988, prc: 0.89885, f1: 0.94668, f1_macro: 0.97208
# epoch: 13, passed number of graphs: 672, train running loss: 0.00304 (passed time: 1h 33m 47s)
#           acc: 0.99878, fpr: 0.00124, fnr: 0.00061, rec: 0.99939, prc: 0.97255, f1: 0.98579, f1_macro: 0.99258
# epoch: 13, passed number of graphs: 768, train running loss: 0.00310 (passed time: 1h 34m 39s)
#           acc: 0.99784, fpr: 0.00226, fnr: 0.00000, rec: 1.00000, prc: 0.95079, f1: 0.97477, f1_macro: 0.98682
# Validation --- epoch: 13, loss: 0.00428
#           acc: 0.99904, f1: 0.97901, f1_macro: 0.98926, fpr: 0.00088, prc: 0.96625, rec: 0.99564, fnr: 0.00436
# epoch: 14, passed number of graphs: 96, train running loss: 0.00251 (passed time: 1h 35m 55s)
#           acc: 0.99935, fpr: 0.00066, fnr: 0.00045, rec: 0.99955, prc: 0.98540, f1: 0.99243, f1_macro: 0.99604
# epoch: 14, passed number of graphs: 192, train running loss: 0.00272 (passed time: 1h 36m 47s)
#           acc: 0.99790, fpr: 0.00124, fnr: 0.02180, rec: 0.97820, prc: 0.97190, f1: 0.97504, f1_macro: 0.98697
# epoch: 14, passed number of graphs: 288, train running loss: 0.00255 (passed time: 1h 37m 39s)
#           acc: 0.99887, fpr: 0.00118, fnr: 0.00012, rec: 0.99988, prc: 0.97389, f1: 0.98671, f1_macro: 0.99306
# epoch: 14, passed number of graphs: 384, train running loss: 0.00260 (passed time: 1h 38m 31s)
#           acc: 0.99849, fpr: 0.00156, fnr: 0.00025, rec: 0.99975, prc: 0.96604, f1: 0.98261, f1_macro: 0.99091
# epoch: 14, passed number of graphs: 480, train running loss: 0.00272 (passed time: 1h 39m 23s)
#           acc: 0.99774, fpr: 0.00233, fnr: 0.00062, rec: 0.99938, prc: 0.95014, f1: 0.97414, f1_macro: 0.98648
# epoch: 14, passed number of graphs: 576, train running loss: 0.00265 (passed time: 1h 40m 14s)
#           acc: 0.99912, fpr: 0.00089, fnr: 0.00069, rec: 0.99931, prc: 0.98043, f1: 0.98978, f1_macro: 0.99466
# epoch: 14, passed number of graphs: 672, train running loss: 0.00264 (passed time: 1h 41m 6s)
#           acc: 0.99906, fpr: 0.00093, fnr: 0.00106, rec: 0.99894, prc: 0.97934, f1: 0.98904, f1_macro: 0.99428
# epoch: 14, passed number of graphs: 768, train running loss: 0.00267 (passed time: 1h 41m 58s)
#           acc: 0.99915, fpr: 0.00089, fnr: 0.00000, rec: 1.00000, prc: 0.98007, f1: 0.98993, f1_macro: 0.99474
# Validation --- epoch: 14, loss: 0.00317
#           acc: 0.99932, f1: 0.98464, f1_macro: 0.99214, fpr: 0.00059, prc: 0.97628, rec: 0.99545, fnr: 0.00455
# epoch: 15, passed number of graphs: 96, train running loss: 0.00234 (passed time: 1h 43m 15s)
#           acc: 0.99926, fpr: 0.00075, fnr: 0.00045, rec: 0.99955, prc: 0.98338, f1: 0.99140, f1_macro: 0.99551
# epoch: 15, passed number of graphs: 192, train running loss: 0.00257 (passed time: 1h 44m 6s)
#           acc: 0.99804, fpr: 0.00111, fnr: 0.02131, rec: 0.97869, prc: 0.97467, f1: 0.97668, f1_macro: 0.98783
# epoch: 15, passed number of graphs: 288, train running loss: 0.00243 (passed time: 1h 44m 58s)
#           acc: 0.99891, fpr: 0.00113, fnr: 0.00021, rec: 0.99979, prc: 0.97499, f1: 0.98724, f1_macro: 0.99333
# epoch: 15, passed number of graphs: 384, train running loss: 0.00250 (passed time: 1h 45m 50s)
#           acc: 0.99837, fpr: 0.00168, fnr: 0.00045, rec: 0.99955, prc: 0.96359, f1: 0.98124, f1_macro: 0.99019
# epoch: 15, passed number of graphs: 480, train running loss: 0.00261 (passed time: 1h 46m 42s)
#           acc: 0.99794, fpr: 0.00213, fnr: 0.00054, rec: 0.99946, prc: 0.95423, f1: 0.97632, f1_macro: 0.98762
# epoch: 15, passed number of graphs: 576, train running loss: 0.00256 (passed time: 1h 47m 34s)
#           acc: 0.99910, fpr: 0.00092, fnr: 0.00049, rec: 0.99951, prc: 0.97977, f1: 0.98954, f1_macro: 0.99454
# epoch: 15, passed number of graphs: 672, train running loss: 0.00255 (passed time: 1h 48m 25s)
#           acc: 0.99914, fpr: 0.00084, fnr: 0.00130, rec: 0.99870, prc: 0.98126, f1: 0.98990, f1_macro: 0.99473
# epoch: 15, passed number of graphs: 768, train running loss: 0.00259 (passed time: 1h 49m 17s)
#           acc: 0.99910, fpr: 0.00093, fnr: 0.00012, rec: 0.99988, prc: 0.97903, f1: 0.98934, f1_macro: 0.99444
# Validation --- epoch: 15, loss: 0.00317
#           acc: 0.99933, f1: 0.98485, f1_macro: 0.99225, fpr: 0.00058, prc: 0.97658, rec: 0.99556, fnr: 0.00444
# epoch: 16, passed number of graphs: 96, train running loss: 0.00241 (passed time: 1h 50m 33s)
#           acc: 0.99905, fpr: 0.00098, fnr: 0.00020, rec: 0.99980, prc: 0.97840, f1: 0.98898, f1_macro: 0.99424
# epoch: 16, passed number of graphs: 192, train running loss: 0.00252 (passed time: 1h 51m 25s)
#           acc: 0.99788, fpr: 0.00088, fnr: 0.03039, rec: 0.96961, prc: 0.97976, f1: 0.97466, f1_macro: 0.98678
# epoch: 16, passed number of graphs: 288, train running loss: 0.00238 (passed time: 1h 52m 17s)
#           acc: 0.99835, fpr: 0.00171, fnr: 0.00029, rec: 0.99971, prc: 0.96262, f1: 0.98082, f1_macro: 0.98998
# epoch: 16, passed number of graphs: 384, train running loss: 0.00240 (passed time: 1h 53m 9s)
#           acc: 0.99874, fpr: 0.00131, fnr: 0.00029, rec: 0.99971, prc: 0.97147, f1: 0.98539, f1_macro: 0.99236
# epoch: 16, passed number of graphs: 480, train running loss: 0.00252 (passed time: 1h 54m 0s)
#           acc: 0.99799, fpr: 0.00208, fnr: 0.00042, rec: 0.99958, prc: 0.95529, f1: 0.97694, f1_macro: 0.98794
# epoch: 16, passed number of graphs: 576, train running loss: 0.00247 (passed time: 1h 54m 52s)
#           acc: 0.99913, fpr: 0.00088, fnr: 0.00073, rec: 0.99927, prc: 0.98063, f1: 0.98986, f1_macro: 0.99470
# epoch: 16, passed number of graphs: 672, train running loss: 0.00245 (passed time: 1h 55m 44s)
#           acc: 0.99917, fpr: 0.00081, fnr: 0.00126, rec: 0.99874, prc: 0.98189, f1: 0.99024, f1_macro: 0.99490
# epoch: 16, passed number of graphs: 768, train running loss: 0.00249 (passed time: 1h 56m 36s)
#           acc: 0.99930, fpr: 0.00072, fnr: 0.00012, rec: 0.99988, prc: 0.98373, f1: 0.99174, f1_macro: 0.99569
# Validation --- epoch: 16, loss: 0.00261
#           acc: 0.99948, f1: 0.98802, f1_macro: 0.99388, fpr: 0.00042, prc: 0.98272, rec: 0.99517, fnr: 0.00483
# Better model saved at ./saved_models/GIN_15: 0.9880165003427619.pt.
# epoch: 17, passed number of graphs: 96, train running loss: 0.00226 (passed time: 1h 57m 52s)
#           acc: 0.99917, fpr: 0.00086, fnr: 0.00012, rec: 0.99988, prc: 0.98095, f1: 0.99032, f1_macro: 0.99494
# epoch: 17, passed number of graphs: 192, train running loss: 0.00243 (passed time: 1h 58m 44s)
#           acc: 0.99792, fpr: 0.00088, fnr: 0.02932, rec: 0.97068, prc: 0.97966, f1: 0.97515, f1_macro: 0.98703
# epoch: 17, passed number of graphs: 288, train running loss: 0.00231 (passed time: 1h 59m 36s)
#           acc: 0.99834, fpr: 0.00172, fnr: 0.00012, rec: 0.99988, prc: 0.96228, f1: 0.98072, f1_macro: 0.98993
# epoch: 17, passed number of graphs: 384, train running loss: 0.00235 (passed time: 2h 0m 28s)
#           acc: 0.99873, fpr: 0.00131, fnr: 0.00029, rec: 0.99971, prc: 0.97143, f1: 0.98537, f1_macro: 0.99235
# epoch: 17, passed number of graphs: 480, train running loss: 0.00248 (passed time: 2h 1m 19s)
#           acc: 0.99799, fpr: 0.00209, fnr: 0.00029, rec: 0.99971, prc: 0.95500, f1: 0.97684, f1_macro: 0.98789
# epoch: 17, passed number of graphs: 576, train running loss: 0.00243 (passed time: 2h 2m 11s)
#           acc: 0.99914, fpr: 0.00086, fnr: 0.00086, rec: 0.99914, prc: 0.98098, f1: 0.98998, f1_macro: 0.99476
# epoch: 17, passed number of graphs: 672, train running loss: 0.00242 (passed time: 2h 3m 3s)
#           acc: 0.99919, fpr: 0.00078, fnr: 0.00159, rec: 0.99841, prc: 0.98267, f1: 0.99048, f1_macro: 0.99503
# epoch: 17, passed number of graphs: 768, train running loss: 0.00246 (passed time: 2h 3m 55s)
#           acc: 0.99936, fpr: 0.00066, fnr: 0.00025, rec: 0.99975, prc: 0.98517, f1: 0.99241, f1_macro: 0.99604
# Validation --- epoch: 17, loss: 0.00264
#           acc: 0.99948, f1: 0.98800, f1_macro: 0.99387, fpr: 0.00042, prc: 0.98264, rec: 0.99522, fnr: 0.00478
# epoch: 18, passed number of graphs: 96, train running loss: 0.00228 (passed time: 2h 5m 11s)
#           acc: 0.99914, fpr: 0.00088, fnr: 0.00020, rec: 0.99980, prc: 0.98044, f1: 0.99002, f1_macro: 0.99479
# epoch: 18, passed number of graphs: 192, train running loss: 0.00243 (passed time: 2h 6m 3s)
#           acc: 0.99796, fpr: 0.00093, fnr: 0.02742, rec: 0.97258, prc: 0.97860, f1: 0.97558, f1_macro: 0.98726
# epoch: 18, passed number of graphs: 288, train running loss: 0.00231 (passed time: 2h 6m 55s)
#           acc: 0.99826, fpr: 0.00182, fnr: 0.00012, rec: 0.99988, prc: 0.96033, f1: 0.97970, f1_macro: 0.98940
# epoch: 18, passed number of graphs: 384, train running loss: 0.00234 (passed time: 2h 7m 47s)
#           acc: 0.99876, fpr: 0.00128, fnr: 0.00033, rec: 0.99967, prc: 0.97209, f1: 0.98569, f1_macro: 0.99252
# epoch: 18, passed number of graphs: 480, train running loss: 0.00247 (passed time: 2h 8m 39s)
#           acc: 0.99794, fpr: 0.00214, fnr: 0.00025, rec: 0.99975, prc: 0.95390, f1: 0.97629, f1_macro: 0.98760
# epoch: 18, passed number of graphs: 576, train running loss: 0.00242 (passed time: 2h 9m 31s)
#           acc: 0.99918, fpr: 0.00083, fnr: 0.00069, rec: 0.99931, prc: 0.98165, f1: 0.99040, f1_macro: 0.99498
# epoch: 18, passed number of graphs: 672, train running loss: 0.00241 (passed time: 2h 10m 22s)
#           acc: 0.99924, fpr: 0.00074, fnr: 0.00118, rec: 0.99882, prc: 0.98351, f1: 0.99110, f1_macro: 0.99535
# epoch: 18, passed number of graphs: 768, train running loss: 0.00245 (passed time: 2h 11m 14s)
#           acc: 0.99934, fpr: 0.00068, fnr: 0.00012, rec: 0.99988, prc: 0.98453, f1: 0.99214, f1_macro: 0.99590
# Validation --- epoch: 18, loss: 0.00266
#           acc: 0.99948, f1: 0.98798, f1_macro: 0.99386, fpr: 0.00043, prc: 0.98254, rec: 0.99531, fnr: 0.00469
# epoch: 19, passed number of graphs: 96, train running loss: 0.00224 (passed time: 2h 12m 30s)
#           acc: 0.99909, fpr: 0.00094, fnr: 0.00016, rec: 0.99984, prc: 0.97914, f1: 0.98938, f1_macro: 0.99445
# epoch: 19, passed number of graphs: 192, train running loss: 0.00238 (passed time: 2h 13m 22s)
#           acc: 0.99805, fpr: 0.00091, fnr: 0.02569, rec: 0.97431, prc: 0.97921, f1: 0.97675, f1_macro: 0.98787
# epoch: 19, passed number of graphs: 288, train running loss: 0.00227 (passed time: 2h 14m 14s)
#           acc: 0.99837, fpr: 0.00169, fnr: 0.00012, rec: 0.99988, prc: 0.96286, f1: 0.98102, f1_macro: 0.99008
# epoch: 19, passed number of graphs: 384, train running loss: 0.00230 (passed time: 2h 15m 6s)
#           acc: 0.99863, fpr: 0.00142, fnr: 0.00029, rec: 0.99971, prc: 0.96903, f1: 0.98413, f1_macro: 0.99171
# epoch: 19, passed number of graphs: 480, train running loss: 0.00242 (passed time: 2h 15m 57s)
#           acc: 0.99835, fpr: 0.00170, fnr: 0.00050, rec: 0.99950, prc: 0.96304, f1: 0.98093, f1_macro: 0.99003
# epoch: 19, passed number of graphs: 576, train running loss: 0.00237 (passed time: 2h 16m 49s)
#           acc: 0.99907, fpr: 0.00095, fnr: 0.00061, rec: 0.99939, prc: 0.97910, f1: 0.98914, f1_macro: 0.99433
# epoch: 19, passed number of graphs: 672, train running loss: 0.00237 (passed time: 2h 17m 41s)
#           acc: 0.99912, fpr: 0.00088, fnr: 0.00082, rec: 0.99918, prc: 0.98041, f1: 0.98971, f1_macro: 0.99462
# epoch: 19, passed number of graphs: 768, train running loss: 0.00241 (passed time: 2h 18m 33s)
#           acc: 0.99934, fpr: 0.00068, fnr: 0.00012, rec: 0.99988, prc: 0.98457, f1: 0.99216, f1_macro: 0.99591
# Validation --- epoch: 19, loss: 0.00251
#           acc: 0.99951, f1: 0.98862, f1_macro: 0.99418, fpr: 0.00039, prc: 0.98384, rec: 0.99512, fnr: 0.00488
# Better model saved at ./saved_models/GIN_18: 0.9886165162238303.pt.
# epoch: 20, passed number of graphs: 96, train running loss: 0.00219 (passed time: 2h 19m 49s)
#           acc: 0.99915, fpr: 0.00088, fnr: 0.00024, rec: 0.99976, prc: 0.98059, f1: 0.99008, f1_macro: 0.99482
# epoch: 20, passed number of graphs: 192, train running loss: 0.00237 (passed time: 2h 20m 41s)
#           acc: 0.99796, fpr: 0.00089, fnr: 0.02816, rec: 0.97184, prc: 0.97948, f1: 0.97564, f1_macro: 0.98729
# epoch: 20, passed number of graphs: 288, train running loss: 0.00226 (passed time: 2h 21m 33s)
#           acc: 0.99845, fpr: 0.00161, fnr: 0.00033, rec: 0.99967, prc: 0.96474, f1: 0.98189, f1_macro: 0.99054
# epoch: 20, passed number of graphs: 384, train running loss: 0.00229 (passed time: 2h 22m 25s)
#           acc: 0.99866, fpr: 0.00138, fnr: 0.00037, rec: 0.99963, prc: 0.96996, f1: 0.98457, f1_macro: 0.99194
# epoch: 20, passed number of graphs: 480, train running loss: 0.00242 (passed time: 2h 23m 16s)
#           acc: 0.99838, fpr: 0.00167, fnr: 0.00046, rec: 0.99954, prc: 0.96377, f1: 0.98133, f1_macro: 0.99024
# epoch: 20, passed number of graphs: 576, train running loss: 0.00236 (passed time: 2h 24m 8s)
#           acc: 0.99902, fpr: 0.00100, fnr: 0.00061, rec: 0.99939, prc: 0.97809, f1: 0.98862, f1_macro: 0.99406
# epoch: 20, passed number of graphs: 672, train running loss: 0.00236 (passed time: 2h 25m 0s)
#           acc: 0.99914, fpr: 0.00085, fnr: 0.00110, rec: 0.99890, prc: 0.98111, f1: 0.98992, f1_macro: 0.99474
# epoch: 20, passed number of graphs: 768, train running loss: 0.00240 (passed time: 2h 25m 52s)
#           acc: 0.99940, fpr: 0.00062, fnr: 0.00012, rec: 0.99988, prc: 0.98602, f1: 0.99290, f1_macro: 0.99629
# Validation --- epoch: 20, loss: 0.00251
#           acc: 0.99951, f1: 0.98864, f1_macro: 0.99419, fpr: 0.00039, prc: 0.98387, rec: 0.99512, fnr: 0.00488
# Better model saved at ./saved_models/GIN_19: 0.9886353770682578.pt.
# epoch: 21, passed number of graphs: 96, train running loss: 0.00221 (passed time: 2h 27m 8s)
#           acc: 0.99916, fpr: 0.00087, fnr: 0.00012, rec: 0.99988, prc: 0.98075, f1: 0.99022, f1_macro: 0.99489
# epoch: 21, passed number of graphs: 192, train running loss: 0.00238 (passed time: 2h 28m 0s)
#           acc: 0.99791, fpr: 0.00094, fnr: 0.02837, rec: 0.97163, prc: 0.97834, f1: 0.97497, f1_macro: 0.98694
# epoch: 21, passed number of graphs: 288, train running loss: 0.00226 (passed time: 2h 28m 52s)
#           acc: 0.99843, fpr: 0.00163, fnr: 0.00021, rec: 0.99979, prc: 0.96428, f1: 0.98171, f1_macro: 0.99045
# epoch: 21, passed number of graphs: 384, train running loss: 0.00229 (passed time: 2h 29m 44s)
#           acc: 0.99874, fpr: 0.00131, fnr: 0.00029, rec: 0.99971, prc: 0.97147, f1: 0.98539, f1_macro: 0.99236
# epoch: 21, passed number of graphs: 480, train running loss: 0.00241 (passed time: 2h 30m 35s)
#           acc: 0.99841, fpr: 0.00163, fnr: 0.00054, rec: 0.99946, prc: 0.96451, f1: 0.98167, f1_macro: 0.99042
# epoch: 21, passed number of graphs: 576, train running loss: 0.00236 (passed time: 2h 31m 27s)
#           acc: 0.99910, fpr: 0.00092, fnr: 0.00053, rec: 0.99947, prc: 0.97977, f1: 0.98952, f1_macro: 0.99453
# epoch: 21, passed number of graphs: 672, train running loss: 0.00236 (passed time: 2h 32m 19s)
#           acc: 0.99914, fpr: 0.00086, fnr: 0.00090, rec: 0.99910, prc: 0.98080, f1: 0.98987, f1_macro: 0.99471
# epoch: 21, passed number of graphs: 768, train running loss: 0.00240 (passed time: 2h 33m 11s)
#           acc: 0.99936, fpr: 0.00066, fnr: 0.00017, rec: 0.99983, prc: 0.98505, f1: 0.99239, f1_macro: 0.99603
# Validation --- epoch: 21, loss: 0.00251
#           acc: 0.99951, f1: 0.98866, f1_macro: 0.99420, fpr: 0.00039, prc: 0.98390, rec: 0.99513, fnr: 0.00487
# Better model saved at ./saved_models/GIN_20: 0.988655564772213.pt.
# epoch: 22, passed number of graphs: 96, train running loss: 0.00218 (passed time: 2h 34m 28s)
#           acc: 0.99916, fpr: 0.00087, fnr: 0.00024, rec: 0.99976, prc: 0.98075, f1: 0.99016, f1_macro: 0.99486
# epoch: 22, passed number of graphs: 192, train running loss: 0.00236 (passed time: 2h 35m 19s)
#           acc: 0.99797, fpr: 0.00086, fnr: 0.02878, rec: 0.97122, prc: 0.98016, f1: 0.97567, f1_macro: 0.98730
# epoch: 22, passed number of graphs: 288, train running loss: 0.00225 (passed time: 2h 36m 11s)
#           acc: 0.99843, fpr: 0.00163, fnr: 0.00025, rec: 0.99975, prc: 0.96432, f1: 0.98171, f1_macro: 0.99045
# epoch: 22, passed number of graphs: 384, train running loss: 0.00228 (passed time: 2h 37m 3s)
#           acc: 0.99867, fpr: 0.00137, fnr: 0.00033, rec: 0.99967, prc: 0.97004, f1: 0.98463, f1_macro: 0.99197
# epoch: 22, passed number of graphs: 480, train running loss: 0.00241 (passed time: 2h 37m 55s)
#           acc: 0.99833, fpr: 0.00173, fnr: 0.00029, rec: 0.99971, prc: 0.96250, f1: 0.98075, f1_macro: 0.98994
# epoch: 22, passed number of graphs: 576, train running loss: 0.00235 (passed time: 2h 38m 46s)
#           acc: 0.99907, fpr: 0.00094, fnr: 0.00069, rec: 0.99931, prc: 0.97918, f1: 0.98914, f1_macro: 0.99433
# epoch: 22, passed number of graphs: 672, train running loss: 0.00235 (passed time: 2h 39m 38s)
#           acc: 0.99914, fpr: 0.00086, fnr: 0.00086, rec: 0.99914, prc: 0.98095, f1: 0.98997, f1_macro: 0.99476
# epoch: 22, passed number of graphs: 768, train running loss: 0.00239 (passed time: 2h 40m 30s)
#           acc: 0.99943, fpr: 0.00059, fnr: 0.00021, rec: 0.99979, prc: 0.98666, f1: 0.99318, f1_macro: 0.99644
# Validation --- epoch: 22, loss: 0.00250
#           acc: 0.99952, f1: 0.98868, f1_macro: 0.99422, fpr: 0.00039, prc: 0.98395, rec: 0.99513, fnr: 0.00487
# Better model saved at ./saved_models/GIN_21: 0.988681400521628.pt.
# epoch: 23, passed number of graphs: 96, train running loss: 0.00219 (passed time: 2h 41m 47s)
#           acc: 0.99916, fpr: 0.00086, fnr: 0.00029, rec: 0.99971, prc: 0.98091, f1: 0.99022, f1_macro: 0.99489
# epoch: 23, passed number of graphs: 192, train running loss: 0.00236 (passed time: 2h 42m 38s)
#           acc: 0.99788, fpr: 0.00096, fnr: 0.02853, rec: 0.97147, prc: 0.97789, f1: 0.97466, f1_macro: 0.98678
# epoch: 23, passed number of graphs: 288, train running loss: 0.00225 (passed time: 2h 43m 30s)
#           acc: 0.99848, fpr: 0.00158, fnr: 0.00021, rec: 0.99979, prc: 0.96524, f1: 0.98221, f1_macro: 0.99071
# epoch: 23, passed number of graphs: 384, train running loss: 0.00228 (passed time: 2h 44m 22s)
#           acc: 0.99877, fpr: 0.00127, fnr: 0.00025, rec: 0.99975, prc: 0.97224, f1: 0.98581, f1_macro: 0.99258
# epoch: 23, passed number of graphs: 480, train running loss: 0.00240 (passed time: 2h 45m 14s)
#           acc: 0.99848, fpr: 0.00157, fnr: 0.00037, rec: 0.99963, prc: 0.96583, f1: 0.98244, f1_macro: 0.99082
# epoch: 23, passed number of graphs: 576, train running loss: 0.00235 (passed time: 2h 46m 6s)
#           acc: 0.99913, fpr: 0.00088, fnr: 0.00049, rec: 0.99951, prc: 0.98052, f1: 0.98992, f1_macro: 0.99473
# epoch: 23, passed number of graphs: 672, train running loss: 0.00234 (passed time: 2h 46m 57s)
#           acc: 0.99913, fpr: 0.00087, fnr: 0.00086, rec: 0.99914, prc: 0.98064, f1: 0.98981, f1_macro: 0.99468
# epoch: 23, passed number of graphs: 768, train running loss: 0.00238 (passed time: 2h 47m 49s)
#           acc: 0.99937, fpr: 0.00065, fnr: 0.00021, rec: 0.99979, prc: 0.98533, f1: 0.99251, f1_macro: 0.99609
# Validation --- epoch: 23, loss: 0.00251
#           acc: 0.99952, f1: 0.98867, f1_macro: 0.99421, fpr: 0.00039, prc: 0.98393, rec: 0.99513, fnr: 0.00487
# epoch: 24, passed number of graphs: 96, train running loss: 0.00217 (passed time: 2h 49m 6s)
#           acc: 0.99916, fpr: 0.00087, fnr: 0.00020, rec: 0.99980, prc: 0.98079, f1: 0.99020, f1_macro: 0.99488
# epoch: 24, passed number of graphs: 192, train running loss: 0.00234 (passed time: 2h 49m 57s)
#           acc: 0.99796, fpr: 0.00085, fnr: 0.02936, rec: 0.97064, prc: 0.98044, f1: 0.97551, f1_macro: 0.98722
# epoch: 24, passed number of graphs: 288, train running loss: 0.00224 (passed time: 2h 50m 49s)
#           acc: 0.99845, fpr: 0.00161, fnr: 0.00025, rec: 0.99975, prc: 0.96462, f1: 0.98187, f1_macro: 0.99053
# epoch: 24, passed number of graphs: 384, train running loss: 0.00227 (passed time: 2h 51m 41s)
#           acc: 0.99869, fpr: 0.00136, fnr: 0.00029, rec: 0.99971, prc: 0.97042, f1: 0.98485, f1_macro: 0.99208

# %%
# !zip -r /content/RevGIN_053_12_Adam_P2P_6k_botnode_24layer.zip /content/saved_models

# %%
from google.colab import files
files.download("/content/RevGIN_053_12_Adam_P2P_6k_botnode_24layer.zip")

# %%
# from google.colab import runtime
# runtime.unassign()
