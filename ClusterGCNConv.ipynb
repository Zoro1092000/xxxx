# %% [markdown]
# <a href="https://colab.research.google.com/github/Zoro1092000/xxxx/blob/main/ClusterGCNConv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # I. Pip & Import.

# %%
import os
import os.path as osp
import torch
import sys

os.environ['TORCH'] = torch.__version__

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install torch-geometric
# !pip install torch-cluster -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install deepdish==0.3.5
# !pip install torch-optimizer

import torch.nn as nn
from torch.nn import Parameter
from torch_geometric.utils import scatter
from torch_geometric.nn.inits import glorot, zeros
from torch_scatter import scatter_add
from torch.utils.data import DataLoader, Dataset
import torch_optimizer as optimization


from itertools import chain
import pickle
import h5py
import deepdish as dd
import numpy as np
from tqdm import tqdm
import inspect
import time
import math
import random
# Out:
#      |████████████████████████████████| 7.9 MB 1.3 MB/s
#      |████████████████████████████████| 3.5 MB 4.0 MB/s
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch-geometric
#   Downloading torch_geometric-2.1.0.post1.tar.gz (467 kB)
#      |████████████████████████████████| 467 kB 4.1 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (4.64.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.7.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.23.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (3.0.9)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.0.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->torch-geometric) (2.0.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (2022.9.24)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric) (1.2.0)
# Building wheels for collected packages: torch-geometric
#   Building wheel for torch-geometric (setup.py) ... done
#   Created wheel for torch-geometric: filename=torch_geometric-2.1.0.post1-py3-none-any.whl size=689859 sha256=6d8fe3af6dc3a77663b8a2816cc3ba0641049023a76f4ab7bb0c66326124ca83
#   Stored in directory: /root/.cache/pip/wheels/d1/cb/43/f7f2e472de4d7cff31bceddadc36d634e1e545fbc17961c282
# Successfully built torch-geometric
# Installing collected packages: torch-geometric
# Successfully installed torch-geometric-2.1.0.post1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://data.pyg.org/whl/torch-1.12.1+cu113.html
# Collecting torch-cluster
#   Downloading https://data.pyg.org/whl/torch-1.12.0%2Bcu113/torch_cluster-1.6.0-cp37-cp37m-linux_x86_64.whl (2.4 MB)
#      |████████████████████████████████| 2.4 MB 3.9 MB/s
# Installing collected packages: torch-cluster
# Successfully installed torch-cluster-1.6.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting deepdish==0.3.5
#   Downloading deepdish-0.3.5-py2.py3-none-any.whl (37 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.7.3)
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (3.7.0)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (2.8.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tables->deepdish==0.3.5) (3.0.9)
# Installing collected packages: deepdish
# Successfully installed deepdish-0.3.5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch-optimizer
#   Downloading torch_optimizer-0.3.0-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 472 kB/s
# Collecting pytorch-ranger>=0.1.1
#   Downloading pytorch_ranger-0.1.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: torch>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from torch-optimizer) (1.12.1+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.5.0->torch-optimizer) (4.1.1)
# Installing collected packages: pytorch-ranger, torch-optimizer
# Successfully installed pytorch-ranger-0.1.1 torch-optimizer-0.3.0

# %%
def time_since(start):
    now = time.time()
    s = now - start
    m = math.floor(s / 60)
    s -= m * 60
    h = math.floor(m / 60)
    m -= h * 60
    if h == 0:
        if m == 0:
            return '%ds' % s
        else:
            return '%dm %ds' % (m, s)
    else:
        return '%dh %dm %ds' % (h, m, s)

# %% [markdown]
# # II. Data

# %%
# Data utils
def h5group_to_dict(h5group):
    group_dict = {k: v[()] for k, v in chain(h5group.items(), h5group.attrs.items())}
    return group_dict

def sub_dict(full_dict, *keys, to_tensor):
    return {k: torch.tensor(full_dict[k]) if to_tensor else full_dict[k] for k in keys if k in full_dict}

def build_graph_from_dict_pyg(graph_dict, to_tensor=True):
    from torch_geometric.data import Data

    g = Data(**sub_dict(graph_dict, 'edge_index', 'x', 'y', 'edge_attr', 'edge_y', to_tensor=to_tensor))
    return g

# Data loader
class GraphDataLoader(DataLoader):
    def __init__(self, dataset, batch_size=128, shuffle=False, num_workers=0):

        def collate_graph(graph_obj_list):
            from torch_geometric.data import Batch
            batch = Batch.from_data_list(graph_obj_list)
            return batch

        super().__init__(
            dataset,
            batch_size=batch_size,
            shuffle=shuffle,
            collate_fn=collate_graph,
            num_workers=num_workers)

# BotnetDataset
class BotnetDataset(Dataset):

    def __init__(self, name='chord', root='data/botnet', split='train', graph_format='pyg', split_idx=None, add_nfeat_ones=True,
                 in_memory=True):
        super().__init__()
        assert name in ['chord', 'debru', 'kadem', 'leet', 'c2', 'p2p']
        assert split in ['train', 'val', 'test']

        if isinstance(root, str):
            root = osp.expanduser(osp.normpath(root))

        self.name = name
        self.root = root
        self.split = split
        self.split_idx = split_idx
        self.add_nfeat_ones = add_nfeat_ones

        self._graph_format = graph_format
        if split == 'train':
            self.path = self.processed_paths[0]
            self.num_graphs = 768
        elif split == 'val':
            self.path = self.processed_paths[1]
            self.num_graphs = 96
        elif split == 'test':
            self.path = self.processed_paths[2]
            self.num_graphs = 96

        if in_memory:
            self.data = dd.io.load(self.path)  # dictionary
            self.data_type = 'dict'
        else:
            # self.data = h5py.File(self.path, 'r')
            self.data = None    # defer opening file in each process to make multiprocessing work
            self.data_type = 'file'
            
    @property
    def processed_dir(self):
        return osp.join(self.root, 'processed')

    @property
    def processed_file_names(self):
        return [self.name + '_' + s + '.hdf5' for s in ('train', 'val', 'test')]

    @property
    def processed_paths(self):
        return [osp.join(self.processed_dir, f) for f in self.processed_file_names]

    def __len__(self):
        return self.num_graphs

    def __getitem__(self, index):
        if self.data_type == 'dict':
            graph_dict = self.data[str(index)]
        elif self.data_type == 'file':
            if self.data is None:
                # only open once in each process
                self.data = h5py.File(self.path, 'r')
            graph_dict = h5group_to_dict(self.data[str(index)])
        else:
            raise ValueError

        # graph_format == 'pyg':
        return build_graph_from_dict_pyg(graph_dict)


    def __iter__(self):
        for i in range(self.num_graphs):
            yield self[i]

    def __repr__(self):
        return f'{self.__class__.__name__}(topology: {self.name} | split: {self.split} | ' \
               f'#graphs: {len(self)} | graph format: {self.graph_format})'

# %% [markdown]
# # III. Measure Performancce

# %% [markdown]
# ## 3.1. Metrics

# %%
def f1(target, pred, label):
    # F1 = 2 * (precision * recall) / (precision + recall)
    tp = np.sum((target==label) & (pred==label))
    fp = np.sum((target!=label) & (pred==label))
    fn = np.sum((pred!=label) & (target==label))
    
    if tp+fp==0 or tp+fn==0:
      return np.nan

    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    
    if precision+recall==0:
      return np.nan
      
    f1 = 2 * (precision * recall) / (precision + recall)
    return f1

def f1_macro(pred, target):
    return np.mean([f1(target, pred, label) for label in range(0, 2)])


def accuracy(pred, target):
    return (pred == target).sum().item() / len(target)


def true_positive(pred, target):
    return (target[pred == 1] == 1).sum().item()


def false_positive(pred, target):
    return (target[pred == 1] == 0).sum().item()


def true_negative(pred, target):
    return (target[pred == 0] == 0).sum().item()


def false_negative(pred, target):
    return (target[pred == 0] == 1).sum().item()


def recall(pred, target):
    try:
        return true_positive(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1


def precision(pred, target):
    try:
        prec = true_positive(pred, target) / (pred == 1).sum().item()
        return prec
    except:  # divide by zero
        return -1


def f1_score(pred, target):
    prec = precision(pred, target)
    rec = recall(pred, target)
    try:
        return 2 * (prec * rec) / (prec + rec)
    except:
        return 0


def false_positive_rate(pred, target):
    try:
        return false_positive(pred, target) / (target == 0).sum().item()
    except:  # divide by zero
        return -1


def false_negative_rate(pred, target):
    try:
        return false_negative(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1

# %% [markdown]
# ## 3.2. Evaluation

# %%
def eval_metrics(target, pred_prob, threshold=0.5):
    if isinstance(target, torch.Tensor):
        target = target.cpu().numpy()
    if isinstance(pred_prob, torch.Tensor):
        pred_prob = pred_prob.cpu().numpy()

    pred = (pred_prob >= threshold).astype(int)

    acc = accuracy(pred, target)
    fpr = false_positive_rate(pred, target)
    fnr = false_negative_rate(pred, target)
    rec = recall(pred, target)
    prc = precision(pred, target)
    f1 = f1_score(pred, target)
    f1macro = f1_macro(pred, target)
    result_dict = {'acc': acc, 'fpr': fpr, 'fnr': fnr, 'rec': rec, 'prc': prc, 'f1': f1, 'f1_macro': f1macro}

    return result_dict


def dict_value_add(dict1, dict2):
    result = {key: dict1.get(key, 0) + dict2.get(key, 0)
              for key in set(dict1) | set(dict2)}
    return result


def dict_value_div(dict, n):
    result = {key: value / n for key, value in dict.items()}
    return result


def eval_predictor(dataset, predictor):
    result_dict_avg = {}
    loss_avg = 0

    for data in dataset:
        # prediction
        try:
            pred_prob, loss = predictor(data)
            loss_avg += loss
        except ValueError:  # if "too many values to unpack"
            pred_prob = predictor(data)

        # get the ground truth target
        # graph_format == 'pyg':
        target = data.y

        # compute the evaluation metrics
        result_dict = eval_metrics(target, pred_prob)

        result_dict_avg = dict_value_add(result_dict_avg, result_dict)

    # average the metrics across all graphs in the dataset as final results
    result_dict_avg = dict_value_div(result_dict_avg, len(dataset))
    loss_avg = loss_avg / len(dataset)

    return result_dict_avg, loss_avg


# =================================================================================================================
# some examples of the 'predictor' model wrapper to be fed into the above evaluation function (for PyG Data format)
# =================================================================================================================
class PygRandomPredictor:
    def __init__(self):
        # torch.manual_seed(0)
        pass

    def __call__(self, data):
        pred_prob = torch.rand(len(data.y))
        return pred_prob


class PygModelPredictor:
    def __init__(self, model, loss_fcn=torch.nn.CrossEntropyLoss()):
        self.model = model
        self.loss_fcn = loss_fcn
        self.device = next(model.parameters()).device

    def __call__(self, data):
        self.model.eval()
        data = data.to(self.device)
        with torch.no_grad():
            # custom the below line to adjust to your model's input format for forward pass
            out = self.model(data.x, data.edge_index)
            loss = self.loss_fcn(out, data.y.long())
            pred_prob = torch.softmax(out, dim=1)[:, 1]
        return pred_prob, loss.float()

# %% [markdown]
# # IV. Model

# %% [markdown]
# ## 5.1. Activation

# %%
def activation(act, negative_slope=0.2):
    activations = nn.ModuleDict([
        ['lrelu', nn.LeakyReLU(negative_slope)],
        ['relu', nn.ReLU()],
        ['elu', nn.ELU()],
        ['none', nn.Identity()],
    ])
    return activations[act]

# %% [markdown]
# ## 5.2. GIN model

# %%
from torch.nn.modules.activation import LeakyReLU
import torch.nn as nn

class GINModel(nn.Module):
    def __init__(self, dim_input_feature, dim_hidden_feature, num_layers, num_classes, non_linear='relu', dropout=0.2):
        super().__init__()

        self.dim_input_feature = dim_input_feature
        self.dim_hidden_feature = dim_hidden_feature

        self.num_layers = num_layers
        self.num_classes = num_classes
        
        from torch.nn import Linear, Sequential, BatchNorm1d, ReLU, Dropout
        from torch_geometric.nn import GATv2Conv, GINConv, TransformerConv, ClusterGCNConv
        
        self.gin_net = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.gin_net.append(ClusterGCNConv(self.dim_input_feature, self.dim_hidden_feature))
          else:
            self.gin_net.append(ClusterGCNConv(self.dim_hidden_feature, self.dim_hidden_feature))


        self.dropout = nn.Dropout(dropout)

        self.residuals = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.residuals.append(nn.Linear(self.dim_input_feature, self.dim_hidden_feature, bias=True))
          else:
            self.residuals.append(nn.Identity())

        self.num_residuals = len(self.residuals)

        self.non_linear = activation(non_linear)

        # self.final_type == 'proj':
        self.final = nn.Linear(self.dim_hidden_feature, num_classes)

    def reset_parameters(self):
        for net in self.gin_net:
            net.reset_parameters()
        # self.residual_hop = 1
        for net in self.residuals:
            net.reset_parameters()
        # self.final_type != 'none':
        self.final.reset_parameters()

    def forward(self, x, edge_index):
        xr = None
        add_xr_at = -1

        for n, net in enumerate(self.gin_net):
            # pass to a GIN layer with non-linear activation
            xo = net(x, edge_index)
            xo = self.dropout(xo)
            # deal with residual connections
            # self.residual_hop = 1
            if n < self.num_residuals:
                xr = self.residuals[n](x)
                xo = self.non_linear(xo + xr)

            x = xo
        # size of x: (B * N, dim_hidden_feature) -> (B * N, num_classes)
        x = self.final(x)

        return x

# %% [markdown]
# # V. Load data

# %%
data_dir = '/content/drive/Shareddrives/botnetdata/p2p_6k_feat_norm'
data_name = 'p2p' # 'chord', 'debru', 'kadem', 'leet', 'c2', 'p2p'
shuffle = False

# ========== load the dataset
print('loading dataset...')

train_ds = BotnetDataset(name=data_name, root=data_dir, split='train',
                         in_memory=True, graph_format='pyg')
val_ds = BotnetDataset(name=data_name, root=data_dir, split='val',
                       in_memory=False, graph_format='pyg')
test_ds = BotnetDataset(name=data_name, root=data_dir, split='test',
                        in_memory=False, graph_format='pyg')
# Out:
# loading dataset...

# %%
batch_size = 1
train_loader = GraphDataLoader(train_ds, batch_size=batch_size, shuffle=bool(shuffle), num_workers=0)

# %% [markdown]
# # VI. Train

# %%
# ============== some default parameters =============
devid = 0
seed = 0
logmode = 'w'
log_interval = 96

dim_input_feature = 1
dim_hidden_feature = 32
act = 'relu' # 'none', 'lrelu', 'relu', 'elu'

num_layers = 12
num_classes = 2 

dropout = 0.0
bias = True

lr = 0.005 # learning rate
weight_decay = 5e-4
epochs = 50
save_dir = './saved_models'
save_name = "GIN_model.pt"
# ====================================================

def train(model, train_loader, val_dataset, test_dataset, optimizer, scheduler=None):
    device = next(model.parameters()).device
    predictor = PygModelPredictor(model)

    best_epoch = 0
    max_f1_score = 0
    start = time.time()
    for ep in range(epochs):
        loss_avg_train = 0
        num_train_graph = 0
        model.train()
        for n, batch in enumerate(train_loader):
            batch.to(device)

            optimizer.zero_grad()

            x = model(batch.x, batch.edge_index)
            loss = criterion(x, batch.y.long())

            loss_avg_train += float(loss)
            num_train_graph += batch.num_graphs

            loss.backward()
            optimizer.step()

            if num_train_graph % log_interval == 0 or n == len(train_loader) - 1:
                with torch.no_grad():
                    # pred = x.argmax(dim=1)
                    pred_prob = torch.softmax(x, dim=1)[:, 1]
                    y = batch.y.long()
                    result_dict = eval_metrics(y, pred_prob)
                print(f'epoch: {ep + 1}, passed number of graphs: {num_train_graph}, '
                        f'train running loss: {loss_avg_train / num_train_graph:.5f} (passed time: {time_since(start)})')
                print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict.items()]))

        result_dict_avg, loss_avg = eval_predictor(val_dataset, predictor)
        print(f'Validation --- epoch: {ep + 1}, loss: {loss_avg:.5f}')
        print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))

        if scheduler is not None:
            scheduler.step(loss_avg)

        if result_dict_avg['f1'] > max_f1_score:
            save_name = f"GIN_{ep}: {result_dict_avg['f1']}.pt"
            torch.save(model, os.path.join(save_dir, save_name))
            print(f'Better model saved at {os.path.join(save_dir, save_name)}.')
            best_epoch = ep
            max_f1_score = result_dict_avg['f1']

    best_model = torch.load(os.path.join(save_dir, save_name))
    print('*' * 12 + f' best model obtained after epoch {best_epoch + 1}, '
                       f'saved at {os.path.join(save_dir, save_name)} ' + '*' * 12)
    
    predictor = PygModelPredictor(best_model)

    result_dict_avg, loss_avg = eval_predictor(test_dataset, predictor)
    print(f'Testing --- loss: {loss_avg:.5f}')
    print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))


if __name__ == '__main__':
    os.makedirs(save_dir, exist_ok=True)

    # ========== random seeds and device
    random.seed(seed)
    torch.manual_seed(seed)

    device = torch.device(f'cuda:{devid}') if devid > -1 else torch.device('cpu')

    # ========== logging setup
    log_name = os.path.splitext(save_name)[0]
    # logger = logging_config(__name__, folder=save_dir, name=log_name, filemode=logmode)
    # logger = logging_config(os.path.basename(__file__), folder=save_dir, name=log_name, filemode=logmode)

    print('python ' + ' '.join(sys.argv))
    print('-' * 30)
    #logger.info(args)
    print('-' * 30)
    print(time.ctime())
    print('-' * 30)

    # ========== define the model, optimizer, and loss

    model = GINModel(dim_input_feature,
                     dim_hidden_feature,
                     num_layers,
                     num_classes,
                     non_linear=act,
                     dropout=dropout)

    print('model ' + '-' * 10)
    print(repr(model))
    model.to(device)

    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.25, patience=1)

    # ========== train the model
    print(f"Batch size: {batch_size}")
    train(model, train_loader, val_ds, test_ds, optimizer, scheduler)
# Out:
# python /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-07e57196-3ae6-402d-a0ec-e3ba56cba5e1.json
# ------------------------------
# ------------------------------
# Thu Nov  3 16:52:02 2022
# ------------------------------
# model ----------
# GINModel(
#   (gin_net): ModuleList(
#     (0): ClusterGCNConv(1, 32, diag_lambda=0.0)
#     (1): ClusterGCNConv(32, 32, diag_lambda=0.0)
#     (2): ClusterGCNConv(32, 32, diag_lambda=0.0)
#     (3): ClusterGCNConv(32, 32, diag_lambda=0.0)
#     (4): ClusterGCNConv(32, 32, diag_lambda=0.0)
#     (5): ClusterGCNConv(32, 32, diag_lambda=0.0)
#     (6): ClusterGCNConv(32, 32, diag_lambda=0.0)
#     (7): ClusterGCNConv(32, 32, diag_lambda=0.0)
#     (8): ClusterGCNConv(32, 32, diag_lambda=0.0)
#     (9): ClusterGCNConv(32, 32, diag_lambda=0.0)
#     (10): ClusterGCNConv(32, 32, diag_lambda=0.0)
#     (11): ClusterGCNConv(32, 32, diag_lambda=0.0)
#   )
#   (dropout): Dropout(p=0.0, inplace=False)
#   (residuals): ModuleList(
#     (0): Linear(in_features=1, out_features=32, bias=True)
#     (1): Identity()
#     (2): Identity()
#     (3): Identity()
#     (4): Identity()
#     (5): Identity()
#     (6): Identity()
#     (7): Identity()
#     (8): Identity()
#     (9): Identity()
#     (10): Identity()
#     (11): Identity()
#   )
#   (non_linear): ReLU()
#   (final): Linear(in_features=32, out_features=2, bias=True)
# )
# Batch size: 1
# epoch: 1, passed number of graphs: 96, train running loss: 0.45971 (passed time: 19s)
#           acc: 0.95801, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 192, train running loss: 0.30860 (passed time: 35s)
#           acc: 0.95996, fpr: 0.00055, fnr: 0.94983, rec: 0.05017, prc: 0.79787, f1: 0.09440, f1_macro: 0.53696
# epoch: 1, passed number of graphs: 288, train running loss: 0.24077 (passed time: 51s)
#           acc: 0.96881, fpr: 0.00361, fnr: 0.67913, rec: 0.32087, prc: 0.79071, f1: 0.45650, f1_macro: 0.72022
# epoch: 1, passed number of graphs: 384, train running loss: 0.20398 (passed time: 1m 7s)
#           acc: 0.97014, fpr: 0.00152, fnr: 0.65255, rec: 0.34745, prc: 0.91211, f1: 0.50321, f1_macro: 0.74391
# epoch: 1, passed number of graphs: 480, train running loss: 0.17333 (passed time: 1m 24s)
#           acc: 0.99096, fpr: 0.00005, fnr: 0.21207, rec: 0.78793, prc: 0.99853, f1: 0.88082, f1_macro: 0.93806
# epoch: 1, passed number of graphs: 576, train running loss: 0.14888 (passed time: 1m 40s)
#           acc: 0.99750, fpr: 0.00057, fnr: 0.04634, rec: 0.95366, prc: 0.98674, f1: 0.96992, f1_macro: 0.98431
# epoch: 1, passed number of graphs: 672, train running loss: 0.12948 (passed time: 1m 57s)
#           acc: 0.99764, fpr: 0.00058, fnr: 0.04343, rec: 0.95657, prc: 0.98636, f1: 0.97124, f1_macro: 0.98500
# epoch: 1, passed number of graphs: 768, train running loss: 0.11460 (passed time: 2m 13s)
#           acc: 0.99821, fpr: 0.00000, fnr: 0.04250, rec: 0.95750, prc: 1.00000, f1: 0.97829, f1_macro: 0.98868
# Validation --- epoch: 1, loss: 0.00666
#           rec: 0.93953, fpr: 0.00001, f1: 0.96790, prc: 0.99951, acc: 0.99869, f1_macro: 0.98362, fnr: 0.06047
# Better model saved at ./saved_models/GIN_0: 0.9679025470968735.pt.
# epoch: 2, passed number of graphs: 96, train running loss: 0.01708 (passed time: 3m 6s)
#           acc: 0.96353, fpr: 0.03555, fnr: 0.05759, rec: 0.94241, prc: 0.53742, f1: 0.68450, f1_macro: 0.83257
# epoch: 2, passed number of graphs: 192, train running loss: 0.02295 (passed time: 3m 23s)
#           acc: 0.99816, fpr: 0.00001, fnr: 0.04398, rec: 0.95602, prc: 0.99983, f1: 0.97743, f1_macro: 0.98824
# epoch: 2, passed number of graphs: 288, train running loss: 0.01710 (passed time: 3m 39s)
#           acc: 0.99859, fpr: 0.00004, fnr: 0.03371, rec: 0.96629, prc: 0.99914, f1: 0.98244, f1_macro: 0.99085
# epoch: 2, passed number of graphs: 384, train running loss: 0.01441 (passed time: 3m 56s)
#           acc: 0.99823, fpr: 0.00000, fnr: 0.04070, rec: 0.95930, prc: 1.00000, f1: 0.97923, f1_macro: 0.98915
# epoch: 2, passed number of graphs: 480, train running loss: 0.01260 (passed time: 4m 13s)
#           acc: 0.99867, fpr: 0.00000, fnr: 0.03124, rec: 0.96876, prc: 1.00000, f1: 0.98413, f1_macro: 0.99172
# epoch: 2, passed number of graphs: 576, train running loss: 0.01120 (passed time: 4m 30s)
#           acc: 0.99896, fpr: 0.00001, fnr: 0.02432, rec: 0.97568, prc: 0.99966, f1: 0.98753, f1_macro: 0.99349
# epoch: 2, passed number of graphs: 672, train running loss: 0.01034 (passed time: 4m 46s)
#           acc: 0.99848, fpr: 0.00043, fnr: 0.02645, rec: 0.97355, prc: 0.98987, f1: 0.98164, f1_macro: 0.99043
# epoch: 2, passed number of graphs: 768, train running loss: 0.00983 (passed time: 5m 3s)
#           acc: 0.99881, fpr: 0.00001, fnr: 0.02805, rec: 0.97195, prc: 0.99983, f1: 0.98569, f1_macro: 0.99253
# Validation --- epoch: 2, loss: 0.00381
#           rec: 0.96824, fpr: 0.00007, f1: 0.98170, prc: 0.99667, acc: 0.99925, f1_macro: 0.99066, fnr: 0.03176
# Better model saved at ./saved_models/GIN_1: 0.9817046448678545.pt.
# epoch: 3, passed number of graphs: 96, train running loss: 0.00584 (passed time: 5m 41s)
#           acc: 0.99879, fpr: 0.00001, fnr: 0.02855, rec: 0.97145, prc: 0.99967, f1: 0.98535, f1_macro: 0.99236
# epoch: 3, passed number of graphs: 192, train running loss: 0.00549 (passed time: 5m 57s)
#           acc: 0.99863, fpr: 0.00001, fnr: 0.03261, rec: 0.96739, prc: 0.99965, f1: 0.98326, f1_macro: 0.99127
# epoch: 3, passed number of graphs: 288, train running loss: 0.00501 (passed time: 6m 14s)
#           acc: 0.99909, fpr: 0.00001, fnr: 0.02203, rec: 0.97797, prc: 0.99966, f1: 0.98870, f1_macro: 0.99411
# epoch: 3, passed number of graphs: 384, train running loss: 0.02468 (passed time: 6m 31s)
#           acc: 0.95657, fpr: 0.00000, fnr: 0.99770, rec: 0.00230, prc: 1.00000, f1: 0.00458, f1_macro: 0.49119
# epoch: 3, passed number of graphs: 480, train running loss: 0.02689 (passed time: 6m 48s)
#           acc: 0.96280, fpr: 0.00000, fnr: 0.87718, rec: 0.12282, prc: 1.00000, f1: 0.21877, f1_macro: 0.59986
# epoch: 3, passed number of graphs: 576, train running loss: 0.02534 (passed time: 7m 5s)
#           acc: 0.99909, fpr: 0.00004, fnr: 0.02054, rec: 0.97946, prc: 0.99899, f1: 0.98913, f1_macro: 0.99433
# epoch: 3, passed number of graphs: 672, train running loss: 0.02290 (passed time: 7m 22s)
#           acc: 0.99820, fpr: 0.00041, fnr: 0.03380, rec: 0.96620, prc: 0.99046, f1: 0.97818, f1_macro: 0.98862
# epoch: 3, passed number of graphs: 768, train running loss: 0.02119 (passed time: 7m 39s)
#           acc: 0.99830, fpr: 0.00001, fnr: 0.04017, rec: 0.95983, prc: 0.99983, f1: 0.97942, f1_macro: 0.98927
# Validation --- epoch: 3, loss: 0.00459
#           rec: 0.95743, fpr: 0.00007, f1: 0.97604, prc: 0.99698, acc: 0.99902, f1_macro: 0.98777, fnr: 0.04257
# epoch: 4, passed number of graphs: 96, train running loss: 0.00551 (passed time: 8m 16s)
#           acc: 0.99778, fpr: 0.00003, fnr: 0.05224, rec: 0.94776, prc: 0.99932, f1: 0.97286, f1_macro: 0.98585
# epoch: 4, passed number of graphs: 192, train running loss: 0.00550 (passed time: 8m 33s)
#           acc: 0.99865, fpr: 0.00000, fnr: 0.03244, rec: 0.96756, prc: 1.00000, f1: 0.98351, f1_macro: 0.99140
# epoch: 4, passed number of graphs: 288, train running loss: 0.00493 (passed time: 8m 50s)
#           acc: 0.99914, fpr: 0.00001, fnr: 0.02102, rec: 0.97898, prc: 0.99983, f1: 0.98929, f1_macro: 0.99442
# epoch: 4, passed number of graphs: 384, train running loss: 0.00520 (passed time: 9m 6s)
#           acc: 0.99897, fpr: 0.00001, fnr: 0.02331, rec: 0.97669, prc: 0.99966, f1: 0.98805, f1_macro: 0.99375
# epoch: 4, passed number of graphs: 480, train running loss: 0.00522 (passed time: 9m 23s)
#           acc: 0.99883, fpr: 0.00001, fnr: 0.02726, rec: 0.97274, prc: 0.99966, f1: 0.98602, f1_macro: 0.99270
# epoch: 4, passed number of graphs: 576, train running loss: 0.00498 (passed time: 9m 40s)
#           acc: 0.99913, fpr: 0.00002, fnr: 0.02005, rec: 0.97995, prc: 0.99950, f1: 0.98963, f1_macro: 0.99459
# epoch: 4, passed number of graphs: 672, train running loss: 0.00503 (passed time: 9m 57s)
#           acc: 0.99768, fpr: 0.00053, fnr: 0.04343, rec: 0.95657, prc: 0.98753, f1: 0.97180, f1_macro: 0.98530
# epoch: 4, passed number of graphs: 768, train running loss: 0.00520 (passed time: 10m 14s)
#           acc: 0.99839, fpr: 0.00000, fnr: 0.03818, rec: 0.96182, prc: 1.00000, f1: 0.98054, f1_macro: 0.98985
# Validation --- epoch: 4, loss: 0.00425
#           rec: 0.96233, fpr: 0.00001, f1: 0.97982, prc: 0.99948, acc: 0.99918, f1_macro: 0.98970, fnr: 0.03767
# epoch: 5, passed number of graphs: 96, train running loss: 0.00434 (passed time: 10m 51s)
#           acc: 0.99908, fpr: 0.00006, fnr: 0.02060, rec: 0.97940, prc: 0.99868, f1: 0.98894, f1_macro: 0.99423
# epoch: 5, passed number of graphs: 192, train running loss: 0.00408 (passed time: 11m 8s)
#           acc: 0.99905, fpr: 0.00003, fnr: 0.02207, rec: 0.97793, prc: 0.99932, f1: 0.98851, f1_macro: 0.99401
# epoch: 5, passed number of graphs: 288, train running loss: 0.00383 (passed time: 11m 25s)
#           acc: 0.99910, fpr: 0.00002, fnr: 0.02153, rec: 0.97847, prc: 0.99949, f1: 0.98887, f1_macro: 0.99420
# epoch: 5, passed number of graphs: 384, train running loss: 0.00370 (passed time: 11m 42s)
#           acc: 0.99911, fpr: 0.00003, fnr: 0.01986, rec: 0.98014, prc: 0.99933, f1: 0.98964, f1_macro: 0.99459
# epoch: 5, passed number of graphs: 480, train running loss: 0.00372 (passed time: 11m 59s)
#           acc: 0.99902, fpr: 0.00001, fnr: 0.02294, rec: 0.97706, prc: 0.99983, f1: 0.98832, f1_macro: 0.99390
# epoch: 5, passed number of graphs: 576, train running loss: 0.00365 (passed time: 12m 15s)
#           acc: 0.99915, fpr: 0.00001, fnr: 0.01988, rec: 0.98012, prc: 0.99983, f1: 0.98988, f1_macro: 0.99472
# epoch: 5, passed number of graphs: 672, train running loss: 0.00363 (passed time: 12m 32s)
#           acc: 0.99886, fpr: 0.00047, fnr: 0.01649, rec: 0.98351, prc: 0.98916, f1: 0.98633, f1_macro: 0.99287
# epoch: 5, passed number of graphs: 768, train running loss: 0.00374 (passed time: 12m 49s)
#           acc: 0.99905, fpr: 0.00001, fnr: 0.02224, rec: 0.97776, prc: 0.99983, f1: 0.98867, f1_macro: 0.99409
# Validation --- epoch: 5, loss: 0.00340
#           rec: 0.97570, fpr: 0.00003, f1: 0.98641, prc: 0.99853, acc: 0.99945, f1_macro: 0.99306, fnr: 0.02430
# Better model saved at ./saved_models/GIN_4: 0.9864103404508645.pt.
# epoch: 6, passed number of graphs: 96, train running loss: 0.00399 (passed time: 13m 30s)
#           acc: 0.99862, fpr: 0.00004, fnr: 0.03180, rec: 0.96820, prc: 0.99900, f1: 0.98336, f1_macro: 0.99132
# epoch: 6, passed number of graphs: 192, train running loss: 0.00394 (passed time: 13m 46s)
#           acc: 0.99901, fpr: 0.00002, fnr: 0.02324, rec: 0.97676, prc: 0.99949, f1: 0.98799, f1_macro: 0.99374
# epoch: 6, passed number of graphs: 288, train running loss: 0.00368 (passed time: 14m 3s)
#           acc: 0.99921, fpr: 0.00001, fnr: 0.01902, rec: 0.98098, prc: 0.99966, f1: 0.99023, f1_macro: 0.99491
# epoch: 6, passed number of graphs: 384, train running loss: 0.00361 (passed time: 14m 20s)
#           acc: 0.99916, fpr: 0.00002, fnr: 0.01887, rec: 0.98113, prc: 0.99950, f1: 0.99023, f1_macro: 0.99489
# epoch: 6, passed number of graphs: 480, train running loss: 0.00365 (passed time: 14m 37s)
#           acc: 0.99908, fpr: 0.00001, fnr: 0.02144, rec: 0.97856, prc: 0.99983, f1: 0.98908, f1_macro: 0.99430
# epoch: 6, passed number of graphs: 576, train running loss: 0.00356 (passed time: 14m 54s)
#           acc: 0.99917, fpr: 0.00001, fnr: 0.01939, rec: 0.98061, prc: 0.99983, f1: 0.99013, f1_macro: 0.99485
# epoch: 6, passed number of graphs: 672, train running loss: 0.00355 (passed time: 15m 11s)
#           acc: 0.99868, fpr: 0.00046, fnr: 0.02106, rec: 0.97894, prc: 0.98928, f1: 0.98408, f1_macro: 0.99170
# epoch: 6, passed number of graphs: 768, train running loss: 0.00376 (passed time: 15m 28s)
#           acc: 0.99916, fpr: 0.00001, fnr: 0.01975, rec: 0.98025, prc: 0.99983, f1: 0.98994, f1_macro: 0.99475
# Validation --- epoch: 6, loss: 0.00345
#           rec: 0.97541, fpr: 0.00003, f1: 0.98638, prc: 0.99882, acc: 0.99945, f1_macro: 0.99305, fnr: 0.02459
# epoch: 7, passed number of graphs: 96, train running loss: 0.00409 (passed time: 16m 7s)
#           acc: 0.99857, fpr: 0.00005, fnr: 0.03293, rec: 0.96707, prc: 0.99883, f1: 0.98269, f1_macro: 0.99097
# epoch: 7, passed number of graphs: 192, train running loss: 0.00397 (passed time: 16m 24s)
#           acc: 0.99897, fpr: 0.00001, fnr: 0.02441, rec: 0.97559, prc: 0.99966, f1: 0.98747, f1_macro: 0.99347
# epoch: 7, passed number of graphs: 288, train running loss: 0.00367 (passed time: 16m 41s)
#           acc: 0.99925, fpr: 0.00001, fnr: 0.01802, rec: 0.98198, prc: 0.99966, f1: 0.99074, f1_macro: 0.99518
# epoch: 7, passed number of graphs: 384, train running loss: 0.00358 (passed time: 16m 58s)
#           acc: 0.99919, fpr: 0.00004, fnr: 0.01789, rec: 0.98211, prc: 0.99917, f1: 0.99056, f1_macro: 0.99507
# epoch: 7, passed number of graphs: 480, train running loss: 0.00359 (passed time: 17m 15s)
#           acc: 0.99916, fpr: 0.00001, fnr: 0.01961, rec: 0.98039, prc: 0.99983, f1: 0.99001, f1_macro: 0.99479
# epoch: 7, passed number of graphs: 576, train running loss: 0.00350 (passed time: 17m 32s)
#           acc: 0.99922, fpr: 0.00001, fnr: 0.01824, rec: 0.98176, prc: 0.99983, f1: 0.99071, f1_macro: 0.99515
# epoch: 7, passed number of graphs: 672, train running loss: 0.00348 (passed time: 17m 49s)
#           acc: 0.99872, fpr: 0.00046, fnr: 0.02008, rec: 0.97992, prc: 0.98929, f1: 0.98458, f1_macro: 0.99196
# epoch: 7, passed number of graphs: 768, train running loss: 0.00368 (passed time: 18m 5s)
#           acc: 0.99905, fpr: 0.00001, fnr: 0.02241, rec: 0.97759, prc: 0.99983, f1: 0.98858, f1_macro: 0.99404
# Validation --- epoch: 7, loss: 0.00301
#           rec: 0.97350, fpr: 0.00003, f1: 0.98531, prc: 0.99854, acc: 0.99940, f1_macro: 0.99250, fnr: 0.02650
# epoch: 8, passed number of graphs: 96, train running loss: 0.00412 (passed time: 18m 43s)
#           acc: 0.99924, fpr: 0.00004, fnr: 0.01736, rec: 0.98264, prc: 0.99918, f1: 0.99084, f1_macro: 0.99522
# epoch: 8, passed number of graphs: 192, train running loss: 0.00396 (passed time: 19m 0s)
#           acc: 0.99910, fpr: 0.00001, fnr: 0.02140, rec: 0.97860, prc: 0.99983, f1: 0.98910, f1_macro: 0.99432
# epoch: 8, passed number of graphs: 288, train running loss: 0.00362 (passed time: 19m 17s)
#           acc: 0.99927, fpr: 0.00001, fnr: 0.01752, rec: 0.98248, prc: 0.99966, f1: 0.99100, f1_macro: 0.99531
# epoch: 8, passed number of graphs: 384, train running loss: 0.00366 (passed time: 19m 34s)
#           acc: 0.99921, fpr: 0.00002, fnr: 0.01756, rec: 0.98244, prc: 0.99950, f1: 0.99090, f1_macro: 0.99524
# epoch: 8, passed number of graphs: 480, train running loss: 0.00362 (passed time: 19m 51s)
#           acc: 0.99918, fpr: 0.00001, fnr: 0.01928, rec: 0.98072, prc: 0.99983, f1: 0.99018, f1_macro: 0.99488
# epoch: 8, passed number of graphs: 576, train running loss: 0.00351 (passed time: 20m 8s)
#           acc: 0.99923, fpr: 0.00001, fnr: 0.01807, rec: 0.98193, prc: 0.99983, f1: 0.99080, f1_macro: 0.99520
# epoch: 8, passed number of graphs: 672, train running loss: 0.00346 (passed time: 20m 25s)
#           acc: 0.99879, fpr: 0.00047, fnr: 0.01829, rec: 0.98171, prc: 0.98914, f1: 0.98541, f1_macro: 0.99239
# epoch: 8, passed number of graphs: 768, train running loss: 0.00358 (passed time: 20m 42s)
#           acc: 0.99912, fpr: 0.00001, fnr: 0.02058, rec: 0.97942, prc: 0.99983, f1: 0.98952, f1_macro: 0.99453
# Validation --- epoch: 8, loss: 0.00322
#           rec: 0.97710, fpr: 0.00005, f1: 0.98667, prc: 0.99757, acc: 0.99946, f1_macro: 0.99319, fnr: 0.02290
# Better model saved at ./saved_models/GIN_7: 0.9866673527903527.pt.
# epoch: 9, passed number of graphs: 96, train running loss: 0.00431 (passed time: 21m 19s)
#           acc: 0.99876, fpr: 0.00003, fnr: 0.02888, rec: 0.97112, prc: 0.99933, f1: 0.98503, f1_macro: 0.99219
# epoch: 9, passed number of graphs: 192, train running loss: 0.00439 (passed time: 21m 36s)
#           acc: 0.99912, fpr: 0.00001, fnr: 0.02074, rec: 0.97926, prc: 0.99966, f1: 0.98936, f1_macro: 0.99445
# epoch: 9, passed number of graphs: 288, train running loss: 0.00388 (passed time: 21m 53s)
#           acc: 0.99927, fpr: 0.00001, fnr: 0.01769, rec: 0.98231, prc: 0.99983, f1: 0.99099, f1_macro: 0.99531
# epoch: 9, passed number of graphs: 384, train running loss: 0.00368 (passed time: 22m 10s)
#           acc: 0.99921, fpr: 0.00003, fnr: 0.01756, rec: 0.98244, prc: 0.99933, f1: 0.99081, f1_macro: 0.99520
# epoch: 9, passed number of graphs: 480, train running loss: 0.00363 (passed time: 22m 27s)
#           acc: 0.99920, fpr: 0.00001, fnr: 0.01861, rec: 0.98139, prc: 0.99983, f1: 0.99052, f1_macro: 0.99505
# epoch: 9, passed number of graphs: 576, train running loss: 0.00351 (passed time: 22m 44s)
#           acc: 0.99930, fpr: 0.00001, fnr: 0.01643, rec: 0.98357, prc: 0.99983, f1: 0.99163, f1_macro: 0.99563
# epoch: 9, passed number of graphs: 672, train running loss: 0.00346 (passed time: 23m 1s)
#           acc: 0.99879, fpr: 0.00047, fnr: 0.01812, rec: 0.98188, prc: 0.98914, f1: 0.98550, f1_macro: 0.99243
# epoch: 9, passed number of graphs: 768, train running loss: 0.00357 (passed time: 23m 18s)
#           acc: 0.99919, fpr: 0.00001, fnr: 0.01876, rec: 0.98124, prc: 0.99966, f1: 0.99037, f1_macro: 0.99497
# Validation --- epoch: 9, loss: 0.00310
#           rec: 0.97855, fpr: 0.00005, f1: 0.98751, prc: 0.99778, acc: 0.99949, f1_macro: 0.99363, fnr: 0.02145
# Better model saved at ./saved_models/GIN_8: 0.9875124998040535.pt.
# epoch: 10, passed number of graphs: 96, train running loss: 0.00326 (passed time: 23m 55s)
#           acc: 0.99931, fpr: 0.00001, fnr: 0.01622, rec: 0.98378, prc: 0.99967, f1: 0.99166, f1_macro: 0.99565
# epoch: 10, passed number of graphs: 192, train running loss: 0.00325 (passed time: 24m 12s)
#           acc: 0.99917, fpr: 0.00001, fnr: 0.01973, rec: 0.98027, prc: 0.99966, f1: 0.98987, f1_macro: 0.99472
# epoch: 10, passed number of graphs: 288, train running loss: 0.00310 (passed time: 24m 29s)
#           acc: 0.99926, fpr: 0.00001, fnr: 0.01785, rec: 0.98215, prc: 0.99983, f1: 0.99091, f1_macro: 0.99526
# epoch: 10, passed number of graphs: 384, train running loss: 0.00304 (passed time: 24m 46s)
#           acc: 0.99923, fpr: 0.00004, fnr: 0.01690, rec: 0.98310, prc: 0.99917, f1: 0.99107, f1_macro: 0.99533
# epoch: 10, passed number of graphs: 480, train running loss: 0.00307 (passed time: 25m 3s)
#           acc: 0.99927, fpr: 0.00001, fnr: 0.01695, rec: 0.98305, prc: 0.99983, f1: 0.99137, f1_macro: 0.99549
# epoch: 10, passed number of graphs: 576, train running loss: 0.00302 (passed time: 25m 20s)
#           acc: 0.99930, fpr: 0.00001, fnr: 0.01627, rec: 0.98373, prc: 0.99983, f1: 0.99172, f1_macro: 0.99568
# epoch: 10, passed number of graphs: 672, train running loss: 0.00301 (passed time: 25m 36s)
#           acc: 0.99886, fpr: 0.00048, fnr: 0.01633, rec: 0.98367, prc: 0.98884, f1: 0.98625, f1_macro: 0.99283
# epoch: 10, passed number of graphs: 768, train running loss: 0.00307 (passed time: 25m 53s)
#           acc: 0.99913, fpr: 0.00001, fnr: 0.02042, rec: 0.97958, prc: 0.99983, f1: 0.98960, f1_macro: 0.99457
# Validation --- epoch: 10, loss: 0.00299
#           rec: 0.97565, fpr: 0.00002, f1: 0.98654, prc: 0.99886, acc: 0.99945, f1_macro: 0.99313, fnr: 0.02435
# epoch: 11, passed number of graphs: 96, train running loss: 0.00320 (passed time: 26m 31s)
#           acc: 0.99915, fpr: 0.00001, fnr: 0.01995, rec: 0.98005, prc: 0.99967, f1: 0.98976, f1_macro: 0.99466
# epoch: 11, passed number of graphs: 192, train running loss: 0.00321 (passed time: 26m 48s)
#           acc: 0.99912, fpr: 0.00001, fnr: 0.02090, rec: 0.97910, prc: 0.99966, f1: 0.98927, f1_macro: 0.99441
# epoch: 11, passed number of graphs: 288, train running loss: 0.00307 (passed time: 27m 5s)
#           acc: 0.99923, fpr: 0.00001, fnr: 0.01869, rec: 0.98131, prc: 0.99983, f1: 0.99048, f1_macro: 0.99504
# epoch: 11, passed number of graphs: 384, train running loss: 0.00303 (passed time: 27m 22s)
#           acc: 0.99921, fpr: 0.00004, fnr: 0.01740, rec: 0.98260, prc: 0.99917, f1: 0.99082, f1_macro: 0.99520
# epoch: 11, passed number of graphs: 480, train running loss: 0.00307 (passed time: 27m 39s)
#           acc: 0.99926, fpr: 0.00001, fnr: 0.01728, rec: 0.98272, prc: 0.99983, f1: 0.99120, f1_macro: 0.99541
# epoch: 11, passed number of graphs: 576, train running loss: 0.00302 (passed time: 27m 56s)
#           acc: 0.99926, fpr: 0.00001, fnr: 0.01742, rec: 0.98258, prc: 0.99983, f1: 0.99113, f1_macro: 0.99537
# epoch: 11, passed number of graphs: 672, train running loss: 0.00301 (passed time: 28m 12s)
#           acc: 0.99887, fpr: 0.00048, fnr: 0.01600, rec: 0.98400, prc: 0.98884, f1: 0.98642, f1_macro: 0.99291
# epoch: 11, passed number of graphs: 768, train running loss: 0.00310 (passed time: 28m 29s)
#           acc: 0.99908, fpr: 0.00001, fnr: 0.02175, rec: 0.97825, prc: 0.99983, f1: 0.98892, f1_macro: 0.99422
# Validation --- epoch: 11, loss: 0.00304
#           rec: 0.97481, fpr: 0.00003, f1: 0.98602, prc: 0.99862, acc: 0.99943, f1_macro: 0.99286, fnr: 0.02519
# epoch: 12, passed number of graphs: 96, train running loss: 0.00327 (passed time: 29m 7s)
#           acc: 0.99897, fpr: 0.00001, fnr: 0.02433, rec: 0.97567, prc: 0.99983, f1: 0.98760, f1_macro: 0.99353
# epoch: 12, passed number of graphs: 192, train running loss: 0.00325 (passed time: 29m 24s)
#           acc: 0.99915, fpr: 0.00001, fnr: 0.02023, rec: 0.97977, prc: 0.99983, f1: 0.98970, f1_macro: 0.99463
# epoch: 12, passed number of graphs: 288, train running loss: 0.00308 (passed time: 29m 41s)
#           acc: 0.99923, fpr: 0.00001, fnr: 0.01869, rec: 0.98131, prc: 0.99983, f1: 0.99048, f1_macro: 0.99504
# epoch: 12, passed number of graphs: 384, train running loss: 0.00302 (passed time: 29m 58s)
#           acc: 0.99923, fpr: 0.00004, fnr: 0.01690, rec: 0.98310, prc: 0.99917, f1: 0.99107, f1_macro: 0.99533
# epoch: 12, passed number of graphs: 480, train running loss: 0.00306 (passed time: 30m 15s)
#           acc: 0.99925, fpr: 0.00001, fnr: 0.01762, rec: 0.98238, prc: 0.99983, f1: 0.99103, f1_macro: 0.99532
# epoch: 12, passed number of graphs: 576, train running loss: 0.00300 (passed time: 30m 31s)
#           acc: 0.99926, fpr: 0.00001, fnr: 0.01725, rec: 0.98275, prc: 0.99983, f1: 0.99122, f1_macro: 0.99542
# epoch: 12, passed number of graphs: 672, train running loss: 0.00299 (passed time: 30m 48s)
#           acc: 0.99891, fpr: 0.00048, fnr: 0.01502, rec: 0.98498, prc: 0.98885, f1: 0.98691, f1_macro: 0.99317
# epoch: 12, passed number of graphs: 768, train running loss: 0.00312 (passed time: 31m 5s)
#           acc: 0.99896, fpr: 0.00001, fnr: 0.02440, rec: 0.97560, prc: 0.99983, f1: 0.98757, f1_macro: 0.99351
# Validation --- epoch: 12, loss: 0.00312
#           rec: 0.97127, fpr: 0.00002, f1: 0.98433, prc: 0.99910, acc: 0.99936, f1_macro: 0.99200, fnr: 0.02873
# epoch: 13, passed number of graphs: 96, train running loss: 0.00312 (passed time: 31m 43s)
#           acc: 0.99946, fpr: 0.00001, fnr: 0.01249, rec: 0.98751, prc: 0.99967, f1: 0.99355, f1_macro: 0.99664
# epoch: 13, passed number of graphs: 192, train running loss: 0.00307 (passed time: 32m 0s)
#           acc: 0.99915, fpr: 0.00001, fnr: 0.02023, rec: 0.97977, prc: 0.99983, f1: 0.98970, f1_macro: 0.99463
# epoch: 13, passed number of graphs: 288, train running loss: 0.00296 (passed time: 32m 17s)
#           acc: 0.99929, fpr: 0.00001, fnr: 0.01719, rec: 0.98281, prc: 0.99983, f1: 0.99125, f1_macro: 0.99544
# epoch: 13, passed number of graphs: 384, train running loss: 0.00292 (passed time: 32m 34s)
#           acc: 0.99923, fpr: 0.00004, fnr: 0.01674, rec: 0.98326, prc: 0.99900, f1: 0.99107, f1_macro: 0.99533
# epoch: 13, passed number of graphs: 480, train running loss: 0.00296 (passed time: 32m 51s)
#           acc: 0.99930, fpr: 0.00001, fnr: 0.01629, rec: 0.98371, prc: 0.99983, f1: 0.99171, f1_macro: 0.99567
# epoch: 13, passed number of graphs: 576, train running loss: 0.00292 (passed time: 33m 8s)
#           acc: 0.99932, fpr: 0.00001, fnr: 0.01594, rec: 0.98406, prc: 0.99983, f1: 0.99188, f1_macro: 0.99576
# epoch: 13, passed number of graphs: 672, train running loss: 0.00291 (passed time: 33m 25s)
#           acc: 0.99889, fpr: 0.00048, fnr: 0.01551, rec: 0.98449, prc: 0.98885, f1: 0.98666, f1_macro: 0.99304
# epoch: 13, passed number of graphs: 768, train running loss: 0.00293 (passed time: 33m 42s)
#           acc: 0.99917, fpr: 0.00001, fnr: 0.01959, rec: 0.98041, prc: 0.99983, f1: 0.99003, f1_macro: 0.99480
# Validation --- epoch: 13, loss: 0.00303
#           rec: 0.97703, fpr: 0.00003, f1: 0.98716, prc: 0.99864, acc: 0.99948, f1_macro: 0.99345, fnr: 0.02297
# epoch: 14, passed number of graphs: 96, train running loss: 0.00305 (passed time: 34m 20s)
#           acc: 0.99945, fpr: 0.00001, fnr: 0.01282, rec: 0.98718, prc: 0.99967, f1: 0.99339, f1_macro: 0.99655
# epoch: 14, passed number of graphs: 192, train running loss: 0.00302 (passed time: 34m 37s)
#           acc: 0.99918, fpr: 0.00001, fnr: 0.01957, rec: 0.98043, prc: 0.99983, f1: 0.99004, f1_macro: 0.99480
# epoch: 14, passed number of graphs: 288, train running loss: 0.00292 (passed time: 34m 53s)
#           acc: 0.99931, fpr: 0.00000, fnr: 0.01702, rec: 0.98298, prc: 1.00000, f1: 0.99142, f1_macro: 0.99553
# epoch: 14, passed number of graphs: 384, train running loss: 0.00289 (passed time: 35m 10s)
#           acc: 0.99924, fpr: 0.00004, fnr: 0.01658, rec: 0.98342, prc: 0.99917, f1: 0.99123, f1_macro: 0.99542
# epoch: 14, passed number of graphs: 480, train running loss: 0.00293 (passed time: 35m 27s)
#           acc: 0.99930, fpr: 0.00001, fnr: 0.01629, rec: 0.98371, prc: 0.99983, f1: 0.99171, f1_macro: 0.99567
# epoch: 14, passed number of graphs: 576, train running loss: 0.00290 (passed time: 35m 44s)
#           acc: 0.99930, fpr: 0.00001, fnr: 0.01643, rec: 0.98357, prc: 0.99983, f1: 0.99163, f1_macro: 0.99563
# epoch: 14, passed number of graphs: 672, train running loss: 0.00289 (passed time: 36m 1s)
#           acc: 0.99891, fpr: 0.00048, fnr: 0.01502, rec: 0.98498, prc: 0.98885, f1: 0.98691, f1_macro: 0.99317
# epoch: 14, passed number of graphs: 768, train running loss: 0.00292 (passed time: 36m 18s)
#           acc: 0.99916, fpr: 0.00001, fnr: 0.01975, rec: 0.98025, prc: 0.99983, f1: 0.98994, f1_macro: 0.99475
# Validation --- epoch: 14, loss: 0.00305
#           rec: 0.97707, fpr: 0.00003, f1: 0.98722, prc: 0.99872, acc: 0.99948, f1_macro: 0.99348, fnr: 0.02293
# epoch: 15, passed number of graphs: 96, train running loss: 0.00300 (passed time: 36m 56s)
#           acc: 0.99945, fpr: 0.00001, fnr: 0.01282, rec: 0.98718, prc: 0.99967, f1: 0.99339, f1_macro: 0.99655
# epoch: 15, passed number of graphs: 192, train running loss: 0.00296 (passed time: 37m 13s)
#           acc: 0.99918, fpr: 0.00001, fnr: 0.01957, rec: 0.98043, prc: 0.99983, f1: 0.99004, f1_macro: 0.99480
# epoch: 15, passed number of graphs: 288, train running loss: 0.00288 (passed time: 37m 30s)
#           acc: 0.99927, fpr: 0.00000, fnr: 0.01785, rec: 0.98215, prc: 1.00000, f1: 0.99099, f1_macro: 0.99531
# epoch: 15, passed number of graphs: 384, train running loss: 0.00286 (passed time: 37m 46s)
#           acc: 0.99924, fpr: 0.00004, fnr: 0.01674, rec: 0.98326, prc: 0.99917, f1: 0.99115, f1_macro: 0.99537
# epoch: 15, passed number of graphs: 480, train running loss: 0.00290 (passed time: 38m 3s)
#           acc: 0.99932, fpr: 0.00001, fnr: 0.01579, rec: 0.98421, prc: 0.99983, f1: 0.99196, f1_macro: 0.99580
# epoch: 15, passed number of graphs: 576, train running loss: 0.00287 (passed time: 38m 20s)
#           acc: 0.99929, fpr: 0.00001, fnr: 0.01660, rec: 0.98340, prc: 0.99983, f1: 0.99155, f1_macro: 0.99559
# epoch: 15, passed number of graphs: 672, train running loss: 0.00287 (passed time: 38m 37s)
#           acc: 0.99884, fpr: 0.00048, fnr: 0.01665, rec: 0.98335, prc: 0.98884, f1: 0.98608, f1_macro: 0.99274
# epoch: 15, passed number of graphs: 768, train running loss: 0.00289 (passed time: 38m 54s)
#           acc: 0.99919, fpr: 0.00001, fnr: 0.01892, rec: 0.98108, prc: 0.99983, f1: 0.99036, f1_macro: 0.99497
# Validation --- epoch: 15, loss: 0.00308
#           rec: 0.97741, fpr: 0.00003, f1: 0.98737, prc: 0.99867, acc: 0.99949, f1_macro: 0.99355, fnr: 0.02259
# epoch: 16, passed number of graphs: 96, train running loss: 0.00302 (passed time: 39m 32s)
#           acc: 0.99946, fpr: 0.00002, fnr: 0.01249, rec: 0.98751, prc: 0.99951, f1: 0.99347, f1_macro: 0.99659
# epoch: 16, passed number of graphs: 192, train running loss: 0.00297 (passed time: 39m 49s)
#           acc: 0.99918, fpr: 0.00001, fnr: 0.01957, rec: 0.98043, prc: 0.99983, f1: 0.99004, f1_macro: 0.99480
# epoch: 16, passed number of graphs: 288, train running loss: 0.00289 (passed time: 40m 6s)
#           acc: 0.99928, fpr: 0.00000, fnr: 0.01769, rec: 0.98231, prc: 1.00000, f1: 0.99108, f1_macro: 0.99535
# epoch: 16, passed number of graphs: 384, train running loss: 0.00286 (passed time: 40m 23s)
#           acc: 0.99924, fpr: 0.00004, fnr: 0.01674, rec: 0.98326, prc: 0.99917, f1: 0.99115, f1_macro: 0.99537
# epoch: 16, passed number of graphs: 480, train running loss: 0.00291 (passed time: 40m 40s)
#           acc: 0.99932, fpr: 0.00001, fnr: 0.01579, rec: 0.98421, prc: 0.99983, f1: 0.99196, f1_macro: 0.99580
# epoch: 16, passed number of graphs: 576, train running loss: 0.00288 (passed time: 40m 57s)
#           acc: 0.99928, fpr: 0.00001, fnr: 0.01676, rec: 0.98324, prc: 0.99983, f1: 0.99147, f1_macro: 0.99555
# epoch: 16, passed number of graphs: 672, train running loss: 0.00287 (passed time: 41m 13s)
#           acc: 0.99884, fpr: 0.00048, fnr: 0.01665, rec: 0.98335, prc: 0.98884, f1: 0.98608, f1_macro: 0.99274
# epoch: 16, passed number of graphs: 768, train running loss: 0.00289 (passed time: 41m 30s)
#           acc: 0.99919, fpr: 0.00001, fnr: 0.01892, rec: 0.98108, prc: 0.99983, f1: 0.99036, f1_macro: 0.99497
# Validation --- epoch: 16, loss: 0.00310
#           rec: 0.97736, fpr: 0.00003, f1: 0.98734, prc: 0.99867, acc: 0.99948, f1_macro: 0.99354, fnr: 0.02264
# epoch: 17, passed number of graphs: 96, train running loss: 0.00302 (passed time: 42m 8s)
#           acc: 0.99943, fpr: 0.00001, fnr: 0.01314, rec: 0.98686, prc: 0.99967, f1: 0.99322, f1_macro: 0.99646
# epoch: 17, passed number of graphs: 192, train running loss: 0.00296 (passed time: 42m 25s)
#           acc: 0.99919, fpr: 0.00001, fnr: 0.01923, rec: 0.98077, prc: 0.99983, f1: 0.99021, f1_macro: 0.99489
# epoch: 17, passed number of graphs: 288, train running loss: 0.00288 (passed time: 42m 42s)
#           acc: 0.99927, fpr: 0.00001, fnr: 0.01769, rec: 0.98231, prc: 0.99983, f1: 0.99099, f1_macro: 0.99531
# epoch: 17, passed number of graphs: 384, train running loss: 0.00285 (passed time: 42m 59s)
#           acc: 0.99926, fpr: 0.00004, fnr: 0.01625, rec: 0.98375, prc: 0.99917, f1: 0.99140, f1_macro: 0.99551
# epoch: 17, passed number of graphs: 480, train running loss: 0.00290 (passed time: 43m 16s)
#           acc: 0.99933, fpr: 0.00001, fnr: 0.01562, rec: 0.98438, prc: 0.99983, f1: 0.99204, f1_macro: 0.99585
# epoch: 17, passed number of graphs: 576, train running loss: 0.00287 (passed time: 43m 33s)
#           acc: 0.99928, fpr: 0.00001, fnr: 0.01676, rec: 0.98324, prc: 0.99983, f1: 0.99147, f1_macro: 0.99555
# epoch: 17, passed number of graphs: 672, train running loss: 0.00287 (passed time: 43m 50s)
#           acc: 0.99885, fpr: 0.00048, fnr: 0.01649, rec: 0.98351, prc: 0.98884, f1: 0.98617, f1_macro: 0.99278
# epoch: 17, passed number of graphs: 768, train running loss: 0.00289 (passed time: 44m 7s)
#           acc: 0.99922, fpr: 0.00001, fnr: 0.01843, rec: 0.98157, prc: 0.99983, f1: 0.99062, f1_macro: 0.99510
# Validation --- epoch: 17, loss: 0.00312
#           rec: 0.97748, fpr: 0.00003, f1: 0.98746, prc: 0.99880, acc: 0.99949, f1_macro: 0.99360, fnr: 0.02252
# epoch: 18, passed number of graphs: 96, train running loss: 0.00301 (passed time: 44m 44s)
#           acc: 0.99943, fpr: 0.00001, fnr: 0.01314, rec: 0.98686, prc: 0.99967, f1: 0.99322, f1_macro: 0.99646
# epoch: 18, passed number of graphs: 192, train running loss: 0.00295 (passed time: 45m 1s)
#           acc: 0.99919, fpr: 0.00001, fnr: 0.01923, rec: 0.98077, prc: 0.99983, f1: 0.99021, f1_macro: 0.99489
# epoch: 18, passed number of graphs: 288, train running loss: 0.00288 (passed time: 45m 18s)
#           acc: 0.99927, fpr: 0.00001, fnr: 0.01769, rec: 0.98231, prc: 0.99983, f1: 0.99099, f1_macro: 0.99531
# epoch: 18, passed number of graphs: 384, train running loss: 0.00285 (passed time: 45m 35s)
#           acc: 0.99926, fpr: 0.00004, fnr: 0.01625, rec: 0.98375, prc: 0.99917, f1: 0.99140, f1_macro: 0.99551
# epoch: 18, passed number of graphs: 480, train running loss: 0.00290 (passed time: 45m 52s)
#           acc: 0.99933, fpr: 0.00001, fnr: 0.01562, rec: 0.98438, prc: 0.99983, f1: 0.99204, f1_macro: 0.99585
# epoch: 18, passed number of graphs: 576, train running loss: 0.00287 (passed time: 46m 9s)
#           acc: 0.99928, fpr: 0.00001, fnr: 0.01676, rec: 0.98324, prc: 0.99983, f1: 0.99147, f1_macro: 0.99555
# epoch: 18, passed number of graphs: 672, train running loss: 0.00286 (passed time: 46m 26s)
#           acc: 0.99885, fpr: 0.00048, fnr: 0.01649, rec: 0.98351, prc: 0.98884, f1: 0.98617, f1_macro: 0.99278
# epoch: 18, passed number of graphs: 768, train running loss: 0.00289 (passed time: 46m 43s)
#           acc: 0.99922, fpr: 0.00001, fnr: 0.01843, rec: 0.98157, prc: 0.99983, f1: 0.99062, f1_macro: 0.99510
# Validation --- epoch: 18, loss: 0.00313
#           rec: 0.97745, fpr: 0.00003, f1: 0.98744, prc: 0.99881, acc: 0.99949, f1_macro: 0.99359, fnr: 0.02255
# epoch: 19, passed number of graphs: 96, train running loss: 0.00300 (passed time: 47m 21s)
#           acc: 0.99943, fpr: 0.00001, fnr: 0.01314, rec: 0.98686, prc: 0.99967, f1: 0.99322, f1_macro: 0.99646
# epoch: 19, passed number of graphs: 192, train running loss: 0.00295 (passed time: 47m 38s)
#           acc: 0.99919, fpr: 0.00001, fnr: 0.01923, rec: 0.98077, prc: 0.99983, f1: 0.99021, f1_macro: 0.99489
# epoch: 19, passed number of graphs: 288, train running loss: 0.00287 (passed time: 47m 55s)
#           acc: 0.99927, fpr: 0.00001, fnr: 0.01769, rec: 0.98231, prc: 0.99983, f1: 0.99099, f1_macro: 0.99531
# epoch: 19, passed number of graphs: 384, train running loss: 0.00285 (passed time: 48m 12s)
#           acc: 0.99926, fpr: 0.00004, fnr: 0.01625, rec: 0.98375, prc: 0.99917, f1: 0.99140, f1_macro: 0.99551
# epoch: 19, passed number of graphs: 480, train running loss: 0.00290 (passed time: 48m 28s)
#           acc: 0.99934, fpr: 0.00001, fnr: 0.01529, rec: 0.98471, prc: 0.99983, f1: 0.99221, f1_macro: 0.99594
# epoch: 19, passed number of graphs: 576, train running loss: 0.00287 (passed time: 48m 45s)
#           acc: 0.99928, fpr: 0.00001, fnr: 0.01676, rec: 0.98324, prc: 0.99983, f1: 0.99147, f1_macro: 0.99555
# epoch: 19, passed number of graphs: 672, train running loss: 0.00286 (passed time: 49m 2s)
#           acc: 0.99885, fpr: 0.00048, fnr: 0.01649, rec: 0.98351, prc: 0.98884, f1: 0.98617, f1_macro: 0.99278
# epoch: 19, passed number of graphs: 768, train running loss: 0.00288 (passed time: 49m 19s)
#           acc: 0.99920, fpr: 0.00001, fnr: 0.01876, rec: 0.98124, prc: 0.99983, f1: 0.99045, f1_macro: 0.99502
# Validation --- epoch: 19, loss: 0.00313
#           rec: 0.97734, fpr: 0.00002, f1: 0.98741, prc: 0.99886, acc: 0.99949, f1_macro: 0.99357, fnr: 0.02266
# epoch: 20, passed number of graphs: 96, train running loss: 0.00300 (passed time: 49m 57s)
#           acc: 0.99943, fpr: 0.00001, fnr: 0.01330, rec: 0.98670, prc: 0.99967, f1: 0.99314, f1_macro: 0.99642
# epoch: 20, passed number of graphs: 192, train running loss: 0.00295 (passed time: 50m 14s)
#           acc: 0.99919, fpr: 0.00001, fnr: 0.01923, rec: 0.98077, prc: 0.99983, f1: 0.99021, f1_macro: 0.99489
# epoch: 20, passed number of graphs: 288, train running loss: 0.00287 (passed time: 50m 31s)
#           acc: 0.99927, fpr: 0.00001, fnr: 0.01769, rec: 0.98231, prc: 0.99983, f1: 0.99099, f1_macro: 0.99531
# epoch: 20, passed number of graphs: 384, train running loss: 0.00285 (passed time: 50m 48s)
#           acc: 0.99926, fpr: 0.00004, fnr: 0.01625, rec: 0.98375, prc: 0.99917, f1: 0.99140, f1_macro: 0.99551
# epoch: 20, passed number of graphs: 480, train running loss: 0.00290 (passed time: 51m 4s)
#           acc: 0.99934, fpr: 0.00001, fnr: 0.01529, rec: 0.98471, prc: 0.99983, f1: 0.99221, f1_macro: 0.99594
# epoch: 20, passed number of graphs: 576, train running loss: 0.00286 (passed time: 51m 21s)
#           acc: 0.99928, fpr: 0.00001, fnr: 0.01676, rec: 0.98324, prc: 0.99983, f1: 0.99147, f1_macro: 0.99555
# epoch: 20, passed number of graphs: 672, train running loss: 0.00286 (passed time: 51m 38s)
#           acc: 0.99885, fpr: 0.00048, fnr: 0.01649, rec: 0.98351, prc: 0.98884, f1: 0.98617, f1_macro: 0.99278
# epoch: 20, passed number of graphs: 768, train running loss: 0.00288 (passed time: 51m 55s)
#           acc: 0.99920, fpr: 0.00001, fnr: 0.01876, rec: 0.98124, prc: 0.99983, f1: 0.99045, f1_macro: 0.99502
# Validation --- epoch: 20, loss: 0.00314
#           rec: 0.97733, fpr: 0.00002, f1: 0.98741, prc: 0.99887, acc: 0.99949, f1_macro: 0.99358, fnr: 0.02267
# epoch: 21, passed number of graphs: 96, train running loss: 0.00300 (passed time: 52m 33s)
#           acc: 0.99942, fpr: 0.00001, fnr: 0.01347, rec: 0.98653, prc: 0.99967, f1: 0.99306, f1_macro: 0.99638
# epoch: 21, passed number of graphs: 192, train running loss: 0.00295 (passed time: 52m 50s)
#           acc: 0.99920, fpr: 0.00001, fnr: 0.01906, rec: 0.98094, prc: 0.99983, f1: 0.99029, f1_macro: 0.99494
# epoch: 21, passed number of graphs: 288, train running loss: 0.00287 (passed time: 53m 7s)
#           acc: 0.99927, fpr: 0.00001, fnr: 0.01769, rec: 0.98231, prc: 0.99983, f1: 0.99099, f1_macro: 0.99531
# epoch: 21, passed number of graphs: 384, train running loss: 0.00284 (passed time: 53m 24s)
#           acc: 0.99926, fpr: 0.00004, fnr: 0.01625, rec: 0.98375, prc: 0.99917, f1: 0.99140, f1_macro: 0.99551
# epoch: 21, passed number of graphs: 480, train running loss: 0.00289 (passed time: 53m 41s)
#           acc: 0.99934, fpr: 0.00001, fnr: 0.01529, rec: 0.98471, prc: 0.99983, f1: 0.99221, f1_macro: 0.99594
# epoch: 21, passed number of graphs: 576, train running loss: 0.00286 (passed time: 53m 58s)
#           acc: 0.99928, fpr: 0.00001, fnr: 0.01676, rec: 0.98324, prc: 0.99983, f1: 0.99147, f1_macro: 0.99555
# epoch: 21, passed number of graphs: 672, train running loss: 0.00286 (passed time: 54m 15s)
#           acc: 0.99885, fpr: 0.00048, fnr: 0.01649, rec: 0.98351, prc: 0.98884, f1: 0.98617, f1_macro: 0.99278
# epoch: 21, passed number of graphs: 768, train running loss: 0.00288 (passed time: 54m 31s)
#           acc: 0.99919, fpr: 0.00001, fnr: 0.01892, rec: 0.98108, prc: 0.99983, f1: 0.99036, f1_macro: 0.99497
# Validation --- epoch: 21, loss: 0.00313
#           rec: 0.97720, fpr: 0.00002, f1: 0.98734, prc: 0.99888, acc: 0.99949, f1_macro: 0.99354, fnr: 0.02280
# epoch: 22, passed number of graphs: 96, train running loss: 0.00300 (passed time: 55m 9s)
#           acc: 0.99942, fpr: 0.00001, fnr: 0.01347, rec: 0.98653, prc: 0.99967, f1: 0.99306, f1_macro: 0.99638
# epoch: 22, passed number of graphs: 192, train running loss: 0.00295 (passed time: 55m 26s)
#           acc: 0.99919, fpr: 0.00001, fnr: 0.01923, rec: 0.98077, prc: 0.99983, f1: 0.99021, f1_macro: 0.99489
# epoch: 22, passed number of graphs: 288, train running loss: 0.00287 (passed time: 55m 43s)
#           acc: 0.99927, fpr: 0.00001, fnr: 0.01769, rec: 0.98231, prc: 0.99983, f1: 0.99099, f1_macro: 0.99531
# epoch: 22, passed number of graphs: 384, train running loss: 0.00284 (passed time: 56m 0s)
#           acc: 0.99926, fpr: 0.00004, fnr: 0.01625, rec: 0.98375, prc: 0.99917, f1: 0.99140, f1_macro: 0.99551
# epoch: 22, passed number of graphs: 480, train running loss: 0.00289 (passed time: 56m 17s)
#           acc: 0.99934, fpr: 0.00001, fnr: 0.01529, rec: 0.98471, prc: 0.99983, f1: 0.99221, f1_macro: 0.99594
# epoch: 22, passed number of graphs: 576, train running loss: 0.00286 (passed time: 56m 34s)
#           acc: 0.99928, fpr: 0.00001, fnr: 0.01676, rec: 0.98324, prc: 0.99983, f1: 0.99147, f1_macro: 0.99555
# epoch: 22, passed number of graphs: 672, train running loss: 0.00286 (passed time: 56m 51s)
#           acc: 0.99885, fpr: 0.00048, fnr: 0.01649, rec: 0.98351, prc: 0.98884, f1: 0.98617, f1_macro: 0.99278
# epoch: 22, passed number of graphs: 768, train running loss: 0.00288 (passed time: 57m 8s)
#           acc: 0.99919, fpr: 0.00001, fnr: 0.01892, rec: 0.98108, prc: 0.99983, f1: 0.99036, f1_macro: 0.99497
# Validation --- epoch: 22, loss: 0.00313
#           rec: 0.97719, fpr: 0.00002, f1: 0.98735, prc: 0.99889, acc: 0.99949, f1_macro: 0.99354, fnr: 0.02281
# epoch: 23, passed number of graphs: 96, train running loss: 0.00300 (passed time: 57m 46s)
#           acc: 0.99942, fpr: 0.00001, fnr: 0.01347, rec: 0.98653, prc: 0.99967, f1: 0.99306, f1_macro: 0.99638
# epoch: 23, passed number of graphs: 192, train running loss: 0.00294 (passed time: 58m 3s)
#           acc: 0.99920, fpr: 0.00001, fnr: 0.01906, rec: 0.98094, prc: 0.99983, f1: 0.99029, f1_macro: 0.99494
# epoch: 23, passed number of graphs: 288, train running loss: 0.00287 (passed time: 58m 20s)
#           acc: 0.99927, fpr: 0.00001, fnr: 0.01769, rec: 0.98231, prc: 0.99983, f1: 0.99099, f1_macro: 0.99531
# epoch: 23, passed number of graphs: 384, train running loss: 0.00284 (passed time: 58m 36s)
#           acc: 0.99926, fpr: 0.00004, fnr: 0.01625, rec: 0.98375, prc: 0.99917, f1: 0.99140, f1_macro: 0.99551
# epoch: 23, passed number of graphs: 480, train running loss: 0.00289 (passed time: 58m 53s)
#           acc: 0.99934, fpr: 0.00001, fnr: 0.01529, rec: 0.98471, prc: 0.99983, f1: 0.99221, f1_macro: 0.99594
# epoch: 23, passed number of graphs: 576, train running loss: 0.00286 (passed time: 59m 10s)
#           acc: 0.99928, fpr: 0.00001, fnr: 0.01676, rec: 0.98324, prc: 0.99983, f1: 0.99147, f1_macro: 0.99555
# epoch: 23, passed number of graphs: 672, train running loss: 0.00286 (passed time: 59m 27s)
#           acc: 0.99885, fpr: 0.00048, fnr: 0.01649, rec: 0.98351, prc: 0.98884, f1: 0.98617, f1_macro: 0.99278
# epoch: 23, passed number of graphs: 768, train running loss: 0.00288 (passed time: 59m 44s)
#           acc: 0.99919, fpr: 0.00001, fnr: 0.01892, rec: 0.98108, prc: 0.99983, f1: 0.99036, f1_macro: 0.99497
# Validation --- epoch: 23, loss: 0.00313
#           rec: 0.97718, fpr: 0.00002, f1: 0.98734, prc: 0.99889, acc: 0.99949, f1_macro: 0.99354, fnr: 0.02282
# epoch: 24, passed number of graphs: 96, train running loss: 0.00300 (passed time: 1h 0m 22s)
#           acc: 0.99942, fpr: 0.00001, fnr: 0.01347, rec: 0.98653, prc: 0.99967, f1: 0.99306, f1_macro: 0.99638
# epoch: 24, passed number of graphs: 192, train running loss: 0.00294 (passed time: 1h 0m 39s)
#           acc: 0.99919, fpr: 0.00001, fnr: 0.01923, rec: 0.98077, prc: 0.99983, f1: 0.99021, f1_macro: 0.99489
# epoch: 24, passed number of graphs: 288, train running loss: 0.00287 (passed time: 1h 0m 56s)
#           acc: 0.99927, fpr: 0.00001, fnr: 0.01769, rec: 0.98231, prc: 0.99983, f1: 0.99099, f1_macro: 0.99531
# epoch: 24, passed number of graphs: 384, train running loss: 0.00284 (passed time: 1h 1m 13s)
#           acc: 0.99926, fpr: 0.00004, fnr: 0.01625, rec: 0.98375, prc: 0.99917, f1: 0.99140, f1_macro: 0.99551
# epoch: 24, passed number of graphs: 480, train running loss: 0.00289 (passed time: 1h 1m 30s)
#           acc: 0.99934, fpr: 0.00001, fnr: 0.01529, rec: 0.98471, prc: 0.99983, f1: 0.99221, f1_macro: 0.99594
# epoch: 24, passed number of graphs: 576, train running loss: 0.00286 (passed time: 1h 1m 47s)
#           acc: 0.99928, fpr: 0.00001, fnr: 0.01676, rec: 0.98324, prc: 0.99983, f1: 0.99147, f1_macro: 0.99555
# epoch: 24, passed number of graphs: 672, train running loss: 0.00286 (passed time: 1h 2m 4s)
#           acc: 0.99885, fpr: 0.00048, fnr: 0.01649, rec: 0.98351, prc: 0.98884, f1: 0.98617, f1_macro: 0.99278
# epoch: 24, passed number of graphs: 768, train running loss: 0.00288 (passed time: 1h 2m 20s)
#           acc: 0.99919, fpr: 0.00001, fnr: 0.01892, rec: 0.98108, prc: 0.99983, f1: 0.99036, f1_macro: 0.99497
# Validation --- epoch: 24, loss: 0.00313
#           rec: 0.97718, fpr: 0.00002, f1: 0.98734, prc: 0.99889, acc: 0.99949, f1_macro: 0.99354, fnr: 0.02282
# epoch: 25, passed number of graphs: 96, train running loss: 0.00300 (passed time: 1h 2m 59s)
#           acc: 0.99942, fpr: 0.00001, fnr: 0.01347, rec: 0.98653, prc: 0.99967, f1: 0.99306, f1_macro: 0.99638
# epoch: 25, passed number of graphs: 192, train running loss: 0.00294 (passed time: 1h 3m 16s)
#           acc: 0.99919, fpr: 0.00001, fnr: 0.01923, rec: 0.98077, prc: 0.99983, f1: 0.99021, f1_macro: 0.99489
# epoch: 25, passed number of graphs: 288, train running loss: 0.00287 (passed time: 1h 3m 33s)
#           acc: 0.99927, fpr: 0.00001, fnr: 0.01769, rec: 0.98231, prc: 0.99983, f1: 0.99099, f1_macro: 0.99531
# epoch: 25, passed number of graphs: 384, train running loss: 0.00284 (passed time: 1h 3m 50s)
#           acc: 0.99926, fpr: 0.00004, fnr: 0.01625, rec: 0.98375, prc: 0.99917, f1: 0.99140, f1_macro: 0.99551
# epoch: 25, passed number of graphs: 480, train running loss: 0.00289 (passed time: 1h 4m 7s)
#           acc: 0.99934, fpr: 0.00001, fnr: 0.01529, rec: 0.98471, prc: 0.99983, f1: 0.99221, f1_macro: 0.99594
# epoch: 25, passed number of graphs: 576, train running loss: 0.00286 (passed time: 1h 4m 23s)
#           acc: 0.99928, fpr: 0.00001, fnr: 0.01676, rec: 0.98324, prc: 0.99983, f1: 0.99147, f1_macro: 0.99555
# epoch: 25, passed number of graphs: 672, train running loss: 0.00286 (passed time: 1h 4m 40s)
#           acc: 0.99885, fpr: 0.00048, fnr: 0.01649, rec: 0.98351, prc: 0.98884, f1: 0.98617, f1_macro: 0.99278
# epoch: 25, passed number of graphs: 768, train running loss: 0.00288 (passed time: 1h 4m 57s)
#           acc: 0.99919, fpr: 0.00001, fnr: 0.01892, rec: 0.98108, prc: 0.99983, f1: 0.99036, f1_macro: 0.99497
# Validation --- epoch: 25, loss: 0.00313
#           rec: 0.97718, fpr: 0.00002, f1: 0.98734, prc: 0.99889, acc: 0.99949, f1_macro: 0.99354, fnr: 0.02282
# epoch: 26, passed number of graphs: 96, train running loss: 0.00300 (passed time: 1h 5m 35s)
#           acc: 0.99942, fpr: 0.00001, fnr: 0.01347, rec: 0.98653, prc: 0.99967, f1: 0.99306, f1_macro: 0.99638
# epoch: 26, passed number of graphs: 192, train running loss: 0.00294 (passed time: 1h 5m 52s)
#           acc: 0.99919, fpr: 0.00001, fnr: 0.01923, rec: 0.98077, prc: 0.99983, f1: 0.99021, f1_macro: 0.99489
# epoch: 26, passed number of graphs: 288, train running loss: 0.00287 (passed time: 1h 6m 9s)
#           acc: 0.99927, fpr: 0.00001, fnr: 0.01769, rec: 0.98231, prc: 0.99983, f1: 0.99099, f1_macro: 0.99531
# epoch: 26, passed number of graphs: 384, train running loss: 0.00284 (passed time: 1h 6m 26s)
#           acc: 0.99926, fpr: 0.00004, fnr: 0.01625, rec: 0.98375, prc: 0.99917, f1: 0.99140, f1_macro: 0.99551
# epoch: 26, passed number of graphs: 480, train running loss: 0.00289 (passed time: 1h 6m 43s)
#           acc: 0.99934, fpr: 0.00001, fnr: 0.01529, rec: 0.98471, prc: 0.99983, f1: 0.99221, f1_macro: 0.99594
# epoch: 26, passed number of graphs: 576, train running loss: 0.00286 (passed time: 1h 7m 0s)
#           acc: 0.99928, fpr: 0.00001, fnr: 0.01676, rec: 0.98324, prc: 0.99983, f1: 0.99147, f1_macro: 0.99555
# epoch: 26, passed number of graphs: 672, train running loss: 0.00286 (passed time: 1h 7m 17s)
#           acc: 0.99885, fpr: 0.00048, fnr: 0.01649, rec: 0.98351, prc: 0.98884, f1: 0.98617, f1_macro: 0.99278
# epoch: 26, passed number of graphs: 768, train running loss: 0.00288 (passed time: 1h 7m 34s)
#           acc: 0.99919, fpr: 0.00001, fnr: 0.01892, rec: 0.98108, prc: 0.99983, f1: 0.99036, f1_macro: 0.99497
# Validation --- epoch: 26, loss: 0.00313
#           rec: 0.97718, fpr: 0.00002, f1: 0.98734, prc: 0.99889, acc: 0.99949, f1_macro: 0.99354, fnr: 0.02282
# epoch: 27, passed number of graphs: 96, train running loss: 0.00300 (passed time: 1h 8m 12s)
#           acc: 0.99942, fpr: 0.00001, fnr: 0.01347, rec: 0.98653, prc: 0.99967, f1: 0.99306, f1_macro: 0.99638
# ...
# epoch: 42, passed number of graphs: 288, train running loss: 0.00287 (passed time: 1h 47m 55s)
#           acc: 0.99927, fpr: 0.00001, fnr: 0.01769, rec: 0.98231, prc: 0.99983, f1: 0.99099, f1_macro: 0.99531
# epoch: 42, passed number of graphs: 384, train running loss: 0.00284 (passed time: 1h 48m 12s)
#           acc: 0.99926, fpr: 0.00004, fnr: 0.01625, rec: 0.98375, prc: 0.99917, f1: 0.99140, f1_macro: 0.99551
# epoch: 42, passed number of graphs: 480, train running loss: 0.00289 (passed time: 1h 48m 29s)
#           acc: 0.99934, fpr: 0.00001, fnr: 0.01529, rec: 0.98471, prc: 0.99983, f1: 0.99221, f1_macro: 0.99594
# epoch: 42, passed number of graphs: 576, train running loss: 0.00286 (passed time: 1h 48m 46s)
#           acc: 0.99928, fpr: 0.00001, fnr: 0.01676, rec: 0.98324, prc: 0.99983, f1: 0.99147, f1_macro: 0.99555
# epoch: 42, passed number of graphs: 672, train running loss: 0.00286 (passed time: 1h 49m 3s)
#           acc: 0.99885, fpr: 0.00048, fnr: 0.01649, rec: 0.98351, prc: 0.98884, f1: 0.98617, f1_macro: 0.99278
# epoch: 42, passed number of graphs: 768, train running loss: 0.00288 (passed time: 1h 49m 20s)
#           acc: 0.99919, fpr: 0.00001, fnr: 0.01892, rec: 0.98108, prc: 0.99983, f1: 0.99036, f1_macro: 0.99497
# Validation --- epoch: 42, loss: 0.00313
#           rec: 0.97718, fpr: 0.00002, f1: 0.98734, prc: 0.99889, acc: 0.99949, f1_macro: 0.99354, fnr: 0.02282
# epoch: 43, passed number of graphs: 96, train running loss: 0.00300 (passed time: 1h 49m 58s)
#           acc: 0.99942, fpr: 0.00001, fnr: 0.01347, rec: 0.98653, prc: 0.99967, f1: 0.99306, f1_macro: 0.99638
# epoch: 43, passed number of graphs: 192, train running loss: 0.00294 (passed time: 1h 50m 15s)
#           acc: 0.99919, fpr: 0.00001, fnr: 0.01923, rec: 0.98077, prc: 0.99983, f1: 0.99021, f1_macro: 0.99489
# epoch: 43, passed number of graphs: 288, train running loss: 0.00287 (passed time: 1h 50m 32s)
#           acc: 0.99927, fpr: 0.00001, fnr: 0.01769, rec: 0.98231, prc: 0.99983, f1: 0.99099, f1_macro: 0.99531
# epoch: 43, passed number of graphs: 384, train running loss: 0.00284 (passed time: 1h 50m 48s)
#           acc: 0.99926, fpr: 0.00004, fnr: 0.01625, rec: 0.98375, prc: 0.99917, f1: 0.99140, f1_macro: 0.99551
# epoch: 43, passed number of graphs: 480, train running loss: 0.00289 (passed time: 1h 51m 5s)
#           acc: 0.99934, fpr: 0.00001, fnr: 0.01529, rec: 0.98471, prc: 0.99983, f1: 0.99221, f1_macro: 0.99594
# epoch: 43, passed number of graphs: 576, train running loss: 0.00286 (passed time: 1h 51m 22s)
#           acc: 0.99928, fpr: 0.00001, fnr: 0.01676, rec: 0.98324, prc: 0.99983, f1: 0.99147, f1_macro: 0.99555
# epoch: 43, passed number of graphs: 672, train running loss: 0.00286 (passed time: 1h 51m 39s)
#           acc: 0.99885, fpr: 0.00048, fnr: 0.01649, rec: 0.98351, prc: 0.98884, f1: 0.98617, f1_macro: 0.99278
# epoch: 43, passed number of graphs: 768, train running loss: 0.00288 (passed time: 1h 51m 56s)
#           acc: 0.99919, fpr: 0.00001, fnr: 0.01892, rec: 0.98108, prc: 0.99983, f1: 0.99036, f1_macro: 0.99497
# Validation --- epoch: 43, loss: 0.00313
#           rec: 0.97718, fpr: 0.00002, f1: 0.98734, prc: 0.99889, acc: 0.99949, f1_macro: 0.99354, fnr: 0.02282
# epoch: 44, passed number of graphs: 96, train running loss: 0.00300 (passed time: 1h 52m 34s)
#           acc: 0.99942, fpr: 0.00001, fnr: 0.01347, rec: 0.98653, prc: 0.99967, f1: 0.99306, f1_macro: 0.99638
# epoch: 44, passed number of graphs: 192, train running loss: 0.00294 (passed time: 1h 52m 51s)
#           acc: 0.99919, fpr: 0.00001, fnr: 0.01923, rec: 0.98077, prc: 0.99983, f1: 0.99021, f1_macro: 0.99489
# epoch: 44, passed number of graphs: 288, train running loss: 0.00287 (passed time: 1h 53m 8s)
#           acc: 0.99927, fpr: 0.00001, fnr: 0.01769, rec: 0.98231, prc: 0.99983, f1: 0.99099, f1_macro: 0.99531
# epoch: 44, passed number of graphs: 384, train running loss: 0.00284 (passed time: 1h 53m 25s)
#           acc: 0.99926, fpr: 0.00004, fnr: 0.01625, rec: 0.98375, prc: 0.99917, f1: 0.99140, f1_macro: 0.99551
# epoch: 44, passed number of graphs: 480, train running loss: 0.00289 (passed time: 1h 53m 41s)
#           acc: 0.99934, fpr: 0.00001, fnr: 0.01529, rec: 0.98471, prc: 0.99983, f1: 0.99221, f1_macro: 0.99594
# epoch: 44, passed number of graphs: 576, train running loss: 0.00286 (passed time: 1h 53m 58s)
#           acc: 0.99928, fpr: 0.00001, fnr: 0.01676, rec: 0.98324, prc: 0.99983, f1: 0.99147, f1_macro: 0.99555
# epoch: 44, passed number of graphs: 672, train running loss: 0.00286 (passed time: 1h 54m 15s)
#           acc: 0.99885, fpr: 0.00048, fnr: 0.01649, rec: 0.98351, prc: 0.98884, f1: 0.98617, f1_macro: 0.99278
# epoch: 44, passed number of graphs: 768, train running loss: 0.00288 (passed time: 1h 54m 32s)
#           acc: 0.99919, fpr: 0.00001, fnr: 0.01892, rec: 0.98108, prc: 0.99983, f1: 0.99036, f1_macro: 0.99497
# Validation --- epoch: 44, loss: 0.00313
#           rec: 0.97718, fpr: 0.00002, f1: 0.98734, prc: 0.99889, acc: 0.99949, f1_macro: 0.99354, fnr: 0.02282
# epoch: 45, passed number of graphs: 96, train running loss: 0.00300 (passed time: 1h 55m 10s)
#           acc: 0.99942, fpr: 0.00001, fnr: 0.01347, rec: 0.98653, prc: 0.99967, f1: 0.99306, f1_macro: 0.99638
# epoch: 45, passed number of graphs: 192, train running loss: 0.00294 (passed time: 1h 55m 27s)
#           acc: 0.99919, fpr: 0.00001, fnr: 0.01923, rec: 0.98077, prc: 0.99983, f1: 0.99021, f1_macro: 0.99489
# epoch: 45, passed number of graphs: 288, train running loss: 0.00287 (passed time: 1h 55m 44s)
#           acc: 0.99927, fpr: 0.00001, fnr: 0.01769, rec: 0.98231, prc: 0.99983, f1: 0.99099, f1_macro: 0.99531
# epoch: 45, passed number of graphs: 384, train running loss: 0.00284 (passed time: 1h 56m 1s)
#           acc: 0.99926, fpr: 0.00004, fnr: 0.01625, rec: 0.98375, prc: 0.99917, f1: 0.99140, f1_macro: 0.99551
# epoch: 45, passed number of graphs: 480, train running loss: 0.00289 (passed time: 1h 56m 18s)
#           acc: 0.99934, fpr: 0.00001, fnr: 0.01529, rec: 0.98471, prc: 0.99983, f1: 0.99221, f1_macro: 0.99594
# epoch: 45, passed number of graphs: 576, train running loss: 0.00286 (passed time: 1h 56m 35s)
#           acc: 0.99928, fpr: 0.00001, fnr: 0.01676, rec: 0.98324, prc: 0.99983, f1: 0.99147, f1_macro: 0.99555
# epoch: 45, passed number of graphs: 672, train running loss: 0.00286 (passed time: 1h 56m 52s)
#           acc: 0.99885, fpr: 0.00048, fnr: 0.01649, rec: 0.98351, prc: 0.98884, f1: 0.98617, f1_macro: 0.99278
# epoch: 45, passed number of graphs: 768, train running loss: 0.00288 (passed time: 1h 57m 9s)
#           acc: 0.99919, fpr: 0.00001, fnr: 0.01892, rec: 0.98108, prc: 0.99983, f1: 0.99036, f1_macro: 0.99497
# Validation --- epoch: 45, loss: 0.00313
#           rec: 0.97718, fpr: 0.00002, f1: 0.98734, prc: 0.99889, acc: 0.99949, f1_macro: 0.99354, fnr: 0.02282
# epoch: 46, passed number of graphs: 96, train running loss: 0.00300 (passed time: 1h 57m 46s)
#           acc: 0.99942, fpr: 0.00001, fnr: 0.01347, rec: 0.98653, prc: 0.99967, f1: 0.99306, f1_macro: 0.99638
# epoch: 46, passed number of graphs: 192, train running loss: 0.00294 (passed time: 1h 58m 3s)
#           acc: 0.99919, fpr: 0.00001, fnr: 0.01923, rec: 0.98077, prc: 0.99983, f1: 0.99021, f1_macro: 0.99489
# epoch: 46, passed number of graphs: 288, train running loss: 0.00287 (passed time: 1h 58m 20s)
#           acc: 0.99927, fpr: 0.00001, fnr: 0.01769, rec: 0.98231, prc: 0.99983, f1: 0.99099, f1_macro: 0.99531
# epoch: 46, passed number of graphs: 384, train running loss: 0.00284 (passed time: 1h 58m 37s)
#           acc: 0.99926, fpr: 0.00004, fnr: 0.01625, rec: 0.98375, prc: 0.99917, f1: 0.99140, f1_macro: 0.99551
# epoch: 46, passed number of graphs: 480, train running loss: 0.00289 (passed time: 1h 58m 54s)
#           acc: 0.99934, fpr: 0.00001, fnr: 0.01529, rec: 0.98471, prc: 0.99983, f1: 0.99221, f1_macro: 0.99594
# epoch: 46, passed number of graphs: 576, train running loss: 0.00286 (passed time: 1h 59m 11s)
#           acc: 0.99928, fpr: 0.00001, fnr: 0.01676, rec: 0.98324, prc: 0.99983, f1: 0.99147, f1_macro: 0.99555
# epoch: 46, passed number of graphs: 672, train running loss: 0.00286 (passed time: 1h 59m 28s)
#           acc: 0.99885, fpr: 0.00048, fnr: 0.01649, rec: 0.98351, prc: 0.98884, f1: 0.98617, f1_macro: 0.99278
# epoch: 46, passed number of graphs: 768, train running loss: 0.00288 (passed time: 1h 59m 45s)
#           acc: 0.99919, fpr: 0.00001, fnr: 0.01892, rec: 0.98108, prc: 0.99983, f1: 0.99036, f1_macro: 0.99497
# Validation --- epoch: 46, loss: 0.00313
#           rec: 0.97718, fpr: 0.00002, f1: 0.98734, prc: 0.99889, acc: 0.99949, f1_macro: 0.99354, fnr: 0.02282
# epoch: 47, passed number of graphs: 96, train running loss: 0.00300 (passed time: 2h 0m 23s)
#           acc: 0.99942, fpr: 0.00001, fnr: 0.01347, rec: 0.98653, prc: 0.99967, f1: 0.99306, f1_macro: 0.99638
# epoch: 47, passed number of graphs: 192, train running loss: 0.00294 (passed time: 2h 0m 40s)
#           acc: 0.99919, fpr: 0.00001, fnr: 0.01923, rec: 0.98077, prc: 0.99983, f1: 0.99021, f1_macro: 0.99489
# epoch: 47, passed number of graphs: 288, train running loss: 0.00287 (passed time: 2h 0m 57s)
#           acc: 0.99927, fpr: 0.00001, fnr: 0.01769, rec: 0.98231, prc: 0.99983, f1: 0.99099, f1_macro: 0.99531
# epoch: 47, passed number of graphs: 384, train running loss: 0.00284 (passed time: 2h 1m 13s)
#           acc: 0.99926, fpr: 0.00004, fnr: 0.01625, rec: 0.98375, prc: 0.99917, f1: 0.99140, f1_macro: 0.99551
# epoch: 47, passed number of graphs: 480, train running loss: 0.00289 (passed time: 2h 1m 30s)
#           acc: 0.99934, fpr: 0.00001, fnr: 0.01529, rec: 0.98471, prc: 0.99983, f1: 0.99221, f1_macro: 0.99594
# epoch: 47, passed number of graphs: 576, train running loss: 0.00286 (passed time: 2h 1m 47s)
#           acc: 0.99928, fpr: 0.00001, fnr: 0.01676, rec: 0.98324, prc: 0.99983, f1: 0.99147, f1_macro: 0.99555
# epoch: 47, passed number of graphs: 672, train running loss: 0.00286 (passed time: 2h 2m 4s)
#           acc: 0.99885, fpr: 0.00048, fnr: 0.01649, rec: 0.98351, prc: 0.98884, f1: 0.98617, f1_macro: 0.99278
# epoch: 47, passed number of graphs: 768, train running loss: 0.00288 (passed time: 2h 2m 21s)
#           acc: 0.99919, fpr: 0.00001, fnr: 0.01892, rec: 0.98108, prc: 0.99983, f1: 0.99036, f1_macro: 0.99497
# Validation --- epoch: 47, loss: 0.00313
#           rec: 0.97718, fpr: 0.00002, f1: 0.98734, prc: 0.99889, acc: 0.99949, f1_macro: 0.99354, fnr: 0.02282
# epoch: 48, passed number of graphs: 96, train running loss: 0.00300 (passed time: 2h 2m 59s)
#           acc: 0.99942, fpr: 0.00001, fnr: 0.01347, rec: 0.98653, prc: 0.99967, f1: 0.99306, f1_macro: 0.99638
# epoch: 48, passed number of graphs: 192, train running loss: 0.00294 (passed time: 2h 3m 16s)
#           acc: 0.99919, fpr: 0.00001, fnr: 0.01923, rec: 0.98077, prc: 0.99983, f1: 0.99021, f1_macro: 0.99489
# epoch: 48, passed number of graphs: 288, train running loss: 0.00287 (passed time: 2h 3m 33s)
#           acc: 0.99927, fpr: 0.00001, fnr: 0.01769, rec: 0.98231, prc: 0.99983, f1: 0.99099, f1_macro: 0.99531
# epoch: 48, passed number of graphs: 384, train running loss: 0.00284 (passed time: 2h 3m 50s)
#           acc: 0.99926, fpr: 0.00004, fnr: 0.01625, rec: 0.98375, prc: 0.99917, f1: 0.99140, f1_macro: 0.99551
# epoch: 48, passed number of graphs: 480, train running loss: 0.00289 (passed time: 2h 4m 7s)
#           acc: 0.99934, fpr: 0.00001, fnr: 0.01529, rec: 0.98471, prc: 0.99983, f1: 0.99221, f1_macro: 0.99594
# epoch: 48, passed number of graphs: 576, train running loss: 0.00286 (passed time: 2h 4m 24s)
#           acc: 0.99928, fpr: 0.00001, fnr: 0.01676, rec: 0.98324, prc: 0.99983, f1: 0.99147, f1_macro: 0.99555
# epoch: 48, passed number of graphs: 672, train running loss: 0.00286 (passed time: 2h 4m 40s)
#           acc: 0.99885, fpr: 0.00048, fnr: 0.01649, rec: 0.98351, prc: 0.98884, f1: 0.98617, f1_macro: 0.99278
# epoch: 48, passed number of graphs: 768, train running loss: 0.00288 (passed time: 2h 4m 57s)
#           acc: 0.99919, fpr: 0.00001, fnr: 0.01892, rec: 0.98108, prc: 0.99983, f1: 0.99036, f1_macro: 0.99497
# Validation --- epoch: 48, loss: 0.00313
#           rec: 0.97718, fpr: 0.00002, f1: 0.98734, prc: 0.99889, acc: 0.99949, f1_macro: 0.99354, fnr: 0.02282
# epoch: 49, passed number of graphs: 96, train running loss: 0.00300 (passed time: 2h 5m 35s)
#           acc: 0.99942, fpr: 0.00001, fnr: 0.01347, rec: 0.98653, prc: 0.99967, f1: 0.99306, f1_macro: 0.99638
# epoch: 49, passed number of graphs: 192, train running loss: 0.00294 (passed time: 2h 5m 52s)
#           acc: 0.99919, fpr: 0.00001, fnr: 0.01923, rec: 0.98077, prc: 0.99983, f1: 0.99021, f1_macro: 0.99489
# epoch: 49, passed number of graphs: 288, train running loss: 0.00287 (passed time: 2h 6m 9s)
#           acc: 0.99927, fpr: 0.00001, fnr: 0.01769, rec: 0.98231, prc: 0.99983, f1: 0.99099, f1_macro: 0.99531
# epoch: 49, passed number of graphs: 384, train running loss: 0.00284 (passed time: 2h 6m 26s)
#           acc: 0.99926, fpr: 0.00004, fnr: 0.01625, rec: 0.98375, prc: 0.99917, f1: 0.99140, f1_macro: 0.99551
# epoch: 49, passed number of graphs: 480, train running loss: 0.00289 (passed time: 2h 6m 43s)
#           acc: 0.99934, fpr: 0.00001, fnr: 0.01529, rec: 0.98471, prc: 0.99983, f1: 0.99221, f1_macro: 0.99594
# epoch: 49, passed number of graphs: 576, train running loss: 0.00286 (passed time: 2h 7m 0s)
#           acc: 0.99928, fpr: 0.00001, fnr: 0.01676, rec: 0.98324, prc: 0.99983, f1: 0.99147, f1_macro: 0.99555
# epoch: 49, passed number of graphs: 672, train running loss: 0.00286 (passed time: 2h 7m 17s)
#           acc: 0.99885, fpr: 0.00048, fnr: 0.01649, rec: 0.98351, prc: 0.98884, f1: 0.98617, f1_macro: 0.99278
# epoch: 49, passed number of graphs: 768, train running loss: 0.00288 (passed time: 2h 7m 34s)
#           acc: 0.99919, fpr: 0.00001, fnr: 0.01892, rec: 0.98108, prc: 0.99983, f1: 0.99036, f1_macro: 0.99497
# Validation --- epoch: 49, loss: 0.00313
#           rec: 0.97718, fpr: 0.00002, f1: 0.98734, prc: 0.99889, acc: 0.99949, f1_macro: 0.99354, fnr: 0.02282
# epoch: 50, passed number of graphs: 96, train running loss: 0.00300 (passed time: 2h 8m 12s)
#           acc: 0.99942, fpr: 0.00001, fnr: 0.01347, rec: 0.98653, prc: 0.99967, f1: 0.99306, f1_macro: 0.99638
# epoch: 50, passed number of graphs: 192, train running loss: 0.00294 (passed time: 2h 8m 29s)
#           acc: 0.99919, fpr: 0.00001, fnr: 0.01923, rec: 0.98077, prc: 0.99983, f1: 0.99021, f1_macro: 0.99489
# epoch: 50, passed number of graphs: 288, train running loss: 0.00287 (passed time: 2h 8m 45s)
#           acc: 0.99927, fpr: 0.00001, fnr: 0.01769, rec: 0.98231, prc: 0.99983, f1: 0.99099, f1_macro: 0.99531
# epoch: 50, passed number of graphs: 384, train running loss: 0.00284 (passed time: 2h 9m 2s)
#           acc: 0.99926, fpr: 0.00004, fnr: 0.01625, rec: 0.98375, prc: 0.99917, f1: 0.99140, f1_macro: 0.99551
# epoch: 50, passed number of graphs: 480, train running loss: 0.00289 (passed time: 2h 9m 19s)
#           acc: 0.99934, fpr: 0.00001, fnr: 0.01529, rec: 0.98471, prc: 0.99983, f1: 0.99221, f1_macro: 0.99594
# epoch: 50, passed number of graphs: 576, train running loss: 0.00286 (passed time: 2h 9m 36s)
#           acc: 0.99928, fpr: 0.00001, fnr: 0.01676, rec: 0.98324, prc: 0.99983, f1: 0.99147, f1_macro: 0.99555
# epoch: 50, passed number of graphs: 672, train running loss: 0.00286 (passed time: 2h 9m 53s)
#           acc: 0.99885, fpr: 0.00048, fnr: 0.01649, rec: 0.98351, prc: 0.98884, f1: 0.98617, f1_macro: 0.99278
# epoch: 50, passed number of graphs: 768, train running loss: 0.00288 (passed time: 2h 10m 10s)
#           acc: 0.99919, fpr: 0.00001, fnr: 0.01892, rec: 0.98108, prc: 0.99983, f1: 0.99036, f1_macro: 0.99497
# Validation --- epoch: 50, loss: 0.00313
#           rec: 0.97718, fpr: 0.00002, f1: 0.98734, prc: 0.99889, acc: 0.99949, f1_macro: 0.99354, fnr: 0.02282
# ************ best model obtained after epoch 9, saved at ./saved_models/GIN_8: 0.9875124998040535.pt ************
# Testing --- loss: 0.00244
#           rec: 0.98128, fpr: 0.00008, f1: 0.98855, prc: 0.99638, acc: 0.99952, f1_macro: 0.99415, fnr: 0.01872

# %%
# !zip -r /content/ClusterGCNConv_p2p_6k_feat_norm.zip /content/saved_models
# Out:
#   adding: content/saved_models/ (stored 0%)
#   adding: content/saved_models/GIN_0: 0.9679025470968735.pt (deflated 21%)
#   adding: content/saved_models/GIN_8: 0.9875124998040535.pt (deflated 21%)
#   adding: content/saved_models/GIN_7: 0.9866673527903527.pt (deflated 21%)
#   adding: content/saved_models/GIN_4: 0.9864103404508645.pt (deflated 21%)
#   adding: content/saved_models/GIN_1: 0.9817046448678545.pt (deflated 20%)

# %%
from google.colab import files
files.download("/content/ClusterGCNConv_p2p_6k_feat_norm.zip")

# %%
from google.colab import runtime
runtime.unassign()
