# %% [markdown]
# <a href="https://colab.research.google.com/github/Zoro1092000/xxxx/blob/main/GATv2Conv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # I. Pip & Import.

# %%
import os
import os.path as osp
import torch
import sys

os.environ['TORCH'] = torch.__version__

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install torch-geometric
# !pip install torch-cluster -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install deepdish==0.3.5
# !pip install torch-optimizer

import torch.nn as nn
from torch.nn import Parameter
from torch_geometric.utils import scatter
from torch_geometric.nn.inits import glorot, zeros
from torch_scatter import scatter_add
from torch.utils.data import DataLoader, Dataset
import torch_optimizer as optimization


from itertools import chain
import pickle
import h5py
import deepdish as dd
import numpy as np
from tqdm import tqdm
import inspect
import time
import math
import random
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-geometric in /usr/local/lib/python3.7/dist-packages (2.1.0.post1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.11.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.7.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.0.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (3.0.9)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.21.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (4.64.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.23.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->torch-geometric) (2.0.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (2022.9.24)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric) (1.2.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://data.pyg.org/whl/torch-1.12.1+cu113.html
# Requirement already satisfied: torch-cluster in /usr/local/lib/python3.7/dist-packages (1.6.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: deepdish==0.3.5 in /usr/local/lib/python3.7/dist-packages (0.3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.7.3)
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (3.7.0)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (2.8.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tables->deepdish==0.3.5) (3.0.9)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-optimizer in /usr/local/lib/python3.7/dist-packages (0.3.0)
# Requirement already satisfied: torch>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from torch-optimizer) (1.12.1+cu113)
# Requirement already satisfied: pytorch-ranger>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from torch-optimizer) (0.1.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.5.0->torch-optimizer) (4.1.1)

# %%
def time_since(start):
    now = time.time()
    s = now - start
    m = math.floor(s / 60)
    s -= m * 60
    h = math.floor(m / 60)
    m -= h * 60
    if h == 0:
        if m == 0:
            return '%ds' % s
        else:
            return '%dm %ds' % (m, s)
    else:
        return '%dh %dm %ds' % (h, m, s)

# %% [markdown]
# # II. Data

# %%
# Data utils
def h5group_to_dict(h5group):
    group_dict = {k: v[()] for k, v in chain(h5group.items(), h5group.attrs.items())}
    return group_dict

def sub_dict(full_dict, *keys, to_tensor):
    return {k: torch.tensor(full_dict[k]) if to_tensor else full_dict[k] for k in keys if k in full_dict}

def build_graph_from_dict_pyg(graph_dict, to_tensor=True):
    from torch_geometric.data import Data

    g = Data(**sub_dict(graph_dict, 'edge_index', 'x', 'y', 'edge_attr', 'edge_y', to_tensor=to_tensor))
    return g

# Data loader
class GraphDataLoader(DataLoader):
    def __init__(self, dataset, batch_size=128, shuffle=False, num_workers=0):

        def collate_graph(graph_obj_list):
            from torch_geometric.data import Batch
            batch = Batch.from_data_list(graph_obj_list)
            return batch

        super().__init__(
            dataset,
            batch_size=batch_size,
            shuffle=shuffle,
            collate_fn=collate_graph,
            num_workers=num_workers)

# BotnetDataset
class BotnetDataset(Dataset):

    def __init__(self, name='chord', root='data/botnet', split='train', graph_format='pyg', split_idx=None, add_nfeat_ones=True,
                 in_memory=True):
        super().__init__()
        assert name in ['chord', 'debru', 'kadem', 'leet', 'c2', 'p2p']
        assert split in ['train', 'val', 'test']

        if isinstance(root, str):
            root = osp.expanduser(osp.normpath(root))

        self.name = name
        self.root = root
        self.split = split
        self.split_idx = split_idx
        self.add_nfeat_ones = add_nfeat_ones

        self._graph_format = graph_format
        if split == 'train':
            self.path = self.processed_paths[0]
            self.num_graphs = 768
        elif split == 'val':
            self.path = self.processed_paths[1]
            self.num_graphs = 96
        elif split == 'test':
            self.path = self.processed_paths[2]
            self.num_graphs = 96

        if in_memory:
            self.data = dd.io.load(self.path)  # dictionary
            self.data_type = 'dict'
        else:
            # self.data = h5py.File(self.path, 'r')
            self.data = None    # defer opening file in each process to make multiprocessing work
            self.data_type = 'file'
            
    @property
    def processed_dir(self):
        return osp.join(self.root, 'processed')

    @property
    def processed_file_names(self):
        return [self.name + '_' + s + '.hdf5' for s in ('train', 'val', 'test')]

    @property
    def processed_paths(self):
        return [osp.join(self.processed_dir, f) for f in self.processed_file_names]

    def __len__(self):
        return self.num_graphs

    def __getitem__(self, index):
        if self.data_type == 'dict':
            graph_dict = self.data[str(index)]
        elif self.data_type == 'file':
            if self.data is None:
                # only open once in each process
                self.data = h5py.File(self.path, 'r')
            graph_dict = h5group_to_dict(self.data[str(index)])
        else:
            raise ValueError

        # graph_format == 'pyg':
        return build_graph_from_dict_pyg(graph_dict)


    def __iter__(self):
        for i in range(self.num_graphs):
            yield self[i]

    def __repr__(self):
        return f'{self.__class__.__name__}(topology: {self.name} | split: {self.split} | ' \
               f'#graphs: {len(self)} | graph format: {self.graph_format})'

# %% [markdown]
# # III. Measure Performancce

# %% [markdown]
# ## 3.1. Metrics

# %%
def f1(target, pred, label):
    # F1 = 2 * (precision * recall) / (precision + recall)
    tp = np.sum((target==label) & (pred==label))
    fp = np.sum((target!=label) & (pred==label))
    fn = np.sum((pred!=label) & (target==label))
    
    if tp+fp==0 or tp+fn==0:
      return np.nan

    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    
    if precision+recall==0:
      return np.nan
      
    f1 = 2 * (precision * recall) / (precision + recall)
    return f1

def f1_macro(pred, target):
    return np.mean([f1(target, pred, label) for label in range(0, 2)])


def accuracy(pred, target):
    return (pred == target).sum().item() / len(target)


def true_positive(pred, target):
    return (target[pred == 1] == 1).sum().item()


def false_positive(pred, target):
    return (target[pred == 1] == 0).sum().item()


def true_negative(pred, target):
    return (target[pred == 0] == 0).sum().item()


def false_negative(pred, target):
    return (target[pred == 0] == 1).sum().item()


def recall(pred, target):
    try:
        return true_positive(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1


def precision(pred, target):
    try:
        prec = true_positive(pred, target) / (pred == 1).sum().item()
        return prec
    except:  # divide by zero
        return -1


def f1_score(pred, target):
    prec = precision(pred, target)
    rec = recall(pred, target)
    try:
        return 2 * (prec * rec) / (prec + rec)
    except:
        return 0


def false_positive_rate(pred, target):
    try:
        return false_positive(pred, target) / (target == 0).sum().item()
    except:  # divide by zero
        return -1


def false_negative_rate(pred, target):
    try:
        return false_negative(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1

# %% [markdown]
# ## 3.2. Evaluation

# %%
def eval_metrics(target, pred_prob, threshold=0.5):
    if isinstance(target, torch.Tensor):
        target = target.cpu().numpy()
    if isinstance(pred_prob, torch.Tensor):
        pred_prob = pred_prob.cpu().numpy()

    pred = (pred_prob >= threshold).astype(int)

    acc = accuracy(pred, target)
    fpr = false_positive_rate(pred, target)
    fnr = false_negative_rate(pred, target)
    rec = recall(pred, target)
    prc = precision(pred, target)
    f1 = f1_score(pred, target)
    f1macro = f1_macro(pred, target)
    result_dict = {'acc': acc, 'fpr': fpr, 'fnr': fnr, 'rec': rec, 'prc': prc, 'f1': f1, 'f1_macro': f1macro}

    return result_dict


def dict_value_add(dict1, dict2):
    result = {key: dict1.get(key, 0) + dict2.get(key, 0)
              for key in set(dict1) | set(dict2)}
    return result


def dict_value_div(dict, n):
    result = {key: value / n for key, value in dict.items()}
    return result


def eval_predictor(dataset, predictor):
    result_dict_avg = {}
    loss_avg = 0

    for data in dataset:
        # prediction
        try:
            pred_prob, loss = predictor(data)
            loss_avg += loss
        except ValueError:  # if "too many values to unpack"
            pred_prob = predictor(data)

        # get the ground truth target
        # graph_format == 'pyg':
        target = data.y

        # compute the evaluation metrics
        result_dict = eval_metrics(target, pred_prob)

        result_dict_avg = dict_value_add(result_dict_avg, result_dict)

    # average the metrics across all graphs in the dataset as final results
    result_dict_avg = dict_value_div(result_dict_avg, len(dataset))
    loss_avg = loss_avg / len(dataset)

    return result_dict_avg, loss_avg


# =================================================================================================================
# some examples of the 'predictor' model wrapper to be fed into the above evaluation function (for PyG Data format)
# =================================================================================================================
class PygRandomPredictor:
    def __init__(self):
        # torch.manual_seed(0)
        pass

    def __call__(self, data):
        pred_prob = torch.rand(len(data.y))
        return pred_prob


class PygModelPredictor:
    def __init__(self, model, loss_fcn=torch.nn.CrossEntropyLoss()):
        self.model = model
        self.loss_fcn = loss_fcn
        self.device = next(model.parameters()).device

    def __call__(self, data):
        self.model.eval()
        data = data.to(self.device)
        with torch.no_grad():
            # custom the below line to adjust to your model's input format for forward pass
            out = self.model(data.x, data.edge_index)
            loss = self.loss_fcn(out, data.y.long())
            pred_prob = torch.softmax(out, dim=1)[:, 1]
        return pred_prob, loss.float()

# %% [markdown]
# # IV. Model

# %% [markdown]
# ## 5.1. Activation

# %%
def activation(act, negative_slope=0.2):
    activations = nn.ModuleDict([
        ['lrelu', nn.LeakyReLU(negative_slope)],
        ['relu', nn.ReLU()],
        ['elu', nn.ELU()],
        ['none', nn.Identity()],
    ])
    return activations[act]

# %% [markdown]
# ## 5.2. GIN model

# %%
from torch.nn.modules.activation import LeakyReLU
import torch.nn as nn

class GINModel(nn.Module):
    def __init__(self, dim_input_feature, dim_hidden_feature, num_layers, num_classes, non_linear='relu', dropout=0.2):
        super().__init__()

        self.dim_input_feature = dim_input_feature
        self.dim_hidden_feature = dim_hidden_feature

        self.num_layers = num_layers
        self.num_classes = num_classes
        
        from torch.nn import Linear, Sequential, BatchNorm1d, ReLU, Dropout
        from torch_geometric.nn import GATv2Conv, GINConv, TransformerConv
        
        self.gin_net = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.gin_net.append(GATv2Conv(self.dim_input_feature, self.dim_hidden_feature, heads=1, concat=False))
          else:
            self.gin_net.append(GATv2Conv(self.dim_hidden_feature, self.dim_hidden_feature, heads=1, concat=False))


        self.dropout = nn.Dropout(dropout)

        self.residuals = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.residuals.append(nn.Linear(self.dim_input_feature, self.dim_hidden_feature, bias=True))
          else:
            self.residuals.append(nn.Identity())

        self.num_residuals = len(self.residuals)

        self.non_linear = activation(non_linear)

        # self.final_type == 'proj':
        self.final = nn.Linear(self.dim_hidden_feature, num_classes)

    def reset_parameters(self):
        for net in self.gin_net:
            net.reset_parameters()
        # self.residual_hop = 1
        for net in self.residuals:
            net.reset_parameters()
        # self.final_type != 'none':
        self.final.reset_parameters()

    def forward(self, x, edge_index):
        xr = None
        add_xr_at = -1

        for n, net in enumerate(self.gin_net):
            # pass to a GIN layer with non-linear activation
            xo = net(x, edge_index)
            xo = self.dropout(xo)
            # deal with residual connections
            # self.residual_hop = 1
            if n < self.num_residuals:
                xr = self.residuals[n](x)
                xo = self.non_linear(xo + xr)

            x = xo
        # size of x: (B * N, dim_hidden_feature) -> (B * N, num_classes)
        x = self.final(x)

        return x

# %% [markdown]
# # V. Load data

# %%
data_dir = '/content/drive/Shareddrives/botnetdata/p2p_6k_feat_norm'
data_name = 'p2p' # 'chord', 'debru', 'kadem', 'leet', 'c2', 'p2p'
shuffle = False

# ========== load the dataset
print('loading dataset...')

train_ds = BotnetDataset(name=data_name, root=data_dir, split='train',
                         in_memory=False, graph_format='pyg')
val_ds = BotnetDataset(name=data_name, root=data_dir, split='val',
                       in_memory=False, graph_format='pyg')
test_ds = BotnetDataset(name=data_name, root=data_dir, split='test',
                        in_memory=False, graph_format='pyg')
# Out:
# loading dataset...

# %%
batch_size = 1
train_loader = GraphDataLoader(train_ds, batch_size=batch_size, shuffle=bool(shuffle), num_workers=0)

# %% [markdown]
# # VI. Train

# %%
# ============== some default parameters =============
devid = 0
seed = 0
logmode = 'w'
log_interval = 96

dim_input_feature = 1
dim_hidden_feature = 32
act = 'relu' # 'none', 'lrelu', 'relu', 'elu'

num_layers = 12
num_classes = 2 

dropout = 0.0
bias = True

lr = 0.005 # learning rate
weight_decay = 5e-4
epochs = 50
save_dir = './saved_models'
save_name = "GIN_model.pt"
# ====================================================

def train(model, train_loader, val_dataset, test_dataset, optimizer, scheduler=None):
    device = next(model.parameters()).device
    predictor = PygModelPredictor(model)

    best_epoch = 0
    max_f1_score = 0
    start = time.time()
    for ep in range(epochs):
        loss_avg_train = 0
        num_train_graph = 0
        model.train()
        for n, batch in enumerate(train_loader):
            batch.to(device)

            optimizer.zero_grad()

            x = model(batch.x, batch.edge_index)
            loss = criterion(x, batch.y.long())

            loss_avg_train += float(loss)
            num_train_graph += batch.num_graphs

            loss.backward()
            optimizer.step()

            if num_train_graph % log_interval == 0 or n == len(train_loader) - 1:
                with torch.no_grad():
                    # pred = x.argmax(dim=1)
                    pred_prob = torch.softmax(x, dim=1)[:, 1]
                    y = batch.y.long()
                    result_dict = eval_metrics(y, pred_prob)
                print(f'epoch: {ep + 1}, passed number of graphs: {num_train_graph}, '
                        f'train running loss: {loss_avg_train / num_train_graph:.5f} (passed time: {time_since(start)})')
                print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict.items()]))

        result_dict_avg, loss_avg = eval_predictor(val_dataset, predictor)
        print(f'Validation --- epoch: {ep + 1}, loss: {loss_avg:.5f}')
        print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))

        if scheduler is not None:
            scheduler.step(loss_avg)

        if result_dict_avg['f1'] > max_f1_score:
            save_name = f"GIN_{ep}: {result_dict_avg['f1']}.pt"
            torch.save(model, os.path.join(save_dir, save_name))
            print(f'Better model saved at {os.path.join(save_dir, save_name)}.')
            best_epoch = ep
            max_f1_score = result_dict_avg['f1']

    best_model = torch.load(os.path.join(save_dir, save_name))
    print('*' * 12 + f' best model obtained after epoch {best_epoch + 1}, '
                       f'saved at {os.path.join(save_dir, save_name)} ' + '*' * 12)
    
    predictor = PygModelPredictor(best_model)

    result_dict_avg, loss_avg = eval_predictor(test_dataset, predictor)
    print(f'Testing --- loss: {loss_avg:.5f}')
    print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))


if __name__ == '__main__':
    os.makedirs(save_dir, exist_ok=True)

    # ========== random seeds and device
    random.seed(seed)
    torch.manual_seed(seed)

    device = torch.device(f'cuda:{devid}') if devid > -1 else torch.device('cpu')

    # ========== logging setup
    log_name = os.path.splitext(save_name)[0]
    # logger = logging_config(__name__, folder=save_dir, name=log_name, filemode=logmode)
    # logger = logging_config(os.path.basename(__file__), folder=save_dir, name=log_name, filemode=logmode)

    print('python ' + ' '.join(sys.argv))
    print('-' * 30)
    #logger.info(args)
    print('-' * 30)
    print(time.ctime())
    print('-' * 30)

    # ========== define the model, optimizer, and loss

    model = GINModel(dim_input_feature,
                     dim_hidden_feature,
                     num_layers,
                     num_classes,
                     non_linear=act,
                     dropout=dropout)

    print('model ' + '-' * 10)
    print(repr(model))
    model.to(device)

    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.25, patience=1)

    # ========== train the model
    print(f"Batch size: {batch_size}")
    train(model, train_loader, val_ds, test_ds, optimizer, scheduler)
# Out:
# python /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-51ddf573-808a-452e-8dce-02ea1a00f62b.json
# ------------------------------
# ------------------------------
# Thu Nov  3 15:45:50 2022
# ------------------------------
# model ----------
# GINModel(
#   (gin_net): ModuleList(
#     (0): GATv2Conv(1, 32, heads=1)
#     (1): GATv2Conv(32, 32, heads=1)
#     (2): GATv2Conv(32, 32, heads=1)
#     (3): GATv2Conv(32, 32, heads=1)
#     (4): GATv2Conv(32, 32, heads=1)
#     (5): GATv2Conv(32, 32, heads=1)
#     (6): GATv2Conv(32, 32, heads=1)
#     (7): GATv2Conv(32, 32, heads=1)
#     (8): GATv2Conv(32, 32, heads=1)
#     (9): GATv2Conv(32, 32, heads=1)
#     (10): GATv2Conv(32, 32, heads=1)
#     (11): GATv2Conv(32, 32, heads=1)
#   )
#   (dropout): Dropout(p=0.0, inplace=False)
#   (residuals): ModuleList(
#     (0): Linear(in_features=1, out_features=32, bias=True)
#     (1): Identity()
#     (2): Identity()
#     (3): Identity()
#     (4): Identity()
#     (5): Identity()
#     (6): Identity()
#     (7): Identity()
#     (8): Identity()
#     (9): Identity()
#     (10): Identity()
#     (11): Identity()
#   )
#   (non_linear): ReLU()
#   (final): Linear(in_features=32, out_features=2, bias=True)
# )
# Batch size: 1
# epoch: 1, passed number of graphs: 96, train running loss: 0.32646 (passed time: 2m 11s)
#           acc: 0.95801, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 192, train running loss: 0.25042 (passed time: 3m 7s)
#           acc: 0.95840, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 288, train running loss: 0.22387 (passed time: 4m 0s)
#           acc: 0.95918, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 384, train running loss: 0.20950 (passed time: 4m 56s)
#           acc: 0.95647, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 480, train running loss: 0.20102 (passed time: 5m 51s)
#           acc: 0.95759, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 576, train running loss: 0.19726 (passed time: 6m 44s)
#           acc: 0.95767, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 672, train running loss: 0.19413 (passed time: 7m 39s)
#           acc: 0.95829, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 768, train running loss: 0.19173 (passed time: 8m 33s)
#           acc: 0.95782, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# Validation --- epoch: 1, loss: 0.10974
#           acc: 0.97848, rec: 0.00000, f1: 0.00000, fnr: 1.00000, prc: -1.00000, f1_macro: nan, fpr: 0.00000
# epoch: 2, passed number of graphs: 96, train running loss: 0.17504 (passed time: 10m 3s)
#           acc: 0.95801, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 2, passed number of graphs: 192, train running loss: 0.17481 (passed time: 10m 52s)
#           acc: 0.95840, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 2, passed number of graphs: 288, train running loss: 0.17473 (passed time: 11m 40s)
#           acc: 0.95918, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 2, passed number of graphs: 384, train running loss: 0.17467 (passed time: 12m 29s)
#           acc: 0.95647, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 2, passed number of graphs: 480, train running loss: 0.17456 (passed time: 13m 18s)
#           acc: 0.95759, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 2, passed number of graphs: 576, train running loss: 0.17225 (passed time: 14m 7s)
#           acc: 0.95767, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 2, passed number of graphs: 672, train running loss: 0.15720 (passed time: 14m 56s)
#           acc: 0.99403, fpr: 0.00039, fnr: 0.13420, rec: 0.86580, prc: 0.98973, f1: 0.92363, f1_macro: 0.96026
# epoch: 2, passed number of graphs: 768, train running loss: 0.13900 (passed time: 15m 45s)
#           acc: 0.99970, fpr: 0.00028, fnr: 0.00083, rec: 0.99917, prc: 0.99373, f1: 0.99644, f1_macro: 0.99814
# Validation --- epoch: 2, loss: 0.00325
#           acc: 0.99933, rec: 0.97832, f1: 0.98276, fnr: 0.02168, prc: 0.99053, f1_macro: 0.99121, fpr: 0.00020
# Better model saved at ./saved_models/GIN_1: 0.9827649963323503.pt.
# epoch: 3, passed number of graphs: 96, train running loss: 0.00960 (passed time: 17m 9s)
#           acc: 0.99967, fpr: 0.00009, fnr: 0.00568, rec: 0.99432, prc: 0.99788, f1: 0.99610, f1_macro: 0.99796
# epoch: 3, passed number of graphs: 192, train running loss: 0.00808 (passed time: 17m 58s)
#           acc: 0.99985, fpr: 0.00015, fnr: 0.00033, rec: 0.99967, prc: 0.99667, f1: 0.99816, f1_macro: 0.99904
# epoch: 3, passed number of graphs: 288, train running loss: 0.00676 (passed time: 18m 47s)
#           acc: 0.99975, fpr: 0.00025, fnr: 0.00017, rec: 0.99983, prc: 0.99419, f1: 0.99700, f1_macro: 0.99844
# epoch: 3, passed number of graphs: 384, train running loss: 0.00608 (passed time: 19m 35s)
#           acc: 0.99966, fpr: 0.00031, fnr: 0.00115, rec: 0.99885, prc: 0.99331, f1: 0.99607, f1_macro: 0.99795
# epoch: 3, passed number of graphs: 480, train running loss: 0.00596 (passed time: 20m 24s)
#           acc: 0.99968, fpr: 0.00032, fnr: 0.00050, rec: 0.99950, prc: 0.99290, f1: 0.99619, f1_macro: 0.99801
# epoch: 3, passed number of graphs: 576, train running loss: 0.00542 (passed time: 21m 13s)
#           acc: 0.99903, fpr: 0.00101, fnr: 0.00000, rec: 1.00000, prc: 0.97767, f1: 0.98871, f1_macro: 0.99410
# epoch: 3, passed number of graphs: 672, train running loss: 0.00525 (passed time: 22m 1s)
#           acc: 0.99468, fpr: 0.00022, fnr: 0.12245, rec: 0.87755, prc: 0.99427, f1: 0.93227, f1_macro: 0.96475
# epoch: 3, passed number of graphs: 768, train running loss: 0.00512 (passed time: 22m 50s)
#           acc: 0.99980, fpr: 0.00013, fnr: 0.00183, rec: 0.99817, prc: 0.99702, f1: 0.99759, f1_macro: 0.99874
# Validation --- epoch: 3, loss: 0.00305
#           acc: 0.99960, rec: 0.98329, f1: 0.98931, fnr: 0.01671, prc: 0.99808, f1_macro: 0.99456, fpr: 0.00004
# Better model saved at ./saved_models/GIN_2: 0.9893144811454738.pt.
# epoch: 4, passed number of graphs: 96, train running loss: 0.00484 (passed time: 24m 14s)
#           acc: 0.99984, fpr: 0.00012, fnr: 0.00097, rec: 0.99903, prc: 0.99725, f1: 0.99814, f1_macro: 0.99903
# epoch: 4, passed number of graphs: 192, train running loss: 0.00455 (passed time: 25m 2s)
#           acc: 0.99974, fpr: 0.00024, fnr: 0.00067, rec: 0.99933, prc: 0.99451, f1: 0.99691, f1_macro: 0.99839
# epoch: 4, passed number of graphs: 288, train running loss: 0.00389 (passed time: 25m 51s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00017, rec: 0.99983, prc: 0.99585, f1: 0.99784, f1_macro: 0.99887
# epoch: 4, passed number of graphs: 384, train running loss: 0.00357 (passed time: 26m 40s)
#           acc: 0.99978, fpr: 0.00022, fnr: 0.00033, rec: 0.99967, prc: 0.99526, f1: 0.99746, f1_macro: 0.99867
# epoch: 4, passed number of graphs: 480, train running loss: 0.00392 (passed time: 27m 28s)
#           acc: 0.99971, fpr: 0.00027, fnr: 0.00066, rec: 0.99934, prc: 0.99388, f1: 0.99660, f1_macro: 0.99823
# epoch: 4, passed number of graphs: 576, train running loss: 0.00366 (passed time: 28m 17s)
#           acc: 0.99965, fpr: 0.00034, fnr: 0.00066, rec: 0.99934, prc: 0.99233, f1: 0.99582, f1_macro: 0.99782
# epoch: 4, passed number of graphs: 672, train running loss: 0.00384 (passed time: 29m 6s)
#           acc: 0.99448, fpr: 0.00024, fnr: 0.12686, rec: 0.87314, prc: 0.99368, f1: 0.92952, f1_macro: 0.96332
# epoch: 4, passed number of graphs: 768, train running loss: 0.00382 (passed time: 29m 55s)
#           acc: 0.99980, fpr: 0.00017, fnr: 0.00100, rec: 0.99900, prc: 0.99619, f1: 0.99760, f1_macro: 0.99875
# Validation --- epoch: 4, loss: 0.00274
#           acc: 0.99957, rec: 0.98321, f1: 0.98860, fnr: 0.01679, prc: 0.99686, f1_macro: 0.99419, fpr: 0.00007
# epoch: 5, passed number of graphs: 96, train running loss: 0.00232 (passed time: 31m 19s)
#           acc: 0.99981, fpr: 0.00019, fnr: 0.00016, rec: 0.99984, prc: 0.99564, f1: 0.99773, f1_macro: 0.99882
# epoch: 5, passed number of graphs: 192, train running loss: 0.00216 (passed time: 32m 7s)
#           acc: 0.99992, fpr: 0.00005, fnr: 0.00084, rec: 0.99916, prc: 0.99883, f1: 0.99900, f1_macro: 0.99948
# epoch: 5, passed number of graphs: 288, train running loss: 0.00351 (passed time: 32m 56s)
#           acc: 0.99965, fpr: 0.00001, fnr: 0.00834, rec: 0.99166, prc: 0.99983, f1: 0.99573, f1_macro: 0.99777
# epoch: 5, passed number of graphs: 384, train running loss: 0.00344 (passed time: 33m 44s)
#           acc: 0.99957, fpr: 0.00043, fnr: 0.00033, rec: 0.99967, prc: 0.99057, f1: 0.99510, f1_macro: 0.99744
# epoch: 5, passed number of graphs: 480, train running loss: 0.00341 (passed time: 34m 33s)
#           acc: 0.99969, fpr: 0.00030, fnr: 0.00050, rec: 0.99950, prc: 0.99323, f1: 0.99636, f1_macro: 0.99810
# epoch: 5, passed number of graphs: 576, train running loss: 0.00300 (passed time: 35m 21s)
#           acc: 0.99960, fpr: 0.00040, fnr: 0.00033, rec: 0.99967, prc: 0.99104, f1: 0.99534, f1_macro: 0.99757
# epoch: 5, passed number of graphs: 672, train running loss: 0.00304 (passed time: 36m 10s)
#           acc: 0.99427, fpr: 0.00006, fnr: 0.13616, rec: 0.86384, prc: 0.99849, f1: 0.92630, f1_macro: 0.96166
# epoch: 5, passed number of graphs: 768, train running loss: 0.00297 (passed time: 36m 59s)
#           acc: 0.99983, fpr: 0.00010, fnr: 0.00183, rec: 0.99817, prc: 0.99784, f1: 0.99801, f1_macro: 0.99896
# Validation --- epoch: 5, loss: 0.00201
#           acc: 0.99968, rec: 0.98657, f1: 0.99147, fnr: 0.01343, prc: 0.99830, f1_macro: 0.99565, fpr: 0.00004
# Better model saved at ./saved_models/GIN_4: 0.9914686070142431.pt.
# epoch: 6, passed number of graphs: 96, train running loss: 0.00163 (passed time: 38m 22s)
#           acc: 0.99948, fpr: 0.00052, fnr: 0.00065, rec: 0.99935, prc: 0.98829, f1: 0.99379, f1_macro: 0.99676
# epoch: 6, passed number of graphs: 192, train running loss: 0.00162 (passed time: 39m 11s)
#           acc: 0.99993, fpr: 0.00006, fnr: 0.00033, rec: 0.99967, prc: 0.99866, f1: 0.99916, f1_macro: 0.99956
# epoch: 6, passed number of graphs: 288, train running loss: 0.00173 (passed time: 39m 59s)
#           acc: 0.99583, fpr: 0.00000, fnr: 0.10212, rec: 0.89788, prc: 1.00000, f1: 0.94619, f1_macro: 0.97201
# epoch: 6, passed number of graphs: 384, train running loss: 0.00180 (passed time: 40m 48s)
#           acc: 0.99979, fpr: 0.00021, fnr: 0.00033, rec: 0.99967, prc: 0.99542, f1: 0.99754, f1_macro: 0.99872
# epoch: 6, passed number of graphs: 480, train running loss: 0.00199 (passed time: 41m 36s)
#           acc: 0.99975, fpr: 0.00024, fnr: 0.00066, rec: 0.99934, prc: 0.99471, f1: 0.99702, f1_macro: 0.99844
# epoch: 6, passed number of graphs: 576, train running loss: 0.00189 (passed time: 42m 25s)
#           acc: 0.99968, fpr: 0.00031, fnr: 0.00066, rec: 0.99934, prc: 0.99314, f1: 0.99623, f1_macro: 0.99803
# epoch: 6, passed number of graphs: 672, train running loss: 0.00193 (passed time: 43m 13s)
#           acc: 0.99925, fpr: 0.00049, fnr: 0.00669, rec: 0.99331, prc: 0.98879, f1: 0.99104, f1_macro: 0.99532
# epoch: 6, passed number of graphs: 768, train running loss: 0.00204 (passed time: 44m 2s)
#           acc: 0.99978, fpr: 0.00005, fnr: 0.00415, rec: 0.99585, prc: 0.99883, f1: 0.99734, f1_macro: 0.99861
# Validation --- epoch: 6, loss: 0.00265
#           acc: 0.99953, rec: 0.97891, f1: 0.98780, fnr: 0.02109, prc: 0.99906, f1_macro: 0.99378, fpr: 0.00002
# epoch: 7, passed number of graphs: 96, train running loss: 0.00183 (passed time: 45m 25s)
#           acc: 0.99782, fpr: 0.00225, fnr: 0.00049, rec: 0.99951, prc: 0.95107, f1: 0.97469, f1_macro: 0.98677
# epoch: 7, passed number of graphs: 192, train running loss: 0.00167 (passed time: 46m 14s)
#           acc: 0.99992, fpr: 0.00005, fnr: 0.00067, rec: 0.99933, prc: 0.99883, f1: 0.99908, f1_macro: 0.99952
# epoch: 7, passed number of graphs: 288, train running loss: 0.00201 (passed time: 47m 2s)
#           acc: 0.99783, fpr: 0.00226, fnr: 0.00017, rec: 0.99983, prc: 0.94960, f1: 0.97407, f1_macro: 0.98647
# epoch: 7, passed number of graphs: 384, train running loss: 0.00333 (passed time: 47m 50s)
#           acc: 0.99978, fpr: 0.00022, fnr: 0.00033, rec: 0.99967, prc: 0.99526, f1: 0.99746, f1_macro: 0.99867
# epoch: 7, passed number of graphs: 480, train running loss: 0.00333 (passed time: 48m 39s)
#           acc: 0.99968, fpr: 0.00030, fnr: 0.00066, rec: 0.99934, prc: 0.99323, f1: 0.99627, f1_macro: 0.99805
# epoch: 7, passed number of graphs: 576, train running loss: 0.00293 (passed time: 49m 27s)
#           acc: 0.99967, fpr: 0.00031, fnr: 0.00099, rec: 0.99901, prc: 0.99314, f1: 0.99607, f1_macro: 0.99795
# epoch: 7, passed number of graphs: 672, train running loss: 0.00286 (passed time: 50m 16s)
#           acc: 0.99928, fpr: 0.00050, fnr: 0.00571, rec: 0.99429, prc: 0.98848, f1: 0.99137, f1_macro: 0.99550
# epoch: 7, passed number of graphs: 768, train running loss: 0.00287 (passed time: 51m 5s)
#           acc: 0.99987, fpr: 0.00012, fnr: 0.00033, rec: 0.99967, prc: 0.99735, f1: 0.99851, f1_macro: 0.99922
# Validation --- epoch: 7, loss: 0.00141
#           acc: 0.99976, rec: 0.99234, f1: 0.99359, fnr: 0.00766, prc: 0.99636, f1_macro: 0.99673, fpr: 0.00008
# Better model saved at ./saved_models/GIN_6: 0.9935939469964441.pt.
# epoch: 8, passed number of graphs: 96, train running loss: 0.00163 (passed time: 52m 28s)
#           acc: 0.99585, fpr: 0.00432, fnr: 0.00032, rec: 0.99968, prc: 0.91033, f1: 0.95291, f1_macro: 0.97537
# epoch: 8, passed number of graphs: 192, train running loss: 0.00145 (passed time: 53m 16s)
#           acc: 0.99985, fpr: 0.00002, fnr: 0.00301, rec: 0.99699, prc: 0.99950, f1: 0.99824, f1_macro: 0.99908
# epoch: 8, passed number of graphs: 288, train running loss: 0.00218 (passed time: 54m 5s)
#           acc: 0.99360, fpr: 0.00000, fnr: 0.15668, rec: 0.84332, prc: 1.00000, f1: 0.91500, f1_macro: 0.95584
# epoch: 8, passed number of graphs: 384, train running loss: 0.00212 (passed time: 54m 53s)
#           acc: 0.99981, fpr: 0.00018, fnr: 0.00033, rec: 0.99967, prc: 0.99608, f1: 0.99787, f1_macro: 0.99889
# epoch: 8, passed number of graphs: 480, train running loss: 0.00227 (passed time: 55m 42s)
#           acc: 0.99975, fpr: 0.00024, fnr: 0.00050, rec: 0.99950, prc: 0.99471, f1: 0.99710, f1_macro: 0.99848
# epoch: 8, passed number of graphs: 576, train running loss: 0.00202 (passed time: 56m 31s)
#           acc: 0.99966, fpr: 0.00033, fnr: 0.00066, rec: 0.99934, prc: 0.99266, f1: 0.99599, f1_macro: 0.99790
# epoch: 8, passed number of graphs: 672, train running loss: 0.00196 (passed time: 57m 19s)
#           acc: 0.99914, fpr: 0.00080, fnr: 0.00245, rec: 0.99755, prc: 0.98200, f1: 0.98971, f1_macro: 0.99463
# epoch: 8, passed number of graphs: 768, train running loss: 0.00203 (passed time: 58m 8s)
#           acc: 0.99983, fpr: 0.00007, fnr: 0.00232, rec: 0.99768, prc: 0.99834, f1: 0.99801, f1_macro: 0.99896
# Validation --- epoch: 8, loss: 0.00236
#           acc: 0.99962, rec: 0.98371, f1: 0.99020, fnr: 0.01629, prc: 0.99850, f1_macro: 0.99500, fpr: 0.00003
# epoch: 9, passed number of graphs: 96, train running loss: 0.00133 (passed time: 59m 31s)
#           acc: 0.99579, fpr: 0.00437, fnr: 0.00065, rec: 0.99935, prc: 0.90936, f1: 0.95223, f1_macro: 0.97502
# epoch: 9, passed number of graphs: 192, train running loss: 0.00129 (passed time: 1h 0m 20s)
#           acc: 0.99985, fpr: 0.00003, fnr: 0.00301, rec: 0.99699, prc: 0.99933, f1: 0.99816, f1_macro: 0.99904
# epoch: 9, passed number of graphs: 288, train running loss: 0.00151 (passed time: 1h 1m 8s)
#           acc: 0.99976, fpr: 0.00013, fnr: 0.00267, rec: 0.99733, prc: 0.99683, f1: 0.99708, f1_macro: 0.99848
# epoch: 9, passed number of graphs: 384, train running loss: 0.00161 (passed time: 1h 1m 58s)
#           acc: 0.99980, fpr: 0.00019, fnr: 0.00033, rec: 0.99967, prc: 0.99575, f1: 0.99771, f1_macro: 0.99880
# epoch: 9, passed number of graphs: 480, train running loss: 0.00172 (passed time: 1h 2m 47s)
#           acc: 0.99970, fpr: 0.00029, fnr: 0.00050, rec: 0.99950, prc: 0.99356, f1: 0.99652, f1_macro: 0.99818
# epoch: 9, passed number of graphs: 576, train running loss: 0.00160 (passed time: 1h 3m 36s)
#           acc: 0.99965, fpr: 0.00033, fnr: 0.00082, rec: 0.99918, prc: 0.99249, f1: 0.99582, f1_macro: 0.99782
# epoch: 9, passed number of graphs: 672, train running loss: 0.00179 (passed time: 1h 4m 25s)
#           acc: 0.99916, fpr: 0.00048, fnr: 0.00931, rec: 0.99069, prc: 0.98908, f1: 0.98989, f1_macro: 0.99472
# epoch: 9, passed number of graphs: 768, train running loss: 0.00207 (passed time: 1h 5m 14s)
#           acc: 0.99984, fpr: 0.00009, fnr: 0.00183, rec: 0.99817, prc: 0.99801, f1: 0.99809, f1_macro: 0.99900
# Validation --- epoch: 9, loss: 0.00208
#           acc: 0.99964, rec: 0.98795, f1: 0.99073, fnr: 0.01205, prc: 0.99541, f1_macro: 0.99527, fpr: 0.00010
# epoch: 10, passed number of graphs: 96, train running loss: 0.00184 (passed time: 1h 6m 37s)
#           acc: 0.99993, fpr: 0.00005, fnr: 0.00049, rec: 0.99951, prc: 0.99887, f1: 0.99919, f1_macro: 0.99958
# epoch: 10, passed number of graphs: 192, train running loss: 0.00152 (passed time: 1h 7m 26s)
#           acc: 0.99989, fpr: 0.00004, fnr: 0.00184, rec: 0.99816, prc: 0.99916, f1: 0.99866, f1_macro: 0.99930
# epoch: 10, passed number of graphs: 288, train running loss: 0.00132 (passed time: 1h 8m 15s)
#           acc: 0.99987, fpr: 0.00011, fnr: 0.00050, rec: 0.99950, prc: 0.99734, f1: 0.99842, f1_macro: 0.99917
# epoch: 10, passed number of graphs: 384, train running loss: 0.00127 (passed time: 1h 9m 4s)
#           acc: 0.99984, fpr: 0.00009, fnr: 0.00181, rec: 0.99819, prc: 0.99803, f1: 0.99811, f1_macro: 0.99901
# epoch: 10, passed number of graphs: 480, train running loss: 0.00129 (passed time: 1h 9m 52s)
#           acc: 0.99977, fpr: 0.00019, fnr: 0.00100, rec: 0.99900, prc: 0.99569, f1: 0.99735, f1_macro: 0.99861
# epoch: 10, passed number of graphs: 576, train running loss: 0.00120 (passed time: 1h 10m 41s)
#           acc: 0.99967, fpr: 0.00029, fnr: 0.00131, rec: 0.99869, prc: 0.99346, f1: 0.99607, f1_macro: 0.99795
# epoch: 10, passed number of graphs: 672, train running loss: 0.00117 (passed time: 1h 11m 30s)
#           acc: 0.99920, fpr: 0.00071, fnr: 0.00294, rec: 0.99706, prc: 0.98389, f1: 0.99043, f1_macro: 0.99501
# epoch: 10, passed number of graphs: 768, train running loss: 0.00121 (passed time: 1h 12m 19s)
#           acc: 0.99987, fpr: 0.00012, fnr: 0.00033, rec: 0.99967, prc: 0.99735, f1: 0.99851, f1_macro: 0.99922
# Validation --- epoch: 10, loss: 0.00088
#           acc: 0.99977, rec: 0.99228, f1: 0.99402, fnr: 0.00772, prc: 0.99727, f1_macro: 0.99695, fpr: 0.00006
# Better model saved at ./saved_models/GIN_9: 0.9940217860537278.pt.
# epoch: 11, passed number of graphs: 96, train running loss: 0.00118 (passed time: 1h 13m 44s)
#           acc: 0.99973, fpr: 0.00026, fnr: 0.00065, rec: 0.99935, prc: 0.99419, f1: 0.99676, f1_macro: 0.99831
# epoch: 11, passed number of graphs: 192, train running loss: 0.00115 (passed time: 1h 14m 33s)
#           acc: 0.99976, fpr: 0.00001, fnr: 0.00552, rec: 0.99448, prc: 0.99983, f1: 0.99715, f1_macro: 0.99851
# epoch: 11, passed number of graphs: 288, train running loss: 0.00104 (passed time: 1h 15m 21s)
#           acc: 0.99984, fpr: 0.00011, fnr: 0.00133, rec: 0.99867, prc: 0.99750, f1: 0.99808, f1_macro: 0.99900
# epoch: 11, passed number of graphs: 384, train running loss: 0.00104 (passed time: 1h 16m 10s)
#           acc: 0.99982, fpr: 0.00011, fnr: 0.00164, rec: 0.99836, prc: 0.99754, f1: 0.99795, f1_macro: 0.99893
# epoch: 11, passed number of graphs: 480, train running loss: 0.00111 (passed time: 1h 16m 59s)
#           acc: 0.99973, fpr: 0.00024, fnr: 0.00100, rec: 0.99900, prc: 0.99454, f1: 0.99677, f1_macro: 0.99831
# epoch: 11, passed number of graphs: 576, train running loss: 0.00105 (passed time: 1h 17m 48s)
#           acc: 0.99965, fpr: 0.00029, fnr: 0.00164, rec: 0.99836, prc: 0.99346, f1: 0.99590, f1_macro: 0.99786
# epoch: 11, passed number of graphs: 672, train running loss: 0.00106 (passed time: 1h 18m 37s)
#           acc: 0.99914, fpr: 0.00087, fnr: 0.00065, rec: 0.99935, prc: 0.98046, f1: 0.98981, f1_macro: 0.99468
# epoch: 11, passed number of graphs: 768, train running loss: 0.00113 (passed time: 1h 19m 26s)
#           acc: 0.99988, fpr: 0.00012, fnr: 0.00017, rec: 0.99983, prc: 0.99735, f1: 0.99859, f1_macro: 0.99926
# Validation --- epoch: 11, loss: 0.00097
#           acc: 0.99976, rec: 0.99265, f1: 0.99376, fnr: 0.00735, prc: 0.99638, f1_macro: 0.99682, fpr: 0.00008
# epoch: 12, passed number of graphs: 96, train running loss: 0.00118 (passed time: 1h 20m 51s)
#           acc: 0.99899, fpr: 0.00105, fnr: 0.00032, rec: 0.99968, prc: 0.97670, f1: 0.98805, f1_macro: 0.99376
# epoch: 12, passed number of graphs: 192, train running loss: 0.00116 (passed time: 1h 21m 40s)
#           acc: 0.99975, fpr: 0.00001, fnr: 0.00585, rec: 0.99415, prc: 0.99983, f1: 0.99698, f1_macro: 0.99843
# epoch: 12, passed number of graphs: 288, train running loss: 0.00107 (passed time: 1h 22m 29s)
#           acc: 0.99985, fpr: 0.00009, fnr: 0.00150, rec: 0.99850, prc: 0.99783, f1: 0.99817, f1_macro: 0.99904
# epoch: 12, passed number of graphs: 384, train running loss: 0.00108 (passed time: 1h 23m 17s)
#           acc: 0.99984, fpr: 0.00011, fnr: 0.00131, rec: 0.99869, prc: 0.99754, f1: 0.99811, f1_macro: 0.99901
# epoch: 12, passed number of graphs: 480, train running loss: 0.00110 (passed time: 1h 24m 6s)
#           acc: 0.99977, fpr: 0.00018, fnr: 0.00116, rec: 0.99884, prc: 0.99586, f1: 0.99734, f1_macro: 0.99861
# epoch: 12, passed number of graphs: 576, train running loss: 0.00106 (passed time: 1h 24m 55s)
#           acc: 0.99963, fpr: 0.00036, fnr: 0.00066, rec: 0.99934, prc: 0.99201, f1: 0.99566, f1_macro: 0.99773
# epoch: 12, passed number of graphs: 672, train running loss: 0.00109 (passed time: 1h 25m 45s)
#           acc: 0.99899, fpr: 0.00105, fnr: 0.00000, rec: 1.00000, prc: 0.97641, f1: 0.98806, f1_macro: 0.99377
# epoch: 12, passed number of graphs: 768, train running loss: 0.00118 (passed time: 1h 26m 33s)
#           acc: 0.99989, fpr: 0.00012, fnr: 0.00000, rec: 1.00000, prc: 0.99735, f1: 0.99867, f1_macro: 0.99931
# Validation --- epoch: 12, loss: 0.00092
#           acc: 0.99976, rec: 0.99327, f1: 0.99386, fnr: 0.00673, prc: 0.99577, f1_macro: 0.99687, fpr: 0.00009
# epoch: 13, passed number of graphs: 96, train running loss: 0.00124 (passed time: 1h 27m 57s)
#           acc: 0.99990, fpr: 0.00009, fnr: 0.00049, rec: 0.99951, prc: 0.99806, f1: 0.99878, f1_macro: 0.99937
# epoch: 13, passed number of graphs: 192, train running loss: 0.00110 (passed time: 1h 28m 46s)
#           acc: 0.99989, fpr: 0.00003, fnr: 0.00201, rec: 0.99799, prc: 0.99933, f1: 0.99866, f1_macro: 0.99930
# epoch: 13, passed number of graphs: 288, train running loss: 0.00095 (passed time: 1h 29m 35s)
#           acc: 0.99986, fpr: 0.00011, fnr: 0.00083, rec: 0.99917, prc: 0.99734, f1: 0.99825, f1_macro: 0.99909
# epoch: 13, passed number of graphs: 384, train running loss: 0.00094 (passed time: 1h 30m 24s)
#           acc: 0.99982, fpr: 0.00012, fnr: 0.00148, rec: 0.99852, prc: 0.99738, f1: 0.99795, f1_macro: 0.99893
# epoch: 13, passed number of graphs: 480, train running loss: 0.00099 (passed time: 1h 31m 13s)
#           acc: 0.99981, fpr: 0.00015, fnr: 0.00100, rec: 0.99900, prc: 0.99652, f1: 0.99776, f1_macro: 0.99883
# epoch: 13, passed number of graphs: 576, train running loss: 0.00094 (passed time: 1h 32m 2s)
#           acc: 0.99966, fpr: 0.00030, fnr: 0.00131, rec: 0.99869, prc: 0.99330, f1: 0.99599, f1_macro: 0.99790
# epoch: 13, passed number of graphs: 672, train running loss: 0.00093 (passed time: 1h 32m 51s)
#           acc: 0.99919, fpr: 0.00079, fnr: 0.00131, rec: 0.99869, prc: 0.98218, f1: 0.99037, f1_macro: 0.99497
# epoch: 13, passed number of graphs: 768, train running loss: 0.00098 (passed time: 1h 33m 40s)
#           acc: 0.99987, fpr: 0.00012, fnr: 0.00050, rec: 0.99950, prc: 0.99735, f1: 0.99842, f1_macro: 0.99918
# Validation --- epoch: 13, loss: 0.00091
#           acc: 0.99977, rec: 0.99245, f1: 0.99393, fnr: 0.00755, prc: 0.99692, f1_macro: 0.99691, fpr: 0.00007
# epoch: 14, passed number of graphs: 96, train running loss: 0.00112 (passed time: 1h 35m 4s)
#           acc: 0.99989, fpr: 0.00010, fnr: 0.00032, rec: 0.99968, prc: 0.99773, f1: 0.99870, f1_macro: 0.99932
# epoch: 14, passed number of graphs: 192, train running loss: 0.00108 (passed time: 1h 35m 53s)
#           acc: 0.99987, fpr: 0.00001, fnr: 0.00284, rec: 0.99716, prc: 0.99983, f1: 0.99849, f1_macro: 0.99921
# epoch: 14, passed number of graphs: 288, train running loss: 0.00095 (passed time: 1h 36m 41s)
#           acc: 0.99986, fpr: 0.00012, fnr: 0.00050, rec: 0.99950, prc: 0.99717, f1: 0.99833, f1_macro: 0.99913
# epoch: 14, passed number of graphs: 384, train running loss: 0.00096 (passed time: 1h 37m 30s)
#           acc: 0.99982, fpr: 0.00010, fnr: 0.00181, rec: 0.99819, prc: 0.99770, f1: 0.99795, f1_macro: 0.99893
# epoch: 14, passed number of graphs: 480, train running loss: 0.00102 (passed time: 1h 38m 20s)
#           acc: 0.99978, fpr: 0.00018, fnr: 0.00100, rec: 0.99900, prc: 0.99586, f1: 0.99743, f1_macro: 0.99866
# epoch: 14, passed number of graphs: 576, train running loss: 0.00096 (passed time: 1h 39m 9s)
#           acc: 0.99966, fpr: 0.00031, fnr: 0.00115, rec: 0.99885, prc: 0.99314, f1: 0.99599, f1_macro: 0.99790
# epoch: 14, passed number of graphs: 672, train running loss: 0.00096 (passed time: 1h 39m 57s)
#           acc: 0.99916, fpr: 0.00079, fnr: 0.00196, rec: 0.99804, prc: 0.98217, f1: 0.99004, f1_macro: 0.99480
# epoch: 14, passed number of graphs: 768, train running loss: 0.00102 (passed time: 1h 40m 46s)
#           acc: 0.99987, fpr: 0.00012, fnr: 0.00033, rec: 0.99967, prc: 0.99735, f1: 0.99851, f1_macro: 0.99922
# Validation --- epoch: 14, loss: 0.00084
#           acc: 0.99977, rec: 0.99248, f1: 0.99395, fnr: 0.00752, prc: 0.99694, f1_macro: 0.99692, fpr: 0.00007
# epoch: 15, passed number of graphs: 96, train running loss: 0.00110 (passed time: 1h 42m 10s)
#           acc: 0.99988, fpr: 0.00010, fnr: 0.00065, rec: 0.99935, prc: 0.99773, f1: 0.99854, f1_macro: 0.99924
# epoch: 15, passed number of graphs: 192, train running loss: 0.00107 (passed time: 1h 42m 59s)
#           acc: 0.99981, fpr: 0.00001, fnr: 0.00452, rec: 0.99548, prc: 0.99983, f1: 0.99765, f1_macro: 0.99878
# epoch: 15, passed number of graphs: 288, train running loss: 0.00095 (passed time: 1h 43m 48s)
#           acc: 0.99986, fpr: 0.00012, fnr: 0.00067, rec: 0.99933, prc: 0.99717, f1: 0.99825, f1_macro: 0.99909
# epoch: 15, passed number of graphs: 384, train running loss: 0.00097 (passed time: 1h 44m 36s)
#           acc: 0.99981, fpr: 0.00010, fnr: 0.00213, rec: 0.99787, prc: 0.99770, f1: 0.99778, f1_macro: 0.99884
# epoch: 15, passed number of graphs: 480, train running loss: 0.00102 (passed time: 1h 45m 25s)
#           acc: 0.99980, fpr: 0.00016, fnr: 0.00116, rec: 0.99884, prc: 0.99635, f1: 0.99759, f1_macro: 0.99874
# epoch: 15, passed number of graphs: 576, train running loss: 0.00096 (passed time: 1h 46m 14s)
#           acc: 0.99967, fpr: 0.00030, fnr: 0.00115, rec: 0.99885, prc: 0.99330, f1: 0.99607, f1_macro: 0.99795
# epoch: 15, passed number of graphs: 672, train running loss: 0.00096 (passed time: 1h 47m 3s)
#           acc: 0.99918, fpr: 0.00077, fnr: 0.00196, rec: 0.99804, prc: 0.98264, f1: 0.99028, f1_macro: 0.99493
# epoch: 15, passed number of graphs: 768, train running loss: 0.00102 (passed time: 1h 47m 52s)
#           acc: 0.99987, fpr: 0.00012, fnr: 0.00033, rec: 0.99967, prc: 0.99735, f1: 0.99851, f1_macro: 0.99922
# Validation --- epoch: 15, loss: 0.00083
#           acc: 0.99977, rec: 0.99237, f1: 0.99397, fnr: 0.00763, prc: 0.99708, f1_macro: 0.99693, fpr: 0.00006
# epoch: 16, passed number of graphs: 96, train running loss: 0.00107 (passed time: 1h 49m 15s)
#           acc: 0.99989, fpr: 0.00010, fnr: 0.00032, rec: 0.99968, prc: 0.99773, f1: 0.99870, f1_macro: 0.99932
# epoch: 16, passed number of graphs: 192, train running loss: 0.00107 (passed time: 1h 50m 4s)
#           acc: 0.99981, fpr: 0.00001, fnr: 0.00452, rec: 0.99548, prc: 0.99983, f1: 0.99765, f1_macro: 0.99878
# epoch: 16, passed number of graphs: 288, train running loss: 0.00095 (passed time: 1h 50m 52s)
#           acc: 0.99986, fpr: 0.00012, fnr: 0.00067, rec: 0.99933, prc: 0.99717, f1: 0.99825, f1_macro: 0.99909
# epoch: 16, passed number of graphs: 384, train running loss: 0.00097 (passed time: 1h 51m 41s)
#           acc: 0.99981, fpr: 0.00010, fnr: 0.00213, rec: 0.99787, prc: 0.99770, f1: 0.99778, f1_macro: 0.99884
# epoch: 16, passed number of graphs: 480, train running loss: 0.00102 (passed time: 1h 52m 30s)
#           acc: 0.99980, fpr: 0.00016, fnr: 0.00116, rec: 0.99884, prc: 0.99635, f1: 0.99759, f1_macro: 0.99874
# epoch: 16, passed number of graphs: 576, train running loss: 0.00097 (passed time: 1h 53m 19s)
#           acc: 0.99967, fpr: 0.00030, fnr: 0.00099, rec: 0.99901, prc: 0.99330, f1: 0.99615, f1_macro: 0.99799
# epoch: 16, passed number of graphs: 672, train running loss: 0.00096 (passed time: 1h 54m 8s)
#           acc: 0.99918, fpr: 0.00076, fnr: 0.00212, rec: 0.99788, prc: 0.98279, f1: 0.99028, f1_macro: 0.99493
# epoch: 16, passed number of graphs: 768, train running loss: 0.00103 (passed time: 1h 54m 57s)
#           acc: 0.99987, fpr: 0.00012, fnr: 0.00033, rec: 0.99967, prc: 0.99735, f1: 0.99851, f1_macro: 0.99922
# Validation --- epoch: 16, loss: 0.00079
#           acc: 0.99977, rec: 0.99230, f1: 0.99400, fnr: 0.00770, prc: 0.99722, f1_macro: 0.99694, fpr: 0.00006
# epoch: 17, passed number of graphs: 96, train running loss: 0.00107 (passed time: 1h 56m 21s)
#           acc: 0.99988, fpr: 0.00011, fnr: 0.00032, rec: 0.99968, prc: 0.99757, f1: 0.99862, f1_macro: 0.99928
# epoch: 17, passed number of graphs: 192, train running loss: 0.00106 (passed time: 1h 57m 9s)
#           acc: 0.99981, fpr: 0.00001, fnr: 0.00452, rec: 0.99548, prc: 0.99983, f1: 0.99765, f1_macro: 0.99878
# epoch: 17, passed number of graphs: 288, train running loss: 0.00095 (passed time: 1h 57m 59s)
#           acc: 0.99986, fpr: 0.00012, fnr: 0.00067, rec: 0.99933, prc: 0.99717, f1: 0.99825, f1_macro: 0.99909
# epoch: 17, passed number of graphs: 384, train running loss: 0.00097 (passed time: 1h 58m 47s)
#           acc: 0.99981, fpr: 0.00011, fnr: 0.00197, rec: 0.99803, prc: 0.99754, f1: 0.99778, f1_macro: 0.99884
# epoch: 17, passed number of graphs: 480, train running loss: 0.00102 (passed time: 1h 59m 36s)
#           acc: 0.99979, fpr: 0.00017, fnr: 0.00116, rec: 0.99884, prc: 0.99619, f1: 0.99751, f1_macro: 0.99870
# epoch: 17, passed number of graphs: 576, train running loss: 0.00096 (passed time: 2h 0m 25s)
#           acc: 0.99967, fpr: 0.00030, fnr: 0.00099, rec: 0.99901, prc: 0.99330, f1: 0.99615, f1_macro: 0.99799
# epoch: 17, passed number of graphs: 672, train running loss: 0.00096 (passed time: 2h 1m 13s)
#           acc: 0.99917, fpr: 0.00078, fnr: 0.00196, rec: 0.99804, prc: 0.98232, f1: 0.99012, f1_macro: 0.99484
# epoch: 17, passed number of graphs: 768, train running loss: 0.00104 (passed time: 2h 2m 2s)
#           acc: 0.99988, fpr: 0.00011, fnr: 0.00033, rec: 0.99967, prc: 0.99752, f1: 0.99859, f1_macro: 0.99926
# Validation --- epoch: 17, loss: 0.00079
#           acc: 0.99978, rec: 0.99217, f1: 0.99403, fnr: 0.00783, prc: 0.99739, f1_macro: 0.99696, fpr: 0.00006
# Better model saved at ./saved_models/GIN_16: 0.9940259312519039.pt.
# epoch: 18, passed number of graphs: 96, train running loss: 0.00106 (passed time: 2h 3m 26s)
#           acc: 0.99986, fpr: 0.00013, fnr: 0.00032, rec: 0.99968, prc: 0.99709, f1: 0.99838, f1_macro: 0.99915
# epoch: 18, passed number of graphs: 192, train running loss: 0.00106 (passed time: 2h 4m 15s)
#           acc: 0.99978, fpr: 0.00001, fnr: 0.00502, rec: 0.99498, prc: 0.99983, f1: 0.99740, f1_macro: 0.99864
# epoch: 18, passed number of graphs: 288, train running loss: 0.00095 (passed time: 2h 5m 3s)
#           acc: 0.99986, fpr: 0.00012, fnr: 0.00067, rec: 0.99933, prc: 0.99717, f1: 0.99825, f1_macro: 0.99909
# epoch: 18, passed number of graphs: 384, train running loss: 0.00097 (passed time: 2h 5m 52s)
#           acc: 0.99981, fpr: 0.00011, fnr: 0.00181, rec: 0.99819, prc: 0.99754, f1: 0.99787, f1_macro: 0.99889
# epoch: 18, passed number of graphs: 480, train running loss: 0.00102 (passed time: 2h 6m 41s)
#           acc: 0.99977, fpr: 0.00020, fnr: 0.00100, rec: 0.99900, prc: 0.99553, f1: 0.99726, f1_macro: 0.99857
# epoch: 18, passed number of graphs: 576, train running loss: 0.00097 (passed time: 2h 7m 30s)
#           acc: 0.99967, fpr: 0.00029, fnr: 0.00115, rec: 0.99885, prc: 0.99346, f1: 0.99615, f1_macro: 0.99799
# epoch: 18, passed number of graphs: 672, train running loss: 0.00097 (passed time: 2h 8m 18s)
#           acc: 0.99916, fpr: 0.00080, fnr: 0.00180, rec: 0.99820, prc: 0.98185, f1: 0.98996, f1_macro: 0.99476
# epoch: 18, passed number of graphs: 768, train running loss: 0.00104 (passed time: 2h 9m 8s)
#           acc: 0.99987, fpr: 0.00012, fnr: 0.00033, rec: 0.99967, prc: 0.99735, f1: 0.99851, f1_macro: 0.99922
# Validation --- epoch: 18, loss: 0.00079
#           acc: 0.99978, rec: 0.99222, f1: 0.99403, fnr: 0.00778, prc: 0.99734, f1_macro: 0.99696, fpr: 0.00006
# Better model saved at ./saved_models/GIN_17: 0.9940263008327985.pt.
# epoch: 19, passed number of graphs: 96, train running loss: 0.00107 (passed time: 2h 10m 31s)
#           acc: 0.99989, fpr: 0.00010, fnr: 0.00032, rec: 0.99968, prc: 0.99773, f1: 0.99870, f1_macro: 0.99932
# epoch: 19, passed number of graphs: 192, train running loss: 0.00106 (passed time: 2h 11m 20s)
#           acc: 0.99977, fpr: 0.00001, fnr: 0.00535, rec: 0.99465, prc: 0.99983, f1: 0.99723, f1_macro: 0.99856
# epoch: 19, passed number of graphs: 288, train running loss: 0.00095 (passed time: 2h 12m 9s)
#           acc: 0.99986, fpr: 0.00012, fnr: 0.00067, rec: 0.99933, prc: 0.99717, f1: 0.99825, f1_macro: 0.99909
# epoch: 19, passed number of graphs: 384, train running loss: 0.00097 (passed time: 2h 12m 57s)
#           acc: 0.99981, fpr: 0.00011, fnr: 0.00181, rec: 0.99819, prc: 0.99754, f1: 0.99787, f1_macro: 0.99889
# epoch: 19, passed number of graphs: 480, train running loss: 0.00101 (passed time: 2h 13m 46s)
#           acc: 0.99979, fpr: 0.00017, fnr: 0.00116, rec: 0.99884, prc: 0.99619, f1: 0.99751, f1_macro: 0.99870
# epoch: 19, passed number of graphs: 576, train running loss: 0.00096 (passed time: 2h 14m 35s)
#           acc: 0.99968, fpr: 0.00030, fnr: 0.00082, rec: 0.99918, prc: 0.99330, f1: 0.99623, f1_macro: 0.99803
# epoch: 19, passed number of graphs: 672, train running loss: 0.00096 (passed time: 2h 15m 24s)
#           acc: 0.99915, fpr: 0.00084, fnr: 0.00114, rec: 0.99886, prc: 0.98108, f1: 0.98989, f1_macro: 0.99472
# epoch: 19, passed number of graphs: 768, train running loss: 0.00104 (passed time: 2h 16m 13s)
#           acc: 0.99987, fpr: 0.00012, fnr: 0.00033, rec: 0.99967, prc: 0.99735, f1: 0.99851, f1_macro: 0.99922
# Validation --- epoch: 19, loss: 0.00085
#           acc: 0.99977, rec: 0.99242, f1: 0.99392, fnr: 0.00758, prc: 0.99693, f1_macro: 0.99690, fpr: 0.00007
# epoch: 20, passed number of graphs: 96, train running loss: 0.00106 (passed time: 2h 17m 37s)
#           acc: 0.99987, fpr: 0.00012, fnr: 0.00032, rec: 0.99968, prc: 0.99725, f1: 0.99846, f1_macro: 0.99920
# epoch: 20, passed number of graphs: 192, train running loss: 0.00107 (passed time: 2h 18m 25s)
#           acc: 0.99978, fpr: 0.00000, fnr: 0.00535, rec: 0.99465, prc: 1.00000, f1: 0.99732, f1_macro: 0.99860
# epoch: 20, passed number of graphs: 288, train running loss: 0.00095 (passed time: 2h 19m 14s)
#           acc: 0.99986, fpr: 0.00012, fnr: 0.00067, rec: 0.99933, prc: 0.99717, f1: 0.99825, f1_macro: 0.99909
# epoch: 20, passed number of graphs: 384, train running loss: 0.00097 (passed time: 2h 20m 3s)
#           acc: 0.99981, fpr: 0.00011, fnr: 0.00181, rec: 0.99819, prc: 0.99754, f1: 0.99787, f1_macro: 0.99889
# epoch: 20, passed number of graphs: 480, train running loss: 0.00101 (passed time: 2h 20m 52s)
#           acc: 0.99978, fpr: 0.00018, fnr: 0.00116, rec: 0.99884, prc: 0.99602, f1: 0.99743, f1_macro: 0.99866
# epoch: 20, passed number of graphs: 576, train running loss: 0.00096 (passed time: 2h 21m 40s)
#           acc: 0.99968, fpr: 0.00030, fnr: 0.00082, rec: 0.99918, prc: 0.99330, f1: 0.99623, f1_macro: 0.99803
# epoch: 20, passed number of graphs: 672, train running loss: 0.00096 (passed time: 2h 22m 29s)
#           acc: 0.99914, fpr: 0.00085, fnr: 0.00114, rec: 0.99886, prc: 0.98076, f1: 0.98973, f1_macro: 0.99464
# epoch: 20, passed number of graphs: 768, train running loss: 0.00104 (passed time: 2h 23m 18s)
#           acc: 0.99987, fpr: 0.00012, fnr: 0.00050, rec: 0.99950, prc: 0.99735, f1: 0.99842, f1_macro: 0.99918
# Validation --- epoch: 20, loss: 0.00083
#           acc: 0.99977, rec: 0.99225, f1: 0.99394, fnr: 0.00775, prc: 0.99714, f1_macro: 0.99691, fpr: 0.00006
# epoch: 21, passed number of graphs: 96, train running loss: 0.00101 (passed time: 2h 24m 43s)
#           acc: 0.99989, fpr: 0.00009, fnr: 0.00049, rec: 0.99951, prc: 0.99789, f1: 0.99870, f1_macro: 0.99932
# epoch: 21, passed number of graphs: 192, train running loss: 0.00098 (passed time: 2h 25m 32s)
#           acc: 0.99989, fpr: 0.00001, fnr: 0.00251, rec: 0.99749, prc: 0.99983, f1: 0.99866, f1_macro: 0.99930
# epoch: 21, passed number of graphs: 288, train running loss: 0.00087 (passed time: 2h 26m 21s)
#           acc: 0.99984, fpr: 0.00011, fnr: 0.00117, rec: 0.99883, prc: 0.99733, f1: 0.99808, f1_macro: 0.99900
# epoch: 21, passed number of graphs: 384, train running loss: 0.00089 (passed time: 2h 27m 10s)
#           acc: 0.99985, fpr: 0.00013, fnr: 0.00066, rec: 0.99934, prc: 0.99722, f1: 0.99828, f1_macro: 0.99910
# epoch: 21, passed number of graphs: 480, train running loss: 0.00092 (passed time: 2h 27m 59s)
#           acc: 0.99980, fpr: 0.00015, fnr: 0.00116, rec: 0.99884, prc: 0.99652, f1: 0.99768, f1_macro: 0.99879
# epoch: 21, passed number of graphs: 576, train running loss: 0.00088 (passed time: 2h 28m 48s)
#           acc: 0.99967, fpr: 0.00029, fnr: 0.00131, rec: 0.99869, prc: 0.99346, f1: 0.99607, f1_macro: 0.99795
# epoch: 21, passed number of graphs: 672, train running loss: 0.00087 (passed time: 2h 29m 37s)
#           acc: 0.99917, fpr: 0.00082, fnr: 0.00114, rec: 0.99886, prc: 0.98155, f1: 0.99013, f1_macro: 0.99485
# epoch: 21, passed number of graphs: 768, train running loss: 0.00092 (passed time: 2h 30m 26s)
#           acc: 0.99988, fpr: 0.00012, fnr: 0.00017, rec: 0.99983, prc: 0.99735, f1: 0.99859, f1_macro: 0.99926
# Validation --- epoch: 21, loss: 0.00087
#           acc: 0.99977, rec: 0.99252, f1: 0.99389, fnr: 0.00748, prc: 0.99678, f1_macro: 0.99689, fpr: 0.00007
# epoch: 22, passed number of graphs: 96, train running loss: 0.00106 (passed time: 2h 31m 50s)
#           acc: 0.99988, fpr: 0.00010, fnr: 0.00049, rec: 0.99951, prc: 0.99773, f1: 0.99862, f1_macro: 0.99928
# epoch: 22, passed number of graphs: 192, train running loss: 0.00101 (passed time: 2h 32m 39s)
#           acc: 0.99986, fpr: 0.00001, fnr: 0.00301, rec: 0.99699, prc: 0.99966, f1: 0.99833, f1_macro: 0.99913
# epoch: 22, passed number of graphs: 288, train running loss: 0.00090 (passed time: 2h 33m 28s)
#           acc: 0.99984, fpr: 0.00011, fnr: 0.00133, rec: 0.99867, prc: 0.99733, f1: 0.99800, f1_macro: 0.99896
# epoch: 22, passed number of graphs: 384, train running loss: 0.00091 (passed time: 2h 34m 16s)
#           acc: 0.99984, fpr: 0.00013, fnr: 0.00082, rec: 0.99918, prc: 0.99705, f1: 0.99811, f1_macro: 0.99901
# epoch: 22, passed number of graphs: 480, train running loss: 0.00095 (passed time: 2h 35m 6s)
#           acc: 0.99980, fpr: 0.00015, fnr: 0.00116, rec: 0.99884, prc: 0.99652, f1: 0.99768, f1_macro: 0.99879
# epoch: 22, passed number of graphs: 576, train running loss: 0.00090 (passed time: 2h 35m 55s)
#           acc: 0.99967, fpr: 0.00029, fnr: 0.00131, rec: 0.99869, prc: 0.99346, f1: 0.99607, f1_macro: 0.99795
# epoch: 22, passed number of graphs: 672, train running loss: 0.00089 (passed time: 2h 36m 43s)
#           acc: 0.99916, fpr: 0.00083, fnr: 0.00114, rec: 0.99886, prc: 0.98123, f1: 0.98997, f1_macro: 0.99476
# epoch: 22, passed number of graphs: 768, train running loss: 0.00094 (passed time: 2h 37m 32s)
#           acc: 0.99988, fpr: 0.00012, fnr: 0.00017, rec: 0.99983, prc: 0.99735, f1: 0.99859, f1_macro: 0.99926
# Validation --- epoch: 22, loss: 0.00087
#           acc: 0.99977, rec: 0.99253, f1: 0.99388, fnr: 0.00747, prc: 0.99675, f1_macro: 0.99688, fpr: 0.00007
# epoch: 23, passed number of graphs: 96, train running loss: 0.00104 (passed time: 2h 38m 56s)
#           acc: 0.99988, fpr: 0.00010, fnr: 0.00049, rec: 0.99951, prc: 0.99773, f1: 0.99862, f1_macro: 0.99928
# epoch: 23, passed number of graphs: 192, train running loss: 0.00099 (passed time: 2h 39m 45s)
#           acc: 0.99987, fpr: 0.00000, fnr: 0.00301, rec: 0.99699, prc: 1.00000, f1: 0.99849, f1_macro: 0.99921
# epoch: 23, passed number of graphs: 288, train running loss: 0.00089 (passed time: 2h 40m 34s)
#           acc: 0.99983, fpr: 0.00011, fnr: 0.00167, rec: 0.99833, prc: 0.99750, f1: 0.99792, f1_macro: 0.99891
# epoch: 23, passed number of graphs: 384, train running loss: 0.00089 (passed time: 2h 41m 23s)
#           acc: 0.99984, fpr: 0.00013, fnr: 0.00066, rec: 0.99934, prc: 0.99705, f1: 0.99820, f1_macro: 0.99906
# epoch: 23, passed number of graphs: 480, train running loss: 0.00092 (passed time: 2h 42m 11s)
#           acc: 0.99977, fpr: 0.00019, fnr: 0.00100, rec: 0.99900, prc: 0.99569, f1: 0.99735, f1_macro: 0.99861
# epoch: 23, passed number of graphs: 576, train running loss: 0.00089 (passed time: 2h 43m 0s)
#           acc: 0.99967, fpr: 0.00029, fnr: 0.00131, rec: 0.99869, prc: 0.99346, f1: 0.99607, f1_macro: 0.99795
# epoch: 23, passed number of graphs: 672, train running loss: 0.00088 (passed time: 2h 43m 49s)
#           acc: 0.99918, fpr: 0.00079, fnr: 0.00163, rec: 0.99837, prc: 0.98217, f1: 0.99020, f1_macro: 0.99489
# epoch: 23, passed number of graphs: 768, train running loss: 0.00091 (passed time: 2h 44m 38s)
#           acc: 0.99987, fpr: 0.00012, fnr: 0.00033, rec: 0.99967, prc: 0.99735, f1: 0.99851, f1_macro: 0.99922
# Validation --- epoch: 23, loss: 0.00086
#           acc: 0.99977, rec: 0.99246, f1: 0.99391, fnr: 0.00754, prc: 0.99687, f1_macro: 0.99689, fpr: 0.00007
# epoch: 24, passed number of graphs: 96, train running loss: 0.00104 (passed time: 2h 46m 3s)
#           acc: 0.99988, fpr: 0.00010, fnr: 0.00049, rec: 0.99951, prc: 0.99773, f1: 0.99862, f1_macro: 0.99928
# epoch: 24, passed number of graphs: 192, train running loss: 0.00099 (passed time: 2h 46m 51s)
#           acc: 0.99987, fpr: 0.00000, fnr: 0.00318, rec: 0.99682, prc: 1.00000, f1: 0.99841, f1_macro: 0.99917
# epoch: 24, passed number of graphs: 288, train running loss: 0.00089 (passed time: 2h 47m 40s)
#           acc: 0.99983, fpr: 0.00011, fnr: 0.00167, rec: 0.99833, prc: 0.99750, f1: 0.99792, f1_macro: 0.99891
# epoch: 24, passed number of graphs: 384, train running loss: 0.00089 (passed time: 2h 48m 29s)
#           acc: 0.99984, fpr: 0.00014, fnr: 0.00066, rec: 0.99934, prc: 0.99689, f1: 0.99811, f1_macro: 0.99901
# epoch: 24, passed number of graphs: 480, train running loss: 0.00092 (passed time: 2h 49m 18s)
#           acc: 0.99977, fpr: 0.00019, fnr: 0.00100, rec: 0.99900, prc: 0.99569, f1: 0.99735, f1_macro: 0.99861
# epoch: 24, passed number of graphs: 576, train running loss: 0.00089 (passed time: 2h 50m 7s)
#           acc: 0.99967, fpr: 0.00029, fnr: 0.00131, rec: 0.99869, prc: 0.99346, f1: 0.99607, f1_macro: 0.99795
# epoch: 24, passed number of graphs: 672, train running loss: 0.00088 (passed time: 2h 50m 56s)
#           acc: 0.99918, fpr: 0.00078, fnr: 0.00163, rec: 0.99837, prc: 0.98233, f1: 0.99028, f1_macro: 0.99493
# epoch: 24, passed number of graphs: 768, train running loss: 0.00091 (passed time: 2h 51m 45s)
#           acc: 0.99988, fpr: 0.00012, fnr: 0.00017, rec: 0.99983, prc: 0.99735, f1: 0.99859, f1_macro: 0.99926
# Validation --- epoch: 24, loss: 0.00086
#           acc: 0.99977, rec: 0.99247, f1: 0.99391, fnr: 0.00753, prc: 0.99687, f1_macro: 0.99690, fpr: 0.00007
# epoch: 25, passed number of graphs: 96, train running loss: 0.00104 (passed time: 2h 53m 9s)
#           acc: 0.99989, fpr: 0.00010, fnr: 0.00032, rec: 0.99968, prc: 0.99773, f1: 0.99870, f1_macro: 0.99932
# epoch: 25, passed number of graphs: 192, train running loss: 0.00100 (passed time: 2h 53m 58s)
#           acc: 0.99987, fpr: 0.00001, fnr: 0.00301, rec: 0.99699, prc: 0.99983, f1: 0.99841, f1_macro: 0.99917
# epoch: 25, passed number of graphs: 288, train running loss: 0.00089 (passed time: 2h 54m 47s)
#           acc: 0.99984, fpr: 0.00011, fnr: 0.00133, rec: 0.99867, prc: 0.99750, f1: 0.99808, f1_macro: 0.99900
# epoch: 25, passed number of graphs: 384, train running loss: 0.00089 (passed time: 2h 55m 36s)
#           acc: 0.99984, fpr: 0.00013, fnr: 0.00082, rec: 0.99918, prc: 0.99705, f1: 0.99811, f1_macro: 0.99901
# epoch: 25, passed number of graphs: 480, train running loss: 0.00092 (passed time: 2h 56m 24s)
#           acc: 0.99977, fpr: 0.00019, fnr: 0.00100, rec: 0.99900, prc: 0.99569, f1: 0.99735, f1_macro: 0.99861
# epoch: 25, passed number of graphs: 576, train running loss: 0.00089 (passed time: 2h 57m 13s)
#           acc: 0.99966, fpr: 0.00031, fnr: 0.00099, rec: 0.99901, prc: 0.99298, f1: 0.99599, f1_macro: 0.99790
# epoch: 25, passed number of graphs: 672, train running loss: 0.00088 (passed time: 2h 58m 3s)
#           acc: 0.99917, fpr: 0.00077, fnr: 0.00212, rec: 0.99788, prc: 0.98248, f1: 0.99012, f1_macro: 0.99484
# epoch: 25, passed number of graphs: 768, train running loss: 0.00091 (passed time: 2h 58m 52s)
#           acc: 0.99987, fpr: 0.00012, fnr: 0.00050, rec: 0.99950, prc: 0.99735, f1: 0.99842, f1_macro: 0.99918
# Validation --- epoch: 25, loss: 0.00086
#           acc: 0.99977, rec: 0.99231, f1: 0.99396, fnr: 0.00769, prc: 0.99713, f1_macro: 0.99692, fpr: 0.00006
# epoch: 26, passed number of graphs: 96, train running loss: 0.00102 (passed time: 3h 0m 16s)
#           acc: 0.99989, fpr: 0.00010, fnr: 0.00032, rec: 0.99968, prc: 0.99773, f1: 0.99870, f1_macro: 0.99932
# epoch: 26, passed number of graphs: 192, train running loss: 0.00098 (passed time: 3h 1m 5s)
#           acc: 0.99987, fpr: 0.00000, fnr: 0.00301, rec: 0.99699, prc: 1.00000, f1: 0.99849, f1_macro: 0.99921
# epoch: 26, passed number of graphs: 288, train running loss: 0.00088 (passed time: 3h 1m 54s)
#           acc: 0.99984, fpr: 0.00011, fnr: 0.00150, rec: 0.99850, prc: 0.99750, f1: 0.99800, f1_macro: 0.99896
# epoch: 26, passed number of graphs: 384, train running loss: 0.00089 (passed time: 3h 2m 42s)
#           acc: 0.99984, fpr: 0.00013, fnr: 0.00082, rec: 0.99918, prc: 0.99705, f1: 0.99811, f1_macro: 0.99901
# epoch: 26, passed number of graphs: 480, train running loss: 0.00092 (passed time: 3h 3m 31s)
#           acc: 0.99977, fpr: 0.00019, fnr: 0.00100, rec: 0.99900, prc: 0.99569, f1: 0.99735, f1_macro: 0.99861
# epoch: 26, passed number of graphs: 576, train running loss: 0.00088 (passed time: 3h 4m 20s)
#           acc: 0.99966, fpr: 0.00031, fnr: 0.00099, rec: 0.99901, prc: 0.99298, f1: 0.99599, f1_macro: 0.99790
# epoch: 26, passed number of graphs: 672, train running loss: 0.00087 (passed time: 3h 5m 9s)
#           acc: 0.99917, fpr: 0.00077, fnr: 0.00212, rec: 0.99788, prc: 0.98248, f1: 0.99012, f1_macro: 0.99484
# epoch: 26, passed number of graphs: 768, train running loss: 0.00091 (passed time: 3h 5m 58s)
#           acc: 0.99987, fpr: 0.00012, fnr: 0.00050, rec: 0.99950, prc: 0.99735, f1: 0.99842, f1_macro: 0.99918
# Validation --- epoch: 26, loss: 0.00086
#           acc: 0.99977, rec: 0.99231, f1: 0.99396, fnr: 0.00769, prc: 0.99713, f1_macro: 0.99692, fpr: 0.00006
# epoch: 27, passed number of graphs: 96, train running loss: 0.00102 (passed time: 3h 7m 22s)
#           acc: 0.99989, fpr: 0.00010, fnr: 0.00032, rec: 0.99968, prc: 0.99773, f1: 0.99870, f1_macro: 0.99932
# epoch: 27, passed number of graphs: 192, train running loss: 0.00098 (passed time: 3h 8m 11s)
#           acc: 0.99987, fpr: 0.00001, fnr: 0.00301, rec: 0.99699, prc: 0.99983, f1: 0.99841, f1_macro: 0.99917
# epoch: 27, passed number of graphs: 288, train running loss: 0.00088 (passed time: 3h 9m 0s)
#           acc: 0.99984, fpr: 0.00011, fnr: 0.00133, rec: 0.99867, prc: 0.99733, f1: 0.99800, f1_macro: 0.99896
# epoch: 27, passed number of graphs: 384, train running loss: 0.00088 (passed time: 3h 9m 49s)
#           acc: 0.99984, fpr: 0.00013, fnr: 0.00082, rec: 0.99918, prc: 0.99705, f1: 0.99811, f1_macro: 0.99901
# epoch: 27, passed number of graphs: 480, train running loss: 0.00092 (passed time: 3h 10m 38s)
#           acc: 0.99977, fpr: 0.00019, fnr: 0.00100, rec: 0.99900, prc: 0.99569, f1: 0.99735, f1_macro: 0.99861
# epoch: 27, passed number of graphs: 576, train running loss: 0.00088 (passed time: 3h 11m 27s)
#           acc: 0.99967, fpr: 0.00031, fnr: 0.00082, rec: 0.99918, prc: 0.99298, f1: 0.99607, f1_macro: 0.99795
# epoch: 27, passed number of graphs: 672, train running loss: 0.00087 (passed time: 3h 12m 16s)
#           acc: 0.99917, fpr: 0.00077, fnr: 0.00212, rec: 0.99788, prc: 0.98248, f1: 0.99012, f1_macro: 0.99484
# epoch: 27, passed number of graphs: 768, train running loss: 0.00091 (passed time: 3h 13m 5s)
#           acc: 0.99987, fpr: 0.00012, fnr: 0.00050, rec: 0.99950, prc: 0.99735, f1: 0.99842, f1_macro: 0.99918
# Validation --- epoch: 27, loss: 0.00086
#           acc: 0.99977, rec: 0.99227, f1: 0.99397, fnr: 0.00773, prc: 0.99719, f1_macro: 0.99693, fpr: 0.00006
# epoch: 28, passed number of graphs: 96, train running loss: 0.00102 (passed time: 3h 14m 28s)
#           acc: 0.99989, fpr: 0.00010, fnr: 0.00032, rec: 0.99968, prc: 0.99773, f1: 0.99870, f1_macro: 0.99932
# epoch: 28, passed number of graphs: 192, train running loss: 0.00098 (passed time: 3h 15m 17s)
#           acc: 0.99987, fpr: 0.00001, fnr: 0.00301, rec: 0.99699, prc: 0.99983, f1: 0.99841, f1_macro: 0.99917
# epoch: 28, passed number of graphs: 288, train running loss: 0.00088 (passed time: 3h 16m 6s)
#           acc: 0.99984, fpr: 0.00011, fnr: 0.00133, rec: 0.99867, prc: 0.99750, f1: 0.99808, f1_macro: 0.99900
# epoch: 28, passed number of graphs: 384, train running loss: 0.00088 (passed time: 3h 16m 55s)
#           acc: 0.99984, fpr: 0.00013, fnr: 0.00082, rec: 0.99918, prc: 0.99722, f1: 0.99820, f1_macro: 0.99906
# epoch: 28, passed number of graphs: 480, train running loss: 0.00092 (passed time: 3h 17m 44s)
#           acc: 0.99978, fpr: 0.00018, fnr: 0.00100, rec: 0.99900, prc: 0.99586, f1: 0.99743, f1_macro: 0.99866
# epoch: 28, passed number of graphs: 576, train running loss: 0.00088 (passed time: 3h 18m 33s)
#           acc: 0.99967, fpr: 0.00031, fnr: 0.00082, rec: 0.99918, prc: 0.99298, f1: 0.99607, f1_macro: 0.99795
# epoch: 28, passed number of graphs: 672, train running loss: 0.00087 (passed time: 3h 19m 22s)
#           acc: 0.99917, fpr: 0.00077, fnr: 0.00212, rec: 0.99788, prc: 0.98248, f1: 0.99012, f1_macro: 0.99484
# epoch: 28, passed number of graphs: 768, train running loss: 0.00091 (passed time: 3h 20m 11s)
#           acc: 0.99987, fpr: 0.00012, fnr: 0.00050, rec: 0.99950, prc: 0.99735, f1: 0.99842, f1_macro: 0.99918
# Validation --- epoch: 28, loss: 0.00086
#           acc: 0.99977, rec: 0.99225, f1: 0.99397, fnr: 0.00775, prc: 0.99721, f1_macro: 0.99693, fpr: 0.00006
# epoch: 29, passed number of graphs: 96, train running loss: 0.00102 (passed time: 3h 21m 36s)
#           acc: 0.99989, fpr: 0.00010, fnr: 0.00032, rec: 0.99968, prc: 0.99773, f1: 0.99870, f1_macro: 0.99932
# epoch: 29, passed number of graphs: 192, train running loss: 0.00098 (passed time: 3h 22m 25s)
#           acc: 0.99987, fpr: 0.00001, fnr: 0.00301, rec: 0.99699, prc: 0.99983, f1: 0.99841, f1_macro: 0.99917
# epoch: 29, passed number of graphs: 288, train running loss: 0.00088 (passed time: 3h 23m 14s)
#           acc: 0.99984, fpr: 0.00011, fnr: 0.00133, rec: 0.99867, prc: 0.99750, f1: 0.99808, f1_macro: 0.99900
# epoch: 29, passed number of graphs: 384, train running loss: 0.00088 (passed time: 3h 24m 3s)
#           acc: 0.99984, fpr: 0.00013, fnr: 0.00082, rec: 0.99918, prc: 0.99722, f1: 0.99820, f1_macro: 0.99906
# epoch: 29, passed number of graphs: 480, train running loss: 0.00092 (passed time: 3h 24m 52s)
#           acc: 0.99978, fpr: 0.00018, fnr: 0.00100, rec: 0.99900, prc: 0.99586, f1: 0.99743, f1_macro: 0.99866
# epoch: 29, passed number of graphs: 576, train running loss: 0.00088 (passed time: 3h 25m 41s)
#           acc: 0.99967, fpr: 0.00031, fnr: 0.00082, rec: 0.99918, prc: 0.99298, f1: 0.99607, f1_macro: 0.99795
# epoch: 29, passed number of graphs: 672, train running loss: 0.00087 (passed time: 3h 26m 30s)
#           acc: 0.99917, fpr: 0.00077, fnr: 0.00212, rec: 0.99788, prc: 0.98248, f1: 0.99012, f1_macro: 0.99484
# epoch: 29, passed number of graphs: 768, train running loss: 0.00090 (passed time: 3h 27m 19s)
#           acc: 0.99987, fpr: 0.00012, fnr: 0.00050, rec: 0.99950, prc: 0.99735, f1: 0.99842, f1_macro: 0.99918
# Validation --- epoch: 29, loss: 0.00086
#           acc: 0.99977, rec: 0.99224, f1: 0.99397, fnr: 0.00776, prc: 0.99722, f1_macro: 0.99693, fpr: 0.00006
# epoch: 30, passed number of graphs: 96, train running loss: 0.00102 (passed time: 3h 28m 43s)
#           acc: 0.99989, fpr: 0.00010, fnr: 0.00032, rec: 0.99968, prc: 0.99773, f1: 0.99870, f1_macro: 0.99932
# epoch: 30, passed number of graphs: 192, train running loss: 0.00098 (passed time: 3h 29m 32s)
#           acc: 0.99987, fpr: 0.00001, fnr: 0.00301, rec: 0.99699, prc: 0.99983, f1: 0.99841, f1_macro: 0.99917
# epoch: 30, passed number of graphs: 288, train running loss: 0.00088 (passed time: 3h 30m 21s)
#           acc: 0.99984, fpr: 0.00011, fnr: 0.00133, rec: 0.99867, prc: 0.99750, f1: 0.99808, f1_macro: 0.99900
# epoch: 30, passed number of graphs: 384, train running loss: 0.00088 (passed time: 3h 31m 10s)
#           acc: 0.99984, fpr: 0.00013, fnr: 0.00082, rec: 0.99918, prc: 0.99722, f1: 0.99820, f1_macro: 0.99906
# epoch: 30, passed number of graphs: 480, train running loss: 0.00092 (passed time: 3h 31m 59s)
#           acc: 0.99978, fpr: 0.00018, fnr: 0.00100, rec: 0.99900, prc: 0.99586, f1: 0.99743, f1_macro: 0.99866
# epoch: 30, passed number of graphs: 576, train running loss: 0.00088 (passed time: 3h 32m 48s)
#           acc: 0.99967, fpr: 0.00031, fnr: 0.00082, rec: 0.99918, prc: 0.99298, f1: 0.99607, f1_macro: 0.99795
# epoch: 30, passed number of graphs: 672, train running loss: 0.00087 (passed time: 3h 33m 37s)
#           acc: 0.99917, fpr: 0.00077, fnr: 0.00212, rec: 0.99788, prc: 0.98248, f1: 0.99012, f1_macro: 0.99484
# epoch: 30, passed number of graphs: 768, train running loss: 0.00090 (passed time: 3h 34m 26s)
#           acc: 0.99987, fpr: 0.00012, fnr: 0.00050, rec: 0.99950, prc: 0.99735, f1: 0.99842, f1_macro: 0.99918
# Validation --- epoch: 30, loss: 0.00086
#           acc: 0.99977, rec: 0.99224, f1: 0.99398, fnr: 0.00776, prc: 0.99723, f1_macro: 0.99693, fpr: 0.00006
# epoch: 31, passed number of graphs: 96, train running loss: 0.00101 (passed time: 3h 35m 50s)
#           acc: 0.99989, fpr: 0.00010, fnr: 0.00032, rec: 0.99968, prc: 0.99773, f1: 0.99870, f1_macro: 0.99932

# %%
# !zip -r /content/GATv2Conv_p2p_6k_feat_norm.zip /content/saved_models

# %%
from google.colab import files
files.download("/content/GATv2Conv_p2p_6k_feat_norm.zip")

# %%
from google.colab import runtime
runtime.unassign()
