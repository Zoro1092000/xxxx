# %% [markdown]
# <a href="https://colab.research.google.com/github/Zoro1092000/xxxx/blob/main/12GIN_MPL_4Layer_p2p_6k_botnode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # I. Pip & Import.

# %%
import os
import os.path as osp
import torch
import sys

os.environ['TORCH'] = torch.__version__

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install torch-geometric==1.4.3
# !pip install torch-cluster -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install deepdish==0.3.5

import torch.nn as nn
from torch.nn import Parameter
from torch_geometric.utils import scatter_
from torch_geometric.nn.inits import glorot, zeros
from torch_scatter import scatter_add
from torch.utils.data import DataLoader, Dataset


from itertools import chain
import pickle
import h5py
import deepdish as dd
import numpy as np
from tqdm import tqdm
import inspect
import time
import math
import random
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-geometric==1.4.3 in /usr/local/lib/python3.7/dist-packages (1.4.3)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.56.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (3.1.0)
# Requirement already satisfied: plyfile in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.7.4)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.18.3)
# Requirement already satisfied: rdflib in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (6.2.0)
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.23.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.3.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.12.1+cu113)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.7.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.6.3)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->torch-geometric==1.4.3) (1.5.2)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (57.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (4.13.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (3.10.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (4.1.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->torch-geometric==1.4.3) (1.15.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (3.0.9)
# Requirement already satisfied: isodate in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (0.6.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2.10)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (7.1.2)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (3.2.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (1.3.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2021.11.2)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2.9.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (1.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (1.2.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://data.pyg.org/whl/torch-1.12.1+cu113.html
# Requirement already satisfied: torch-cluster in /usr/local/lib/python3.7/dist-packages (1.6.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: deepdish==0.3.5 in /usr/local/lib/python3.7/dist-packages (0.3.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.21.6)
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (3.7.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (21.3)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (2.8.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tables->deepdish==0.3.5) (3.0.9)

# %%
def time_since(start):
    now = time.time()
    s = now - start
    m = math.floor(s / 60)
    s -= m * 60
    h = math.floor(m / 60)
    m -= h * 60
    if h == 0:
        if m == 0:
            return '%ds' % s
        else:
            return '%dm %ds' % (m, s)
    else:
        return '%dh %dm %ds' % (h, m, s)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # II. Data

# %%
# Data utils
def h5group_to_dict(h5group):
    group_dict = {k: v[()] for k, v in chain(h5group.items(), h5group.attrs.items())}
    return group_dict

def sub_dict(full_dict, *keys, to_tensor):
    return {k: torch.tensor(full_dict[k]) if to_tensor else full_dict[k] for k in keys if k in full_dict}

def build_graph_from_dict_pyg(graph_dict, to_tensor=True):
    from torch_geometric.data import Data

    g = Data(**sub_dict(graph_dict, 'edge_index', 'x', 'y', 'edge_attr', 'edge_y', to_tensor=to_tensor))
    return g

# Data loader
class GraphDataLoader(DataLoader):
    def __init__(self, dataset, batch_size=128, shuffle=False, num_workers=0):

        def collate_graph(graph_obj_list):
            from torch_geometric.data import Batch
            batch = Batch.from_data_list(graph_obj_list)
            return batch

        super().__init__(
            dataset,
            batch_size=batch_size,
            shuffle=shuffle,
            collate_fn=collate_graph,
            num_workers=num_workers)

# BotnetDataset
class BotnetDataset(Dataset):

    def __init__(self, name='chord', root='data/botnet', split='train', graph_format='pyg', split_idx=None, add_nfeat_ones=True,
                 in_memory=True):
        super().__init__()
        assert name in ['chord', 'debru', 'kadem', 'leet', 'c2', 'p2p']
        assert split in ['train', 'val', 'test']

        if isinstance(root, str):
            root = osp.expanduser(osp.normpath(root))

        self.name = name
        self.root = root
        self.split = split
        self.split_idx = split_idx
        self.add_nfeat_ones = add_nfeat_ones

        self._graph_format = graph_format
        if split == 'train':
            self.path = self.processed_paths[0]
            self.num_graphs = 768
        elif split == 'val':
            self.path = self.processed_paths[1]
            self.num_graphs = 96
        elif split == 'test':
            self.path = self.processed_paths[2]
            self.num_graphs = 96
            
        if in_memory:
            self.data = dd.io.load(self.path)  # dictionary
            self.data_type = 'dict'
        else:
            # self.data = h5py.File(self.path, 'r')
            self.data = None    # defer opening file in each process to make multiprocessing work
            self.data_type = 'file'

            
    @property
    def processed_dir(self):
        return osp.join(self.root, 'processed')

    @property
    def processed_file_names(self):
        return [self.name + '_' + s + '.hdf5' for s in ('train', 'val', 'test')]

    @property
    def processed_paths(self):
        return [osp.join(self.processed_dir, f) for f in self.processed_file_names]

    def __len__(self):
        return self.num_graphs

    def __getitem__(self, index):
        if self.data_type == 'dict':
            graph_dict = self.data[str(index)]
        elif self.data_type == 'file':
            if self.data is None:
                # only open once in each process
                self.data = h5py.File(self.path, 'r')
            graph_dict = h5group_to_dict(self.data[str(index)])
        else:
            raise ValueError

        # graph_format == 'pyg':
        return build_graph_from_dict_pyg(graph_dict)


    def __iter__(self):
        for i in range(self.num_graphs):
            yield self[i]

    def __repr__(self):
        return f'{self.__class__.__name__}(topology: {self.name} | split: {self.split} | ' \
               f'#graphs: {len(self)} | graph format: {self.graph_format})'

# %% [markdown]
# # III. Measure Performancce

# %% [markdown]
# ## 3.1. Metrics

# %%
def f1(target, pred, label):
    # F1 = 2 * (precision * recall) / (precision + recall)
    tp = np.sum((target==label) & (pred==label))
    fp = np.sum((target!=label) & (pred==label))
    fn = np.sum((pred!=label) & (target==label))
    
    if tp+fp==0 or tp+fn==0:
      return np.nan

    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    
    if precision+recall==0:
      return np.nan
      
    f1 = 2 * (precision * recall) / (precision + recall)
    return f1

def f1_macro(pred, target):
    return np.mean([f1(target, pred, label) for label in range(0, 2)])


def accuracy(pred, target):
    return (pred == target).sum().item() / len(target)


def true_positive(pred, target):
    return (target[pred == 1] == 1).sum().item()


def false_positive(pred, target):
    return (target[pred == 1] == 0).sum().item()


def true_negative(pred, target):
    return (target[pred == 0] == 0).sum().item()


def false_negative(pred, target):
    return (target[pred == 0] == 1).sum().item()


def recall(pred, target):
    try:
        return true_positive(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1


def precision(pred, target):
    try:
        prec = true_positive(pred, target) / (pred == 1).sum().item()
        return prec
    except:  # divide by zero
        return -1


def f1_score(pred, target):
    prec = precision(pred, target)
    rec = recall(pred, target)
    try:
        return 2 * (prec * rec) / (prec + rec)
    except:
        return 0


def false_positive_rate(pred, target):
    try:
        return false_positive(pred, target) / (target == 0).sum().item()
    except:  # divide by zero
        return -1


def false_negative_rate(pred, target):
    try:
        return false_negative(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1

# %% [markdown]
# ## 3.2. Evaluation

# %%
def eval_metrics(target, pred_prob, threshold=0.5):
    if isinstance(target, torch.Tensor):
        target = target.cpu().numpy()
    if isinstance(pred_prob, torch.Tensor):
        pred_prob = pred_prob.cpu().numpy()

    pred = (pred_prob >= threshold).astype(int)

    acc = accuracy(pred, target)
    fpr = false_positive_rate(pred, target)
    fnr = false_negative_rate(pred, target)
    rec = recall(pred, target)
    prc = precision(pred, target)
    f1 = f1_score(pred, target)
    f1macro = f1_macro(pred, target)
    result_dict = {'acc': acc, 'fpr': fpr, 'fnr': fnr, 'rec': rec, 'prc': prc, 'f1': f1, 'f1_macro': f1macro}

    return result_dict


def dict_value_add(dict1, dict2):
    result = {key: dict1.get(key, 0) + dict2.get(key, 0)
              for key in set(dict1) | set(dict2)}
    return result


def dict_value_div(dict, n):
    result = {key: value / n for key, value in dict.items()}
    return result


def eval_predictor(dataset, predictor):
    result_dict_avg = {}
    loss_avg = 0

    for data in dataset:
        # prediction
        try:
            pred_prob, loss = predictor(data)
            loss_avg += loss
        except ValueError:  # if "too many values to unpack"
            pred_prob = predictor(data)

        # get the ground truth target
        # graph_format == 'pyg':
        target = data.y

        # compute the evaluation metrics
        result_dict = eval_metrics(target, pred_prob)

        result_dict_avg = dict_value_add(result_dict_avg, result_dict)

    # average the metrics across all graphs in the dataset as final results
    result_dict_avg = dict_value_div(result_dict_avg, len(dataset))
    loss_avg = loss_avg / len(dataset)

    return result_dict_avg, loss_avg


# =================================================================================================================
# some examples of the 'predictor' model wrapper to be fed into the above evaluation function (for PyG Data format)
# =================================================================================================================
class PygRandomPredictor:
    def __init__(self):
        # torch.manual_seed(0)
        pass

    def __call__(self, data):
        pred_prob = torch.rand(len(data.y))
        return pred_prob


class PygModelPredictor:
    def __init__(self, model, loss_fcn=torch.nn.CrossEntropyLoss()):
        self.model = model
        self.loss_fcn = loss_fcn
        self.device = next(model.parameters()).device

    def __call__(self, data):
        self.model.eval()
        data = data.to(self.device)
        with torch.no_grad():
            # custom the below line to adjust to your model's input format for forward pass
            out = self.model(data.x, data.edge_index)
            loss = self.loss_fcn(out, data.y.long())
            pred_prob = torch.softmax(out, dim=1)[:, 1]
        return pred_prob, loss.float()

# %% [markdown]
# # IV. Model

# %% [markdown]
# ## 5.1. Activation

# %%
def activation(act, negative_slope=0.2):
    activations = nn.ModuleDict([
        ['lrelu', nn.LeakyReLU(negative_slope)],
        ['relu', nn.ReLU()],
        ['elu', nn.ELU()],
        ['none', nn.Identity()],
    ])
    return activations[act]

# %% [markdown]
# ## 5.2. GIN model

# %%
import torch.nn as nn

class GINModel(nn.Module):
    def __init__(self, dim_input_feature, dim_hidden_feature, num_layers, num_classes, non_linear='relu', dropout=0.2):
        super().__init__()

        self.dim_input_feature = dim_input_feature
        self.dim_hidden_feature = dim_hidden_feature

        self.num_layers = num_layers
        self.num_classes = num_classes
        
        from torch.nn import Linear, Sequential, BatchNorm1d, ReLU, Dropout
        from torch_geometric.nn import GINConv
        
        self.gin_net = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.gin_net.append(
                GINConv(
                  Sequential(Linear(self.dim_input_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU())))
          else:
            self.gin_net.append(
                GINConv(
                  Sequential(Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU()))) 

        self.dropout = nn.Dropout(dropout)

        self.residuals = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.residuals.append(nn.Linear(self.dim_input_feature, self.dim_hidden_feature, bias=True))
          else:
            self.residuals.append(nn.Identity())

        self.num_residuals = len(self.residuals)

        self.non_linear = activation(non_linear)

        # self.final_type == 'proj':
        self.final = nn.Linear(self.dim_hidden_feature, num_classes)

    def reset_parameters(self):
        for net in self.gin_net:
            net.reset_parameters()
        # self.residual_hop = 1
        for net in self.residuals:
            net.reset_parameters()
        # self.final_type != 'none':
        self.final.reset_parameters()

    def forward(self, x, edge_index):
        xr = None
        add_xr_at = -1

        for n, net in enumerate(self.gin_net):
            # pass to a GIN layer with non-linear activation
            xo = net(x, edge_index)
            xo = self.dropout(xo)
            # deal with residual connections
            # self.residual_hop = 1
            if n < self.num_residuals:
                xr = self.residuals[n](x)
                add_xr_at = n
            if n == add_xr_at:
                xo = self.non_linear(xo + xr)

            x = xo
        # size of x: (B * N, dim_hidden_feature) -> (B * N, num_classes)
        x = self.final(x)

        return x

# %% [markdown]
# # V. Load data

# %%
data_dir = '/content/drive/Shareddrives/botnetdata/p2p_6k_botnode'
data_name = 'p2p' # 'chord', 'debru', 'kadem', 'leet', 'c2', 'p2p'
shuffle = False

# ========== load the dataset
print('loading dataset...')

train_ds = BotnetDataset(name=data_name, root=data_dir, split='train',
                         in_memory=True, graph_format='pyg')
val_ds = BotnetDataset(name=data_name, root=data_dir, split='val',
                       in_memory=False, graph_format='pyg')
test_ds = BotnetDataset(name=data_name, root=data_dir, split='test',
                        in_memory=False, graph_format='pyg')
# Out:
# loading dataset...

# %%
batch_size = 2
train_loader = GraphDataLoader(train_ds, batch_size=batch_size, shuffle=bool(shuffle), num_workers=0)

# %% [markdown]
# # VI. Train

# %%
# ============== some default parameters =============
devid = 0
seed = 0
logmode = 'w'
log_interval = 96

dim_input_feature = 1
dim_hidden_feature = 32
act = 'relu' # 'none', 'lrelu', 'relu', 'elu'

num_layers = 12
num_classes = 2 

dropout = 0.2
bias = True

lr = 0.005 # learning rate
weight_decay = 5e-4
epochs = 50
save_dir = './saved_models'
save_name = "GIN_model.pt"
# ====================================================

def train(model, train_loader, val_dataset, test_dataset, optimizer, scheduler=None):
    device = next(model.parameters()).device
    predictor = PygModelPredictor(model)

    best_epoch = 0
    max_f1_score = 0
    start = time.time()
    for ep in range(epochs):
        loss_avg_train = 0
        num_train_graph = 0
        model.train()
        for n, batch in enumerate(train_loader):
            batch.to(device)

            optimizer.zero_grad()

            x = model(batch.x, batch.edge_index)
            loss = criterion(x, batch.y.long())

            loss_avg_train += float(loss)
            num_train_graph += batch.num_graphs

            loss.backward()
            optimizer.step()

            if num_train_graph % log_interval == 0 or n == len(train_loader) - 1:
                with torch.no_grad():
                    # pred = x.argmax(dim=1)
                    pred_prob = torch.softmax(x, dim=1)[:, 1]
                    y = batch.y.long()
                    result_dict = eval_metrics(y, pred_prob)
                print(f'epoch: {ep + 1}, passed number of graphs: {num_train_graph}, '
                        f'train running loss: {loss_avg_train / num_train_graph:.5f} (passed time: {time_since(start)})')
                print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict.items()]))

        result_dict_avg, loss_avg = eval_predictor(val_dataset, predictor)
        print(f'Validation --- epoch: {ep + 1}, loss: {loss_avg:.5f}')
        print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))

        if scheduler is not None:
            scheduler.step(loss_avg)

        if result_dict_avg['f1'] > max_f1_score:
            save_name = f"GIN_{ep}: {result_dict_avg['f1']}.pt"
            torch.save(model, os.path.join(save_dir, save_name))
            print(f'Better model saved at {os.path.join(save_dir, save_name)}.')
            best_epoch = ep
            max_f1_score = result_dict_avg['f1']

    best_model = torch.load(os.path.join(save_dir, save_name))
    print('*' * 12 + f' best model obtained after epoch {best_epoch + 1}, '
                       f'saved at {os.path.join(save_dir, save_name)} ' + '*' * 12)
    
    predictor = PygModelPredictor(best_model)

    result_dict_avg, loss_avg = eval_predictor(test_dataset, predictor)
    print(f'Testing --- loss: {loss_avg:.5f}')
    print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))


if __name__ == '__main__':
    os.makedirs(save_dir, exist_ok=True)

    # ========== random seeds and device
    random.seed(seed)
    torch.manual_seed(seed)

    device = torch.device(f'cuda:{devid}') if devid > -1 else torch.device('cpu')

    # ========== logging setup
    log_name = os.path.splitext(save_name)[0]
    # logger = logging_config(__name__, folder=save_dir, name=log_name, filemode=logmode)
    # logger = logging_config(os.path.basename(__file__), folder=save_dir, name=log_name, filemode=logmode)

    print('python ' + ' '.join(sys.argv))
    print('-' * 30)
    #logger.info(args)
    print('-' * 30)
    print(time.ctime())
    print('-' * 30)

    # ========== define the model, optimizer, and loss

    model = GINModel(dim_input_feature,
                     dim_hidden_feature,
                     num_layers,
                     num_classes,
                     non_linear=act,
                     dropout=dropout)

    print('model ' + '-' * 10)
    print(repr(model))
    model.to(device)

    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.25, patience=1)

    # ========== train the model
    print(f"Batch size: {batch_size}")
    train(model, train_loader, val_ds, test_ds, optimizer, scheduler)
# Out:
# python /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-893d8e34-58e7-4f83-8ef1-b94eb3f6ffb0.json
# ------------------------------
# ------------------------------
# Wed Nov  9 05:52:32 2022
# ------------------------------
# model ----------
# GINModel(
#   (gin_net): ModuleList(
#     (0): GINConv(nn=Sequential(
#       (0): Linear(in_features=1, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#     ))
#     (1): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#     ))
#     (2): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#     ))
#     (3): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#     ))
#     (4): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#     ))
#     (5): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#     ))
#     (6): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#     ))
#     (7): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#     ))
#     (8): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#     ))
#     (9): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#     ))
#     (10): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#     ))
#     (11): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
#       (7): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU()
#       (9): Linear(in_features=32, out_features=32, bias=True)
#       (10): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): ReLU()
#     ))
#   )
#   (dropout): Dropout(p=0.2, inplace=False)
#   (residuals): ModuleList(
#     (0): Linear(in_features=1, out_features=32, bias=True)
#     (1): Identity()
#     (2): Identity()
#     (3): Identity()
#     (4): Identity()
#     (5): Identity()
#     (6): Identity()
#     (7): Identity()
#     (8): Identity()
#     (9): Identity()
#     (10): Identity()
#     (11): Identity()
#   )
#   (non_linear): ReLU()
#   (final): Linear(in_features=32, out_features=2, bias=True)
# )
# Batch size: 2
# epoch: 1, passed number of graphs: 96, train running loss: 0.09116 (passed time: 23s)
#           acc: 0.99167, fpr: 0.00051, fnr: 0.18359, rec: 0.81641, prc: 0.98610, f1: 0.89327, f1_macro: 0.94447
# epoch: 1, passed number of graphs: 192, train running loss: 0.05573 (passed time: 44s)
#           acc: 0.99323, fpr: 0.00364, fnr: 0.07808, rec: 0.92192, prc: 0.91758, f1: 0.91974, f1_macro: 0.95810
# epoch: 1, passed number of graphs: 288, train running loss: 0.03852 (passed time: 1m 4s)
#           acc: 0.99689, fpr: 0.00251, fnr: 0.01702, rec: 0.98298, prc: 0.94464, f1: 0.96343, f1_macro: 0.98090
# epoch: 1, passed number of graphs: 384, train running loss: 0.03454 (passed time: 1m 25s)
#           acc: 0.99678, fpr: 0.00057, fnr: 0.06184, rec: 0.93816, prc: 0.98684, f1: 0.96188, f1_macro: 0.98010
# epoch: 1, passed number of graphs: 480, train running loss: 0.02982 (passed time: 1m 46s)
#           acc: 0.99919, fpr: 0.00013, fnr: 0.01620, rec: 0.98380, prc: 0.99714, f1: 0.99042, f1_macro: 0.99500
# epoch: 1, passed number of graphs: 576, train running loss: 0.02593 (passed time: 2m 7s)
#           acc: 0.99967, fpr: 0.00018, fnr: 0.00369, rec: 0.99631, prc: 0.99590, f1: 0.99611, f1_macro: 0.99797
# epoch: 1, passed number of graphs: 672, train running loss: 0.02311 (passed time: 2m 28s)
#           acc: 0.99685, fpr: 0.00009, fnr: 0.07179, rec: 0.92821, prc: 0.99782, f1: 0.96176, f1_macro: 0.98006
# epoch: 1, passed number of graphs: 768, train running loss: 0.02062 (passed time: 2m 49s)
#           acc: 0.99702, fpr: 0.00014, fnr: 0.06790, rec: 0.93210, prc: 0.99655, f1: 0.96325, f1_macro: 0.98085
# Validation --- epoch: 1, loss: 1.78297
#           rec: 0.33156, prc: 0.02932, fnr: 0.66844, fpr: 0.24108, f1: 0.05386, acc: 0.74972, f1_macro: 0.45480
# Better model saved at ./saved_models/GIN_0: 0.053864353126480864.pt.
# epoch: 2, passed number of graphs: 96, train running loss: 0.01313 (passed time: 3m 50s)
#           acc: 0.99731, fpr: 0.00005, fnr: 0.06174, rec: 0.93826, prc: 0.99879, f1: 0.96758, f1_macro: 0.98309
# epoch: 2, passed number of graphs: 192, train running loss: 0.01045 (passed time: 4m 11s)
#           acc: 0.99963, fpr: 0.00014, fnr: 0.00547, rec: 0.99453, prc: 0.99676, f1: 0.99564, f1_macro: 0.99773
# epoch: 2, passed number of graphs: 288, train running loss: 0.01700 (passed time: 4m 31s)
#           acc: 0.99458, fpr: 0.00367, fnr: 0.04565, rec: 0.95435, prc: 0.91880, f1: 0.93624, f1_macro: 0.96670
# epoch: 2, passed number of graphs: 384, train running loss: 0.01482 (passed time: 4m 52s)
#           acc: 0.99913, fpr: 0.00005, fnr: 0.01906, rec: 0.98094, prc: 0.99892, f1: 0.98985, f1_macro: 0.99470
# epoch: 2, passed number of graphs: 480, train running loss: 0.01287 (passed time: 5m 13s)
#           acc: 0.99958, fpr: 0.00015, fnr: 0.00640, rec: 0.99360, prc: 0.99658, f1: 0.99509, f1_macro: 0.99744
# epoch: 2, passed number of graphs: 576, train running loss: 0.01181 (passed time: 5m 34s)
#           acc: 0.99868, fpr: 0.00053, fnr: 0.01926, rec: 0.98074, prc: 0.98778, f1: 0.98425, f1_macro: 0.99178
# epoch: 2, passed number of graphs: 672, train running loss: 0.01122 (passed time: 5m 55s)
#           acc: 0.99710, fpr: 0.00012, fnr: 0.06530, rec: 0.93470, prc: 0.99723, f1: 0.96495, f1_macro: 0.98172
# epoch: 2, passed number of graphs: 768, train running loss: 0.01009 (passed time: 6m 16s)
#           acc: 0.99914, fpr: 0.00016, fnr: 0.01673, rec: 0.98327, prc: 0.99622, f1: 0.98971, f1_macro: 0.99463
# Validation --- epoch: 2, loss: 0.02421
#           rec: 0.81843, prc: 0.99995, fnr: 0.18157, fpr: 0.00000, f1: 0.89390, acc: 0.99609, f1_macro: 0.94595
# Better model saved at ./saved_models/GIN_1: 0.8938984500829775.pt.
# epoch: 3, passed number of graphs: 96, train running loss: 0.00301 (passed time: 6m 59s)
#           acc: 0.99970, fpr: 0.00016, fnr: 0.00332, rec: 0.99668, prc: 0.99636, f1: 0.99652, f1_macro: 0.99818
# epoch: 3, passed number of graphs: 192, train running loss: 0.00387 (passed time: 7m 20s)
#           acc: 0.99742, fpr: 0.00013, fnr: 0.05836, rec: 0.94164, prc: 0.99693, f1: 0.96850, f1_macro: 0.98358
# epoch: 3, passed number of graphs: 288, train running loss: 0.00406 (passed time: 7m 40s)
#           acc: 0.99939, fpr: 0.00015, fnr: 0.01121, rec: 0.98879, prc: 0.99657, f1: 0.99267, f1_macro: 0.99617
# epoch: 3, passed number of graphs: 384, train running loss: 0.00349 (passed time: 8m 1s)
#           acc: 0.99966, fpr: 0.00023, fnr: 0.00278, rec: 0.99722, prc: 0.99486, f1: 0.99604, f1_macro: 0.99793
# epoch: 3, passed number of graphs: 480, train running loss: 0.00337 (passed time: 8m 22s)
#           acc: 0.99966, fpr: 0.00023, fnr: 0.00282, rec: 0.99718, prc: 0.99494, f1: 0.99606, f1_macro: 0.99794
# epoch: 3, passed number of graphs: 576, train running loss: 0.00315 (passed time: 8m 43s)
#           acc: 0.99960, fpr: 0.00012, fnr: 0.00697, rec: 0.99303, prc: 0.99737, f1: 0.99519, f1_macro: 0.99749
# epoch: 3, passed number of graphs: 672, train running loss: 0.00322 (passed time: 9m 4s)
#           acc: 0.99937, fpr: 0.00047, fnr: 0.00414, rec: 0.99586, prc: 0.98944, f1: 0.99264, f1_macro: 0.99616
# epoch: 3, passed number of graphs: 768, train running loss: 0.00309 (passed time: 9m 25s)
#           acc: 0.99973, fpr: 0.00009, fnr: 0.00455, rec: 0.99545, prc: 0.99801, f1: 0.99672, f1_macro: 0.99829
# Validation --- epoch: 3, loss: 0.02672
#           rec: 0.98692, prc: 0.74556, fnr: 0.01308, fpr: 0.00739, f1: 0.84889, acc: 0.99249, f1_macro: 0.92252
# epoch: 4, passed number of graphs: 96, train running loss: 0.00196 (passed time: 10m 8s)
#           acc: 0.99989, fpr: 0.00007, fnr: 0.00097, rec: 0.99903, prc: 0.99846, f1: 0.99874, f1_macro: 0.99934
# epoch: 4, passed number of graphs: 192, train running loss: 0.00877 (passed time: 10m 29s)
#           acc: 0.99890, fpr: 0.00057, fnr: 0.01326, rec: 0.98674, prc: 0.98706, f1: 0.98690, f1_macro: 0.99316
# epoch: 4, passed number of graphs: 288, train running loss: 0.00831 (passed time: 10m 49s)
#           acc: 0.99965, fpr: 0.00020, fnr: 0.00374, rec: 0.99626, prc: 0.99544, f1: 0.99585, f1_macro: 0.99784
# epoch: 4, passed number of graphs: 384, train running loss: 0.00667 (passed time: 11m 10s)
#           acc: 0.99983, fpr: 0.00009, fnr: 0.00204, rec: 0.99796, prc: 0.99804, f1: 0.99800, f1_macro: 0.99895
# epoch: 4, passed number of graphs: 480, train running loss: 0.00579 (passed time: 11m 31s)
#           acc: 0.99980, fpr: 0.00005, fnr: 0.00374, rec: 0.99626, prc: 0.99892, f1: 0.99759, f1_macro: 0.99874
# epoch: 4, passed number of graphs: 576, train running loss: 0.00609 (passed time: 11m 52s)
#           acc: 0.95887, fpr: 0.00647, fnr: 0.82846, rec: 0.17154, prc: 0.53860, f1: 0.26021, f1_macro: 0.61953
# epoch: 4, passed number of graphs: 672, train running loss: 0.00697 (passed time: 12m 13s)
#           acc: 0.99645, fpr: 0.00012, fnr: 0.08047, rec: 0.91953, prc: 0.99701, f1: 0.95670, f1_macro: 0.97743
# epoch: 4, passed number of graphs: 768, train running loss: 0.00645 (passed time: 12m 34s)
#           acc: 0.99972, fpr: 0.00006, fnr: 0.00530, rec: 0.99470, prc: 0.99859, f1: 0.99664, f1_macro: 0.99825
# Validation --- epoch: 4, loss: 0.00234
#           rec: 0.98748, prc: 0.99903, fnr: 0.01252, fpr: 0.00002, f1: 0.99244, acc: 0.99971, f1_macro: 0.99615
# Better model saved at ./saved_models/GIN_3: 0.9924424099067789.pt.
# epoch: 5, passed number of graphs: 96, train running loss: 0.00600 (passed time: 13m 16s)
#           acc: 0.99976, fpr: 0.00003, fnr: 0.00494, rec: 0.99506, prc: 0.99935, f1: 0.99720, f1_macro: 0.99854
# epoch: 5, passed number of graphs: 192, train running loss: 0.00489 (passed time: 13m 37s)
#           acc: 0.99981, fpr: 0.00001, fnr: 0.00414, rec: 0.99586, prc: 0.99967, f1: 0.99776, f1_macro: 0.99883
# epoch: 5, passed number of graphs: 288, train running loss: 0.00365 (passed time: 13m 58s)
#           acc: 0.99975, fpr: 0.00015, fnr: 0.00241, rec: 0.99759, prc: 0.99652, f1: 0.99705, f1_macro: 0.99846
# epoch: 5, passed number of graphs: 384, train running loss: 0.00304 (passed time: 14m 19s)
#           acc: 0.99973, fpr: 0.00016, fnr: 0.00270, rec: 0.99730, prc: 0.99649, f1: 0.99689, f1_macro: 0.99838
# epoch: 5, passed number of graphs: 480, train running loss: 0.00284 (passed time: 14m 40s)
#           acc: 0.99983, fpr: 0.00007, fnr: 0.00249, rec: 0.99751, prc: 0.99842, f1: 0.99796, f1_macro: 0.99894
# epoch: 5, passed number of graphs: 576, train running loss: 0.00272 (passed time: 15m 0s)
#           acc: 0.99974, fpr: 0.00016, fnr: 0.00262, rec: 0.99738, prc: 0.99640, f1: 0.99689, f1_macro: 0.99837
# epoch: 5, passed number of graphs: 672, train running loss: 0.00258 (passed time: 15m 21s)
#           acc: 0.99873, fpr: 0.00028, fnr: 0.02344, rec: 0.97656, prc: 0.99364, f1: 0.98503, f1_macro: 0.99218
# epoch: 5, passed number of graphs: 768, train running loss: 0.00257 (passed time: 15m 42s)
#           acc: 0.99948, fpr: 0.00001, fnr: 0.01209, rec: 0.98791, prc: 0.99966, f1: 0.99375, f1_macro: 0.99674
# Validation --- epoch: 5, loss: 0.00529
#           rec: 0.96393, prc: 0.99953, fnr: 0.03607, fpr: 0.00001, f1: 0.97988, acc: 0.99921, f1_macro: 0.98974
# epoch: 6, passed number of graphs: 96, train running loss: 0.00223 (passed time: 16m 25s)
#           acc: 0.99978, fpr: 0.00003, fnr: 0.00470, rec: 0.99530, prc: 0.99943, f1: 0.99736, f1_macro: 0.99862
# epoch: 6, passed number of graphs: 192, train running loss: 0.00198 (passed time: 16m 46s)
#           acc: 0.99985, fpr: 0.00005, fnr: 0.00232, rec: 0.99768, prc: 0.99884, f1: 0.99826, f1_macro: 0.99909
# epoch: 6, passed number of graphs: 288, train running loss: 0.00306 (passed time: 17m 7s)
#           acc: 0.99947, fpr: 0.00004, fnr: 0.01179, rec: 0.98821, prc: 0.99899, f1: 0.99357, f1_macro: 0.99665
# epoch: 6, passed number of graphs: 384, train running loss: 0.00273 (passed time: 17m 27s)
#           acc: 0.99971, fpr: 0.00009, fnr: 0.00491, rec: 0.99509, prc: 0.99811, f1: 0.99660, f1_macro: 0.99822
# epoch: 6, passed number of graphs: 480, train running loss: 0.00279 (passed time: 17m 48s)
#           acc: 0.99975, fpr: 0.00019, fnr: 0.00158, rec: 0.99842, prc: 0.99569, f1: 0.99706, f1_macro: 0.99846
# epoch: 6, passed number of graphs: 576, train running loss: 0.00248 (passed time: 18m 9s)
#           acc: 0.99964, fpr: 0.00033, fnr: 0.00107, rec: 0.99893, prc: 0.99259, f1: 0.99575, f1_macro: 0.99778
# epoch: 6, passed number of graphs: 672, train running loss: 0.00231 (passed time: 18m 30s)
#           acc: 0.99946, fpr: 0.00046, fnr: 0.00235, rec: 0.99765, prc: 0.98986, f1: 0.99374, f1_macro: 0.99673
# epoch: 6, passed number of graphs: 768, train running loss: 0.00222 (passed time: 18m 51s)
#           acc: 0.99982, fpr: 0.00007, fnr: 0.00290, rec: 0.99710, prc: 0.99851, f1: 0.99780, f1_macro: 0.99885
# Validation --- epoch: 6, loss: 0.00179
#           rec: 0.99277, prc: 0.99578, fnr: 0.00723, fpr: 0.00010, f1: 0.99363, acc: 0.99974, f1_macro: 0.99675
# Better model saved at ./saved_models/GIN_5: 0.99362945194152.pt.
# epoch: 7, passed number of graphs: 96, train running loss: 0.00081 (passed time: 19m 33s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00089, rec: 0.99911, prc: 0.99935, f1: 0.99923, f1_macro: 0.99960
# epoch: 7, passed number of graphs: 192, train running loss: 0.00080 (passed time: 19m 54s)
#           acc: 0.99976, fpr: 0.00004, fnr: 0.00489, rec: 0.99511, prc: 0.99908, f1: 0.99709, f1_macro: 0.99848
# epoch: 7, passed number of graphs: 288, train running loss: 0.00072 (passed time: 20m 15s)
#           acc: 0.99978, fpr: 0.00017, fnr: 0.00141, rec: 0.99859, prc: 0.99619, f1: 0.99739, f1_macro: 0.99864
# epoch: 7, passed number of graphs: 384, train running loss: 0.00077 (passed time: 20m 36s)
#           acc: 0.99972, fpr: 0.00010, fnr: 0.00409, rec: 0.99591, prc: 0.99771, f1: 0.99681, f1_macro: 0.99833
# epoch: 7, passed number of graphs: 480, train running loss: 0.00082 (passed time: 20m 56s)
#           acc: 0.99974, fpr: 0.00010, fnr: 0.00374, rec: 0.99626, prc: 0.99767, f1: 0.99697, f1_macro: 0.99842
# epoch: 7, passed number of graphs: 576, train running loss: 0.00078 (passed time: 21m 17s)
#           acc: 0.99973, fpr: 0.00021, fnr: 0.00172, rec: 0.99828, prc: 0.99534, f1: 0.99681, f1_macro: 0.99833
# epoch: 7, passed number of graphs: 672, train running loss: 0.00329 (passed time: 21m 38s)
#           acc: 0.95827, fpr: 0.00073, fnr: 0.96195, rec: 0.03805, prc: 0.69792, f1: 0.07216, f1_macro: 0.52541
# epoch: 7, passed number of graphs: 768, train running loss: 0.00423 (passed time: 21m 59s)
#           acc: 0.99979, fpr: 0.00005, fnr: 0.00381, rec: 0.99619, prc: 0.99884, f1: 0.99751, f1_macro: 0.99870
# Validation --- epoch: 7, loss: 0.13653
#           rec: 0.00175, prc: 0.14812, fnr: 0.99825, fpr: 0.00003, f1: 0.00343, acc: 0.97849, f1_macro: nan
# epoch: 8, passed number of graphs: 96, train running loss: 0.00262 (passed time: 22m 42s)
#           acc: 0.99983, fpr: 0.00002, fnr: 0.00340, rec: 0.99660, prc: 0.99951, f1: 0.99805, f1_macro: 0.99898
# epoch: 8, passed number of graphs: 192, train running loss: 0.00467 (passed time: 23m 2s)
#           acc: 0.99986, fpr: 0.00003, fnr: 0.00249, rec: 0.99751, prc: 0.99925, f1: 0.99838, f1_macro: 0.99916
# epoch: 8, passed number of graphs: 288, train running loss: 0.00406 (passed time: 23m 23s)
#           acc: 0.99975, fpr: 0.00019, fnr: 0.00174, rec: 0.99826, prc: 0.99569, f1: 0.99697, f1_macro: 0.99842
# epoch: 8, passed number of graphs: 384, train running loss: 0.00369 (passed time: 23m 44s)
#           acc: 0.99973, fpr: 0.00007, fnr: 0.00458, rec: 0.99542, prc: 0.99844, f1: 0.99693, f1_macro: 0.99839
# epoch: 8, passed number of graphs: 480, train running loss: 0.00361 (passed time: 24m 5s)
#           acc: 0.99934, fpr: 0.00059, fnr: 0.00233, rec: 0.99767, prc: 0.98693, f1: 0.99227, f1_macro: 0.99596
# epoch: 8, passed number of graphs: 576, train running loss: 0.00323 (passed time: 24m 26s)
#           acc: 0.99970, fpr: 0.00021, fnr: 0.00221, rec: 0.99779, prc: 0.99518, f1: 0.99648, f1_macro: 0.99816
# epoch: 8, passed number of graphs: 672, train running loss: 0.00297 (passed time: 24m 46s)
#           acc: 0.99952, fpr: 0.00036, fnr: 0.00316, rec: 0.99684, prc: 0.99201, f1: 0.99442, f1_macro: 0.99708
# epoch: 8, passed number of graphs: 768, train running loss: 0.00281 (passed time: 25m 7s)
#           acc: 0.99965, fpr: 0.00002, fnr: 0.00803, rec: 0.99197, prc: 0.99958, f1: 0.99576, f1_macro: 0.99779
# Validation --- epoch: 8, loss: 0.01343
#           rec: 0.90542, prc: 0.99984, fnr: 0.09458, fpr: 0.00000, f1: 0.94764, acc: 0.99796, f1_macro: 0.97330
# epoch: 9, passed number of graphs: 96, train running loss: 0.00114 (passed time: 25m 50s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00113, rec: 0.99887, prc: 0.99943, f1: 0.99915, f1_macro: 0.99956
# epoch: 9, passed number of graphs: 192, train running loss: 0.00104 (passed time: 26m 11s)
#           acc: 0.99986, fpr: 0.00005, fnr: 0.00232, rec: 0.99768, prc: 0.99892, f1: 0.99830, f1_macro: 0.99911
# epoch: 9, passed number of graphs: 288, train running loss: 0.00095 (passed time: 26m 32s)
#           acc: 0.99974, fpr: 0.00018, fnr: 0.00199, rec: 0.99801, prc: 0.99586, f1: 0.99693, f1_macro: 0.99840
# epoch: 9, passed number of graphs: 384, train running loss: 0.00093 (passed time: 26m 53s)
#           acc: 0.99974, fpr: 0.00011, fnr: 0.00352, rec: 0.99648, prc: 0.99763, f1: 0.99705, f1_macro: 0.99846
# epoch: 9, passed number of graphs: 480, train running loss: 0.00095 (passed time: 27m 13s)
#           acc: 0.99977, fpr: 0.00009, fnr: 0.00332, rec: 0.99668, prc: 0.99792, f1: 0.99730, f1_macro: 0.99859
# epoch: 9, passed number of graphs: 576, train running loss: 0.00091 (passed time: 27m 34s)
#           acc: 0.99976, fpr: 0.00017, fnr: 0.00172, rec: 0.99828, prc: 0.99607, f1: 0.99718, f1_macro: 0.99853
# epoch: 9, passed number of graphs: 672, train running loss: 0.00089 (passed time: 27m 55s)
#           acc: 0.99954, fpr: 0.00041, fnr: 0.00162, rec: 0.99838, prc: 0.99090, f1: 0.99463, f1_macro: 0.99719
# epoch: 9, passed number of graphs: 768, train running loss: 0.00093 (passed time: 28m 16s)
#           acc: 0.99988, fpr: 0.00005, fnr: 0.00190, rec: 0.99810, prc: 0.99892, f1: 0.99851, f1_macro: 0.99922
# Validation --- epoch: 9, loss: 0.00214
#           rec: 0.98575, prc: 0.99881, fnr: 0.01425, fpr: 0.00003, f1: 0.99149, acc: 0.99967, f1_macro: 0.99566
# epoch: 10, passed number of graphs: 96, train running loss: 0.00088 (passed time: 28m 59s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00097, rec: 0.99903, prc: 0.99935, f1: 0.99919, f1_macro: 0.99958
# epoch: 10, passed number of graphs: 192, train running loss: 0.00083 (passed time: 29m 20s)
#           acc: 0.99986, fpr: 0.00004, fnr: 0.00224, rec: 0.99776, prc: 0.99900, f1: 0.99838, f1_macro: 0.99916
# epoch: 10, passed number of graphs: 288, train running loss: 0.00075 (passed time: 29m 41s)
#           acc: 0.99974, fpr: 0.00017, fnr: 0.00232, rec: 0.99768, prc: 0.99602, f1: 0.99685, f1_macro: 0.99836
# epoch: 10, passed number of graphs: 384, train running loss: 0.00078 (passed time: 30m 1s)
#           acc: 0.99982, fpr: 0.00008, fnr: 0.00237, rec: 0.99763, prc: 0.99820, f1: 0.99791, f1_macro: 0.99891
# epoch: 10, passed number of graphs: 480, train running loss: 0.00083 (passed time: 30m 22s)
#           acc: 0.99981, fpr: 0.00012, fnr: 0.00183, rec: 0.99817, prc: 0.99734, f1: 0.99776, f1_macro: 0.99883
# epoch: 10, passed number of graphs: 576, train running loss: 0.00079 (passed time: 30m 43s)
#           acc: 0.99974, fpr: 0.00017, fnr: 0.00229, rec: 0.99771, prc: 0.99607, f1: 0.99689, f1_macro: 0.99838
# epoch: 10, passed number of graphs: 672, train running loss: 0.00080 (passed time: 31m 4s)
#           acc: 0.99956, fpr: 0.00032, fnr: 0.00308, rec: 0.99692, prc: 0.99281, f1: 0.99486, f1_macro: 0.99731
# epoch: 10, passed number of graphs: 768, train running loss: 0.00081 (passed time: 31m 24s)
#           acc: 0.99985, fpr: 0.00004, fnr: 0.00273, rec: 0.99727, prc: 0.99909, f1: 0.99818, f1_macro: 0.99905
# Validation --- epoch: 10, loss: 0.00145
#           rec: 0.99340, prc: 0.99755, fnr: 0.00660, fpr: 0.00005, f1: 0.99492, acc: 0.99980, f1_macro: 0.99741
# Better model saved at ./saved_models/GIN_9: 0.9949196173233937.pt.
# epoch: 11, passed number of graphs: 96, train running loss: 0.00068 (passed time: 32m 8s)
#           acc: 0.99992, fpr: 0.00003, fnr: 0.00122, rec: 0.99878, prc: 0.99935, f1: 0.99907, f1_macro: 0.99951
# epoch: 11, passed number of graphs: 192, train running loss: 0.00074 (passed time: 32m 28s)
#           acc: 0.99980, fpr: 0.00005, fnr: 0.00348, rec: 0.99652, prc: 0.99884, f1: 0.99768, f1_macro: 0.99879
# epoch: 11, passed number of graphs: 288, train running loss: 0.00070 (passed time: 32m 49s)
#           acc: 0.99974, fpr: 0.00022, fnr: 0.00125, rec: 0.99875, prc: 0.99504, f1: 0.99689, f1_macro: 0.99838
# epoch: 11, passed number of graphs: 384, train running loss: 0.00067 (passed time: 33m 10s)
#           acc: 0.99981, fpr: 0.00007, fnr: 0.00278, rec: 0.99722, prc: 0.99844, f1: 0.99783, f1_macro: 0.99887
# epoch: 11, passed number of graphs: 480, train running loss: 0.00072 (passed time: 33m 31s)
#           acc: 0.99980, fpr: 0.00011, fnr: 0.00224, rec: 0.99776, prc: 0.99743, f1: 0.99759, f1_macro: 0.99874
# epoch: 11, passed number of graphs: 576, train running loss: 0.00070 (passed time: 33m 52s)
#           acc: 0.99969, fpr: 0.00026, fnr: 0.00164, rec: 0.99836, prc: 0.99421, f1: 0.99628, f1_macro: 0.99806
# epoch: 11, passed number of graphs: 672, train running loss: 0.00069 (passed time: 34m 12s)
#           acc: 0.99953, fpr: 0.00034, fnr: 0.00333, rec: 0.99667, prc: 0.99241, f1: 0.99454, f1_macro: 0.99715
# epoch: 11, passed number of graphs: 768, train running loss: 0.00073 (passed time: 34m 33s)
#           acc: 0.99975, fpr: 0.00002, fnr: 0.00547, rec: 0.99453, prc: 0.99958, f1: 0.99705, f1_macro: 0.99846
# Validation --- epoch: 11, loss: 0.16678
#           rec: 0.00000, prc: -1.00000, fnr: 1.00000, fpr: 0.00000, f1: 0.00000, acc: 0.97848, f1_macro: nan
# epoch: 12, passed number of graphs: 96, train running loss: 0.00073 (passed time: 35m 16s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00089, rec: 0.99911, prc: 0.99927, f1: 0.99919, f1_macro: 0.99958
# epoch: 12, passed number of graphs: 192, train running loss: 0.00071 (passed time: 35m 37s)
#           acc: 0.99982, fpr: 0.00004, fnr: 0.00332, rec: 0.99668, prc: 0.99900, f1: 0.99784, f1_macro: 0.99887
# epoch: 12, passed number of graphs: 288, train running loss: 0.00063 (passed time: 35m 58s)
#           acc: 0.99976, fpr: 0.00016, fnr: 0.00191, rec: 0.99809, prc: 0.99627, f1: 0.99718, f1_macro: 0.99853
# epoch: 12, passed number of graphs: 384, train running loss: 0.00064 (passed time: 36m 19s)
#           acc: 0.99982, fpr: 0.00009, fnr: 0.00221, rec: 0.99779, prc: 0.99795, f1: 0.99787, f1_macro: 0.99889
# epoch: 12, passed number of graphs: 480, train running loss: 0.00068 (passed time: 36m 39s)
#           acc: 0.99976, fpr: 0.00014, fnr: 0.00258, rec: 0.99742, prc: 0.99685, f1: 0.99713, f1_macro: 0.99850
# epoch: 12, passed number of graphs: 576, train running loss: 0.00065 (passed time: 37m 0s)
#           acc: 0.99972, fpr: 0.00018, fnr: 0.00246, rec: 0.99754, prc: 0.99583, f1: 0.99668, f1_macro: 0.99827
# epoch: 12, passed number of graphs: 672, train running loss: 0.00065 (passed time: 37m 21s)
#           acc: 0.99953, fpr: 0.00039, fnr: 0.00227, rec: 0.99773, prc: 0.99130, f1: 0.99450, f1_macro: 0.99713
# epoch: 12, passed number of graphs: 768, train running loss: 0.00072 (passed time: 37m 42s)
#           acc: 0.99913, fpr: 0.00002, fnr: 0.02029, rec: 0.97971, prc: 0.99958, f1: 0.98954, f1_macro: 0.99455
# Validation --- epoch: 12, loss: 0.11561
#           rec: 0.10169, prc: 0.56248, fnr: 0.89831, fpr: 0.00000, f1: 0.16957, acc: 0.98066, f1_macro: nan
# epoch: 13, passed number of graphs: 96, train running loss: 0.00190 (passed time: 38m 25s)
#           acc: 0.99987, fpr: 0.00003, fnr: 0.00243, rec: 0.99757, prc: 0.99935, f1: 0.99846, f1_macro: 0.99920
# epoch: 13, passed number of graphs: 192, train running loss: 0.00129 (passed time: 38m 46s)
#           acc: 0.99983, fpr: 0.00005, fnr: 0.00307, rec: 0.99693, prc: 0.99892, f1: 0.99793, f1_macro: 0.99892
# epoch: 13, passed number of graphs: 288, train running loss: 0.00103 (passed time: 39m 6s)
#           acc: 0.99978, fpr: 0.00010, fnr: 0.00291, rec: 0.99709, prc: 0.99759, f1: 0.99734, f1_macro: 0.99861
# epoch: 13, passed number of graphs: 384, train running loss: 0.00094 (passed time: 39m 27s)
#           acc: 0.99977, fpr: 0.00010, fnr: 0.00303, rec: 0.99697, prc: 0.99779, f1: 0.99738, f1_macro: 0.99863
# epoch: 13, passed number of graphs: 480, train running loss: 0.00090 (passed time: 39m 48s)
#           acc: 0.99980, fpr: 0.00013, fnr: 0.00199, rec: 0.99801, prc: 0.99718, f1: 0.99759, f1_macro: 0.99874
# epoch: 13, passed number of graphs: 576, train running loss: 0.00084 (passed time: 40m 9s)
#           acc: 0.99973, fpr: 0.00018, fnr: 0.00213, rec: 0.99787, prc: 0.99583, f1: 0.99685, f1_macro: 0.99835
# epoch: 13, passed number of graphs: 672, train running loss: 0.00081 (passed time: 40m 29s)
#           acc: 0.99951, fpr: 0.00036, fnr: 0.00324, rec: 0.99676, prc: 0.99185, f1: 0.99429, f1_macro: 0.99702
# epoch: 13, passed number of graphs: 768, train running loss: 0.00081 (passed time: 40m 50s)
#           acc: 0.99985, fpr: 0.00009, fnr: 0.00141, rec: 0.99859, prc: 0.99793, f1: 0.99826, f1_macro: 0.99909
# Validation --- epoch: 13, loss: 0.00131
#           rec: 0.99363, prc: 0.99718, fnr: 0.00637, fpr: 0.00006, f1: 0.99485, acc: 0.99980, f1_macro: 0.99737
# epoch: 14, passed number of graphs: 96, train running loss: 0.00056 (passed time: 41m 33s)
#           acc: 0.99991, fpr: 0.00003, fnr: 0.00146, rec: 0.99854, prc: 0.99943, f1: 0.99899, f1_macro: 0.99947
# epoch: 14, passed number of graphs: 192, train running loss: 0.00059 (passed time: 41m 54s)
#           acc: 0.99988, fpr: 0.00005, fnr: 0.00157, rec: 0.99843, prc: 0.99884, f1: 0.99863, f1_macro: 0.99929
# epoch: 14, passed number of graphs: 288, train running loss: 0.00055 (passed time: 42m 14s)
#           acc: 0.99978, fpr: 0.00016, fnr: 0.00158, rec: 0.99842, prc: 0.99636, f1: 0.99739, f1_macro: 0.99864
# epoch: 14, passed number of graphs: 384, train running loss: 0.00056 (passed time: 42m 35s)
#           acc: 0.99980, fpr: 0.00013, fnr: 0.00164, rec: 0.99836, prc: 0.99714, f1: 0.99775, f1_macro: 0.99882
# epoch: 14, passed number of graphs: 480, train running loss: 0.00059 (passed time: 42m 56s)
#           acc: 0.99978, fpr: 0.00014, fnr: 0.00191, rec: 0.99809, prc: 0.99685, f1: 0.99747, f1_macro: 0.99868
# epoch: 14, passed number of graphs: 576, train running loss: 0.00057 (passed time: 43m 17s)
#           acc: 0.99973, fpr: 0.00018, fnr: 0.00213, rec: 0.99787, prc: 0.99583, f1: 0.99685, f1_macro: 0.99835
# epoch: 14, passed number of graphs: 672, train running loss: 0.00058 (passed time: 43m 37s)
#           acc: 0.99953, fpr: 0.00040, fnr: 0.00211, rec: 0.99789, prc: 0.99106, f1: 0.99446, f1_macro: 0.99711
# epoch: 14, passed number of graphs: 768, train running loss: 0.00059 (passed time: 43m 58s)
#           acc: 0.99984, fpr: 0.00010, fnr: 0.00149, rec: 0.99851, prc: 0.99777, f1: 0.99814, f1_macro: 0.99903
# Validation --- epoch: 14, loss: 0.15932
#           rec: 0.00320, prc: -0.50000, fnr: 0.99680, fpr: 0.00000, f1: 0.00598, acc: 0.97855, f1_macro: nan
# epoch: 15, passed number of graphs: 96, train running loss: 0.00054 (passed time: 44m 41s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00097, rec: 0.99903, prc: 0.99935, f1: 0.99919, f1_macro: 0.99958
# epoch: 15, passed number of graphs: 192, train running loss: 0.00056 (passed time: 45m 2s)
#           acc: 0.99989, fpr: 0.00004, fnr: 0.00174, rec: 0.99826, prc: 0.99909, f1: 0.99867, f1_macro: 0.99931
# epoch: 15, passed number of graphs: 288, train running loss: 0.00052 (passed time: 45m 23s)
#           acc: 0.99978, fpr: 0.00016, fnr: 0.00158, rec: 0.99842, prc: 0.99636, f1: 0.99739, f1_macro: 0.99864
# epoch: 15, passed number of graphs: 384, train running loss: 0.00055 (passed time: 45m 43s)
#           acc: 0.99978, fpr: 0.00013, fnr: 0.00221, rec: 0.99779, prc: 0.99706, f1: 0.99742, f1_macro: 0.99865
# epoch: 15, passed number of graphs: 480, train running loss: 0.00058 (passed time: 46m 4s)
#           acc: 0.99976, fpr: 0.00017, fnr: 0.00183, rec: 0.99817, prc: 0.99627, f1: 0.99722, f1_macro: 0.99855
# epoch: 15, passed number of graphs: 576, train running loss: 0.00056 (passed time: 46m 25s)
#           acc: 0.99971, fpr: 0.00023, fnr: 0.00164, rec: 0.99836, prc: 0.99485, f1: 0.99660, f1_macro: 0.99823
# epoch: 15, passed number of graphs: 672, train running loss: 0.00055 (passed time: 46m 46s)
#           acc: 0.99954, fpr: 0.00033, fnr: 0.00341, rec: 0.99659, prc: 0.99265, f1: 0.99462, f1_macro: 0.99719
# epoch: 15, passed number of graphs: 768, train running loss: 0.00056 (passed time: 47m 6s)
#           acc: 0.99985, fpr: 0.00008, fnr: 0.00174, rec: 0.99826, prc: 0.99826, f1: 0.99826, f1_macro: 0.99909
# Validation --- epoch: 15, loss: 0.18085
#           rec: 0.00000, prc: -1.00000, fnr: 1.00000, fpr: 0.00000, f1: 0.00000, acc: 0.97848, f1_macro: nan
# epoch: 16, passed number of graphs: 96, train running loss: 0.00054 (passed time: 47m 50s)
#           acc: 0.99991, fpr: 0.00004, fnr: 0.00138, rec: 0.99862, prc: 0.99919, f1: 0.99891, f1_macro: 0.99943
# epoch: 16, passed number of graphs: 192, train running loss: 0.00055 (passed time: 48m 10s)
#           acc: 0.99984, fpr: 0.00004, fnr: 0.00274, rec: 0.99726, prc: 0.99900, f1: 0.99813, f1_macro: 0.99903
# epoch: 16, passed number of graphs: 288, train running loss: 0.00051 (passed time: 48m 31s)
#           acc: 0.99975, fpr: 0.00019, fnr: 0.00149, rec: 0.99851, prc: 0.99561, f1: 0.99706, f1_macro: 0.99846
# epoch: 16, passed number of graphs: 384, train running loss: 0.00052 (passed time: 48m 52s)
#           acc: 0.99979, fpr: 0.00011, fnr: 0.00254, rec: 0.99746, prc: 0.99763, f1: 0.99755, f1_macro: 0.99872
# epoch: 16, passed number of graphs: 480, train running loss: 0.00054 (passed time: 49m 12s)
#           acc: 0.99982, fpr: 0.00014, fnr: 0.00108, rec: 0.99892, prc: 0.99677, f1: 0.99784, f1_macro: 0.99887
# epoch: 16, passed number of graphs: 576, train running loss: 0.00052 (passed time: 49m 33s)
#           acc: 0.99974, fpr: 0.00019, fnr: 0.00172, rec: 0.99828, prc: 0.99559, f1: 0.99693, f1_macro: 0.99840
# epoch: 16, passed number of graphs: 672, train running loss: 0.00052 (passed time: 49m 54s)
#           acc: 0.99951, fpr: 0.00042, fnr: 0.00203, rec: 0.99797, prc: 0.99058, f1: 0.99426, f1_macro: 0.99700
# epoch: 16, passed number of graphs: 768, train running loss: 0.00053 (passed time: 50m 15s)
#           acc: 0.99985, fpr: 0.00010, fnr: 0.00116, rec: 0.99884, prc: 0.99760, f1: 0.99822, f1_macro: 0.99907
# Validation --- epoch: 16, loss: 0.00132
#           rec: 0.99352, prc: 0.99765, fnr: 0.00648, fpr: 0.00005, f1: 0.99503, acc: 0.99981, f1_macro: 0.99747
# Better model saved at ./saved_models/GIN_15: 0.9950334247717402.pt.
# epoch: 17, passed number of graphs: 96, train running loss: 0.00054 (passed time: 50m 58s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00113, rec: 0.99887, prc: 0.99943, f1: 0.99915, f1_macro: 0.99956
# epoch: 17, passed number of graphs: 192, train running loss: 0.00054 (passed time: 51m 19s)
#           acc: 0.99988, fpr: 0.00005, fnr: 0.00149, rec: 0.99851, prc: 0.99876, f1: 0.99863, f1_macro: 0.99929
# epoch: 17, passed number of graphs: 288, train running loss: 0.00051 (passed time: 51m 40s)
#           acc: 0.99976, fpr: 0.00018, fnr: 0.00158, rec: 0.99842, prc: 0.99586, f1: 0.99714, f1_macro: 0.99851
# epoch: 17, passed number of graphs: 384, train running loss: 0.00051 (passed time: 52m 0s)
#           acc: 0.99979, fpr: 0.00017, fnr: 0.00115, rec: 0.99885, prc: 0.99633, f1: 0.99759, f1_macro: 0.99874
# epoch: 17, passed number of graphs: 480, train running loss: 0.00054 (passed time: 52m 21s)
#           acc: 0.99979, fpr: 0.00013, fnr: 0.00208, rec: 0.99792, prc: 0.99718, f1: 0.99755, f1_macro: 0.99872
# epoch: 17, passed number of graphs: 576, train running loss: 0.00052 (passed time: 52m 42s)
#           acc: 0.99971, fpr: 0.00019, fnr: 0.00270, rec: 0.99730, prc: 0.99574, f1: 0.99652, f1_macro: 0.99818
# epoch: 17, passed number of graphs: 672, train running loss: 0.00052 (passed time: 53m 2s)
#           acc: 0.99952, fpr: 0.00034, fnr: 0.00381, rec: 0.99619, prc: 0.99248, f1: 0.99433, f1_macro: 0.99704
# epoch: 17, passed number of graphs: 768, train running loss: 0.00054 (passed time: 53m 23s)
#           acc: 0.99989, fpr: 0.00010, fnr: 0.00041, rec: 0.99959, prc: 0.99777, f1: 0.99868, f1_macro: 0.99931
# Validation --- epoch: 17, loss: 0.00144
#           rec: 0.99269, prc: 0.99772, fnr: 0.00731, fpr: 0.00005, f1: 0.99466, acc: 0.99979, f1_macro: 0.99728
# epoch: 18, passed number of graphs: 96, train running loss: 0.00052 (passed time: 54m 6s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00073, rec: 0.99927, prc: 0.99927, f1: 0.99927, f1_macro: 0.99962
# epoch: 18, passed number of graphs: 192, train running loss: 0.00053 (passed time: 54m 27s)
#           acc: 0.99984, fpr: 0.00007, fnr: 0.00216, rec: 0.99784, prc: 0.99834, f1: 0.99809, f1_macro: 0.99900
# epoch: 18, passed number of graphs: 288, train running loss: 0.00050 (passed time: 54m 48s)
#           acc: 0.99977, fpr: 0.00017, fnr: 0.00158, rec: 0.99842, prc: 0.99611, f1: 0.99726, f1_macro: 0.99857
# epoch: 18, passed number of graphs: 384, train running loss: 0.00049 (passed time: 55m 8s)
#           acc: 0.99979, fpr: 0.00010, fnr: 0.00262, rec: 0.99738, prc: 0.99771, f1: 0.99755, f1_macro: 0.99872
# epoch: 18, passed number of graphs: 480, train running loss: 0.00052 (passed time: 55m 29s)
#           acc: 0.99977, fpr: 0.00016, fnr: 0.00183, rec: 0.99817, prc: 0.99643, f1: 0.99730, f1_macro: 0.99859
# epoch: 18, passed number of graphs: 576, train running loss: 0.00051 (passed time: 55m 50s)
#           acc: 0.99965, fpr: 0.00029, fnr: 0.00172, rec: 0.99828, prc: 0.99356, f1: 0.99591, f1_macro: 0.99787
# epoch: 18, passed number of graphs: 672, train running loss: 0.00051 (passed time: 56m 10s)
#           acc: 0.99947, fpr: 0.00044, fnr: 0.00251, rec: 0.99749, prc: 0.99010, f1: 0.99378, f1_macro: 0.99675
# epoch: 18, passed number of graphs: 768, train running loss: 0.00052 (passed time: 56m 31s)
#           acc: 0.99988, fpr: 0.00008, fnr: 0.00108, rec: 0.99892, prc: 0.99810, f1: 0.99851, f1_macro: 0.99922
# Validation --- epoch: 18, loss: 0.00126
#           rec: 0.99375, prc: 0.99763, fnr: 0.00625, fpr: 0.00005, f1: 0.99514, acc: 0.99981, f1_macro: 0.99752
# Better model saved at ./saved_models/GIN_17: 0.9951375794278546.pt.
# epoch: 19, passed number of graphs: 96, train running loss: 0.00051 (passed time: 57m 14s)
#           acc: 0.99990, fpr: 0.00003, fnr: 0.00162, rec: 0.99838, prc: 0.99935, f1: 0.99887, f1_macro: 0.99941
# epoch: 19, passed number of graphs: 192, train running loss: 0.00052 (passed time: 57m 35s)
#           acc: 0.99988, fpr: 0.00005, fnr: 0.00157, rec: 0.99843, prc: 0.99876, f1: 0.99859, f1_macro: 0.99926
# epoch: 19, passed number of graphs: 288, train running loss: 0.00050 (passed time: 57m 56s)
#           acc: 0.99981, fpr: 0.00016, fnr: 0.00108, rec: 0.99892, prc: 0.99644, f1: 0.99768, f1_macro: 0.99879
# epoch: 19, passed number of graphs: 384, train running loss: 0.00051 (passed time: 58m 16s)
#           acc: 0.99980, fpr: 0.00014, fnr: 0.00164, rec: 0.99836, prc: 0.99698, f1: 0.99767, f1_macro: 0.99878
# epoch: 19, passed number of graphs: 480, train running loss: 0.00053 (passed time: 58m 37s)
#           acc: 0.99980, fpr: 0.00014, fnr: 0.00150, rec: 0.99850, prc: 0.99685, f1: 0.99768, f1_macro: 0.99879
# epoch: 19, passed number of graphs: 576, train running loss: 0.00051 (passed time: 58m 58s)
#           acc: 0.99972, fpr: 0.00020, fnr: 0.00205, rec: 0.99795, prc: 0.99550, f1: 0.99673, f1_macro: 0.99829
# epoch: 19, passed number of graphs: 672, train running loss: 0.00051 (passed time: 59m 19s)
#           acc: 0.99948, fpr: 0.00046, fnr: 0.00187, rec: 0.99813, prc: 0.98986, f1: 0.99398, f1_macro: 0.99686
# epoch: 19, passed number of graphs: 768, train running loss: 0.00052 (passed time: 59m 39s)
#           acc: 0.99989, fpr: 0.00008, fnr: 0.00099, rec: 0.99901, prc: 0.99826, f1: 0.99863, f1_macro: 0.99929
# Validation --- epoch: 19, loss: 0.00124
#           rec: 0.99408, prc: 0.99748, fnr: 0.00592, fpr: 0.00006, f1: 0.99523, acc: 0.99982, f1_macro: 0.99757
# Better model saved at ./saved_models/GIN_18: 0.9952254371023694.pt.
# epoch: 20, passed number of graphs: 96, train running loss: 0.00056 (passed time: 1h 0m 22s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00105, rec: 0.99895, prc: 0.99935, f1: 0.99915, f1_macro: 0.99956
# epoch: 20, passed number of graphs: 192, train running loss: 0.00055 (passed time: 1h 0m 43s)
#           acc: 0.99986, fpr: 0.00004, fnr: 0.00240, rec: 0.99760, prc: 0.99909, f1: 0.99834, f1_macro: 0.99913
# epoch: 20, passed number of graphs: 288, train running loss: 0.00051 (passed time: 1h 1m 4s)
#           acc: 0.99976, fpr: 0.00019, fnr: 0.00125, rec: 0.99875, prc: 0.99561, f1: 0.99718, f1_macro: 0.99853
# epoch: 20, passed number of graphs: 384, train running loss: 0.00051 (passed time: 1h 1m 25s)
#           acc: 0.99976, fpr: 0.00013, fnr: 0.00262, rec: 0.99738, prc: 0.99714, f1: 0.99726, f1_macro: 0.99857
# epoch: 20, passed number of graphs: 480, train running loss: 0.00053 (passed time: 1h 1m 45s)
#           acc: 0.99980, fpr: 0.00013, fnr: 0.00191, rec: 0.99809, prc: 0.99710, f1: 0.99759, f1_macro: 0.99874
# epoch: 20, passed number of graphs: 576, train running loss: 0.00051 (passed time: 1h 2m 6s)
#           acc: 0.99970, fpr: 0.00021, fnr: 0.00229, rec: 0.99771, prc: 0.99526, f1: 0.99648, f1_macro: 0.99816
# epoch: 20, passed number of graphs: 672, train running loss: 0.00051 (passed time: 1h 2m 27s)
#           acc: 0.99948, fpr: 0.00046, fnr: 0.00187, rec: 0.99813, prc: 0.98978, f1: 0.99394, f1_macro: 0.99684
# epoch: 20, passed number of graphs: 768, train running loss: 0.00052 (passed time: 1h 2m 48s)
#           acc: 0.99988, fpr: 0.00007, fnr: 0.00124, rec: 0.99876, prc: 0.99834, f1: 0.99855, f1_macro: 0.99924
# Validation --- epoch: 20, loss: 0.00125
#           rec: 0.99380, prc: 0.99763, fnr: 0.00620, fpr: 0.00005, f1: 0.99516, acc: 0.99981, f1_macro: 0.99753
# epoch: 21, passed number of graphs: 96, train running loss: 0.00054 (passed time: 1h 3m 30s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00089, rec: 0.99911, prc: 0.99959, f1: 0.99935, f1_macro: 0.99966
# epoch: 21, passed number of graphs: 192, train running loss: 0.00054 (passed time: 1h 3m 51s)
#           acc: 0.99988, fpr: 0.00004, fnr: 0.00191, rec: 0.99809, prc: 0.99909, f1: 0.99859, f1_macro: 0.99926
# epoch: 21, passed number of graphs: 288, train running loss: 0.00049 (passed time: 1h 4m 12s)
#           acc: 0.99978, fpr: 0.00018, fnr: 0.00108, rec: 0.99892, prc: 0.99586, f1: 0.99739, f1_macro: 0.99864
# epoch: 21, passed number of graphs: 384, train running loss: 0.00049 (passed time: 1h 4m 32s)
#           acc: 0.99980, fpr: 0.00012, fnr: 0.00204, rec: 0.99796, prc: 0.99738, f1: 0.99767, f1_macro: 0.99878
# epoch: 21, passed number of graphs: 480, train running loss: 0.00052 (passed time: 1h 4m 53s)
#           acc: 0.99983, fpr: 0.00010, fnr: 0.00166, rec: 0.99834, prc: 0.99776, f1: 0.99805, f1_macro: 0.99898
# epoch: 21, passed number of graphs: 576, train running loss: 0.00051 (passed time: 1h 5m 14s)
#           acc: 0.99972, fpr: 0.00019, fnr: 0.00221, rec: 0.99779, prc: 0.99567, f1: 0.99673, f1_macro: 0.99829
# epoch: 21, passed number of graphs: 672, train running loss: 0.00051 (passed time: 1h 5m 35s)
#           acc: 0.99957, fpr: 0.00033, fnr: 0.00260, rec: 0.99740, prc: 0.99265, f1: 0.99502, f1_macro: 0.99740
# epoch: 21, passed number of graphs: 768, train running loss: 0.00051 (passed time: 1h 5m 55s)
#           acc: 0.99986, fpr: 0.00009, fnr: 0.00124, rec: 0.99876, prc: 0.99801, f1: 0.99839, f1_macro: 0.99916
# Validation --- epoch: 21, loss: 0.00124
#           rec: 0.99414, prc: 0.99745, fnr: 0.00586, fpr: 0.00006, f1: 0.99524, acc: 0.99982, f1_macro: 0.99757
# Better model saved at ./saved_models/GIN_20: 0.9952429299056434.pt.
# epoch: 22, passed number of graphs: 96, train running loss: 0.00062 (passed time: 1h 6m 38s)
#           acc: 0.99992, fpr: 0.00003, fnr: 0.00130, rec: 0.99870, prc: 0.99935, f1: 0.99903, f1_macro: 0.99949
# epoch: 22, passed number of graphs: 192, train running loss: 0.00062 (passed time: 1h 6m 59s)
#           acc: 0.99985, fpr: 0.00006, fnr: 0.00216, rec: 0.99784, prc: 0.99867, f1: 0.99826, f1_macro: 0.99909
# epoch: 22, passed number of graphs: 288, train running loss: 0.00055 (passed time: 1h 7m 20s)
#           acc: 0.99977, fpr: 0.00018, fnr: 0.00141, rec: 0.99859, prc: 0.99586, f1: 0.99722, f1_macro: 0.99855
# epoch: 22, passed number of graphs: 384, train running loss: 0.00055 (passed time: 1h 7m 41s)
# ...
#           acc: 0.99977, fpr: 0.00018, fnr: 0.00141, rec: 0.99859, prc: 0.99594, f1: 0.99726, f1_macro: 0.99857
# epoch: 42, passed number of graphs: 384, train running loss: 0.00048 (passed time: 2h 10m 12s)
#           acc: 0.99982, fpr: 0.00010, fnr: 0.00196, rec: 0.99804, prc: 0.99771, f1: 0.99787, f1_macro: 0.99889
# epoch: 42, passed number of graphs: 480, train running loss: 0.00050 (passed time: 2h 10m 33s)
#           acc: 0.99977, fpr: 0.00016, fnr: 0.00174, rec: 0.99826, prc: 0.99635, f1: 0.99730, f1_macro: 0.99859
# epoch: 42, passed number of graphs: 576, train running loss: 0.00049 (passed time: 2h 10m 53s)
#           acc: 0.99973, fpr: 0.00020, fnr: 0.00180, rec: 0.99820, prc: 0.99542, f1: 0.99681, f1_macro: 0.99833
# epoch: 42, passed number of graphs: 672, train running loss: 0.00049 (passed time: 2h 11m 14s)
#           acc: 0.99953, fpr: 0.00038, fnr: 0.00243, rec: 0.99757, prc: 0.99153, f1: 0.99454, f1_macro: 0.99715
# epoch: 42, passed number of graphs: 768, train running loss: 0.00051 (passed time: 2h 11m 35s)
#           acc: 0.99986, fpr: 0.00009, fnr: 0.00116, rec: 0.99884, prc: 0.99793, f1: 0.99839, f1_macro: 0.99916
# Validation --- epoch: 42, loss: 0.00125
#           rec: 0.99385, prc: 0.99766, fnr: 0.00615, fpr: 0.00005, f1: 0.99520, acc: 0.99982, f1_macro: 0.99755
# epoch: 43, passed number of graphs: 96, train running loss: 0.00049 (passed time: 2h 12m 17s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00089, rec: 0.99911, prc: 0.99927, f1: 0.99919, f1_macro: 0.99958
# epoch: 43, passed number of graphs: 192, train running loss: 0.00051 (passed time: 2h 12m 38s)
#           acc: 0.99988, fpr: 0.00006, fnr: 0.00149, rec: 0.99851, prc: 0.99859, f1: 0.99855, f1_macro: 0.99924
# epoch: 43, passed number of graphs: 288, train running loss: 0.00048 (passed time: 2h 12m 59s)
#           acc: 0.99975, fpr: 0.00018, fnr: 0.00183, rec: 0.99817, prc: 0.99578, f1: 0.99697, f1_macro: 0.99842
# epoch: 43, passed number of graphs: 384, train running loss: 0.00047 (passed time: 2h 13m 20s)
#           acc: 0.99977, fpr: 0.00014, fnr: 0.00213, rec: 0.99787, prc: 0.99689, f1: 0.99738, f1_macro: 0.99863
# epoch: 43, passed number of graphs: 480, train running loss: 0.00050 (passed time: 2h 13m 40s)
#           acc: 0.99980, fpr: 0.00014, fnr: 0.00150, rec: 0.99850, prc: 0.99685, f1: 0.99768, f1_macro: 0.99879
# epoch: 43, passed number of graphs: 576, train running loss: 0.00049 (passed time: 2h 14m 1s)
#           acc: 0.99972, fpr: 0.00022, fnr: 0.00172, rec: 0.99828, prc: 0.99502, f1: 0.99665, f1_macro: 0.99825
# epoch: 43, passed number of graphs: 672, train running loss: 0.00049 (passed time: 2h 14m 22s)
#           acc: 0.99953, fpr: 0.00039, fnr: 0.00235, rec: 0.99765, prc: 0.99129, f1: 0.99446, f1_macro: 0.99711
# epoch: 43, passed number of graphs: 768, train running loss: 0.00050 (passed time: 2h 14m 42s)
#           acc: 0.99986, fpr: 0.00008, fnr: 0.00149, rec: 0.99851, prc: 0.99826, f1: 0.99839, f1_macro: 0.99916
# Validation --- epoch: 43, loss: 0.00125
#           rec: 0.99381, prc: 0.99769, fnr: 0.00619, fpr: 0.00005, f1: 0.99520, acc: 0.99982, f1_macro: 0.99755
# epoch: 44, passed number of graphs: 96, train running loss: 0.00053 (passed time: 2h 15m 25s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00105, rec: 0.99895, prc: 0.99943, f1: 0.99919, f1_macro: 0.99958
# epoch: 44, passed number of graphs: 192, train running loss: 0.00052 (passed time: 2h 15m 46s)
#           acc: 0.99987, fpr: 0.00006, fnr: 0.00174, rec: 0.99826, prc: 0.99859, f1: 0.99842, f1_macro: 0.99918
# epoch: 44, passed number of graphs: 288, train running loss: 0.00049 (passed time: 2h 16m 6s)
#           acc: 0.99977, fpr: 0.00017, fnr: 0.00149, rec: 0.99851, prc: 0.99603, f1: 0.99726, f1_macro: 0.99857
# epoch: 44, passed number of graphs: 384, train running loss: 0.00049 (passed time: 2h 16m 27s)
#           acc: 0.99983, fpr: 0.00011, fnr: 0.00155, rec: 0.99845, prc: 0.99755, f1: 0.99800, f1_macro: 0.99895
# epoch: 44, passed number of graphs: 480, train running loss: 0.00052 (passed time: 2h 16m 48s)
#           acc: 0.99982, fpr: 0.00014, fnr: 0.00108, rec: 0.99892, prc: 0.99685, f1: 0.99788, f1_macro: 0.99889
# epoch: 44, passed number of graphs: 576, train running loss: 0.00050 (passed time: 2h 17m 8s)
#           acc: 0.99973, fpr: 0.00020, fnr: 0.00197, rec: 0.99803, prc: 0.99550, f1: 0.99677, f1_macro: 0.99831
# epoch: 44, passed number of graphs: 672, train running loss: 0.00050 (passed time: 2h 17m 29s)
#           acc: 0.99947, fpr: 0.00047, fnr: 0.00178, rec: 0.99822, prc: 0.98955, f1: 0.99386, f1_macro: 0.99679
# epoch: 44, passed number of graphs: 768, train running loss: 0.00051 (passed time: 2h 17m 50s)
#           acc: 0.99985, fpr: 0.00009, fnr: 0.00132, rec: 0.99868, prc: 0.99785, f1: 0.99826, f1_macro: 0.99909
# Validation --- epoch: 44, loss: 0.00125
#           rec: 0.99382, prc: 0.99768, fnr: 0.00618, fpr: 0.00005, f1: 0.99519, acc: 0.99982, f1_macro: 0.99755
# epoch: 45, passed number of graphs: 96, train running loss: 0.00051 (passed time: 2h 18m 33s)
#           acc: 0.99994, fpr: 0.00001, fnr: 0.00113, rec: 0.99887, prc: 0.99976, f1: 0.99931, f1_macro: 0.99964
# epoch: 45, passed number of graphs: 192, train running loss: 0.00051 (passed time: 2h 18m 53s)
#           acc: 0.99988, fpr: 0.00005, fnr: 0.00182, rec: 0.99818, prc: 0.99892, f1: 0.99855, f1_macro: 0.99924
# epoch: 45, passed number of graphs: 288, train running loss: 0.00049 (passed time: 2h 19m 14s)
#           acc: 0.99976, fpr: 0.00020, fnr: 0.00116, rec: 0.99884, prc: 0.99537, f1: 0.99710, f1_macro: 0.99849
# epoch: 45, passed number of graphs: 384, train running loss: 0.00048 (passed time: 2h 19m 35s)
#           acc: 0.99978, fpr: 0.00013, fnr: 0.00204, rec: 0.99796, prc: 0.99706, f1: 0.99751, f1_macro: 0.99870
# epoch: 45, passed number of graphs: 480, train running loss: 0.00050 (passed time: 2h 19m 56s)
#           acc: 0.99980, fpr: 0.00015, fnr: 0.00125, rec: 0.99875, prc: 0.99652, f1: 0.99764, f1_macro: 0.99876
# epoch: 45, passed number of graphs: 576, train running loss: 0.00049 (passed time: 2h 20m 16s)
#           acc: 0.99973, fpr: 0.00020, fnr: 0.00189, rec: 0.99811, prc: 0.99550, f1: 0.99681, f1_macro: 0.99833
# epoch: 45, passed number of graphs: 672, train running loss: 0.00049 (passed time: 2h 20m 37s)
#           acc: 0.99947, fpr: 0.00042, fnr: 0.00300, rec: 0.99700, prc: 0.99057, f1: 0.99377, f1_macro: 0.99675
# epoch: 45, passed number of graphs: 768, train running loss: 0.00050 (passed time: 2h 20m 58s)
#           acc: 0.99983, fpr: 0.00010, fnr: 0.00190, rec: 0.99810, prc: 0.99776, f1: 0.99793, f1_macro: 0.99892
# Validation --- epoch: 45, loss: 0.00125
#           rec: 0.99381, prc: 0.99770, fnr: 0.00619, fpr: 0.00005, f1: 0.99520, acc: 0.99982, f1_macro: 0.99755
# epoch: 46, passed number of graphs: 96, train running loss: 0.00049 (passed time: 2h 21m 40s)
#           acc: 0.99992, fpr: 0.00002, fnr: 0.00138, rec: 0.99862, prc: 0.99959, f1: 0.99911, f1_macro: 0.99953
# epoch: 46, passed number of graphs: 192, train running loss: 0.00051 (passed time: 2h 22m 1s)
#           acc: 0.99987, fpr: 0.00005, fnr: 0.00182, rec: 0.99818, prc: 0.99876, f1: 0.99847, f1_macro: 0.99920
# epoch: 46, passed number of graphs: 288, train running loss: 0.00047 (passed time: 2h 22m 21s)
#           acc: 0.99977, fpr: 0.00017, fnr: 0.00149, rec: 0.99851, prc: 0.99611, f1: 0.99731, f1_macro: 0.99859
# epoch: 46, passed number of graphs: 384, train running loss: 0.00047 (passed time: 2h 22m 42s)
#           acc: 0.99981, fpr: 0.00011, fnr: 0.00180, rec: 0.99820, prc: 0.99747, f1: 0.99783, f1_macro: 0.99887
# epoch: 46, passed number of graphs: 480, train running loss: 0.00049 (passed time: 2h 23m 3s)
#           acc: 0.99975, fpr: 0.00017, fnr: 0.00199, rec: 0.99801, prc: 0.99610, f1: 0.99705, f1_macro: 0.99846
# epoch: 46, passed number of graphs: 576, train running loss: 0.00048 (passed time: 2h 23m 24s)
#           acc: 0.99975, fpr: 0.00017, fnr: 0.00221, rec: 0.99779, prc: 0.99624, f1: 0.99701, f1_macro: 0.99844
# epoch: 46, passed number of graphs: 672, train running loss: 0.00048 (passed time: 2h 23m 44s)
#           acc: 0.99952, fpr: 0.00045, fnr: 0.00122, rec: 0.99878, prc: 0.99003, f1: 0.99439, f1_macro: 0.99707
# epoch: 46, passed number of graphs: 768, train running loss: 0.00049 (passed time: 2h 24m 5s)
#           acc: 0.99984, fpr: 0.00009, fnr: 0.00182, rec: 0.99818, prc: 0.99801, f1: 0.99810, f1_macro: 0.99901
# Validation --- epoch: 46, loss: 0.00125
#           rec: 0.99384, prc: 0.99766, fnr: 0.00616, fpr: 0.00005, f1: 0.99520, acc: 0.99982, f1_macro: 0.99755
# epoch: 47, passed number of graphs: 96, train running loss: 0.00051 (passed time: 2h 24m 47s)
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00122, rec: 0.99878, prc: 0.99951, f1: 0.99915, f1_macro: 0.99956
# epoch: 47, passed number of graphs: 192, train running loss: 0.00051 (passed time: 2h 25m 8s)
#           acc: 0.99984, fpr: 0.00007, fnr: 0.00232, rec: 0.99768, prc: 0.99851, f1: 0.99809, f1_macro: 0.99900
# epoch: 47, passed number of graphs: 288, train running loss: 0.00048 (passed time: 2h 25m 29s)
#           acc: 0.99977, fpr: 0.00018, fnr: 0.00141, rec: 0.99859, prc: 0.99586, f1: 0.99722, f1_macro: 0.99855
# epoch: 47, passed number of graphs: 384, train running loss: 0.00048 (passed time: 2h 25m 49s)
#           acc: 0.99980, fpr: 0.00011, fnr: 0.00213, rec: 0.99787, prc: 0.99747, f1: 0.99767, f1_macro: 0.99878
# epoch: 47, passed number of graphs: 480, train running loss: 0.00051 (passed time: 2h 26m 10s)
#           acc: 0.99979, fpr: 0.00015, fnr: 0.00150, rec: 0.99850, prc: 0.99660, f1: 0.99755, f1_macro: 0.99872
# epoch: 47, passed number of graphs: 576, train running loss: 0.00049 (passed time: 2h 26m 31s)
#           acc: 0.99972, fpr: 0.00022, fnr: 0.00180, rec: 0.99820, prc: 0.99510, f1: 0.99664, f1_macro: 0.99825
# epoch: 47, passed number of graphs: 672, train running loss: 0.00049 (passed time: 2h 26m 52s)
#           acc: 0.99946, fpr: 0.00044, fnr: 0.00284, rec: 0.99716, prc: 0.99017, f1: 0.99365, f1_macro: 0.99669
# epoch: 47, passed number of graphs: 768, train running loss: 0.00051 (passed time: 2h 27m 12s)
#           acc: 0.99986, fpr: 0.00008, fnr: 0.00149, rec: 0.99851, prc: 0.99818, f1: 0.99834, f1_macro: 0.99914
# Validation --- epoch: 47, loss: 0.00125
#           rec: 0.99385, prc: 0.99765, fnr: 0.00615, fpr: 0.00005, f1: 0.99520, acc: 0.99982, f1_macro: 0.99755
# epoch: 48, passed number of graphs: 96, train running loss: 0.00050 (passed time: 2h 27m 55s)
#           acc: 0.99995, fpr: 0.00002, fnr: 0.00073, rec: 0.99927, prc: 0.99951, f1: 0.99939, f1_macro: 0.99968
# epoch: 48, passed number of graphs: 192, train running loss: 0.00051 (passed time: 2h 28m 15s)
#           acc: 0.99987, fpr: 0.00006, fnr: 0.00174, rec: 0.99826, prc: 0.99867, f1: 0.99847, f1_macro: 0.99920
# epoch: 48, passed number of graphs: 288, train running loss: 0.00050 (passed time: 2h 28m 36s)
#           acc: 0.99977, fpr: 0.00018, fnr: 0.00133, rec: 0.99867, prc: 0.99594, f1: 0.99731, f1_macro: 0.99859
# epoch: 48, passed number of graphs: 384, train running loss: 0.00049 (passed time: 2h 28m 57s)
#           acc: 0.99982, fpr: 0.00011, fnr: 0.00180, rec: 0.99820, prc: 0.99763, f1: 0.99791, f1_macro: 0.99891
# epoch: 48, passed number of graphs: 480, train running loss: 0.00052 (passed time: 2h 29m 17s)
#           acc: 0.99978, fpr: 0.00016, fnr: 0.00141, rec: 0.99859, prc: 0.99635, f1: 0.99747, f1_macro: 0.99868
# epoch: 48, passed number of graphs: 576, train running loss: 0.00050 (passed time: 2h 29m 38s)
#           acc: 0.99975, fpr: 0.00020, fnr: 0.00139, rec: 0.99861, prc: 0.99551, f1: 0.99705, f1_macro: 0.99846
# epoch: 48, passed number of graphs: 672, train running loss: 0.00050 (passed time: 2h 29m 59s)
#           acc: 0.99949, fpr: 0.00045, fnr: 0.00178, rec: 0.99822, prc: 0.99002, f1: 0.99410, f1_macro: 0.99692
# epoch: 48, passed number of graphs: 768, train running loss: 0.00051 (passed time: 2h 30m 20s)
#           acc: 0.99986, fpr: 0.00008, fnr: 0.00149, rec: 0.99851, prc: 0.99818, f1: 0.99834, f1_macro: 0.99914
# Validation --- epoch: 48, loss: 0.00125
#           rec: 0.99382, prc: 0.99768, fnr: 0.00618, fpr: 0.00005, f1: 0.99520, acc: 0.99982, f1_macro: 0.99755
# epoch: 49, passed number of graphs: 96, train running loss: 0.00051 (passed time: 2h 31m 2s)
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00122, rec: 0.99878, prc: 0.99951, f1: 0.99915, f1_macro: 0.99956
# epoch: 49, passed number of graphs: 192, train running loss: 0.00052 (passed time: 2h 31m 23s)
#           acc: 0.99987, fpr: 0.00006, fnr: 0.00182, rec: 0.99818, prc: 0.99867, f1: 0.99842, f1_macro: 0.99918
# epoch: 49, passed number of graphs: 288, train running loss: 0.00049 (passed time: 2h 31m 44s)
#           acc: 0.99976, fpr: 0.00018, fnr: 0.00166, rec: 0.99834, prc: 0.99586, f1: 0.99710, f1_macro: 0.99849
# epoch: 49, passed number of graphs: 384, train running loss: 0.00048 (passed time: 2h 32m 4s)
#           acc: 0.99980, fpr: 0.00012, fnr: 0.00196, rec: 0.99804, prc: 0.99730, f1: 0.99767, f1_macro: 0.99878
# epoch: 49, passed number of graphs: 480, train running loss: 0.00051 (passed time: 2h 32m 25s)
#           acc: 0.99977, fpr: 0.00015, fnr: 0.00183, rec: 0.99817, prc: 0.99652, f1: 0.99734, f1_macro: 0.99861
# epoch: 49, passed number of graphs: 576, train running loss: 0.00049 (passed time: 2h 32m 46s)
#           acc: 0.99975, fpr: 0.00018, fnr: 0.00180, rec: 0.99820, prc: 0.99583, f1: 0.99701, f1_macro: 0.99844
# epoch: 49, passed number of graphs: 672, train running loss: 0.00049 (passed time: 2h 33m 7s)
#           acc: 0.99953, fpr: 0.00038, fnr: 0.00243, rec: 0.99757, prc: 0.99153, f1: 0.99454, f1_macro: 0.99715
# epoch: 49, passed number of graphs: 768, train running loss: 0.00050 (passed time: 2h 33m 27s)
#           acc: 0.99985, fpr: 0.00009, fnr: 0.00149, rec: 0.99851, prc: 0.99801, f1: 0.99826, f1_macro: 0.99909
# Validation --- epoch: 49, loss: 0.00125
#           rec: 0.99384, prc: 0.99766, fnr: 0.00616, fpr: 0.00005, f1: 0.99520, acc: 0.99982, f1_macro: 0.99755
# epoch: 50, passed number of graphs: 96, train running loss: 0.00049 (passed time: 2h 34m 10s)
#           acc: 0.99992, fpr: 0.00003, fnr: 0.00122, rec: 0.99878, prc: 0.99943, f1: 0.99911, f1_macro: 0.99953
# epoch: 50, passed number of graphs: 192, train running loss: 0.00051 (passed time: 2h 34m 31s)
#           acc: 0.99985, fpr: 0.00006, fnr: 0.00207, rec: 0.99793, prc: 0.99859, f1: 0.99826, f1_macro: 0.99909
# epoch: 50, passed number of graphs: 288, train running loss: 0.00048 (passed time: 2h 34m 52s)
#           acc: 0.99977, fpr: 0.00017, fnr: 0.00141, rec: 0.99859, prc: 0.99603, f1: 0.99731, f1_macro: 0.99859
# epoch: 50, passed number of graphs: 384, train running loss: 0.00049 (passed time: 2h 35m 12s)
#           acc: 0.99976, fpr: 0.00016, fnr: 0.00204, rec: 0.99796, prc: 0.99657, f1: 0.99726, f1_macro: 0.99857
# epoch: 50, passed number of graphs: 480, train running loss: 0.00051 (passed time: 2h 35m 33s)
#           acc: 0.99977, fpr: 0.00015, fnr: 0.00183, rec: 0.99817, prc: 0.99652, f1: 0.99734, f1_macro: 0.99861
# epoch: 50, passed number of graphs: 576, train running loss: 0.00050 (passed time: 2h 35m 54s)
#           acc: 0.99970, fpr: 0.00022, fnr: 0.00213, rec: 0.99787, prc: 0.99510, f1: 0.99648, f1_macro: 0.99816
# epoch: 50, passed number of graphs: 672, train running loss: 0.00050 (passed time: 2h 36m 14s)
#           acc: 0.99949, fpr: 0.00043, fnr: 0.00227, rec: 0.99773, prc: 0.99042, f1: 0.99406, f1_macro: 0.99690
# epoch: 50, passed number of graphs: 768, train running loss: 0.00051 (passed time: 2h 36m 35s)
#           acc: 0.99987, fpr: 0.00008, fnr: 0.00132, rec: 0.99868, prc: 0.99818, f1: 0.99843, f1_macro: 0.99918
# Validation --- epoch: 50, loss: 0.00125
#           rec: 0.99379, prc: 0.99772, fnr: 0.00621, fpr: 0.00005, f1: 0.99520, acc: 0.99982, f1_macro: 0.99755
# ************ best model obtained after epoch 21, saved at ./saved_models/GIN_20: 0.9952429299056434.pt ************
# Testing --- loss: 0.00067
#           rec: 0.99585, prc: 0.99557, fnr: 0.00415, fpr: 0.00010, f1: 0.99546, acc: 0.99981, f1_macro: 0.99768

# %% [markdown]
# 12GIN_MPL_4Layer_p2p_6k_botnode
