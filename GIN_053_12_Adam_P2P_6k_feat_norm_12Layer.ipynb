# %% [markdown]
# <a href="https://colab.research.google.com/github/Zoro1092000/xxxx/blob/main/GIN_053_12_Adam_P2P_6k_feat_norm_12Layer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # I. Pip & Import.

# %%
import os
import os.path as osp
import torch
import sys

os.environ['TORCH'] = torch.__version__

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install torch-geometric==1.4.3
# !pip install torch-cluster -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install deepdish==0.3.5
# !pip install torch-optimizer

import torch.nn as nn
from torch.nn import Parameter
from torch_geometric.utils import scatter_
from torch_geometric.nn.inits import glorot, zeros
from torch_scatter import scatter_add
from torch.utils.data import DataLoader, Dataset
import torch_optimizer as optimization


from itertools import chain
import pickle
import h5py
import deepdish as dd
import numpy as np
from tqdm import tqdm
import inspect
import time
import math
import random
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-geometric==1.4.3 in /usr/local/lib/python3.7/dist-packages (1.4.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.21.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.0.2)
# Requirement already satisfied: rdflib in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (6.2.0)
# Requirement already satisfied: plyfile in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.7.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (3.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.3.5)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.18.3)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.56.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.23.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (2.6.3)
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (0.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torch-geometric==1.4.3) (1.12.1+cu113)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->torch-geometric==1.4.3) (1.5.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (4.13.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba->torch-geometric==1.4.3) (57.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->numba->torch-geometric==1.4.3) (3.10.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2022.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->torch-geometric==1.4.3) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->torch-geometric==1.4.3) (1.15.0)
# Requirement already satisfied: isodate in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (0.6.1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from rdflib->torch-geometric==1.4.3) (3.0.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric==1.4.3) (1.24.3)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (3.2.2)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2021.11.2)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (2.9.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (1.3.0)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,>=4.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->torch-geometric==1.4.3) (7.1.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.0.0,>=2.0.0->scikit-image->torch-geometric==1.4.3) (0.11.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric==1.4.3) (3.1.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://data.pyg.org/whl/torch-1.12.1+cu113.html
# Requirement already satisfied: torch-cluster in /usr/local/lib/python3.7/dist-packages (1.6.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: deepdish==0.3.5 in /usr/local/lib/python3.7/dist-packages (0.3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.7.3)
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (3.7.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (21.3)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (2.8.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tables->deepdish==0.3.5) (3.0.9)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-optimizer in /usr/local/lib/python3.7/dist-packages (0.3.0)
# Requirement already satisfied: torch>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from torch-optimizer) (1.12.1+cu113)
# Requirement already satisfied: pytorch-ranger>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from torch-optimizer) (0.1.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.5.0->torch-optimizer) (4.1.1)

# %%
def time_since(start):
    now = time.time()
    s = now - start
    m = math.floor(s / 60)
    s -= m * 60
    h = math.floor(m / 60)
    m -= h * 60
    if h == 0:
        if m == 0:
            return '%ds' % s
        else:
            return '%dm %ds' % (m, s)
    else:
        return '%dh %dm %ds' % (h, m, s)

# %% [markdown]
# # II. Data

# %%
# Data utils
def h5group_to_dict(h5group):
    group_dict = {k: v[()] for k, v in chain(h5group.items(), h5group.attrs.items())}
    return group_dict

def sub_dict(full_dict, *keys, to_tensor):
    return {k: torch.tensor(full_dict[k]) if to_tensor else full_dict[k] for k in keys if k in full_dict}

def build_graph_from_dict_pyg(graph_dict, to_tensor=True):
    from torch_geometric.data import Data

    g = Data(**sub_dict(graph_dict, 'edge_index', 'x', 'y', 'edge_attr', 'edge_y', to_tensor=to_tensor))
    return g

# Data loader
class GraphDataLoader(DataLoader):
    def __init__(self, dataset, batch_size=128, shuffle=False, num_workers=0):

        def collate_graph(graph_obj_list):
            from torch_geometric.data import Batch
            batch = Batch.from_data_list(graph_obj_list)
            return batch

        super().__init__(
            dataset,
            batch_size=batch_size,
            shuffle=shuffle,
            collate_fn=collate_graph,
            num_workers=num_workers)

# BotnetDataset
class BotnetDataset(Dataset):

    def __init__(self, name='chord', root='data/botnet', split='train', graph_format='pyg', split_idx=None, add_nfeat_ones=True,
                 in_memory=True):
        super().__init__()
        assert name in ['chord', 'debru', 'kadem', 'leet', 'c2', 'p2p']
        assert split in ['train', 'val', 'test']

        if isinstance(root, str):
            root = osp.expanduser(osp.normpath(root))

        self.name = name
        self.root = root
        self.split = split
        self.split_idx = split_idx
        self.add_nfeat_ones = add_nfeat_ones

        self._graph_format = graph_format
        if split == 'train':
            self.path = self.processed_paths[0]
            self.num_graphs = 768
        elif split == 'val':
            self.path = self.processed_paths[1]
            self.num_graphs = 96
        elif split == 'test':
            self.path = self.processed_paths[2]
            self.num_graphs = 96

        if in_memory:
            self.data = dd.io.load(self.path)  # dictionary
            self.data_type = 'dict'
        else:
            # self.data = h5py.File(self.path, 'r')
            self.data = None    # defer opening file in each process to make multiprocessing work
            self.data_type = 'file'
            
    @property
    def processed_dir(self):
        return osp.join(self.root, 'processed')

    @property
    def processed_file_names(self):
        return [self.name + '_' + s + '.hdf5' for s in ('train', 'val', 'test')]

    @property
    def processed_paths(self):
        return [osp.join(self.processed_dir, f) for f in self.processed_file_names]

    def __len__(self):
        return self.num_graphs

    def __getitem__(self, index):
        if self.data_type == 'dict':
            graph_dict = self.data[str(index)]
        elif self.data_type == 'file':
            if self.data is None:
                # only open once in each process
                self.data = h5py.File(self.path, 'r')
            graph_dict = h5group_to_dict(self.data[str(index)])
        else:
            raise ValueError

        # graph_format == 'pyg':
        return build_graph_from_dict_pyg(graph_dict)


    def __iter__(self):
        for i in range(self.num_graphs):
            yield self[i]

    def __repr__(self):
        return f'{self.__class__.__name__}(topology: {self.name} | split: {self.split} | ' \
               f'#graphs: {len(self)} | graph format: {self.graph_format})'

# %% [markdown]
# # III. Measure Performancce

# %% [markdown]
# ## 3.1. Metrics

# %%
def f1(target, pred, label):
    # F1 = 2 * (precision * recall) / (precision + recall)
    tp = np.sum((target==label) & (pred==label))
    fp = np.sum((target!=label) & (pred==label))
    fn = np.sum((pred!=label) & (target==label))
    
    if tp+fp==0 or tp+fn==0:
      return np.nan

    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    
    if precision+recall==0:
      return np.nan
      
    f1 = 2 * (precision * recall) / (precision + recall)
    return f1

def f1_macro(pred, target):
    return np.mean([f1(target, pred, label) for label in range(0, 2)])


def accuracy(pred, target):
    return (pred == target).sum().item() / len(target)


def true_positive(pred, target):
    return (target[pred == 1] == 1).sum().item()


def false_positive(pred, target):
    return (target[pred == 1] == 0).sum().item()


def true_negative(pred, target):
    return (target[pred == 0] == 0).sum().item()


def false_negative(pred, target):
    return (target[pred == 0] == 1).sum().item()


def recall(pred, target):
    try:
        return true_positive(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1


def precision(pred, target):
    try:
        prec = true_positive(pred, target) / (pred == 1).sum().item()
        return prec
    except:  # divide by zero
        return -1


def f1_score(pred, target):
    prec = precision(pred, target)
    rec = recall(pred, target)
    try:
        return 2 * (prec * rec) / (prec + rec)
    except:
        return 0


def false_positive_rate(pred, target):
    try:
        return false_positive(pred, target) / (target == 0).sum().item()
    except:  # divide by zero
        return -1


def false_negative_rate(pred, target):
    try:
        return false_negative(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1

# %% [markdown]
# ## 3.2. Evaluation

# %%
def eval_metrics(target, pred_prob, threshold=0.5):
    if isinstance(target, torch.Tensor):
        target = target.cpu().numpy()
    if isinstance(pred_prob, torch.Tensor):
        pred_prob = pred_prob.cpu().numpy()

    pred = (pred_prob >= threshold).astype(int)

    acc = accuracy(pred, target)
    fpr = false_positive_rate(pred, target)
    fnr = false_negative_rate(pred, target)
    rec = recall(pred, target)
    prc = precision(pred, target)
    f1 = f1_score(pred, target)
    f1macro = f1_macro(pred, target)
    result_dict = {'acc': acc, 'fpr': fpr, 'fnr': fnr, 'rec': rec, 'prc': prc, 'f1': f1, 'f1_macro': f1macro}

    return result_dict


def dict_value_add(dict1, dict2):
    result = {key: dict1.get(key, 0) + dict2.get(key, 0)
              for key in set(dict1) | set(dict2)}
    return result


def dict_value_div(dict, n):
    result = {key: value / n for key, value in dict.items()}
    return result


def eval_predictor(dataset, predictor):
    result_dict_avg = {}
    loss_avg = 0

    for data in dataset:
        # prediction
        try:
            pred_prob, loss = predictor(data)
            loss_avg += loss
        except ValueError:  # if "too many values to unpack"
            pred_prob = predictor(data)

        # get the ground truth target
        # graph_format == 'pyg':
        target = data.y

        # compute the evaluation metrics
        result_dict = eval_metrics(target, pred_prob)

        result_dict_avg = dict_value_add(result_dict_avg, result_dict)

    # average the metrics across all graphs in the dataset as final results
    result_dict_avg = dict_value_div(result_dict_avg, len(dataset))
    loss_avg = loss_avg / len(dataset)

    return result_dict_avg, loss_avg


# =================================================================================================================
# some examples of the 'predictor' model wrapper to be fed into the above evaluation function (for PyG Data format)
# =================================================================================================================
class PygRandomPredictor:
    def __init__(self):
        # torch.manual_seed(0)
        pass

    def __call__(self, data):
        pred_prob = torch.rand(len(data.y))
        return pred_prob


class PygModelPredictor:
    def __init__(self, model, loss_fcn=torch.nn.CrossEntropyLoss()):
        self.model = model
        self.loss_fcn = loss_fcn
        self.device = next(model.parameters()).device

    def __call__(self, data):
        self.model.eval()
        data = data.to(self.device)
        with torch.no_grad():
            # custom the below line to adjust to your model's input format for forward pass
            out = self.model(data.x, data.edge_index)
            loss = self.loss_fcn(out, data.y.long())
            pred_prob = torch.softmax(out, dim=1)[:, 1]
        return pred_prob, loss.float()

# %% [markdown]
# # IV. Model

# %% [markdown]
# ## 5.1. Activation

# %%
def activation(act, negative_slope=0.2):
    activations = nn.ModuleDict([
        ['lrelu', nn.LeakyReLU(negative_slope)],
        ['relu', nn.ReLU()],
        ['elu', nn.ELU()],
        ['none', nn.Identity()],
    ])
    return activations[act]

# %% [markdown]
# ## 5.2. GIN model

# %%
import torch.nn as nn

class GINModel(nn.Module):
    def __init__(self, dim_input_feature, dim_hidden_feature, num_layers, num_classes, non_linear='relu', dropout=0.2):
        super().__init__()

        self.dim_input_feature = dim_input_feature
        self.dim_hidden_feature = dim_hidden_feature

        self.num_layers = num_layers
        self.num_classes = num_classes
        
        from torch.nn import Linear, Sequential, BatchNorm1d, ReLU, Dropout
        from torch_geometric.nn import GINConv, ARMAConv
        
        self.gin_net = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.gin_net.append(
                GINConv(
                  Sequential(Linear(self.dim_input_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature), ReLU())))
          else:
            self.gin_net.append(
                GINConv(
                  Sequential(Linear(self.dim_hidden_feature, self.dim_hidden_feature),
                             BatchNorm1d(self.dim_hidden_feature), ReLU(),
                             Linear(self.dim_hidden_feature, self.dim_hidden_feature), ReLU()))) 

        self.dropout = nn.Dropout(dropout)

        self.residuals = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.residuals.append(nn.Linear(self.dim_input_feature, self.dim_hidden_feature, bias=True))
          else:
            self.residuals.append(nn.Identity())

        self.num_residuals = len(self.residuals)

        self.non_linear = activation(non_linear)

        # self.final_type == 'proj':
        self.final = nn.Linear(self.dim_hidden_feature, num_classes)

    def reset_parameters(self):
        for net in self.gin_net:
            net.reset_parameters()
        # self.residual_hop = 1
        for net in self.residuals:
            net.reset_parameters()
        # self.final_type != 'none':
        self.final.reset_parameters()

    def forward(self, x, edge_index):
        xr = None
        add_xr_at = -1

        for n, net in enumerate(self.gin_net):
            # pass to a GIN layer with non-linear activation
            xo = net(x, edge_index)
            xo = self.dropout(xo)
            # deal with residual connections
            # self.residual_hop = 1
            if n < self.num_residuals:
                xr = self.residuals[n](x)
                add_xr_at = n
            if n == add_xr_at:
                xo = self.non_linear(xo + xr)

            x = xo
        # size of x: (B * N, dim_hidden_feature) -> (B * N, num_classes)
        x = self.final(x)

        return x

# %% [markdown]
# # V. Load data

# %%
data_dir = '/content/drive/Shareddrives/botnetdata/p2p_6k_feat_norm'
data_name = 'p2p' # 'chord', 'debru', 'kadem', 'leet', 'c2', 'p2p'
shuffle = False

# ========== load the dataset
print('loading dataset...')

train_ds = BotnetDataset(name=data_name, root=data_dir, split='train',
                         in_memory=False, graph_format='pyg')
val_ds = BotnetDataset(name=data_name, root=data_dir, split='val',
                       in_memory=False, graph_format='pyg')
test_ds = BotnetDataset(name=data_name, root=data_dir, split='test',
                        in_memory=False, graph_format='pyg')
# Out:
# loading dataset...

# %%
batch_size = 2
train_loader = GraphDataLoader(train_ds, batch_size=batch_size, shuffle=bool(shuffle), num_workers=0)

# %% [markdown]
# # VI. Train

# %%
# ============== some default parameters =============
devid = 0
seed = 0
logmode = 'w'
log_interval = 96

dim_input_feature = 1
dim_hidden_feature = 32
act = 'relu' # 'none', 'lrelu', 'relu', 'elu'

num_layers = 12
num_classes = 2 

dropout = 0.0
bias = True

lr = 0.005 # learning rate
weight_decay = 5e-4
epochs = 50
save_dir = './saved_models'
save_name = "GIN_model.pt"
# ====================================================

def train(model, train_loader, val_dataset, test_dataset, optimizer, scheduler=None):
    device = next(model.parameters()).device
    predictor = PygModelPredictor(model)

    best_epoch = 0
    max_f1_score = 0
    start = time.time()
    for ep in range(epochs):
        loss_avg_train = 0
        num_train_graph = 0
        model.train()
        for n, batch in enumerate(train_loader):
            batch.to(device)

            optimizer.zero_grad()

            x = model(batch.x, batch.edge_index)
            loss = criterion(x, batch.y.long())

            loss_avg_train += float(loss)
            num_train_graph += batch.num_graphs

            loss.backward()
            optimizer.step()

            if num_train_graph % log_interval == 0 or n == len(train_loader) - 1:
                with torch.no_grad():
                    # pred = x.argmax(dim=1)
                    pred_prob = torch.softmax(x, dim=1)[:, 1]
                    y = batch.y.long()
                    result_dict = eval_metrics(y, pred_prob)
                print(f'epoch: {ep + 1}, passed number of graphs: {num_train_graph}, '
                        f'train running loss: {loss_avg_train / num_train_graph:.5f} (passed time: {time_since(start)})')
                print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict.items()]))

        result_dict_avg, loss_avg = eval_predictor(val_dataset, predictor)
        print(f'Validation --- epoch: {ep + 1}, loss: {loss_avg:.5f}')
        print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))

        if scheduler is not None:
            scheduler.step(loss_avg)

        if result_dict_avg['f1'] > max_f1_score:
            save_name = f"GIN_{ep}: {result_dict_avg['f1']}.pt"
            torch.save(model, os.path.join(save_dir, save_name))
            print(f'Better model saved at {os.path.join(save_dir, save_name)}.')
            best_epoch = ep
            max_f1_score = result_dict_avg['f1']

    best_model = torch.load(os.path.join(save_dir, save_name))
    print('*' * 12 + f' best model obtained after epoch {best_epoch + 1}, '
                       f'saved at {os.path.join(save_dir, save_name)} ' + '*' * 12)
    
    predictor = PygModelPredictor(best_model)

    result_dict_avg, loss_avg = eval_predictor(test_dataset, predictor)
    print(f'Testing --- loss: {loss_avg:.5f}')
    print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))


if __name__ == '__main__':
    os.makedirs(save_dir, exist_ok=True)

    # ========== random seeds and device
    random.seed(seed)
    torch.manual_seed(seed)

    device = torch.device(f'cuda:{devid}') if devid > -1 else torch.device('cpu')

    # ========== logging setup
    log_name = os.path.splitext(save_name)[0]
    # logger = logging_config(__name__, folder=save_dir, name=log_name, filemode=logmode)
    # logger = logging_config(os.path.basename(__file__), folder=save_dir, name=log_name, filemode=logmode)

    print('python ' + ' '.join(sys.argv))
    print('-' * 30)
    #logger.info(args)
    print('-' * 30)
    print(time.ctime())
    print('-' * 30)

    # ========== define the model, optimizer, and loss

    model = GINModel(dim_input_feature,
                     dim_hidden_feature,
                     num_layers,
                     num_classes,
                     non_linear=act,
                     dropout=dropout)

    print('model ' + '-' * 10)
    print(repr(model))
    model.to(device)

    class_weight = torch.Tensor([0.53, 12])
    class_weight = class_weight.cuda(device=0)
    criterion = torch.nn.CrossEntropyLoss(weight=class_weight)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.25, patience=1)

    # ========== train the model
    print(f"Batch size: {batch_size}")
    print(class_weight)
    train(model, train_loader, val_ds, test_ds, optimizer, scheduler)
# Out:
# python /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-c190880a-c5a1-4615-8daf-ea6564d8634a.json
# ------------------------------
# ------------------------------
# Fri Nov  4 04:16:44 2022
# ------------------------------
# model ----------
# GINModel(
#   (gin_net): ModuleList(
#     (0): GINConv(nn=Sequential(
#       (0): Linear(in_features=1, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (1): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (2): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (3): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (4): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (5): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (6): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (7): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (8): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (9): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (10): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#     (11): GINConv(nn=Sequential(
#       (0): Linear(in_features=32, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): ReLU()
#     ))
#   )
#   (dropout): Dropout(p=0.0, inplace=False)
#   (residuals): ModuleList(
#     (0): Linear(in_features=1, out_features=32, bias=True)
#     (1): Identity()
#     (2): Identity()
#     (3): Identity()
#     (4): Identity()
#     (5): Identity()
#     (6): Identity()
#     (7): Identity()
#     (8): Identity()
#     (9): Identity()
#     (10): Identity()
#     (11): Identity()
#   )
#   (non_linear): ReLU()
#   (final): Linear(in_features=32, out_features=2, bias=True)
# )
# Batch size: 2
# tensor([ 0.5300, 12.0000], device='cuda:0')
# epoch: 1, passed number of graphs: 96, train running loss: 0.20796 (passed time: 3m 42s)
#           acc: 0.94685, fpr: 0.05547, fnr: 0.00105, rec: 0.99895, prc: 0.44551, f1: 0.61621, f1_macro: 0.79383
# epoch: 1, passed number of graphs: 192, train running loss: 0.12756 (passed time: 4m 17s)
#           acc: 0.96052, fpr: 0.04122, fnr: 0.00008, rec: 0.99992, prc: 0.51604, f1: 0.68076, f1_macro: 0.82986
# epoch: 1, passed number of graphs: 288, train running loss: 0.09506 (passed time: 4m 50s)
#           acc: 0.99097, fpr: 0.00937, fnr: 0.00116, rec: 0.99884, prc: 0.82271, f1: 0.90226, f1_macro: 0.94876
# epoch: 1, passed number of graphs: 384, train running loss: 0.07630 (passed time: 5m 22s)
#           acc: 0.99609, fpr: 0.00406, fnr: 0.00057, rec: 0.99943, prc: 0.91775, f1: 0.95685, f1_macro: 0.97740
# epoch: 1, passed number of graphs: 480, train running loss: 0.06573 (passed time: 5m 55s)
#           acc: 0.99680, fpr: 0.00332, fnr: 0.00042, rec: 0.99958, prc: 0.93041, f1: 0.96376, f1_macro: 0.98104
# epoch: 1, passed number of graphs: 576, train running loss: 0.05772 (passed time: 6m 29s)
#           acc: 0.98802, fpr: 0.01249, fnr: 0.00033, rec: 0.99967, prc: 0.77896, f1: 0.87562, f1_macro: 0.93467
# epoch: 1, passed number of graphs: 672, train running loss: 0.05237 (passed time: 7m 3s)
#           acc: 0.99386, fpr: 0.00364, fnr: 0.06246, rec: 0.93754, prc: 0.91992, f1: 0.92865, f1_macro: 0.96272
# epoch: 1, passed number of graphs: 768, train running loss: 0.04803 (passed time: 7m 37s)
#           acc: 0.99681, fpr: 0.00332, fnr: 0.00017, rec: 0.99983, prc: 0.92934, f1: 0.96330, f1_macro: 0.98082
# Validation --- epoch: 1, loss: 0.00900
#           fnr: 0.01564, acc: 0.99906, prc: 0.97573, fpr: 0.00062, rec: 0.98436, f1_macro: 0.98892, f1: 0.97833
# Better model saved at ./saved_models/GIN_0: 0.9783286786406181.pt.
# epoch: 2, passed number of graphs: 96, train running loss: 0.00904 (passed time: 8m 37s)
#           acc: 0.99869, fpr: 0.00137, fnr: 0.00000, rec: 1.00000, prc: 0.97013, f1: 0.98484, f1_macro: 0.99208
# epoch: 2, passed number of graphs: 192, train running loss: 0.00815 (passed time: 9m 0s)
#           acc: 0.99908, fpr: 0.00095, fnr: 0.00025, rec: 0.99975, prc: 0.97874, f1: 0.98913, f1_macro: 0.99433
# epoch: 2, passed number of graphs: 288, train running loss: 0.00945 (passed time: 9m 23s)
#           acc: 0.99739, fpr: 0.00267, fnr: 0.00116, rec: 0.99884, prc: 0.94207, f1: 0.96962, f1_macro: 0.98413
# epoch: 2, passed number of graphs: 384, train running loss: 0.02071 (passed time: 9m 45s)
#           acc: 0.98593, fpr: 0.01460, fnr: 0.00229, rec: 0.99771, prc: 0.75593, f1: 0.86016, f1_macro: 0.92637
# epoch: 2, passed number of graphs: 480, train running loss: 0.02160 (passed time: 10m 8s)
#           acc: 0.99375, fpr: 0.00647, fnr: 0.00141, rec: 0.99859, prc: 0.87279, f1: 0.93146, f1_macro: 0.96409
# epoch: 2, passed number of graphs: 576, train running loss: 0.02359 (passed time: 10m 31s)
#           acc: 0.98584, fpr: 0.01477, fnr: 0.00033, rec: 0.99967, prc: 0.74874, f1: 0.85620, f1_macro: 0.92438
# epoch: 2, passed number of graphs: 672, train running loss: 0.02407 (passed time: 10m 54s)
#           acc: 0.99399, fpr: 0.00339, fnr: 0.06474, rec: 0.93526, prc: 0.92476, f1: 0.92998, f1_macro: 0.96342
# epoch: 2, passed number of graphs: 768, train running loss: 0.02320 (passed time: 11m 16s)
#           acc: 0.99677, fpr: 0.00336, fnr: 0.00017, rec: 0.99983, prc: 0.92855, f1: 0.96288, f1_macro: 0.98060
# Validation --- epoch: 2, loss: 0.21928
#           fnr: 0.00914, acc: 0.94801, prc: 0.30397, fpr: 0.05294, rec: 0.99086, f1_macro: 0.71727, f1: 0.46191
# epoch: 3, passed number of graphs: 96, train running loss: 0.01108 (passed time: 12m 2s)
#           acc: 0.99900, fpr: 0.00104, fnr: 0.00008, rec: 0.99992, prc: 0.97720, f1: 0.98843, f1_macro: 0.99395
# epoch: 3, passed number of graphs: 192, train running loss: 0.00966 (passed time: 12m 25s)
#           acc: 0.99938, fpr: 0.00064, fnr: 0.00008, rec: 0.99992, prc: 0.98562, f1: 0.99272, f1_macro: 0.99620
# epoch: 3, passed number of graphs: 288, train running loss: 0.00900 (passed time: 12m 48s)
#           acc: 0.97318, fpr: 0.02798, fnr: 0.00017, rec: 0.99983, prc: 0.60867, f1: 0.75669, f1_macro: 0.87125
# epoch: 3, passed number of graphs: 384, train running loss: 0.00981 (passed time: 13m 11s)
#           acc: 0.99974, fpr: 0.00024, fnr: 0.00065, rec: 0.99935, prc: 0.99471, f1: 0.99702, f1_macro: 0.99844
# epoch: 3, passed number of graphs: 480, train running loss: 0.00986 (passed time: 13m 35s)
#           acc: 0.99968, fpr: 0.00032, fnr: 0.00033, rec: 0.99967, prc: 0.99290, f1: 0.99627, f1_macro: 0.99805
# epoch: 3, passed number of graphs: 576, train running loss: 0.00876 (passed time: 13m 58s)
#           acc: 0.99964, fpr: 0.00035, fnr: 0.00074, rec: 0.99926, prc: 0.99219, f1: 0.99571, f1_macro: 0.99776
# epoch: 3, passed number of graphs: 672, train running loss: 0.00803 (passed time: 14m 21s)
#           acc: 0.99792, fpr: 0.00216, fnr: 0.00032, rec: 0.99968, prc: 0.95372, f1: 0.97616, f1_macro: 0.98753
# epoch: 3, passed number of graphs: 768, train running loss: 0.00826 (passed time: 14m 44s)
#           acc: 0.99903, fpr: 0.00097, fnr: 0.00091, rec: 0.99909, prc: 0.97819, f1: 0.98853, f1_macro: 0.99401
# Validation --- epoch: 3, loss: 0.01691
#           fnr: 0.00898, acc: 0.99809, prc: 0.93889, fpr: 0.00176, rec: 0.99102, f1_macro: 0.97964, f1: 0.96026
# epoch: 4, passed number of graphs: 96, train running loss: 0.00767 (passed time: 15m 28s)
#           acc: 0.99936, fpr: 0.00066, fnr: 0.00016, rec: 0.99984, prc: 0.98547, f1: 0.99260, f1_macro: 0.99613
# epoch: 4, passed number of graphs: 192, train running loss: 0.00645 (passed time: 15m 51s)
#           acc: 0.99984, fpr: 0.00012, fnr: 0.00116, rec: 0.99884, prc: 0.99727, f1: 0.99805, f1_macro: 0.99898
# epoch: 4, passed number of graphs: 288, train running loss: 0.00536 (passed time: 16m 14s)
#           acc: 0.99931, fpr: 0.00071, fnr: 0.00017, rec: 0.99983, prc: 0.98391, f1: 0.99181, f1_macro: 0.99572
# epoch: 4, passed number of graphs: 384, train running loss: 0.00516 (passed time: 16m 38s)
#           acc: 0.99975, fpr: 0.00022, fnr: 0.00082, rec: 0.99918, prc: 0.99511, f1: 0.99714, f1_macro: 0.99851
# epoch: 4, passed number of graphs: 480, train running loss: 0.00497 (passed time: 17m 0s)
#           acc: 0.99966, fpr: 0.00034, fnr: 0.00033, rec: 0.99967, prc: 0.99249, f1: 0.99607, f1_macro: 0.99795
# epoch: 4, passed number of graphs: 576, train running loss: 0.00438 (passed time: 17m 23s)
#           acc: 0.99958, fpr: 0.00043, fnr: 0.00016, rec: 0.99984, prc: 0.99034, f1: 0.99507, f1_macro: 0.99742
# epoch: 4, passed number of graphs: 672, train running loss: 0.00408 (passed time: 17m 46s)
#           acc: 0.99836, fpr: 0.00171, fnr: 0.00024, rec: 0.99976, prc: 0.96311, f1: 0.98109, f1_macro: 0.99012
# epoch: 4, passed number of graphs: 768, train running loss: 0.00409 (passed time: 18m 9s)
#           acc: 0.99769, fpr: 0.00235, fnr: 0.00132, rec: 0.99868, prc: 0.94878, f1: 0.97309, f1_macro: 0.98594
# Validation --- epoch: 4, loss: 0.00580
#           fnr: 0.00851, acc: 0.99887, prc: 0.96569, fpr: 0.00097, rec: 0.99149, f1_macro: 0.98761, f1: 0.97580
# epoch: 5, passed number of graphs: 96, train running loss: 0.00253 (passed time: 18m 53s)
#           acc: 0.99968, fpr: 0.00033, fnr: 0.00016, rec: 0.99984, prc: 0.99268, f1: 0.99625, f1_macro: 0.99804
# epoch: 5, passed number of graphs: 192, train running loss: 0.00237 (passed time: 19m 16s)
#           acc: 0.99983, fpr: 0.00017, fnr: 0.00025, rec: 0.99975, prc: 0.99612, f1: 0.99793, f1_macro: 0.99892
# epoch: 5, passed number of graphs: 288, train running loss: 0.00199 (passed time: 19m 39s)
#           acc: 0.99972, fpr: 0.00028, fnr: 0.00025, rec: 0.99975, prc: 0.99365, f1: 0.99669, f1_macro: 0.99827
# epoch: 5, passed number of graphs: 384, train running loss: 0.00215 (passed time: 20m 2s)
#           acc: 0.99970, fpr: 0.00028, fnr: 0.00074, rec: 0.99926, prc: 0.99390, f1: 0.99657, f1_macro: 0.99821
# epoch: 5, passed number of graphs: 480, train running loss: 0.00229 (passed time: 20m 25s)
#           acc: 0.99969, fpr: 0.00030, fnr: 0.00042, rec: 0.99958, prc: 0.99323, f1: 0.99640, f1_macro: 0.99812
# epoch: 5, passed number of graphs: 576, train running loss: 0.00208 (passed time: 20m 48s)
#           acc: 0.99959, fpr: 0.00040, fnr: 0.00049, rec: 0.99951, prc: 0.99090, f1: 0.99519, f1_macro: 0.99749
# epoch: 5, passed number of graphs: 672, train running loss: 0.00206 (passed time: 21m 11s)
#           acc: 0.99739, fpr: 0.00271, fnr: 0.00032, rec: 0.99968, prc: 0.94256, f1: 0.97028, f1_macro: 0.98446
# epoch: 5, passed number of graphs: 768, train running loss: 0.00232 (passed time: 21m 34s)
#           acc: 0.99771, fpr: 0.00226, fnr: 0.00298, rec: 0.99702, prc: 0.95065, f1: 0.97328, f1_macro: 0.98604
# Validation --- epoch: 5, loss: 0.00320
#           fnr: 0.01904, acc: 0.99958, prc: 0.99945, fpr: 0.00001, rec: 0.98096, f1_macro: 0.99445, f1: 0.98911
# Better model saved at ./saved_models/GIN_4: 0.9891057451780186.pt.
# epoch: 6, passed number of graphs: 96, train running loss: 0.00206 (passed time: 22m 19s)
#           acc: 0.99962, fpr: 0.00039, fnr: 0.00008, rec: 0.99992, prc: 0.99133, f1: 0.99560, f1_macro: 0.99770
# epoch: 6, passed number of graphs: 192, train running loss: 0.00217 (passed time: 22m 41s)
#           acc: 0.99986, fpr: 0.00013, fnr: 0.00033, rec: 0.99967, prc: 0.99711, f1: 0.99839, f1_macro: 0.99916
# epoch: 6, passed number of graphs: 288, train running loss: 0.00179 (passed time: 23m 4s)
#           acc: 0.99974, fpr: 0.00026, fnr: 0.00008, rec: 0.99992, prc: 0.99398, f1: 0.99694, f1_macro: 0.99840
# epoch: 6, passed number of graphs: 384, train running loss: 0.00193 (passed time: 23m 27s)
#           acc: 0.99967, fpr: 0.00032, fnr: 0.00057, rec: 0.99943, prc: 0.99301, f1: 0.99621, f1_macro: 0.99802
# epoch: 6, passed number of graphs: 480, train running loss: 0.00211 (passed time: 23m 49s)
#           acc: 0.99965, fpr: 0.00035, fnr: 0.00042, rec: 0.99958, prc: 0.99217, f1: 0.99586, f1_macro: 0.99784
# epoch: 6, passed number of graphs: 576, train running loss: 0.00191 (passed time: 24m 12s)
#           acc: 0.99960, fpr: 0.00041, fnr: 0.00025, rec: 0.99975, prc: 0.99074, f1: 0.99523, f1_macro: 0.99751
# epoch: 6, passed number of graphs: 672, train running loss: 0.00191 (passed time: 24m 34s)
#           acc: 0.99923, fpr: 0.00080, fnr: 0.00008, rec: 0.99992, prc: 0.98239, f1: 0.99108, f1_macro: 0.99534
# epoch: 6, passed number of graphs: 768, train running loss: 0.00212 (passed time: 24m 56s)
#           acc: 0.99983, fpr: 0.00009, fnr: 0.00199, rec: 0.99801, prc: 0.99801, f1: 0.99801, f1_macro: 0.99896
# Validation --- epoch: 6, loss: 0.00452
#           fnr: 0.00589, acc: 0.99920, prc: 0.97926, fpr: 0.00069, rec: 0.99411, f1_macro: 0.99190, f1: 0.98421
# epoch: 7, passed number of graphs: 96, train running loss: 0.00224 (passed time: 25m 40s)
#           acc: 0.99945, fpr: 0.00057, fnr: 0.00000, rec: 1.00000, prc: 0.98728, f1: 0.99360, f1_macro: 0.99666
# epoch: 7, passed number of graphs: 192, train running loss: 0.00235 (passed time: 26m 3s)
#           acc: 0.99986, fpr: 0.00012, fnr: 0.00041, rec: 0.99959, prc: 0.99719, f1: 0.99839, f1_macro: 0.99916
# epoch: 7, passed number of graphs: 288, train running loss: 0.00191 (passed time: 26m 25s)
#           acc: 0.99972, fpr: 0.00029, fnr: 0.00017, rec: 0.99983, prc: 0.99348, f1: 0.99665, f1_macro: 0.99825
# epoch: 7, passed number of graphs: 384, train running loss: 0.00189 (passed time: 26m 49s)
#           acc: 0.99969, fpr: 0.00030, fnr: 0.00049, rec: 0.99951, prc: 0.99341, f1: 0.99645, f1_macro: 0.99815
# epoch: 7, passed number of graphs: 480, train running loss: 0.00206 (passed time: 27m 11s)
#           acc: 0.99969, fpr: 0.00030, fnr: 0.00042, rec: 0.99958, prc: 0.99323, f1: 0.99640, f1_macro: 0.99812
# epoch: 7, passed number of graphs: 576, train running loss: 0.00186 (passed time: 27m 34s)
#           acc: 0.99962, fpr: 0.00039, fnr: 0.00025, rec: 0.99975, prc: 0.99130, f1: 0.99551, f1_macro: 0.99766
# epoch: 7, passed number of graphs: 672, train running loss: 0.00188 (passed time: 27m 56s)
#           acc: 0.99902, fpr: 0.00101, fnr: 0.00024, rec: 0.99976, prc: 0.97778, f1: 0.98865, f1_macro: 0.99407
# epoch: 7, passed number of graphs: 768, train running loss: 0.00183 (passed time: 28m 19s)
#           acc: 0.99981, fpr: 0.00020, fnr: 0.00008, rec: 0.99992, prc: 0.99547, f1: 0.99769, f1_macro: 0.99879
# Validation --- epoch: 7, loss: 0.00192
#           fnr: 0.00526, acc: 0.99981, prc: 0.99631, fpr: 0.00008, rec: 0.99474, f1_macro: 0.99744, f1: 0.99497
# Better model saved at ./saved_models/GIN_6: 0.9949714269630436.pt.
# epoch: 8, passed number of graphs: 96, train running loss: 0.00101 (passed time: 29m 3s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00016, rec: 0.99984, prc: 0.99596, f1: 0.99790, f1_macro: 0.99890
# epoch: 8, passed number of graphs: 192, train running loss: 0.00115 (passed time: 29m 26s)
#           acc: 0.99981, fpr: 0.00019, fnr: 0.00025, rec: 0.99975, prc: 0.99579, f1: 0.99777, f1_macro: 0.99883
# epoch: 8, passed number of graphs: 288, train running loss: 0.00103 (passed time: 29m 49s)
#           acc: 0.99973, fpr: 0.00027, fnr: 0.00025, rec: 0.99975, prc: 0.99389, f1: 0.99681, f1_macro: 0.99834
# epoch: 8, passed number of graphs: 384, train running loss: 0.00117 (passed time: 30m 12s)
#           acc: 0.99964, fpr: 0.00036, fnr: 0.00049, rec: 0.99951, prc: 0.99220, f1: 0.99584, f1_macro: 0.99783
# epoch: 8, passed number of graphs: 480, train running loss: 0.00146 (passed time: 30m 35s)
#           acc: 0.99969, fpr: 0.00031, fnr: 0.00033, rec: 0.99967, prc: 0.99299, f1: 0.99632, f1_macro: 0.99808
# epoch: 8, passed number of graphs: 576, train running loss: 0.00135 (passed time: 30m 57s)
#           acc: 0.99964, fpr: 0.00036, fnr: 0.00049, rec: 0.99951, prc: 0.99195, f1: 0.99571, f1_macro: 0.99776
# epoch: 8, passed number of graphs: 672, train running loss: 0.00141 (passed time: 31m 20s)
#           acc: 0.99903, fpr: 0.00101, fnr: 0.00016, rec: 0.99984, prc: 0.97786, f1: 0.98873, f1_macro: 0.99411
# epoch: 8, passed number of graphs: 768, train running loss: 0.00150 (passed time: 31m 42s)
#           acc: 0.99882, fpr: 0.00117, fnr: 0.00141, rec: 0.99859, prc: 0.97384, f1: 0.98606, f1_macro: 0.99272
# Validation --- epoch: 8, loss: 0.00254
#           fnr: 0.01636, acc: 0.99964, prc: 0.99952, fpr: 0.00001, rec: 0.98364, f1_macro: 0.99516, f1: 0.99051
# epoch: 9, passed number of graphs: 96, train running loss: 0.00122 (passed time: 32m 25s)
#           acc: 0.99982, fpr: 0.00018, fnr: 0.00008, rec: 0.99992, prc: 0.99597, f1: 0.99794, f1_macro: 0.99892
# epoch: 9, passed number of graphs: 192, train running loss: 0.00135 (passed time: 32m 47s)
#           acc: 0.99979, fpr: 0.00022, fnr: 0.00008, rec: 0.99992, prc: 0.99505, f1: 0.99748, f1_macro: 0.99868
# epoch: 9, passed number of graphs: 288, train running loss: 0.00120 (passed time: 33m 10s)
#           acc: 0.99975, fpr: 0.00025, fnr: 0.00025, rec: 0.99975, prc: 0.99422, f1: 0.99698, f1_macro: 0.99842
# epoch: 9, passed number of graphs: 384, train running loss: 0.00129 (passed time: 33m 33s)
#           acc: 0.99964, fpr: 0.00036, fnr: 0.00033, rec: 0.99967, prc: 0.99204, f1: 0.99584, f1_macro: 0.99783
# epoch: 9, passed number of graphs: 480, train running loss: 0.00186 (passed time: 33m 55s)
#           acc: 0.99967, fpr: 0.00033, fnr: 0.00025, rec: 0.99975, prc: 0.99266, f1: 0.99619, f1_macro: 0.99801
# epoch: 9, passed number of graphs: 576, train running loss: 0.00181 (passed time: 34m 18s)
#           acc: 0.99960, fpr: 0.00039, fnr: 0.00066, rec: 0.99934, prc: 0.99114, f1: 0.99523, f1_macro: 0.99751
# epoch: 9, passed number of graphs: 672, train running loss: 0.00188 (passed time: 34m 40s)
#           acc: 0.99956, fpr: 0.00044, fnr: 0.00057, rec: 0.99943, prc: 0.99027, f1: 0.99483, f1_macro: 0.99730
# epoch: 9, passed number of graphs: 768, train running loss: 0.00201 (passed time: 35m 3s)
#           acc: 0.99700, fpr: 0.00314, fnr: 0.00000, rec: 1.00000, prc: 0.93301, f1: 0.96535, f1_macro: 0.98189
# Validation --- epoch: 9, loss: 0.00263
#           fnr: 0.00565, acc: 0.99979, prc: 0.99591, fpr: 0.00009, rec: 0.99435, f1_macro: 0.99723, f1: 0.99458
# epoch: 10, passed number of graphs: 96, train running loss: 0.00135 (passed time: 35m 47s)
#           acc: 0.99964, fpr: 0.00036, fnr: 0.00024, rec: 0.99976, prc: 0.99196, f1: 0.99584, f1_macro: 0.99783
# epoch: 10, passed number of graphs: 192, train running loss: 0.00138 (passed time: 36m 11s)
#           acc: 0.99985, fpr: 0.00014, fnr: 0.00033, rec: 0.99967, prc: 0.99686, f1: 0.99826, f1_macro: 0.99909
# epoch: 10, passed number of graphs: 288, train running loss: 0.00121 (passed time: 36m 33s)
#           acc: 0.99973, fpr: 0.00027, fnr: 0.00017, rec: 0.99983, prc: 0.99381, f1: 0.99681, f1_macro: 0.99834
# epoch: 10, passed number of graphs: 384, train running loss: 0.00122 (passed time: 36m 57s)
#           acc: 0.99970, fpr: 0.00028, fnr: 0.00082, rec: 0.99918, prc: 0.99390, f1: 0.99653, f1_macro: 0.99819
# epoch: 10, passed number of graphs: 480, train running loss: 0.00124 (passed time: 37m 19s)
#           acc: 0.99970, fpr: 0.00030, fnr: 0.00033, rec: 0.99967, prc: 0.99340, f1: 0.99652, f1_macro: 0.99818
# epoch: 10, passed number of graphs: 576, train running loss: 0.00116 (passed time: 37m 41s)
#           acc: 0.99960, fpr: 0.00040, fnr: 0.00041, rec: 0.99959, prc: 0.99106, f1: 0.99531, f1_macro: 0.99755
# epoch: 10, passed number of graphs: 672, train running loss: 0.00116 (passed time: 38m 4s)
#           acc: 0.99941, fpr: 0.00061, fnr: 0.00008, rec: 0.99992, prc: 0.98647, f1: 0.99315, f1_macro: 0.99642
# epoch: 10, passed number of graphs: 768, train running loss: 0.00135 (passed time: 38m 26s)
#           acc: 0.99940, fpr: 0.00061, fnr: 0.00025, rec: 0.99975, prc: 0.98620, f1: 0.99293, f1_macro: 0.99631
# Validation --- epoch: 10, loss: 0.00445
#           fnr: 0.00497, acc: 0.99906, prc: 0.96795, fpr: 0.00085, rec: 0.99503, f1_macro: 0.98949, f1: 0.97946
# epoch: 11, passed number of graphs: 96, train running loss: 0.00141 (passed time: 39m 10s)
#           acc: 0.99965, fpr: 0.00036, fnr: 0.00008, rec: 0.99992, prc: 0.99196, f1: 0.99592, f1_macro: 0.99787
# epoch: 11, passed number of graphs: 192, train running loss: 0.00148 (passed time: 39m 32s)
#           acc: 0.99983, fpr: 0.00017, fnr: 0.00008, rec: 0.99992, prc: 0.99604, f1: 0.99797, f1_macro: 0.99894
# epoch: 11, passed number of graphs: 288, train running loss: 0.00125 (passed time: 39m 55s)
#           acc: 0.99974, fpr: 0.00027, fnr: 0.00008, rec: 0.99992, prc: 0.99381, f1: 0.99686, f1_macro: 0.99836
# epoch: 11, passed number of graphs: 384, train running loss: 0.00130 (passed time: 40m 17s)
#           acc: 0.99968, fpr: 0.00030, fnr: 0.00057, rec: 0.99943, prc: 0.99333, f1: 0.99637, f1_macro: 0.99810
# epoch: 11, passed number of graphs: 480, train running loss: 0.00130 (passed time: 40m 40s)
#           acc: 0.99974, fpr: 0.00026, fnr: 0.00025, rec: 0.99975, prc: 0.99414, f1: 0.99694, f1_macro: 0.99840
# epoch: 11, passed number of graphs: 576, train running loss: 0.00120 (passed time: 41m 2s)
#           acc: 0.99960, fpr: 0.00040, fnr: 0.00033, rec: 0.99967, prc: 0.99090, f1: 0.99527, f1_macro: 0.99753
# epoch: 11, passed number of graphs: 672, train running loss: 0.00118 (passed time: 41m 24s)
#           acc: 0.99942, fpr: 0.00061, fnr: 0.00008, rec: 0.99992, prc: 0.98655, f1: 0.99319, f1_macro: 0.99644
# epoch: 11, passed number of graphs: 768, train running loss: 0.00118 (passed time: 41m 46s)
#           acc: 0.99980, fpr: 0.00020, fnr: 0.00017, rec: 0.99983, prc: 0.99547, f1: 0.99765, f1_macro: 0.99877
# Validation --- epoch: 11, loss: 0.00211
#           fnr: 0.00481, acc: 0.99974, prc: 0.99335, fpr: 0.00015, rec: 0.99519, f1_macro: 0.99675, f1: 0.99363
# epoch: 12, passed number of graphs: 96, train running loss: 0.00137 (passed time: 42m 29s)
#           acc: 0.99975, fpr: 0.00025, fnr: 0.00008, rec: 0.99992, prc: 0.99436, f1: 0.99713, f1_macro: 0.99850
# epoch: 12, passed number of graphs: 192, train running loss: 0.00120 (passed time: 42m 50s)
#           acc: 0.99985, fpr: 0.00015, fnr: 0.00008, rec: 0.99992, prc: 0.99653, f1: 0.99822, f1_macro: 0.99907
# epoch: 12, passed number of graphs: 288, train running loss: 0.00104 (passed time: 43m 13s)
#           acc: 0.99974, fpr: 0.00027, fnr: 0.00008, rec: 0.99992, prc: 0.99381, f1: 0.99686, f1_macro: 0.99836
# epoch: 12, passed number of graphs: 384, train running loss: 0.00106 (passed time: 43m 36s)
#           acc: 0.99971, fpr: 0.00028, fnr: 0.00049, rec: 0.99951, prc: 0.99390, f1: 0.99670, f1_macro: 0.99827
# epoch: 12, passed number of graphs: 480, train running loss: 0.00110 (passed time: 43m 58s)
#           acc: 0.99972, fpr: 0.00028, fnr: 0.00017, rec: 0.99983, prc: 0.99364, f1: 0.99673, f1_macro: 0.99829
# epoch: 12, passed number of graphs: 576, train running loss: 0.00102 (passed time: 44m 21s)
#           acc: 0.99961, fpr: 0.00040, fnr: 0.00025, rec: 0.99975, prc: 0.99106, f1: 0.99539, f1_macro: 0.99759
# epoch: 12, passed number of graphs: 672, train running loss: 0.00102 (passed time: 44m 43s)
#           acc: 0.99948, fpr: 0.00053, fnr: 0.00016, rec: 0.99984, prc: 0.98821, f1: 0.99399, f1_macro: 0.99686
# epoch: 12, passed number of graphs: 768, train running loss: 0.00103 (passed time: 45m 6s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00017, rec: 0.99983, prc: 0.99629, f1: 0.99806, f1_macro: 0.99899
# Validation --- epoch: 12, loss: 0.00173
#           fnr: 0.00509, acc: 0.99980, prc: 0.99583, fpr: 0.00009, rec: 0.99491, f1_macro: 0.99734, f1: 0.99479
# epoch: 13, passed number of graphs: 96, train running loss: 0.00101 (passed time: 45m 50s)
#           acc: 0.99975, fpr: 0.00025, fnr: 0.00008, rec: 0.99992, prc: 0.99436, f1: 0.99713, f1_macro: 0.99850
# epoch: 13, passed number of graphs: 192, train running loss: 0.00101 (passed time: 46m 12s)
#           acc: 0.99983, fpr: 0.00017, fnr: 0.00008, rec: 0.99992, prc: 0.99612, f1: 0.99801, f1_macro: 0.99896
# epoch: 13, passed number of graphs: 288, train running loss: 0.00090 (passed time: 46m 34s)
#           acc: 0.99975, fpr: 0.00026, fnr: 0.00008, rec: 0.99992, prc: 0.99414, f1: 0.99702, f1_macro: 0.99845
# epoch: 13, passed number of graphs: 384, train running loss: 0.00095 (passed time: 46m 57s)
#           acc: 0.99971, fpr: 0.00028, fnr: 0.00049, rec: 0.99951, prc: 0.99382, f1: 0.99666, f1_macro: 0.99825
# epoch: 13, passed number of graphs: 480, train running loss: 0.00099 (passed time: 47m 19s)
#           acc: 0.99973, fpr: 0.00028, fnr: 0.00017, rec: 0.99983, prc: 0.99381, f1: 0.99681, f1_macro: 0.99833
# epoch: 13, passed number of graphs: 576, train running loss: 0.00094 (passed time: 47m 41s)
#           acc: 0.99961, fpr: 0.00040, fnr: 0.00025, rec: 0.99975, prc: 0.99098, f1: 0.99535, f1_macro: 0.99757
# epoch: 13, passed number of graphs: 672, train running loss: 0.00094 (passed time: 48m 3s)
#           acc: 0.99947, fpr: 0.00054, fnr: 0.00016, rec: 0.99984, prc: 0.98798, f1: 0.99387, f1_macro: 0.99680
# epoch: 13, passed number of graphs: 768, train running loss: 0.00096 (passed time: 48m 25s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00017, rec: 0.99983, prc: 0.99637, f1: 0.99810, f1_macro: 0.99901
# Validation --- epoch: 13, loss: 0.00173
#           fnr: 0.00505, acc: 0.99979, prc: 0.99553, fpr: 0.00010, rec: 0.99495, f1_macro: 0.99727, f1: 0.99465
# epoch: 14, passed number of graphs: 96, train running loss: 0.00094 (passed time: 49m 9s)
#           acc: 0.99977, fpr: 0.00023, fnr: 0.00008, rec: 0.99992, prc: 0.99476, f1: 0.99733, f1_macro: 0.99861
# epoch: 14, passed number of graphs: 192, train running loss: 0.00097 (passed time: 49m 31s)
#           acc: 0.99985, fpr: 0.00016, fnr: 0.00000, rec: 1.00000, prc: 0.99645, f1: 0.99822, f1_macro: 0.99907
# epoch: 14, passed number of graphs: 288, train running loss: 0.00087 (passed time: 49m 54s)
#           acc: 0.99975, fpr: 0.00026, fnr: 0.00008, rec: 0.99992, prc: 0.99406, f1: 0.99698, f1_macro: 0.99842
# epoch: 14, passed number of graphs: 384, train running loss: 0.00091 (passed time: 50m 16s)
#           acc: 0.99971, fpr: 0.00028, fnr: 0.00057, rec: 0.99943, prc: 0.99382, f1: 0.99661, f1_macro: 0.99823
# epoch: 14, passed number of graphs: 480, train running loss: 0.00095 (passed time: 50m 39s)
#           acc: 0.99973, fpr: 0.00027, fnr: 0.00017, rec: 0.99983, prc: 0.99389, f1: 0.99685, f1_macro: 0.99836
# epoch: 14, passed number of graphs: 576, train running loss: 0.00090 (passed time: 51m 1s)
#           acc: 0.99961, fpr: 0.00040, fnr: 0.00025, rec: 0.99975, prc: 0.99098, f1: 0.99535, f1_macro: 0.99757
# epoch: 14, passed number of graphs: 672, train running loss: 0.00091 (passed time: 51m 23s)
#           acc: 0.99946, fpr: 0.00056, fnr: 0.00016, rec: 0.99984, prc: 0.98766, f1: 0.99371, f1_macro: 0.99671
# epoch: 14, passed number of graphs: 768, train running loss: 0.00093 (passed time: 51m 45s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00017, rec: 0.99983, prc: 0.99645, f1: 0.99814, f1_macro: 0.99903
# Validation --- epoch: 14, loss: 0.00173
#           fnr: 0.00498, acc: 0.99978, prc: 0.99517, fpr: 0.00011, rec: 0.99502, f1_macro: 0.99719, f1: 0.99448
# epoch: 15, passed number of graphs: 96, train running loss: 0.00095 (passed time: 52m 28s)
#           acc: 0.99979, fpr: 0.00022, fnr: 0.00008, rec: 0.99992, prc: 0.99516, f1: 0.99753, f1_macro: 0.99871
# epoch: 15, passed number of graphs: 192, train running loss: 0.00098 (passed time: 52m 50s)
#           acc: 0.99985, fpr: 0.00016, fnr: 0.00000, rec: 1.00000, prc: 0.99637, f1: 0.99818, f1_macro: 0.99905
# epoch: 15, passed number of graphs: 288, train running loss: 0.00088 (passed time: 53m 12s)
#           acc: 0.99975, fpr: 0.00026, fnr: 0.00008, rec: 0.99992, prc: 0.99414, f1: 0.99702, f1_macro: 0.99845
# epoch: 15, passed number of graphs: 384, train running loss: 0.00091 (passed time: 53m 34s)
#           acc: 0.99972, fpr: 0.00028, fnr: 0.00041, rec: 0.99959, prc: 0.99390, f1: 0.99674, f1_macro: 0.99829
# epoch: 15, passed number of graphs: 480, train running loss: 0.00095 (passed time: 53m 57s)
#           acc: 0.99973, fpr: 0.00027, fnr: 0.00017, rec: 0.99983, prc: 0.99389, f1: 0.99685, f1_macro: 0.99836
# epoch: 15, passed number of graphs: 576, train running loss: 0.00089 (passed time: 54m 20s)
#           acc: 0.99960, fpr: 0.00041, fnr: 0.00025, rec: 0.99975, prc: 0.99082, f1: 0.99527, f1_macro: 0.99753
# epoch: 15, passed number of graphs: 672, train running loss: 0.00090 (passed time: 54m 42s)
#           acc: 0.99947, fpr: 0.00055, fnr: 0.00008, rec: 0.99992, prc: 0.98774, f1: 0.99379, f1_macro: 0.99676
# epoch: 15, passed number of graphs: 768, train running loss: 0.00092 (passed time: 55m 4s)
#           acc: 0.99986, fpr: 0.00014, fnr: 0.00017, rec: 0.99983, prc: 0.99678, f1: 0.99831, f1_macro: 0.99912
# Validation --- epoch: 15, loss: 0.00176
#           fnr: 0.00493, acc: 0.99977, prc: 0.99477, fpr: 0.00012, rec: 0.99507, f1_macro: 0.99709, f1: 0.99429
# epoch: 16, passed number of graphs: 96, train running loss: 0.00110 (passed time: 55m 47s)
#           acc: 0.99975, fpr: 0.00026, fnr: 0.00008, rec: 0.99992, prc: 0.99428, f1: 0.99709, f1_macro: 0.99848
# epoch: 16, passed number of graphs: 192, train running loss: 0.00102 (passed time: 56m 9s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00000, rec: 1.00000, prc: 0.99628, f1: 0.99814, f1_macro: 0.99903
# epoch: 16, passed number of graphs: 288, train running loss: 0.00090 (passed time: 56m 31s)
#           acc: 0.99975, fpr: 0.00026, fnr: 0.00008, rec: 0.99992, prc: 0.99406, f1: 0.99698, f1_macro: 0.99842
# epoch: 16, passed number of graphs: 384, train running loss: 0.00091 (passed time: 56m 54s)
#           acc: 0.99972, fpr: 0.00027, fnr: 0.00049, rec: 0.99951, prc: 0.99398, f1: 0.99674, f1_macro: 0.99829
# epoch: 16, passed number of graphs: 480, train running loss: 0.00094 (passed time: 57m 16s)
#           acc: 0.99972, fpr: 0.00029, fnr: 0.00017, rec: 0.99983, prc: 0.99356, f1: 0.99669, f1_macro: 0.99827
# epoch: 16, passed number of graphs: 576, train running loss: 0.00089 (passed time: 57m 39s)
#           acc: 0.99963, fpr: 0.00038, fnr: 0.00033, rec: 0.99967, prc: 0.99155, f1: 0.99559, f1_macro: 0.99770
# epoch: 16, passed number of graphs: 672, train running loss: 0.00089 (passed time: 58m 1s)
#           acc: 0.99951, fpr: 0.00051, fnr: 0.00008, rec: 0.99992, prc: 0.98869, f1: 0.99427, f1_macro: 0.99701
# epoch: 16, passed number of graphs: 768, train running loss: 0.00091 (passed time: 58m 24s)
#           acc: 0.99985, fpr: 0.00014, fnr: 0.00017, rec: 0.99983, prc: 0.99670, f1: 0.99826, f1_macro: 0.99909
# Validation --- epoch: 16, loss: 0.00170
#           fnr: 0.00498, acc: 0.99978, prc: 0.99523, fpr: 0.00011, rec: 0.99502, f1_macro: 0.99720, f1: 0.99452
# epoch: 17, passed number of graphs: 96, train running loss: 0.00087 (passed time: 59m 9s)
#           acc: 0.99979, fpr: 0.00022, fnr: 0.00008, rec: 0.99992, prc: 0.99516, f1: 0.99753, f1_macro: 0.99871
# epoch: 17, passed number of graphs: 192, train running loss: 0.00089 (passed time: 59m 31s)
#           acc: 0.99985, fpr: 0.00016, fnr: 0.00000, rec: 1.00000, prc: 0.99637, f1: 0.99818, f1_macro: 0.99905
# epoch: 17, passed number of graphs: 288, train running loss: 0.00081 (passed time: 59m 54s)
#           acc: 0.99975, fpr: 0.00025, fnr: 0.00008, rec: 0.99992, prc: 0.99422, f1: 0.99706, f1_macro: 0.99847
# epoch: 17, passed number of graphs: 384, train running loss: 0.00084 (passed time: 1h 0m 17s)
#           acc: 0.99973, fpr: 0.00026, fnr: 0.00049, rec: 0.99951, prc: 0.99422, f1: 0.99686, f1_macro: 0.99836
# epoch: 17, passed number of graphs: 480, train running loss: 0.00089 (passed time: 1h 0m 40s)
#           acc: 0.99973, fpr: 0.00027, fnr: 0.00017, rec: 0.99983, prc: 0.99389, f1: 0.99685, f1_macro: 0.99836
# epoch: 17, passed number of graphs: 576, train running loss: 0.00084 (passed time: 1h 1m 3s)
#           acc: 0.99962, fpr: 0.00038, fnr: 0.00033, rec: 0.99967, prc: 0.99138, f1: 0.99551, f1_macro: 0.99766
# epoch: 17, passed number of graphs: 672, train running loss: 0.00085 (passed time: 1h 1m 25s)
#           acc: 0.99951, fpr: 0.00051, fnr: 0.00016, rec: 0.99984, prc: 0.98877, f1: 0.99427, f1_macro: 0.99701
# epoch: 17, passed number of graphs: 768, train running loss: 0.00087 (passed time: 1h 1m 48s)
#           acc: 0.99986, fpr: 0.00014, fnr: 0.00017, rec: 0.99983, prc: 0.99678, f1: 0.99831, f1_macro: 0.99912
# Validation --- epoch: 17, loss: 0.00170
#           fnr: 0.00495, acc: 0.99978, prc: 0.99494, fpr: 0.00012, rec: 0.99505, f1_macro: 0.99713, f1: 0.99437
# epoch: 18, passed number of graphs: 96, train running loss: 0.00086 (passed time: 1h 2m 32s)
#           acc: 0.99981, fpr: 0.00020, fnr: 0.00008, rec: 0.99992, prc: 0.99564, f1: 0.99778, f1_macro: 0.99884
# epoch: 18, passed number of graphs: 192, train running loss: 0.00088 (passed time: 1h 2m 55s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00000, rec: 1.00000, prc: 0.99628, f1: 0.99814, f1_macro: 0.99903
# epoch: 18, passed number of graphs: 288, train running loss: 0.00081 (passed time: 1h 3m 19s)
#           acc: 0.99976, fpr: 0.00025, fnr: 0.00008, rec: 0.99992, prc: 0.99430, f1: 0.99710, f1_macro: 0.99849
# epoch: 18, passed number of graphs: 384, train running loss: 0.00083 (passed time: 1h 3m 42s)
#           acc: 0.99973, fpr: 0.00026, fnr: 0.00049, rec: 0.99951, prc: 0.99438, f1: 0.99694, f1_macro: 0.99840
# epoch: 18, passed number of graphs: 480, train running loss: 0.00088 (passed time: 1h 4m 5s)
#           acc: 0.99973, fpr: 0.00028, fnr: 0.00017, rec: 0.99983, prc: 0.99381, f1: 0.99681, f1_macro: 0.99833
# epoch: 18, passed number of graphs: 576, train running loss: 0.00083 (passed time: 1h 4m 27s)
#           acc: 0.99962, fpr: 0.00038, fnr: 0.00033, rec: 0.99967, prc: 0.99146, f1: 0.99555, f1_macro: 0.99768
# epoch: 18, passed number of graphs: 672, train running loss: 0.00084 (passed time: 1h 4m 50s)
#           acc: 0.99950, fpr: 0.00051, fnr: 0.00016, rec: 0.99984, prc: 0.98861, f1: 0.99419, f1_macro: 0.99697
# epoch: 18, passed number of graphs: 768, train running loss: 0.00086 (passed time: 1h 5m 13s)
#           acc: 0.99986, fpr: 0.00014, fnr: 0.00017, rec: 0.99983, prc: 0.99686, f1: 0.99835, f1_macro: 0.99914
# Validation --- epoch: 18, loss: 0.00172
#           fnr: 0.00489, acc: 0.99977, prc: 0.99473, fpr: 0.00012, rec: 0.99511, f1_macro: 0.99708, f1: 0.99428
# epoch: 19, passed number of graphs: 96, train running loss: 0.00086 (passed time: 1h 5m 57s)
#           acc: 0.99980, fpr: 0.00021, fnr: 0.00000, rec: 1.00000, prc: 0.99540, f1: 0.99770, f1_macro: 0.99880
# epoch: 19, passed number of graphs: 192, train running loss: 0.00088 (passed time: 1h 6m 20s)
#           acc: 0.99984, fpr: 0.00017, fnr: 0.00000, rec: 1.00000, prc: 0.99620, f1: 0.99810, f1_macro: 0.99901
# epoch: 19, passed number of graphs: 288, train running loss: 0.00080 (passed time: 1h 6m 42s)
#           acc: 0.99975, fpr: 0.00025, fnr: 0.00017, rec: 0.99983, prc: 0.99422, f1: 0.99702, f1_macro: 0.99845
# epoch: 19, passed number of graphs: 384, train running loss: 0.00082 (passed time: 1h 7m 5s)
#           acc: 0.99974, fpr: 0.00025, fnr: 0.00049, rec: 0.99951, prc: 0.99455, f1: 0.99702, f1_macro: 0.99844
# epoch: 19, passed number of graphs: 480, train running loss: 0.00087 (passed time: 1h 7m 27s)
#           acc: 0.99972, fpr: 0.00029, fnr: 0.00017, rec: 0.99983, prc: 0.99356, f1: 0.99669, f1_macro: 0.99827
# epoch: 19, passed number of graphs: 576, train running loss: 0.00083 (passed time: 1h 7m 50s)
#           acc: 0.99964, fpr: 0.00036, fnr: 0.00033, rec: 0.99967, prc: 0.99195, f1: 0.99580, f1_macro: 0.99780
# epoch: 19, passed number of graphs: 672, train running loss: 0.00083 (passed time: 1h 8m 13s)
#           acc: 0.99951, fpr: 0.00051, fnr: 0.00016, rec: 0.99984, prc: 0.98869, f1: 0.99423, f1_macro: 0.99699
# epoch: 19, passed number of graphs: 768, train running loss: 0.00085 (passed time: 1h 8m 36s)
#           acc: 0.99985, fpr: 0.00014, fnr: 0.00017, rec: 0.99983, prc: 0.99670, f1: 0.99826, f1_macro: 0.99909
# Validation --- epoch: 19, loss: 0.00169
#           fnr: 0.00490, acc: 0.99978, prc: 0.99495, fpr: 0.00012, rec: 0.99510, f1_macro: 0.99715, f1: 0.99441
# epoch: 20, passed number of graphs: 96, train running loss: 0.00085 (passed time: 1h 9m 20s)
#           acc: 0.99981, fpr: 0.00020, fnr: 0.00000, rec: 1.00000, prc: 0.99556, f1: 0.99778, f1_macro: 0.99884
# epoch: 20, passed number of graphs: 192, train running loss: 0.00087 (passed time: 1h 9m 42s)
#           acc: 0.99984, fpr: 0.00017, fnr: 0.00008, rec: 0.99992, prc: 0.99620, f1: 0.99806, f1_macro: 0.99899
# epoch: 20, passed number of graphs: 288, train running loss: 0.00079 (passed time: 1h 10m 5s)
#           acc: 0.99975, fpr: 0.00025, fnr: 0.00017, rec: 0.99983, prc: 0.99430, f1: 0.99706, f1_macro: 0.99847
# epoch: 20, passed number of graphs: 384, train running loss: 0.00082 (passed time: 1h 10m 28s)
#           acc: 0.99974, fpr: 0.00025, fnr: 0.00049, rec: 0.99951, prc: 0.99447, f1: 0.99698, f1_macro: 0.99842
# epoch: 20, passed number of graphs: 480, train running loss: 0.00086 (passed time: 1h 10m 50s)
#           acc: 0.99972, fpr: 0.00029, fnr: 0.00017, rec: 0.99983, prc: 0.99356, f1: 0.99669, f1_macro: 0.99827
# epoch: 20, passed number of graphs: 576, train running loss: 0.00082 (passed time: 1h 11m 13s)
#           acc: 0.99964, fpr: 0.00036, fnr: 0.00033, rec: 0.99967, prc: 0.99195, f1: 0.99580, f1_macro: 0.99780
# epoch: 20, passed number of graphs: 672, train running loss: 0.00083 (passed time: 1h 11m 35s)
#           acc: 0.99951, fpr: 0.00051, fnr: 0.00016, rec: 0.99984, prc: 0.98869, f1: 0.99423, f1_macro: 0.99699
# epoch: 20, passed number of graphs: 768, train running loss: 0.00085 (passed time: 1h 11m 58s)
#           acc: 0.99985, fpr: 0.00014, fnr: 0.00017, rec: 0.99983, prc: 0.99670, f1: 0.99826, f1_macro: 0.99909
# Validation --- epoch: 20, loss: 0.00169
#           fnr: 0.00489, acc: 0.99978, prc: 0.99492, fpr: 0.00012, rec: 0.99511, f1_macro: 0.99714, f1: 0.99439
# epoch: 21, passed number of graphs: 96, train running loss: 0.00084 (passed time: 1h 12m 42s)
#           acc: 0.99981, fpr: 0.00020, fnr: 0.00008, rec: 0.99992, prc: 0.99556, f1: 0.99774, f1_macro: 0.99882
# epoch: 21, passed number of graphs: 192, train running loss: 0.00086 (passed time: 1h 13m 6s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00008, rec: 0.99992, prc: 0.99637, f1: 0.99814, f1_macro: 0.99903
# epoch: 21, passed number of graphs: 288, train running loss: 0.00079 (passed time: 1h 13m 28s)
#           acc: 0.99975, fpr: 0.00025, fnr: 0.00017, rec: 0.99983, prc: 0.99430, f1: 0.99706, f1_macro: 0.99847
# epoch: 21, passed number of graphs: 384, train running loss: 0.00081 (passed time: 1h 13m 51s)
#           acc: 0.99974, fpr: 0.00025, fnr: 0.00049, rec: 0.99951, prc: 0.99447, f1: 0.99698, f1_macro: 0.99842
# epoch: 21, passed number of graphs: 480, train running loss: 0.00086 (passed time: 1h 14m 13s)
#           acc: 0.99972, fpr: 0.00029, fnr: 0.00017, rec: 0.99983, prc: 0.99356, f1: 0.99669, f1_macro: 0.99827
# epoch: 21, passed number of graphs: 576, train running loss: 0.00082 (passed time: 1h 14m 36s)
#           acc: 0.99964, fpr: 0.00036, fnr: 0.00033, rec: 0.99967, prc: 0.99195, f1: 0.99580, f1_macro: 0.99780
# epoch: 21, passed number of graphs: 672, train running loss: 0.00082 (passed time: 1h 14m 58s)
#           acc: 0.99951, fpr: 0.00051, fnr: 0.00016, rec: 0.99984, prc: 0.98869, f1: 0.99423, f1_macro: 0.99699
# epoch: 21, passed number of graphs: 768, train running loss: 0.00085 (passed time: 1h 15m 21s)
#           acc: 0.99985, fpr: 0.00014, fnr: 0.00017, rec: 0.99983, prc: 0.99670, f1: 0.99826, f1_macro: 0.99909
# Validation --- epoch: 21, loss: 0.00169
#           fnr: 0.00489, acc: 0.99978, prc: 0.99489, fpr: 0.00012, rec: 0.99511, f1_macro: 0.99713, f1: 0.99437
# epoch: 22, passed number of graphs: 96, train running loss: 0.00084 (passed time: 1h 16m 4s)
#           acc: 0.99981, fpr: 0.00020, fnr: 0.00008, rec: 0.99992, prc: 0.99556, f1: 0.99774, f1_macro: 0.99882
# epoch: 22, passed number of graphs: 192, train running loss: 0.00086 (passed time: 1h 16m 26s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00008, rec: 0.99992, prc: 0.99628, f1: 0.99810, f1_macro: 0.99901
# epoch: 22, passed number of graphs: 288, train running loss: 0.00079 (passed time: 1h 16m 48s)
#           acc: 0.99975, fpr: 0.00025, fnr: 0.00017, rec: 0.99983, prc: 0.99430, f1: 0.99706, f1_macro: 0.99847
# epoch: 22, passed number of graphs: 384, train running loss: 0.00081 (passed time: 1h 17m 10s)
#           acc: 0.99974, fpr: 0.00025, fnr: 0.00049, rec: 0.99951, prc: 0.99455, f1: 0.99702, f1_macro: 0.99844
# epoch: 22, passed number of graphs: 480, train running loss: 0.00086 (passed time: 1h 17m 32s)
#           acc: 0.99972, fpr: 0.00029, fnr: 0.00017, rec: 0.99983, prc: 0.99356, f1: 0.99669, f1_macro: 0.99827
# epoch: 22, passed number of graphs: 576, train running loss: 0.00081 (passed time: 1h 17m 55s)
#           acc: 0.99965, fpr: 0.00035, fnr: 0.00033, rec: 0.99967, prc: 0.99203, f1: 0.99584, f1_macro: 0.99783
# epoch: 22, passed number of graphs: 672, train running loss: 0.00082 (passed time: 1h 18m 17s)
#           acc: 0.99950, fpr: 0.00051, fnr: 0.00016, rec: 0.99984, prc: 0.98861, f1: 0.99419, f1_macro: 0.99697
# epoch: 22, passed number of graphs: 768, train running loss: 0.00085 (passed time: 1h 18m 39s)
#           acc: 0.99986, fpr: 0.00014, fnr: 0.00017, rec: 0.99983, prc: 0.99678, f1: 0.99831, f1_macro: 0.99912
# Validation --- epoch: 22, loss: 0.00169
#           fnr: 0.00489, acc: 0.99978, prc: 0.99486, fpr: 0.00012, rec: 0.99511, f1_macro: 0.99712, f1: 0.99436
# epoch: 23, passed number of graphs: 96, train running loss: 0.00083 (passed time: 1h 19m 21s)
#           acc: 0.99981, fpr: 0.00020, fnr: 0.00008, rec: 0.99992, prc: 0.99556, f1: 0.99774, f1_macro: 0.99882
# epoch: 23, passed number of graphs: 192, train running loss: 0.00086 (passed time: 1h 19m 44s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00008, rec: 0.99992, prc: 0.99628, f1: 0.99810, f1_macro: 0.99901
# epoch: 23, passed number of graphs: 288, train running loss: 0.00079 (passed time: 1h 20m 6s)
#           acc: 0.99975, fpr: 0.00025, fnr: 0.00017, rec: 0.99983, prc: 0.99430, f1: 0.99706, f1_macro: 0.99847
# epoch: 23, passed number of graphs: 384, train running loss: 0.00081 (passed time: 1h 20m 28s)
#           acc: 0.99974, fpr: 0.00025, fnr: 0.00049, rec: 0.99951, prc: 0.99455, f1: 0.99702, f1_macro: 0.99844
# epoch: 23, passed number of graphs: 480, train running loss: 0.00085 (passed time: 1h 20m 50s)
#           acc: 0.99972, fpr: 0.00028, fnr: 0.00017, rec: 0.99983, prc: 0.99364, f1: 0.99673, f1_macro: 0.99829
# epoch: 23, passed number of graphs: 576, train running loss: 0.00081 (passed time: 1h 21m 12s)
#           acc: 0.99965, fpr: 0.00035, fnr: 0.00033, rec: 0.99967, prc: 0.99203, f1: 0.99584, f1_macro: 0.99783
# epoch: 23, passed number of graphs: 672, train running loss: 0.00082 (passed time: 1h 21m 34s)
#           acc: 0.99950, fpr: 0.00051, fnr: 0.00016, rec: 0.99984, prc: 0.98861, f1: 0.99419, f1_macro: 0.99697
# epoch: 23, passed number of graphs: 768, train running loss: 0.00084 (passed time: 1h 21m 57s)
#           acc: 0.99986, fpr: 0.00014, fnr: 0.00017, rec: 0.99983, prc: 0.99678, f1: 0.99831, f1_macro: 0.99912
# Validation --- epoch: 23, loss: 0.00169
#           fnr: 0.00488, acc: 0.99978, prc: 0.99483, fpr: 0.00012, rec: 0.99512, f1_macro: 0.99711, f1: 0.99434
# epoch: 24, passed number of graphs: 96, train running loss: 0.00083 (passed time: 1h 22m 41s)
#           acc: 0.99981, fpr: 0.00020, fnr: 0.00008, rec: 0.99992, prc: 0.99556, f1: 0.99774, f1_macro: 0.99882
# epoch: 24, passed number of graphs: 192, train running loss: 0.00085 (passed time: 1h 23m 3s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00008, rec: 0.99992, prc: 0.99637, f1: 0.99814, f1_macro: 0.99903
# epoch: 24, passed number of graphs: 288, train running loss: 0.00078 (passed time: 1h 23m 25s)
#           acc: 0.99975, fpr: 0.00025, fnr: 0.00017, rec: 0.99983, prc: 0.99430, f1: 0.99706, f1_macro: 0.99847
# epoch: 24, passed number of graphs: 384, train running loss: 0.00081 (passed time: 1h 23m 48s)
#           acc: 0.99973, fpr: 0.00026, fnr: 0.00049, rec: 0.99951, prc: 0.99422, f1: 0.99686, f1_macro: 0.99836
# epoch: 24, passed number of graphs: 480, train running loss: 0.00085 (passed time: 1h 24m 9s)
#           acc: 0.99972, fpr: 0.00029, fnr: 0.00017, rec: 0.99983, prc: 0.99356, f1: 0.99669, f1_macro: 0.99827
# epoch: 24, passed number of graphs: 576, train running loss: 0.00081 (passed time: 1h 24m 31s)
#           acc: 0.99965, fpr: 0.00035, fnr: 0.00033, rec: 0.99967, prc: 0.99203, f1: 0.99584, f1_macro: 0.99783
# epoch: 24, passed number of graphs: 672, train running loss: 0.00082 (passed time: 1h 24m 53s)
#           acc: 0.99950, fpr: 0.00051, fnr: 0.00016, rec: 0.99984, prc: 0.98861, f1: 0.99419, f1_macro: 0.99697
# epoch: 24, passed number of graphs: 768, train running loss: 0.00084 (passed time: 1h 25m 15s)
#           acc: 0.99986, fpr: 0.00014, fnr: 0.00017, rec: 0.99983, prc: 0.99678, f1: 0.99831, f1_macro: 0.99912
# Validation --- epoch: 24, loss: 0.00169
#           fnr: 0.00488, acc: 0.99978, prc: 0.99484, fpr: 0.00012, rec: 0.99512, f1_macro: 0.99712, f1: 0.99435
# epoch: 25, passed number of graphs: 96, train running loss: 0.00083 (passed time: 1h 25m 58s)
#           acc: 0.99981, fpr: 0.00020, fnr: 0.00008, rec: 0.99992, prc: 0.99556, f1: 0.99774, f1_macro: 0.99882
# epoch: 25, passed number of graphs: 192, train running loss: 0.00085 (passed time: 1h 26m 20s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00008, rec: 0.99992, prc: 0.99637, f1: 0.99814, f1_macro: 0.99903
# epoch: 25, passed number of graphs: 288, train running loss: 0.00078 (passed time: 1h 26m 43s)
#           acc: 0.99975, fpr: 0.00025, fnr: 0.00017, rec: 0.99983, prc: 0.99430, f1: 0.99706, f1_macro: 0.99847
# epoch: 25, passed number of graphs: 384, train running loss: 0.00081 (passed time: 1h 27m 6s)
#           acc: 0.99973, fpr: 0.00026, fnr: 0.00049, rec: 0.99951, prc: 0.99422, f1: 0.99686, f1_macro: 0.99836
# ...
#           acc: 0.99975, fpr: 0.00025, fnr: 0.00017, rec: 0.99983, prc: 0.99430, f1: 0.99706, f1_macro: 0.99847
# epoch: 42, passed number of graphs: 384, train running loss: 0.00079 (passed time: 2h 24m 13s)
#           acc: 0.99973, fpr: 0.00026, fnr: 0.00049, rec: 0.99951, prc: 0.99430, f1: 0.99690, f1_macro: 0.99838
# epoch: 42, passed number of graphs: 480, train running loss: 0.00084 (passed time: 2h 24m 35s)
#           acc: 0.99972, fpr: 0.00028, fnr: 0.00017, rec: 0.99983, prc: 0.99364, f1: 0.99673, f1_macro: 0.99829
# epoch: 42, passed number of graphs: 576, train running loss: 0.00080 (passed time: 2h 24m 58s)
#           acc: 0.99964, fpr: 0.00036, fnr: 0.00033, rec: 0.99967, prc: 0.99195, f1: 0.99580, f1_macro: 0.99780
# epoch: 42, passed number of graphs: 672, train running loss: 0.00080 (passed time: 2h 25m 20s)
#           acc: 0.99950, fpr: 0.00052, fnr: 0.00016, rec: 0.99984, prc: 0.98853, f1: 0.99415, f1_macro: 0.99694
# epoch: 42, passed number of graphs: 768, train running loss: 0.00083 (passed time: 2h 25m 43s)
#           acc: 0.99986, fpr: 0.00014, fnr: 0.00017, rec: 0.99983, prc: 0.99686, f1: 0.99835, f1_macro: 0.99914
# Validation --- epoch: 42, loss: 0.00168
#           fnr: 0.00487, acc: 0.99977, prc: 0.99471, fpr: 0.00012, rec: 0.99513, f1_macro: 0.99708, f1: 0.99428
# epoch: 43, passed number of graphs: 96, train running loss: 0.00081 (passed time: 2h 26m 27s)
#           acc: 0.99982, fpr: 0.00019, fnr: 0.00008, rec: 0.99992, prc: 0.99580, f1: 0.99786, f1_macro: 0.99888
# epoch: 43, passed number of graphs: 192, train running loss: 0.00084 (passed time: 2h 26m 49s)
#           acc: 0.99986, fpr: 0.00015, fnr: 0.00008, rec: 0.99992, prc: 0.99670, f1: 0.99830, f1_macro: 0.99911
# epoch: 43, passed number of graphs: 288, train running loss: 0.00077 (passed time: 2h 27m 12s)
#           acc: 0.99975, fpr: 0.00025, fnr: 0.00017, rec: 0.99983, prc: 0.99430, f1: 0.99706, f1_macro: 0.99847
# epoch: 43, passed number of graphs: 384, train running loss: 0.00079 (passed time: 2h 27m 35s)
#           acc: 0.99973, fpr: 0.00026, fnr: 0.00049, rec: 0.99951, prc: 0.99430, f1: 0.99690, f1_macro: 0.99838
# epoch: 43, passed number of graphs: 480, train running loss: 0.00084 (passed time: 2h 27m 58s)
#           acc: 0.99972, fpr: 0.00028, fnr: 0.00017, rec: 0.99983, prc: 0.99364, f1: 0.99673, f1_macro: 0.99829
# epoch: 43, passed number of graphs: 576, train running loss: 0.00080 (passed time: 2h 28m 20s)
#           acc: 0.99964, fpr: 0.00036, fnr: 0.00033, rec: 0.99967, prc: 0.99195, f1: 0.99580, f1_macro: 0.99780
# epoch: 43, passed number of graphs: 672, train running loss: 0.00080 (passed time: 2h 28m 43s)
#           acc: 0.99950, fpr: 0.00052, fnr: 0.00016, rec: 0.99984, prc: 0.98853, f1: 0.99415, f1_macro: 0.99694
# epoch: 43, passed number of graphs: 768, train running loss: 0.00083 (passed time: 2h 29m 5s)
#           acc: 0.99986, fpr: 0.00014, fnr: 0.00017, rec: 0.99983, prc: 0.99686, f1: 0.99835, f1_macro: 0.99914
# Validation --- epoch: 43, loss: 0.00168
#           fnr: 0.00487, acc: 0.99977, prc: 0.99471, fpr: 0.00012, rec: 0.99513, f1_macro: 0.99708, f1: 0.99428
# epoch: 44, passed number of graphs: 96, train running loss: 0.00081 (passed time: 2h 29m 49s)
#           acc: 0.99982, fpr: 0.00019, fnr: 0.00008, rec: 0.99992, prc: 0.99580, f1: 0.99786, f1_macro: 0.99888
# epoch: 44, passed number of graphs: 192, train running loss: 0.00084 (passed time: 2h 30m 12s)
#           acc: 0.99986, fpr: 0.00015, fnr: 0.00008, rec: 0.99992, prc: 0.99670, f1: 0.99830, f1_macro: 0.99911
# epoch: 44, passed number of graphs: 288, train running loss: 0.00077 (passed time: 2h 30m 34s)
#           acc: 0.99975, fpr: 0.00025, fnr: 0.00017, rec: 0.99983, prc: 0.99430, f1: 0.99706, f1_macro: 0.99847
# epoch: 44, passed number of graphs: 384, train running loss: 0.00079 (passed time: 2h 30m 57s)
#           acc: 0.99973, fpr: 0.00026, fnr: 0.00049, rec: 0.99951, prc: 0.99430, f1: 0.99690, f1_macro: 0.99838
# epoch: 44, passed number of graphs: 480, train running loss: 0.00084 (passed time: 2h 31m 20s)
#           acc: 0.99972, fpr: 0.00028, fnr: 0.00017, rec: 0.99983, prc: 0.99364, f1: 0.99673, f1_macro: 0.99829
# epoch: 44, passed number of graphs: 576, train running loss: 0.00080 (passed time: 2h 31m 42s)
#           acc: 0.99964, fpr: 0.00036, fnr: 0.00033, rec: 0.99967, prc: 0.99195, f1: 0.99580, f1_macro: 0.99780
# epoch: 44, passed number of graphs: 672, train running loss: 0.00080 (passed time: 2h 32m 4s)
#           acc: 0.99950, fpr: 0.00052, fnr: 0.00016, rec: 0.99984, prc: 0.98853, f1: 0.99415, f1_macro: 0.99694
# epoch: 44, passed number of graphs: 768, train running loss: 0.00083 (passed time: 2h 32m 27s)
#           acc: 0.99986, fpr: 0.00014, fnr: 0.00017, rec: 0.99983, prc: 0.99686, f1: 0.99835, f1_macro: 0.99914
# Validation --- epoch: 44, loss: 0.00168
#           fnr: 0.00487, acc: 0.99977, prc: 0.99471, fpr: 0.00012, rec: 0.99513, f1_macro: 0.99708, f1: 0.99428
# epoch: 45, passed number of graphs: 96, train running loss: 0.00081 (passed time: 2h 33m 12s)
#           acc: 0.99982, fpr: 0.00019, fnr: 0.00008, rec: 0.99992, prc: 0.99580, f1: 0.99786, f1_macro: 0.99888
# epoch: 45, passed number of graphs: 192, train running loss: 0.00084 (passed time: 2h 33m 34s)
#           acc: 0.99986, fpr: 0.00015, fnr: 0.00008, rec: 0.99992, prc: 0.99670, f1: 0.99830, f1_macro: 0.99911
# epoch: 45, passed number of graphs: 288, train running loss: 0.00077 (passed time: 2h 33m 57s)
#           acc: 0.99975, fpr: 0.00025, fnr: 0.00017, rec: 0.99983, prc: 0.99430, f1: 0.99706, f1_macro: 0.99847
# epoch: 45, passed number of graphs: 384, train running loss: 0.00079 (passed time: 2h 34m 20s)
#           acc: 0.99973, fpr: 0.00026, fnr: 0.00049, rec: 0.99951, prc: 0.99430, f1: 0.99690, f1_macro: 0.99838
# epoch: 45, passed number of graphs: 480, train running loss: 0.00084 (passed time: 2h 34m 42s)
#           acc: 0.99972, fpr: 0.00028, fnr: 0.00017, rec: 0.99983, prc: 0.99364, f1: 0.99673, f1_macro: 0.99829
# epoch: 45, passed number of graphs: 576, train running loss: 0.00080 (passed time: 2h 35m 4s)
#           acc: 0.99964, fpr: 0.00036, fnr: 0.00033, rec: 0.99967, prc: 0.99195, f1: 0.99580, f1_macro: 0.99780
# epoch: 45, passed number of graphs: 672, train running loss: 0.00080 (passed time: 2h 35m 27s)
#           acc: 0.99950, fpr: 0.00052, fnr: 0.00016, rec: 0.99984, prc: 0.98853, f1: 0.99415, f1_macro: 0.99694
# epoch: 45, passed number of graphs: 768, train running loss: 0.00083 (passed time: 2h 35m 49s)
#           acc: 0.99986, fpr: 0.00014, fnr: 0.00017, rec: 0.99983, prc: 0.99686, f1: 0.99835, f1_macro: 0.99914
# Validation --- epoch: 45, loss: 0.00168
#           fnr: 0.00487, acc: 0.99977, prc: 0.99471, fpr: 0.00012, rec: 0.99513, f1_macro: 0.99708, f1: 0.99428
# epoch: 46, passed number of graphs: 96, train running loss: 0.00081 (passed time: 2h 36m 33s)
#           acc: 0.99982, fpr: 0.00019, fnr: 0.00008, rec: 0.99992, prc: 0.99580, f1: 0.99786, f1_macro: 0.99888
# epoch: 46, passed number of graphs: 192, train running loss: 0.00084 (passed time: 2h 36m 55s)
#           acc: 0.99986, fpr: 0.00015, fnr: 0.00008, rec: 0.99992, prc: 0.99670, f1: 0.99830, f1_macro: 0.99911
# epoch: 46, passed number of graphs: 288, train running loss: 0.00077 (passed time: 2h 37m 18s)
#           acc: 0.99975, fpr: 0.00025, fnr: 0.00017, rec: 0.99983, prc: 0.99430, f1: 0.99706, f1_macro: 0.99847
# epoch: 46, passed number of graphs: 384, train running loss: 0.00079 (passed time: 2h 37m 41s)
#           acc: 0.99973, fpr: 0.00026, fnr: 0.00049, rec: 0.99951, prc: 0.99430, f1: 0.99690, f1_macro: 0.99838
# epoch: 46, passed number of graphs: 480, train running loss: 0.00084 (passed time: 2h 38m 4s)
#           acc: 0.99972, fpr: 0.00028, fnr: 0.00017, rec: 0.99983, prc: 0.99364, f1: 0.99673, f1_macro: 0.99829
# epoch: 46, passed number of graphs: 576, train running loss: 0.00080 (passed time: 2h 38m 27s)
#           acc: 0.99964, fpr: 0.00036, fnr: 0.00033, rec: 0.99967, prc: 0.99195, f1: 0.99580, f1_macro: 0.99780
# epoch: 46, passed number of graphs: 672, train running loss: 0.00080 (passed time: 2h 38m 50s)
#           acc: 0.99950, fpr: 0.00052, fnr: 0.00016, rec: 0.99984, prc: 0.98853, f1: 0.99415, f1_macro: 0.99694
# epoch: 46, passed number of graphs: 768, train running loss: 0.00083 (passed time: 2h 39m 12s)
#           acc: 0.99986, fpr: 0.00014, fnr: 0.00017, rec: 0.99983, prc: 0.99686, f1: 0.99835, f1_macro: 0.99914
# Validation --- epoch: 46, loss: 0.00168
#           fnr: 0.00487, acc: 0.99977, prc: 0.99471, fpr: 0.00012, rec: 0.99513, f1_macro: 0.99708, f1: 0.99428
# epoch: 47, passed number of graphs: 96, train running loss: 0.00081 (passed time: 2h 39m 57s)
#           acc: 0.99982, fpr: 0.00019, fnr: 0.00008, rec: 0.99992, prc: 0.99580, f1: 0.99786, f1_macro: 0.99888
# epoch: 47, passed number of graphs: 192, train running loss: 0.00084 (passed time: 2h 40m 19s)
#           acc: 0.99986, fpr: 0.00015, fnr: 0.00008, rec: 0.99992, prc: 0.99670, f1: 0.99830, f1_macro: 0.99911
# epoch: 47, passed number of graphs: 288, train running loss: 0.00077 (passed time: 2h 40m 42s)
#           acc: 0.99975, fpr: 0.00025, fnr: 0.00017, rec: 0.99983, prc: 0.99430, f1: 0.99706, f1_macro: 0.99847
# epoch: 47, passed number of graphs: 384, train running loss: 0.00079 (passed time: 2h 41m 5s)
#           acc: 0.99973, fpr: 0.00026, fnr: 0.00049, rec: 0.99951, prc: 0.99430, f1: 0.99690, f1_macro: 0.99838
# epoch: 47, passed number of graphs: 480, train running loss: 0.00084 (passed time: 2h 41m 27s)
#           acc: 0.99972, fpr: 0.00028, fnr: 0.00017, rec: 0.99983, prc: 0.99364, f1: 0.99673, f1_macro: 0.99829
# epoch: 47, passed number of graphs: 576, train running loss: 0.00080 (passed time: 2h 41m 50s)
#           acc: 0.99964, fpr: 0.00036, fnr: 0.00033, rec: 0.99967, prc: 0.99195, f1: 0.99580, f1_macro: 0.99780
# epoch: 47, passed number of graphs: 672, train running loss: 0.00080 (passed time: 2h 42m 12s)
#           acc: 0.99950, fpr: 0.00052, fnr: 0.00016, rec: 0.99984, prc: 0.98853, f1: 0.99415, f1_macro: 0.99694
# epoch: 47, passed number of graphs: 768, train running loss: 0.00083 (passed time: 2h 42m 35s)
#           acc: 0.99986, fpr: 0.00014, fnr: 0.00017, rec: 0.99983, prc: 0.99686, f1: 0.99835, f1_macro: 0.99914
# Validation --- epoch: 47, loss: 0.00168
#           fnr: 0.00487, acc: 0.99977, prc: 0.99471, fpr: 0.00012, rec: 0.99513, f1_macro: 0.99708, f1: 0.99428
# epoch: 48, passed number of graphs: 96, train running loss: 0.00081 (passed time: 2h 43m 19s)
#           acc: 0.99982, fpr: 0.00019, fnr: 0.00008, rec: 0.99992, prc: 0.99580, f1: 0.99786, f1_macro: 0.99888
# epoch: 48, passed number of graphs: 192, train running loss: 0.00084 (passed time: 2h 43m 42s)
#           acc: 0.99986, fpr: 0.00015, fnr: 0.00008, rec: 0.99992, prc: 0.99670, f1: 0.99830, f1_macro: 0.99911
# epoch: 48, passed number of graphs: 288, train running loss: 0.00077 (passed time: 2h 44m 4s)
#           acc: 0.99975, fpr: 0.00025, fnr: 0.00017, rec: 0.99983, prc: 0.99430, f1: 0.99706, f1_macro: 0.99847
# epoch: 48, passed number of graphs: 384, train running loss: 0.00079 (passed time: 2h 44m 27s)
#           acc: 0.99973, fpr: 0.00026, fnr: 0.00049, rec: 0.99951, prc: 0.99430, f1: 0.99690, f1_macro: 0.99838
# epoch: 48, passed number of graphs: 480, train running loss: 0.00084 (passed time: 2h 44m 50s)
#           acc: 0.99972, fpr: 0.00028, fnr: 0.00017, rec: 0.99983, prc: 0.99364, f1: 0.99673, f1_macro: 0.99829
# epoch: 48, passed number of graphs: 576, train running loss: 0.00080 (passed time: 2h 45m 12s)
#           acc: 0.99964, fpr: 0.00036, fnr: 0.00033, rec: 0.99967, prc: 0.99195, f1: 0.99580, f1_macro: 0.99780
# epoch: 48, passed number of graphs: 672, train running loss: 0.00080 (passed time: 2h 45m 35s)
#           acc: 0.99950, fpr: 0.00052, fnr: 0.00016, rec: 0.99984, prc: 0.98853, f1: 0.99415, f1_macro: 0.99694
# epoch: 48, passed number of graphs: 768, train running loss: 0.00083 (passed time: 2h 45m 58s)
#           acc: 0.99986, fpr: 0.00014, fnr: 0.00017, rec: 0.99983, prc: 0.99686, f1: 0.99835, f1_macro: 0.99914
# Validation --- epoch: 48, loss: 0.00168
#           fnr: 0.00487, acc: 0.99977, prc: 0.99471, fpr: 0.00012, rec: 0.99513, f1_macro: 0.99708, f1: 0.99428
# epoch: 49, passed number of graphs: 96, train running loss: 0.00081 (passed time: 2h 46m 42s)
#           acc: 0.99982, fpr: 0.00019, fnr: 0.00008, rec: 0.99992, prc: 0.99580, f1: 0.99786, f1_macro: 0.99888
# epoch: 49, passed number of graphs: 192, train running loss: 0.00084 (passed time: 2h 47m 4s)
#           acc: 0.99986, fpr: 0.00015, fnr: 0.00008, rec: 0.99992, prc: 0.99670, f1: 0.99830, f1_macro: 0.99911
# epoch: 49, passed number of graphs: 288, train running loss: 0.00077 (passed time: 2h 47m 27s)
#           acc: 0.99975, fpr: 0.00025, fnr: 0.00017, rec: 0.99983, prc: 0.99430, f1: 0.99706, f1_macro: 0.99847
# epoch: 49, passed number of graphs: 384, train running loss: 0.00079 (passed time: 2h 47m 50s)
#           acc: 0.99973, fpr: 0.00026, fnr: 0.00049, rec: 0.99951, prc: 0.99430, f1: 0.99690, f1_macro: 0.99838
# epoch: 49, passed number of graphs: 480, train running loss: 0.00084 (passed time: 2h 48m 13s)
#           acc: 0.99972, fpr: 0.00028, fnr: 0.00017, rec: 0.99983, prc: 0.99364, f1: 0.99673, f1_macro: 0.99829
# epoch: 49, passed number of graphs: 576, train running loss: 0.00080 (passed time: 2h 48m 35s)
#           acc: 0.99964, fpr: 0.00036, fnr: 0.00033, rec: 0.99967, prc: 0.99195, f1: 0.99580, f1_macro: 0.99780
# epoch: 49, passed number of graphs: 672, train running loss: 0.00080 (passed time: 2h 48m 57s)
#           acc: 0.99950, fpr: 0.00052, fnr: 0.00016, rec: 0.99984, prc: 0.98853, f1: 0.99415, f1_macro: 0.99694
# epoch: 49, passed number of graphs: 768, train running loss: 0.00083 (passed time: 2h 49m 18s)
#           acc: 0.99986, fpr: 0.00014, fnr: 0.00017, rec: 0.99983, prc: 0.99686, f1: 0.99835, f1_macro: 0.99914
# Validation --- epoch: 49, loss: 0.00168
#           fnr: 0.00487, acc: 0.99977, prc: 0.99471, fpr: 0.00012, rec: 0.99513, f1_macro: 0.99708, f1: 0.99428
# epoch: 50, passed number of graphs: 96, train running loss: 0.00081 (passed time: 2h 50m 2s)
#           acc: 0.99982, fpr: 0.00019, fnr: 0.00008, rec: 0.99992, prc: 0.99580, f1: 0.99786, f1_macro: 0.99888
# epoch: 50, passed number of graphs: 192, train running loss: 0.00084 (passed time: 2h 50m 24s)
#           acc: 0.99986, fpr: 0.00015, fnr: 0.00008, rec: 0.99992, prc: 0.99670, f1: 0.99830, f1_macro: 0.99911
# epoch: 50, passed number of graphs: 288, train running loss: 0.00077 (passed time: 2h 50m 46s)
#           acc: 0.99975, fpr: 0.00025, fnr: 0.00017, rec: 0.99983, prc: 0.99430, f1: 0.99706, f1_macro: 0.99847
# epoch: 50, passed number of graphs: 384, train running loss: 0.00079 (passed time: 2h 51m 9s)
#           acc: 0.99973, fpr: 0.00026, fnr: 0.00049, rec: 0.99951, prc: 0.99430, f1: 0.99690, f1_macro: 0.99838
# epoch: 50, passed number of graphs: 480, train running loss: 0.00084 (passed time: 2h 51m 31s)
#           acc: 0.99972, fpr: 0.00028, fnr: 0.00017, rec: 0.99983, prc: 0.99364, f1: 0.99673, f1_macro: 0.99829
# epoch: 50, passed number of graphs: 576, train running loss: 0.00080 (passed time: 2h 51m 53s)
#           acc: 0.99964, fpr: 0.00036, fnr: 0.00033, rec: 0.99967, prc: 0.99195, f1: 0.99580, f1_macro: 0.99780
# epoch: 50, passed number of graphs: 672, train running loss: 0.00080 (passed time: 2h 52m 14s)
#           acc: 0.99950, fpr: 0.00052, fnr: 0.00016, rec: 0.99984, prc: 0.98853, f1: 0.99415, f1_macro: 0.99694
# epoch: 50, passed number of graphs: 768, train running loss: 0.00083 (passed time: 2h 52m 37s)
#           acc: 0.99986, fpr: 0.00014, fnr: 0.00017, rec: 0.99983, prc: 0.99686, f1: 0.99835, f1_macro: 0.99914
# Validation --- epoch: 50, loss: 0.00168
#           fnr: 0.00487, acc: 0.99977, prc: 0.99471, fpr: 0.00012, rec: 0.99513, f1_macro: 0.99708, f1: 0.99428
# ************ best model obtained after epoch 7, saved at ./saved_models/GIN_6: 0.9949714269630436.pt ************
# Testing --- loss: 0.00154
#           fnr: 0.00299, acc: 0.99979, prc: 0.99323, fpr: 0.00015, rec: 0.99701, f1_macro: 0.99747, f1: 0.99505

# %%
# !zip -r /content/GIN_053_12_Adam_P2P_6k_feat_norm_12Layer.zip /content/saved_models
# Out:
#   adding: content/saved_models/ (stored 0%)
#   adding: content/saved_models/GIN_0: 0.9783286786406181.pt (deflated 30%)
#   adding: content/saved_models/GIN_4: 0.9891057451780186.pt (deflated 29%)
#   adding: content/saved_models/GIN_6: 0.9949714269630436.pt (deflated 29%)

# %%
from google.colab import files
files.download("/content/GIN_053_12_Adam_P2P_6k_feat_norm_12Layer.zip")
