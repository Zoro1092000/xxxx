# %% [markdown]
# <a href="https://colab.research.google.com/github/Zoro1092000/xxxx/blob/main/TransformerConv_99_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # I. Pip & Import.

# %%
import os
import os.path as osp
import torch
import sys

os.environ['TORCH'] = torch.__version__

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install torch-geometric
# !pip install torch-cluster -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install deepdish==0.3.5
# !pip install torch-optimizer

import torch.nn as nn
from torch.nn import Parameter
from torch_geometric.utils import scatter
from torch_geometric.nn.inits import glorot, zeros
from torch_scatter import scatter_add
from torch.utils.data import DataLoader, Dataset
import torch_optimizer as optimization


from itertools import chain
import pickle
import h5py
import deepdish as dd
import numpy as np
from tqdm import tqdm
import inspect
import time
import math
import random
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-geometric in /usr/local/lib/python3.7/dist-packages (2.1.0.post1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.21.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (4.64.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.0.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (3.0.9)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.7.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.23.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->torch-geometric) (2.0.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (3.0.4)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric) (3.1.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://data.pyg.org/whl/torch-1.12.1+cu113.html
# Requirement already satisfied: torch-cluster in /usr/local/lib/python3.7/dist-packages (1.6.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: deepdish==0.3.5 in /usr/local/lib/python3.7/dist-packages (0.3.5)
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (3.7.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.7.3)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (2.8.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tables->deepdish==0.3.5) (3.0.9)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-optimizer in /usr/local/lib/python3.7/dist-packages (0.3.0)
# Requirement already satisfied: torch>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from torch-optimizer) (1.12.1+cu113)
# Requirement already satisfied: pytorch-ranger>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from torch-optimizer) (0.1.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.5.0->torch-optimizer) (4.1.1)

# %%
def time_since(start):
    now = time.time()
    s = now - start
    m = math.floor(s / 60)
    s -= m * 60
    h = math.floor(m / 60)
    m -= h * 60
    if h == 0:
        if m == 0:
            return '%ds' % s
        else:
            return '%dm %ds' % (m, s)
    else:
        return '%dh %dm %ds' % (h, m, s)

# %% [markdown]
# # II. Data

# %%
# Data utils
def h5group_to_dict(h5group):
    group_dict = {k: v[()] for k, v in chain(h5group.items(), h5group.attrs.items())}
    return group_dict

def sub_dict(full_dict, *keys, to_tensor):
    return {k: torch.tensor(full_dict[k]) if to_tensor else full_dict[k] for k in keys if k in full_dict}

def build_graph_from_dict_pyg(graph_dict, to_tensor=True):
    from torch_geometric.data import Data

    g = Data(**sub_dict(graph_dict, 'edge_index', 'x', 'y', 'edge_attr', 'edge_y', to_tensor=to_tensor))
    return g

# Data loader
class GraphDataLoader(DataLoader):
    def __init__(self, dataset, batch_size=128, shuffle=False, num_workers=0):

        def collate_graph(graph_obj_list):
            from torch_geometric.data import Batch
            batch = Batch.from_data_list(graph_obj_list)
            return batch

        super().__init__(
            dataset,
            batch_size=batch_size,
            shuffle=shuffle,
            collate_fn=collate_graph,
            num_workers=num_workers)

# BotnetDataset
class BotnetDataset(Dataset):

    def __init__(self, name='chord', root='data/botnet', split='train', graph_format='pyg', split_idx=None, add_nfeat_ones=True,
                 in_memory=True):
        super().__init__()
        assert name in ['chord', 'debru', 'kadem', 'leet', 'c2', 'p2p']
        assert split in ['train', 'val', 'test']

        if isinstance(root, str):
            root = osp.expanduser(osp.normpath(root))

        self.name = name
        self.root = root
        self.split = split
        self.split_idx = split_idx
        self.add_nfeat_ones = add_nfeat_ones

        self._graph_format = graph_format
        if split == 'train':
            self.path = self.processed_paths[0]
            self.num_graphs = 768
        elif split == 'val':
            self.path = self.processed_paths[1]
            self.num_graphs = 96
        elif split == 'test':
            self.path = self.processed_paths[2]
            self.num_graphs = 96

        if in_memory:
            self.data = dd.io.load(self.path)  # dictionary
            self.data_type = 'dict'
        else:
            # self.data = h5py.File(self.path, 'r')
            self.data = None    # defer opening file in each process to make multiprocessing work
            self.data_type = 'file'
            
    @property
    def processed_dir(self):
        return osp.join(self.root, 'processed')

    @property
    def processed_file_names(self):
        return [self.name + '_' + s + '.hdf5' for s in ('train', 'val', 'test')]

    @property
    def processed_paths(self):
        return [osp.join(self.processed_dir, f) for f in self.processed_file_names]

    def __len__(self):
        return self.num_graphs

    def __getitem__(self, index):
        if self.data_type == 'dict':
            graph_dict = self.data[str(index)]
        elif self.data_type == 'file':
            if self.data is None:
                # only open once in each process
                self.data = h5py.File(self.path, 'r')
            graph_dict = h5group_to_dict(self.data[str(index)])
        else:
            raise ValueError

        # graph_format == 'pyg':
        return build_graph_from_dict_pyg(graph_dict)


    def __iter__(self):
        for i in range(self.num_graphs):
            yield self[i]

    def __repr__(self):
        return f'{self.__class__.__name__}(topology: {self.name} | split: {self.split} | ' \
               f'#graphs: {len(self)} | graph format: {self.graph_format})'

# %% [markdown]
# # III. Measure Performancce

# %% [markdown]
# ## 3.1. Metrics

# %%
def f1(target, pred, label):
    # F1 = 2 * (precision * recall) / (precision + recall)
    tp = np.sum((target==label) & (pred==label))
    fp = np.sum((target!=label) & (pred==label))
    fn = np.sum((pred!=label) & (target==label))
    
    if tp+fp==0 or tp+fn==0:
      return np.nan

    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    
    if precision+recall==0:
      return np.nan
      
    f1 = 2 * (precision * recall) / (precision + recall)
    return f1

def f1_macro(pred, target):
    return np.mean([f1(target, pred, label) for label in range(0, 2)])


def accuracy(pred, target):
    return (pred == target).sum().item() / len(target)


def true_positive(pred, target):
    return (target[pred == 1] == 1).sum().item()


def false_positive(pred, target):
    return (target[pred == 1] == 0).sum().item()


def true_negative(pred, target):
    return (target[pred == 0] == 0).sum().item()


def false_negative(pred, target):
    return (target[pred == 0] == 1).sum().item()


def recall(pred, target):
    try:
        return true_positive(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1


def precision(pred, target):
    try:
        prec = true_positive(pred, target) / (pred == 1).sum().item()
        return prec
    except:  # divide by zero
        return -1


def f1_score(pred, target):
    prec = precision(pred, target)
    rec = recall(pred, target)
    try:
        return 2 * (prec * rec) / (prec + rec)
    except:
        return 0


def false_positive_rate(pred, target):
    try:
        return false_positive(pred, target) / (target == 0).sum().item()
    except:  # divide by zero
        return -1


def false_negative_rate(pred, target):
    try:
        return false_negative(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1

# %% [markdown]
# ## 3.2. Evaluation

# %%
def eval_metrics(target, pred_prob, threshold=0.5):
    if isinstance(target, torch.Tensor):
        target = target.cpu().numpy()
    if isinstance(pred_prob, torch.Tensor):
        pred_prob = pred_prob.cpu().numpy()

    pred = (pred_prob >= threshold).astype(int)

    acc = accuracy(pred, target)
    fpr = false_positive_rate(pred, target)
    fnr = false_negative_rate(pred, target)
    rec = recall(pred, target)
    prc = precision(pred, target)
    f1 = f1_score(pred, target)
    f1macro = f1_macro(pred, target)
    result_dict = {'acc': acc, 'fpr': fpr, 'fnr': fnr, 'rec': rec, 'prc': prc, 'f1': f1, 'f1_macro': f1macro}

    return result_dict


def dict_value_add(dict1, dict2):
    result = {key: dict1.get(key, 0) + dict2.get(key, 0)
              for key in set(dict1) | set(dict2)}
    return result


def dict_value_div(dict, n):
    result = {key: value / n for key, value in dict.items()}
    return result


def eval_predictor(dataset, predictor):
    result_dict_avg = {}
    loss_avg = 0

    for data in dataset:
        # prediction
        try:
            pred_prob, loss = predictor(data)
            loss_avg += loss
        except ValueError:  # if "too many values to unpack"
            pred_prob = predictor(data)

        # get the ground truth target
        # graph_format == 'pyg':
        target = data.y

        # compute the evaluation metrics
        result_dict = eval_metrics(target, pred_prob)

        result_dict_avg = dict_value_add(result_dict_avg, result_dict)

    # average the metrics across all graphs in the dataset as final results
    result_dict_avg = dict_value_div(result_dict_avg, len(dataset))
    loss_avg = loss_avg / len(dataset)

    return result_dict_avg, loss_avg


# =================================================================================================================
# some examples of the 'predictor' model wrapper to be fed into the above evaluation function (for PyG Data format)
# =================================================================================================================
class PygRandomPredictor:
    def __init__(self):
        # torch.manual_seed(0)
        pass

    def __call__(self, data):
        pred_prob = torch.rand(len(data.y))
        return pred_prob


class PygModelPredictor:
    def __init__(self, model, loss_fcn=torch.nn.CrossEntropyLoss()):
        self.model = model
        self.loss_fcn = loss_fcn
        self.device = next(model.parameters()).device

    def __call__(self, data):
        self.model.eval()
        data = data.to(self.device)
        with torch.no_grad():
            # custom the below line to adjust to your model's input format for forward pass
            out = self.model(data.x, data.edge_index)
            loss = self.loss_fcn(out, data.y.long())
            pred_prob = torch.softmax(out, dim=1)[:, 1]
        return pred_prob, loss.float()

# %% [markdown]
# # IV. Model

# %% [markdown]
# ## 5.1. Activation

# %%
def activation(act, negative_slope=0.2):
    activations = nn.ModuleDict([
        ['lrelu', nn.LeakyReLU(negative_slope)],
        ['relu', nn.ReLU()],
        ['elu', nn.ELU()],
        ['none', nn.Identity()],
    ])
    return activations[act]

# %% [markdown]
# ## 5.2. GIN model

# %%
from torch.nn.modules.activation import LeakyReLU
import torch.nn as nn

class GINModel(nn.Module):
    def __init__(self, dim_input_feature, dim_hidden_feature, num_layers, num_classes, non_linear='relu', dropout=0.2):
        super().__init__()

        self.dim_input_feature = dim_input_feature
        self.dim_hidden_feature = dim_hidden_feature

        self.num_layers = num_layers
        self.num_classes = num_classes
        
        from torch.nn import Linear, Sequential, BatchNorm1d, ReLU, Dropout
        from torch_geometric.nn import GATv2Conv, GINConv, TransformerConv
        
        self.gin_net = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.gin_net.append(TransformerConv(self.dim_input_feature, self.dim_hidden_feature, heads=1, concat=False))
          else:
            self.gin_net.append(TransformerConv(self.dim_hidden_feature, self.dim_hidden_feature, heads=1, concat=False))


        self.dropout = nn.Dropout(dropout)

        self.residuals = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.residuals.append(nn.Linear(self.dim_input_feature, self.dim_hidden_feature, bias=True))
          else:
            self.residuals.append(nn.Identity())

        self.num_residuals = len(self.residuals)

        self.non_linear = activation(non_linear)

        # self.final_type == 'proj':
        self.final = nn.Linear(self.dim_hidden_feature, num_classes)

    def reset_parameters(self):
        for net in self.gin_net:
            net.reset_parameters()
        # self.residual_hop = 1
        for net in self.residuals:
            net.reset_parameters()
        # self.final_type != 'none':
        self.final.reset_parameters()

    def forward(self, x, edge_index):
        xr = None
        add_xr_at = -1

        for n, net in enumerate(self.gin_net):
            # pass to a GIN layer with non-linear activation
            xo = net(x, edge_index)
            xo = self.dropout(xo)
            # deal with residual connections
            # self.residual_hop = 1
            if n < self.num_residuals:
                xr = self.residuals[n](x)
                xo = self.non_linear(xo + xr)

            x = xo
        # size of x: (B * N, dim_hidden_feature) -> (B * N, num_classes)
        x = self.final(x)

        return x

# %% [markdown]
# # V. Load data

# %%
data_dir = '/content/drive/Shareddrives/botnetdata/p2p_6k_feat_norm'
data_name = 'p2p' # 'chord', 'debru', 'kadem', 'leet', 'c2', 'p2p'
shuffle = False

# ========== load the dataset
print('loading dataset...')

train_ds = BotnetDataset(name=data_name, root=data_dir, split='train',
                         in_memory=False, graph_format='pyg')
val_ds = BotnetDataset(name=data_name, root=data_dir, split='val',
                       in_memory=False, graph_format='pyg')
test_ds = BotnetDataset(name=data_name, root=data_dir, split='test',
                        in_memory=False, graph_format='pyg')
# Out:
# loading dataset...

# %%
batch_size = 1
train_loader = GraphDataLoader(train_ds, batch_size=batch_size, shuffle=bool(shuffle), num_workers=0)

# %% [markdown]
# # VI. Train

# %%
# ============== some default parameters =============
devid = 0
seed = 0
logmode = 'w'
log_interval = 96

dim_input_feature = 1
dim_hidden_feature = 32
act = 'relu' # 'none', 'lrelu', 'relu', 'elu'

num_layers = 12
num_classes = 2 

dropout = 0.0
bias = True

lr = 0.005 # learning rate
weight_decay = 5e-4
epochs = 50
save_dir = './saved_models'
save_name = "GIN_model.pt"
# ====================================================

def train(model, train_loader, val_dataset, test_dataset, optimizer, scheduler=None):
    device = next(model.parameters()).device
    predictor = PygModelPredictor(model)

    best_epoch = 0
    max_f1_score = 0
    start = time.time()
    for ep in range(epochs):
        loss_avg_train = 0
        num_train_graph = 0
        model.train()
        for n, batch in enumerate(train_loader):
            batch.to(device)

            optimizer.zero_grad()

            x = model(batch.x, batch.edge_index)
            loss = criterion(x, batch.y.long())

            loss_avg_train += float(loss)
            num_train_graph += batch.num_graphs

            loss.backward()
            optimizer.step()

            if num_train_graph % log_interval == 0 or n == len(train_loader) - 1:
                with torch.no_grad():
                    # pred = x.argmax(dim=1)
                    pred_prob = torch.softmax(x, dim=1)[:, 1]
                    y = batch.y.long()
                    result_dict = eval_metrics(y, pred_prob)
                print(f'epoch: {ep + 1}, passed number of graphs: {num_train_graph}, '
                        f'train running loss: {loss_avg_train / num_train_graph:.5f} (passed time: {time_since(start)})')
                print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict.items()]))

        result_dict_avg, loss_avg = eval_predictor(val_dataset, predictor)
        print(f'Validation --- epoch: {ep + 1}, loss: {loss_avg:.5f}')
        print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))

        if scheduler is not None:
            scheduler.step(loss_avg)

        if result_dict_avg['f1'] > max_f1_score:
            save_name = f"GIN_{ep}: {result_dict_avg['f1']}.pt"
            torch.save(model, os.path.join(save_dir, save_name))
            print(f'Better model saved at {os.path.join(save_dir, save_name)}.')
            best_epoch = ep
            max_f1_score = result_dict_avg['f1']

    best_model = torch.load(os.path.join(save_dir, save_name))
    print('*' * 12 + f' best model obtained after epoch {best_epoch + 1}, '
                       f'saved at {os.path.join(save_dir, save_name)} ' + '*' * 12)
    
    predictor = PygModelPredictor(best_model)

    result_dict_avg, loss_avg = eval_predictor(test_dataset, predictor)
    print(f'Testing --- loss: {loss_avg:.5f}')
    print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))


if __name__ == '__main__':
    os.makedirs(save_dir, exist_ok=True)

    # ========== random seeds and device
    random.seed(seed)
    torch.manual_seed(seed)

    device = torch.device(f'cuda:{devid}') if devid > -1 else torch.device('cpu')

    # ========== logging setup
    log_name = os.path.splitext(save_name)[0]
    # logger = logging_config(__name__, folder=save_dir, name=log_name, filemode=logmode)
    # logger = logging_config(os.path.basename(__file__), folder=save_dir, name=log_name, filemode=logmode)

    print('python ' + ' '.join(sys.argv))
    print('-' * 30)
    #logger.info(args)
    print('-' * 30)
    print(time.ctime())
    print('-' * 30)

    # ========== define the model, optimizer, and loss

    model = GINModel(dim_input_feature,
                     dim_hidden_feature,
                     num_layers,
                     num_classes,
                     non_linear=act,
                     dropout=dropout)

    print('model ' + '-' * 10)
    print(repr(model))
    model.to(device)

    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.25, patience=1)

    # ========== train the model
    print(f"Batch size: {batch_size}")
    train(model, train_loader, val_ds, test_ds, optimizer, scheduler)
# Out:
# python /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-bff4cdbc-5b08-4967-9731-11d0025c87f9.json
# ------------------------------
# ------------------------------
# Thu Nov  3 14:26:37 2022
# ------------------------------
# model ----------
# GINModel(
#   (gin_net): ModuleList(
#     (0): TransformerConv(1, 32, heads=1)
#     (1): TransformerConv(32, 32, heads=1)
#     (2): TransformerConv(32, 32, heads=1)
#     (3): TransformerConv(32, 32, heads=1)
#     (4): TransformerConv(32, 32, heads=1)
#     (5): TransformerConv(32, 32, heads=1)
#     (6): TransformerConv(32, 32, heads=1)
#     (7): TransformerConv(32, 32, heads=1)
#     (8): TransformerConv(32, 32, heads=1)
#     (9): TransformerConv(32, 32, heads=1)
#     (10): TransformerConv(32, 32, heads=1)
#     (11): TransformerConv(32, 32, heads=1)
#   )
#   (dropout): Dropout(p=0.0, inplace=False)
#   (residuals): ModuleList(
#     (0): Linear(in_features=1, out_features=32, bias=True)
#     (1): Identity()
#     (2): Identity()
#     (3): Identity()
#     (4): Identity()
#     (5): Identity()
#     (6): Identity()
#     (7): Identity()
#     (8): Identity()
#     (9): Identity()
#     (10): Identity()
#     (11): Identity()
#   )
#   (non_linear): ReLU()
#   (final): Linear(in_features=32, out_features=2, bias=True)
# )
# Batch size: 1
# epoch: 1, passed number of graphs: 96, train running loss: 0.19269 (passed time: 2m 17s)
#           acc: 0.95801, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 192, train running loss: 0.18264 (passed time: 3m 17s)
#           acc: 0.95840, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 288, train running loss: 0.18953 (passed time: 4m 18s)
#           acc: 0.95918, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 384, train running loss: 0.18572 (passed time: 5m 20s)
#           acc: 0.95647, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 480, train running loss: 0.18340 (passed time: 6m 21s)
#           acc: 0.95759, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 576, train running loss: 0.18177 (passed time: 7m 24s)
#           acc: 0.95767, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 672, train running loss: 0.18077 (passed time: 8m 25s)
#           acc: 0.95829, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 768, train running loss: 0.17991 (passed time: 9m 25s)
#           acc: 0.95782, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# Validation --- epoch: 1, loss: 0.10725
#           prc: -1.00000, acc: 0.97848, f1_macro: nan, fpr: 0.00000, f1: 0.00000, rec: 0.00000, fnr: 1.00000
# epoch: 2, passed number of graphs: 96, train running loss: 0.17502 (passed time: 11m 5s)
#           acc: 0.95801, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 2, passed number of graphs: 192, train running loss: 0.17499 (passed time: 12m 3s)
#           acc: 0.95840, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 2, passed number of graphs: 288, train running loss: 0.17500 (passed time: 13m 2s)
#           acc: 0.95918, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 2, passed number of graphs: 384, train running loss: 0.17494 (passed time: 14m 0s)
#           acc: 0.95647, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 2, passed number of graphs: 480, train running loss: 0.17482 (passed time: 14m 59s)
#           acc: 0.95759, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 2, passed number of graphs: 576, train running loss: 0.17467 (passed time: 15m 56s)
#           acc: 0.95767, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 2, passed number of graphs: 672, train running loss: 0.17440 (passed time: 16m 55s)
#           acc: 0.95829, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 2, passed number of graphs: 768, train running loss: 0.17327 (passed time: 17m 54s)
#           acc: 0.95781, fpr: 0.00001, fnr: 1.00000, rec: 0.00000, prc: 0.00000, f1: 0.00000, f1_macro: nan
# Validation --- epoch: 2, loss: 0.11149
#           prc: 0.06416, acc: 0.97526, f1_macro: nan, fpr: 0.00368, f1: 0.01441, rec: 0.01814, fnr: 0.98186
# Better model saved at ./saved_models/GIN_1: 0.014411624996837702.pt.
# epoch: 3, passed number of graphs: 96, train running loss: 0.15384 (passed time: 19m 27s)
#           acc: 0.94172, fpr: 0.05977, fnr: 0.02433, rec: 0.97567, prc: 0.41706, f1: 0.58434, f1_macro: 0.77650
# epoch: 3, passed number of graphs: 192, train running loss: 0.12080 (passed time: 20m 25s)
#           acc: 0.98923, fpr: 0.01100, fnr: 0.00552, rec: 0.99448, prc: 0.79697, f1: 0.88484, f1_macro: 0.93960
# epoch: 3, passed number of graphs: 288, train running loss: 0.08612 (passed time: 21m 24s)
#           acc: 0.99620, fpr: 0.00009, fnr: 0.09094, rec: 0.90906, prc: 0.99762, f1: 0.95128, f1_macro: 0.97465
# epoch: 3, passed number of graphs: 384, train running loss: 0.07441 (passed time: 22m 22s)
#           acc: 0.99949, fpr: 0.00019, fnr: 0.00755, rec: 0.99245, prc: 0.99588, f1: 0.99416, f1_macro: 0.99695
# epoch: 3, passed number of graphs: 480, train running loss: 0.06168 (passed time: 23m 20s)
#           acc: 0.99965, fpr: 0.00031, fnr: 0.00133, rec: 0.99867, prc: 0.99306, f1: 0.99586, f1_macro: 0.99784
# epoch: 3, passed number of graphs: 576, train running loss: 0.05279 (passed time: 24m 18s)
#           acc: 0.98907, fpr: 0.01136, fnr: 0.00115, rec: 0.99885, prc: 0.79537, f1: 0.88557, f1_macro: 0.93992
# epoch: 3, passed number of graphs: 672, train running loss: 0.04638 (passed time: 25m 16s)
#           acc: 0.99450, fpr: 0.00019, fnr: 0.12735, rec: 0.87265, prc: 0.99497, f1: 0.92981, f1_macro: 0.96347
# epoch: 3, passed number of graphs: 768, train running loss: 0.04163 (passed time: 26m 15s)
#           acc: 0.99086, fpr: 0.00949, fnr: 0.00116, rec: 0.99884, prc: 0.82256, f1: 0.90217, f1_macro: 0.94869
# Validation --- epoch: 3, loss: 0.00431
#           prc: 0.98195, acc: 0.99907, f1_macro: 0.98885, fpr: 0.00046, f1: 0.97817, rec: 0.97762, fnr: 0.02238
# Better model saved at ./saved_models/GIN_2: 0.9781720440700327.pt.
# epoch: 4, passed number of graphs: 96, train running loss: 0.01575 (passed time: 27m 49s)
#           acc: 0.99991, fpr: 0.00005, fnr: 0.00097, rec: 0.99903, prc: 0.99886, f1: 0.99895, f1_macro: 0.99945
# epoch: 4, passed number of graphs: 192, train running loss: 0.01339 (passed time: 28m 47s)
#           acc: 0.99985, fpr: 0.00005, fnr: 0.00234, rec: 0.99766, prc: 0.99883, f1: 0.99824, f1_macro: 0.99908
# epoch: 4, passed number of graphs: 288, train running loss: 0.01136 (passed time: 29m 46s)
#           acc: 0.99979, fpr: 0.00013, fnr: 0.00217, rec: 0.99783, prc: 0.99700, f1: 0.99741, f1_macro: 0.99865
# epoch: 4, passed number of graphs: 384, train running loss: 0.01051 (passed time: 30m 44s)
#           acc: 0.99924, fpr: 0.00067, fnr: 0.00263, rec: 0.99737, prc: 0.98541, f1: 0.99135, f1_macro: 0.99548
# epoch: 4, passed number of graphs: 480, train running loss: 0.01009 (passed time: 31m 42s)
#           acc: 0.99974, fpr: 0.00015, fnr: 0.00283, rec: 0.99717, prc: 0.99668, f1: 0.99693, f1_macro: 0.99839
# epoch: 4, passed number of graphs: 576, train running loss: 0.00936 (passed time: 32m 40s)
#           acc: 0.99933, fpr: 0.00060, fnr: 0.00214, rec: 0.99786, prc: 0.98652, f1: 0.99216, f1_macro: 0.99590
# epoch: 4, passed number of graphs: 672, train running loss: 0.00893 (passed time: 33m 38s)
#           acc: 0.99452, fpr: 0.00009, fnr: 0.12931, rec: 0.87069, prc: 0.99757, f1: 0.92982, f1_macro: 0.96349
# epoch: 4, passed number of graphs: 768, train running loss: 0.00877 (passed time: 34m 38s)
#           acc: 0.99976, fpr: 0.00009, fnr: 0.00365, rec: 0.99635, prc: 0.99800, f1: 0.99718, f1_macro: 0.99853
# Validation --- epoch: 4, loss: 0.00321
#           prc: 0.99663, acc: 0.99958, f1_macro: 0.99439, fpr: 0.00007, f1: 0.98900, rec: 0.98334, fnr: 0.01666
# Better model saved at ./saved_models/GIN_3: 0.9889959739422087.pt.
# epoch: 5, passed number of graphs: 96, train running loss: 0.01369 (passed time: 36m 11s)
#           acc: 0.99993, fpr: 0.00003, fnr: 0.00114, rec: 0.99886, prc: 0.99935, f1: 0.99911, f1_macro: 0.99953
# epoch: 5, passed number of graphs: 192, train running loss: 0.00984 (passed time: 37m 9s)
#           acc: 0.99985, fpr: 0.00001, fnr: 0.00334, rec: 0.99666, prc: 0.99966, f1: 0.99816, f1_macro: 0.99904
# epoch: 5, passed number of graphs: 288, train running loss: 0.00794 (passed time: 38m 8s)
#           acc: 0.99982, fpr: 0.00002, fnr: 0.00400, rec: 0.99600, prc: 0.99950, f1: 0.99774, f1_macro: 0.99882
# epoch: 5, passed number of graphs: 384, train running loss: 0.00776 (passed time: 39m 7s)
#           acc: 0.99353, fpr: 0.00672, fnr: 0.00098, rec: 0.99902, prc: 0.87119, f1: 0.93073, f1_macro: 0.96367
# epoch: 5, passed number of graphs: 480, train running loss: 0.00772 (passed time: 40m 5s)
#           acc: 0.99975, fpr: 0.00009, fnr: 0.00382, rec: 0.99618, prc: 0.99800, f1: 0.99709, f1_macro: 0.99848
# epoch: 5, passed number of graphs: 576, train running loss: 0.00726 (passed time: 41m 3s)
#           acc: 0.99923, fpr: 0.00080, fnr: 0.00016, rec: 0.99984, prc: 0.98224, f1: 0.99096, f1_macro: 0.99528
# epoch: 5, passed number of graphs: 672, train running loss: 0.00720 (passed time: 42m 2s)
#           acc: 0.99453, fpr: 0.00013, fnr: 0.12816, rec: 0.87184, prc: 0.99664, f1: 0.93007, f1_macro: 0.96361
# epoch: 5, passed number of graphs: 768, train running loss: 0.00701 (passed time: 43m 1s)
#           acc: 0.99251, fpr: 0.00008, fnr: 0.17580, rec: 0.82420, prc: 0.99779, f1: 0.90273, f1_macro: 0.94942
# Validation --- epoch: 5, loss: 0.00316
#           prc: 0.99308, acc: 0.99940, f1_macro: 0.99224, fpr: 0.00016, f1: 0.98479, rec: 0.97919, fnr: 0.02081
# epoch: 6, passed number of graphs: 96, train running loss: 0.01344 (passed time: 44m 34s)
#           acc: 0.99993, fpr: 0.00004, fnr: 0.00081, rec: 0.99919, prc: 0.99903, f1: 0.99911, f1_macro: 0.99953
# epoch: 6, passed number of graphs: 192, train running loss: 0.01189 (passed time: 45m 33s)
#           acc: 0.99985, fpr: 0.00000, fnr: 0.00351, rec: 0.99649, prc: 1.00000, f1: 0.99824, f1_macro: 0.99908
# epoch: 6, passed number of graphs: 288, train running loss: 0.00899 (passed time: 46m 32s)
#           acc: 0.99982, fpr: 0.00006, fnr: 0.00300, rec: 0.99700, prc: 0.99866, f1: 0.99783, f1_macro: 0.99887
# epoch: 6, passed number of graphs: 384, train running loss: 0.00810 (passed time: 47m 30s)
#           acc: 0.99981, fpr: 0.00015, fnr: 0.00115, rec: 0.99885, prc: 0.99672, f1: 0.99779, f1_macro: 0.99884
# epoch: 6, passed number of graphs: 480, train running loss: 0.00780 (passed time: 48m 28s)
#           acc: 0.99975, fpr: 0.00012, fnr: 0.00332, rec: 0.99668, prc: 0.99734, f1: 0.99701, f1_macro: 0.99844
# epoch: 6, passed number of graphs: 576, train running loss: 0.00736 (passed time: 49m 26s)
#           acc: 0.99931, fpr: 0.00063, fnr: 0.00197, rec: 0.99803, prc: 0.98588, f1: 0.99192, f1_macro: 0.99578
# epoch: 6, passed number of graphs: 672, train running loss: 0.00721 (passed time: 50m 25s)
#           acc: 0.99452, fpr: 0.00009, fnr: 0.12931, rec: 0.87069, prc: 0.99757, f1: 0.92982, f1_macro: 0.96349
# epoch: 6, passed number of graphs: 768, train running loss: 0.00706 (passed time: 51m 24s)
#           acc: 0.99981, fpr: 0.00010, fnr: 0.00216, rec: 0.99784, prc: 0.99768, f1: 0.99776, f1_macro: 0.99883
# Validation --- epoch: 6, loss: 0.00337
#           prc: 0.99728, acc: 0.99929, f1_macro: 0.99020, fpr: 0.00006, f1: 0.98076, rec: 0.96943, fnr: 0.03057
# epoch: 7, passed number of graphs: 96, train running loss: 0.00711 (passed time: 52m 57s)
#           acc: 0.99995, fpr: 0.00002, fnr: 0.00081, rec: 0.99919, prc: 0.99951, f1: 0.99935, f1_macro: 0.99966
# epoch: 7, passed number of graphs: 192, train running loss: 0.00678 (passed time: 53m 56s)
#           acc: 0.99985, fpr: 0.00001, fnr: 0.00334, rec: 0.99666, prc: 0.99983, f1: 0.99824, f1_macro: 0.99908
# epoch: 7, passed number of graphs: 288, train running loss: 0.00573 (passed time: 54m 55s)
#           acc: 0.99987, fpr: 0.00005, fnr: 0.00200, rec: 0.99800, prc: 0.99883, f1: 0.99841, f1_macro: 0.99917
# epoch: 7, passed number of graphs: 384, train running loss: 0.00598 (passed time: 55m 53s)
#           acc: 0.99981, fpr: 0.00019, fnr: 0.00000, rec: 1.00000, prc: 0.99575, f1: 0.99787, f1_macro: 0.99889
# epoch: 7, passed number of graphs: 480, train running loss: 0.00674 (passed time: 56m 51s)
#           acc: 0.99957, fpr: 0.00016, fnr: 0.00648, rec: 0.99352, prc: 0.99633, f1: 0.99492, f1_macro: 0.99735
# epoch: 7, passed number of graphs: 576, train running loss: 0.00785 (passed time: 57m 48s)
#           acc: 0.99921, fpr: 0.00081, fnr: 0.00049, rec: 0.99951, prc: 0.98208, f1: 0.99072, f1_macro: 0.99515
# epoch: 7, passed number of graphs: 672, train running loss: 0.00773 (passed time: 58m 47s)
#           acc: 0.99449, fpr: 0.00014, fnr: 0.12882, rec: 0.87118, prc: 0.99627, f1: 0.92954, f1_macro: 0.96333
# epoch: 7, passed number of graphs: 768, train running loss: 0.00743 (passed time: 59m 46s)
#           acc: 0.99980, fpr: 0.00013, fnr: 0.00166, rec: 0.99834, prc: 0.99702, f1: 0.99768, f1_macro: 0.99879
# Validation --- epoch: 7, loss: 0.00321
#           prc: 0.99679, acc: 0.99939, f1_macro: 0.99168, fpr: 0.00007, f1: 0.98368, rec: 0.97474, fnr: 0.02526
# epoch: 8, passed number of graphs: 96, train running loss: 0.00358 (passed time: 1h 1m 18s)
#           acc: 0.99995, fpr: 0.00003, fnr: 0.00049, rec: 0.99951, prc: 0.99935, f1: 0.99943, f1_macro: 0.99970
# epoch: 8, passed number of graphs: 192, train running loss: 0.00363 (passed time: 1h 2m 17s)
#           acc: 0.99987, fpr: 0.00002, fnr: 0.00251, rec: 0.99749, prc: 0.99950, f1: 0.99849, f1_macro: 0.99921
# epoch: 8, passed number of graphs: 288, train running loss: 0.00347 (passed time: 1h 3m 16s)
#           acc: 0.99985, fpr: 0.00006, fnr: 0.00234, rec: 0.99766, prc: 0.99866, f1: 0.99816, f1_macro: 0.99904
# epoch: 8, passed number of graphs: 384, train running loss: 0.00339 (passed time: 1h 4m 15s)
#           acc: 0.99979, fpr: 0.00012, fnr: 0.00230, rec: 0.99770, prc: 0.99737, f1: 0.99754, f1_macro: 0.99871
# epoch: 8, passed number of graphs: 480, train running loss: 0.00379 (passed time: 1h 5m 13s)
#           acc: 0.99969, fpr: 0.00027, fnr: 0.00116, rec: 0.99884, prc: 0.99388, f1: 0.99635, f1_macro: 0.99810
# epoch: 8, passed number of graphs: 576, train running loss: 0.00372 (passed time: 1h 6m 11s)
#           acc: 0.99933, fpr: 0.00061, fnr: 0.00214, rec: 0.99786, prc: 0.98636, f1: 0.99208, f1_macro: 0.99586
# epoch: 8, passed number of graphs: 672, train running loss: 0.00379 (passed time: 1h 7m 9s)
#           acc: 0.99454, fpr: 0.00014, fnr: 0.12767, rec: 0.87233, prc: 0.99646, f1: 0.93027, f1_macro: 0.96372
# epoch: 8, passed number of graphs: 768, train running loss: 0.00381 (passed time: 1h 8m 8s)
#           acc: 0.99981, fpr: 0.00012, fnr: 0.00166, rec: 0.99834, prc: 0.99718, f1: 0.99776, f1_macro: 0.99883
# Validation --- epoch: 8, loss: 0.00288
#           prc: 0.99562, acc: 0.99951, f1_macro: 0.99345, fpr: 0.00009, f1: 0.98714, rec: 0.98125, fnr: 0.01875
# epoch: 9, passed number of graphs: 96, train running loss: 0.00353 (passed time: 1h 9m 41s)
#           acc: 0.99997, fpr: 0.00003, fnr: 0.00016, rec: 0.99984, prc: 0.99935, f1: 0.99959, f1_macro: 0.99979
# epoch: 9, passed number of graphs: 192, train running loss: 0.00365 (passed time: 1h 10m 39s)
#           acc: 0.99989, fpr: 0.00003, fnr: 0.00201, rec: 0.99799, prc: 0.99933, f1: 0.99866, f1_macro: 0.99930
# epoch: 9, passed number of graphs: 288, train running loss: 0.00360 (passed time: 1h 11m 38s)
#           acc: 0.99984, fpr: 0.00011, fnr: 0.00133, rec: 0.99867, prc: 0.99750, f1: 0.99808, f1_macro: 0.99900
# epoch: 9, passed number of graphs: 384, train running loss: 0.00348 (passed time: 1h 12m 36s)
#           acc: 0.99980, fpr: 0.00010, fnr: 0.00230, rec: 0.99770, prc: 0.99770, f1: 0.99770, f1_macro: 0.99880
# epoch: 9, passed number of graphs: 480, train running loss: 0.00384 (passed time: 1h 13m 34s)
#           acc: 0.99970, fpr: 0.00027, fnr: 0.00083, rec: 0.99917, prc: 0.99388, f1: 0.99652, f1_macro: 0.99818
# epoch: 9, passed number of graphs: 576, train running loss: 0.00376 (passed time: 1h 14m 32s)
#           acc: 0.99938, fpr: 0.00054, fnr: 0.00230, rec: 0.99770, prc: 0.98780, f1: 0.99272, f1_macro: 0.99620
# epoch: 9, passed number of graphs: 672, train running loss: 0.00388 (passed time: 1h 15m 30s)
#           acc: 0.99455, fpr: 0.00015, fnr: 0.12718, rec: 0.87282, prc: 0.99609, f1: 0.93039, f1_macro: 0.96378
# epoch: 9, passed number of graphs: 768, train running loss: 0.00393 (passed time: 1h 16m 29s)
#           acc: 0.99984, fpr: 0.00012, fnr: 0.00100, rec: 0.99900, prc: 0.99718, f1: 0.99809, f1_macro: 0.99900
# Validation --- epoch: 9, loss: 0.00299
#           prc: 0.99342, acc: 0.99942, f1_macro: 0.99251, fpr: 0.00015, f1: 0.98531, rec: 0.97990, fnr: 0.02010
# epoch: 10, passed number of graphs: 96, train running loss: 0.00388 (passed time: 1h 18m 1s)
#           acc: 0.99997, fpr: 0.00003, fnr: 0.00016, rec: 0.99984, prc: 0.99935, f1: 0.99959, f1_macro: 0.99979
# epoch: 10, passed number of graphs: 192, train running loss: 0.00377 (passed time: 1h 19m 0s)
#           acc: 0.99990, fpr: 0.00001, fnr: 0.00217, rec: 0.99783, prc: 0.99966, f1: 0.99874, f1_macro: 0.99935
# epoch: 10, passed number of graphs: 288, train running loss: 0.00360 (passed time: 1h 19m 59s)
#           acc: 0.99986, fpr: 0.00012, fnr: 0.00067, rec: 0.99933, prc: 0.99717, f1: 0.99825, f1_macro: 0.99909
# epoch: 10, passed number of graphs: 384, train running loss: 0.00365 (passed time: 1h 20m 57s)
#           acc: 0.99977, fpr: 0.00019, fnr: 0.00115, rec: 0.99885, prc: 0.99591, f1: 0.99738, f1_macro: 0.99863
# epoch: 10, passed number of graphs: 480, train running loss: 0.00395 (passed time: 1h 21m 54s)
#           acc: 0.99972, fpr: 0.00026, fnr: 0.00083, rec: 0.99917, prc: 0.99421, f1: 0.99668, f1_macro: 0.99827
# epoch: 10, passed number of graphs: 576, train running loss: 0.00392 (passed time: 1h 22m 51s)
#           acc: 0.99931, fpr: 0.00068, fnr: 0.00082, rec: 0.99918, prc: 0.98478, f1: 0.99193, f1_macro: 0.99578
# epoch: 10, passed number of graphs: 672, train running loss: 0.00402 (passed time: 1h 23m 50s)
#           acc: 0.99457, fpr: 0.00013, fnr: 0.12735, rec: 0.87265, prc: 0.99664, f1: 0.93054, f1_macro: 0.96385
# epoch: 10, passed number of graphs: 768, train running loss: 0.00405 (passed time: 1h 24m 49s)
#           acc: 0.99983, fpr: 0.00011, fnr: 0.00149, rec: 0.99851, prc: 0.99751, f1: 0.99801, f1_macro: 0.99896
# Validation --- epoch: 10, loss: 0.00279
#           prc: 0.99714, acc: 0.99951, f1_macro: 0.99339, fpr: 0.00006, f1: 0.98703, rec: 0.98016, fnr: 0.01984
# epoch: 11, passed number of graphs: 96, train running loss: 0.00340 (passed time: 1h 26m 21s)
#           acc: 0.99997, fpr: 0.00003, fnr: 0.00016, rec: 0.99984, prc: 0.99935, f1: 0.99959, f1_macro: 0.99979
# epoch: 11, passed number of graphs: 192, train running loss: 0.00366 (passed time: 1h 27m 20s)
#           acc: 0.99990, fpr: 0.00001, fnr: 0.00217, rec: 0.99783, prc: 0.99966, f1: 0.99874, f1_macro: 0.99935
# epoch: 11, passed number of graphs: 288, train running loss: 0.00347 (passed time: 1h 28m 18s)
#           acc: 0.99980, fpr: 0.00019, fnr: 0.00033, rec: 0.99967, prc: 0.99551, f1: 0.99759, f1_macro: 0.99874
# epoch: 11, passed number of graphs: 384, train running loss: 0.00362 (passed time: 1h 29m 16s)
#           acc: 0.99981, fpr: 0.00013, fnr: 0.00164, rec: 0.99836, prc: 0.99721, f1: 0.99779, f1_macro: 0.99884
# epoch: 11, passed number of graphs: 480, train running loss: 0.00395 (passed time: 1h 30m 14s)
#           acc: 0.99972, fpr: 0.00024, fnr: 0.00116, rec: 0.99884, prc: 0.99454, f1: 0.99668, f1_macro: 0.99827
# epoch: 11, passed number of graphs: 576, train running loss: 0.00394 (passed time: 1h 31m 11s)
#           acc: 0.99926, fpr: 0.00076, fnr: 0.00016, rec: 0.99984, prc: 0.98304, f1: 0.99137, f1_macro: 0.99549
# epoch: 11, passed number of graphs: 672, train running loss: 0.00403 (passed time: 1h 32m 10s)
#           acc: 0.99456, fpr: 0.00014, fnr: 0.12718, rec: 0.87282, prc: 0.99627, f1: 0.93047, f1_macro: 0.96382
# epoch: 11, passed number of graphs: 768, train running loss: 0.00400 (passed time: 1h 33m 10s)
#           acc: 0.99984, fpr: 0.00012, fnr: 0.00116, rec: 0.99884, prc: 0.99735, f1: 0.99809, f1_macro: 0.99900
# Validation --- epoch: 11, loss: 0.00277
#           prc: 0.99698, acc: 0.99951, f1_macro: 0.99325, fpr: 0.00007, f1: 0.98675, rec: 0.97983, fnr: 0.02017
# epoch: 12, passed number of graphs: 96, train running loss: 0.00340 (passed time: 1h 34m 42s)
#           acc: 0.99997, fpr: 0.00003, fnr: 0.00000, rec: 1.00000, prc: 0.99935, f1: 0.99968, f1_macro: 0.99983
# epoch: 12, passed number of graphs: 192, train running loss: 0.00360 (passed time: 1h 35m 41s)
#           acc: 0.99990, fpr: 0.00002, fnr: 0.00201, rec: 0.99799, prc: 0.99950, f1: 0.99874, f1_macro: 0.99935
# epoch: 12, passed number of graphs: 288, train running loss: 0.00344 (passed time: 1h 36m 40s)
#           acc: 0.99982, fpr: 0.00016, fnr: 0.00050, rec: 0.99950, prc: 0.99617, f1: 0.99783, f1_macro: 0.99887
# epoch: 12, passed number of graphs: 384, train running loss: 0.00349 (passed time: 1h 37m 38s)
#           acc: 0.99984, fpr: 0.00013, fnr: 0.00082, rec: 0.99918, prc: 0.99722, f1: 0.99820, f1_macro: 0.99906
# epoch: 12, passed number of graphs: 480, train running loss: 0.00388 (passed time: 1h 38m 37s)
#           acc: 0.99975, fpr: 0.00020, fnr: 0.00150, rec: 0.99850, prc: 0.99553, f1: 0.99701, f1_macro: 0.99844
# epoch: 12, passed number of graphs: 576, train running loss: 0.00371 (passed time: 1h 39m 34s)
#           acc: 0.99944, fpr: 0.00049, fnr: 0.00230, rec: 0.99770, prc: 0.98909, f1: 0.99337, f1_macro: 0.99654
# epoch: 12, passed number of graphs: 672, train running loss: 0.00387 (passed time: 1h 40m 33s)
#           acc: 0.99457, fpr: 0.00013, fnr: 0.12735, rec: 0.87265, prc: 0.99664, f1: 0.93054, f1_macro: 0.96385
# epoch: 12, passed number of graphs: 768, train running loss: 0.00393 (passed time: 1h 41m 32s)
#           acc: 0.99985, fpr: 0.00012, fnr: 0.00083, rec: 0.99917, prc: 0.99718, f1: 0.99818, f1_macro: 0.99905
# Validation --- epoch: 12, loss: 0.00268
#           prc: 0.99626, acc: 0.99953, f1_macro: 0.99368, fpr: 0.00008, f1: 0.98760, rec: 0.98175, fnr: 0.01825
# epoch: 13, passed number of graphs: 96, train running loss: 0.00343 (passed time: 1h 43m 4s)
#           acc: 0.99997, fpr: 0.00003, fnr: 0.00016, rec: 0.99984, prc: 0.99935, f1: 0.99959, f1_macro: 0.99979
# epoch: 13, passed number of graphs: 192, train running loss: 0.00354 (passed time: 1h 44m 3s)
#           acc: 0.99992, fpr: 0.00001, fnr: 0.00184, rec: 0.99816, prc: 0.99983, f1: 0.99900, f1_macro: 0.99948
# epoch: 13, passed number of graphs: 288, train running loss: 0.00328 (passed time: 1h 45m 2s)
#           acc: 0.99982, fpr: 0.00016, fnr: 0.00050, rec: 0.99950, prc: 0.99617, f1: 0.99783, f1_macro: 0.99887
# epoch: 13, passed number of graphs: 384, train running loss: 0.00342 (passed time: 1h 46m 0s)
#           acc: 0.99983, fpr: 0.00013, fnr: 0.00098, rec: 0.99902, prc: 0.99705, f1: 0.99803, f1_macro: 0.99897
# epoch: 13, passed number of graphs: 480, train running loss: 0.00381 (passed time: 1h 46m 58s)
#           acc: 0.99973, fpr: 0.00022, fnr: 0.00133, rec: 0.99867, prc: 0.99503, f1: 0.99685, f1_macro: 0.99835
# epoch: 13, passed number of graphs: 576, train running loss: 0.00362 (passed time: 1h 47m 56s)
#           acc: 0.99928, fpr: 0.00070, fnr: 0.00099, rec: 0.99901, prc: 0.98430, f1: 0.99160, f1_macro: 0.99561
# epoch: 13, passed number of graphs: 672, train running loss: 0.00368 (passed time: 1h 48m 55s)
#           acc: 0.99457, fpr: 0.00011, fnr: 0.12784, rec: 0.87216, prc: 0.99720, f1: 0.93050, f1_macro: 0.96384
# epoch: 13, passed number of graphs: 768, train running loss: 0.00378 (passed time: 1h 49m 54s)
#           acc: 0.99982, fpr: 0.00010, fnr: 0.00183, rec: 0.99817, prc: 0.99768, f1: 0.99793, f1_macro: 0.99892
# Validation --- epoch: 13, loss: 0.00328
#           prc: 0.99779, acc: 0.99945, f1_macro: 0.99255, fpr: 0.00005, f1: 0.98538, rec: 0.97646, fnr: 0.02354
# epoch: 14, passed number of graphs: 96, train running loss: 0.00327 (passed time: 1h 51m 27s)
#           acc: 0.99995, fpr: 0.00001, fnr: 0.00114, rec: 0.99886, prc: 0.99984, f1: 0.99935, f1_macro: 0.99966
# epoch: 14, passed number of graphs: 192, train running loss: 0.00462 (passed time: 1h 52m 26s)
#           acc: 0.99992, fpr: 0.00001, fnr: 0.00184, rec: 0.99816, prc: 0.99983, f1: 0.99900, f1_macro: 0.99948
# epoch: 14, passed number of graphs: 288, train running loss: 0.00390 (passed time: 1h 53m 25s)
#           acc: 0.99992, fpr: 0.00004, fnr: 0.00100, rec: 0.99900, prc: 0.99900, f1: 0.99900, f1_macro: 0.99948
# epoch: 14, passed number of graphs: 384, train running loss: 0.00369 (passed time: 1h 54m 24s)
#           acc: 0.99982, fpr: 0.00011, fnr: 0.00164, rec: 0.99836, prc: 0.99754, f1: 0.99795, f1_macro: 0.99893
# epoch: 14, passed number of graphs: 480, train running loss: 0.00401 (passed time: 1h 55m 22s)
#           acc: 0.99969, fpr: 0.00029, fnr: 0.00083, rec: 0.99917, prc: 0.99355, f1: 0.99635, f1_macro: 0.99810
# epoch: 14, passed number of graphs: 576, train running loss: 0.00379 (passed time: 1h 56m 20s)
#           acc: 0.99928, fpr: 0.00074, fnr: 0.00033, rec: 0.99967, prc: 0.98351, f1: 0.99153, f1_macro: 0.99557
# epoch: 14, passed number of graphs: 672, train running loss: 0.00378 (passed time: 1h 57m 19s)
#           acc: 0.99454, fpr: 0.00018, fnr: 0.12669, rec: 0.87331, prc: 0.99516, f1: 0.93026, f1_macro: 0.96371
# epoch: 14, passed number of graphs: 768, train running loss: 0.00395 (passed time: 1h 58m 19s)
#           acc: 0.99984, fpr: 0.00012, fnr: 0.00116, rec: 0.99884, prc: 0.99735, f1: 0.99809, f1_macro: 0.99900
# Validation --- epoch: 14, loss: 0.00260
#           prc: 0.99626, acc: 0.99960, f1_macro: 0.99467, fpr: 0.00008, f1: 0.98953, rec: 0.98526, fnr: 0.01474
# Better model saved at ./saved_models/GIN_13: 0.9895330693166291.pt.
# epoch: 15, passed number of graphs: 96, train running loss: 0.00321 (passed time: 1h 59m 52s)
#           acc: 0.99997, fpr: 0.00003, fnr: 0.00016, rec: 0.99984, prc: 0.99935, f1: 0.99959, f1_macro: 0.99979
# epoch: 15, passed number of graphs: 192, train running loss: 0.00338 (passed time: 2h 0m 51s)
#           acc: 0.99990, fpr: 0.00001, fnr: 0.00217, rec: 0.99783, prc: 0.99966, f1: 0.99874, f1_macro: 0.99935
# epoch: 15, passed number of graphs: 288, train running loss: 0.00321 (passed time: 2h 1m 50s)
#           acc: 0.99981, fpr: 0.00019, fnr: 0.00017, rec: 0.99983, prc: 0.99551, f1: 0.99767, f1_macro: 0.99878
# epoch: 15, passed number of graphs: 384, train running loss: 0.00322 (passed time: 2h 2m 49s)
#           acc: 0.99980, fpr: 0.00011, fnr: 0.00213, rec: 0.99787, prc: 0.99754, f1: 0.99770, f1_macro: 0.99880
# epoch: 15, passed number of graphs: 480, train running loss: 0.00362 (passed time: 2h 3m 48s)
#           acc: 0.99972, fpr: 0.00024, fnr: 0.00116, rec: 0.99884, prc: 0.99454, f1: 0.99668, f1_macro: 0.99827
# epoch: 15, passed number of graphs: 576, train running loss: 0.00354 (passed time: 2h 4m 46s)
#           acc: 0.99930, fpr: 0.00070, fnr: 0.00066, rec: 0.99934, prc: 0.98430, f1: 0.99177, f1_macro: 0.99570
# epoch: 15, passed number of graphs: 672, train running loss: 0.00361 (passed time: 2h 5m 45s)
#           acc: 0.99457, fpr: 0.00014, fnr: 0.12702, rec: 0.87298, prc: 0.99627, f1: 0.93056, f1_macro: 0.96387
# epoch: 15, passed number of graphs: 768, train running loss: 0.00362 (passed time: 2h 6m 45s)
#           acc: 0.99985, fpr: 0.00012, fnr: 0.00083, rec: 0.99917, prc: 0.99718, f1: 0.99818, f1_macro: 0.99905
# Validation --- epoch: 15, loss: 0.00253
#           prc: 0.99621, acc: 0.99958, f1_macro: 0.99439, fpr: 0.00008, f1: 0.98899, rec: 0.98433, fnr: 0.01567
# epoch: 16, passed number of graphs: 96, train running loss: 0.00309 (passed time: 2h 8m 18s)
#           acc: 0.99996, fpr: 0.00002, fnr: 0.00049, rec: 0.99951, prc: 0.99951, f1: 0.99951, f1_macro: 0.99975
# epoch: 16, passed number of graphs: 192, train running loss: 0.00319 (passed time: 2h 9m 18s)
#           acc: 0.99989, fpr: 0.00001, fnr: 0.00251, rec: 0.99749, prc: 0.99983, f1: 0.99866, f1_macro: 0.99930
# epoch: 16, passed number of graphs: 288, train running loss: 0.00294 (passed time: 2h 10m 17s)
#           acc: 0.99982, fpr: 0.00017, fnr: 0.00050, rec: 0.99950, prc: 0.99601, f1: 0.99775, f1_macro: 0.99883
# epoch: 16, passed number of graphs: 384, train running loss: 0.00289 (passed time: 2h 11m 15s)
#           acc: 0.99983, fpr: 0.00009, fnr: 0.00197, rec: 0.99803, prc: 0.99803, f1: 0.99803, f1_macro: 0.99897
# epoch: 16, passed number of graphs: 480, train running loss: 0.00318 (passed time: 2h 12m 14s)
#           acc: 0.99969, fpr: 0.00027, fnr: 0.00116, rec: 0.99884, prc: 0.99388, f1: 0.99635, f1_macro: 0.99810
# epoch: 16, passed number of graphs: 576, train running loss: 0.00309 (passed time: 2h 13m 12s)
#           acc: 0.99925, fpr: 0.00077, fnr: 0.00033, rec: 0.99967, prc: 0.98288, f1: 0.99120, f1_macro: 0.99541
# epoch: 16, passed number of graphs: 672, train running loss: 0.00323 (passed time: 2h 14m 11s)
#           acc: 0.99454, fpr: 0.00016, fnr: 0.12718, rec: 0.87282, prc: 0.99590, f1: 0.93031, f1_macro: 0.96373
# epoch: 16, passed number of graphs: 768, train running loss: 0.00332 (passed time: 2h 15m 10s)
#           acc: 0.99986, fpr: 0.00012, fnr: 0.00050, rec: 0.99950, prc: 0.99718, f1: 0.99834, f1_macro: 0.99913
# Validation --- epoch: 16, loss: 0.00245
#           prc: 0.99668, acc: 0.99962, f1_macro: 0.99484, fpr: 0.00007, f1: 0.98987, rec: 0.98551, fnr: 0.01449
# Better model saved at ./saved_models/GIN_15: 0.9898667954482492.pt.
# epoch: 17, passed number of graphs: 96, train running loss: 0.00328 (passed time: 2h 16m 43s)
#           acc: 0.99992, fpr: 0.00001, fnr: 0.00178, rec: 0.99822, prc: 0.99984, f1: 0.99903, f1_macro: 0.99949
# epoch: 17, passed number of graphs: 192, train running loss: 0.00343 (passed time: 2h 17m 43s)
#           acc: 0.99987, fpr: 0.00001, fnr: 0.00284, rec: 0.99716, prc: 0.99983, f1: 0.99849, f1_macro: 0.99921
# epoch: 17, passed number of graphs: 288, train running loss: 0.00312 (passed time: 2h 18m 42s)
#           acc: 0.99981, fpr: 0.00019, fnr: 0.00017, rec: 0.99983, prc: 0.99551, f1: 0.99767, f1_macro: 0.99878
# epoch: 17, passed number of graphs: 384, train running loss: 0.00301 (passed time: 2h 19m 40s)
#           acc: 0.99982, fpr: 0.00015, fnr: 0.00082, rec: 0.99918, prc: 0.99673, f1: 0.99795, f1_macro: 0.99893
# epoch: 17, passed number of graphs: 480, train running loss: 0.00332 (passed time: 2h 20m 38s)
#           acc: 0.99973, fpr: 0.00017, fnr: 0.00249, rec: 0.99751, prc: 0.99618, f1: 0.99684, f1_macro: 0.99835
# epoch: 17, passed number of graphs: 576, train running loss: 0.00347 (passed time: 2h 21m 36s)
#           acc: 0.99933, fpr: 0.00069, fnr: 0.00033, rec: 0.99967, prc: 0.98463, f1: 0.99209, f1_macro: 0.99587
# epoch: 17, passed number of graphs: 672, train running loss: 0.00367 (passed time: 2h 22m 35s)
#           acc: 0.99457, fpr: 0.00014, fnr: 0.12702, rec: 0.87298, prc: 0.99627, f1: 0.93056, f1_macro: 0.96387
# epoch: 17, passed number of graphs: 768, train running loss: 0.00373 (passed time: 2h 23m 34s)
#           acc: 0.99985, fpr: 0.00012, fnr: 0.00083, rec: 0.99917, prc: 0.99718, f1: 0.99818, f1_macro: 0.99905
# Validation --- epoch: 17, loss: 0.00252
#           prc: 0.99572, acc: 0.99960, f1_macro: 0.99463, fpr: 0.00010, f1: 0.98947, rec: 0.98572, fnr: 0.01428
# epoch: 18, passed number of graphs: 96, train running loss: 0.00290 (passed time: 2h 25m 7s)
#           acc: 0.99996, fpr: 0.00002, fnr: 0.00049, rec: 0.99951, prc: 0.99951, f1: 0.99951, f1_macro: 0.99975
# epoch: 18, passed number of graphs: 192, train running loss: 0.00310 (passed time: 2h 26m 7s)
#           acc: 0.99987, fpr: 0.00001, fnr: 0.00268, rec: 0.99732, prc: 0.99966, f1: 0.99849, f1_macro: 0.99921
# epoch: 18, passed number of graphs: 288, train running loss: 0.00283 (passed time: 2h 27m 6s)
#           acc: 0.99982, fpr: 0.00017, fnr: 0.00033, rec: 0.99967, prc: 0.99601, f1: 0.99783, f1_macro: 0.99887
# epoch: 18, passed number of graphs: 384, train running loss: 0.00286 (passed time: 2h 28m 4s)
#           acc: 0.99987, fpr: 0.00010, fnr: 0.00082, rec: 0.99918, prc: 0.99787, f1: 0.99852, f1_macro: 0.99923
# epoch: 18, passed number of graphs: 480, train running loss: 0.00313 (passed time: 2h 29m 2s)
#           acc: 0.99968, fpr: 0.00018, fnr: 0.00366, rec: 0.99634, prc: 0.99601, f1: 0.99618, f1_macro: 0.99800
# epoch: 18, passed number of graphs: 576, train running loss: 0.00308 (passed time: 2h 30m 1s)
#           acc: 0.99928, fpr: 0.00073, fnr: 0.00066, rec: 0.99934, prc: 0.98382, f1: 0.99152, f1_macro: 0.99557
# epoch: 18, passed number of graphs: 672, train running loss: 0.00313 (passed time: 2h 31m 0s)
#           acc: 0.99454, fpr: 0.00018, fnr: 0.12669, rec: 0.87331, prc: 0.99516, f1: 0.93026, f1_macro: 0.96371
# epoch: 18, passed number of graphs: 768, train running loss: 0.00319 (passed time: 2h 31m 59s)
#           acc: 0.99985, fpr: 0.00012, fnr: 0.00083, rec: 0.99917, prc: 0.99735, f1: 0.99826, f1_macro: 0.99909
# Validation --- epoch: 18, loss: 0.00252
#           prc: 0.99685, acc: 0.99959, f1_macro: 0.99446, fpr: 0.00007, f1: 0.98914, rec: 0.98399, fnr: 0.01601
# epoch: 19, passed number of graphs: 96, train running loss: 0.00257 (passed time: 2h 33m 32s)
#           acc: 0.99997, fpr: 0.00003, fnr: 0.00000, rec: 1.00000, prc: 0.99935, f1: 0.99968, f1_macro: 0.99983
# epoch: 19, passed number of graphs: 192, train running loss: 0.00250 (passed time: 2h 34m 32s)
#           acc: 0.99990, fpr: 0.00001, fnr: 0.00217, rec: 0.99783, prc: 0.99983, f1: 0.99883, f1_macro: 0.99939
# epoch: 19, passed number of graphs: 288, train running loss: 0.00225 (passed time: 2h 35m 31s)
#           acc: 0.99983, fpr: 0.00016, fnr: 0.00050, rec: 0.99950, prc: 0.99634, f1: 0.99792, f1_macro: 0.99891
# epoch: 19, passed number of graphs: 384, train running loss: 0.00219 (passed time: 2h 36m 29s)
#           acc: 0.99979, fpr: 0.00014, fnr: 0.00181, rec: 0.99819, prc: 0.99689, f1: 0.99754, f1_macro: 0.99871
# epoch: 19, passed number of graphs: 480, train running loss: 0.00247 (passed time: 2h 37m 27s)
#           acc: 0.99968, fpr: 0.00027, fnr: 0.00150, rec: 0.99850, prc: 0.99388, f1: 0.99619, f1_macro: 0.99801
# epoch: 19, passed number of graphs: 576, train running loss: 0.00237 (passed time: 2h 38m 25s)
#           acc: 0.99935, fpr: 0.00062, fnr: 0.00131, rec: 0.99869, prc: 0.98621, f1: 0.99241, f1_macro: 0.99603
# epoch: 19, passed number of graphs: 672, train running loss: 0.00242 (passed time: 2h 39m 24s)
#           acc: 0.99459, fpr: 0.00011, fnr: 0.12718, rec: 0.87282, prc: 0.99702, f1: 0.93079, f1_macro: 0.96399
# epoch: 19, passed number of graphs: 768, train running loss: 0.00251 (passed time: 2h 40m 24s)
#           acc: 0.99984, fpr: 0.00012, fnr: 0.00116, rec: 0.99884, prc: 0.99735, f1: 0.99809, f1_macro: 0.99900
# Validation --- epoch: 19, loss: 0.00236
#           prc: 0.99465, acc: 0.99957, f1_macro: 0.99439, fpr: 0.00014, f1: 0.98899, rec: 0.98611, fnr: 0.01389
# epoch: 20, passed number of graphs: 96, train running loss: 0.00232 (passed time: 2h 41m 57s)
#           acc: 0.99996, fpr: 0.00003, fnr: 0.00032, rec: 0.99968, prc: 0.99935, f1: 0.99951, f1_macro: 0.99975
# epoch: 20, passed number of graphs: 192, train running loss: 0.00238 (passed time: 2h 42m 56s)
#           acc: 0.99990, fpr: 0.00001, fnr: 0.00217, rec: 0.99783, prc: 0.99966, f1: 0.99874, f1_macro: 0.99935
# epoch: 20, passed number of graphs: 288, train running loss: 0.00217 (passed time: 2h 43m 55s)
#           acc: 0.99982, fpr: 0.00016, fnr: 0.00067, rec: 0.99933, prc: 0.99634, f1: 0.99783, f1_macro: 0.99887
# epoch: 20, passed number of graphs: 384, train running loss: 0.00213 (passed time: 2h 44m 53s)
#           acc: 0.99980, fpr: 0.00013, fnr: 0.00164, rec: 0.99836, prc: 0.99705, f1: 0.99770, f1_macro: 0.99880
# epoch: 20, passed number of graphs: 480, train running loss: 0.00241 (passed time: 2h 45m 51s)
#           acc: 0.99968, fpr: 0.00027, fnr: 0.00150, rec: 0.99850, prc: 0.99388, f1: 0.99619, f1_macro: 0.99801
# epoch: 20, passed number of graphs: 576, train running loss: 0.00233 (passed time: 2h 46m 49s)
#           acc: 0.99936, fpr: 0.00060, fnr: 0.00148, rec: 0.99852, prc: 0.98653, f1: 0.99249, f1_macro: 0.99608
# epoch: 20, passed number of graphs: 672, train running loss: 0.00238 (passed time: 2h 47m 48s)
#           acc: 0.99460, fpr: 0.00010, fnr: 0.12718, rec: 0.87282, prc: 0.99739, f1: 0.93095, f1_macro: 0.96407
# epoch: 20, passed number of graphs: 768, train running loss: 0.00247 (passed time: 2h 48m 47s)
#           acc: 0.99984, fpr: 0.00012, fnr: 0.00116, rec: 0.99884, prc: 0.99735, f1: 0.99809, f1_macro: 0.99900
# Validation --- epoch: 20, loss: 0.00238
#           prc: 0.99440, acc: 0.99956, f1_macro: 0.99433, fpr: 0.00014, f1: 0.98888, rec: 0.98617, fnr: 0.01383
# epoch: 21, passed number of graphs: 96, train running loss: 0.00226 (passed time: 2h 50m 20s)
#           acc: 0.99996, fpr: 0.00003, fnr: 0.00032, rec: 0.99968, prc: 0.99935, f1: 0.99951, f1_macro: 0.99975
# epoch: 21, passed number of graphs: 192, train running loss: 0.00231 (passed time: 2h 51m 19s)
#           acc: 0.99989, fpr: 0.00002, fnr: 0.00217, rec: 0.99783, prc: 0.99950, f1: 0.99866, f1_macro: 0.99930
# epoch: 21, passed number of graphs: 288, train running loss: 0.00214 (passed time: 2h 52m 17s)
#           acc: 0.99982, fpr: 0.00016, fnr: 0.00067, rec: 0.99933, prc: 0.99617, f1: 0.99775, f1_macro: 0.99883
# epoch: 21, passed number of graphs: 384, train running loss: 0.00211 (passed time: 2h 53m 15s)
#           acc: 0.99981, fpr: 0.00013, fnr: 0.00131, rec: 0.99869, prc: 0.99705, f1: 0.99787, f1_macro: 0.99889
# epoch: 21, passed number of graphs: 480, train running loss: 0.00239 (passed time: 2h 54m 13s)
#           acc: 0.99970, fpr: 0.00026, fnr: 0.00116, rec: 0.99884, prc: 0.99405, f1: 0.99644, f1_macro: 0.99814
# epoch: 21, passed number of graphs: 576, train running loss: 0.00230 (passed time: 2h 55m 11s)
#           acc: 0.99937, fpr: 0.00057, fnr: 0.00181, rec: 0.99819, prc: 0.98716, f1: 0.99265, f1_macro: 0.99616
# epoch: 21, passed number of graphs: 672, train running loss: 0.00236 (passed time: 2h 56m 10s)
#           acc: 0.99459, fpr: 0.00011, fnr: 0.12718, rec: 0.87282, prc: 0.99720, f1: 0.93087, f1_macro: 0.96403
# epoch: 21, passed number of graphs: 768, train running loss: 0.00246 (passed time: 2h 57m 9s)
#           acc: 0.99984, fpr: 0.00012, fnr: 0.00116, rec: 0.99884, prc: 0.99735, f1: 0.99809, f1_macro: 0.99900
# Validation --- epoch: 21, loss: 0.00235
#           prc: 0.99601, acc: 0.99961, f1_macro: 0.99481, fpr: 0.00009, f1: 0.98981, rec: 0.98608, fnr: 0.01392
# epoch: 22, passed number of graphs: 96, train running loss: 0.00223 (passed time: 2h 58m 42s)
#           acc: 0.99995, fpr: 0.00004, fnr: 0.00032, rec: 0.99968, prc: 0.99919, f1: 0.99943, f1_macro: 0.99970
# epoch: 22, passed number of graphs: 192, train running loss: 0.00228 (passed time: 2h 59m 41s)
#           acc: 0.99990, fpr: 0.00002, fnr: 0.00184, rec: 0.99816, prc: 0.99950, f1: 0.99883, f1_macro: 0.99939
# epoch: 22, passed number of graphs: 288, train running loss: 0.00211 (passed time: 3h 0m 40s)
#           acc: 0.99982, fpr: 0.00016, fnr: 0.00083, rec: 0.99917, prc: 0.99634, f1: 0.99775, f1_macro: 0.99883
# epoch: 22, passed number of graphs: 384, train running loss: 0.00209 (passed time: 3h 1m 38s)
#           acc: 0.99979, fpr: 0.00013, fnr: 0.00181, rec: 0.99819, prc: 0.99705, f1: 0.99762, f1_macro: 0.99876
# epoch: 22, passed number of graphs: 480, train running loss: 0.00236 (passed time: 3h 2m 36s)
#           acc: 0.99968, fpr: 0.00026, fnr: 0.00166, rec: 0.99834, prc: 0.99404, f1: 0.99619, f1_macro: 0.99801
# epoch: 22, passed number of graphs: 576, train running loss: 0.00231 (passed time: 3h 3m 34s)
#           acc: 0.99933, fpr: 0.00061, fnr: 0.00197, rec: 0.99803, prc: 0.98636, f1: 0.99216, f1_macro: 0.99591
# epoch: 22, passed number of graphs: 672, train running loss: 0.00237 (passed time: 3h 4m 33s)
#           acc: 0.99459, fpr: 0.00011, fnr: 0.12718, rec: 0.87282, prc: 0.99720, f1: 0.93087, f1_macro: 0.96403
# epoch: 22, passed number of graphs: 768, train running loss: 0.00247 (passed time: 3h 5m 32s)
#           acc: 0.99984, fpr: 0.00012, fnr: 0.00116, rec: 0.99884, prc: 0.99735, f1: 0.99809, f1_macro: 0.99900
# Validation --- epoch: 22, loss: 0.00235
#           prc: 0.99623, acc: 0.99962, f1_macro: 0.99483, fpr: 0.00008, f1: 0.98985, rec: 0.98593, fnr: 0.01407
# epoch: 23, passed number of graphs: 96, train running loss: 0.00222 (passed time: 3h 7m 4s)
#           acc: 0.99995, fpr: 0.00004, fnr: 0.00049, rec: 0.99951, prc: 0.99919, f1: 0.99935, f1_macro: 0.99966
# epoch: 23, passed number of graphs: 192, train running loss: 0.00226 (passed time: 3h 8m 3s)
#           acc: 0.99990, fpr: 0.00002, fnr: 0.00184, rec: 0.99816, prc: 0.99950, f1: 0.99883, f1_macro: 0.99939
# epoch: 23, passed number of graphs: 288, train running loss: 0.00209 (passed time: 3h 9m 2s)
#           acc: 0.99982, fpr: 0.00016, fnr: 0.00083, rec: 0.99917, prc: 0.99634, f1: 0.99775, f1_macro: 0.99883
# epoch: 23, passed number of graphs: 384, train running loss: 0.00208 (passed time: 3h 10m 1s)
#           acc: 0.99979, fpr: 0.00013, fnr: 0.00181, rec: 0.99819, prc: 0.99705, f1: 0.99762, f1_macro: 0.99876
# epoch: 23, passed number of graphs: 480, train running loss: 0.00235 (passed time: 3h 10m 59s)
#           acc: 0.99969, fpr: 0.00026, fnr: 0.00133, rec: 0.99867, prc: 0.99404, f1: 0.99635, f1_macro: 0.99810
# epoch: 23, passed number of graphs: 576, train running loss: 0.00229 (passed time: 3h 11m 57s)
#           acc: 0.99935, fpr: 0.00059, fnr: 0.00197, rec: 0.99803, prc: 0.98684, f1: 0.99240, f1_macro: 0.99603
# epoch: 23, passed number of graphs: 672, train running loss: 0.00234 (passed time: 3h 12m 55s)
#           acc: 0.99461, fpr: 0.00009, fnr: 0.12718, rec: 0.87282, prc: 0.99776, f1: 0.93112, f1_macro: 0.96416
# epoch: 23, passed number of graphs: 768, train running loss: 0.00244 (passed time: 3h 13m 54s)
#           acc: 0.99984, fpr: 0.00012, fnr: 0.00116, rec: 0.99884, prc: 0.99735, f1: 0.99809, f1_macro: 0.99900
# Validation --- epoch: 23, loss: 0.00234
#           prc: 0.99633, acc: 0.99962, f1_macro: 0.99488, fpr: 0.00008, f1: 0.98995, rec: 0.98602, fnr: 0.01398
# Better model saved at ./saved_models/GIN_22: 0.9899543134934761.pt.
# epoch: 24, passed number of graphs: 96, train running loss: 0.00218 (passed time: 3h 15m 26s)
#           acc: 0.99996, fpr: 0.00004, fnr: 0.00000, rec: 1.00000, prc: 0.99903, f1: 0.99951, f1_macro: 0.99975
# epoch: 24, passed number of graphs: 192, train running loss: 0.00223 (passed time: 3h 16m 25s)
#           acc: 0.99991, fpr: 0.00002, fnr: 0.00167, rec: 0.99833, prc: 0.99950, f1: 0.99891, f1_macro: 0.99943
# epoch: 24, passed number of graphs: 288, train running loss: 0.00205 (passed time: 3h 17m 24s)
#           acc: 0.99982, fpr: 0.00016, fnr: 0.00083, rec: 0.99917, prc: 0.99634, f1: 0.99775, f1_macro: 0.99883
# epoch: 24, passed number of graphs: 384, train running loss: 0.00205 (passed time: 3h 18m 22s)
#           acc: 0.99979, fpr: 0.00014, fnr: 0.00181, rec: 0.99819, prc: 0.99689, f1: 0.99754, f1_macro: 0.99871
# epoch: 24, passed number of graphs: 480, train running loss: 0.00233 (passed time: 3h 19m 20s)
#           acc: 0.99969, fpr: 0.00026, fnr: 0.00133, rec: 0.99867, prc: 0.99404, f1: 0.99635, f1_macro: 0.99810
# epoch: 24, passed number of graphs: 576, train running loss: 0.00228 (passed time: 3h 20m 18s)
#           acc: 0.99935, fpr: 0.00057, fnr: 0.00246, rec: 0.99754, prc: 0.98715, f1: 0.99232, f1_macro: 0.99599
# epoch: 24, passed number of graphs: 672, train running loss: 0.00235 (passed time: 3h 21m 17s)
#           acc: 0.99461, fpr: 0.00009, fnr: 0.12718, rec: 0.87282, prc: 0.99757, f1: 0.93103, f1_macro: 0.96411
# epoch: 24, passed number of graphs: 768, train running loss: 0.00245 (passed time: 3h 22m 16s)
#           acc: 0.99984, fpr: 0.00012, fnr: 0.00116, rec: 0.99884, prc: 0.99735, f1: 0.99809, f1_macro: 0.99900
# Validation --- epoch: 24, loss: 0.00234
#           prc: 0.99678, acc: 0.99963, f1_macro: 0.99500, fpr: 0.00007, f1: 0.99019, rec: 0.98600, fnr: 0.01400
# Better model saved at ./saved_models/GIN_23: 0.9901872184030162.pt.
# epoch: 25, passed number of graphs: 96, train running loss: 0.00217 (passed time: 3h 23m 49s)
#           acc: 0.99996, fpr: 0.00004, fnr: 0.00000, rec: 1.00000, prc: 0.99903, f1: 0.99951, f1_macro: 0.99975
# epoch: 25, passed number of graphs: 192, train running loss: 0.00222 (passed time: 3h 24m 48s)
#           acc: 0.99990, fpr: 0.00002, fnr: 0.00184, rec: 0.99816, prc: 0.99950, f1: 0.99883, f1_macro: 0.99939
# epoch: 25, passed number of graphs: 288, train running loss: 0.00205 (passed time: 3h 25m 47s)
#           acc: 0.99982, fpr: 0.00016, fnr: 0.00083, rec: 0.99917, prc: 0.99634, f1: 0.99775, f1_macro: 0.99883
# epoch: 25, passed number of graphs: 384, train running loss: 0.00205 (passed time: 3h 26m 46s)
#           acc: 0.99981, fpr: 0.00013, fnr: 0.00164, rec: 0.99836, prc: 0.99721, f1: 0.99779, f1_macro: 0.99884
# epoch: 25, passed number of graphs: 480, train running loss: 0.00232 (passed time: 3h 27m 44s)
#           acc: 0.99970, fpr: 0.00026, fnr: 0.00133, rec: 0.99867, prc: 0.99421, f1: 0.99643, f1_macro: 0.99814
# epoch: 25, passed number of graphs: 576, train running loss: 0.00232 (passed time: 3h 28m 42s)
#           acc: 0.99935, fpr: 0.00058, fnr: 0.00230, rec: 0.99770, prc: 0.98700, f1: 0.99232, f1_macro: 0.99599
# epoch: 25, passed number of graphs: 672, train running loss: 0.00235 (passed time: 3h 29m 40s)
#           acc: 0.99461, fpr: 0.00009, fnr: 0.12718, rec: 0.87282, prc: 0.99757, f1: 0.93103, f1_macro: 0.96411
# epoch: 25, passed number of graphs: 768, train running loss: 0.00245 (passed time: 3h 30m 39s)
#           acc: 0.99984, fpr: 0.00012, fnr: 0.00116, rec: 0.99884, prc: 0.99735, f1: 0.99809, f1_macro: 0.99900
# Validation --- epoch: 25, loss: 0.00235
#           prc: 0.99661, acc: 0.99962, f1_macro: 0.99489, fpr: 0.00007, f1: 0.98997, rec: 0.98576, fnr: 0.01424
# epoch: 26, passed number of graphs: 96, train running loss: 0.00202 (passed time: 3h 32m 11s)
#           acc: 0.99996, fpr: 0.00004, fnr: 0.00000, rec: 1.00000, prc: 0.99903, f1: 0.99951, f1_macro: 0.99975
# epoch: 26, passed number of graphs: 192, train running loss: 0.00202 (passed time: 3h 33m 10s)
#           acc: 0.99989, fpr: 0.00001, fnr: 0.00234, rec: 0.99766, prc: 0.99966, f1: 0.99866, f1_macro: 0.99930
# epoch: 26, passed number of graphs: 288, train running loss: 0.00181 (passed time: 3h 34m 9s)
#           acc: 0.99982, fpr: 0.00016, fnr: 0.00050, rec: 0.99950, prc: 0.99617, f1: 0.99783, f1_macro: 0.99887
# epoch: 26, passed number of graphs: 384, train running loss: 0.00181 (passed time: 3h 35m 7s)
#           acc: 0.99983, fpr: 0.00013, fnr: 0.00098, rec: 0.99902, prc: 0.99705, f1: 0.99803, f1_macro: 0.99897
# epoch: 26, passed number of graphs: 480, train running loss: 0.00210 (passed time: 3h 36m 5s)
#           acc: 0.99968, fpr: 0.00026, fnr: 0.00166, rec: 0.99834, prc: 0.99404, f1: 0.99619, f1_macro: 0.99801
# epoch: 26, passed number of graphs: 576, train running loss: 0.00198 (passed time: 3h 37m 2s)
#           acc: 0.99935, fpr: 0.00062, fnr: 0.00148, rec: 0.99852, prc: 0.98621, f1: 0.99233, f1_macro: 0.99599
# epoch: 26, passed number of graphs: 672, train running loss: 0.00202 (passed time: 3h 38m 1s)
#           acc: 0.99461, fpr: 0.00007, fnr: 0.12751, rec: 0.87249, prc: 0.99813, f1: 0.93109, f1_macro: 0.96414
# epoch: 26, passed number of graphs: 768, train running loss: 0.00213 (passed time: 3h 39m 0s)
#           acc: 0.99984, fpr: 0.00012, fnr: 0.00116, rec: 0.99884, prc: 0.99735, f1: 0.99809, f1_macro: 0.99900
# Validation --- epoch: 26, loss: 0.00235
#           prc: 0.99612, acc: 0.99963, f1_macro: 0.99509, fpr: 0.00009, f1: 0.99036, rec: 0.98688, fnr: 0.01312
# Better model saved at ./saved_models/GIN_25: 0.9903624915815202.pt.
# epoch: 27, passed number of graphs: 96, train running loss: 0.00194 (passed time: 3h 40m 32s)
#           acc: 0.99995, fpr: 0.00004, fnr: 0.00032, rec: 0.99968, prc: 0.99903, f1: 0.99935, f1_macro: 0.99966
# epoch: 27, passed number of graphs: 192, train running loss: 0.00196 (passed time: 3h 41m 31s)
#           acc: 0.99989, fpr: 0.00001, fnr: 0.00234, rec: 0.99766, prc: 0.99966, f1: 0.99866, f1_macro: 0.99930
# epoch: 27, passed number of graphs: 288, train running loss: 0.00176 (passed time: 3h 42m 30s)
#           acc: 0.99983, fpr: 0.00016, fnr: 0.00050, rec: 0.99950, prc: 0.99634, f1: 0.99792, f1_macro: 0.99891
# epoch: 27, passed number of graphs: 384, train running loss: 0.00176 (passed time: 3h 43m 28s)
#           acc: 0.99983, fpr: 0.00013, fnr: 0.00098, rec: 0.99902, prc: 0.99705, f1: 0.99803, f1_macro: 0.99897
# epoch: 27, passed number of graphs: 480, train running loss: 0.00206 (passed time: 3h 44m 26s)
#           acc: 0.99968, fpr: 0.00026, fnr: 0.00166, rec: 0.99834, prc: 0.99404, f1: 0.99619, f1_macro: 0.99801
# epoch: 27, passed number of graphs: 576, train running loss: 0.00195 (passed time: 3h 45m 24s)
#           acc: 0.99936, fpr: 0.00060, fnr: 0.00148, rec: 0.99852, prc: 0.98653, f1: 0.99249, f1_macro: 0.99608
# epoch: 27, passed number of graphs: 672, train running loss: 0.00199 (passed time: 3h 46m 23s)
#           acc: 0.99461, fpr: 0.00007, fnr: 0.12751, rec: 0.87249, prc: 0.99813, f1: 0.93109, f1_macro: 0.96414
# epoch: 27, passed number of graphs: 768, train running loss: 0.00210 (passed time: 3h 47m 22s)
#           acc: 0.99985, fpr: 0.00010, fnr: 0.00116, rec: 0.99884, prc: 0.99768, f1: 0.99826, f1_macro: 0.99909
# Validation --- epoch: 27, loss: 0.00235
#           prc: 0.99623, acc: 0.99964, f1_macro: 0.99512, fpr: 0.00008, f1: 0.99042, rec: 0.98687, fnr: 0.01313
# Better model saved at ./saved_models/GIN_26: 0.990419498436975.pt.
# epoch: 28, passed number of graphs: 96, train running loss: 0.00191 (passed time: 3h 48m 54s)
#           acc: 0.99995, fpr: 0.00004, fnr: 0.00032, rec: 0.99968, prc: 0.99903, f1: 0.99935, f1_macro: 0.99966
# epoch: 28, passed number of graphs: 192, train running loss: 0.00190 (passed time: 3h 49m 53s)
#           acc: 0.99990, fpr: 0.00001, fnr: 0.00234, rec: 0.99766, prc: 0.99983, f1: 0.99874, f1_macro: 0.99935
# epoch: 28, passed number of graphs: 288, train running loss: 0.00171 (passed time: 3h 50m 52s)
#           acc: 0.99982, fpr: 0.00016, fnr: 0.00083, rec: 0.99917, prc: 0.99634, f1: 0.99775, f1_macro: 0.99883
# epoch: 28, passed number of graphs: 384, train running loss: 0.00171 (passed time: 3h 51m 50s)
#           acc: 0.99983, fpr: 0.00014, fnr: 0.00082, rec: 0.99918, prc: 0.99689, f1: 0.99803, f1_macro: 0.99897
# epoch: 28, passed number of graphs: 480, train running loss: 0.00201 (passed time: 3h 52m 48s)
#           acc: 0.99968, fpr: 0.00026, fnr: 0.00166, rec: 0.99834, prc: 0.99404, f1: 0.99619, f1_macro: 0.99801
# epoch: 28, passed number of graphs: 576, train running loss: 0.00188 (passed time: 3h 53m 45s)
#           acc: 0.99935, fpr: 0.00061, fnr: 0.00148, rec: 0.99852, prc: 0.98637, f1: 0.99241, f1_macro: 0.99603

# %%
# !zip -r /content/TransformerConv_p2p_6k_feat_norm.zip /content/saved_models

# %%
from google.colab import files
files.download("/content/TransformerConv_p2p_6k_feat_norm.zip")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-fee5c06b74b0> in <module>
#       1 from google.colab import files
# ----> 2 files.download("/content/TransformerConv_p2p_6k_feat_norm.zip")
#
# /usr/local/lib/python3.7/dist-packages/google/colab/files.py in download(filename)
#     207   if not _os.path.exists(filename):
#     208     msg = 'Cannot find file: {}'.format(filename)
# --> 209     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     210
#     211   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: /content/TransformerConv_p2p_6k_feat_norm.zip

# %%
from google.colab import runtime
runtime.unassign()
