# %% [markdown]
# <a href="https://colab.research.google.com/github/Zoro1092000/xxxx/blob/main/Author_p2p_6k_feat_norm_0_53_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/harvardnlp/botnet-detection.git

# %%
import os
import os.path as osp
import torch
import sys

os.environ['TORCH'] = torch.__version__

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install torch-geometric==1.4.3
# !pip install torch-cluster -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install deepdish==0.3.5

# %%
# !cd botnet_detection
# !python botnet_detection/setup.py install

# %%
# !bash /content/botnet_detection/run_botnet.sh
# Out:
# All Logs will be saved to ./saved_models/p2p_model_lay12_rh1_rw_ep50.log
# python /content/botnet_detection/train_botnet.py --devid 0 --data_dir /content/drive/Shareddrives/botnetdata/p2p_6k_feat_norm --data_name p2p --batch_size 2 --enc_sizes 32 32 32 32 32 32 32 32 32 32 32 32 --act relu --residual_hop 1 --deg_norm rw --final proj --epochs 50 --lr 0.005 --early_stop 1 --save_dir ./saved_models --save_name p2p_model_lay12_rh1_rw_ep50.pt
# ------------------------------
# ...

# %%
# !zip -r /content/GCNConv_p2p_6k_feat_norm_0_53_12.zip /content/saved_models

# %%
from google.colab import files
files.download("/content/GCNConv_p2p_normalization.zip"

# %%
from google.colab import runtime
runtime.unassign()
