# %% [markdown]
# <a href="https://colab.research.google.com/github/Zoro1092000/xxxx/blob/main/GATv2Conv_p2p_normalization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # I. Pip & Import.

# %%
import os
import os.path as osp
import torch
import sys

os.environ['TORCH'] = torch.__version__

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install torch-geometric
# !pip install torch-cluster -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install deepdish==0.3.5
# !pip install torch-optimizer

import torch.nn as nn
from torch.nn import Parameter
from torch_geometric.utils import scatter
from torch_geometric.nn.inits import glorot, zeros
from torch_scatter import scatter_add
from torch.utils.data import DataLoader, Dataset
import torch_optimizer as optimization


from itertools import chain
import pickle
import h5py
import deepdish as dd
import numpy as np
from tqdm import tqdm
import inspect
import time
import math
import random
# Out:
#      |████████████████████████████████| 7.9 MB 4.3 MB/s
#      |████████████████████████████████| 3.5 MB 4.3 MB/s
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch-geometric
#   Downloading torch_geometric-2.1.0.post1.tar.gz (467 kB)
#      |████████████████████████████████| 467 kB 4.0 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (4.64.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.7.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.23.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (3.0.9)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.0.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->torch-geometric) (2.0.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (2022.9.24)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric) (1.2.0)
# Building wheels for collected packages: torch-geometric
#   Building wheel for torch-geometric (setup.py) ... done
#   Created wheel for torch-geometric: filename=torch_geometric-2.1.0.post1-py3-none-any.whl size=689859 sha256=301d6b1724293daea7bca07e6d5021685762df0860870ca6b9eaf80cee506be9
#   Stored in directory: /root/.cache/pip/wheels/d1/cb/43/f7f2e472de4d7cff31bceddadc36d634e1e545fbc17961c282
# Successfully built torch-geometric
# Installing collected packages: torch-geometric
# Successfully installed torch-geometric-2.1.0.post1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://data.pyg.org/whl/torch-1.12.1+cu113.html
# Collecting torch-cluster
#   Downloading https://data.pyg.org/whl/torch-1.12.0%2Bcu113/torch_cluster-1.6.0-cp37-cp37m-linux_x86_64.whl (2.4 MB)
#      |████████████████████████████████| 2.4 MB 1.7 MB/s
# Installing collected packages: torch-cluster
# Successfully installed torch-cluster-1.6.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting deepdish==0.3.5
#   Downloading deepdish-0.3.5-py2.py3-none-any.whl (37 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.7.3)
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (3.7.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.21.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (21.3)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (2.8.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tables->deepdish==0.3.5) (3.0.9)
# Installing collected packages: deepdish
# Successfully installed deepdish-0.3.5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch-optimizer
#   Downloading torch_optimizer-0.3.0-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 417 kB/s
# Collecting pytorch-ranger>=0.1.1
#   Downloading pytorch_ranger-0.1.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: torch>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from torch-optimizer) (1.12.1+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.5.0->torch-optimizer) (4.1.1)
# Installing collected packages: pytorch-ranger, torch-optimizer
# Successfully installed pytorch-ranger-0.1.1 torch-optimizer-0.3.0

# %%
def time_since(start):
    now = time.time()
    s = now - start
    m = math.floor(s / 60)
    s -= m * 60
    h = math.floor(m / 60)
    m -= h * 60
    if h == 0:
        if m == 0:
            return '%ds' % s
        else:
            return '%dm %ds' % (m, s)
    else:
        return '%dh %dm %ds' % (h, m, s)

# %% [markdown]
# # II. Data

# %%
# Data utils
def h5group_to_dict(h5group):
    group_dict = {k: v[()] for k, v in chain(h5group.items(), h5group.attrs.items())}
    return group_dict

def sub_dict(full_dict, *keys, to_tensor):
    return {k: torch.tensor(full_dict[k]) if to_tensor else full_dict[k] for k in keys if k in full_dict}

def build_graph_from_dict_pyg(graph_dict, to_tensor=True):
    from torch_geometric.data import Data

    g = Data(**sub_dict(graph_dict, 'edge_index', 'x', 'y', 'edge_attr', 'edge_y', to_tensor=to_tensor))
    return g

# Data loader
class GraphDataLoader(DataLoader):
    def __init__(self, dataset, batch_size=128, shuffle=False, num_workers=0):

        def collate_graph(graph_obj_list):
            from torch_geometric.data import Batch
            batch = Batch.from_data_list(graph_obj_list)
            return batch

        super().__init__(
            dataset,
            batch_size=batch_size,
            shuffle=shuffle,
            collate_fn=collate_graph,
            num_workers=num_workers)

# BotnetDataset
class BotnetDataset(Dataset):

    def __init__(self, name='chord', root='data/botnet', split='train', graph_format='pyg', split_idx=None, add_nfeat_ones=True,
                 in_memory=True):
        super().__init__()
        assert name in ['chord', 'debru', 'kadem', 'leet', 'c2', 'p2p']
        assert split in ['train', 'val', 'test']

        if isinstance(root, str):
            root = osp.expanduser(osp.normpath(root))

        self.name = name
        self.root = root
        self.split = split
        self.split_idx = split_idx
        self.add_nfeat_ones = add_nfeat_ones

        self._graph_format = graph_format
        if split == 'train':
            self.path = self.processed_paths[0]
            self.num_graphs = 768
        elif split == 'val':
            self.path = self.processed_paths[1]
            self.num_graphs = 96
        elif split == 'test':
            self.path = self.processed_paths[2]
            self.num_graphs = 96

        if in_memory:
            self.data = dd.io.load(self.path)  # dictionary
            self.data_type = 'dict'
        else:
            # self.data = h5py.File(self.path, 'r')
            self.data = None    # defer opening file in each process to make multiprocessing work
            self.data_type = 'file'
            
    @property
    def processed_dir(self):
        return osp.join(self.root, 'processed')

    @property
    def processed_file_names(self):
        return [self.name + '_' + s + '.hdf5' for s in ('train', 'val', 'test')]

    @property
    def processed_paths(self):
        return [osp.join(self.processed_dir, f) for f in self.processed_file_names]

    def __len__(self):
        return self.num_graphs

    def __getitem__(self, index):
        if self.data_type == 'dict':
            graph_dict = self.data[str(index)]
        elif self.data_type == 'file':
            if self.data is None:
                # only open once in each process
                self.data = h5py.File(self.path, 'r')
            graph_dict = h5group_to_dict(self.data[str(index)])
        else:
            raise ValueError

        # graph_format == 'pyg':
        return build_graph_from_dict_pyg(graph_dict)


    def __iter__(self):
        for i in range(self.num_graphs):
            yield self[i]

    def __repr__(self):
        return f'{self.__class__.__name__}(topology: {self.name} | split: {self.split} | ' \
               f'#graphs: {len(self)} | graph format: {self.graph_format})'

# %% [markdown]
# # III. Measure Performancce

# %% [markdown]
# ## 3.1. Metrics

# %%
def f1(target, pred, label):
    # F1 = 2 * (precision * recall) / (precision + recall)
    tp = np.sum((target==label) & (pred==label))
    fp = np.sum((target!=label) & (pred==label))
    fn = np.sum((pred!=label) & (target==label))
    
    if tp+fp==0 or tp+fn==0:
      return np.nan

    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    
    if precision+recall==0:
      return np.nan
      
    f1 = 2 * (precision * recall) / (precision + recall)
    return f1

def f1_macro(pred, target):
    return np.mean([f1(target, pred, label) for label in range(0, 2)])


def accuracy(pred, target):
    return (pred == target).sum().item() / len(target)


def true_positive(pred, target):
    return (target[pred == 1] == 1).sum().item()


def false_positive(pred, target):
    return (target[pred == 1] == 0).sum().item()


def true_negative(pred, target):
    return (target[pred == 0] == 0).sum().item()


def false_negative(pred, target):
    return (target[pred == 0] == 1).sum().item()


def recall(pred, target):
    try:
        return true_positive(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1


def precision(pred, target):
    try:
        prec = true_positive(pred, target) / (pred == 1).sum().item()
        return prec
    except:  # divide by zero
        return -1


def f1_score(pred, target):
    prec = precision(pred, target)
    rec = recall(pred, target)
    try:
        return 2 * (prec * rec) / (prec + rec)
    except:
        return 0


def false_positive_rate(pred, target):
    try:
        return false_positive(pred, target) / (target == 0).sum().item()
    except:  # divide by zero
        return -1


def false_negative_rate(pred, target):
    try:
        return false_negative(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1

# %% [markdown]
# ## 3.2. Evaluation

# %%
def eval_metrics(target, pred_prob, threshold=0.5):
    if isinstance(target, torch.Tensor):
        target = target.cpu().numpy()
    if isinstance(pred_prob, torch.Tensor):
        pred_prob = pred_prob.cpu().numpy()

    pred = (pred_prob >= threshold).astype(int)

    acc = accuracy(pred, target)
    fpr = false_positive_rate(pred, target)
    fnr = false_negative_rate(pred, target)
    rec = recall(pred, target)
    prc = precision(pred, target)
    f1 = f1_score(pred, target)
    f1macro = f1_macro(pred, target)
    result_dict = {'acc': acc, 'fpr': fpr, 'fnr': fnr, 'rec': rec, 'prc': prc, 'f1': f1, 'f1_macro': f1macro}

    return result_dict


def dict_value_add(dict1, dict2):
    result = {key: dict1.get(key, 0) + dict2.get(key, 0)
              for key in set(dict1) | set(dict2)}
    return result


def dict_value_div(dict, n):
    result = {key: value / n for key, value in dict.items()}
    return result


def eval_predictor(dataset, predictor):
    result_dict_avg = {}
    loss_avg = 0

    for data in dataset:
        # prediction
        try:
            pred_prob, loss = predictor(data)
            loss_avg += loss
        except ValueError:  # if "too many values to unpack"
            pred_prob = predictor(data)

        # get the ground truth target
        # graph_format == 'pyg':
        target = data.y

        # compute the evaluation metrics
        result_dict = eval_metrics(target, pred_prob)

        result_dict_avg = dict_value_add(result_dict_avg, result_dict)

    # average the metrics across all graphs in the dataset as final results
    result_dict_avg = dict_value_div(result_dict_avg, len(dataset))
    loss_avg = loss_avg / len(dataset)

    return result_dict_avg, loss_avg


# =================================================================================================================
# some examples of the 'predictor' model wrapper to be fed into the above evaluation function (for PyG Data format)
# =================================================================================================================
class PygRandomPredictor:
    def __init__(self):
        # torch.manual_seed(0)
        pass

    def __call__(self, data):
        pred_prob = torch.rand(len(data.y))
        return pred_prob


class PygModelPredictor:
    def __init__(self, model, loss_fcn=torch.nn.CrossEntropyLoss()):
        self.model = model
        self.loss_fcn = loss_fcn
        self.device = next(model.parameters()).device

    def __call__(self, data):
        self.model.eval()
        data = data.to(self.device)
        with torch.no_grad():
            # custom the below line to adjust to your model's input format for forward pass
            out = self.model(data.x, data.edge_index)
            loss = self.loss_fcn(out, data.y.long())
            pred_prob = torch.softmax(out, dim=1)[:, 1]
        return pred_prob, loss.float()

# %% [markdown]
# # IV. Model

# %% [markdown]
# ## 5.1. Activation

# %%
def activation(act, negative_slope=0.2):
    activations = nn.ModuleDict([
        ['lrelu', nn.LeakyReLU(negative_slope)],
        ['relu', nn.ReLU()],
        ['elu', nn.ELU()],
        ['none', nn.Identity()],
    ])
    return activations[act]

# %% [markdown]
# ## 5.2. GIN model

# %%
from torch.nn.modules.activation import LeakyReLU
import torch.nn as nn

class GINModel(nn.Module):
    def __init__(self, dim_input_feature, dim_hidden_feature, num_layers, num_classes, non_linear='relu', dropout=0.2):
        super().__init__()

        self.dim_input_feature = dim_input_feature
        self.dim_hidden_feature = dim_hidden_feature

        self.num_layers = num_layers
        self.num_classes = num_classes
        
        from torch.nn import Linear, Sequential, BatchNorm1d, ReLU, Dropout
        from torch_geometric.nn import GATv2Conv, GINConv, TransformerConv
        
        self.gin_net = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.gin_net.append(GATv2Conv(self.dim_input_feature, self.dim_hidden_feature, heads=1, concat=False))
          else:
            self.gin_net.append(GATv2Conv(self.dim_hidden_feature, self.dim_hidden_feature, heads=1, concat=False))


        self.dropout = nn.Dropout(dropout)

        self.residuals = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.residuals.append(nn.Linear(self.dim_input_feature, self.dim_hidden_feature, bias=True))
          else:
            self.residuals.append(nn.Identity())

        self.num_residuals = len(self.residuals)

        self.non_linear = activation(non_linear)

        # self.final_type == 'proj':
        self.final = nn.Linear(self.dim_hidden_feature, num_classes)

    def reset_parameters(self):
        for net in self.gin_net:
            net.reset_parameters()
        # self.residual_hop = 1
        for net in self.residuals:
            net.reset_parameters()
        # self.final_type != 'none':
        self.final.reset_parameters()

    def forward(self, x, edge_index):
        xr = None
        add_xr_at = -1

        for n, net in enumerate(self.gin_net):
            # pass to a GIN layer with non-linear activation
            xo = net(x, edge_index)
            xo = self.dropout(xo)
            # deal with residual connections
            # self.residual_hop = 1
            if n < self.num_residuals:
                xr = self.residuals[n](x)
                xo = self.non_linear(xo + xr)

            x = xo
        # size of x: (B * N, dim_hidden_feature) -> (B * N, num_classes)
        x = self.final(x)

        return x

# %% [markdown]
# # V. Load data

# %%
data_dir = '/content/drive/Shareddrives/botnetdata/p2p_normalization'
data_name = 'p2p' # 'chord', 'debru', 'kadem', 'leet', 'c2', 'p2p'
shuffle = False

# ========== load the dataset
print('loading dataset...')

train_ds = BotnetDataset(name=data_name, root=data_dir, split='train',
                         in_memory=True, graph_format='pyg')
val_ds = BotnetDataset(name=data_name, root=data_dir, split='val',
                       in_memory=False, graph_format='pyg')
test_ds = BotnetDataset(name=data_name, root=data_dir, split='test',
                        in_memory=False, graph_format='pyg')
# Out:
# loading dataset...

# %%
batch_size = 1
train_loader = GraphDataLoader(train_ds, batch_size=batch_size, shuffle=bool(shuffle), num_workers=0)

# %% [markdown]
# # VI. Train

# %%
# ============== some default parameters =============
devid = 0
seed = 0
logmode = 'w'
log_interval = 96

dim_input_feature = 1
dim_hidden_feature = 32
act = 'relu' # 'none', 'lrelu', 'relu', 'elu'

num_layers = 12
num_classes = 2 

dropout = 0.0
bias = True

lr = 0.005 # learning rate
weight_decay = 5e-4
epochs = 50
save_dir = './saved_models'
save_name = "GIN_model.pt"
# ====================================================

def train(model, train_loader, val_dataset, test_dataset, optimizer, scheduler=None):
    device = next(model.parameters()).device
    predictor = PygModelPredictor(model)

    best_epoch = 0
    max_f1_score = 0
    start = time.time()
    for ep in range(epochs):
        loss_avg_train = 0
        num_train_graph = 0
        model.train()
        for n, batch in enumerate(train_loader):
            batch.to(device)

            optimizer.zero_grad()

            x = model(batch.x, batch.edge_index)
            loss = criterion(x, batch.y.long())

            loss_avg_train += float(loss)
            num_train_graph += batch.num_graphs

            loss.backward()
            optimizer.step()

            if num_train_graph % log_interval == 0 or n == len(train_loader) - 1:
                with torch.no_grad():
                    # pred = x.argmax(dim=1)
                    pred_prob = torch.softmax(x, dim=1)[:, 1]
                    y = batch.y.long()
                    result_dict = eval_metrics(y, pred_prob)
                print(f'epoch: {ep + 1}, passed number of graphs: {num_train_graph}, '
                        f'train running loss: {loss_avg_train / num_train_graph:.5f} (passed time: {time_since(start)})')
                print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict.items()]))

        result_dict_avg, loss_avg = eval_predictor(val_dataset, predictor)
        print(f'Validation --- epoch: {ep + 1}, loss: {loss_avg:.5f}')
        print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))

        if scheduler is not None:
            scheduler.step(loss_avg)

        if result_dict_avg['f1'] > max_f1_score:
            save_name = f"GIN_{ep}: {result_dict_avg['f1']}.pt"
            torch.save(model, os.path.join(save_dir, save_name))
            print(f'Better model saved at {os.path.join(save_dir, save_name)}.')
            best_epoch = ep
            max_f1_score = result_dict_avg['f1']

    best_model = torch.load(os.path.join(save_dir, save_name))
    print('*' * 12 + f' best model obtained after epoch {best_epoch + 1}, '
                       f'saved at {os.path.join(save_dir, save_name)} ' + '*' * 12)
    
    predictor = PygModelPredictor(best_model)

    result_dict_avg, loss_avg = eval_predictor(test_dataset, predictor)
    print(f'Testing --- loss: {loss_avg:.5f}')
    print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))


if __name__ == '__main__':
    os.makedirs(save_dir, exist_ok=True)

    # ========== random seeds and device
    random.seed(seed)
    torch.manual_seed(seed)

    device = torch.device(f'cuda:{devid}') if devid > -1 else torch.device('cpu')

    # ========== logging setup
    log_name = os.path.splitext(save_name)[0]
    # logger = logging_config(__name__, folder=save_dir, name=log_name, filemode=logmode)
    # logger = logging_config(os.path.basename(__file__), folder=save_dir, name=log_name, filemode=logmode)

    print('python ' + ' '.join(sys.argv))
    print('-' * 30)
    #logger.info(args)
    print('-' * 30)
    print(time.ctime())
    print('-' * 30)

    # ========== define the model, optimizer, and loss

    model = GINModel(dim_input_feature,
                     dim_hidden_feature,
                     num_layers,
                     num_classes,
                     non_linear=act,
                     dropout=dropout)

    print('model ' + '-' * 10)
    print(repr(model))
    model.to(device)

    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.25, patience=1)

    # ========== train the model
    print(f"Batch size: {batch_size}")
    train(model, train_loader, val_ds, test_ds, optimizer, scheduler)
# Out:
# python /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-e485dbaa-acda-4196-a428-9ce33a025e35.json
# ------------------------------
# ------------------------------
# Fri Nov  4 01:23:44 2022
# ------------------------------
# model ----------
# GINModel(
#   (gin_net): ModuleList(
#     (0): GATv2Conv(1, 32, heads=1)
#     (1): GATv2Conv(32, 32, heads=1)
#     (2): GATv2Conv(32, 32, heads=1)
#     (3): GATv2Conv(32, 32, heads=1)
#     (4): GATv2Conv(32, 32, heads=1)
#     (5): GATv2Conv(32, 32, heads=1)
#     (6): GATv2Conv(32, 32, heads=1)
#     (7): GATv2Conv(32, 32, heads=1)
#     (8): GATv2Conv(32, 32, heads=1)
#     (9): GATv2Conv(32, 32, heads=1)
#     (10): GATv2Conv(32, 32, heads=1)
#     (11): GATv2Conv(32, 32, heads=1)
#   )
#   (dropout): Dropout(p=0.0, inplace=False)
#   (residuals): ModuleList(
#     (0): Linear(in_features=1, out_features=32, bias=True)
#     (1): Identity()
#     (2): Identity()
#     (3): Identity()
#     (4): Identity()
#     (5): Identity()
#     (6): Identity()
#     (7): Identity()
#     (8): Identity()
#     (9): Identity()
#     (10): Identity()
#     (11): Identity()
#   )
#   (non_linear): ReLU()
#   (final): Linear(in_features=32, out_features=2, bias=True)
# )
# Batch size: 1
# epoch: 1, passed number of graphs: 96, train running loss: 0.25658 (passed time: 50s)
#           acc: 0.97869, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 192, train running loss: 0.18001 (passed time: 1m 39s)
#           acc: 0.97884, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 288, train running loss: 0.15443 (passed time: 2m 27s)
#           acc: 0.97924, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 384, train running loss: 0.14138 (passed time: 3m 16s)
#           acc: 0.97787, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 480, train running loss: 0.12745 (passed time: 4m 4s)
#           acc: 0.99972, fpr: 0.00006, fnr: 0.01044, rec: 0.98956, prc: 0.99737, f1: 0.99345, f1_macro: 0.99665
# epoch: 1, passed number of graphs: 576, train running loss: 0.12076 (passed time: 4m 53s)
#           acc: 0.97854, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 672, train running loss: 0.11643 (passed time: 5m 41s)
#           acc: 0.97883, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 768, train running loss: 0.10858 (passed time: 6m 29s)
#           acc: 0.99349, fpr: 0.00019, fnr: 0.29481, rec: 0.70519, prc: 0.98765, f1: 0.82286, f1_macro: 0.90977
# Validation --- epoch: 1, loss: 0.02425
#           prc: 0.91068, fpr: 0.00156, rec: 0.64697, fnr: 0.35303, f1: 0.72389, acc: 0.99088, f1_macro: nan
# Better model saved at ./saved_models/GIN_0: 0.7238947869714817.pt.
# epoch: 2, passed number of graphs: 96, train running loss: 0.01513 (passed time: 8m 10s)
#           acc: 0.99963, fpr: 0.00022, fnr: 0.00767, rec: 0.99233, prc: 0.99011, f1: 0.99122, f1_macro: 0.99551
# epoch: 2, passed number of graphs: 192, train running loss: 0.01359 (passed time: 8m 59s)
#           acc: 0.99958, fpr: 0.00013, fnr: 0.01414, rec: 0.98586, prc: 0.99403, f1: 0.98993, f1_macro: 0.99486
# epoch: 2, passed number of graphs: 288, train running loss: 0.01115 (passed time: 9m 47s)
#           acc: 0.99921, fpr: 0.00023, fnr: 0.02723, rec: 0.97277, prc: 0.98899, f1: 0.98081, f1_macro: 0.99021
# epoch: 2, passed number of graphs: 384, train running loss: 0.00972 (passed time: 10m 35s)
#           acc: 0.99965, fpr: 0.00011, fnr: 0.01098, rec: 0.98902, prc: 0.99513, f1: 0.99206, f1_macro: 0.99594
# epoch: 2, passed number of graphs: 480, train running loss: 0.00839 (passed time: 11m 23s)
#           acc: 0.99985, fpr: 0.00006, fnr: 0.00424, rec: 0.99576, prc: 0.99739, f1: 0.99657, f1_macro: 0.99825
# epoch: 2, passed number of graphs: 576, train running loss: 0.00805 (passed time: 12m 12s)
#           acc: 0.99971, fpr: 0.00020, fnr: 0.00454, rec: 0.99546, prc: 0.99096, f1: 0.99321, f1_macro: 0.99653
# epoch: 2, passed number of graphs: 672, train running loss: 0.00797 (passed time: 13m 0s)
#           acc: 0.99445, fpr: 0.00011, fnr: 0.25700, rec: 0.74300, prc: 0.99312, f1: 0.85005, f1_macro: 0.92361
# epoch: 2, passed number of graphs: 768, train running loss: 0.00801 (passed time: 13m 49s)
#           acc: 0.99974, fpr: 0.00007, fnr: 0.00881, rec: 0.99119, prc: 0.99672, f1: 0.99394, f1_macro: 0.99691
# Validation --- epoch: 2, loss: 0.00414
#           prc: 0.99507, fpr: 0.00011, rec: 0.97398, fnr: 0.02602, f1: 0.98301, acc: 0.99934, f1_macro: 0.99133
# Better model saved at ./saved_models/GIN_1: 0.9830058595248558.pt.
# epoch: 3, passed number of graphs: 96, train running loss: 0.00404 (passed time: 15m 10s)
#           acc: 0.99987, fpr: 0.00005, fnr: 0.00384, rec: 0.99616, prc: 0.99776, f1: 0.99696, f1_macro: 0.99845
# epoch: 3, passed number of graphs: 192, train running loss: 0.00509 (passed time: 15m 58s)
#           acc: 0.99970, fpr: 0.00000, fnr: 0.01414, rec: 0.98586, prc: 1.00000, f1: 0.99288, f1_macro: 0.99636
# epoch: 3, passed number of graphs: 288, train running loss: 0.00505 (passed time: 16m 46s)
#           acc: 0.99967, fpr: 0.00016, fnr: 0.00820, rec: 0.99180, prc: 0.99245, f1: 0.99212, f1_macro: 0.99598
# epoch: 3, passed number of graphs: 384, train running loss: 0.00466 (passed time: 17m 35s)
#           acc: 0.99978, fpr: 0.00005, fnr: 0.00775, rec: 0.99225, prc: 0.99773, f1: 0.99498, f1_macro: 0.99743
# epoch: 3, passed number of graphs: 480, train running loss: 0.00417 (passed time: 18m 23s)
#           acc: 0.99984, fpr: 0.00004, fnr: 0.00555, rec: 0.99445, prc: 0.99804, f1: 0.99624, f1_macro: 0.99808
# epoch: 3, passed number of graphs: 576, train running loss: 0.00438 (passed time: 19m 11s)
#           acc: 0.99962, fpr: 0.00031, fnr: 0.00357, rec: 0.99643, prc: 0.98620, f1: 0.99129, f1_macro: 0.99555
# epoch: 3, passed number of graphs: 672, train running loss: 0.00449 (passed time: 20m 0s)
#           acc: 0.99444, fpr: 0.00014, fnr: 0.25603, rec: 0.74397, prc: 0.99143, f1: 0.85006, f1_macro: 0.92361
# epoch: 3, passed number of graphs: 768, train running loss: 0.00509 (passed time: 20m 48s)
#           acc: 0.99980, fpr: 0.00008, fnr: 0.00588, rec: 0.99412, prc: 0.99640, f1: 0.99526, f1_macro: 0.99758
# Validation --- epoch: 3, loss: 0.00355
#           prc: 0.99695, fpr: 0.00007, rec: 0.97407, fnr: 0.02593, f1: 0.98397, acc: 0.99938, f1_macro: 0.99183
# Better model saved at ./saved_models/GIN_2: 0.9839715862606427.pt.
# epoch: 4, passed number of graphs: 96, train running loss: 0.00351 (passed time: 22m 9s)
#           acc: 0.99985, fpr: 0.00008, fnr: 0.00352, rec: 0.99648, prc: 0.99648, f1: 0.99648, f1_macro: 0.99820
# epoch: 4, passed number of graphs: 192, train running loss: 0.00449 (passed time: 22m 58s)
#           acc: 0.99798, fpr: 0.00200, fnr: 0.00263, rec: 0.99737, prc: 0.91496, f1: 0.95439, f1_macro: 0.97668
# epoch: 4, passed number of graphs: 288, train running loss: 0.00431 (passed time: 23m 46s)
#           acc: 0.99977, fpr: 0.00013, fnr: 0.00525, rec: 0.99475, prc: 0.99410, f1: 0.99442, f1_macro: 0.99715
# epoch: 4, passed number of graphs: 384, train running loss: 0.00386 (passed time: 24m 34s)
#           acc: 0.99981, fpr: 0.00004, fnr: 0.00678, rec: 0.99322, prc: 0.99805, f1: 0.99563, f1_macro: 0.99777
# epoch: 4, passed number of graphs: 480, train running loss: 0.00348 (passed time: 25m 23s)
#           acc: 0.99984, fpr: 0.00014, fnr: 0.00131, rec: 0.99869, prc: 0.99383, f1: 0.99626, f1_macro: 0.99809
# epoch: 4, passed number of graphs: 576, train running loss: 0.00351 (passed time: 26m 11s)
#           acc: 0.99962, fpr: 0.00030, fnr: 0.00421, rec: 0.99579, prc: 0.98651, f1: 0.99113, f1_macro: 0.99547
# epoch: 4, passed number of graphs: 672, train running loss: 0.00381 (passed time: 27m 0s)
#           acc: 0.99444, fpr: 0.00010, fnr: 0.25796, rec: 0.74204, prc: 0.99354, f1: 0.84957, f1_macro: 0.92337
# epoch: 4, passed number of graphs: 768, train running loss: 0.00389 (passed time: 27m 48s)
#           acc: 0.99978, fpr: 0.00004, fnr: 0.00881, rec: 0.99119, prc: 0.99836, f1: 0.99476, f1_macro: 0.99732
# Validation --- epoch: 4, loss: 0.00373
#           prc: 0.99935, fpr: 0.00001, rec: 0.97226, fnr: 0.02774, f1: 0.98420, acc: 0.99939, f1_macro: 0.99194
# Better model saved at ./saved_models/GIN_3: 0.9841963287227858.pt.
# epoch: 5, passed number of graphs: 96, train running loss: 0.00299 (passed time: 29m 10s)
#           acc: 0.99989, fpr: 0.00007, fnr: 0.00192, rec: 0.99808, prc: 0.99681, f1: 0.99744, f1_macro: 0.99869
# epoch: 5, passed number of graphs: 192, train running loss: 0.00369 (passed time: 29m 58s)
#           acc: 0.99932, fpr: 0.00065, fnr: 0.00230, rec: 0.99770, prc: 0.97089, f1: 0.98411, f1_macro: 0.99188
# epoch: 5, passed number of graphs: 288, train running loss: 0.00382 (passed time: 30m 46s)
#           acc: 0.99980, fpr: 0.00018, fnr: 0.00131, rec: 0.99869, prc: 0.99153, f1: 0.99510, f1_macro: 0.99750
# epoch: 5, passed number of graphs: 384, train running loss: 0.00332 (passed time: 31m 35s)
#           acc: 0.99984, fpr: 0.00004, fnr: 0.00581, rec: 0.99419, prc: 0.99838, f1: 0.99628, f1_macro: 0.99810
# epoch: 5, passed number of graphs: 480, train running loss: 0.00297 (passed time: 32m 23s)
#           acc: 0.99977, fpr: 0.00022, fnr: 0.00033, rec: 0.99967, prc: 0.98998, f1: 0.99481, f1_macro: 0.99734
# epoch: 5, passed number of graphs: 576, train running loss: 0.00318 (passed time: 33m 11s)
#           acc: 0.99935, fpr: 0.00062, fnr: 0.00194, rec: 0.99806, prc: 0.97252, f1: 0.98512, f1_macro: 0.99240
# epoch: 5, passed number of graphs: 672, train running loss: 0.00328 (passed time: 34m 0s)
#           acc: 0.99444, fpr: 0.00008, fnr: 0.25860, rec: 0.74140, prc: 0.99482, f1: 0.84961, f1_macro: 0.92339
# epoch: 5, passed number of graphs: 768, train running loss: 0.00321 (passed time: 34m 48s)
#           acc: 0.99989, fpr: 0.00009, fnr: 0.00098, rec: 0.99902, prc: 0.99609, f1: 0.99756, f1_macro: 0.99875
# Validation --- epoch: 5, loss: 0.00262
#           prc: 0.99582, fpr: 0.00009, rec: 0.98251, fnr: 0.01749, f1: 0.98788, acc: 0.99954, f1_macro: 0.99382
# Better model saved at ./saved_models/GIN_4: 0.9878751650413671.pt.
# epoch: 6, passed number of graphs: 96, train running loss: 0.00222 (passed time: 36m 9s)
#           acc: 0.99992, fpr: 0.00007, fnr: 0.00064, rec: 0.99936, prc: 0.99681, f1: 0.99808, f1_macro: 0.99902
# epoch: 6, passed number of graphs: 192, train running loss: 0.00319 (passed time: 36m 58s)
#           acc: 0.99647, fpr: 0.00360, fnr: 0.00033, rec: 0.99967, prc: 0.85710, f1: 0.92291, f1_macro: 0.96055
# epoch: 6, passed number of graphs: 288, train running loss: 0.00294 (passed time: 37m 46s)
#           acc: 0.99977, fpr: 0.00023, fnr: 0.00033, rec: 0.99967, prc: 0.98929, f1: 0.99445, f1_macro: 0.99717
# epoch: 6, passed number of graphs: 384, train running loss: 0.00267 (passed time: 38m 34s)
#           acc: 0.99989, fpr: 0.00004, fnr: 0.00355, rec: 0.99645, prc: 0.99838, f1: 0.99741, f1_macro: 0.99868
# epoch: 6, passed number of graphs: 480, train running loss: 0.00244 (passed time: 39m 23s)
#           acc: 0.99978, fpr: 0.00022, fnr: 0.00033, rec: 0.99967, prc: 0.99030, f1: 0.99497, f1_macro: 0.99743
# epoch: 6, passed number of graphs: 576, train running loss: 0.00240 (passed time: 40m 11s)
#           acc: 0.99964, fpr: 0.00035, fnr: 0.00097, rec: 0.99903, prc: 0.98435, f1: 0.99163, f1_macro: 0.99572
# epoch: 6, passed number of graphs: 672, train running loss: 0.00309 (passed time: 40m 59s)
#           acc: 0.99451, fpr: 0.00004, fnr: 0.25732, rec: 0.74268, prc: 0.99741, f1: 0.85140, f1_macro: 0.92430
# epoch: 6, passed number of graphs: 768, train running loss: 0.00309 (passed time: 41m 48s)
#           acc: 0.99992, fpr: 0.00006, fnr: 0.00098, rec: 0.99902, prc: 0.99739, f1: 0.99821, f1_macro: 0.99908
# Validation --- epoch: 6, loss: 0.00209
#           prc: 0.99722, fpr: 0.00006, rec: 0.98448, fnr: 0.01552, f1: 0.98954, acc: 0.99961, f1_macro: 0.99467
# Better model saved at ./saved_models/GIN_5: 0.9895426580892068.pt.
# epoch: 7, passed number of graphs: 96, train running loss: 0.00201 (passed time: 43m 9s)
#           acc: 0.99994, fpr: 0.00006, fnr: 0.00000, rec: 1.00000, prc: 0.99713, f1: 0.99856, f1_macro: 0.99927
# epoch: 7, passed number of graphs: 192, train running loss: 0.00263 (passed time: 43m 57s)
#           acc: 0.99972, fpr: 0.00028, fnr: 0.00033, rec: 0.99967, prc: 0.98734, f1: 0.99347, f1_macro: 0.99666
# epoch: 7, passed number of graphs: 288, train running loss: 0.00252 (passed time: 44m 46s)
#           acc: 0.99983, fpr: 0.00015, fnr: 0.00098, rec: 0.99902, prc: 0.99283, f1: 0.99591, f1_macro: 0.99791
# epoch: 7, passed number of graphs: 384, train running loss: 0.00224 (passed time: 45m 34s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00161, rec: 0.99839, prc: 0.99903, f1: 0.99871, f1_macro: 0.99934
# epoch: 7, passed number of graphs: 480, train running loss: 0.00208 (passed time: 46m 22s)
#           acc: 0.99975, fpr: 0.00024, fnr: 0.00033, rec: 0.99967, prc: 0.98903, f1: 0.99432, f1_macro: 0.99710
# epoch: 7, passed number of graphs: 576, train running loss: 0.00218 (passed time: 47m 11s)
#           acc: 0.99939, fpr: 0.00062, fnr: 0.00032, rec: 0.99968, prc: 0.97256, f1: 0.98593, f1_macro: 0.99281
# epoch: 7, passed number of graphs: 672, train running loss: 0.00254 (passed time: 47m 59s)
#           acc: 0.99459, fpr: 0.00004, fnr: 0.25346, rec: 0.74654, prc: 0.99742, f1: 0.85394, f1_macro: 0.92559
# epoch: 7, passed number of graphs: 768, train running loss: 0.00254 (passed time: 48m 47s)
#           acc: 0.99995, fpr: 0.00003, fnr: 0.00098, rec: 0.99902, prc: 0.99869, f1: 0.99886, f1_macro: 0.99942
# Validation --- epoch: 7, loss: 0.00191
#           prc: 0.99487, fpr: 0.00011, rec: 0.98552, fnr: 0.01448, f1: 0.98902, acc: 0.99958, f1_macro: 0.99440
# epoch: 8, passed number of graphs: 96, train running loss: 0.00161 (passed time: 50m 9s)
#           acc: 0.99994, fpr: 0.00006, fnr: 0.00000, rec: 1.00000, prc: 0.99713, f1: 0.99856, f1_macro: 0.99927
# epoch: 8, passed number of graphs: 192, train running loss: 0.00239 (passed time: 50m 57s)
#           acc: 0.99989, fpr: 0.00011, fnr: 0.00033, rec: 0.99967, prc: 0.99509, f1: 0.99738, f1_macro: 0.99866
# epoch: 8, passed number of graphs: 288, train running loss: 0.00238 (passed time: 51m 45s)
#           acc: 0.99986, fpr: 0.00011, fnr: 0.00131, rec: 0.99869, prc: 0.99477, f1: 0.99673, f1_macro: 0.99833
# epoch: 8, passed number of graphs: 384, train running loss: 0.00210 (passed time: 52m 34s)
#           acc: 0.99995, fpr: 0.00002, fnr: 0.00129, rec: 0.99871, prc: 0.99903, f1: 0.99887, f1_macro: 0.99942
# epoch: 8, passed number of graphs: 480, train running loss: 0.00197 (passed time: 53m 22s)
#           acc: 0.99981, fpr: 0.00019, fnr: 0.00033, rec: 0.99967, prc: 0.99159, f1: 0.99561, f1_macro: 0.99776
# epoch: 8, passed number of graphs: 576, train running loss: 0.00193 (passed time: 54m 10s)
#           acc: 0.99960, fpr: 0.00040, fnr: 0.00032, rec: 0.99968, prc: 0.98217, f1: 0.99084, f1_macro: 0.99532
# epoch: 8, passed number of graphs: 672, train running loss: 0.00243 (passed time: 54m 59s)
#           acc: 0.99452, fpr: 0.00000, fnr: 0.25860, rec: 0.74140, prc: 1.00000, f1: 0.85150, f1_macro: 0.92435
# epoch: 8, passed number of graphs: 768, train running loss: 0.00245 (passed time: 55m 47s)
#           acc: 0.99996, fpr: 0.00003, fnr: 0.00065, rec: 0.99935, prc: 0.99869, f1: 0.99902, f1_macro: 0.99950
# Validation --- epoch: 8, loss: 0.00163
#           prc: 0.99402, fpr: 0.00013, rec: 0.98961, fnr: 0.01039, f1: 0.99110, acc: 0.99965, f1_macro: 0.99546
# Better model saved at ./saved_models/GIN_7: 0.9910956310491369.pt.
# epoch: 9, passed number of graphs: 96, train running loss: 0.00142 (passed time: 57m 9s)
#           acc: 0.99995, fpr: 0.00005, fnr: 0.00000, rec: 1.00000, prc: 0.99777, f1: 0.99888, f1_macro: 0.99943
# epoch: 9, passed number of graphs: 192, train running loss: 0.00184 (passed time: 57m 57s)
#           acc: 0.99981, fpr: 0.00018, fnr: 0.00033, rec: 0.99967, prc: 0.99152, f1: 0.99558, f1_macro: 0.99774
# epoch: 9, passed number of graphs: 288, train running loss: 0.00180 (passed time: 58m 45s)
#           acc: 0.99988, fpr: 0.00008, fnr: 0.00197, rec: 0.99803, prc: 0.99640, f1: 0.99721, f1_macro: 0.99858
# epoch: 9, passed number of graphs: 384, train running loss: 0.00166 (passed time: 59m 34s)
#           acc: 0.99996, fpr: 0.00002, fnr: 0.00065, rec: 0.99935, prc: 0.99903, f1: 0.99919, f1_macro: 0.99959
# epoch: 9, passed number of graphs: 480, train running loss: 0.00159 (passed time: 1h 0m 22s)
#           acc: 0.99988, fpr: 0.00005, fnr: 0.00326, rec: 0.99674, prc: 0.99771, f1: 0.99723, f1_macro: 0.99858
# epoch: 9, passed number of graphs: 576, train running loss: 0.00155 (passed time: 1h 1m 10s)
#           acc: 0.99957, fpr: 0.00043, fnr: 0.00065, rec: 0.99935, prc: 0.98091, f1: 0.99004, f1_macro: 0.99491
# epoch: 9, passed number of graphs: 672, train running loss: 0.00185 (passed time: 1h 1m 59s)
#           acc: 0.99457, fpr: 0.00000, fnr: 0.25667, rec: 0.74333, prc: 1.00000, f1: 0.85277, f1_macro: 0.92500
# epoch: 9, passed number of graphs: 768, train running loss: 0.00187 (passed time: 1h 2m 47s)
#           acc: 0.99989, fpr: 0.00001, fnr: 0.00490, rec: 0.99510, prc: 0.99967, f1: 0.99738, f1_macro: 0.99866
# Validation --- epoch: 9, loss: 0.00221
#           prc: 0.99539, fpr: 0.00010, rec: 0.98153, fnr: 0.01847, f1: 0.98718, acc: 0.99950, f1_macro: 0.99346
# epoch: 10, passed number of graphs: 96, train running loss: 0.00092 (passed time: 1h 4m 9s)
#           acc: 0.99999, fpr: 0.00001, fnr: 0.00032, rec: 0.99968, prc: 0.99968, f1: 0.99968, f1_macro: 0.99984
# epoch: 10, passed number of graphs: 192, train running loss: 0.00175 (passed time: 1h 4m 57s)
#           acc: 0.99993, fpr: 0.00004, fnr: 0.00131, rec: 0.99869, prc: 0.99803, f1: 0.99836, f1_macro: 0.99916
# epoch: 10, passed number of graphs: 288, train running loss: 0.00161 (passed time: 1h 5m 45s)
#           acc: 0.99990, fpr: 0.00008, fnr: 0.00098, rec: 0.99902, prc: 0.99607, f1: 0.99754, f1_macro: 0.99875
# epoch: 10, passed number of graphs: 384, train running loss: 0.00155 (passed time: 1h 6m 34s)
#           acc: 0.99995, fpr: 0.00002, fnr: 0.00129, rec: 0.99871, prc: 0.99903, f1: 0.99887, f1_macro: 0.99942
# epoch: 10, passed number of graphs: 480, train running loss: 0.00152 (passed time: 1h 7m 22s)
#           acc: 0.99742, fpr: 0.00000, fnr: 0.11941, rec: 0.88059, prc: 1.00000, f1: 0.93650, f1_macro: 0.96759
# epoch: 10, passed number of graphs: 576, train running loss: 0.00166 (passed time: 1h 8m 10s)
#           acc: 0.99967, fpr: 0.00031, fnr: 0.00130, rec: 0.99870, prc: 0.98592, f1: 0.99227, f1_macro: 0.99605
# epoch: 10, passed number of graphs: 672, train running loss: 0.00188 (passed time: 1h 8m 58s)
#           acc: 0.99457, fpr: 0.00000, fnr: 0.25635, rec: 0.74365, prc: 1.00000, f1: 0.85298, f1_macro: 0.92511
# epoch: 10, passed number of graphs: 768, train running loss: 0.00189 (passed time: 1h 9m 47s)
#           acc: 0.99992, fpr: 0.00001, fnr: 0.00326, rec: 0.99674, prc: 0.99935, f1: 0.99804, f1_macro: 0.99900
# Validation --- epoch: 10, loss: 0.00178
#           prc: 0.99870, fpr: 0.00003, rec: 0.98620, fnr: 0.01380, f1: 0.99142, acc: 0.99968, f1_macro: 0.99563
# Better model saved at ./saved_models/GIN_9: 0.9914196685021919.pt.
# epoch: 11, passed number of graphs: 96, train running loss: 0.00081 (passed time: 1h 11m 8s)
#           acc: 0.99997, fpr: 0.00002, fnr: 0.00032, rec: 0.99968, prc: 0.99904, f1: 0.99936, f1_macro: 0.99967
# epoch: 11, passed number of graphs: 192, train running loss: 0.00095 (passed time: 1h 11m 57s)
#           acc: 0.99994, fpr: 0.00000, fnr: 0.00296, rec: 0.99704, prc: 1.00000, f1: 0.99852, f1_macro: 0.99924
# epoch: 11, passed number of graphs: 288, train running loss: 0.00086 (passed time: 1h 12m 45s)
#           acc: 0.99990, fpr: 0.00008, fnr: 0.00098, rec: 0.99902, prc: 0.99640, f1: 0.99771, f1_macro: 0.99883
# epoch: 11, passed number of graphs: 384, train running loss: 0.00086 (passed time: 1h 13m 33s)
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00226, rec: 0.99774, prc: 0.99903, f1: 0.99838, f1_macro: 0.99917
# epoch: 11, passed number of graphs: 480, train running loss: 0.00084 (passed time: 1h 14m 21s)
#           acc: 0.99985, fpr: 0.00014, fnr: 0.00065, rec: 0.99935, prc: 0.99384, f1: 0.99658, f1_macro: 0.99825
# epoch: 11, passed number of graphs: 576, train running loss: 0.00080 (passed time: 1h 15m 10s)
#           acc: 0.99970, fpr: 0.00028, fnr: 0.00130, rec: 0.99870, prc: 0.98750, f1: 0.99307, f1_macro: 0.99646
# epoch: 11, passed number of graphs: 672, train running loss: 0.00096 (passed time: 1h 15m 58s)
#           acc: 0.99939, fpr: 0.00049, fnr: 0.00611, rec: 0.99389, prc: 0.97785, f1: 0.98580, f1_macro: 0.99275
# epoch: 11, passed number of graphs: 768, train running loss: 0.00102 (passed time: 1h 16m 46s)
#           acc: 0.99988, fpr: 0.00001, fnr: 0.00490, rec: 0.99510, prc: 0.99934, f1: 0.99722, f1_macro: 0.99858
# Validation --- epoch: 11, loss: 0.00187
#           prc: 0.99884, fpr: 0.00003, rec: 0.98584, fnr: 0.01416, f1: 0.99146, acc: 0.99967, f1_macro: 0.99564
# Better model saved at ./saved_models/GIN_10: 0.9914569743807733.pt.
# epoch: 12, passed number of graphs: 96, train running loss: 0.00065 (passed time: 1h 18m 8s)
#           acc: 0.99999, fpr: 0.00001, fnr: 0.00032, rec: 0.99968, prc: 0.99968, f1: 0.99968, f1_macro: 0.99984
# epoch: 12, passed number of graphs: 192, train running loss: 0.00093 (passed time: 1h 18m 56s)
#           acc: 0.99993, fpr: 0.00000, fnr: 0.00329, rec: 0.99671, prc: 1.00000, f1: 0.99835, f1_macro: 0.99916
# epoch: 12, passed number of graphs: 288, train running loss: 0.00086 (passed time: 1h 19m 45s)
#           acc: 0.99990, fpr: 0.00008, fnr: 0.00098, rec: 0.99902, prc: 0.99640, f1: 0.99771, f1_macro: 0.99883
# epoch: 12, passed number of graphs: 384, train running loss: 0.00087 (passed time: 1h 20m 33s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00161, rec: 0.99839, prc: 0.99871, f1: 0.99855, f1_macro: 0.99926
# epoch: 12, passed number of graphs: 480, train running loss: 0.00084 (passed time: 1h 21m 21s)
#           acc: 0.99984, fpr: 0.00015, fnr: 0.00065, rec: 0.99935, prc: 0.99319, f1: 0.99626, f1_macro: 0.99809
# epoch: 12, passed number of graphs: 576, train running loss: 0.00080 (passed time: 1h 22m 10s)
#           acc: 0.99969, fpr: 0.00027, fnr: 0.00194, rec: 0.99806, prc: 0.98781, f1: 0.99291, f1_macro: 0.99637
# epoch: 12, passed number of graphs: 672, train running loss: 0.00100 (passed time: 1h 22m 58s)
#           acc: 0.99941, fpr: 0.00051, fnr: 0.00386, rec: 0.99614, prc: 0.97666, f1: 0.98631, f1_macro: 0.99300
# epoch: 12, passed number of graphs: 768, train running loss: 0.00105 (passed time: 1h 23m 46s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00196, rec: 0.99804, prc: 0.99902, f1: 0.99853, f1_macro: 0.99925
# Validation --- epoch: 12, loss: 0.00132
#           prc: 0.99780, fpr: 0.00005, rec: 0.99074, fnr: 0.00926, f1: 0.99352, acc: 0.99975, f1_macro: 0.99670
# Better model saved at ./saved_models/GIN_11: 0.9935161056967313.pt.
# epoch: 13, passed number of graphs: 96, train running loss: 0.00056 (passed time: 1h 25m 8s)
#           acc: 0.99999, fpr: 0.00001, fnr: 0.00032, rec: 0.99968, prc: 0.99968, f1: 0.99968, f1_macro: 0.99984
# epoch: 13, passed number of graphs: 192, train running loss: 0.00088 (passed time: 1h 25m 56s)
#           acc: 0.99994, fpr: 0.00000, fnr: 0.00263, rec: 0.99737, prc: 1.00000, f1: 0.99868, f1_macro: 0.99933
# epoch: 13, passed number of graphs: 288, train running loss: 0.00082 (passed time: 1h 26m 45s)
#           acc: 0.99990, fpr: 0.00008, fnr: 0.00098, rec: 0.99902, prc: 0.99607, f1: 0.99754, f1_macro: 0.99875
# epoch: 13, passed number of graphs: 384, train running loss: 0.00082 (passed time: 1h 27m 33s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00161, rec: 0.99839, prc: 0.99903, f1: 0.99871, f1_macro: 0.99934
# epoch: 13, passed number of graphs: 480, train running loss: 0.00078 (passed time: 1h 28m 21s)
#           acc: 0.99983, fpr: 0.00016, fnr: 0.00065, rec: 0.99935, prc: 0.99287, f1: 0.99610, f1_macro: 0.99801
# epoch: 13, passed number of graphs: 576, train running loss: 0.00074 (passed time: 1h 29m 10s)
#           acc: 0.99969, fpr: 0.00028, fnr: 0.00194, rec: 0.99806, prc: 0.98749, f1: 0.99275, f1_macro: 0.99629
# epoch: 13, passed number of graphs: 672, train running loss: 0.00093 (passed time: 1h 29m 58s)
#           acc: 0.99787, fpr: 0.00022, fnr: 0.09070, rec: 0.90930, prc: 0.98915, f1: 0.94754, f1_macro: 0.97323
# epoch: 13, passed number of graphs: 768, train running loss: 0.00098 (passed time: 1h 30m 46s)
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00229, rec: 0.99771, prc: 0.99902, f1: 0.99837, f1_macro: 0.99917
# Validation --- epoch: 13, loss: 0.00144
#           prc: 0.99765, fpr: 0.00005, rec: 0.99068, fnr: 0.00932, f1: 0.99341, acc: 0.99975, f1_macro: 0.99664
# epoch: 14, passed number of graphs: 96, train running loss: 0.00049 (passed time: 1h 32m 8s)
#           acc: 0.99999, fpr: 0.00001, fnr: 0.00032, rec: 0.99968, prc: 0.99968, f1: 0.99968, f1_macro: 0.99984
# epoch: 14, passed number of graphs: 192, train running loss: 0.00076 (passed time: 1h 32m 56s)
#           acc: 0.99994, fpr: 0.00000, fnr: 0.00263, rec: 0.99737, prc: 1.00000, f1: 0.99868, f1_macro: 0.99933
# epoch: 14, passed number of graphs: 288, train running loss: 0.00071 (passed time: 1h 33m 45s)
#           acc: 0.99990, fpr: 0.00008, fnr: 0.00098, rec: 0.99902, prc: 0.99640, f1: 0.99771, f1_macro: 0.99883
# epoch: 14, passed number of graphs: 384, train running loss: 0.00072 (passed time: 1h 34m 33s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00194, rec: 0.99806, prc: 0.99903, f1: 0.99855, f1_macro: 0.99926
# epoch: 14, passed number of graphs: 480, train running loss: 0.00069 (passed time: 1h 35m 21s)
#           acc: 0.99980, fpr: 0.00019, fnr: 0.00065, rec: 0.99935, prc: 0.99158, f1: 0.99545, f1_macro: 0.99767
# epoch: 14, passed number of graphs: 576, train running loss: 0.00066 (passed time: 1h 36m 10s)
#           acc: 0.99967, fpr: 0.00031, fnr: 0.00130, rec: 0.99870, prc: 0.98592, f1: 0.99227, f1_macro: 0.99605
# epoch: 14, passed number of graphs: 672, train running loss: 0.00083 (passed time: 1h 36m 58s)
#           acc: 0.99894, fpr: 0.00028, fnr: 0.03699, rec: 0.96301, prc: 0.98682, f1: 0.97477, f1_macro: 0.98711
# epoch: 14, passed number of graphs: 768, train running loss: 0.00089 (passed time: 1h 37m 46s)
#           acc: 0.99992, fpr: 0.00001, fnr: 0.00326, rec: 0.99674, prc: 0.99935, f1: 0.99804, f1_macro: 0.99900
# Validation --- epoch: 14, loss: 0.00159
#           prc: 0.99784, fpr: 0.00005, rec: 0.98982, fnr: 0.01018, f1: 0.99307, acc: 0.99973, f1_macro: 0.99647
# epoch: 15, passed number of graphs: 96, train running loss: 0.00050 (passed time: 1h 39m 8s)
#           acc: 0.99999, fpr: 0.00001, fnr: 0.00032, rec: 0.99968, prc: 0.99968, f1: 0.99968, f1_macro: 0.99984
# epoch: 15, passed number of graphs: 192, train running loss: 0.00060 (passed time: 1h 39m 56s)
#           acc: 0.99994, fpr: 0.00000, fnr: 0.00263, rec: 0.99737, prc: 1.00000, f1: 0.99868, f1_macro: 0.99933
# epoch: 15, passed number of graphs: 288, train running loss: 0.00055 (passed time: 1h 40m 44s)
#           acc: 0.99988, fpr: 0.00007, fnr: 0.00230, rec: 0.99770, prc: 0.99672, f1: 0.99721, f1_macro: 0.99858
# epoch: 15, passed number of graphs: 384, train running loss: 0.00057 (passed time: 1h 41m 33s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00161, rec: 0.99839, prc: 0.99903, f1: 0.99871, f1_macro: 0.99934
# epoch: 15, passed number of graphs: 480, train running loss: 0.00055 (passed time: 1h 42m 21s)
#           acc: 0.99987, fpr: 0.00011, fnr: 0.00098, rec: 0.99902, prc: 0.99513, f1: 0.99707, f1_macro: 0.99850
# epoch: 15, passed number of graphs: 576, train running loss: 0.00053 (passed time: 1h 43m 9s)
#           acc: 0.99967, fpr: 0.00031, fnr: 0.00130, rec: 0.99870, prc: 0.98592, f1: 0.99227, f1_macro: 0.99605
# epoch: 15, passed number of graphs: 672, train running loss: 0.00059 (passed time: 1h 43m 58s)
#           acc: 0.99941, fpr: 0.00056, fnr: 0.00225, rec: 0.99775, prc: 0.97486, f1: 0.98617, f1_macro: 0.99293
# epoch: 15, passed number of graphs: 768, train running loss: 0.00065 (passed time: 1h 44m 46s)
#           acc: 0.99994, fpr: 0.00003, fnr: 0.00131, rec: 0.99869, prc: 0.99869, f1: 0.99869, f1_macro: 0.99933
# Validation --- epoch: 15, loss: 0.00135
#           prc: 0.99696, fpr: 0.00007, rec: 0.99204, fnr: 0.00796, f1: 0.99378, acc: 0.99976, f1_macro: 0.99683
# Better model saved at ./saved_models/GIN_14: 0.993779208589142.pt.
# epoch: 16, passed number of graphs: 96, train running loss: 0.00044 (passed time: 1h 46m 8s)
#           acc: 0.99999, fpr: 0.00001, fnr: 0.00032, rec: 0.99968, prc: 0.99968, f1: 0.99968, f1_macro: 0.99984
# epoch: 16, passed number of graphs: 192, train running loss: 0.00061 (passed time: 1h 46m 56s)
#           acc: 0.99994, fpr: 0.00000, fnr: 0.00263, rec: 0.99737, prc: 1.00000, f1: 0.99868, f1_macro: 0.99933
# epoch: 16, passed number of graphs: 288, train running loss: 0.00056 (passed time: 1h 47m 44s)
#           acc: 0.99989, fpr: 0.00007, fnr: 0.00197, rec: 0.99803, prc: 0.99672, f1: 0.99738, f1_macro: 0.99866
# epoch: 16, passed number of graphs: 384, train running loss: 0.00058 (passed time: 1h 48m 33s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00194, rec: 0.99806, prc: 0.99903, f1: 0.99855, f1_macro: 0.99926
# epoch: 16, passed number of graphs: 480, train running loss: 0.00057 (passed time: 1h 49m 21s)
#           acc: 0.99988, fpr: 0.00010, fnr: 0.00098, rec: 0.99902, prc: 0.99545, f1: 0.99723, f1_macro: 0.99859
# epoch: 16, passed number of graphs: 576, train running loss: 0.00054 (passed time: 1h 50m 9s)
#           acc: 0.99967, fpr: 0.00031, fnr: 0.00097, rec: 0.99903, prc: 0.98592, f1: 0.99243, f1_macro: 0.99613
# epoch: 16, passed number of graphs: 672, train running loss: 0.00062 (passed time: 1h 50m 57s)
#           acc: 0.99941, fpr: 0.00054, fnr: 0.00289, rec: 0.99711, prc: 0.97546, f1: 0.98616, f1_macro: 0.99293
# epoch: 16, passed number of graphs: 768, train running loss: 0.00067 (passed time: 1h 51m 46s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00163, rec: 0.99837, prc: 0.99902, f1: 0.99869, f1_macro: 0.99933
# Validation --- epoch: 16, loss: 0.00132
#           prc: 0.99715, fpr: 0.00006, rec: 0.99158, fnr: 0.00842, f1: 0.99361, acc: 0.99976, f1_macro: 0.99674
# epoch: 17, passed number of graphs: 96, train running loss: 0.00043 (passed time: 1h 53m 8s)
#           acc: 0.99999, fpr: 0.00001, fnr: 0.00032, rec: 0.99968, prc: 0.99968, f1: 0.99968, f1_macro: 0.99984
# epoch: 17, passed number of graphs: 192, train running loss: 0.00059 (passed time: 1h 53m 56s)
#           acc: 0.99994, fpr: 0.00000, fnr: 0.00263, rec: 0.99737, prc: 1.00000, f1: 0.99868, f1_macro: 0.99933
# epoch: 17, passed number of graphs: 288, train running loss: 0.00054 (passed time: 1h 54m 44s)
#           acc: 0.99989, fpr: 0.00007, fnr: 0.00197, rec: 0.99803, prc: 0.99672, f1: 0.99738, f1_macro: 0.99866
# epoch: 17, passed number of graphs: 384, train running loss: 0.00057 (passed time: 1h 55m 32s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00194, rec: 0.99806, prc: 0.99903, f1: 0.99855, f1_macro: 0.99926
# epoch: 17, passed number of graphs: 480, train running loss: 0.00056 (passed time: 1h 56m 21s)
#           acc: 0.99988, fpr: 0.00010, fnr: 0.00098, rec: 0.99902, prc: 0.99545, f1: 0.99723, f1_macro: 0.99859
# epoch: 17, passed number of graphs: 576, train running loss: 0.00054 (passed time: 1h 57m 9s)
#           acc: 0.99967, fpr: 0.00031, fnr: 0.00097, rec: 0.99903, prc: 0.98592, f1: 0.99243, f1_macro: 0.99613
# epoch: 17, passed number of graphs: 672, train running loss: 0.00061 (passed time: 1h 57m 57s)
#           acc: 0.99941, fpr: 0.00053, fnr: 0.00354, rec: 0.99646, prc: 0.97606, f1: 0.98615, f1_macro: 0.99293
# epoch: 17, passed number of graphs: 768, train running loss: 0.00066 (passed time: 1h 58m 45s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00163, rec: 0.99837, prc: 0.99902, f1: 0.99869, f1_macro: 0.99933
# Validation --- epoch: 17, loss: 0.00131
#           prc: 0.99697, fpr: 0.00007, rec: 0.99149, fnr: 0.00851, f1: 0.99347, acc: 0.99975, f1_macro: 0.99667
# epoch: 18, passed number of graphs: 96, train running loss: 0.00042 (passed time: 2h 0m 7s)
#           acc: 0.99999, fpr: 0.00001, fnr: 0.00032, rec: 0.99968, prc: 0.99968, f1: 0.99968, f1_macro: 0.99984
# epoch: 18, passed number of graphs: 192, train running loss: 0.00058 (passed time: 2h 0m 55s)
#           acc: 0.99994, fpr: 0.00000, fnr: 0.00263, rec: 0.99737, prc: 1.00000, f1: 0.99868, f1_macro: 0.99933
# epoch: 18, passed number of graphs: 288, train running loss: 0.00053 (passed time: 2h 1m 43s)
#           acc: 0.99989, fpr: 0.00007, fnr: 0.00197, rec: 0.99803, prc: 0.99672, f1: 0.99738, f1_macro: 0.99866
# epoch: 18, passed number of graphs: 384, train running loss: 0.00056 (passed time: 2h 2m 32s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00194, rec: 0.99806, prc: 0.99903, f1: 0.99855, f1_macro: 0.99926
# epoch: 18, passed number of graphs: 480, train running loss: 0.00055 (passed time: 2h 3m 20s)
#           acc: 0.99988, fpr: 0.00010, fnr: 0.00098, rec: 0.99902, prc: 0.99545, f1: 0.99723, f1_macro: 0.99859
# epoch: 18, passed number of graphs: 576, train running loss: 0.00053 (passed time: 2h 4m 8s)
#           acc: 0.99967, fpr: 0.00031, fnr: 0.00097, rec: 0.99903, prc: 0.98592, f1: 0.99243, f1_macro: 0.99613
# epoch: 18, passed number of graphs: 672, train running loss: 0.00060 (passed time: 2h 4m 57s)
#           acc: 0.99940, fpr: 0.00052, fnr: 0.00418, rec: 0.99582, prc: 0.97635, f1: 0.98599, f1_macro: 0.99284
# epoch: 18, passed number of graphs: 768, train running loss: 0.00066 (passed time: 2h 5m 45s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00196, rec: 0.99804, prc: 0.99902, f1: 0.99853, f1_macro: 0.99925
# Validation --- epoch: 18, loss: 0.00137
#           prc: 0.99717, fpr: 0.00006, rec: 0.99103, fnr: 0.00897, f1: 0.99334, acc: 0.99975, f1_macro: 0.99660
# epoch: 19, passed number of graphs: 96, train running loss: 0.00042 (passed time: 2h 7m 7s)
#           acc: 0.99999, fpr: 0.00001, fnr: 0.00032, rec: 0.99968, prc: 0.99968, f1: 0.99968, f1_macro: 0.99984
# epoch: 19, passed number of graphs: 192, train running loss: 0.00056 (passed time: 2h 7m 55s)
#           acc: 0.99994, fpr: 0.00000, fnr: 0.00263, rec: 0.99737, prc: 1.00000, f1: 0.99868, f1_macro: 0.99933
# epoch: 19, passed number of graphs: 288, train running loss: 0.00051 (passed time: 2h 8m 43s)
#           acc: 0.99989, fpr: 0.00007, fnr: 0.00197, rec: 0.99803, prc: 0.99672, f1: 0.99738, f1_macro: 0.99866
# epoch: 19, passed number of graphs: 384, train running loss: 0.00055 (passed time: 2h 9m 31s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00194, rec: 0.99806, prc: 0.99903, f1: 0.99855, f1_macro: 0.99926
# epoch: 19, passed number of graphs: 480, train running loss: 0.00054 (passed time: 2h 10m 20s)
#           acc: 0.99986, fpr: 0.00012, fnr: 0.00098, rec: 0.99902, prc: 0.99448, f1: 0.99674, f1_macro: 0.99834
# epoch: 19, passed number of graphs: 576, train running loss: 0.00052 (passed time: 2h 11m 8s)
#           acc: 0.99968, fpr: 0.00031, fnr: 0.00065, rec: 0.99935, prc: 0.98593, f1: 0.99259, f1_macro: 0.99622
# epoch: 19, passed number of graphs: 672, train running loss: 0.00059 (passed time: 2h 11m 56s)
#           acc: 0.99940, fpr: 0.00052, fnr: 0.00418, rec: 0.99582, prc: 0.97635, f1: 0.98599, f1_macro: 0.99284
# epoch: 19, passed number of graphs: 768, train running loss: 0.00065 (passed time: 2h 12m 45s)
#           acc: 0.99993, fpr: 0.00002, fnr: 0.00229, rec: 0.99771, prc: 0.99902, f1: 0.99837, f1_macro: 0.99917
# Validation --- epoch: 19, loss: 0.00138
#           prc: 0.99735, fpr: 0.00006, rec: 0.99083, fnr: 0.00917, f1: 0.99333, acc: 0.99975, f1_macro: 0.99660
# epoch: 20, passed number of graphs: 96, train running loss: 0.00044 (passed time: 2h 14m 6s)
#           acc: 0.99999, fpr: 0.00001, fnr: 0.00032, rec: 0.99968, prc: 0.99968, f1: 0.99968, f1_macro: 0.99984
# epoch: 20, passed number of graphs: 192, train running loss: 0.00054 (passed time: 2h 14m 55s)
#           acc: 0.99994, fpr: 0.00000, fnr: 0.00263, rec: 0.99737, prc: 1.00000, f1: 0.99868, f1_macro: 0.99933
# epoch: 20, passed number of graphs: 288, train running loss: 0.00050 (passed time: 2h 15m 43s)
#           acc: 0.99988, fpr: 0.00007, fnr: 0.00262, rec: 0.99738, prc: 0.99672, f1: 0.99705, f1_macro: 0.99849
# epoch: 20, passed number of graphs: 384, train running loss: 0.00051 (passed time: 2h 16m 31s)
#           acc: 0.99995, fpr: 0.00002, fnr: 0.00129, rec: 0.99871, prc: 0.99903, f1: 0.99887, f1_macro: 0.99942
# epoch: 20, passed number of graphs: 480, train running loss: 0.00049 (passed time: 2h 17m 19s)
#           acc: 0.99988, fpr: 0.00009, fnr: 0.00131, rec: 0.99869, prc: 0.99577, f1: 0.99723, f1_macro: 0.99858
# epoch: 20, passed number of graphs: 576, train running loss: 0.00047 (passed time: 2h 18m 8s)
#           acc: 0.99968, fpr: 0.00031, fnr: 0.00097, rec: 0.99903, prc: 0.98624, f1: 0.99259, f1_macro: 0.99621
# epoch: 20, passed number of graphs: 672, train running loss: 0.00053 (passed time: 2h 18m 56s)
#           acc: 0.99940, fpr: 0.00055, fnr: 0.00289, rec: 0.99711, prc: 0.97515, f1: 0.98601, f1_macro: 0.99285
# epoch: 20, passed number of graphs: 768, train running loss: 0.00058 (passed time: 2h 19m 44s)
#           acc: 0.99995, fpr: 0.00003, fnr: 0.00098, rec: 0.99902, prc: 0.99869, f1: 0.99886, f1_macro: 0.99942
# Validation --- epoch: 20, loss: 0.00127
#           prc: 0.99700, fpr: 0.00007, rec: 0.99205, fnr: 0.00795, f1: 0.99380, acc: 0.99976, f1_macro: 0.99684
# Better model saved at ./saved_models/GIN_19: 0.993800137885532.pt.
# epoch: 21, passed number of graphs: 96, train running loss: 0.00046 (passed time: 2h 21m 6s)
#           acc: 0.99999, fpr: 0.00001, fnr: 0.00032, rec: 0.99968, prc: 0.99968, f1: 0.99968, f1_macro: 0.99984
# epoch: 21, passed number of graphs: 192, train running loss: 0.00058 (passed time: 2h 21m 54s)
#           acc: 0.99994, fpr: 0.00000, fnr: 0.00263, rec: 0.99737, prc: 1.00000, f1: 0.99868, f1_macro: 0.99933
# epoch: 21, passed number of graphs: 288, train running loss: 0.00053 (passed time: 2h 22m 42s)
#           acc: 0.99988, fpr: 0.00006, fnr: 0.00295, rec: 0.99705, prc: 0.99705, f1: 0.99705, f1_macro: 0.99849
# epoch: 21, passed number of graphs: 384, train running loss: 0.00054 (passed time: 2h 23m 31s)
#           acc: 0.99995, fpr: 0.00002, fnr: 0.00129, rec: 0.99871, prc: 0.99903, f1: 0.99887, f1_macro: 0.99942
# epoch: 21, passed number of graphs: 480, train running loss: 0.00052 (passed time: 2h 24m 19s)
#           acc: 0.99988, fpr: 0.00009, fnr: 0.00131, rec: 0.99869, prc: 0.99577, f1: 0.99723, f1_macro: 0.99858
# epoch: 21, passed number of graphs: 576, train running loss: 0.00049 (passed time: 2h 25m 7s)
#           acc: 0.99968, fpr: 0.00031, fnr: 0.00097, rec: 0.99903, prc: 0.98624, f1: 0.99259, f1_macro: 0.99621
# epoch: 21, passed number of graphs: 672, train running loss: 0.00055 (passed time: 2h 25m 55s)
#           acc: 0.99941, fpr: 0.00054, fnr: 0.00289, rec: 0.99711, prc: 0.97546, f1: 0.98616, f1_macro: 0.99293
# epoch: 21, passed number of graphs: 768, train running loss: 0.00060 (passed time: 2h 26m 44s)
#           acc: 0.99995, fpr: 0.00003, fnr: 0.00098, rec: 0.99902, prc: 0.99869, f1: 0.99886, f1_macro: 0.99942
# Validation --- epoch: 21, loss: 0.00128
#           prc: 0.99697, fpr: 0.00007, rec: 0.99191, fnr: 0.00809, f1: 0.99369, acc: 0.99976, f1_macro: 0.99678
# epoch: 22, passed number of graphs: 96, train running loss: 0.00046 (passed time: 2h 28m 5s)
#           acc: 0.99999, fpr: 0.00001, fnr: 0.00032, rec: 0.99968, prc: 0.99968, f1: 0.99968, f1_macro: 0.99984
# epoch: 22, passed number of graphs: 192, train running loss: 0.00058 (passed time: 2h 28m 54s)
#           acc: 0.99994, fpr: 0.00000, fnr: 0.00263, rec: 0.99737, prc: 1.00000, f1: 0.99868, f1_macro: 0.99933
# epoch: 22, passed number of graphs: 288, train running loss: 0.00053 (passed time: 2h 29m 42s)
#           acc: 0.99988, fpr: 0.00006, fnr: 0.00295, rec: 0.99705, prc: 0.99737, f1: 0.99721, f1_macro: 0.99858
# epoch: 22, passed number of graphs: 384, train running loss: 0.00054 (passed time: 2h 30m 30s)
#           acc: 0.99995, fpr: 0.00002, fnr: 0.00129, rec: 0.99871, prc: 0.99903, f1: 0.99887, f1_macro: 0.99942
# epoch: 22, passed number of graphs: 480, train running loss: 0.00051 (passed time: 2h 31m 18s)
#           acc: 0.99988, fpr: 0.00009, fnr: 0.00131, rec: 0.99869, prc: 0.99577, f1: 0.99723, f1_macro: 0.99858
# epoch: 22, passed number of graphs: 576, train running loss: 0.00049 (passed time: 2h 32m 7s)
#           acc: 0.99968, fpr: 0.00031, fnr: 0.00097, rec: 0.99903, prc: 0.98624, f1: 0.99259, f1_macro: 0.99621
# epoch: 22, passed number of graphs: 672, train running loss: 0.00055 (passed time: 2h 32m 55s)
#           acc: 0.99941, fpr: 0.00054, fnr: 0.00289, rec: 0.99711, prc: 0.97546, f1: 0.98616, f1_macro: 0.99293
# epoch: 22, passed number of graphs: 768, train running loss: 0.00060 (passed time: 2h 33m 44s)
#           acc: 0.99996, fpr: 0.00003, fnr: 0.00065, rec: 0.99935, prc: 0.99869, f1: 0.99902, f1_macro: 0.99950
# Validation --- epoch: 22, loss: 0.00127
#           prc: 0.99692, fpr: 0.00007, rec: 0.99197, fnr: 0.00803, f1: 0.99369, acc: 0.99976, f1_macro: 0.99678
# epoch: 23, passed number of graphs: 96, train running loss: 0.00046 (passed time: 2h 35m 5s)
#           acc: 0.99999, fpr: 0.00001, fnr: 0.00032, rec: 0.99968, prc: 0.99968, f1: 0.99968, f1_macro: 0.99984
# epoch: 23, passed number of graphs: 192, train running loss: 0.00058 (passed time: 2h 35m 53s)
#           acc: 0.99994, fpr: 0.00000, fnr: 0.00263, rec: 0.99737, prc: 1.00000, f1: 0.99868, f1_macro: 0.99933
# epoch: 23, passed number of graphs: 288, train running loss: 0.00053 (passed time: 2h 36m 42s)
#           acc: 0.99988, fpr: 0.00006, fnr: 0.00295, rec: 0.99705, prc: 0.99737, f1: 0.99721, f1_macro: 0.99858
# epoch: 23, passed number of graphs: 384, train running loss: 0.00053 (passed time: 2h 37m 30s)
#           acc: 0.99995, fpr: 0.00002, fnr: 0.00129, rec: 0.99871, prc: 0.99903, f1: 0.99887, f1_macro: 0.99942
# epoch: 23, passed number of graphs: 480, train running loss: 0.00051 (passed time: 2h 38m 18s)
#           acc: 0.99988, fpr: 0.00009, fnr: 0.00131, rec: 0.99869, prc: 0.99577, f1: 0.99723, f1_macro: 0.99858
# epoch: 23, passed number of graphs: 576, train running loss: 0.00049 (passed time: 2h 39m 7s)
#           acc: 0.99969, fpr: 0.00031, fnr: 0.00065, rec: 0.99935, prc: 0.98624, f1: 0.99275, f1_macro: 0.99630
# epoch: 23, passed number of graphs: 672, train running loss: 0.00054 (passed time: 2h 39m 55s)
#           acc: 0.99941, fpr: 0.00054, fnr: 0.00289, rec: 0.99711, prc: 0.97546, f1: 0.98616, f1_macro: 0.99293
# epoch: 23, passed number of graphs: 768, train running loss: 0.00059 (passed time: 2h 40m 43s)
#           acc: 0.99996, fpr: 0.00003, fnr: 0.00065, rec: 0.99935, prc: 0.99869, f1: 0.99902, f1_macro: 0.99950
# Validation --- epoch: 23, loss: 0.00126
#           prc: 0.99691, fpr: 0.00007, rec: 0.99198, fnr: 0.00802, f1: 0.99369, acc: 0.99976, f1_macro: 0.99678
# epoch: 24, passed number of graphs: 96, train running loss: 0.00045 (passed time: 2h 42m 5s)
#           acc: 0.99999, fpr: 0.00001, fnr: 0.00032, rec: 0.99968, prc: 0.99968, f1: 0.99968, f1_macro: 0.99984
# epoch: 24, passed number of graphs: 192, train running loss: 0.00057 (passed time: 2h 42m 53s)
#           acc: 0.99994, fpr: 0.00000, fnr: 0.00263, rec: 0.99737, prc: 1.00000, f1: 0.99868, f1_macro: 0.99933
# epoch: 24, passed number of graphs: 288, train running loss: 0.00052 (passed time: 2h 43m 41s)
#           acc: 0.99988, fpr: 0.00006, fnr: 0.00295, rec: 0.99705, prc: 0.99737, f1: 0.99721, f1_macro: 0.99858
# epoch: 24, passed number of graphs: 384, train running loss: 0.00053 (passed time: 2h 44m 30s)
#           acc: 0.99995, fpr: 0.00002, fnr: 0.00129, rec: 0.99871, prc: 0.99903, f1: 0.99887, f1_macro: 0.99942
# epoch: 24, passed number of graphs: 480, train running loss: 0.00051 (passed time: 2h 45m 18s)
#           acc: 0.99988, fpr: 0.00009, fnr: 0.00131, rec: 0.99869, prc: 0.99577, f1: 0.99723, f1_macro: 0.99858
# epoch: 24, passed number of graphs: 576, train running loss: 0.00049 (passed time: 2h 46m 6s)
#           acc: 0.99970, fpr: 0.00029, fnr: 0.00065, rec: 0.99935, prc: 0.98688, f1: 0.99307, f1_macro: 0.99646
# epoch: 24, passed number of graphs: 672, train running loss: 0.00054 (passed time: 2h 46m 55s)
#           acc: 0.99941, fpr: 0.00054, fnr: 0.00289, rec: 0.99711, prc: 0.97546, f1: 0.98616, f1_macro: 0.99293
# epoch: 24, passed number of graphs: 768, train running loss: 0.00059 (passed time: 2h 47m 43s)
#           acc: 0.99996, fpr: 0.00003, fnr: 0.00033, rec: 0.99967, prc: 0.99870, f1: 0.99918, f1_macro: 0.99958
# Validation --- epoch: 24, loss: 0.00128
#           prc: 0.99659, fpr: 0.00008, rec: 0.99222, fnr: 0.00778, f1: 0.99368, acc: 0.99976, f1_macro: 0.99678
# epoch: 25, passed number of graphs: 96, train running loss: 0.00045 (passed time: 2h 49m 5s)
#           acc: 0.99999, fpr: 0.00001, fnr: 0.00032, rec: 0.99968, prc: 0.99968, f1: 0.99968, f1_macro: 0.99984
# epoch: 25, passed number of graphs: 192, train running loss: 0.00057 (passed time: 2h 49m 53s)
#           acc: 0.99994, fpr: 0.00000, fnr: 0.00263, rec: 0.99737, prc: 1.00000, f1: 0.99868, f1_macro: 0.99933
# epoch: 25, passed number of graphs: 288, train running loss: 0.00052 (passed time: 2h 50m 42s)
#           acc: 0.99988, fpr: 0.00006, fnr: 0.00295, rec: 0.99705, prc: 0.99737, f1: 0.99721, f1_macro: 0.99858
# epoch: 25, passed number of graphs: 384, train running loss: 0.00053 (passed time: 2h 51m 30s)
#           acc: 0.99995, fpr: 0.00002, fnr: 0.00129, rec: 0.99871, prc: 0.99903, f1: 0.99887, f1_macro: 0.99942
# epoch: 25, passed number of graphs: 480, train running loss: 0.00051 (passed time: 2h 52m 18s)
#           acc: 0.99988, fpr: 0.00009, fnr: 0.00131, rec: 0.99869, prc: 0.99577, f1: 0.99723, f1_macro: 0.99858
# epoch: 25, passed number of graphs: 576, train running loss: 0.00048 (passed time: 2h 53m 7s)
#           acc: 0.99970, fpr: 0.00029, fnr: 0.00065, rec: 0.99935, prc: 0.98688, f1: 0.99307, f1_macro: 0.99646
# epoch: 25, passed number of graphs: 672, train running loss: 0.00054 (passed time: 2h 53m 55s)
#           acc: 0.99941, fpr: 0.00054, fnr: 0.00289, rec: 0.99711, prc: 0.97576, f1: 0.98632, f1_macro: 0.99301
# epoch: 25, passed number of graphs: 768, train running loss: 0.00059 (passed time: 2h 54m 44s)
#           acc: 0.99996, fpr: 0.00003, fnr: 0.00033, rec: 0.99967, prc: 0.99870, f1: 0.99918, f1_macro: 0.99958
# Validation --- epoch: 25, loss: 0.00127
#           prc: 0.99670, fpr: 0.00007, rec: 0.99203, fnr: 0.00797, f1: 0.99361, acc: 0.99976, f1_macro: 0.99674
# epoch: 26, passed number of graphs: 96, train running loss: 0.00055 (passed time: 2h 56m 5s)
#           acc: 0.99999, fpr: 0.00001, fnr: 0.00032, rec: 0.99968, prc: 0.99968, f1: 0.99968, f1_macro: 0.99984
# epoch: 26, passed number of graphs: 192, train running loss: 0.00060 (passed time: 2h 56m 54s)
#           acc: 0.99994, fpr: 0.00000, fnr: 0.00263, rec: 0.99737, prc: 1.00000, f1: 0.99868, f1_macro: 0.99933
# epoch: 26, passed number of graphs: 288, train running loss: 0.00054 (passed time: 2h 57m 42s)
#           acc: 0.99989, fpr: 0.00006, fnr: 0.00230, rec: 0.99770, prc: 0.99705, f1: 0.99738, f1_macro: 0.99866
# epoch: 26, passed number of graphs: 384, train running loss: 0.00053 (passed time: 2h 58m 30s)
#           acc: 0.99995, fpr: 0.00002, fnr: 0.00129, rec: 0.99871, prc: 0.99903, f1: 0.99887, f1_macro: 0.99942
# epoch: 26, passed number of graphs: 480, train running loss: 0.00051 (passed time: 2h 59m 19s)
#           acc: 0.99988, fpr: 0.00009, fnr: 0.00131, rec: 0.99869, prc: 0.99577, f1: 0.99723, f1_macro: 0.99858
# epoch: 26, passed number of graphs: 576, train running loss: 0.00048 (passed time: 3h 0m 7s)
#           acc: 0.99969, fpr: 0.00031, fnr: 0.00065, rec: 0.99935, prc: 0.98624, f1: 0.99275, f1_macro: 0.99630
# epoch: 26, passed number of graphs: 672, train running loss: 0.00053 (passed time: 3h 0m 55s)
# ...
# epoch: 42, passed number of graphs: 288, train running loss: 0.00050 (passed time: 4h 49m 48s)
#           acc: 0.99989, fpr: 0.00006, fnr: 0.00262, rec: 0.99738, prc: 0.99738, f1: 0.99738, f1_macro: 0.99866
# epoch: 42, passed number of graphs: 384, train running loss: 0.00050 (passed time: 4h 50m 36s)
#           acc: 0.99995, fpr: 0.00002, fnr: 0.00129, rec: 0.99871, prc: 0.99903, f1: 0.99887, f1_macro: 0.99942
# epoch: 42, passed number of graphs: 480, train running loss: 0.00048 (passed time: 4h 51m 25s)
#           acc: 0.99988, fpr: 0.00009, fnr: 0.00131, rec: 0.99869, prc: 0.99577, f1: 0.99723, f1_macro: 0.99858
# epoch: 42, passed number of graphs: 576, train running loss: 0.00047 (passed time: 4h 52m 13s)
#           acc: 0.99968, fpr: 0.00031, fnr: 0.00065, rec: 0.99935, prc: 0.98593, f1: 0.99259, f1_macro: 0.99622
# epoch: 42, passed number of graphs: 672, train running loss: 0.00051 (passed time: 4h 53m 1s)
#           acc: 0.99940, fpr: 0.00048, fnr: 0.00611, rec: 0.99389, prc: 0.97816, f1: 0.98596, f1_macro: 0.99283
# epoch: 42, passed number of graphs: 768, train running loss: 0.00056 (passed time: 4h 53m 50s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00163, rec: 0.99837, prc: 0.99902, f1: 0.99869, f1_macro: 0.99933
# Validation --- epoch: 42, loss: 0.00120
#           prc: 0.99804, fpr: 0.00004, rec: 0.99100, fnr: 0.00900, f1: 0.99377, acc: 0.99976, f1_macro: 0.99682
# epoch: 43, passed number of graphs: 96, train running loss: 0.00043 (passed time: 4h 55m 12s)
#           acc: 0.99999, fpr: 0.00001, fnr: 0.00032, rec: 0.99968, prc: 0.99968, f1: 0.99968, f1_macro: 0.99984
# epoch: 43, passed number of graphs: 192, train running loss: 0.00054 (passed time: 4h 56m 0s)
#           acc: 0.99994, fpr: 0.00000, fnr: 0.00263, rec: 0.99737, prc: 1.00000, f1: 0.99868, f1_macro: 0.99933
# epoch: 43, passed number of graphs: 288, train running loss: 0.00050 (passed time: 4h 56m 49s)
#           acc: 0.99989, fpr: 0.00006, fnr: 0.00262, rec: 0.99738, prc: 0.99738, f1: 0.99738, f1_macro: 0.99866
# epoch: 43, passed number of graphs: 384, train running loss: 0.00050 (passed time: 4h 57m 37s)
#           acc: 0.99995, fpr: 0.00002, fnr: 0.00129, rec: 0.99871, prc: 0.99903, f1: 0.99887, f1_macro: 0.99942
# epoch: 43, passed number of graphs: 480, train running loss: 0.00048 (passed time: 4h 58m 25s)
#           acc: 0.99988, fpr: 0.00009, fnr: 0.00131, rec: 0.99869, prc: 0.99577, f1: 0.99723, f1_macro: 0.99858
# epoch: 43, passed number of graphs: 576, train running loss: 0.00047 (passed time: 4h 59m 14s)
#           acc: 0.99968, fpr: 0.00031, fnr: 0.00065, rec: 0.99935, prc: 0.98593, f1: 0.99259, f1_macro: 0.99622
# epoch: 43, passed number of graphs: 672, train running loss: 0.00051 (passed time: 5h 0m 2s)
#           acc: 0.99940, fpr: 0.00048, fnr: 0.00611, rec: 0.99389, prc: 0.97816, f1: 0.98596, f1_macro: 0.99283
# epoch: 43, passed number of graphs: 768, train running loss: 0.00056 (passed time: 5h 0m 51s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00163, rec: 0.99837, prc: 0.99902, f1: 0.99869, f1_macro: 0.99933
# Validation --- epoch: 43, loss: 0.00120
#           prc: 0.99804, fpr: 0.00004, rec: 0.99100, fnr: 0.00900, f1: 0.99377, acc: 0.99976, f1_macro: 0.99682
# epoch: 44, passed number of graphs: 96, train running loss: 0.00043 (passed time: 5h 2m 13s)
#           acc: 0.99999, fpr: 0.00001, fnr: 0.00032, rec: 0.99968, prc: 0.99968, f1: 0.99968, f1_macro: 0.99984
# epoch: 44, passed number of graphs: 192, train running loss: 0.00054 (passed time: 5h 3m 1s)
#           acc: 0.99994, fpr: 0.00000, fnr: 0.00263, rec: 0.99737, prc: 1.00000, f1: 0.99868, f1_macro: 0.99933
# epoch: 44, passed number of graphs: 288, train running loss: 0.00050 (passed time: 5h 3m 49s)
#           acc: 0.99989, fpr: 0.00006, fnr: 0.00262, rec: 0.99738, prc: 0.99738, f1: 0.99738, f1_macro: 0.99866
# epoch: 44, passed number of graphs: 384, train running loss: 0.00050 (passed time: 5h 4m 38s)
#           acc: 0.99995, fpr: 0.00002, fnr: 0.00129, rec: 0.99871, prc: 0.99903, f1: 0.99887, f1_macro: 0.99942
# epoch: 44, passed number of graphs: 480, train running loss: 0.00048 (passed time: 5h 5m 26s)
#           acc: 0.99988, fpr: 0.00009, fnr: 0.00131, rec: 0.99869, prc: 0.99577, f1: 0.99723, f1_macro: 0.99858
# epoch: 44, passed number of graphs: 576, train running loss: 0.00047 (passed time: 5h 6m 15s)
#           acc: 0.99968, fpr: 0.00031, fnr: 0.00065, rec: 0.99935, prc: 0.98593, f1: 0.99259, f1_macro: 0.99622
# epoch: 44, passed number of graphs: 672, train running loss: 0.00051 (passed time: 5h 7m 3s)
#           acc: 0.99940, fpr: 0.00048, fnr: 0.00611, rec: 0.99389, prc: 0.97816, f1: 0.98596, f1_macro: 0.99283
# epoch: 44, passed number of graphs: 768, train running loss: 0.00056 (passed time: 5h 7m 51s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00163, rec: 0.99837, prc: 0.99902, f1: 0.99869, f1_macro: 0.99933
# Validation --- epoch: 44, loss: 0.00120
#           prc: 0.99804, fpr: 0.00004, rec: 0.99100, fnr: 0.00900, f1: 0.99377, acc: 0.99976, f1_macro: 0.99682
# epoch: 45, passed number of graphs: 96, train running loss: 0.00043 (passed time: 5h 9m 13s)
#           acc: 0.99999, fpr: 0.00001, fnr: 0.00032, rec: 0.99968, prc: 0.99968, f1: 0.99968, f1_macro: 0.99984
# epoch: 45, passed number of graphs: 192, train running loss: 0.00054 (passed time: 5h 10m 2s)
#           acc: 0.99994, fpr: 0.00000, fnr: 0.00263, rec: 0.99737, prc: 1.00000, f1: 0.99868, f1_macro: 0.99933
# epoch: 45, passed number of graphs: 288, train running loss: 0.00050 (passed time: 5h 10m 50s)
#           acc: 0.99989, fpr: 0.00006, fnr: 0.00262, rec: 0.99738, prc: 0.99738, f1: 0.99738, f1_macro: 0.99866
# epoch: 45, passed number of graphs: 384, train running loss: 0.00050 (passed time: 5h 11m 38s)
#           acc: 0.99995, fpr: 0.00002, fnr: 0.00129, rec: 0.99871, prc: 0.99903, f1: 0.99887, f1_macro: 0.99942
# epoch: 45, passed number of graphs: 480, train running loss: 0.00048 (passed time: 5h 12m 27s)
#           acc: 0.99988, fpr: 0.00009, fnr: 0.00131, rec: 0.99869, prc: 0.99577, f1: 0.99723, f1_macro: 0.99858
# epoch: 45, passed number of graphs: 576, train running loss: 0.00047 (passed time: 5h 13m 15s)
#           acc: 0.99968, fpr: 0.00031, fnr: 0.00065, rec: 0.99935, prc: 0.98593, f1: 0.99259, f1_macro: 0.99622
# epoch: 45, passed number of graphs: 672, train running loss: 0.00051 (passed time: 5h 14m 3s)
#           acc: 0.99940, fpr: 0.00048, fnr: 0.00611, rec: 0.99389, prc: 0.97816, f1: 0.98596, f1_macro: 0.99283
# epoch: 45, passed number of graphs: 768, train running loss: 0.00056 (passed time: 5h 14m 52s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00163, rec: 0.99837, prc: 0.99902, f1: 0.99869, f1_macro: 0.99933
# Validation --- epoch: 45, loss: 0.00120
#           prc: 0.99804, fpr: 0.00004, rec: 0.99100, fnr: 0.00900, f1: 0.99377, acc: 0.99976, f1_macro: 0.99682
# epoch: 46, passed number of graphs: 96, train running loss: 0.00043 (passed time: 5h 16m 14s)
#           acc: 0.99999, fpr: 0.00001, fnr: 0.00032, rec: 0.99968, prc: 0.99968, f1: 0.99968, f1_macro: 0.99984
# epoch: 46, passed number of graphs: 192, train running loss: 0.00054 (passed time: 5h 17m 2s)
#           acc: 0.99994, fpr: 0.00000, fnr: 0.00263, rec: 0.99737, prc: 1.00000, f1: 0.99868, f1_macro: 0.99933
# epoch: 46, passed number of graphs: 288, train running loss: 0.00050 (passed time: 5h 17m 51s)
#           acc: 0.99989, fpr: 0.00006, fnr: 0.00262, rec: 0.99738, prc: 0.99738, f1: 0.99738, f1_macro: 0.99866
# epoch: 46, passed number of graphs: 384, train running loss: 0.00050 (passed time: 5h 18m 39s)
#           acc: 0.99995, fpr: 0.00002, fnr: 0.00129, rec: 0.99871, prc: 0.99903, f1: 0.99887, f1_macro: 0.99942
# epoch: 46, passed number of graphs: 480, train running loss: 0.00048 (passed time: 5h 19m 27s)
#           acc: 0.99988, fpr: 0.00009, fnr: 0.00131, rec: 0.99869, prc: 0.99577, f1: 0.99723, f1_macro: 0.99858
# epoch: 46, passed number of graphs: 576, train running loss: 0.00047 (passed time: 5h 20m 16s)
#           acc: 0.99968, fpr: 0.00031, fnr: 0.00065, rec: 0.99935, prc: 0.98593, f1: 0.99259, f1_macro: 0.99622
# epoch: 46, passed number of graphs: 672, train running loss: 0.00051 (passed time: 5h 21m 4s)
#           acc: 0.99940, fpr: 0.00048, fnr: 0.00611, rec: 0.99389, prc: 0.97816, f1: 0.98596, f1_macro: 0.99283
# epoch: 46, passed number of graphs: 768, train running loss: 0.00056 (passed time: 5h 21m 53s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00163, rec: 0.99837, prc: 0.99902, f1: 0.99869, f1_macro: 0.99933
# Validation --- epoch: 46, loss: 0.00120
#           prc: 0.99804, fpr: 0.00004, rec: 0.99100, fnr: 0.00900, f1: 0.99377, acc: 0.99976, f1_macro: 0.99682
# epoch: 47, passed number of graphs: 96, train running loss: 0.00043 (passed time: 5h 23m 15s)
#           acc: 0.99999, fpr: 0.00001, fnr: 0.00032, rec: 0.99968, prc: 0.99968, f1: 0.99968, f1_macro: 0.99984
# epoch: 47, passed number of graphs: 192, train running loss: 0.00054 (passed time: 5h 24m 3s)
#           acc: 0.99994, fpr: 0.00000, fnr: 0.00263, rec: 0.99737, prc: 1.00000, f1: 0.99868, f1_macro: 0.99933
# epoch: 47, passed number of graphs: 288, train running loss: 0.00050 (passed time: 5h 24m 51s)
#           acc: 0.99989, fpr: 0.00006, fnr: 0.00262, rec: 0.99738, prc: 0.99738, f1: 0.99738, f1_macro: 0.99866
# epoch: 47, passed number of graphs: 384, train running loss: 0.00050 (passed time: 5h 25m 40s)
#           acc: 0.99995, fpr: 0.00002, fnr: 0.00129, rec: 0.99871, prc: 0.99903, f1: 0.99887, f1_macro: 0.99942
# epoch: 47, passed number of graphs: 480, train running loss: 0.00048 (passed time: 5h 26m 28s)
#           acc: 0.99988, fpr: 0.00009, fnr: 0.00131, rec: 0.99869, prc: 0.99577, f1: 0.99723, f1_macro: 0.99858
# epoch: 47, passed number of graphs: 576, train running loss: 0.00047 (passed time: 5h 27m 16s)
#           acc: 0.99968, fpr: 0.00031, fnr: 0.00065, rec: 0.99935, prc: 0.98593, f1: 0.99259, f1_macro: 0.99622
# epoch: 47, passed number of graphs: 672, train running loss: 0.00051 (passed time: 5h 28m 5s)
#           acc: 0.99940, fpr: 0.00048, fnr: 0.00611, rec: 0.99389, prc: 0.97816, f1: 0.98596, f1_macro: 0.99283
# epoch: 47, passed number of graphs: 768, train running loss: 0.00056 (passed time: 5h 28m 53s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00163, rec: 0.99837, prc: 0.99902, f1: 0.99869, f1_macro: 0.99933
# Validation --- epoch: 47, loss: 0.00120
#           prc: 0.99804, fpr: 0.00004, rec: 0.99100, fnr: 0.00900, f1: 0.99377, acc: 0.99976, f1_macro: 0.99682
# epoch: 48, passed number of graphs: 96, train running loss: 0.00043 (passed time: 5h 30m 15s)
#           acc: 0.99999, fpr: 0.00001, fnr: 0.00032, rec: 0.99968, prc: 0.99968, f1: 0.99968, f1_macro: 0.99984
# epoch: 48, passed number of graphs: 192, train running loss: 0.00054 (passed time: 5h 31m 3s)
#           acc: 0.99994, fpr: 0.00000, fnr: 0.00263, rec: 0.99737, prc: 1.00000, f1: 0.99868, f1_macro: 0.99933
# epoch: 48, passed number of graphs: 288, train running loss: 0.00050 (passed time: 5h 31m 52s)
#           acc: 0.99989, fpr: 0.00006, fnr: 0.00262, rec: 0.99738, prc: 0.99738, f1: 0.99738, f1_macro: 0.99866
# epoch: 48, passed number of graphs: 384, train running loss: 0.00050 (passed time: 5h 32m 40s)
#           acc: 0.99995, fpr: 0.00002, fnr: 0.00129, rec: 0.99871, prc: 0.99903, f1: 0.99887, f1_macro: 0.99942
# epoch: 48, passed number of graphs: 480, train running loss: 0.00048 (passed time: 5h 33m 28s)
#           acc: 0.99988, fpr: 0.00009, fnr: 0.00131, rec: 0.99869, prc: 0.99577, f1: 0.99723, f1_macro: 0.99858
# epoch: 48, passed number of graphs: 576, train running loss: 0.00047 (passed time: 5h 34m 17s)
#           acc: 0.99968, fpr: 0.00031, fnr: 0.00065, rec: 0.99935, prc: 0.98593, f1: 0.99259, f1_macro: 0.99622
# epoch: 48, passed number of graphs: 672, train running loss: 0.00051 (passed time: 5h 35m 5s)
#           acc: 0.99940, fpr: 0.00048, fnr: 0.00611, rec: 0.99389, prc: 0.97816, f1: 0.98596, f1_macro: 0.99283
# epoch: 48, passed number of graphs: 768, train running loss: 0.00056 (passed time: 5h 35m 54s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00163, rec: 0.99837, prc: 0.99902, f1: 0.99869, f1_macro: 0.99933
# Validation --- epoch: 48, loss: 0.00120
#           prc: 0.99804, fpr: 0.00004, rec: 0.99100, fnr: 0.00900, f1: 0.99377, acc: 0.99976, f1_macro: 0.99682
# epoch: 49, passed number of graphs: 96, train running loss: 0.00043 (passed time: 5h 37m 16s)
#           acc: 0.99999, fpr: 0.00001, fnr: 0.00032, rec: 0.99968, prc: 0.99968, f1: 0.99968, f1_macro: 0.99984
# epoch: 49, passed number of graphs: 192, train running loss: 0.00054 (passed time: 5h 38m 4s)
#           acc: 0.99994, fpr: 0.00000, fnr: 0.00263, rec: 0.99737, prc: 1.00000, f1: 0.99868, f1_macro: 0.99933
# epoch: 49, passed number of graphs: 288, train running loss: 0.00050 (passed time: 5h 38m 52s)
#           acc: 0.99989, fpr: 0.00006, fnr: 0.00262, rec: 0.99738, prc: 0.99738, f1: 0.99738, f1_macro: 0.99866
# epoch: 49, passed number of graphs: 384, train running loss: 0.00050 (passed time: 5h 39m 41s)
#           acc: 0.99995, fpr: 0.00002, fnr: 0.00129, rec: 0.99871, prc: 0.99903, f1: 0.99887, f1_macro: 0.99942
# epoch: 49, passed number of graphs: 480, train running loss: 0.00048 (passed time: 5h 40m 29s)
#           acc: 0.99988, fpr: 0.00009, fnr: 0.00131, rec: 0.99869, prc: 0.99577, f1: 0.99723, f1_macro: 0.99858
# epoch: 49, passed number of graphs: 576, train running loss: 0.00047 (passed time: 5h 41m 17s)
#           acc: 0.99968, fpr: 0.00031, fnr: 0.00065, rec: 0.99935, prc: 0.98593, f1: 0.99259, f1_macro: 0.99622
# epoch: 49, passed number of graphs: 672, train running loss: 0.00051 (passed time: 5h 42m 6s)
#           acc: 0.99940, fpr: 0.00048, fnr: 0.00611, rec: 0.99389, prc: 0.97816, f1: 0.98596, f1_macro: 0.99283
# epoch: 49, passed number of graphs: 768, train running loss: 0.00056 (passed time: 5h 42m 54s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00163, rec: 0.99837, prc: 0.99902, f1: 0.99869, f1_macro: 0.99933
# Validation --- epoch: 49, loss: 0.00120
#           prc: 0.99804, fpr: 0.00004, rec: 0.99100, fnr: 0.00900, f1: 0.99377, acc: 0.99976, f1_macro: 0.99682
# epoch: 50, passed number of graphs: 96, train running loss: 0.00043 (passed time: 5h 44m 16s)
#           acc: 0.99999, fpr: 0.00001, fnr: 0.00032, rec: 0.99968, prc: 0.99968, f1: 0.99968, f1_macro: 0.99984
# epoch: 50, passed number of graphs: 192, train running loss: 0.00054 (passed time: 5h 45m 5s)
#           acc: 0.99994, fpr: 0.00000, fnr: 0.00263, rec: 0.99737, prc: 1.00000, f1: 0.99868, f1_macro: 0.99933
# epoch: 50, passed number of graphs: 288, train running loss: 0.00050 (passed time: 5h 45m 53s)
#           acc: 0.99989, fpr: 0.00006, fnr: 0.00262, rec: 0.99738, prc: 0.99738, f1: 0.99738, f1_macro: 0.99866
# epoch: 50, passed number of graphs: 384, train running loss: 0.00050 (passed time: 5h 46m 41s)
#           acc: 0.99995, fpr: 0.00002, fnr: 0.00129, rec: 0.99871, prc: 0.99903, f1: 0.99887, f1_macro: 0.99942
# epoch: 50, passed number of graphs: 480, train running loss: 0.00048 (passed time: 5h 47m 29s)
#           acc: 0.99988, fpr: 0.00009, fnr: 0.00131, rec: 0.99869, prc: 0.99577, f1: 0.99723, f1_macro: 0.99858
# epoch: 50, passed number of graphs: 576, train running loss: 0.00047 (passed time: 5h 48m 18s)
#           acc: 0.99968, fpr: 0.00031, fnr: 0.00065, rec: 0.99935, prc: 0.98593, f1: 0.99259, f1_macro: 0.99622
# epoch: 50, passed number of graphs: 672, train running loss: 0.00051 (passed time: 5h 49m 6s)
#           acc: 0.99940, fpr: 0.00048, fnr: 0.00611, rec: 0.99389, prc: 0.97816, f1: 0.98596, f1_macro: 0.99283
# epoch: 50, passed number of graphs: 768, train running loss: 0.00056 (passed time: 5h 49m 55s)
#           acc: 0.99994, fpr: 0.00002, fnr: 0.00163, rec: 0.99837, prc: 0.99902, f1: 0.99869, f1_macro: 0.99933
# Validation --- epoch: 50, loss: 0.00120
#           prc: 0.99804, fpr: 0.00004, rec: 0.99100, fnr: 0.00900, f1: 0.99377, acc: 0.99976, f1_macro: 0.99682
# ************ best model obtained after epoch 26, saved at ./saved_models/GIN_25: 0.9938025280955806.pt ************
# Testing --- loss: 0.00080
#           prc: 0.99617, fpr: 0.00009, rec: 0.99528, fnr: 0.00472, f1: 0.99550, acc: 0.99981, f1_macro: 0.99770

# %%
# !zip -r /content/GATv2Conv_p2p_normalization.zip /content/saved_models

# %%
from google.colab import files
files.download("/content/GATv2Conv_p2p_normalization.zip")

# %%
# from google.colab import runtime
# runtime.unassign()
