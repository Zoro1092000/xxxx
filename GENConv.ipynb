# %% [markdown]
# <a href="https://colab.research.google.com/github/Zoro1092000/xxxx/blob/main/GENConv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # I. Pip & Import.

# %%
import os
import os.path as osp
import torch
import sys

os.environ['TORCH'] = torch.__version__

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install torch-geometric
# !pip install torch-cluster -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install deepdish==0.3.5
# !pip install torch-optimizer

import torch.nn as nn
from torch.nn import Parameter
from torch_geometric.utils import scatter
from torch_geometric.nn.inits import glorot, zeros
from torch_scatter import scatter_add
from torch.utils.data import DataLoader, Dataset
import torch_optimizer as optimization


from itertools import chain
import pickle
import h5py
import deepdish as dd
import numpy as np
from tqdm import tqdm
import inspect
import time
import math
import random
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-geometric in /usr/local/lib/python3.7/dist-packages (2.1.0.post1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.7.3)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (3.0.9)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.0.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.11.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.21.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (4.64.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.23.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->torch-geometric) (2.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (2.10)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric) (3.1.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://data.pyg.org/whl/torch-1.12.1+cu113.html
# Requirement already satisfied: torch-cluster in /usr/local/lib/python3.7/dist-packages (1.6.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: deepdish==0.3.5 in /usr/local/lib/python3.7/dist-packages (0.3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.21.6)
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (3.7.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.7.3)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (2.8.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tables->deepdish==0.3.5) (3.0.9)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-optimizer in /usr/local/lib/python3.7/dist-packages (0.3.0)
# Requirement already satisfied: torch>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from torch-optimizer) (1.12.1+cu113)
# Requirement already satisfied: pytorch-ranger>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from torch-optimizer) (0.1.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.5.0->torch-optimizer) (4.1.1)

# %%
def time_since(start):
    now = time.time()
    s = now - start
    m = math.floor(s / 60)
    s -= m * 60
    h = math.floor(m / 60)
    m -= h * 60
    if h == 0:
        if m == 0:
            return '%ds' % s
        else:
            return '%dm %ds' % (m, s)
    else:
        return '%dh %dm %ds' % (h, m, s)

# %% [markdown]
# # II. Data

# %%
# Data utils
def h5group_to_dict(h5group):
    group_dict = {k: v[()] for k, v in chain(h5group.items(), h5group.attrs.items())}
    return group_dict

def sub_dict(full_dict, *keys, to_tensor):
    return {k: torch.tensor(full_dict[k]) if to_tensor else full_dict[k] for k in keys if k in full_dict}

def build_graph_from_dict_pyg(graph_dict, to_tensor=True):
    from torch_geometric.data import Data

    g = Data(**sub_dict(graph_dict, 'edge_index', 'x', 'y', 'edge_attr', 'edge_y', to_tensor=to_tensor))
    return g

# Data loader
class GraphDataLoader(DataLoader):
    def __init__(self, dataset, batch_size=128, shuffle=False, num_workers=0):

        def collate_graph(graph_obj_list):
            from torch_geometric.data import Batch
            batch = Batch.from_data_list(graph_obj_list)
            return batch

        super().__init__(
            dataset,
            batch_size=batch_size,
            shuffle=shuffle,
            collate_fn=collate_graph,
            num_workers=num_workers)

# BotnetDataset
class BotnetDataset(Dataset):

    def __init__(self, name='chord', root='data/botnet', split='train', graph_format='pyg', split_idx=None, add_nfeat_ones=True,
                 in_memory=True):
        super().__init__()
        assert name in ['chord', 'debru', 'kadem', 'leet', 'c2', 'p2p']
        assert split in ['train', 'val', 'test']

        if isinstance(root, str):
            root = osp.expanduser(osp.normpath(root))

        self.name = name
        self.root = root
        self.split = split
        self.split_idx = split_idx
        self.add_nfeat_ones = add_nfeat_ones

        self._graph_format = graph_format
        if split == 'train':
            self.path = self.processed_paths[0]
            self.num_graphs = 768
        elif split == 'val':
            self.path = self.processed_paths[1]
            self.num_graphs = 96
        elif split == 'test':
            self.path = self.processed_paths[2]
            self.num_graphs = 96

        if in_memory:
            self.data = dd.io.load(self.path)  # dictionary
            self.data_type = 'dict'
        else:
            # self.data = h5py.File(self.path, 'r')
            self.data = None    # defer opening file in each process to make multiprocessing work
            self.data_type = 'file'
            
    @property
    def processed_dir(self):
        return osp.join(self.root, 'processed')

    @property
    def processed_file_names(self):
        return [self.name + '_' + s + '.hdf5' for s in ('train', 'val', 'test')]

    @property
    def processed_paths(self):
        return [osp.join(self.processed_dir, f) for f in self.processed_file_names]

    def __len__(self):
        return self.num_graphs

    def __getitem__(self, index):
        if self.data_type == 'dict':
            graph_dict = self.data[str(index)]
        elif self.data_type == 'file':
            if self.data is None:
                # only open once in each process
                self.data = h5py.File(self.path, 'r')
            graph_dict = h5group_to_dict(self.data[str(index)])
        else:
            raise ValueError

        # graph_format == 'pyg':
        return build_graph_from_dict_pyg(graph_dict)


    def __iter__(self):
        for i in range(self.num_graphs):
            yield self[i]

    def __repr__(self):
        return f'{self.__class__.__name__}(topology: {self.name} | split: {self.split} | ' \
               f'#graphs: {len(self)} | graph format: {self.graph_format})'

# %% [markdown]
# # III. Measure Performancce

# %% [markdown]
# ## 3.1. Metrics

# %%
def f1(target, pred, label):
    # F1 = 2 * (precision * recall) / (precision + recall)
    tp = np.sum((target==label) & (pred==label))
    fp = np.sum((target!=label) & (pred==label))
    fn = np.sum((pred!=label) & (target==label))
    
    if tp+fp==0 or tp+fn==0:
      return np.nan

    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    
    if precision+recall==0:
      return np.nan
      
    f1 = 2 * (precision * recall) / (precision + recall)
    return f1

def f1_macro(pred, target):
    return np.mean([f1(target, pred, label) for label in range(0, 2)])


def accuracy(pred, target):
    return (pred == target).sum().item() / len(target)


def true_positive(pred, target):
    return (target[pred == 1] == 1).sum().item()


def false_positive(pred, target):
    return (target[pred == 1] == 0).sum().item()


def true_negative(pred, target):
    return (target[pred == 0] == 0).sum().item()


def false_negative(pred, target):
    return (target[pred == 0] == 1).sum().item()


def recall(pred, target):
    try:
        return true_positive(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1


def precision(pred, target):
    try:
        prec = true_positive(pred, target) / (pred == 1).sum().item()
        return prec
    except:  # divide by zero
        return -1


def f1_score(pred, target):
    prec = precision(pred, target)
    rec = recall(pred, target)
    try:
        return 2 * (prec * rec) / (prec + rec)
    except:
        return 0


def false_positive_rate(pred, target):
    try:
        return false_positive(pred, target) / (target == 0).sum().item()
    except:  # divide by zero
        return -1


def false_negative_rate(pred, target):
    try:
        return false_negative(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1

# %% [markdown]
# ## 3.2. Evaluation

# %%
def eval_metrics(target, pred_prob, threshold=0.5):
    if isinstance(target, torch.Tensor):
        target = target.cpu().numpy()
    if isinstance(pred_prob, torch.Tensor):
        pred_prob = pred_prob.cpu().numpy()

    pred = (pred_prob >= threshold).astype(int)

    acc = accuracy(pred, target)
    fpr = false_positive_rate(pred, target)
    fnr = false_negative_rate(pred, target)
    rec = recall(pred, target)
    prc = precision(pred, target)
    f1 = f1_score(pred, target)
    f1macro = f1_macro(pred, target)
    result_dict = {'acc': acc, 'fpr': fpr, 'fnr': fnr, 'rec': rec, 'prc': prc, 'f1': f1, 'f1_macro': f1macro}

    return result_dict


def dict_value_add(dict1, dict2):
    result = {key: dict1.get(key, 0) + dict2.get(key, 0)
              for key in set(dict1) | set(dict2)}
    return result


def dict_value_div(dict, n):
    result = {key: value / n for key, value in dict.items()}
    return result


def eval_predictor(dataset, predictor):
    result_dict_avg = {}
    loss_avg = 0

    for data in dataset:
        # prediction
        try:
            pred_prob, loss = predictor(data)
            loss_avg += loss
        except ValueError:  # if "too many values to unpack"
            pred_prob = predictor(data)

        # get the ground truth target
        # graph_format == 'pyg':
        target = data.y

        # compute the evaluation metrics
        result_dict = eval_metrics(target, pred_prob)

        result_dict_avg = dict_value_add(result_dict_avg, result_dict)

    # average the metrics across all graphs in the dataset as final results
    result_dict_avg = dict_value_div(result_dict_avg, len(dataset))
    loss_avg = loss_avg / len(dataset)

    return result_dict_avg, loss_avg


# =================================================================================================================
# some examples of the 'predictor' model wrapper to be fed into the above evaluation function (for PyG Data format)
# =================================================================================================================
class PygRandomPredictor:
    def __init__(self):
        # torch.manual_seed(0)
        pass

    def __call__(self, data):
        pred_prob = torch.rand(len(data.y))
        return pred_prob


class PygModelPredictor:
    def __init__(self, model, loss_fcn=torch.nn.CrossEntropyLoss()):
        self.model = model
        self.loss_fcn = loss_fcn
        self.device = next(model.parameters()).device

    def __call__(self, data):
        self.model.eval()
        data = data.to(self.device)
        with torch.no_grad():
            # custom the below line to adjust to your model's input format for forward pass
            out = self.model(data.x, data.edge_index)
            loss = self.loss_fcn(out, data.y.long())
            pred_prob = torch.softmax(out, dim=1)[:, 1]
        return pred_prob, loss.float()

# %% [markdown]
# # IV. Model

# %% [markdown]
# ## 5.1. Activation

# %%
def activation(act, negative_slope=0.2):
    activations = nn.ModuleDict([
        ['lrelu', nn.LeakyReLU(negative_slope)],
        ['relu', nn.ReLU()],
        ['elu', nn.ELU()],
        ['none', nn.Identity()],
    ])
    return activations[act]

# %% [markdown]
# ## 5.2. GIN model

# %%
from torch.nn.modules.activation import LeakyReLU
import torch.nn as nn

class GINModel(nn.Module):
    def __init__(self, dim_input_feature, dim_hidden_feature, num_layers, num_classes, non_linear='relu', dropout=0.2):
        super().__init__()

        self.dim_input_feature = dim_input_feature
        self.dim_hidden_feature = dim_hidden_feature

        self.num_layers = num_layers
        self.num_classes = num_classes
        
        from torch.nn import Linear, Sequential, BatchNorm1d, ReLU, Dropout
        from torch_geometric.nn import GATv2Conv, GINConv, TransformerConv, GENConv
        
        self.gin_net = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.gin_net.append(GENConv(self.dim_input_feature, self.dim_hidden_feature, aggr='powermean'))
          else:
            self.gin_net.append(GENConv(self.dim_hidden_feature, self.dim_hidden_feature, aggr='powermean'))


        self.dropout = nn.Dropout(dropout)

        self.residuals = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.residuals.append(nn.Linear(self.dim_input_feature, self.dim_hidden_feature, bias=True))
          else:
            self.residuals.append(nn.Identity())

        self.num_residuals = len(self.residuals)

        self.non_linear = activation(non_linear)

        # self.final_type == 'proj':
        self.final = nn.Linear(self.dim_hidden_feature, num_classes)

    def reset_parameters(self):
        for net in self.gin_net:
            net.reset_parameters()
        # self.residual_hop = 1
        for net in self.residuals:
            net.reset_parameters()
        # self.final_type != 'none':
        self.final.reset_parameters()

    def forward(self, x, edge_index):
        xr = None
        add_xr_at = -1

        for n, net in enumerate(self.gin_net):
            # pass to a GIN layer with non-linear activation
            xo = net(x, edge_index)
            xo = self.dropout(xo)
            # deal with residual connections
            # self.residual_hop = 1
            if n < self.num_residuals:
                xr = self.residuals[n](x)
                xo = self.non_linear(xo + xr)

            x = xo
        # size of x: (B * N, dim_hidden_feature) -> (B * N, num_classes)
        x = self.final(x)

        return x

# %% [markdown]
# # V. Load data

# %%
data_dir = '/content/drive/Shareddrives/botnetdata/p2p_6k_feat_norm'
data_name = 'p2p' # 'chord', 'debru', 'kadem', 'leet', 'c2', 'p2p'
shuffle = False

# ========== load the dataset
print('loading dataset...')

train_ds = BotnetDataset(name=data_name, root=data_dir, split='train',
                         in_memory=False, graph_format='pyg')
val_ds = BotnetDataset(name=data_name, root=data_dir, split='val',
                       in_memory=False, graph_format='pyg')
test_ds = BotnetDataset(name=data_name, root=data_dir, split='test',
                        in_memory=False, graph_format='pyg')
# Out:
# loading dataset...

# %%
batch_size = 1
train_loader = GraphDataLoader(train_ds, batch_size=batch_size, shuffle=bool(shuffle), num_workers=0)

# %% [markdown]
# # VI. Train

# %%
# ============== some default parameters =============
devid = 0
seed = 0
logmode = 'w'
log_interval = 96

dim_input_feature = 1
dim_hidden_feature = 32
act = 'relu' # 'none', 'lrelu', 'relu', 'elu'

num_layers = 12
num_classes = 2 

dropout = 0.0
bias = True

lr = 0.005 # learning rate
weight_decay = 5e-4
epochs = 50
save_dir = './saved_models'
save_name = "GIN_model.pt"
# ====================================================

def train(model, train_loader, val_dataset, test_dataset, optimizer, scheduler=None):
    device = next(model.parameters()).device
    predictor = PygModelPredictor(model)

    best_epoch = 0
    max_f1_score = 0
    start = time.time()
    for ep in range(epochs):
        loss_avg_train = 0
        num_train_graph = 0
        model.train()
        for n, batch in enumerate(train_loader):
            batch.to(device)

            optimizer.zero_grad()

            x = model(batch.x, batch.edge_index)
            loss = criterion(x, batch.y.long())

            loss_avg_train += float(loss)
            num_train_graph += batch.num_graphs

            loss.backward()
            optimizer.step()

            if num_train_graph % log_interval == 0 or n == len(train_loader) - 1:
                with torch.no_grad():
                    # pred = x.argmax(dim=1)
                    pred_prob = torch.softmax(x, dim=1)[:, 1]
                    y = batch.y.long()
                    result_dict = eval_metrics(y, pred_prob)
                print(f'epoch: {ep + 1}, passed number of graphs: {num_train_graph}, '
                        f'train running loss: {loss_avg_train / num_train_graph:.5f} (passed time: {time_since(start)})')
                print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict.items()]))

        result_dict_avg, loss_avg = eval_predictor(val_dataset, predictor)
        print(f'Validation --- epoch: {ep + 1}, loss: {loss_avg:.5f}')
        print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))

        if scheduler is not None:
            scheduler.step(loss_avg)

        if result_dict_avg['f1'] > max_f1_score:
            save_name = f"GIN_{ep}: {result_dict_avg['f1']}.pt"
            torch.save(model, os.path.join(save_dir, save_name))
            print(f'Better model saved at {os.path.join(save_dir, save_name)}.')
            best_epoch = ep
            max_f1_score = result_dict_avg['f1']

    best_model = torch.load(os.path.join(save_dir, save_name))
    print('*' * 12 + f' best model obtained after epoch {best_epoch + 1}, '
                       f'saved at {os.path.join(save_dir, save_name)} ' + '*' * 12)
    
    predictor = PygModelPredictor(best_model)

    result_dict_avg, loss_avg = eval_predictor(test_dataset, predictor)
    print(f'Testing --- loss: {loss_avg:.5f}')
    print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))


if __name__ == '__main__':
    os.makedirs(save_dir, exist_ok=True)

    # ========== random seeds and device
    random.seed(seed)
    torch.manual_seed(seed)

    device = torch.device(f'cuda:{devid}') if devid > -1 else torch.device('cpu')

    # ========== logging setup
    log_name = os.path.splitext(save_name)[0]
    # logger = logging_config(__name__, folder=save_dir, name=log_name, filemode=logmode)
    # logger = logging_config(os.path.basename(__file__), folder=save_dir, name=log_name, filemode=logmode)

    print('python ' + ' '.join(sys.argv))
    print('-' * 30)
    #logger.info(args)
    print('-' * 30)
    print(time.ctime())
    print('-' * 30)

    # ========== define the model, optimizer, and loss

    model = GINModel(dim_input_feature,
                     dim_hidden_feature,
                     num_layers,
                     num_classes,
                     non_linear=act,
                     dropout=dropout)

    print('model ' + '-' * 10)
    print(repr(model))
    model.to(device)

    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.25, patience=1)

    # ========== train the model
    print(f"Batch size: {batch_size}")
    train(model, train_loader, val_ds, test_ds, optimizer, scheduler)
# Out:
# python /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-203ffb24-228b-4198-8d93-25fd17473122.json
# ------------------------------
# ------------------------------
# Thu Nov  3 15:59:10 2022
# ------------------------------
# model ----------
# GINModel(
#   (gin_net): ModuleList(
#     (0): GENConv(1, 32, aggr=powermean)
#     (1): GENConv(32, 32, aggr=powermean)
#     (2): GENConv(32, 32, aggr=powermean)
#     (3): GENConv(32, 32, aggr=powermean)
#     (4): GENConv(32, 32, aggr=powermean)
#     (5): GENConv(32, 32, aggr=powermean)
#     (6): GENConv(32, 32, aggr=powermean)
#     (7): GENConv(32, 32, aggr=powermean)
#     (8): GENConv(32, 32, aggr=powermean)
#     (9): GENConv(32, 32, aggr=powermean)
#     (10): GENConv(32, 32, aggr=powermean)
#     (11): GENConv(32, 32, aggr=powermean)
#   )
#   (dropout): Dropout(p=0.0, inplace=False)
#   (residuals): ModuleList(
#     (0): Linear(in_features=1, out_features=32, bias=True)
#     (1): Identity()
#     (2): Identity()
#     (3): Identity()
#     (4): Identity()
#     (5): Identity()
#     (6): Identity()
#     (7): Identity()
#     (8): Identity()
#     (9): Identity()
#     (10): Identity()
#     (11): Identity()
#   )
#   (non_linear): ReLU()
#   (final): Linear(in_features=32, out_features=2, bias=True)
# )
# Batch size: 1
# epoch: 1, passed number of graphs: 96, train running loss: 0.13283 (passed time: 1m 20s)
#           acc: 0.95346, fpr: 0.01055, fnr: 0.86762, rec: 0.13238, prc: 0.35478, f1: 0.19282, f1_macro: 0.58443
# epoch: 1, passed number of graphs: 192, train running loss: 0.08878 (passed time: 1m 50s)
#           acc: 0.99534, fpr: 0.00185, fnr: 0.06940, rec: 0.93060, prc: 0.95619, f1: 0.94322, f1_macro: 0.97040
# epoch: 1, passed number of graphs: 288, train running loss: 0.06433 (passed time: 2m 20s)
#           acc: 0.99538, fpr: 0.00206, fnr: 0.06474, rec: 0.93526, prc: 0.95081, f1: 0.94297, f1_macro: 0.97028
# epoch: 1, passed number of graphs: 384, train running loss: 0.06161 (passed time: 2m 51s)
#           acc: 0.96808, fpr: 0.00549, fnr: 0.61267, rec: 0.38733, prc: 0.76252, f1: 0.51371, f1_macro: 0.74861
# epoch: 1, passed number of graphs: 480, train running loss: 0.05452 (passed time: 3m 25s)
#           acc: 0.99740, fpr: 0.00066, fnr: 0.04653, rec: 0.95347, prc: 0.98472, f1: 0.96884, f1_macro: 0.98374
# epoch: 1, passed number of graphs: 576, train running loss: 0.04790 (passed time: 3m 55s)
#           acc: 0.99231, fpr: 0.00013, fnr: 0.17877, rec: 0.82123, prc: 0.99641, f1: 0.90038, f1_macro: 0.94819
# epoch: 1, passed number of graphs: 672, train running loss: 0.04295 (passed time: 4m 25s)
#           acc: 0.99436, fpr: 0.00367, fnr: 0.05078, rec: 0.94922, prc: 0.91834, f1: 0.93353, f1_macro: 0.96529
# epoch: 1, passed number of graphs: 768, train running loss: 0.03896 (passed time: 4m 57s)
#           acc: 0.99818, fpr: 0.00024, fnr: 0.03768, rec: 0.96232, prc: 0.99434, f1: 0.97807, f1_macro: 0.98856
# Validation --- epoch: 1, loss: 0.16175
#           prc: -0.71875, fnr: 1.00000, f1: 0.00000, acc: 0.97847, rec: 0.00000, fpr: 0.00001, f1_macro: nan
# epoch: 2, passed number of graphs: 96, train running loss: 0.01007 (passed time: 5m 56s)
#           acc: 0.99900, fpr: 0.00015, fnr: 0.02044, rec: 0.97956, prc: 0.99653, f1: 0.98797, f1_macro: 0.99373
# epoch: 2, passed number of graphs: 192, train running loss: 0.01328 (passed time: 6m 24s)
#           acc: 0.99667, fpr: 0.00127, fnr: 0.05084, rec: 0.94916, prc: 0.97009, f1: 0.95951, f1_macro: 0.97889
# epoch: 2, passed number of graphs: 288, train running loss: 0.01775 (passed time: 6m 52s)
#           acc: 0.99756, fpr: 0.00001, fnr: 0.05957, rec: 0.94043, prc: 0.99965, f1: 0.96913, f1_macro: 0.98393
# epoch: 2, passed number of graphs: 384, train running loss: 0.01650 (passed time: 7m 23s)
#           acc: 0.99864, fpr: 0.00004, fnr: 0.03053, rec: 0.96947, prc: 0.99915, f1: 0.98409, f1_macro: 0.99169
# epoch: 2, passed number of graphs: 480, train running loss: 0.01470 (passed time: 7m 51s)
#           acc: 0.99875, fpr: 0.00003, fnr: 0.02875, rec: 0.97125, prc: 0.99932, f1: 0.98508, f1_macro: 0.99222
# epoch: 2, passed number of graphs: 576, train running loss: 0.01459 (passed time: 8m 18s)
#           acc: 0.98822, fpr: 0.00964, fnr: 0.06030, rec: 0.93970, prc: 0.81167, f1: 0.87100, f1_macro: 0.93241
# epoch: 2, passed number of graphs: 672, train running loss: 0.01394 (passed time: 8m 46s)
#           acc: 0.99585, fpr: 0.00357, fnr: 0.01763, rec: 0.98237, prc: 0.92299, f1: 0.95176, f1_macro: 0.97479
# epoch: 2, passed number of graphs: 768, train running loss: 0.01448 (passed time: 9m 14s)
#           acc: 0.99254, fpr: 0.00487, fnr: 0.06624, rec: 0.93376, prc: 0.89413, f1: 0.91352, f1_macro: 0.95481
# Validation --- epoch: 2, loss: 0.13128
#           prc: -0.53356, fnr: 0.99998, f1: 0.00005, acc: 0.97847, rec: 0.00002, fpr: 0.00001, f1_macro: nan
# Better model saved at ./saved_models/GIN_1: 4.669655246024122e-05.pt.
# epoch: 3, passed number of graphs: 96, train running loss: 0.01018 (passed time: 10m 8s)
#           acc: 0.98976, fpr: 0.00875, fnr: 0.04429, rec: 0.95571, prc: 0.82716, f1: 0.88680, f1_macro: 0.94072
# epoch: 3, passed number of graphs: 192, train running loss: 0.01142 (passed time: 10m 36s)
#           acc: 0.99597, fpr: 0.00326, fnr: 0.02191, rec: 0.97809, prc: 0.92871, f1: 0.95276, f1_macro: 0.97533
# epoch: 3, passed number of graphs: 288, train running loss: 0.01138 (passed time: 11m 4s)
#           acc: 0.99878, fpr: 0.00004, fnr: 0.02903, rec: 0.97097, prc: 0.99914, f1: 0.98485, f1_macro: 0.99211
# epoch: 3, passed number of graphs: 384, train running loss: 0.01100 (passed time: 11m 32s)
#           acc: 0.98981, fpr: 0.00946, fnr: 0.02610, rec: 0.97390, prc: 0.82405, f1: 0.89273, f1_macro: 0.94369
# epoch: 3, passed number of graphs: 480, train running loss: 0.01299 (passed time: 12m 0s)
#           acc: 0.99739, fpr: 0.00060, fnr: 0.04803, rec: 0.95197, prc: 0.98589, f1: 0.96863, f1_macro: 0.98363
# epoch: 3, passed number of graphs: 576, train running loss: 0.01823 (passed time: 12m 28s)
#           acc: 0.99852, fpr: 0.00015, fnr: 0.03155, rec: 0.96845, prc: 0.99645, f1: 0.98225, f1_macro: 0.99074
# epoch: 3, passed number of graphs: 672, train running loss: 0.01800 (passed time: 12m 56s)
#           acc: 0.99875, fpr: 0.00046, fnr: 0.01927, rec: 0.98073, prc: 0.98930, f1: 0.98500, f1_macro: 0.99217
# epoch: 3, passed number of graphs: 768, train running loss: 0.01758 (passed time: 13m 24s)
#           acc: 0.99859, fpr: 0.00023, fnr: 0.02805, rec: 0.97195, prc: 0.99456, f1: 0.98312, f1_macro: 0.99120
# Validation --- epoch: 3, loss: 0.12557
#           prc: -0.37302, fnr: 0.96785, f1: 0.05430, acc: 0.97917, rec: 0.03215, fpr: 0.00000, f1_macro: nan
# Better model saved at ./saved_models/GIN_2: 0.05430041078252482.pt.
# epoch: 4, passed number of graphs: 96, train running loss: 0.01211 (passed time: 14m 18s)
#           acc: 0.99429, fpr: 0.00429, fnr: 0.03829, rec: 0.96171, prc: 0.90767, f1: 0.93391, f1_macro: 0.96546
# epoch: 4, passed number of graphs: 192, train running loss: 0.01364 (passed time: 14m 45s)
#           acc: 0.99875, fpr: 0.00049, fnr: 0.01873, rec: 0.98127, prc: 0.98871, f1: 0.98498, f1_macro: 0.99216
# epoch: 4, passed number of graphs: 288, train running loss: 0.01157 (passed time: 15m 13s)
#           acc: 0.99935, fpr: 0.00012, fnr: 0.01318, rec: 0.98682, prc: 0.99713, f1: 0.99195, f1_macro: 0.99580
# epoch: 4, passed number of graphs: 384, train running loss: 0.01253 (passed time: 15m 41s)
#           acc: 0.99391, fpr: 0.00138, fnr: 0.10947, rec: 0.89053, prc: 0.96703, f1: 0.92720, f1_macro: 0.96201
# epoch: 4, passed number of graphs: 480, train running loss: 0.01533 (passed time: 16m 9s)
#           acc: 0.99892, fpr: 0.00038, fnr: 0.01695, rec: 0.98305, prc: 0.99145, f1: 0.98723, f1_macro: 0.99333
# epoch: 4, passed number of graphs: 576, train running loss: 0.01507 (passed time: 16m 36s)
#           acc: 0.99366, fpr: 0.00055, fnr: 0.13736, rec: 0.86264, prc: 0.98573, f1: 0.92008, f1_macro: 0.95839
# epoch: 4, passed number of graphs: 672, train running loss: 0.01454 (passed time: 17m 5s)
#           acc: 0.99517, fpr: 0.00452, fnr: 0.01192, rec: 0.98808, prc: 0.90490, f1: 0.94467, f1_macro: 0.97107
# epoch: 4, passed number of graphs: 768, train running loss: 0.01372 (passed time: 17m 33s)
#           acc: 0.99891, fpr: 0.00046, fnr: 0.01544, rec: 0.98456, prc: 0.98949, f1: 0.98702, f1_macro: 0.99322
# Validation --- epoch: 4, loss: 0.01614
#           prc: 0.98282, fnr: 0.20904, f1: 0.85573, acc: 0.99539, rec: 0.79096, fpr: 0.00013, f1_macro: 0.92669
# Better model saved at ./saved_models/GIN_3: 0.8557298622683676.pt.
# epoch: 5, passed number of graphs: 96, train running loss: 0.00695 (passed time: 18m 27s)
#           acc: 0.99788, fpr: 0.00025, fnr: 0.04478, rec: 0.95522, prc: 0.99409, f1: 0.97427, f1_macro: 0.98658
# epoch: 5, passed number of graphs: 192, train running loss: 0.00558 (passed time: 18m 55s)
#           acc: 0.99936, fpr: 0.00015, fnr: 0.01204, rec: 0.98796, prc: 0.99663, f1: 0.99227, f1_macro: 0.99597
# epoch: 5, passed number of graphs: 288, train running loss: 0.00567 (passed time: 19m 22s)
#           acc: 0.99909, fpr: 0.00011, fnr: 0.01969, rec: 0.98031, prc: 0.99728, f1: 0.98872, f1_macro: 0.99412
# epoch: 5, passed number of graphs: 384, train running loss: 0.00531 (passed time: 19m 49s)
#           acc: 0.99949, fpr: 0.00014, fnr: 0.00870, rec: 0.99130, prc: 0.99686, f1: 0.99408, f1_macro: 0.99690
# epoch: 5, passed number of graphs: 480, train running loss: 0.00649 (passed time: 20m 16s)
#           acc: 0.99933, fpr: 0.00017, fnr: 0.01197, rec: 0.98803, prc: 0.99615, f1: 0.99207, f1_macro: 0.99586
# epoch: 5, passed number of graphs: 576, train running loss: 0.00669 (passed time: 20m 43s)
#           acc: 0.99944, fpr: 0.00018, fnr: 0.00904, rec: 0.99096, prc: 0.99587, f1: 0.99341, f1_macro: 0.99656
# epoch: 5, passed number of graphs: 672, train running loss: 0.00657 (passed time: 21m 10s)
#           acc: 0.99839, fpr: 0.00054, fnr: 0.02629, rec: 0.97371, prc: 0.98742, f1: 0.98052, f1_macro: 0.98984
# epoch: 5, passed number of graphs: 768, train running loss: 0.00689 (passed time: 21m 37s)
#           acc: 0.99924, fpr: 0.00030, fnr: 0.01129, rec: 0.98871, prc: 0.99316, f1: 0.99093, f1_macro: 0.99527
# Validation --- epoch: 5, loss: 0.28310
#           prc: 0.13287, fnr: 0.06185, f1: 0.23192, acc: 0.85897, rec: 0.93815, fpr: 0.14277, f1_macro: 0.57682
# epoch: 6, passed number of graphs: 96, train running loss: 0.00510 (passed time: 22m 30s)
#           acc: 0.99375, fpr: 0.00012, fnr: 0.14601, rec: 0.85399, prc: 0.99678, f1: 0.91988, f1_macro: 0.95831
# epoch: 6, passed number of graphs: 192, train running loss: 0.08847 (passed time: 22m 57s)
#           acc: 0.95840, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 6, passed number of graphs: 288, train running loss: 0.11615 (passed time: 23m 25s)
#           acc: 0.95918, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 6, passed number of graphs: 384, train running loss: 0.12931 (passed time: 23m 52s)
#           acc: 0.95647, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 6, passed number of graphs: 480, train running loss: 0.13181 (passed time: 24m 19s)
#           acc: 0.96797, fpr: 0.01410, fnr: 0.43693, rec: 0.56307, prc: 0.63888, f1: 0.59859, f1_macro: 0.79095
# epoch: 6, passed number of graphs: 576, train running loss: 0.11883 (passed time: 24m 46s)
#           acc: 0.99728, fpr: 0.00021, fnr: 0.05948, rec: 0.94052, prc: 0.99496, f1: 0.96697, f1_macro: 0.98278
# epoch: 6, passed number of graphs: 672, train running loss: 0.10503 (passed time: 25m 14s)
#           acc: 0.99734, fpr: 0.00075, fnr: 0.04637, rec: 0.95363, prc: 0.98218, f1: 0.96769, f1_macro: 0.98315
# epoch: 6, passed number of graphs: 768, train running loss: 0.09426 (passed time: 25m 41s)
#           acc: 0.99569, fpr: 0.00025, fnr: 0.09661, rec: 0.90339, prc: 0.99379, f1: 0.94643, f1_macro: 0.97209
# Validation --- epoch: 6, loss: 0.26662
#           prc: 0.17143, fnr: 0.02617, f1: 0.29014, acc: 0.89214, rec: 0.97383, fpr: 0.10966, f1_macro: 0.61574
# epoch: 7, passed number of graphs: 96, train running loss: 0.01338 (passed time: 26m 34s)
#           acc: 0.99851, fpr: 0.00006, fnr: 0.03407, rec: 0.96593, prc: 0.99849, f1: 0.98194, f1_macro: 0.99058
# epoch: 7, passed number of graphs: 192, train running loss: 0.01068 (passed time: 27m 2s)
#           acc: 0.99845, fpr: 0.00001, fnr: 0.03696, rec: 0.96304, prc: 0.99965, f1: 0.98101, f1_macro: 0.99010
# epoch: 7, passed number of graphs: 288, train running loss: 0.00980 (passed time: 27m 29s)
#           acc: 0.99863, fpr: 0.00001, fnr: 0.03337, rec: 0.96663, prc: 0.99983, f1: 0.98295, f1_macro: 0.99112
# epoch: 7, passed number of graphs: 384, train running loss: 0.00953 (passed time: 27m 56s)
#           acc: 0.99871, fpr: 0.00003, fnr: 0.02905, rec: 0.97095, prc: 0.99932, f1: 0.98493, f1_macro: 0.99213
# epoch: 7, passed number of graphs: 480, train running loss: 0.00940 (passed time: 28m 23s)
#           acc: 0.99821, fpr: 0.00007, fnr: 0.04055, rec: 0.95945, prc: 0.99827, f1: 0.97847, f1_macro: 0.98877
# epoch: 7, passed number of graphs: 576, train running loss: 0.00883 (passed time: 28m 50s)
#           acc: 0.99843, fpr: 0.00012, fnr: 0.03451, rec: 0.96549, prc: 0.99728, f1: 0.98113, f1_macro: 0.99016
# epoch: 7, passed number of graphs: 672, train running loss: 0.00859 (passed time: 29m 17s)
#           acc: 0.99864, fpr: 0.00060, fnr: 0.01861, rec: 0.98139, prc: 0.98606, f1: 0.98372, f1_macro: 0.99150
# epoch: 7, passed number of graphs: 768, train running loss: 0.00851 (passed time: 29m 45s)
#           acc: 0.99898, fpr: 0.00009, fnr: 0.02224, rec: 0.97776, prc: 0.99797, f1: 0.98776, f1_macro: 0.99361
# Validation --- epoch: 7, loss: 0.02440
#           prc: 0.98764, fnr: 0.21252, f1: 0.85504, acc: 0.99541, rec: 0.78748, fpr: 0.00003, f1_macro: nan
# epoch: 8, passed number of graphs: 96, train running loss: 0.00984 (passed time: 30m 37s)
#           acc: 0.97684, fpr: 0.02257, fnr: 0.03650, rec: 0.96350, prc: 0.65163, f1: 0.77746, f1_macro: 0.88262
# epoch: 8, passed number of graphs: 192, train running loss: 0.00808 (passed time: 31m 4s)
#           acc: 0.99915, fpr: 0.00001, fnr: 0.02007, rec: 0.97993, prc: 0.99966, f1: 0.98970, f1_macro: 0.99463
# epoch: 8, passed number of graphs: 288, train running loss: 0.00724 (passed time: 31m 31s)
#           acc: 0.99911, fpr: 0.00003, fnr: 0.02119, rec: 0.97881, prc: 0.99932, f1: 0.98896, f1_macro: 0.99425
# epoch: 8, passed number of graphs: 384, train running loss: 0.00680 (passed time: 31m 58s)
#           acc: 0.99908, fpr: 0.00002, fnr: 0.02068, rec: 0.97932, prc: 0.99950, f1: 0.98931, f1_macro: 0.99441
# epoch: 8, passed number of graphs: 480, train running loss: 0.00674 (passed time: 32m 25s)
#           acc: 0.99918, fpr: 0.00004, fnr: 0.01845, rec: 0.98155, prc: 0.99915, f1: 0.99027, f1_macro: 0.99492
# epoch: 8, passed number of graphs: 576, train running loss: 0.00665 (passed time: 32m 52s)
#           acc: 0.99925, fpr: 0.00012, fnr: 0.01512, rec: 0.98488, prc: 0.99734, f1: 0.99107, f1_macro: 0.99534
# epoch: 8, passed number of graphs: 672, train running loss: 0.00662 (passed time: 33m 19s)
#           acc: 0.99826, fpr: 0.00077, fnr: 0.02416, rec: 0.97584, prc: 0.98225, f1: 0.97903, f1_macro: 0.98906
# epoch: 8, passed number of graphs: 768, train running loss: 0.00667 (passed time: 33m 47s)
#           acc: 0.99813, fpr: 0.00075, fnr: 0.02722, rec: 0.97278, prc: 0.98273, f1: 0.97773, f1_macro: 0.98838
# Validation --- epoch: 8, loss: 0.01681
#           prc: 0.90800, fnr: 0.04210, f1: 0.92513, acc: 0.99617, rec: 0.95790, fpr: 0.00298, f1_macro: 0.96158
# Better model saved at ./saved_models/GIN_7: 0.9251264886891778.pt.
# epoch: 9, passed number of graphs: 96, train running loss: 0.00625 (passed time: 34m 39s)
#           acc: 0.99898, fpr: 0.00031, fnr: 0.01720, rec: 0.98280, prc: 0.99279, f1: 0.98777, f1_macro: 0.99362
# epoch: 9, passed number of graphs: 192, train running loss: 0.00527 (passed time: 35m 6s)
#           acc: 0.99937, fpr: 0.00003, fnr: 0.01455, rec: 0.98545, prc: 0.99932, f1: 0.99234, f1_macro: 0.99600
# epoch: 9, passed number of graphs: 288, train running loss: 0.00485 (passed time: 35m 33s)
#           acc: 0.99947, fpr: 0.00000, fnr: 0.01302, rec: 0.98698, prc: 1.00000, f1: 0.99345, f1_macro: 0.99659
# epoch: 9, passed number of graphs: 384, train running loss: 0.00467 (passed time: 36m 1s)
#           acc: 0.99937, fpr: 0.00002, fnr: 0.01395, rec: 0.98605, prc: 0.99950, f1: 0.99273, f1_macro: 0.99620
# epoch: 9, passed number of graphs: 480, train running loss: 0.00475 (passed time: 36m 28s)
#           acc: 0.99879, fpr: 0.00004, fnr: 0.02742, rec: 0.97258, prc: 0.99898, f1: 0.98560, f1_macro: 0.99249
# epoch: 9, passed number of graphs: 576, train running loss: 0.00443 (passed time: 36m 55s)
#           acc: 0.99951, fpr: 0.00007, fnr: 0.01002, rec: 0.98998, prc: 0.99851, f1: 0.99422, f1_macro: 0.99699
# epoch: 9, passed number of graphs: 672, train running loss: 0.00444 (passed time: 37m 22s)
#           acc: 0.99903, fpr: 0.00053, fnr: 0.01110, rec: 0.98890, prc: 0.98777, f1: 0.98833, f1_macro: 0.99391
# epoch: 9, passed number of graphs: 768, train running loss: 0.00446 (passed time: 37m 50s)
#           acc: 0.99941, fpr: 0.00004, fnr: 0.01295, rec: 0.98705, prc: 0.99899, f1: 0.99299, f1_macro: 0.99634
# Validation --- epoch: 9, loss: 0.01850
#           prc: 0.97628, fnr: 0.01561, f1: 0.97819, acc: 0.99897, rec: 0.98439, fpr: 0.00071, f1_macro: 0.98883
# Better model saved at ./saved_models/GIN_8: 0.9781915244480687.pt.
# epoch: 10, passed number of graphs: 96, train running loss: 0.00392 (passed time: 38m 42s)
#           acc: 0.99936, fpr: 0.00030, fnr: 0.00844, rec: 0.99156, prc: 0.99318, f1: 0.99237, f1_macro: 0.99602
# epoch: 10, passed number of graphs: 192, train running loss: 0.00356 (passed time: 39m 9s)
#           acc: 0.99952, fpr: 0.00001, fnr: 0.01120, rec: 0.98880, prc: 0.99966, f1: 0.99420, f1_macro: 0.99697
# epoch: 10, passed number of graphs: 288, train running loss: 0.00320 (passed time: 39m 36s)
#           acc: 0.99962, fpr: 0.00002, fnr: 0.00884, rec: 0.99116, prc: 0.99950, f1: 0.99531, f1_macro: 0.99755
# epoch: 10, passed number of graphs: 384, train running loss: 0.00327 (passed time: 40m 4s)
#           acc: 0.99944, fpr: 0.00002, fnr: 0.01231, rec: 0.98769, prc: 0.99950, f1: 0.99356, f1_macro: 0.99663
# epoch: 10, passed number of graphs: 480, train running loss: 0.00352 (passed time: 40m 31s)
#           acc: 0.99963, fpr: 0.00008, fnr: 0.00698, rec: 0.99302, prc: 0.99816, f1: 0.99558, f1_macro: 0.99769
# epoch: 10, passed number of graphs: 576, train running loss: 0.00338 (passed time: 40m 59s)
#           acc: 0.99962, fpr: 0.00007, fnr: 0.00739, rec: 0.99261, prc: 0.99851, f1: 0.99555, f1_macro: 0.99768
# epoch: 10, passed number of graphs: 672, train running loss: 0.00363 (passed time: 41m 27s)
#           acc: 0.99903, fpr: 0.00055, fnr: 0.01061, rec: 0.98939, prc: 0.98729, f1: 0.98834, f1_macro: 0.99392
# epoch: 10, passed number of graphs: 768, train running loss: 0.00378 (passed time: 41m 55s)
#           acc: 0.99931, fpr: 0.00002, fnr: 0.01577, rec: 0.98423, prc: 0.99949, f1: 0.99180, f1_macro: 0.99572
# Validation --- epoch: 10, loss: 0.01272
#           prc: 0.99697, fnr: 0.11598, f1: 0.92663, acc: 0.99746, rec: 0.88402, fpr: 0.00005, f1_macro: 0.96267
# epoch: 11, passed number of graphs: 96, train running loss: 0.00385 (passed time: 42m 49s)
#           acc: 0.99960, fpr: 0.00010, fnr: 0.00730, rec: 0.99270, prc: 0.99772, f1: 0.99520, f1_macro: 0.99750
# epoch: 11, passed number of graphs: 192, train running loss: 0.00344 (passed time: 43m 17s)
#           acc: 0.99953, fpr: 0.00001, fnr: 0.01104, rec: 0.98896, prc: 0.99966, f1: 0.99428, f1_macro: 0.99702
# epoch: 11, passed number of graphs: 288, train running loss: 0.00318 (passed time: 43m 45s)
#           acc: 0.99937, fpr: 0.00000, fnr: 0.01552, rec: 0.98448, prc: 1.00000, f1: 0.99218, f1_macro: 0.99593
# epoch: 11, passed number of graphs: 384, train running loss: 0.00344 (passed time: 44m 13s)
#           acc: 0.99943, fpr: 0.00002, fnr: 0.01264, rec: 0.98736, prc: 0.99950, f1: 0.99339, f1_macro: 0.99655
# epoch: 11, passed number of graphs: 480, train running loss: 0.00368 (passed time: 44m 40s)
#           acc: 0.99920, fpr: 0.00009, fnr: 0.01679, rec: 0.98321, prc: 0.99798, f1: 0.99054, f1_macro: 0.99506
# epoch: 11, passed number of graphs: 576, train running loss: 0.00350 (passed time: 45m 8s)
#           acc: 0.99965, fpr: 0.00004, fnr: 0.00756, rec: 0.99244, prc: 0.99917, f1: 0.99580, f1_macro: 0.99781
# epoch: 11, passed number of graphs: 672, train running loss: 0.00361 (passed time: 45m 36s)
#           acc: 0.99905, fpr: 0.00063, fnr: 0.00833, rec: 0.99167, prc: 0.98572, f1: 0.98869, f1_macro: 0.99410
# epoch: 11, passed number of graphs: 768, train running loss: 0.00371 (passed time: 46m 4s)
#           acc: 0.99933, fpr: 0.00010, fnr: 0.01378, rec: 0.98622, prc: 0.99782, f1: 0.99199, f1_macro: 0.99582
# Validation --- epoch: 11, loss: 0.00569
#           prc: 0.97686, fnr: 0.03065, f1: 0.97104, acc: 0.99861, rec: 0.96935, fpr: 0.00075, f1_macro: 0.98516
# epoch: 12, passed number of graphs: 96, train running loss: 0.00478 (passed time: 46m 58s)
#           acc: 0.99948, fpr: 0.00017, fnr: 0.00844, rec: 0.99156, prc: 0.99609, f1: 0.99382, f1_macro: 0.99678
# epoch: 12, passed number of graphs: 192, train running loss: 0.00387 (passed time: 47m 25s)
#           acc: 0.99956, fpr: 0.00001, fnr: 0.01020, rec: 0.98980, prc: 0.99966, f1: 0.99471, f1_macro: 0.99724
# epoch: 12, passed number of graphs: 288, train running loss: 0.00334 (passed time: 47m 53s)
#           acc: 0.99960, fpr: 0.00003, fnr: 0.00918, rec: 0.99082, prc: 0.99933, f1: 0.99506, f1_macro: 0.99742
# epoch: 12, passed number of graphs: 384, train running loss: 0.00328 (passed time: 48m 21s)
#           acc: 0.99953, fpr: 0.00004, fnr: 0.00985, rec: 0.99015, prc: 0.99901, f1: 0.99456, f1_macro: 0.99716
# epoch: 12, passed number of graphs: 480, train running loss: 0.00354 (passed time: 48m 48s)
#           acc: 0.99867, fpr: 0.00007, fnr: 0.02958, rec: 0.97042, prc: 0.99829, f1: 0.98416, f1_macro: 0.99173
# epoch: 12, passed number of graphs: 576, train running loss: 0.00331 (passed time: 49m 16s)
#           acc: 0.99968, fpr: 0.00007, fnr: 0.00608, rec: 0.99392, prc: 0.99851, f1: 0.99621, f1_macro: 0.99802
# epoch: 12, passed number of graphs: 672, train running loss: 0.00340 (passed time: 49m 44s)
#           acc: 0.99901, fpr: 0.00062, fnr: 0.00963, rec: 0.99037, prc: 0.98586, f1: 0.98811, f1_macro: 0.99379
# epoch: 12, passed number of graphs: 768, train running loss: 0.00348 (passed time: 50m 12s)
#           acc: 0.99943, fpr: 0.00004, fnr: 0.01262, rec: 0.98738, prc: 0.99916, f1: 0.99324, f1_macro: 0.99647
# Validation --- epoch: 12, loss: 0.00477
#           prc: 0.98265, fnr: 0.02623, f1: 0.97649, acc: 0.99890, rec: 0.97377, fpr: 0.00055, f1_macro: 0.98796
# epoch: 13, passed number of graphs: 96, train running loss: 0.00647 (passed time: 51m 6s)
#           acc: 0.99937, fpr: 0.00006, fnr: 0.01347, rec: 0.98653, prc: 0.99852, f1: 0.99249, f1_macro: 0.99608
# epoch: 13, passed number of graphs: 192, train running loss: 0.00570 (passed time: 51m 34s)
#           acc: 0.99949, fpr: 0.00001, fnr: 0.01204, rec: 0.98796, prc: 0.99966, f1: 0.99378, f1_macro: 0.99675
# epoch: 13, passed number of graphs: 288, train running loss: 0.00515 (passed time: 52m 2s)
#           acc: 0.99939, fpr: 0.00000, fnr: 0.01502, rec: 0.98498, prc: 1.00000, f1: 0.99243, f1_macro: 0.99606
# epoch: 13, passed number of graphs: 384, train running loss: 0.00483 (passed time: 52m 30s)
#           acc: 0.99954, fpr: 0.00002, fnr: 0.01001, rec: 0.98999, prc: 0.99950, f1: 0.99472, f1_macro: 0.99724
# epoch: 13, passed number of graphs: 480, train running loss: 0.00516 (passed time: 52m 58s)
#           acc: 0.99935, fpr: 0.00001, fnr: 0.01496, rec: 0.98504, prc: 0.99966, f1: 0.99230, f1_macro: 0.99598
# epoch: 13, passed number of graphs: 576, train running loss: 0.00477 (passed time: 53m 26s)
#           acc: 0.99964, fpr: 0.00002, fnr: 0.00805, rec: 0.99195, prc: 0.99950, f1: 0.99571, f1_macro: 0.99776
# epoch: 13, passed number of graphs: 672, train running loss: 0.00479 (passed time: 53m 55s)
#           acc: 0.99905, fpr: 0.00057, fnr: 0.00980, rec: 0.99020, prc: 0.98698, f1: 0.98859, f1_macro: 0.99405
# epoch: 13, passed number of graphs: 768, train running loss: 0.00496 (passed time: 54m 23s)
#           acc: 0.99933, fpr: 0.00010, fnr: 0.01361, rec: 0.98639, prc: 0.99765, f1: 0.99199, f1_macro: 0.99582
# Validation --- epoch: 13, loss: 0.18576
#           prc: 0.32390, fnr: 0.01248, f1: 0.46396, acc: 0.93511, rec: 0.98752, fpr: 0.06604, f1_macro: 0.71454
# epoch: 14, passed number of graphs: 96, train running loss: 0.00409 (passed time: 55m 17s)
#           acc: 0.99964, fpr: 0.00009, fnr: 0.00665, rec: 0.99335, prc: 0.99804, f1: 0.99569, f1_macro: 0.99775
# epoch: 14, passed number of graphs: 192, train running loss: 0.00346 (passed time: 55m 45s)
#           acc: 0.99957, fpr: 0.00004, fnr: 0.00953, rec: 0.99047, prc: 0.99916, f1: 0.99479, f1_macro: 0.99728
# epoch: 14, passed number of graphs: 288, train running loss: 0.00341 (passed time: 56m 13s)
#           acc: 0.99952, fpr: 0.00001, fnr: 0.01168, rec: 0.98832, prc: 0.99983, f1: 0.99404, f1_macro: 0.99690
# epoch: 14, passed number of graphs: 384, train running loss: 0.00344 (passed time: 56m 41s)
#           acc: 0.99951, fpr: 0.00002, fnr: 0.01067, rec: 0.98933, prc: 0.99950, f1: 0.99439, f1_macro: 0.99707
# epoch: 14, passed number of graphs: 480, train running loss: 0.00394 (passed time: 57m 9s)
#           acc: 0.99925, fpr: 0.00000, fnr: 0.01762, rec: 0.98238, prc: 1.00000, f1: 0.99111, f1_macro: 0.99536
# epoch: 14, passed number of graphs: 576, train running loss: 0.00384 (passed time: 57m 37s)
#           acc: 0.99958, fpr: 0.00001, fnr: 0.00986, rec: 0.99014, prc: 0.99983, f1: 0.99496, f1_macro: 0.99737
# epoch: 14, passed number of graphs: 672, train running loss: 0.00424 (passed time: 58m 4s)
#           acc: 0.99681, fpr: 0.00286, fnr: 0.01078, rec: 0.98922, prc: 0.93778, f1: 0.96282, f1_macro: 0.98058
# epoch: 14, passed number of graphs: 768, train running loss: 0.00432 (passed time: 58m 33s)
#           acc: 0.99951, fpr: 0.00004, fnr: 0.01062, rec: 0.98938, prc: 0.99899, f1: 0.99416, f1_macro: 0.99695
# Validation --- epoch: 14, loss: 0.00578
#           prc: 0.99749, fnr: 0.05105, f1: 0.97034, acc: 0.99886, rec: 0.94895, fpr: 0.00004, f1_macro: 0.98488
# epoch: 15, passed number of graphs: 96, train running loss: 0.00365 (passed time: 59m 26s)
#           acc: 0.99961, fpr: 0.00009, fnr: 0.00730, rec: 0.99270, prc: 0.99804, f1: 0.99536, f1_macro: 0.99758
# epoch: 15, passed number of graphs: 192, train running loss: 0.00326 (passed time: 59m 55s)
#           acc: 0.99958, fpr: 0.00001, fnr: 0.00970, rec: 0.99030, prc: 0.99966, f1: 0.99496, f1_macro: 0.99737
# epoch: 15, passed number of graphs: 288, train running loss: 0.00293 (passed time: 1h 0m 22s)
#           acc: 0.99964, fpr: 0.00003, fnr: 0.00818, rec: 0.99182, prc: 0.99933, f1: 0.99556, f1_macro: 0.99769
# epoch: 15, passed number of graphs: 384, train running loss: 0.00294 (passed time: 1h 0m 49s)
#           acc: 0.99953, fpr: 0.00004, fnr: 0.00985, rec: 0.99015, prc: 0.99901, f1: 0.99456, f1_macro: 0.99716
# epoch: 15, passed number of graphs: 480, train running loss: 0.00322 (passed time: 1h 1m 17s)
#           acc: 0.99940, fpr: 0.00009, fnr: 0.01213, rec: 0.98787, prc: 0.99799, f1: 0.99290, f1_macro: 0.99629
# epoch: 15, passed number of graphs: 576, train running loss: 0.00304 (passed time: 1h 1m 45s)
#           acc: 0.99971, fpr: 0.00003, fnr: 0.00624, rec: 0.99376, prc: 0.99934, f1: 0.99654, f1_macro: 0.99819
# epoch: 15, passed number of graphs: 672, train running loss: 0.00313 (passed time: 1h 2m 12s)
#           acc: 0.99907, fpr: 0.00065, fnr: 0.00735, rec: 0.99265, prc: 0.98509, f1: 0.98886, f1_macro: 0.99419
# epoch: 15, passed number of graphs: 768, train running loss: 0.00323 (passed time: 1h 2m 40s)
#           acc: 0.99957, fpr: 0.00009, fnr: 0.00830, rec: 0.99170, prc: 0.99800, f1: 0.99484, f1_macro: 0.99731
# Validation --- epoch: 15, loss: 0.00421
#           prc: 0.98916, fnr: 0.02498, f1: 0.98082, acc: 0.99920, rec: 0.97502, fpr: 0.00027, f1_macro: 0.99021
# Better model saved at ./saved_models/GIN_14: 0.9808227176211669.pt.
# epoch: 16, passed number of graphs: 96, train running loss: 0.00322 (passed time: 1h 3m 33s)
#           acc: 0.99955, fpr: 0.00020, fnr: 0.00616, rec: 0.99384, prc: 0.99545, f1: 0.99464, f1_macro: 0.99720
# epoch: 16, passed number of graphs: 192, train running loss: 0.00294 (passed time: 1h 4m 1s)
#           acc: 0.99960, fpr: 0.00003, fnr: 0.00903, rec: 0.99097, prc: 0.99933, f1: 0.99513, f1_macro: 0.99746
# epoch: 16, passed number of graphs: 288, train running loss: 0.00266 (passed time: 1h 4m 28s)
#           acc: 0.99965, fpr: 0.00004, fnr: 0.00768, rec: 0.99232, prc: 0.99916, f1: 0.99573, f1_macro: 0.99777
# epoch: 16, passed number of graphs: 384, train running loss: 0.00270 (passed time: 1h 4m 56s)
#           acc: 0.99954, fpr: 0.00004, fnr: 0.00968, rec: 0.99032, prc: 0.99901, f1: 0.99464, f1_macro: 0.99720
# epoch: 16, passed number of graphs: 480, train running loss: 0.00301 (passed time: 1h 5m 25s)
#           acc: 0.99948, fpr: 0.00009, fnr: 0.01030, rec: 0.98970, prc: 0.99799, f1: 0.99383, f1_macro: 0.99678
# epoch: 16, passed number of graphs: 576, train running loss: 0.00285 (passed time: 1h 5m 53s)
#           acc: 0.99971, fpr: 0.00004, fnr: 0.00575, rec: 0.99425, prc: 0.99901, f1: 0.99662, f1_macro: 0.99824
# epoch: 16, passed number of graphs: 672, train running loss: 0.00295 (passed time: 1h 6m 21s)
#           acc: 0.99907, fpr: 0.00065, fnr: 0.00735, rec: 0.99265, prc: 0.98525, f1: 0.98894, f1_macro: 0.99423
# epoch: 16, passed number of graphs: 768, train running loss: 0.00308 (passed time: 1h 6m 50s)
#           acc: 0.99957, fpr: 0.00009, fnr: 0.00813, rec: 0.99187, prc: 0.99800, f1: 0.99492, f1_macro: 0.99735
# Validation --- epoch: 16, loss: 0.00445
#           prc: 0.98665, fnr: 0.02238, f1: 0.98075, acc: 0.99916, rec: 0.97762, fpr: 0.00037, f1_macro: 0.99016
# epoch: 17, passed number of graphs: 96, train running loss: 0.00356 (passed time: 1h 7m 43s)
#           acc: 0.98828, fpr: 0.01188, fnr: 0.00811, rec: 0.99189, prc: 0.78536, f1: 0.87662, f1_macro: 0.93523
# epoch: 17, passed number of graphs: 192, train running loss: 0.00356 (passed time: 1h 8m 11s)
#           acc: 0.99950, fpr: 0.00004, fnr: 0.01104, rec: 0.98896, prc: 0.99899, f1: 0.99395, f1_macro: 0.99684
# epoch: 17, passed number of graphs: 288, train running loss: 0.00321 (passed time: 1h 8m 39s)
#           acc: 0.99963, fpr: 0.00003, fnr: 0.00834, rec: 0.99166, prc: 0.99933, f1: 0.99548, f1_macro: 0.99764
# epoch: 17, passed number of graphs: 384, train running loss: 0.00318 (passed time: 1h 9m 7s)
#           acc: 0.99956, fpr: 0.00001, fnr: 0.00985, rec: 0.99015, prc: 0.99983, f1: 0.99497, f1_macro: 0.99737
# epoch: 17, passed number of graphs: 480, train running loss: 0.00341 (passed time: 1h 9m 35s)
#           acc: 0.99895, fpr: 0.00007, fnr: 0.02327, rec: 0.97673, prc: 0.99847, f1: 0.98748, f1_macro: 0.99347
# epoch: 17, passed number of graphs: 576, train running loss: 0.00319 (passed time: 1h 10m 3s)
#           acc: 0.99971, fpr: 0.00004, fnr: 0.00608, rec: 0.99392, prc: 0.99917, f1: 0.99654, f1_macro: 0.99819
# epoch: 17, passed number of graphs: 672, train running loss: 0.00326 (passed time: 1h 10m 31s)
#           acc: 0.99905, fpr: 0.00065, fnr: 0.00767, rec: 0.99233, prc: 0.98509, f1: 0.98869, f1_macro: 0.99410
# epoch: 17, passed number of graphs: 768, train running loss: 0.00335 (passed time: 1h 10m 59s)
#           acc: 0.99955, fpr: 0.00005, fnr: 0.00946, rec: 0.99054, prc: 0.99883, f1: 0.99467, f1_macro: 0.99722
# Validation --- epoch: 17, loss: 0.00462
#           prc: 0.99041, fnr: 0.03528, f1: 0.97574, acc: 0.99905, rec: 0.96472, fpr: 0.00019, f1_macro: 0.98763
# epoch: 18, passed number of graphs: 96, train running loss: 0.00378 (passed time: 1h 11m 53s)
#           acc: 0.98892, fpr: 0.01123, fnr: 0.00762, rec: 0.99238, prc: 0.79473, f1: 0.88262, f1_macro: 0.93840
# epoch: 18, passed number of graphs: 192, train running loss: 0.00338 (passed time: 1h 12m 21s)
#           acc: 0.99959, fpr: 0.00003, fnr: 0.00920, rec: 0.99080, prc: 0.99933, f1: 0.99505, f1_macro: 0.99742
# epoch: 18, passed number of graphs: 288, train running loss: 0.00296 (passed time: 1h 12m 49s)
#           acc: 0.99967, fpr: 0.00004, fnr: 0.00718, rec: 0.99282, prc: 0.99916, f1: 0.99598, f1_macro: 0.99791
# epoch: 18, passed number of graphs: 384, train running loss: 0.00291 (passed time: 1h 13m 18s)
#           acc: 0.99954, fpr: 0.00004, fnr: 0.00968, rec: 0.99032, prc: 0.99901, f1: 0.99464, f1_macro: 0.99720
# epoch: 18, passed number of graphs: 480, train running loss: 0.00315 (passed time: 1h 13m 46s)
#           acc: 0.99896, fpr: 0.00007, fnr: 0.02294, rec: 0.97706, prc: 0.99830, f1: 0.98757, f1_macro: 0.99351
# epoch: 18, passed number of graphs: 576, train running loss: 0.00297 (passed time: 1h 14m 14s)
#           acc: 0.99970, fpr: 0.00003, fnr: 0.00641, rec: 0.99359, prc: 0.99934, f1: 0.99646, f1_macro: 0.99815
# epoch: 18, passed number of graphs: 672, train running loss: 0.00306 (passed time: 1h 14m 43s)
#           acc: 0.99909, fpr: 0.00066, fnr: 0.00653, rec: 0.99347, prc: 0.98495, f1: 0.98919, f1_macro: 0.99436
# epoch: 18, passed number of graphs: 768, train running loss: 0.00314 (passed time: 1h 15m 11s)
#           acc: 0.99954, fpr: 0.00007, fnr: 0.00946, rec: 0.99054, prc: 0.99849, f1: 0.99450, f1_macro: 0.99713
# Validation --- epoch: 18, loss: 0.00415
#           prc: 0.98910, fnr: 0.02998, f1: 0.97818, acc: 0.99911, rec: 0.97002, fpr: 0.00025, f1_macro: 0.98886
# epoch: 19, passed number of graphs: 96, train running loss: 0.00339 (passed time: 1h 16m 6s)
#           acc: 0.99469, fpr: 0.00524, fnr: 0.00681, rec: 0.99319, prc: 0.89255, f1: 0.94018, f1_macro: 0.96870
# epoch: 19, passed number of graphs: 192, train running loss: 0.00300 (passed time: 1h 16m 35s)
#           acc: 0.99959, fpr: 0.00003, fnr: 0.00920, rec: 0.99080, prc: 0.99933, f1: 0.99505, f1_macro: 0.99742
# epoch: 19, passed number of graphs: 288, train running loss: 0.00269 (passed time: 1h 17m 3s)
#           acc: 0.99967, fpr: 0.00004, fnr: 0.00718, rec: 0.99282, prc: 0.99916, f1: 0.99598, f1_macro: 0.99791
# epoch: 19, passed number of graphs: 384, train running loss: 0.00270 (passed time: 1h 17m 32s)
#           acc: 0.99956, fpr: 0.00002, fnr: 0.00968, rec: 0.99032, prc: 0.99950, f1: 0.99489, f1_macro: 0.99733
# epoch: 19, passed number of graphs: 480, train running loss: 0.00297 (passed time: 1h 18m 0s)
#           acc: 0.99906, fpr: 0.00008, fnr: 0.02028, rec: 0.97972, prc: 0.99814, f1: 0.98885, f1_macro: 0.99418
# epoch: 19, passed number of graphs: 576, train running loss: 0.00281 (passed time: 1h 18m 28s)
#           acc: 0.99971, fpr: 0.00004, fnr: 0.00608, rec: 0.99392, prc: 0.99917, f1: 0.99654, f1_macro: 0.99819
# epoch: 19, passed number of graphs: 672, train running loss: 0.00292 (passed time: 1h 18m 56s)
#           acc: 0.99909, fpr: 0.00067, fnr: 0.00637, rec: 0.99363, prc: 0.98479, f1: 0.98919, f1_macro: 0.99436
# epoch: 19, passed number of graphs: 768, train running loss: 0.00301 (passed time: 1h 19m 24s)
#           acc: 0.99953, fpr: 0.00008, fnr: 0.00930, rec: 0.99070, prc: 0.99816, f1: 0.99442, f1_macro: 0.99709
# Validation --- epoch: 19, loss: 0.00406
#           prc: 0.98816, fnr: 0.02671, f1: 0.97949, acc: 0.99914, rec: 0.97329, fpr: 0.00029, f1_macro: 0.98952
# epoch: 20, passed number of graphs: 96, train running loss: 0.00338 (passed time: 1h 20m 17s)
#           acc: 0.99679, fpr: 0.00310, fnr: 0.00568, rec: 0.99432, prc: 0.93359, f1: 0.96300, f1_macro: 0.98066
# epoch: 20, passed number of graphs: 192, train running loss: 0.00300 (passed time: 1h 20m 45s)
#           acc: 0.99960, fpr: 0.00004, fnr: 0.00886, rec: 0.99114, prc: 0.99916, f1: 0.99513, f1_macro: 0.99746
# epoch: 20, passed number of graphs: 288, train running loss: 0.00268 (passed time: 1h 21m 12s)
#           acc: 0.99967, fpr: 0.00004, fnr: 0.00718, rec: 0.99282, prc: 0.99916, f1: 0.99598, f1_macro: 0.99791
# epoch: 20, passed number of graphs: 384, train running loss: 0.00269 (passed time: 1h 21m 41s)
#           acc: 0.99954, fpr: 0.00004, fnr: 0.00968, rec: 0.99032, prc: 0.99917, f1: 0.99472, f1_macro: 0.99724
# epoch: 20, passed number of graphs: 480, train running loss: 0.00296 (passed time: 1h 22m 9s)
#           acc: 0.99912, fpr: 0.00008, fnr: 0.01895, rec: 0.98105, prc: 0.99814, f1: 0.98952, f1_macro: 0.99453
# epoch: 20, passed number of graphs: 576, train running loss: 0.00280 (passed time: 1h 22m 37s)
#           acc: 0.99971, fpr: 0.00004, fnr: 0.00592, rec: 0.99408, prc: 0.99917, f1: 0.99662, f1_macro: 0.99824
# epoch: 20, passed number of graphs: 672, train running loss: 0.00291 (passed time: 1h 23m 5s)
#           acc: 0.99909, fpr: 0.00068, fnr: 0.00620, rec: 0.99380, prc: 0.98447, f1: 0.98911, f1_macro: 0.99432
# epoch: 20, passed number of graphs: 768, train running loss: 0.00299 (passed time: 1h 23m 34s)
#           acc: 0.99953, fpr: 0.00008, fnr: 0.00930, rec: 0.99070, prc: 0.99816, f1: 0.99442, f1_macro: 0.99709
# Validation --- epoch: 20, loss: 0.00413
#           prc: 0.98804, fnr: 0.02559, f1: 0.97994, acc: 0.99915, rec: 0.97441, fpr: 0.00031, f1_macro: 0.98975
# epoch: 21, passed number of graphs: 96, train running loss: 0.00318 (passed time: 1h 24m 29s)
#           acc: 0.99813, fpr: 0.00171, fnr: 0.00552, rec: 0.99448, prc: 0.96217, f1: 0.97806, f1_macro: 0.98854
# epoch: 21, passed number of graphs: 192, train running loss: 0.00288 (passed time: 1h 24m 57s)
#           acc: 0.99960, fpr: 0.00004, fnr: 0.00886, rec: 0.99114, prc: 0.99916, f1: 0.99513, f1_macro: 0.99746
# epoch: 21, passed number of graphs: 288, train running loss: 0.00260 (passed time: 1h 25m 25s)
#           acc: 0.99967, fpr: 0.00004, fnr: 0.00718, rec: 0.99282, prc: 0.99899, f1: 0.99590, f1_macro: 0.99786
# epoch: 21, passed number of graphs: 384, train running loss: 0.00263 (passed time: 1h 25m 53s)
#           acc: 0.99954, fpr: 0.00004, fnr: 0.00968, rec: 0.99032, prc: 0.99917, f1: 0.99472, f1_macro: 0.99724
# epoch: 21, passed number of graphs: 480, train running loss: 0.00290 (passed time: 1h 26m 20s)
#           acc: 0.99943, fpr: 0.00008, fnr: 0.01163, rec: 0.98837, prc: 0.99815, f1: 0.99324, f1_macro: 0.99647
# epoch: 21, passed number of graphs: 576, train running loss: 0.00275 (passed time: 1h 26m 47s)
#           acc: 0.99971, fpr: 0.00004, fnr: 0.00592, rec: 0.99408, prc: 0.99901, f1: 0.99654, f1_macro: 0.99819
# epoch: 21, passed number of graphs: 672, train running loss: 0.00286 (passed time: 1h 27m 14s)
#           acc: 0.99910, fpr: 0.00068, fnr: 0.00588, rec: 0.99412, prc: 0.98448, f1: 0.98928, f1_macro: 0.99440
# epoch: 21, passed number of graphs: 768, train running loss: 0.00295 (passed time: 1h 27m 42s)
#           acc: 0.99954, fpr: 0.00008, fnr: 0.00913, rec: 0.99087, prc: 0.99816, f1: 0.99450, f1_macro: 0.99713
# Validation --- epoch: 21, loss: 0.00404
#           prc: 0.98720, fnr: 0.02393, f1: 0.98039, acc: 0.99916, rec: 0.97607, fpr: 0.00034, f1_macro: 0.98998
# epoch: 22, passed number of graphs: 96, train running loss: 0.00312 (passed time: 1h 28m 36s)
#           acc: 0.99813, fpr: 0.00171, fnr: 0.00552, rec: 0.99448, prc: 0.96217, f1: 0.97806, f1_macro: 0.98854
# epoch: 22, passed number of graphs: 192, train running loss: 0.00283 (passed time: 1h 29m 3s)
#           acc: 0.99961, fpr: 0.00003, fnr: 0.00870, rec: 0.99130, prc: 0.99933, f1: 0.99530, f1_macro: 0.99755
# epoch: 22, passed number of graphs: 288, train running loss: 0.00258 (passed time: 1h 29m 30s)
#           acc: 0.99967, fpr: 0.00004, fnr: 0.00718, rec: 0.99282, prc: 0.99899, f1: 0.99590, f1_macro: 0.99786
# epoch: 22, passed number of graphs: 384, train running loss: 0.00261 (passed time: 1h 29m 58s)
#           acc: 0.99954, fpr: 0.00004, fnr: 0.00968, rec: 0.99032, prc: 0.99917, f1: 0.99472, f1_macro: 0.99724
# epoch: 22, passed number of graphs: 480, train running loss: 0.00289 (passed time: 1h 30m 25s)
#           acc: 0.99949, fpr: 0.00007, fnr: 0.01030, rec: 0.98970, prc: 0.99832, f1: 0.99399, f1_macro: 0.99686
# epoch: 22, passed number of graphs: 576, train running loss: 0.00275 (passed time: 1h 30m 53s)
#           acc: 0.99971, fpr: 0.00004, fnr: 0.00592, rec: 0.99408, prc: 0.99917, f1: 0.99662, f1_macro: 0.99824
# epoch: 22, passed number of graphs: 672, train running loss: 0.00286 (passed time: 1h 31m 20s)
#           acc: 0.99909, fpr: 0.00068, fnr: 0.00620, rec: 0.99380, prc: 0.98447, f1: 0.98911, f1_macro: 0.99432
# epoch: 22, passed number of graphs: 768, train running loss: 0.00295 (passed time: 1h 31m 47s)
#           acc: 0.99956, fpr: 0.00009, fnr: 0.00847, rec: 0.99153, prc: 0.99799, f1: 0.99475, f1_macro: 0.99726
# Validation --- epoch: 22, loss: 0.00405
#           prc: 0.98623, fnr: 0.02294, f1: 0.98029, acc: 0.99914, rec: 0.97706, fpr: 0.00037, f1_macro: 0.98993
# epoch: 23, passed number of graphs: 96, train running loss: 0.00307 (passed time: 1h 32m 41s)
#           acc: 0.99951, fpr: 0.00028, fnr: 0.00535, rec: 0.99465, prc: 0.99368, f1: 0.99416, f1_macro: 0.99695
# epoch: 23, passed number of graphs: 192, train running loss: 0.00280 (passed time: 1h 33m 8s)
#           acc: 0.99961, fpr: 0.00004, fnr: 0.00853, rec: 0.99147, prc: 0.99916, f1: 0.99530, f1_macro: 0.99755
# epoch: 23, passed number of graphs: 288, train running loss: 0.00253 (passed time: 1h 33m 35s)
#           acc: 0.99967, fpr: 0.00004, fnr: 0.00701, rec: 0.99299, prc: 0.99899, f1: 0.99598, f1_macro: 0.99791
# epoch: 23, passed number of graphs: 384, train running loss: 0.00257 (passed time: 1h 34m 2s)
#           acc: 0.99954, fpr: 0.00004, fnr: 0.00968, rec: 0.99032, prc: 0.99917, f1: 0.99472, f1_macro: 0.99724
# epoch: 23, passed number of graphs: 480, train running loss: 0.00286 (passed time: 1h 34m 29s)
#           acc: 0.99946, fpr: 0.00009, fnr: 0.01064, rec: 0.98936, prc: 0.99799, f1: 0.99366, f1_macro: 0.99669
# epoch: 23, passed number of graphs: 576, train running loss: 0.00271 (passed time: 1h 34m 56s)
#           acc: 0.99971, fpr: 0.00004, fnr: 0.00592, rec: 0.99408, prc: 0.99901, f1: 0.99654, f1_macro: 0.99819
# epoch: 23, passed number of graphs: 672, train running loss: 0.00282 (passed time: 1h 35m 23s)
#           acc: 0.99909, fpr: 0.00070, fnr: 0.00588, rec: 0.99412, prc: 0.98416, f1: 0.98912, f1_macro: 0.99432
# epoch: 23, passed number of graphs: 768, train running loss: 0.00291 (passed time: 1h 35m 51s)
#           acc: 0.99955, fpr: 0.00010, fnr: 0.00847, rec: 0.99153, prc: 0.99783, f1: 0.99467, f1_macro: 0.99722
# Validation --- epoch: 23, loss: 0.00407
#           prc: 0.98767, fnr: 0.02375, f1: 0.98070, acc: 0.99917, rec: 0.97625, fpr: 0.00033, f1_macro: 0.99014
# epoch: 24, passed number of graphs: 96, train running loss: 0.00306 (passed time: 1h 36m 44s)
#           acc: 0.99948, fpr: 0.00031, fnr: 0.00519, rec: 0.99481, prc: 0.99288, f1: 0.99384, f1_macro: 0.99679
# epoch: 24, passed number of graphs: 192, train running loss: 0.00280 (passed time: 1h 37m 11s)
#           acc: 0.99963, fpr: 0.00003, fnr: 0.00819, rec: 0.99181, prc: 0.99933, f1: 0.99555, f1_macro: 0.99768
# epoch: 24, passed number of graphs: 288, train running loss: 0.00253 (passed time: 1h 37m 38s)
#           acc: 0.99967, fpr: 0.00006, fnr: 0.00684, rec: 0.99316, prc: 0.99866, f1: 0.99590, f1_macro: 0.99786
# epoch: 24, passed number of graphs: 384, train running loss: 0.00257 (passed time: 1h 38m 6s)
#           acc: 0.99954, fpr: 0.00004, fnr: 0.00968, rec: 0.99032, prc: 0.99917, f1: 0.99472, f1_macro: 0.99724
# epoch: 24, passed number of graphs: 480, train running loss: 0.00285 (passed time: 1h 38m 34s)
#           acc: 0.99948, fpr: 0.00009, fnr: 0.01030, rec: 0.98970, prc: 0.99799, f1: 0.99383, f1_macro: 0.99678
# epoch: 24, passed number of graphs: 576, train running loss: 0.00270 (passed time: 1h 39m 1s)
#           acc: 0.99970, fpr: 0.00004, fnr: 0.00608, rec: 0.99392, prc: 0.99901, f1: 0.99646, f1_macro: 0.99815
# epoch: 24, passed number of graphs: 672, train running loss: 0.00281 (passed time: 1h 39m 28s)
#           acc: 0.99910, fpr: 0.00068, fnr: 0.00604, rec: 0.99396, prc: 0.98464, f1: 0.98928, f1_macro: 0.99440
# epoch: 24, passed number of graphs: 768, train running loss: 0.00289 (passed time: 1h 39m 56s)
#           acc: 0.99953, fpr: 0.00008, fnr: 0.00930, rec: 0.99070, prc: 0.99816, f1: 0.99442, f1_macro: 0.99709
# Validation --- epoch: 24, loss: 0.00410
#           prc: 0.98835, fnr: 0.02463, f1: 0.98055, acc: 0.99917, rec: 0.97537, fpr: 0.00031, f1_macro: 0.99006
# epoch: 25, passed number of graphs: 96, train running loss: 0.00308 (passed time: 1h 40m 49s)
#           acc: 0.99792, fpr: 0.00193, fnr: 0.00535, rec: 0.99465, prc: 0.95752, f1: 0.97573, f1_macro: 0.98732
# epoch: 25, passed number of graphs: 192, train running loss: 0.00280 (passed time: 1h 41m 17s)
#           acc: 0.99961, fpr: 0.00003, fnr: 0.00870, rec: 0.99130, prc: 0.99933, f1: 0.99530, f1_macro: 0.99755
# epoch: 25, passed number of graphs: 288, train running loss: 0.00253 (passed time: 1h 41m 45s)
#           acc: 0.99967, fpr: 0.00006, fnr: 0.00684, rec: 0.99316, prc: 0.99866, f1: 0.99590, f1_macro: 0.99786
# epoch: 25, passed number of graphs: 384, train running loss: 0.00256 (passed time: 1h 42m 13s)
#           acc: 0.99954, fpr: 0.00004, fnr: 0.00968, rec: 0.99032, prc: 0.99917, f1: 0.99472, f1_macro: 0.99724
# epoch: 25, passed number of graphs: 480, train running loss: 0.00284 (passed time: 1h 42m 41s)
#           acc: 0.99948, fpr: 0.00009, fnr: 0.01030, rec: 0.98970, prc: 0.99799, f1: 0.99383, f1_macro: 0.99678
# epoch: 25, passed number of graphs: 576, train running loss: 0.00269 (passed time: 1h 43m 10s)
#           acc: 0.99971, fpr: 0.00004, fnr: 0.00592, rec: 0.99408, prc: 0.99901, f1: 0.99654, f1_macro: 0.99819
# epoch: 25, passed number of graphs: 672, train running loss: 0.00280 (passed time: 1h 43m 38s)
#           acc: 0.99911, fpr: 0.00067, fnr: 0.00604, rec: 0.99396, prc: 0.98479, f1: 0.98936, f1_macro: 0.99445
# epoch: 25, passed number of graphs: 768, train running loss: 0.00288 (passed time: 1h 44m 7s)
#           acc: 0.99953, fpr: 0.00009, fnr: 0.00913, rec: 0.99087, prc: 0.99799, f1: 0.99442, f1_macro: 0.99709
# Validation --- epoch: 25, loss: 0.00409
#           prc: 0.98819, fnr: 0.02429, f1: 0.98064, acc: 0.99917, rec: 0.97571, fpr: 0.00031, f1_macro: 0.99011
# epoch: 26, passed number of graphs: 96, train running loss: 0.00306 (passed time: 1h 45m 1s)
#           acc: 0.99780, fpr: 0.00206, fnr: 0.00535, rec: 0.99465, prc: 0.95484, f1: 0.97433, f1_macro: 0.98659
# epoch: 26, passed number of graphs: 192, train running loss: 0.00279 (passed time: 1h 45m 29s)
#           acc: 0.99961, fpr: 0.00003, fnr: 0.00870, rec: 0.99130, prc: 0.99933, f1: 0.99530, f1_macro: 0.99755
# epoch: 26, passed number of graphs: 288, train running loss: 0.00252 (passed time: 1h 45m 57s)
#           acc: 0.99969, fpr: 0.00006, fnr: 0.00634, rec: 0.99366, prc: 0.99866, f1: 0.99615, f1_macro: 0.99799
# epoch: 26, passed number of graphs: 384, train running loss: 0.00256 (passed time: 1h 46m 25s)
#           acc: 0.99954, fpr: 0.00004, fnr: 0.00968, rec: 0.99032, prc: 0.99917, f1: 0.99472, f1_macro: 0.99724
# epoch: 26, passed number of graphs: 480, train running loss: 0.00283 (passed time: 1h 46m 53s)
#           acc: 0.99946, fpr: 0.00009, fnr: 0.01064, rec: 0.98936, prc: 0.99799, f1: 0.99366, f1_macro: 0.99669
# epoch: 26, passed number of graphs: 576, train running loss: 0.00269 (passed time: 1h 47m 20s)
#           acc: 0.99971, fpr: 0.00004, fnr: 0.00592, rec: 0.99408, prc: 0.99901, f1: 0.99654, f1_macro: 0.99819
# epoch: 26, passed number of graphs: 672, train running loss: 0.00279 (passed time: 1h 47m 48s)
#           acc: 0.99910, fpr: 0.00067, fnr: 0.00620, rec: 0.99380, prc: 0.98479, f1: 0.98927, f1_macro: 0.99440
# epoch: 26, passed number of graphs: 768, train running loss: 0.00287 (passed time: 1h 48m 16s)
#           acc: 0.99953, fpr: 0.00009, fnr: 0.00913, rec: 0.99087, prc: 0.99799, f1: 0.99442, f1_macro: 0.99709
# Validation --- epoch: 26, loss: 0.00411
#           prc: 0.98756, fnr: 0.02391, f1: 0.98041, acc: 0.99915, rec: 0.97609, fpr: 0.00034, f1_macro: 0.98999
# ...
# epoch: 42, passed number of graphs: 288, train running loss: 0.00251 (passed time: 2h 52m 27s)
#           acc: 0.99969, fpr: 0.00006, fnr: 0.00634, rec: 0.99366, prc: 0.99866, f1: 0.99615, f1_macro: 0.99799
# epoch: 42, passed number of graphs: 384, train running loss: 0.00255 (passed time: 2h 52m 55s)
#           acc: 0.99954, fpr: 0.00004, fnr: 0.00968, rec: 0.99032, prc: 0.99917, f1: 0.99472, f1_macro: 0.99724
# epoch: 42, passed number of graphs: 480, train running loss: 0.00283 (passed time: 2h 53m 23s)
#           acc: 0.99947, fpr: 0.00009, fnr: 0.01047, rec: 0.98953, prc: 0.99799, f1: 0.99374, f1_macro: 0.99673
# epoch: 42, passed number of graphs: 576, train running loss: 0.00268 (passed time: 2h 53m 51s)
#           acc: 0.99971, fpr: 0.00004, fnr: 0.00592, rec: 0.99408, prc: 0.99901, f1: 0.99654, f1_macro: 0.99819
# epoch: 42, passed number of graphs: 672, train running loss: 0.00279 (passed time: 2h 54m 18s)
#           acc: 0.99909, fpr: 0.00067, fnr: 0.00637, rec: 0.99363, prc: 0.98479, f1: 0.98919, f1_macro: 0.99436
# epoch: 42, passed number of graphs: 768, train running loss: 0.00286 (passed time: 2h 54m 47s)
#           acc: 0.99953, fpr: 0.00009, fnr: 0.00913, rec: 0.99087, prc: 0.99799, f1: 0.99442, f1_macro: 0.99709
# Validation --- epoch: 42, loss: 0.00411
#           prc: 0.98757, fnr: 0.02378, f1: 0.98048, acc: 0.99915, rec: 0.97622, fpr: 0.00034, f1_macro: 0.99003
# epoch: 43, passed number of graphs: 96, train running loss: 0.00305 (passed time: 2h 55m 41s)
#           acc: 0.99794, fpr: 0.00192, fnr: 0.00535, rec: 0.99465, prc: 0.95782, f1: 0.97589, f1_macro: 0.98740
# epoch: 43, passed number of graphs: 192, train running loss: 0.00278 (passed time: 2h 56m 9s)
#           acc: 0.99962, fpr: 0.00003, fnr: 0.00853, rec: 0.99147, prc: 0.99933, f1: 0.99538, f1_macro: 0.99759
# epoch: 43, passed number of graphs: 288, train running loss: 0.00251 (passed time: 2h 56m 36s)
#           acc: 0.99969, fpr: 0.00006, fnr: 0.00634, rec: 0.99366, prc: 0.99866, f1: 0.99615, f1_macro: 0.99799
# epoch: 43, passed number of graphs: 384, train running loss: 0.00255 (passed time: 2h 57m 4s)
#           acc: 0.99954, fpr: 0.00004, fnr: 0.00968, rec: 0.99032, prc: 0.99917, f1: 0.99472, f1_macro: 0.99724
# epoch: 43, passed number of graphs: 480, train running loss: 0.00283 (passed time: 2h 57m 31s)
#           acc: 0.99947, fpr: 0.00009, fnr: 0.01047, rec: 0.98953, prc: 0.99799, f1: 0.99374, f1_macro: 0.99673
# epoch: 43, passed number of graphs: 576, train running loss: 0.00268 (passed time: 2h 57m 59s)
#           acc: 0.99971, fpr: 0.00004, fnr: 0.00592, rec: 0.99408, prc: 0.99901, f1: 0.99654, f1_macro: 0.99819
# epoch: 43, passed number of graphs: 672, train running loss: 0.00279 (passed time: 2h 58m 27s)
#           acc: 0.99909, fpr: 0.00067, fnr: 0.00637, rec: 0.99363, prc: 0.98479, f1: 0.98919, f1_macro: 0.99436
# epoch: 43, passed number of graphs: 768, train running loss: 0.00286 (passed time: 2h 58m 55s)
#           acc: 0.99953, fpr: 0.00009, fnr: 0.00913, rec: 0.99087, prc: 0.99799, f1: 0.99442, f1_macro: 0.99709
# Validation --- epoch: 43, loss: 0.00411
#           prc: 0.98757, fnr: 0.02378, f1: 0.98048, acc: 0.99915, rec: 0.97622, fpr: 0.00034, f1_macro: 0.99003
# epoch: 44, passed number of graphs: 96, train running loss: 0.00305 (passed time: 2h 59m 49s)
#           acc: 0.99794, fpr: 0.00192, fnr: 0.00535, rec: 0.99465, prc: 0.95782, f1: 0.97589, f1_macro: 0.98740
# epoch: 44, passed number of graphs: 192, train running loss: 0.00278 (passed time: 3h 0m 17s)
#           acc: 0.99962, fpr: 0.00003, fnr: 0.00853, rec: 0.99147, prc: 0.99933, f1: 0.99538, f1_macro: 0.99759
# epoch: 44, passed number of graphs: 288, train running loss: 0.00251 (passed time: 3h 0m 44s)
#           acc: 0.99969, fpr: 0.00006, fnr: 0.00634, rec: 0.99366, prc: 0.99866, f1: 0.99615, f1_macro: 0.99799
# epoch: 44, passed number of graphs: 384, train running loss: 0.00255 (passed time: 3h 1m 12s)
#           acc: 0.99954, fpr: 0.00004, fnr: 0.00968, rec: 0.99032, prc: 0.99917, f1: 0.99472, f1_macro: 0.99724
# epoch: 44, passed number of graphs: 480, train running loss: 0.00283 (passed time: 3h 1m 41s)
#           acc: 0.99947, fpr: 0.00009, fnr: 0.01047, rec: 0.98953, prc: 0.99799, f1: 0.99374, f1_macro: 0.99673
# epoch: 44, passed number of graphs: 576, train running loss: 0.00268 (passed time: 3h 2m 9s)
#           acc: 0.99971, fpr: 0.00004, fnr: 0.00592, rec: 0.99408, prc: 0.99901, f1: 0.99654, f1_macro: 0.99819
# epoch: 44, passed number of graphs: 672, train running loss: 0.00279 (passed time: 3h 2m 37s)
#           acc: 0.99909, fpr: 0.00067, fnr: 0.00637, rec: 0.99363, prc: 0.98479, f1: 0.98919, f1_macro: 0.99436
# epoch: 44, passed number of graphs: 768, train running loss: 0.00286 (passed time: 3h 3m 5s)
#           acc: 0.99953, fpr: 0.00009, fnr: 0.00913, rec: 0.99087, prc: 0.99799, f1: 0.99442, f1_macro: 0.99709
# Validation --- epoch: 44, loss: 0.00411
#           prc: 0.98757, fnr: 0.02378, f1: 0.98048, acc: 0.99915, rec: 0.97622, fpr: 0.00034, f1_macro: 0.99003
# epoch: 45, passed number of graphs: 96, train running loss: 0.00305 (passed time: 3h 3m 59s)
#           acc: 0.99794, fpr: 0.00192, fnr: 0.00535, rec: 0.99465, prc: 0.95782, f1: 0.97589, f1_macro: 0.98740
# epoch: 45, passed number of graphs: 192, train running loss: 0.00278 (passed time: 3h 4m 26s)
#           acc: 0.99962, fpr: 0.00003, fnr: 0.00853, rec: 0.99147, prc: 0.99933, f1: 0.99538, f1_macro: 0.99759
# epoch: 45, passed number of graphs: 288, train running loss: 0.00251 (passed time: 3h 4m 53s)
#           acc: 0.99969, fpr: 0.00006, fnr: 0.00634, rec: 0.99366, prc: 0.99866, f1: 0.99615, f1_macro: 0.99799
# epoch: 45, passed number of graphs: 384, train running loss: 0.00255 (passed time: 3h 5m 21s)
#           acc: 0.99954, fpr: 0.00004, fnr: 0.00968, rec: 0.99032, prc: 0.99917, f1: 0.99472, f1_macro: 0.99724
# epoch: 45, passed number of graphs: 480, train running loss: 0.00283 (passed time: 3h 5m 49s)
#           acc: 0.99947, fpr: 0.00009, fnr: 0.01047, rec: 0.98953, prc: 0.99799, f1: 0.99374, f1_macro: 0.99673
# epoch: 45, passed number of graphs: 576, train running loss: 0.00268 (passed time: 3h 6m 16s)
#           acc: 0.99971, fpr: 0.00004, fnr: 0.00592, rec: 0.99408, prc: 0.99901, f1: 0.99654, f1_macro: 0.99819
# epoch: 45, passed number of graphs: 672, train running loss: 0.00279 (passed time: 3h 6m 44s)
#           acc: 0.99909, fpr: 0.00067, fnr: 0.00637, rec: 0.99363, prc: 0.98479, f1: 0.98919, f1_macro: 0.99436
# epoch: 45, passed number of graphs: 768, train running loss: 0.00286 (passed time: 3h 7m 13s)
#           acc: 0.99953, fpr: 0.00009, fnr: 0.00913, rec: 0.99087, prc: 0.99799, f1: 0.99442, f1_macro: 0.99709
# Validation --- epoch: 45, loss: 0.00411
#           prc: 0.98757, fnr: 0.02378, f1: 0.98048, acc: 0.99915, rec: 0.97622, fpr: 0.00034, f1_macro: 0.99003
# epoch: 46, passed number of graphs: 96, train running loss: 0.00305 (passed time: 3h 8m 6s)
#           acc: 0.99794, fpr: 0.00192, fnr: 0.00535, rec: 0.99465, prc: 0.95782, f1: 0.97589, f1_macro: 0.98740
# epoch: 46, passed number of graphs: 192, train running loss: 0.00278 (passed time: 3h 8m 34s)
#           acc: 0.99962, fpr: 0.00003, fnr: 0.00853, rec: 0.99147, prc: 0.99933, f1: 0.99538, f1_macro: 0.99759
# epoch: 46, passed number of graphs: 288, train running loss: 0.00251 (passed time: 3h 9m 2s)
#           acc: 0.99969, fpr: 0.00006, fnr: 0.00634, rec: 0.99366, prc: 0.99866, f1: 0.99615, f1_macro: 0.99799
# epoch: 46, passed number of graphs: 384, train running loss: 0.00255 (passed time: 3h 9m 29s)
#           acc: 0.99954, fpr: 0.00004, fnr: 0.00968, rec: 0.99032, prc: 0.99917, f1: 0.99472, f1_macro: 0.99724
# epoch: 46, passed number of graphs: 480, train running loss: 0.00283 (passed time: 3h 9m 57s)
#           acc: 0.99947, fpr: 0.00009, fnr: 0.01047, rec: 0.98953, prc: 0.99799, f1: 0.99374, f1_macro: 0.99673
# epoch: 46, passed number of graphs: 576, train running loss: 0.00268 (passed time: 3h 10m 25s)
#           acc: 0.99971, fpr: 0.00004, fnr: 0.00592, rec: 0.99408, prc: 0.99901, f1: 0.99654, f1_macro: 0.99819
# epoch: 46, passed number of graphs: 672, train running loss: 0.00279 (passed time: 3h 10m 53s)
#           acc: 0.99909, fpr: 0.00067, fnr: 0.00637, rec: 0.99363, prc: 0.98479, f1: 0.98919, f1_macro: 0.99436
# epoch: 46, passed number of graphs: 768, train running loss: 0.00286 (passed time: 3h 11m 21s)
#           acc: 0.99953, fpr: 0.00009, fnr: 0.00913, rec: 0.99087, prc: 0.99799, f1: 0.99442, f1_macro: 0.99709
# Validation --- epoch: 46, loss: 0.00411
#           prc: 0.98757, fnr: 0.02378, f1: 0.98048, acc: 0.99915, rec: 0.97622, fpr: 0.00034, f1_macro: 0.99003
# epoch: 47, passed number of graphs: 96, train running loss: 0.00305 (passed time: 3h 12m 16s)
#           acc: 0.99794, fpr: 0.00192, fnr: 0.00535, rec: 0.99465, prc: 0.95782, f1: 0.97589, f1_macro: 0.98740
# epoch: 47, passed number of graphs: 192, train running loss: 0.00278 (passed time: 3h 12m 44s)
#           acc: 0.99962, fpr: 0.00003, fnr: 0.00853, rec: 0.99147, prc: 0.99933, f1: 0.99538, f1_macro: 0.99759
# epoch: 47, passed number of graphs: 288, train running loss: 0.00251 (passed time: 3h 13m 11s)
#           acc: 0.99969, fpr: 0.00006, fnr: 0.00634, rec: 0.99366, prc: 0.99866, f1: 0.99615, f1_macro: 0.99799
# epoch: 47, passed number of graphs: 384, train running loss: 0.00255 (passed time: 3h 13m 39s)
#           acc: 0.99954, fpr: 0.00004, fnr: 0.00968, rec: 0.99032, prc: 0.99917, f1: 0.99472, f1_macro: 0.99724
# epoch: 47, passed number of graphs: 480, train running loss: 0.00283 (passed time: 3h 14m 7s)
#           acc: 0.99947, fpr: 0.00009, fnr: 0.01047, rec: 0.98953, prc: 0.99799, f1: 0.99374, f1_macro: 0.99673
# epoch: 47, passed number of graphs: 576, train running loss: 0.00268 (passed time: 3h 14m 35s)
#           acc: 0.99971, fpr: 0.00004, fnr: 0.00592, rec: 0.99408, prc: 0.99901, f1: 0.99654, f1_macro: 0.99819
# epoch: 47, passed number of graphs: 672, train running loss: 0.00279 (passed time: 3h 15m 2s)
#           acc: 0.99909, fpr: 0.00067, fnr: 0.00637, rec: 0.99363, prc: 0.98479, f1: 0.98919, f1_macro: 0.99436
# epoch: 47, passed number of graphs: 768, train running loss: 0.00286 (passed time: 3h 15m 30s)
#           acc: 0.99953, fpr: 0.00009, fnr: 0.00913, rec: 0.99087, prc: 0.99799, f1: 0.99442, f1_macro: 0.99709
# Validation --- epoch: 47, loss: 0.00411
#           prc: 0.98757, fnr: 0.02378, f1: 0.98048, acc: 0.99915, rec: 0.97622, fpr: 0.00034, f1_macro: 0.99003
# epoch: 48, passed number of graphs: 96, train running loss: 0.00305 (passed time: 3h 16m 24s)
#           acc: 0.99794, fpr: 0.00192, fnr: 0.00535, rec: 0.99465, prc: 0.95782, f1: 0.97589, f1_macro: 0.98740
# epoch: 48, passed number of graphs: 192, train running loss: 0.00278 (passed time: 3h 16m 52s)
#           acc: 0.99962, fpr: 0.00003, fnr: 0.00853, rec: 0.99147, prc: 0.99933, f1: 0.99538, f1_macro: 0.99759
# epoch: 48, passed number of graphs: 288, train running loss: 0.00251 (passed time: 3h 17m 19s)
#           acc: 0.99969, fpr: 0.00006, fnr: 0.00634, rec: 0.99366, prc: 0.99866, f1: 0.99615, f1_macro: 0.99799
# epoch: 48, passed number of graphs: 384, train running loss: 0.00255 (passed time: 3h 17m 47s)
#           acc: 0.99954, fpr: 0.00004, fnr: 0.00968, rec: 0.99032, prc: 0.99917, f1: 0.99472, f1_macro: 0.99724
# epoch: 48, passed number of graphs: 480, train running loss: 0.00283 (passed time: 3h 18m 15s)
#           acc: 0.99947, fpr: 0.00009, fnr: 0.01047, rec: 0.98953, prc: 0.99799, f1: 0.99374, f1_macro: 0.99673
# epoch: 48, passed number of graphs: 576, train running loss: 0.00268 (passed time: 3h 18m 43s)
#           acc: 0.99971, fpr: 0.00004, fnr: 0.00592, rec: 0.99408, prc: 0.99901, f1: 0.99654, f1_macro: 0.99819
# epoch: 48, passed number of graphs: 672, train running loss: 0.00279 (passed time: 3h 19m 11s)
#           acc: 0.99909, fpr: 0.00067, fnr: 0.00637, rec: 0.99363, prc: 0.98479, f1: 0.98919, f1_macro: 0.99436
# epoch: 48, passed number of graphs: 768, train running loss: 0.00286 (passed time: 3h 19m 39s)
#           acc: 0.99953, fpr: 0.00009, fnr: 0.00913, rec: 0.99087, prc: 0.99799, f1: 0.99442, f1_macro: 0.99709
# Validation --- epoch: 48, loss: 0.00411
#           prc: 0.98757, fnr: 0.02378, f1: 0.98048, acc: 0.99915, rec: 0.97622, fpr: 0.00034, f1_macro: 0.99003
# epoch: 49, passed number of graphs: 96, train running loss: 0.00305 (passed time: 3h 20m 33s)
#           acc: 0.99794, fpr: 0.00192, fnr: 0.00535, rec: 0.99465, prc: 0.95782, f1: 0.97589, f1_macro: 0.98740
# epoch: 49, passed number of graphs: 192, train running loss: 0.00278 (passed time: 3h 21m 0s)
#           acc: 0.99962, fpr: 0.00003, fnr: 0.00853, rec: 0.99147, prc: 0.99933, f1: 0.99538, f1_macro: 0.99759
# epoch: 49, passed number of graphs: 288, train running loss: 0.00251 (passed time: 3h 21m 28s)
#           acc: 0.99969, fpr: 0.00006, fnr: 0.00634, rec: 0.99366, prc: 0.99866, f1: 0.99615, f1_macro: 0.99799
# epoch: 49, passed number of graphs: 384, train running loss: 0.00255 (passed time: 3h 21m 56s)
#           acc: 0.99954, fpr: 0.00004, fnr: 0.00968, rec: 0.99032, prc: 0.99917, f1: 0.99472, f1_macro: 0.99724
# epoch: 49, passed number of graphs: 480, train running loss: 0.00283 (passed time: 3h 22m 24s)
#           acc: 0.99947, fpr: 0.00009, fnr: 0.01047, rec: 0.98953, prc: 0.99799, f1: 0.99374, f1_macro: 0.99673
# epoch: 49, passed number of graphs: 576, train running loss: 0.00268 (passed time: 3h 22m 52s)
#           acc: 0.99971, fpr: 0.00004, fnr: 0.00592, rec: 0.99408, prc: 0.99901, f1: 0.99654, f1_macro: 0.99819
# epoch: 49, passed number of graphs: 672, train running loss: 0.00279 (passed time: 3h 23m 20s)
#           acc: 0.99909, fpr: 0.00067, fnr: 0.00637, rec: 0.99363, prc: 0.98479, f1: 0.98919, f1_macro: 0.99436
# epoch: 49, passed number of graphs: 768, train running loss: 0.00286 (passed time: 3h 23m 48s)
#           acc: 0.99953, fpr: 0.00009, fnr: 0.00913, rec: 0.99087, prc: 0.99799, f1: 0.99442, f1_macro: 0.99709
# Validation --- epoch: 49, loss: 0.00411
#           prc: 0.98758, fnr: 0.02378, f1: 0.98048, acc: 0.99915, rec: 0.97622, fpr: 0.00034, f1_macro: 0.99003
# epoch: 50, passed number of graphs: 96, train running loss: 0.00305 (passed time: 3h 24m 41s)
#           acc: 0.99794, fpr: 0.00192, fnr: 0.00535, rec: 0.99465, prc: 0.95782, f1: 0.97589, f1_macro: 0.98740
# epoch: 50, passed number of graphs: 192, train running loss: 0.00278 (passed time: 3h 25m 8s)
#           acc: 0.99962, fpr: 0.00003, fnr: 0.00853, rec: 0.99147, prc: 0.99933, f1: 0.99538, f1_macro: 0.99759
# epoch: 50, passed number of graphs: 288, train running loss: 0.00251 (passed time: 3h 25m 36s)
#           acc: 0.99969, fpr: 0.00006, fnr: 0.00634, rec: 0.99366, prc: 0.99866, f1: 0.99615, f1_macro: 0.99799
# epoch: 50, passed number of graphs: 384, train running loss: 0.00255 (passed time: 3h 26m 3s)
#           acc: 0.99954, fpr: 0.00004, fnr: 0.00968, rec: 0.99032, prc: 0.99917, f1: 0.99472, f1_macro: 0.99724
# epoch: 50, passed number of graphs: 480, train running loss: 0.00283 (passed time: 3h 26m 31s)
#           acc: 0.99947, fpr: 0.00009, fnr: 0.01047, rec: 0.98953, prc: 0.99799, f1: 0.99374, f1_macro: 0.99673
# epoch: 50, passed number of graphs: 576, train running loss: 0.00268 (passed time: 3h 26m 58s)
#           acc: 0.99971, fpr: 0.00004, fnr: 0.00592, rec: 0.99408, prc: 0.99901, f1: 0.99654, f1_macro: 0.99819
# epoch: 50, passed number of graphs: 672, train running loss: 0.00279 (passed time: 3h 27m 25s)
#           acc: 0.99909, fpr: 0.00067, fnr: 0.00637, rec: 0.99363, prc: 0.98479, f1: 0.98919, f1_macro: 0.99436
# epoch: 50, passed number of graphs: 768, train running loss: 0.00286 (passed time: 3h 27m 53s)
#           acc: 0.99953, fpr: 0.00009, fnr: 0.00913, rec: 0.99087, prc: 0.99799, f1: 0.99442, f1_macro: 0.99709
# Validation --- epoch: 50, loss: 0.00411
#           prc: 0.98758, fnr: 0.02378, f1: 0.98048, acc: 0.99915, rec: 0.97622, fpr: 0.00034, f1_macro: 0.99003
# ************ best model obtained after epoch 15, saved at ./saved_models/GIN_14: 0.9808227176211669.pt ************
# Testing --- loss: 0.00316
#           prc: 0.99659, fnr: 0.02504, f1: 0.98456, acc: 0.99940, rec: 0.97496, fpr: 0.00007, f1_macro: 0.99213

# %%
# !zip -r /content/GENConv_p2p_6k_feat_norm.zip /content/saved_models
# Out:
#   adding: content/saved_models/ (stored 0%)
#   adding: content/saved_models/GIN_1: 4.669655246024122e-05.pt (deflated 21%)
#   adding: content/saved_models/GIN_8: 0.9781915244480687.pt (deflated 25%)
#   adding: content/saved_models/GIN_14: 0.9808227176211669.pt (deflated 28%)
#   adding: content/saved_models/GIN_3: 0.8557298622683676.pt (deflated 19%)
#   adding: content/saved_models/GIN_2: 0.05430041078252482.pt (deflated 20%)
#   adding: content/saved_models/GIN_7: 0.9251264886891778.pt (deflated 24%)

# %%
from google.colab import files
files.download("/content/GENConv_p2p_6k_feat_norm.zip")

# %%
from google.colab import runtime
runtime.unassign()
