# %% [markdown]
# <a href="https://colab.research.google.com/github/Zoro1092000/xxxx/blob/main/01_09_GATv2Conv_p2p_6k_feat_norm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # I. Pip & Import.

# %%
import os
import os.path as osp
import torch
import sys

os.environ['TORCH'] = torch.__version__

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install torch-geometric
# !pip install torch-cluster -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install deepdish==0.3.5
# !pip install torch-optimizer

import torch.nn as nn
from torch.nn import Parameter
from torch_geometric.utils import scatter
from torch_geometric.nn.inits import glorot, zeros
from torch_scatter import scatter_add
from torch.utils.data import DataLoader, Dataset
import torch_optimizer as optimization


from itertools import chain
import pickle
import h5py
import deepdish as dd
import numpy as np
from tqdm import tqdm
import inspect
import time
import math
import random
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-geometric in /usr/local/lib/python3.7/dist-packages (2.1.0.post1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.11.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.7.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.0.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (3.0.9)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (1.21.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (4.64.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torch-geometric) (2.23.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->torch-geometric) (2.0.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torch-geometric) (2022.9.24)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->torch-geometric) (1.2.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://data.pyg.org/whl/torch-1.12.1+cu113.html
# Requirement already satisfied: torch-cluster in /usr/local/lib/python3.7/dist-packages (1.6.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: deepdish==0.3.5 in /usr/local/lib/python3.7/dist-packages (0.3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (1.7.3)
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (from deepdish==0.3.5) (3.7.0)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (2.8.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tables->deepdish==0.3.5) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tables->deepdish==0.3.5) (3.0.9)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch-optimizer in /usr/local/lib/python3.7/dist-packages (0.3.0)
# Requirement already satisfied: torch>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from torch-optimizer) (1.12.1+cu113)
# Requirement already satisfied: pytorch-ranger>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from torch-optimizer) (0.1.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.5.0->torch-optimizer) (4.1.1)

# %%
def time_since(start):
    now = time.time()
    s = now - start
    m = math.floor(s / 60)
    s -= m * 60
    h = math.floor(m / 60)
    m -= h * 60
    if h == 0:
        if m == 0:
            return '%ds' % s
        else:
            return '%dm %ds' % (m, s)
    else:
        return '%dh %dm %ds' % (h, m, s)

# %% [markdown]
# # II. Data

# %%
# Data utils
def h5group_to_dict(h5group):
    group_dict = {k: v[()] for k, v in chain(h5group.items(), h5group.attrs.items())}
    return group_dict

def sub_dict(full_dict, *keys, to_tensor):
    return {k: torch.tensor(full_dict[k]) if to_tensor else full_dict[k] for k in keys if k in full_dict}

def build_graph_from_dict_pyg(graph_dict, to_tensor=True):
    from torch_geometric.data import Data

    g = Data(**sub_dict(graph_dict, 'edge_index', 'x', 'y', 'edge_attr', 'edge_y', to_tensor=to_tensor))
    return g

# Data loader
class GraphDataLoader(DataLoader):
    def __init__(self, dataset, batch_size=128, shuffle=False, num_workers=0):

        def collate_graph(graph_obj_list):
            from torch_geometric.data import Batch
            batch = Batch.from_data_list(graph_obj_list)
            return batch

        super().__init__(
            dataset,
            batch_size=batch_size,
            shuffle=shuffle,
            collate_fn=collate_graph,
            num_workers=num_workers)

# BotnetDataset
class BotnetDataset(Dataset):

    def __init__(self, name='chord', root='data/botnet', split='train', graph_format='pyg', split_idx=None, add_nfeat_ones=True,
                 in_memory=True):
        super().__init__()
        assert name in ['chord', 'debru', 'kadem', 'leet', 'c2', 'p2p']
        assert split in ['train', 'val', 'test']

        if isinstance(root, str):
            root = osp.expanduser(osp.normpath(root))

        self.name = name
        self.root = root
        self.split = split
        self.split_idx = split_idx
        self.add_nfeat_ones = add_nfeat_ones

        self._graph_format = graph_format
        if split == 'train':
            self.path = self.processed_paths[0]
            self.num_graphs = 768
        elif split == 'val':
            self.path = self.processed_paths[1]
            self.num_graphs = 96
        elif split == 'test':
            self.path = self.processed_paths[2]
            self.num_graphs = 96

        if in_memory:
            self.data = dd.io.load(self.path)  # dictionary
            self.data_type = 'dict'
        else:
            # self.data = h5py.File(self.path, 'r')
            self.data = None    # defer opening file in each process to make multiprocessing work
            self.data_type = 'file'
            
    @property
    def processed_dir(self):
        return osp.join(self.root, 'processed')

    @property
    def processed_file_names(self):
        return [self.name + '_' + s + '.hdf5' for s in ('train', 'val', 'test')]

    @property
    def processed_paths(self):
        return [osp.join(self.processed_dir, f) for f in self.processed_file_names]

    def __len__(self):
        return self.num_graphs

    def __getitem__(self, index):
        if self.data_type == 'dict':
            graph_dict = self.data[str(index)]
        elif self.data_type == 'file':
            if self.data is None:
                # only open once in each process
                self.data = h5py.File(self.path, 'r')
            graph_dict = h5group_to_dict(self.data[str(index)])
        else:
            raise ValueError

        # graph_format == 'pyg':
        return build_graph_from_dict_pyg(graph_dict)


    def __iter__(self):
        for i in range(self.num_graphs):
            yield self[i]

    def __repr__(self):
        return f'{self.__class__.__name__}(topology: {self.name} | split: {self.split} | ' \
               f'#graphs: {len(self)} | graph format: {self.graph_format})'

# %% [markdown]
# # III. Measure Performancce

# %% [markdown]
# ## 3.1. Metrics

# %%
def f1(target, pred, label):
    # F1 = 2 * (precision * recall) / (precision + recall)
    tp = np.sum((target==label) & (pred==label))
    fp = np.sum((target!=label) & (pred==label))
    fn = np.sum((pred!=label) & (target==label))
    
    if tp+fp==0 or tp+fn==0:
      return np.nan

    precision = tp/(tp+fp)
    recall = tp/(tp+fn)
    
    if precision+recall==0:
      return np.nan
      
    f1 = 2 * (precision * recall) / (precision + recall)
    return f1

def f1_macro(pred, target):
    return np.mean([f1(target, pred, label) for label in range(0, 2)])


def accuracy(pred, target):
    return (pred == target).sum().item() / len(target)


def true_positive(pred, target):
    return (target[pred == 1] == 1).sum().item()


def false_positive(pred, target):
    return (target[pred == 1] == 0).sum().item()


def true_negative(pred, target):
    return (target[pred == 0] == 0).sum().item()


def false_negative(pred, target):
    return (target[pred == 0] == 1).sum().item()


def recall(pred, target):
    try:
        return true_positive(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1


def precision(pred, target):
    try:
        prec = true_positive(pred, target) / (pred == 1).sum().item()
        return prec
    except:  # divide by zero
        return -1


def f1_score(pred, target):
    prec = precision(pred, target)
    rec = recall(pred, target)
    try:
        return 2 * (prec * rec) / (prec + rec)
    except:
        return 0


def false_positive_rate(pred, target):
    try:
        return false_positive(pred, target) / (target == 0).sum().item()
    except:  # divide by zero
        return -1


def false_negative_rate(pred, target):
    try:
        return false_negative(pred, target) / (target == 1).sum().item()
    except:  # divide by zero
        return -1

# %% [markdown]
# ## 3.2. Evaluation

# %%
def eval_metrics(target, pred_prob, threshold=0.5):
    if isinstance(target, torch.Tensor):
        target = target.cpu().numpy()
    if isinstance(pred_prob, torch.Tensor):
        pred_prob = pred_prob.cpu().numpy()

    pred = (pred_prob >= threshold).astype(int)

    acc = accuracy(pred, target)
    fpr = false_positive_rate(pred, target)
    fnr = false_negative_rate(pred, target)
    rec = recall(pred, target)
    prc = precision(pred, target)
    f1 = f1_score(pred, target)
    f1macro = f1_macro(pred, target)
    result_dict = {'acc': acc, 'fpr': fpr, 'fnr': fnr, 'rec': rec, 'prc': prc, 'f1': f1, 'f1_macro': f1macro}

    return result_dict


def dict_value_add(dict1, dict2):
    result = {key: dict1.get(key, 0) + dict2.get(key, 0)
              for key in set(dict1) | set(dict2)}
    return result


def dict_value_div(dict, n):
    result = {key: value / n for key, value in dict.items()}
    return result


def eval_predictor(dataset, predictor):
    result_dict_avg = {}
    loss_avg = 0

    for data in dataset:
        # prediction
        try:
            pred_prob, loss = predictor(data)
            loss_avg += loss
        except ValueError:  # if "too many values to unpack"
            pred_prob = predictor(data)

        # get the ground truth target
        # graph_format == 'pyg':
        target = data.y

        # compute the evaluation metrics
        result_dict = eval_metrics(target, pred_prob)

        result_dict_avg = dict_value_add(result_dict_avg, result_dict)

    # average the metrics across all graphs in the dataset as final results
    result_dict_avg = dict_value_div(result_dict_avg, len(dataset))
    loss_avg = loss_avg / len(dataset)

    return result_dict_avg, loss_avg


# =================================================================================================================
# some examples of the 'predictor' model wrapper to be fed into the above evaluation function (for PyG Data format)
# =================================================================================================================
class PygRandomPredictor:
    def __init__(self):
        # torch.manual_seed(0)
        pass

    def __call__(self, data):
        pred_prob = torch.rand(len(data.y))
        return pred_prob


class PygModelPredictor:
    def __init__(self, model, loss_fcn=torch.nn.CrossEntropyLoss()):
        self.model = model
        self.loss_fcn = loss_fcn
        self.device = next(model.parameters()).device

    def __call__(self, data):
        self.model.eval()
        data = data.to(self.device)
        with torch.no_grad():
            # custom the below line to adjust to your model's input format for forward pass
            out = self.model(data.x, data.edge_index)
            loss = self.loss_fcn(out, data.y.long())
            pred_prob = torch.softmax(out, dim=1)[:, 1]
        return pred_prob, loss.float()

# %% [markdown]
# # IV. Model

# %% [markdown]
# ## 5.1. Activation

# %%
def activation(act, negative_slope=0.2):
    activations = nn.ModuleDict([
        ['lrelu', nn.LeakyReLU(negative_slope)],
        ['relu', nn.ReLU()],
        ['elu', nn.ELU()],
        ['none', nn.Identity()],
    ])
    return activations[act]

# %% [markdown]
# ## 5.2. GIN model

# %%
from torch.nn.modules.activation import LeakyReLU
import torch.nn as nn

class GINModel(nn.Module):
    def __init__(self, dim_input_feature, dim_hidden_feature, num_layers, num_classes, non_linear='relu', dropout=0.2):
        super().__init__()

        self.dim_input_feature = dim_input_feature
        self.dim_hidden_feature = dim_hidden_feature

        self.num_layers = num_layers
        self.num_classes = num_classes
        
        from torch.nn import Linear, Sequential, BatchNorm1d, ReLU, Dropout
        from torch_geometric.nn import GATv2Conv, GINConv, TransformerConv
        
        self.gin_net = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.gin_net.append(GATv2Conv(self.dim_input_feature, self.dim_hidden_feature, heads=1, concat=False))
          else:
            self.gin_net.append(GATv2Conv(self.dim_hidden_feature, self.dim_hidden_feature, heads=1, concat=False))


        self.dropout = nn.Dropout(dropout)

        self.residuals = nn.ModuleList()
        for i in range(self.num_layers):
          if i == 0:
            self.residuals.append(nn.Linear(self.dim_input_feature, self.dim_hidden_feature, bias=True))
          else:
            self.residuals.append(nn.Identity())

        self.num_residuals = len(self.residuals)

        self.non_linear = activation(non_linear)

        # self.final_type == 'proj':
        self.final = nn.Linear(self.dim_hidden_feature, num_classes)

    def reset_parameters(self):
        for net in self.gin_net:
            net.reset_parameters()
        # self.residual_hop = 1
        for net in self.residuals:
            net.reset_parameters()
        # self.final_type != 'none':
        self.final.reset_parameters()

    def forward(self, x, edge_index):
        xr = None
        add_xr_at = -1

        for n, net in enumerate(self.gin_net):
            # pass to a GIN layer with non-linear activation
            xo = net(x, edge_index)
            xo = self.dropout(xo)
            # deal with residual connections
            # self.residual_hop = 1
            if n < self.num_residuals:
                xr = self.residuals[n](x)
                xo = self.non_linear(xo + xr)

            x = xo
        # size of x: (B * N, dim_hidden_feature) -> (B * N, num_classes)
        x = self.final(x)

        return x

# %% [markdown]
# # V. Load data

# %%
data_dir = '/content/drive/Shareddrives/botnetdata/p2p_6k_feat_norm'
data_name = 'p2p' # 'chord', 'debru', 'kadem', 'leet', 'c2', 'p2p'
shuffle = False

# ========== load the dataset
print('loading dataset...')

train_ds = BotnetDataset(name=data_name, root=data_dir, split='train',
                         in_memory=False, graph_format='pyg')
val_ds = BotnetDataset(name=data_name, root=data_dir, split='val',
                       in_memory=False, graph_format='pyg')
test_ds = BotnetDataset(name=data_name, root=data_dir, split='test',
                        in_memory=False, graph_format='pyg')
# Out:
# loading dataset...

# %%
batch_size = 1
train_loader = GraphDataLoader(train_ds, batch_size=batch_size, shuffle=bool(shuffle), num_workers=0)

# %% [markdown]
# # VI. Train

# %%
# ============== some default parameters =============
devid = 0
seed = 0
logmode = 'w'
log_interval = 96

dim_input_feature = 1
dim_hidden_feature = 32
act = 'relu' # 'none', 'lrelu', 'relu', 'elu'

num_layers = 12
num_classes = 2 

dropout = 0.0
bias = True

lr = 0.005 # learning rate
weight_decay = 5e-4
epochs = 50
save_dir = './saved_models'
save_name = "GIN_model.pt"
# ====================================================

def train(model, train_loader, val_dataset, test_dataset, optimizer, scheduler=None):
    device = next(model.parameters()).device
    predictor = PygModelPredictor(model)

    best_epoch = 0
    max_f1_score = 0
    start = time.time()
    for ep in range(epochs):
        loss_avg_train = 0
        num_train_graph = 0
        model.train()
        for n, batch in enumerate(train_loader):
            batch.to(device)

            optimizer.zero_grad()

            x = model(batch.x, batch.edge_index)
            loss = criterion(x, batch.y.long())

            loss_avg_train += float(loss)
            num_train_graph += batch.num_graphs

            loss.backward()
            optimizer.step()

            if num_train_graph % log_interval == 0 or n == len(train_loader) - 1:
                with torch.no_grad():
                    # pred = x.argmax(dim=1)
                    pred_prob = torch.softmax(x, dim=1)[:, 1]
                    y = batch.y.long()
                    result_dict = eval_metrics(y, pred_prob)
                print(f'epoch: {ep + 1}, passed number of graphs: {num_train_graph}, '
                        f'train running loss: {loss_avg_train / num_train_graph:.5f} (passed time: {time_since(start)})')
                print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict.items()]))

        result_dict_avg, loss_avg = eval_predictor(val_dataset, predictor)
        print(f'Validation --- epoch: {ep + 1}, loss: {loss_avg:.5f}')
        print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))

        if scheduler is not None:
            scheduler.step(loss_avg)

        if result_dict_avg['f1'] > max_f1_score:
            save_name = f"GIN_{ep}: {result_dict_avg['f1']}.pt"
            torch.save(model, os.path.join(save_dir, save_name))
            print(f'Better model saved at {os.path.join(save_dir, save_name)}.')
            best_epoch = ep
            max_f1_score = result_dict_avg['f1']

    best_model = torch.load(os.path.join(save_dir, save_name))
    print('*' * 12 + f' best model obtained after epoch {best_epoch + 1}, '
                       f'saved at {os.path.join(save_dir, save_name)} ' + '*' * 12)
    
    predictor = PygModelPredictor(best_model)

    result_dict_avg, loss_avg = eval_predictor(test_dataset, predictor)
    print(f'Testing --- loss: {loss_avg:.5f}')
    print(' ' * 10 + ', '.join(['{}: {:.5f}'.format(k, v) for k, v in result_dict_avg.items()]))


if __name__ == '__main__':
    os.makedirs(save_dir, exist_ok=True)

    # ========== random seeds and device
    random.seed(seed)
    torch.manual_seed(seed)

    device = torch.device(f'cuda:{devid}') if devid > -1 else torch.device('cpu')

    # ========== logging setup
    log_name = os.path.splitext(save_name)[0]
    # logger = logging_config(__name__, folder=save_dir, name=log_name, filemode=logmode)
    # logger = logging_config(os.path.basename(__file__), folder=save_dir, name=log_name, filemode=logmode)

    print('python ' + ' '.join(sys.argv))
    print('-' * 30)
    #logger.info(args)
    print('-' * 30)
    print(time.ctime())
    print('-' * 30)

    # ========== define the model, optimizer, and loss

    model = GINModel(dim_input_feature,
                     dim_hidden_feature,
                     num_layers,
                     num_classes,
                     non_linear=act,
                     dropout=dropout)

    print('model ' + '-' * 10)
    print(repr(model))
    model.to(device)

    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.25, patience=1)

    # ========== train the model
    print(f"Batch size: {batch_size}")
    train(model, train_loader, val_ds, test_ds, optimizer, scheduler)
# Out:
# python /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py -f /root/.local/share/jupyter/runtime/kernel-f992536d-3e55-40a7-b5e5-500d4fb6c7a1.json
# ------------------------------
# ------------------------------
# Fri Nov  4 14:12:37 2022
# ------------------------------
# model ----------
# GATModel(
#   (gin_net): ModuleList(
#     (0): GATv2Conv(1, 32, heads=1)
#     (1): GATv2Conv(32, 32, heads=1)
#     (2): GATv2Conv(32, 32, heads=1)
#     (3): GATv2Conv(32, 32, heads=1)
#     (4): GATv2Conv(32, 32, heads=1)
#     (5): GATv2Conv(32, 32, heads=1)
#     (6): GATv2Conv(32, 32, heads=1)
#     (7): GATv2Conv(32, 32, heads=1)
#     (8): GATv2Conv(32, 32, heads=1)
#     (9): GATv2Conv(32, 32, heads=1)
#     (10): GATv2Conv(32, 32, heads=1)
#     (11): GATv2Conv(32, 32, heads=1)
#   )
#   (dropout): Dropout(p=0.0, inplace=False)
#   (residuals): ModuleList(
#     (0): Linear(in_features=1, out_features=32, bias=True)
#     (1): Identity()
#     (2): Identity()
#     (3): Identity()
#     (4): Identity()
#     (5): Identity()
#     (6): Identity()
#     (7): Identity()
#     (8): Identity()
#     (9): Identity()
#     (10): Identity()
#     (11): Identity()
#   )
#   (non_linear): ReLU()
#   (final): Linear(in_features=32, out_features=2, bias=True)
# )
# Batch size: 1
# epoch: 1, passed number of graphs: 96, train running loss: 0.73183 (passed time: 3m 12s)
#           acc: 0.95801, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 192, train running loss: 0.64278 (passed time: 4m 14s)
#           acc: 0.95840, fpr: 0.00000, fnr: 1.00000, rec: 0.00000, prc: -1.00000, f1: 0.00000, f1_macro: nan
# epoch: 1, passed number of graphs: 288, train running loss: 0.62388 (passed time: 5m 13s)
#           acc: 0.91391, fpr: 0.04958, fnr: 0.94410, rec: 0.05590, prc: 0.04578, f1: 0.05033, f1_macro: 0.50262
# epoch: 1, passed number of graphs: 384, train running loss: 0.55511 (passed time: 6m 11s)
#           acc: 0.98208, fpr: 0.00716, fnr: 0.25439, rec: 0.74561, prc: 0.82585, f1: 0.78368, f1_macro: 0.88717
# epoch: 1, passed number of graphs: 480, train running loss: 0.45802 (passed time: 7m 9s)
#           acc: 0.99583, fpr: 0.00428, fnr: 0.00166, rec: 0.99834, prc: 0.91167, f1: 0.95304, f1_macro: 0.97543
# epoch: 1, passed number of graphs: 576, train running loss: 0.38851 (passed time: 8m 6s)
#           acc: 0.98971, fpr: 0.01052, fnr: 0.00509, rec: 0.99491, prc: 0.80690, f1: 0.89110, f1_macro: 0.94285
# epoch: 1, passed number of graphs: 672, train running loss: 0.33777 (passed time: 9m 2s)
#           acc: 0.99423, fpr: 0.00051, fnr: 0.12653, rec: 0.87347, prc: 0.98672, f1: 0.92665, f1_macro: 0.96182
# epoch: 1, passed number of graphs: 768, train running loss: 0.29900 (passed time: 10m 0s)
#           acc: 0.99984, fpr: 0.00015, fnr: 0.00050, rec: 0.99950, prc: 0.99669, f1: 0.99809, f1_macro: 0.99900
# Validation --- epoch: 1, loss: 0.00580
#           fnr: 0.01438, f1: 0.98832, rec: 0.98562, f1_macro: 0.99405, fpr: 0.00014, prc: 0.99338, acc: 0.99955
# Better model saved at ./saved_models/GIN_0: 0.9883182370064715.pt.
# epoch: 2, passed number of graphs: 96, train running loss: 0.01941 (passed time: 11m 46s)
#           acc: 0.99938, fpr: 0.00065, fnr: 0.00000, rec: 1.00000, prc: 0.98545, f1: 0.99267, f1_macro: 0.99617
# epoch: 2, passed number of graphs: 192, train running loss: 0.02336 (passed time: 12m 35s)
#           acc: 0.98095, fpr: 0.01988, fnr: 0.00000, rec: 1.00000, prc: 0.68586, f1: 0.81366, f1_macro: 0.90181
# epoch: 2, passed number of graphs: 288, train running loss: 0.02124 (passed time: 13m 23s)
#           acc: 0.99969, fpr: 0.00031, fnr: 0.00017, rec: 0.99983, prc: 0.99271, f1: 0.99626, f1_macro: 0.99805
# epoch: 2, passed number of graphs: 384, train running loss: 0.01909 (passed time: 14m 12s)
#           acc: 0.99292, fpr: 0.00740, fnr: 0.00000, rec: 1.00000, prc: 0.86011, f1: 0.92479, f1_macro: 0.96054
# epoch: 2, passed number of graphs: 480, train running loss: 0.01973 (passed time: 15m 0s)
#           acc: 0.99963, fpr: 0.00037, fnr: 0.00050, rec: 0.99950, prc: 0.99175, f1: 0.99561, f1_macro: 0.99771
# epoch: 2, passed number of graphs: 576, train running loss: 0.01686 (passed time: 15m 48s)
#           acc: 0.99989, fpr: 0.00007, fnr: 0.00099, rec: 0.99901, prc: 0.99836, f1: 0.99869, f1_macro: 0.99931
# epoch: 2, passed number of graphs: 672, train running loss: 0.02309 (passed time: 16m 36s)
#           acc: 0.99335, fpr: 0.00694, fnr: 0.00000, rec: 1.00000, prc: 0.86243, f1: 0.92614, f1_macro: 0.96133
# epoch: 2, passed number of graphs: 768, train running loss: 0.02214 (passed time: 17m 25s)
#           acc: 0.99985, fpr: 0.00014, fnr: 0.00050, rec: 0.99950, prc: 0.99685, f1: 0.99818, f1_macro: 0.99905
# Validation --- epoch: 2, loss: 0.00304
#           fnr: 0.00691, f1: 0.98759, rec: 0.99309, f1_macro: 0.99367, fpr: 0.00037, prc: 0.98359, acc: 0.99949
# epoch: 3, passed number of graphs: 96, train running loss: 0.01462 (passed time: 18m 48s)
#           acc: 0.99816, fpr: 0.00192, fnr: 0.00000, rec: 1.00000, prc: 0.95804, f1: 0.97857, f1_macro: 0.98880
# epoch: 3, passed number of graphs: 192, train running loss: 0.01206 (passed time: 19m 37s)
#           acc: 0.99993, fpr: 0.00006, fnr: 0.00033, rec: 0.99967, prc: 0.99866, f1: 0.99916, f1_macro: 0.99956
# epoch: 3, passed number of graphs: 288, train running loss: 0.00906 (passed time: 20m 25s)
#           acc: 0.99981, fpr: 0.00019, fnr: 0.00017, rec: 0.99983, prc: 0.99551, f1: 0.99767, f1_macro: 0.99878
# epoch: 3, passed number of graphs: 384, train running loss: 0.00834 (passed time: 21m 13s)
#           acc: 0.99978, fpr: 0.00023, fnr: 0.00000, rec: 1.00000, prc: 0.99494, f1: 0.99746, f1_macro: 0.99867
# epoch: 3, passed number of graphs: 480, train running loss: 0.00851 (passed time: 22m 2s)
#           acc: 0.99968, fpr: 0.00032, fnr: 0.00050, rec: 0.99950, prc: 0.99290, f1: 0.99619, f1_macro: 0.99801
# epoch: 3, passed number of graphs: 576, train running loss: 0.00732 (passed time: 22m 50s)
#           acc: 0.99983, fpr: 0.00015, fnr: 0.00049, rec: 0.99951, prc: 0.99656, f1: 0.99803, f1_macro: 0.99897
# epoch: 3, passed number of graphs: 672, train running loss: 0.00676 (passed time: 23m 39s)
#           acc: 0.99892, fpr: 0.00112, fnr: 0.00000, rec: 1.00000, prc: 0.97485, f1: 0.98727, f1_macro: 0.99335
# epoch: 3, passed number of graphs: 768, train running loss: 0.00644 (passed time: 24m 27s)
#           acc: 0.99987, fpr: 0.00013, fnr: 0.00000, rec: 1.00000, prc: 0.99702, f1: 0.99851, f1_macro: 0.99922
# Validation --- epoch: 3, loss: 0.00167
#           fnr: 0.00435, f1: 0.99388, rec: 0.99565, f1_macro: 0.99688, fpr: 0.00015, prc: 0.99331, acc: 0.99976
# Better model saved at ./saved_models/GIN_2: 0.9938825470663728.pt.
# epoch: 4, passed number of graphs: 96, train running loss: 0.00350 (passed time: 25m 50s)
#           acc: 0.99802, fpr: 0.00207, fnr: 0.00000, rec: 1.00000, prc: 0.95492, f1: 0.97694, f1_macro: 0.98795
# epoch: 4, passed number of graphs: 192, train running loss: 0.00276 (passed time: 26m 39s)
#           acc: 0.99994, fpr: 0.00005, fnr: 0.00017, rec: 0.99983, prc: 0.99883, f1: 0.99933, f1_macro: 0.99965
# epoch: 4, passed number of graphs: 288, train running loss: 0.00222 (passed time: 27m 26s)
#           acc: 0.99982, fpr: 0.00017, fnr: 0.00033, rec: 0.99967, prc: 0.99601, f1: 0.99783, f1_macro: 0.99887
# epoch: 4, passed number of graphs: 384, train running loss: 0.00430 (passed time: 28m 16s)
#           acc: 0.99832, fpr: 0.00176, fnr: 0.00000, rec: 1.00000, prc: 0.96286, f1: 0.98108, f1_macro: 0.99010
# epoch: 4, passed number of graphs: 480, train running loss: 0.00838 (passed time: 29m 4s)
#           acc: 0.98998, fpr: 0.01044, fnr: 0.00050, rec: 0.99950, prc: 0.80920, f1: 0.89434, f1_macro: 0.94454
# epoch: 4, passed number of graphs: 576, train running loss: 0.00753 (passed time: 29m 52s)
#           acc: 0.99942, fpr: 0.00061, fnr: 0.00000, rec: 1.00000, prc: 0.98639, f1: 0.99315, f1_macro: 0.99642
# epoch: 4, passed number of graphs: 672, train running loss: 0.00697 (passed time: 30m 40s)
#           acc: 0.99896, fpr: 0.00108, fnr: 0.00000, rec: 1.00000, prc: 0.97578, f1: 0.98774, f1_macro: 0.99360
# epoch: 4, passed number of graphs: 768, train running loss: 0.00763 (passed time: 31m 29s)
#           acc: 0.99988, fpr: 0.00012, fnr: 0.00000, rec: 1.00000, prc: 0.99719, f1: 0.99859, f1_macro: 0.99926
# Validation --- epoch: 4, loss: 0.00163
#           fnr: 0.00579, f1: 0.99402, rec: 0.99421, f1_macro: 0.99695, fpr: 0.00011, prc: 0.99495, acc: 0.99977
# Better model saved at ./saved_models/GIN_3: 0.9940245137989758.pt.
# epoch: 5, passed number of graphs: 96, train running loss: 0.00564 (passed time: 32m 54s)
#           acc: 0.99544, fpr: 0.00476, fnr: 0.00000, rec: 1.00000, prc: 0.90196, f1: 0.94845, f1_macro: 0.97303
# epoch: 5, passed number of graphs: 192, train running loss: 0.00399 (passed time: 33m 43s)
#           acc: 0.99981, fpr: 0.00020, fnr: 0.00000, rec: 1.00000, prc: 0.99551, f1: 0.99775, f1_macro: 0.99882
# epoch: 5, passed number of graphs: 288, train running loss: 0.00341 (passed time: 34m 31s)
#           acc: 0.99953, fpr: 0.00048, fnr: 0.00017, rec: 0.99983, prc: 0.98878, f1: 0.99428, f1_macro: 0.99702
# epoch: 5, passed number of graphs: 384, train running loss: 0.00503 (passed time: 35m 19s)
#           acc: 0.99979, fpr: 0.00020, fnr: 0.00033, rec: 0.99967, prc: 0.99559, f1: 0.99763, f1_macro: 0.99876
# epoch: 5, passed number of graphs: 480, train running loss: 0.00738 (passed time: 36m 8s)
#           acc: 0.99865, fpr: 0.00139, fnr: 0.00033, rec: 0.99967, prc: 0.96954, f1: 0.98437, f1_macro: 0.99183
# epoch: 5, passed number of graphs: 576, train running loss: 0.00672 (passed time: 36m 56s)
#           acc: 0.99962, fpr: 0.00038, fnr: 0.00016, rec: 0.99984, prc: 0.99137, f1: 0.99558, f1_macro: 0.99769
# epoch: 5, passed number of graphs: 672, train running loss: 0.00606 (passed time: 37m 44s)
#           acc: 0.99890, fpr: 0.00115, fnr: 0.00000, rec: 1.00000, prc: 0.97423, f1: 0.98695, f1_macro: 0.99319
# epoch: 5, passed number of graphs: 768, train running loss: 0.00608 (passed time: 38m 32s)
#           acc: 0.99984, fpr: 0.00017, fnr: 0.00000, rec: 1.00000, prc: 0.99620, f1: 0.99809, f1_macro: 0.99901
# Validation --- epoch: 5, loss: 0.00717
#           fnr: 0.00440, f1: 0.96537, rec: 0.99560, f1_macro: 0.98228, fpr: 0.00152, prc: 0.94085, acc: 0.99842
# epoch: 6, passed number of graphs: 96, train running loss: 0.00609 (passed time: 39m 58s)
#           acc: 0.99931, fpr: 0.00072, fnr: 0.00000, rec: 1.00000, prc: 0.98388, f1: 0.99187, f1_macro: 0.99576
# epoch: 6, passed number of graphs: 192, train running loss: 0.00395 (passed time: 40m 46s)
#           acc: 0.99993, fpr: 0.00004, fnr: 0.00067, rec: 0.99933, prc: 0.99900, f1: 0.99916, f1_macro: 0.99956
# epoch: 6, passed number of graphs: 288, train running loss: 0.00301 (passed time: 41m 34s)
#           acc: 0.99978, fpr: 0.00021, fnr: 0.00033, rec: 0.99967, prc: 0.99502, f1: 0.99734, f1_macro: 0.99861
# epoch: 6, passed number of graphs: 384, train running loss: 0.00277 (passed time: 42m 23s)
#           acc: 0.99980, fpr: 0.00019, fnr: 0.00033, rec: 0.99967, prc: 0.99575, f1: 0.99771, f1_macro: 0.99880
# epoch: 6, passed number of graphs: 480, train running loss: 0.00266 (passed time: 43m 12s)
#           acc: 0.99977, fpr: 0.00022, fnr: 0.00050, rec: 0.99950, prc: 0.99504, f1: 0.99726, f1_macro: 0.99857
# epoch: 6, passed number of graphs: 576, train running loss: 0.00238 (passed time: 44m 0s)
#           acc: 0.99967, fpr: 0.00033, fnr: 0.00049, rec: 0.99951, prc: 0.99266, f1: 0.99607, f1_macro: 0.99795
# epoch: 6, passed number of graphs: 672, train running loss: 0.00230 (passed time: 44m 48s)
#           acc: 0.99907, fpr: 0.00097, fnr: 0.00016, rec: 0.99984, prc: 0.97827, f1: 0.98894, f1_macro: 0.99423
# epoch: 6, passed number of graphs: 768, train running loss: 0.00314 (passed time: 45m 36s)
#           acc: 0.99974, fpr: 0.00027, fnr: 0.00000, rec: 1.00000, prc: 0.99390, f1: 0.99694, f1_macro: 0.99840
# Validation --- epoch: 6, loss: 0.00303
#           fnr: 0.00457, f1: 0.98894, rec: 0.99543, f1_macro: 0.99435, fpr: 0.00038, prc: 0.98411, acc: 0.99953
# epoch: 7, passed number of graphs: 96, train running loss: 0.00516 (passed time: 47m 2s)
#           acc: 0.99996, fpr: 0.00004, fnr: 0.00000, rec: 1.00000, prc: 0.99903, f1: 0.99951, f1_macro: 0.99975
# epoch: 7, passed number of graphs: 192, train running loss: 0.00348 (passed time: 47m 51s)
#           acc: 0.99983, fpr: 0.00015, fnr: 0.00067, rec: 0.99933, prc: 0.99666, f1: 0.99800, f1_macro: 0.99895
# epoch: 7, passed number of graphs: 288, train running loss: 0.00272 (passed time: 48m 40s)
#           acc: 0.99978, fpr: 0.00022, fnr: 0.00033, rec: 0.99967, prc: 0.99485, f1: 0.99725, f1_macro: 0.99857
# epoch: 7, passed number of graphs: 384, train running loss: 0.00246 (passed time: 49m 29s)
#           acc: 0.99978, fpr: 0.00022, fnr: 0.00033, rec: 0.99967, prc: 0.99526, f1: 0.99746, f1_macro: 0.99867
# epoch: 7, passed number of graphs: 480, train running loss: 0.00248 (passed time: 50m 17s)
#           acc: 0.99975, fpr: 0.00024, fnr: 0.00050, rec: 0.99950, prc: 0.99454, f1: 0.99702, f1_macro: 0.99844
# epoch: 7, passed number of graphs: 576, train running loss: 0.00223 (passed time: 51m 5s)
#           acc: 0.99964, fpr: 0.00036, fnr: 0.00033, rec: 0.99967, prc: 0.99185, f1: 0.99574, f1_macro: 0.99778
# epoch: 7, passed number of graphs: 672, train running loss: 0.00213 (passed time: 51m 53s)
#           acc: 0.99893, fpr: 0.00112, fnr: 0.00000, rec: 1.00000, prc: 0.97501, f1: 0.98735, f1_macro: 0.99339
# epoch: 7, passed number of graphs: 768, train running loss: 0.00222 (passed time: 52m 42s)
#           acc: 0.99984, fpr: 0.00017, fnr: 0.00000, rec: 1.00000, prc: 0.99620, f1: 0.99809, f1_macro: 0.99901
# Validation --- epoch: 7, loss: 0.00185
#           fnr: 0.00446, f1: 0.99219, rec: 0.99554, f1_macro: 0.99601, fpr: 0.00023, prc: 0.99023, acc: 0.99968
# epoch: 8, passed number of graphs: 96, train running loss: 0.00317 (passed time: 54m 6s)
#           acc: 0.99733, fpr: 0.00279, fnr: 0.00000, rec: 1.00000, prc: 0.94021, f1: 0.96918, f1_macro: 0.98389
# epoch: 8, passed number of graphs: 192, train running loss: 0.00244 (passed time: 54m 55s)
#           acc: 0.99991, fpr: 0.00007, fnr: 0.00067, rec: 0.99933, prc: 0.99850, f1: 0.99891, f1_macro: 0.99943
# epoch: 8, passed number of graphs: 288, train running loss: 0.00197 (passed time: 55m 43s)
#           acc: 0.99979, fpr: 0.00021, fnr: 0.00033, rec: 0.99967, prc: 0.99518, f1: 0.99742, f1_macro: 0.99865
# epoch: 8, passed number of graphs: 384, train running loss: 0.00180 (passed time: 56m 32s)
#           acc: 0.99979, fpr: 0.00021, fnr: 0.00033, rec: 0.99967, prc: 0.99542, f1: 0.99754, f1_macro: 0.99872
# epoch: 8, passed number of graphs: 480, train running loss: 0.00191 (passed time: 57m 20s)
#           acc: 0.99974, fpr: 0.00025, fnr: 0.00050, rec: 0.99950, prc: 0.99438, f1: 0.99693, f1_macro: 0.99840
# epoch: 8, passed number of graphs: 576, train running loss: 0.00174 (passed time: 58m 9s)
#           acc: 0.99967, fpr: 0.00032, fnr: 0.00049, rec: 0.99951, prc: 0.99282, f1: 0.99615, f1_macro: 0.99799
# epoch: 8, passed number of graphs: 672, train running loss: 0.00170 (passed time: 58m 57s)
#           acc: 0.99897, fpr: 0.00107, fnr: 0.00016, rec: 0.99984, prc: 0.97609, f1: 0.98782, f1_macro: 0.99364
# epoch: 8, passed number of graphs: 768, train running loss: 0.00178 (passed time: 59m 45s)
#           acc: 0.99987, fpr: 0.00014, fnr: 0.00000, rec: 1.00000, prc: 0.99686, f1: 0.99843, f1_macro: 0.99918
# Validation --- epoch: 8, loss: 0.00167
#           fnr: 0.00445, f1: 0.99341, rec: 0.99555, f1_macro: 0.99664, fpr: 0.00017, prc: 0.99259, acc: 0.99973
# epoch: 9, passed number of graphs: 96, train running loss: 0.00217 (passed time: 1h 1m 9s)
#           acc: 0.99996, fpr: 0.00004, fnr: 0.00000, rec: 1.00000, prc: 0.99903, f1: 0.99951, f1_macro: 0.99975
# epoch: 9, passed number of graphs: 192, train running loss: 0.00187 (passed time: 1h 1m 58s)
#           acc: 0.99992, fpr: 0.00007, fnr: 0.00050, rec: 0.99950, prc: 0.99850, f1: 0.99900, f1_macro: 0.99948
# epoch: 9, passed number of graphs: 288, train running loss: 0.00157 (passed time: 1h 2m 46s)
#           acc: 0.99980, fpr: 0.00020, fnr: 0.00033, rec: 0.99967, prc: 0.99535, f1: 0.99750, f1_macro: 0.99870
# epoch: 9, passed number of graphs: 384, train running loss: 0.00147 (passed time: 1h 3m 35s)
#           acc: 0.99978, fpr: 0.00022, fnr: 0.00033, rec: 0.99967, prc: 0.99526, f1: 0.99746, f1_macro: 0.99867
# epoch: 9, passed number of graphs: 480, train running loss: 0.00154 (passed time: 1h 4m 23s)
#           acc: 0.99974, fpr: 0.00025, fnr: 0.00050, rec: 0.99950, prc: 0.99438, f1: 0.99693, f1_macro: 0.99840
# epoch: 9, passed number of graphs: 576, train running loss: 0.00145 (passed time: 1h 5m 11s)
#           acc: 0.99965, fpr: 0.00035, fnr: 0.00049, rec: 0.99951, prc: 0.99217, f1: 0.99583, f1_macro: 0.99782
# epoch: 9, passed number of graphs: 672, train running loss: 0.00143 (passed time: 1h 5m 59s)
#           acc: 0.99901, fpr: 0.00103, fnr: 0.00016, rec: 0.99984, prc: 0.97687, f1: 0.98822, f1_macro: 0.99385
# epoch: 9, passed number of graphs: 768, train running loss: 0.00150 (passed time: 1h 6m 47s)
#           acc: 0.99987, fpr: 0.00013, fnr: 0.00017, rec: 0.99983, prc: 0.99702, f1: 0.99843, f1_macro: 0.99918
# Validation --- epoch: 9, loss: 0.00162
#           fnr: 0.00447, f1: 0.99368, rec: 0.99553, f1_macro: 0.99678, fpr: 0.00016, prc: 0.99312, acc: 0.99975
# epoch: 10, passed number of graphs: 96, train running loss: 0.00224 (passed time: 1h 8m 11s)
#           acc: 0.99992, fpr: 0.00009, fnr: 0.00000, rec: 1.00000, prc: 0.99806, f1: 0.99903, f1_macro: 0.99949
# epoch: 10, passed number of graphs: 192, train running loss: 0.00190 (passed time: 1h 8m 59s)
#           acc: 0.99994, fpr: 0.00004, fnr: 0.00050, rec: 0.99950, prc: 0.99900, f1: 0.99925, f1_macro: 0.99961
# epoch: 10, passed number of graphs: 288, train running loss: 0.00160 (passed time: 1h 9m 48s)
#           acc: 0.99979, fpr: 0.00021, fnr: 0.00033, rec: 0.99967, prc: 0.99518, f1: 0.99742, f1_macro: 0.99865
# epoch: 10, passed number of graphs: 384, train running loss: 0.00150 (passed time: 1h 10m 37s)
#           acc: 0.99981, fpr: 0.00019, fnr: 0.00033, rec: 0.99967, prc: 0.99591, f1: 0.99779, f1_macro: 0.99884
# epoch: 10, passed number of graphs: 480, train running loss: 0.00158 (passed time: 1h 11m 25s)
#           acc: 0.99975, fpr: 0.00024, fnr: 0.00050, rec: 0.99950, prc: 0.99471, f1: 0.99710, f1_macro: 0.99848
# epoch: 10, passed number of graphs: 576, train running loss: 0.00148 (passed time: 1h 12m 13s)
#           acc: 0.99964, fpr: 0.00036, fnr: 0.00033, rec: 0.99967, prc: 0.99185, f1: 0.99574, f1_macro: 0.99778
# epoch: 10, passed number of graphs: 672, train running loss: 0.00145 (passed time: 1h 13m 1s)
#           acc: 0.99905, fpr: 0.00098, fnr: 0.00016, rec: 0.99984, prc: 0.97796, f1: 0.98878, f1_macro: 0.99414
# epoch: 10, passed number of graphs: 768, train running loss: 0.00154 (passed time: 1h 13m 49s)
#           acc: 0.99988, fpr: 0.00012, fnr: 0.00017, rec: 0.99983, prc: 0.99735, f1: 0.99859, f1_macro: 0.99926
# Validation --- epoch: 10, loss: 0.00165
#           fnr: 0.00449, f1: 0.99376, rec: 0.99551, f1_macro: 0.99681, fpr: 0.00016, prc: 0.99329, acc: 0.99975
# epoch: 11, passed number of graphs: 96, train running loss: 0.00221 (passed time: 1h 15m 13s)
#           acc: 0.99988, fpr: 0.00013, fnr: 0.00000, rec: 1.00000, prc: 0.99709, f1: 0.99854, f1_macro: 0.99924
# epoch: 11, passed number of graphs: 192, train running loss: 0.00187 (passed time: 1h 16m 1s)
#           acc: 0.99993, fpr: 0.00004, fnr: 0.00067, rec: 0.99933, prc: 0.99900, f1: 0.99916, f1_macro: 0.99956
# epoch: 11, passed number of graphs: 288, train running loss: 0.00157 (passed time: 1h 16m 49s)
#           acc: 0.99979, fpr: 0.00021, fnr: 0.00033, rec: 0.99967, prc: 0.99518, f1: 0.99742, f1_macro: 0.99865
# epoch: 11, passed number of graphs: 384, train running loss: 0.00148 (passed time: 1h 17m 38s)
#           acc: 0.99981, fpr: 0.00019, fnr: 0.00033, rec: 0.99967, prc: 0.99591, f1: 0.99779, f1_macro: 0.99884
# epoch: 11, passed number of graphs: 480, train running loss: 0.00157 (passed time: 1h 18m 27s)
#           acc: 0.99977, fpr: 0.00022, fnr: 0.00050, rec: 0.99950, prc: 0.99504, f1: 0.99726, f1_macro: 0.99857
# epoch: 11, passed number of graphs: 576, train running loss: 0.00146 (passed time: 1h 19m 16s)
#           acc: 0.99962, fpr: 0.00038, fnr: 0.00049, rec: 0.99951, prc: 0.99152, f1: 0.99550, f1_macro: 0.99765
# epoch: 11, passed number of graphs: 672, train running loss: 0.00144 (passed time: 1h 20m 4s)
#           acc: 0.99905, fpr: 0.00098, fnr: 0.00016, rec: 0.99984, prc: 0.97796, f1: 0.98878, f1_macro: 0.99414
# epoch: 11, passed number of graphs: 768, train running loss: 0.00157 (passed time: 1h 20m 52s)
#           acc: 0.99988, fpr: 0.00012, fnr: 0.00017, rec: 0.99983, prc: 0.99735, f1: 0.99859, f1_macro: 0.99926
# Validation --- epoch: 11, loss: 0.00169
#           fnr: 0.00446, f1: 0.99347, rec: 0.99554, f1_macro: 0.99667, fpr: 0.00017, prc: 0.99272, acc: 0.99974
# epoch: 12, passed number of graphs: 96, train running loss: 0.00207 (passed time: 1h 22m 17s)
#           acc: 0.99996, fpr: 0.00004, fnr: 0.00000, rec: 1.00000, prc: 0.99903, f1: 0.99951, f1_macro: 0.99975
# epoch: 12, passed number of graphs: 192, train running loss: 0.00176 (passed time: 1h 23m 5s)
#           acc: 0.99994, fpr: 0.00004, fnr: 0.00050, rec: 0.99950, prc: 0.99900, f1: 0.99925, f1_macro: 0.99961
# epoch: 12, passed number of graphs: 288, train running loss: 0.00151 (passed time: 1h 23m 54s)
#           acc: 0.99980, fpr: 0.00019, fnr: 0.00033, rec: 0.99967, prc: 0.99551, f1: 0.99759, f1_macro: 0.99874
# epoch: 12, passed number of graphs: 384, train running loss: 0.00141 (passed time: 1h 24m 43s)
#           acc: 0.99981, fpr: 0.00019, fnr: 0.00033, rec: 0.99967, prc: 0.99591, f1: 0.99779, f1_macro: 0.99884
# epoch: 12, passed number of graphs: 480, train running loss: 0.00147 (passed time: 1h 25m 32s)
#           acc: 0.99973, fpr: 0.00026, fnr: 0.00050, rec: 0.99950, prc: 0.99421, f1: 0.99685, f1_macro: 0.99836
# epoch: 12, passed number of graphs: 576, train running loss: 0.00138 (passed time: 1h 26m 20s)
#           acc: 0.99964, fpr: 0.00036, fnr: 0.00049, rec: 0.99951, prc: 0.99201, f1: 0.99574, f1_macro: 0.99778
# epoch: 12, passed number of graphs: 672, train running loss: 0.00136 (passed time: 1h 27m 8s)
#           acc: 0.99903, fpr: 0.00100, fnr: 0.00016, rec: 0.99984, prc: 0.97749, f1: 0.98854, f1_macro: 0.99402
# epoch: 12, passed number of graphs: 768, train running loss: 0.00144 (passed time: 1h 27m 56s)
#           acc: 0.99989, fpr: 0.00012, fnr: 0.00000, rec: 1.00000, prc: 0.99735, f1: 0.99867, f1_macro: 0.99931
# Validation --- epoch: 12, loss: 0.00166
#           fnr: 0.00440, f1: 0.99385, rec: 0.99560, f1_macro: 0.99686, fpr: 0.00015, prc: 0.99337, acc: 0.99975
# epoch: 13, passed number of graphs: 96, train running loss: 0.00202 (passed time: 1h 29m 22s)
#           acc: 0.99996, fpr: 0.00004, fnr: 0.00000, rec: 1.00000, prc: 0.99903, f1: 0.99951, f1_macro: 0.99975
# epoch: 13, passed number of graphs: 192, train running loss: 0.00171 (passed time: 1h 30m 10s)
#           acc: 0.99994, fpr: 0.00004, fnr: 0.00033, rec: 0.99967, prc: 0.99900, f1: 0.99933, f1_macro: 0.99965
# epoch: 13, passed number of graphs: 288, train running loss: 0.00147 (passed time: 1h 30m 59s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00033, rec: 0.99967, prc: 0.99634, f1: 0.99800, f1_macro: 0.99896
# epoch: 13, passed number of graphs: 384, train running loss: 0.00138 (passed time: 1h 31m 48s)
#           acc: 0.99981, fpr: 0.00019, fnr: 0.00033, rec: 0.99967, prc: 0.99591, f1: 0.99779, f1_macro: 0.99884
# epoch: 13, passed number of graphs: 480, train running loss: 0.00144 (passed time: 1h 32m 36s)
#           acc: 0.99973, fpr: 0.00026, fnr: 0.00050, rec: 0.99950, prc: 0.99421, f1: 0.99685, f1_macro: 0.99836
# epoch: 13, passed number of graphs: 576, train running loss: 0.00136 (passed time: 1h 33m 24s)
#           acc: 0.99963, fpr: 0.00036, fnr: 0.00049, rec: 0.99951, prc: 0.99185, f1: 0.99566, f1_macro: 0.99774
# epoch: 13, passed number of graphs: 672, train running loss: 0.00134 (passed time: 1h 34m 12s)
#           acc: 0.99903, fpr: 0.00100, fnr: 0.00016, rec: 0.99984, prc: 0.97749, f1: 0.98854, f1_macro: 0.99402
# epoch: 13, passed number of graphs: 768, train running loss: 0.00144 (passed time: 1h 35m 0s)
#           acc: 0.99989, fpr: 0.00012, fnr: 0.00000, rec: 1.00000, prc: 0.99735, f1: 0.99867, f1_macro: 0.99931
# Validation --- epoch: 13, loss: 0.00161
#           fnr: 0.00440, f1: 0.99406, rec: 0.99560, f1_macro: 0.99697, fpr: 0.00014, prc: 0.99376, acc: 0.99976
# Better model saved at ./saved_models/GIN_12: 0.9940560875676835.pt.
# epoch: 14, passed number of graphs: 96, train running loss: 0.00202 (passed time: 1h 36m 25s)
#           acc: 0.99996, fpr: 0.00004, fnr: 0.00000, rec: 1.00000, prc: 0.99903, f1: 0.99951, f1_macro: 0.99975
# epoch: 14, passed number of graphs: 192, train running loss: 0.00170 (passed time: 1h 37m 14s)
#           acc: 0.99994, fpr: 0.00004, fnr: 0.00033, rec: 0.99967, prc: 0.99900, f1: 0.99933, f1_macro: 0.99965
# epoch: 14, passed number of graphs: 288, train running loss: 0.00145 (passed time: 1h 38m 2s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00033, rec: 0.99967, prc: 0.99634, f1: 0.99800, f1_macro: 0.99896
# epoch: 14, passed number of graphs: 384, train running loss: 0.00138 (passed time: 1h 38m 50s)
#           acc: 0.99980, fpr: 0.00019, fnr: 0.00033, rec: 0.99967, prc: 0.99575, f1: 0.99771, f1_macro: 0.99880
# epoch: 14, passed number of graphs: 480, train running loss: 0.00144 (passed time: 1h 39m 39s)
#           acc: 0.99973, fpr: 0.00026, fnr: 0.00050, rec: 0.99950, prc: 0.99421, f1: 0.99685, f1_macro: 0.99836
# epoch: 14, passed number of graphs: 576, train running loss: 0.00135 (passed time: 1h 40m 27s)
#           acc: 0.99963, fpr: 0.00036, fnr: 0.00066, rec: 0.99934, prc: 0.99201, f1: 0.99566, f1_macro: 0.99773
# epoch: 14, passed number of graphs: 672, train running loss: 0.00134 (passed time: 1h 41m 15s)
#           acc: 0.99903, fpr: 0.00100, fnr: 0.00016, rec: 0.99984, prc: 0.97749, f1: 0.98854, f1_macro: 0.99402
# epoch: 14, passed number of graphs: 768, train running loss: 0.00145 (passed time: 1h 42m 4s)
#           acc: 0.99989, fpr: 0.00012, fnr: 0.00000, rec: 1.00000, prc: 0.99735, f1: 0.99867, f1_macro: 0.99931
# Validation --- epoch: 14, loss: 0.00159
#           fnr: 0.00441, f1: 0.99411, rec: 0.99559, f1_macro: 0.99700, fpr: 0.00014, prc: 0.99387, acc: 0.99977
# Better model saved at ./saved_models/GIN_13: 0.9941104762805759.pt.
# epoch: 15, passed number of graphs: 96, train running loss: 0.00203 (passed time: 1h 43m 28s)
#           acc: 0.99996, fpr: 0.00004, fnr: 0.00000, rec: 1.00000, prc: 0.99903, f1: 0.99951, f1_macro: 0.99975
# epoch: 15, passed number of graphs: 192, train running loss: 0.00169 (passed time: 1h 44m 16s)
#           acc: 0.99993, fpr: 0.00004, fnr: 0.00067, rec: 0.99933, prc: 0.99900, f1: 0.99916, f1_macro: 0.99956
# epoch: 15, passed number of graphs: 288, train running loss: 0.00144 (passed time: 1h 45m 4s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00033, rec: 0.99967, prc: 0.99634, f1: 0.99800, f1_macro: 0.99896
# epoch: 15, passed number of graphs: 384, train running loss: 0.00138 (passed time: 1h 45m 52s)
#           acc: 0.99980, fpr: 0.00019, fnr: 0.00033, rec: 0.99967, prc: 0.99575, f1: 0.99771, f1_macro: 0.99880
# epoch: 15, passed number of graphs: 480, train running loss: 0.00144 (passed time: 1h 46m 40s)
#           acc: 0.99974, fpr: 0.00025, fnr: 0.00050, rec: 0.99950, prc: 0.99438, f1: 0.99693, f1_macro: 0.99840
# epoch: 15, passed number of graphs: 576, train running loss: 0.00135 (passed time: 1h 47m 29s)
#           acc: 0.99963, fpr: 0.00036, fnr: 0.00066, rec: 0.99934, prc: 0.99201, f1: 0.99566, f1_macro: 0.99773
# epoch: 15, passed number of graphs: 672, train running loss: 0.00134 (passed time: 1h 48m 16s)
#           acc: 0.99901, fpr: 0.00102, fnr: 0.00016, rec: 0.99984, prc: 0.97703, f1: 0.98830, f1_macro: 0.99389
# epoch: 15, passed number of graphs: 768, train running loss: 0.00145 (passed time: 1h 49m 5s)
#           acc: 0.99988, fpr: 0.00012, fnr: 0.00017, rec: 0.99983, prc: 0.99735, f1: 0.99859, f1_macro: 0.99926
# Validation --- epoch: 15, loss: 0.00155
#           fnr: 0.00443, f1: 0.99416, rec: 0.99557, f1_macro: 0.99702, fpr: 0.00014, prc: 0.99397, acc: 0.99977
# Better model saved at ./saved_models/GIN_14: 0.9941551611600971.pt.
# epoch: 16, passed number of graphs: 96, train running loss: 0.00212 (passed time: 1h 50m 29s)
#           acc: 0.99931, fpr: 0.00073, fnr: 0.00000, rec: 1.00000, prc: 0.98372, f1: 0.99179, f1_macro: 0.99572
# epoch: 16, passed number of graphs: 192, train running loss: 0.00175 (passed time: 1h 51m 17s)
#           acc: 0.99994, fpr: 0.00004, fnr: 0.00050, rec: 0.99950, prc: 0.99900, f1: 0.99925, f1_macro: 0.99961
# epoch: 16, passed number of graphs: 288, train running loss: 0.00149 (passed time: 1h 52m 5s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00033, rec: 0.99967, prc: 0.99634, f1: 0.99800, f1_macro: 0.99896
# epoch: 16, passed number of graphs: 384, train running loss: 0.00142 (passed time: 1h 52m 55s)
#           acc: 0.99980, fpr: 0.00019, fnr: 0.00033, rec: 0.99967, prc: 0.99575, f1: 0.99771, f1_macro: 0.99880
# epoch: 16, passed number of graphs: 480, train running loss: 0.00147 (passed time: 1h 53m 44s)
#           acc: 0.99974, fpr: 0.00025, fnr: 0.00050, rec: 0.99950, prc: 0.99438, f1: 0.99693, f1_macro: 0.99840
# epoch: 16, passed number of graphs: 576, train running loss: 0.00138 (passed time: 1h 54m 32s)
#           acc: 0.99962, fpr: 0.00037, fnr: 0.00049, rec: 0.99951, prc: 0.99169, f1: 0.99558, f1_macro: 0.99769
# epoch: 16, passed number of graphs: 672, train running loss: 0.00136 (passed time: 1h 55m 20s)
#           acc: 0.99902, fpr: 0.00102, fnr: 0.00016, rec: 0.99984, prc: 0.97718, f1: 0.98838, f1_macro: 0.99393
# epoch: 16, passed number of graphs: 768, train running loss: 0.00149 (passed time: 1h 56m 9s)
#           acc: 0.99988, fpr: 0.00012, fnr: 0.00017, rec: 0.99983, prc: 0.99735, f1: 0.99859, f1_macro: 0.99926
# Validation --- epoch: 16, loss: 0.00157
#           fnr: 0.00442, f1: 0.99412, rec: 0.99558, f1_macro: 0.99700, fpr: 0.00014, prc: 0.99391, acc: 0.99977
# epoch: 17, passed number of graphs: 96, train running loss: 0.00208 (passed time: 1h 57m 35s)
#           acc: 0.99996, fpr: 0.00004, fnr: 0.00000, rec: 1.00000, prc: 0.99903, f1: 0.99951, f1_macro: 0.99975
# epoch: 17, passed number of graphs: 192, train running loss: 0.00172 (passed time: 1h 58m 24s)
#           acc: 0.99994, fpr: 0.00004, fnr: 0.00033, rec: 0.99967, prc: 0.99900, f1: 0.99933, f1_macro: 0.99965
# epoch: 17, passed number of graphs: 288, train running loss: 0.00146 (passed time: 1h 59m 12s)
#           acc: 0.99983, fpr: 0.00016, fnr: 0.00033, rec: 0.99967, prc: 0.99618, f1: 0.99792, f1_macro: 0.99891
# epoch: 17, passed number of graphs: 384, train running loss: 0.00141 (passed time: 2h 0m 1s)
#           acc: 0.99980, fpr: 0.00019, fnr: 0.00033, rec: 0.99967, prc: 0.99575, f1: 0.99771, f1_macro: 0.99880
# epoch: 17, passed number of graphs: 480, train running loss: 0.00146 (passed time: 2h 0m 49s)
#           acc: 0.99975, fpr: 0.00024, fnr: 0.00050, rec: 0.99950, prc: 0.99454, f1: 0.99702, f1_macro: 0.99844
# epoch: 17, passed number of graphs: 576, train running loss: 0.00137 (passed time: 2h 1m 38s)
#           acc: 0.99962, fpr: 0.00037, fnr: 0.00066, rec: 0.99934, prc: 0.99168, f1: 0.99550, f1_macro: 0.99765
# epoch: 17, passed number of graphs: 672, train running loss: 0.00135 (passed time: 2h 2m 26s)
#           acc: 0.99904, fpr: 0.00099, fnr: 0.00016, rec: 0.99984, prc: 0.97765, f1: 0.98862, f1_macro: 0.99406
# epoch: 17, passed number of graphs: 768, train running loss: 0.00148 (passed time: 2h 3m 15s)
#           acc: 0.99988, fpr: 0.00012, fnr: 0.00017, rec: 0.99983, prc: 0.99735, f1: 0.99859, f1_macro: 0.99926
# Validation --- epoch: 17, loss: 0.00154
#           fnr: 0.00442, f1: 0.99417, rec: 0.99558, f1_macro: 0.99703, fpr: 0.00014, prc: 0.99400, acc: 0.99977
# Better model saved at ./saved_models/GIN_16: 0.9941713462098362.pt.
# epoch: 18, passed number of graphs: 96, train running loss: 0.00211 (passed time: 2h 4m 41s)
#           acc: 0.99905, fpr: 0.00100, fnr: 0.00000, rec: 1.00000, prc: 0.97779, f1: 0.98877, f1_macro: 0.99414
# epoch: 18, passed number of graphs: 192, train running loss: 0.00174 (passed time: 2h 5m 29s)
#           acc: 0.99994, fpr: 0.00004, fnr: 0.00050, rec: 0.99950, prc: 0.99900, f1: 0.99925, f1_macro: 0.99961
# epoch: 18, passed number of graphs: 288, train running loss: 0.00148 (passed time: 2h 6m 18s)
#           acc: 0.99983, fpr: 0.00016, fnr: 0.00033, rec: 0.99967, prc: 0.99618, f1: 0.99792, f1_macro: 0.99891
# epoch: 18, passed number of graphs: 384, train running loss: 0.00142 (passed time: 2h 7m 7s)
#           acc: 0.99980, fpr: 0.00019, fnr: 0.00033, rec: 0.99967, prc: 0.99575, f1: 0.99771, f1_macro: 0.99880
# epoch: 18, passed number of graphs: 480, train running loss: 0.00147 (passed time: 2h 7m 56s)
#           acc: 0.99975, fpr: 0.00024, fnr: 0.00050, rec: 0.99950, prc: 0.99454, f1: 0.99702, f1_macro: 0.99844
# epoch: 18, passed number of graphs: 576, train running loss: 0.00137 (passed time: 2h 8m 44s)
#           acc: 0.99962, fpr: 0.00037, fnr: 0.00049, rec: 0.99951, prc: 0.99169, f1: 0.99558, f1_macro: 0.99769
# epoch: 18, passed number of graphs: 672, train running loss: 0.00135 (passed time: 2h 9m 32s)
#           acc: 0.99904, fpr: 0.00099, fnr: 0.00016, rec: 0.99984, prc: 0.97765, f1: 0.98862, f1_macro: 0.99406
# epoch: 18, passed number of graphs: 768, train running loss: 0.00148 (passed time: 2h 10m 21s)
#           acc: 0.99988, fpr: 0.00012, fnr: 0.00017, rec: 0.99983, prc: 0.99735, f1: 0.99859, f1_macro: 0.99926
# Validation --- epoch: 18, loss: 0.00154
#           fnr: 0.00442, f1: 0.99405, rec: 0.99558, f1_macro: 0.99696, fpr: 0.00014, prc: 0.99375, acc: 0.99976
# epoch: 19, passed number of graphs: 96, train running loss: 0.00207 (passed time: 2h 11m 47s)
#           acc: 0.99996, fpr: 0.00004, fnr: 0.00000, rec: 1.00000, prc: 0.99903, f1: 0.99951, f1_macro: 0.99975
# epoch: 19, passed number of graphs: 192, train running loss: 0.00170 (passed time: 2h 12m 35s)
#           acc: 0.99994, fpr: 0.00004, fnr: 0.00050, rec: 0.99950, prc: 0.99900, f1: 0.99925, f1_macro: 0.99961
# epoch: 19, passed number of graphs: 288, train running loss: 0.00144 (passed time: 2h 13m 24s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00033, rec: 0.99967, prc: 0.99634, f1: 0.99800, f1_macro: 0.99896
# epoch: 19, passed number of graphs: 384, train running loss: 0.00139 (passed time: 2h 14m 13s)
#           acc: 0.99980, fpr: 0.00019, fnr: 0.00033, rec: 0.99967, prc: 0.99575, f1: 0.99771, f1_macro: 0.99880
# epoch: 19, passed number of graphs: 480, train running loss: 0.00144 (passed time: 2h 15m 2s)
#           acc: 0.99975, fpr: 0.00024, fnr: 0.00050, rec: 0.99950, prc: 0.99454, f1: 0.99702, f1_macro: 0.99844
# epoch: 19, passed number of graphs: 576, train running loss: 0.00135 (passed time: 2h 15m 50s)
#           acc: 0.99962, fpr: 0.00036, fnr: 0.00066, rec: 0.99934, prc: 0.99185, f1: 0.99558, f1_macro: 0.99769
# epoch: 19, passed number of graphs: 672, train running loss: 0.00133 (passed time: 2h 16m 38s)
#           acc: 0.99905, fpr: 0.00099, fnr: 0.00016, rec: 0.99984, prc: 0.97781, f1: 0.98870, f1_macro: 0.99410
# epoch: 19, passed number of graphs: 768, train running loss: 0.00146 (passed time: 2h 17m 26s)
#           acc: 0.99988, fpr: 0.00012, fnr: 0.00017, rec: 0.99983, prc: 0.99735, f1: 0.99859, f1_macro: 0.99926
# Validation --- epoch: 19, loss: 0.00150
#           fnr: 0.00444, f1: 0.99415, rec: 0.99556, f1_macro: 0.99702, fpr: 0.00014, prc: 0.99397, acc: 0.99977
# epoch: 20, passed number of graphs: 96, train running loss: 0.00211 (passed time: 2h 18m 53s)
#           acc: 0.99909, fpr: 0.00095, fnr: 0.00000, rec: 1.00000, prc: 0.97888, f1: 0.98933, f1_macro: 0.99443
# epoch: 20, passed number of graphs: 192, train running loss: 0.00174 (passed time: 2h 19m 42s)
#           acc: 0.99994, fpr: 0.00004, fnr: 0.00050, rec: 0.99950, prc: 0.99900, f1: 0.99925, f1_macro: 0.99961
# epoch: 20, passed number of graphs: 288, train running loss: 0.00148 (passed time: 2h 20m 30s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00033, rec: 0.99967, prc: 0.99634, f1: 0.99800, f1_macro: 0.99896
# epoch: 20, passed number of graphs: 384, train running loss: 0.00142 (passed time: 2h 21m 20s)
#           acc: 0.99980, fpr: 0.00019, fnr: 0.00033, rec: 0.99967, prc: 0.99575, f1: 0.99771, f1_macro: 0.99880
# epoch: 20, passed number of graphs: 480, train running loss: 0.00147 (passed time: 2h 22m 8s)
#           acc: 0.99975, fpr: 0.00024, fnr: 0.00050, rec: 0.99950, prc: 0.99454, f1: 0.99702, f1_macro: 0.99844
# epoch: 20, passed number of graphs: 576, train running loss: 0.00137 (passed time: 2h 22m 57s)
#           acc: 0.99961, fpr: 0.00038, fnr: 0.00066, rec: 0.99934, prc: 0.99152, f1: 0.99542, f1_macro: 0.99761
# epoch: 20, passed number of graphs: 672, train running loss: 0.00135 (passed time: 2h 23m 45s)
#           acc: 0.99905, fpr: 0.00098, fnr: 0.00016, rec: 0.99984, prc: 0.97796, f1: 0.98878, f1_macro: 0.99414
# epoch: 20, passed number of graphs: 768, train running loss: 0.00148 (passed time: 2h 24m 33s)
#           acc: 0.99988, fpr: 0.00012, fnr: 0.00017, rec: 0.99983, prc: 0.99735, f1: 0.99859, f1_macro: 0.99926
# Validation --- epoch: 20, loss: 0.00151
#           fnr: 0.00443, f1: 0.99413, rec: 0.99557, f1_macro: 0.99700, fpr: 0.00014, prc: 0.99391, acc: 0.99977
# epoch: 21, passed number of graphs: 96, train running loss: 0.00222 (passed time: 2h 26m 0s)
#           acc: 0.99996, fpr: 0.00004, fnr: 0.00000, rec: 1.00000, prc: 0.99903, f1: 0.99951, f1_macro: 0.99975
# epoch: 21, passed number of graphs: 192, train running loss: 0.00177 (passed time: 2h 26m 48s)
#           acc: 0.99994, fpr: 0.00004, fnr: 0.00050, rec: 0.99950, prc: 0.99900, f1: 0.99925, f1_macro: 0.99961
# epoch: 21, passed number of graphs: 288, train running loss: 0.00149 (passed time: 2h 27m 37s)
#           acc: 0.99984, fpr: 0.00016, fnr: 0.00033, rec: 0.99967, prc: 0.99634, f1: 0.99800, f1_macro: 0.99896
# epoch: 21, passed number of graphs: 384, train running loss: 0.00143 (passed time: 2h 28m 26s)
#           acc: 0.99980, fpr: 0.00019, fnr: 0.00033, rec: 0.99967, prc: 0.99575, f1: 0.99771, f1_macro: 0.99880
# epoch: 21, passed number of graphs: 480, train running loss: 0.00147 (passed time: 2h 29m 14s)
#           acc: 0.99975, fpr: 0.00024, fnr: 0.00050, rec: 0.99950, prc: 0.99471, f1: 0.99710, f1_macro: 0.99848
# epoch: 21, passed number of graphs: 576, train running loss: 0.00138 (passed time: 2h 30m 3s)
#           acc: 0.99962, fpr: 0.00037, fnr: 0.00066, rec: 0.99934, prc: 0.99168, f1: 0.99550, f1_macro: 0.99765
# epoch: 21, passed number of graphs: 672, train running loss: 0.00135 (passed time: 2h 30m 51s)
#           acc: 0.99905, fpr: 0.00098, fnr: 0.00016, rec: 0.99984, prc: 0.97796, f1: 0.98878, f1_macro: 0.99414
# epoch: 21, passed number of graphs: 768, train running loss: 0.00149 (passed time: 2h 31m 40s)
#           acc: 0.99988, fpr: 0.00012, fnr: 0.00017, rec: 0.99983, prc: 0.99735, f1: 0.99859, f1_macro: 0.99926
# Validation --- epoch: 21, loss: 0.00151
#           fnr: 0.00445, f1: 0.99409, rec: 0.99555, f1_macro: 0.99698, fpr: 0.00014, prc: 0.99386, acc: 0.99976
# epoch: 22, passed number of graphs: 96, train running loss: 0.00207 (passed time: 2h 33m 6s)
#           acc: 0.99996, fpr: 0.00004, fnr: 0.00000, rec: 1.00000, prc: 0.99903, f1: 0.99951, f1_macro: 0.99975
# epoch: 22, passed number of graphs: 192, train running loss: 0.00173 (passed time: 2h 33m 55s)
#           acc: 0.99994, fpr: 0.00004, fnr: 0.00050, rec: 0.99950, prc: 0.99900, f1: 0.99925, f1_macro: 0.99961
# epoch: 22, passed number of graphs: 288, train running loss: 0.00148 (passed time: 2h 34m 43s)
#           acc: 0.99984, fpr: 0.00015, fnr: 0.00033, rec: 0.99967, prc: 0.99651, f1: 0.99808, f1_macro: 0.99900
# epoch: 22, passed number of graphs: 384, train running loss: 0.00140 (passed time: 2h 35m 33s)
#           acc: 0.99981, fpr: 0.00019, fnr: 0.00033, rec: 0.99967, prc: 0.99591, f1: 0.99779, f1_macro: 0.99884
# epoch: 22, passed number of graphs: 480, train running loss: 0.00144 (passed time: 2h 36m 22s)
#           acc: 0.99975, fpr: 0.00024, fnr: 0.00050, rec: 0.99950, prc: 0.99454, f1: 0.99702, f1_macro: 0.99844
# epoch: 22, passed number of graphs: 576, train running loss: 0.00136 (passed time: 2h 37m 10s)
#           acc: 0.99961, fpr: 0.00038, fnr: 0.00049, rec: 0.99951, prc: 0.99136, f1: 0.99542, f1_macro: 0.99761
# epoch: 22, passed number of graphs: 672, train running loss: 0.00134 (passed time: 2h 37m 58s)
#           acc: 0.99904, fpr: 0.00099, fnr: 0.00033, rec: 0.99967, prc: 0.97780, f1: 0.98862, f1_macro: 0.99406
# epoch: 22, passed number of graphs: 768, train running loss: 0.00143 (passed time: 2h 38m 47s)
#           acc: 0.99988, fpr: 0.00012, fnr: 0.00017, rec: 0.99983, prc: 0.99735, f1: 0.99859, f1_macro: 0.99926
# Validation --- epoch: 22, loss: 0.00142
#           fnr: 0.00444, f1: 0.99437, rec: 0.99556, f1_macro: 0.99713, fpr: 0.00013, prc: 0.99438, acc: 0.99978
# Better model saved at ./saved_models/GIN_21: 0.9943669344695275.pt.
# epoch: 23, passed number of graphs: 96, train running loss: 0.00200 (passed time: 2h 40m 12s)
#           acc: 0.99996, fpr: 0.00004, fnr: 0.00000, rec: 1.00000, prc: 0.99903, f1: 0.99951, f1_macro: 0.99975
# epoch: 23, passed number of graphs: 192, train running loss: 0.00167 (passed time: 2h 41m 1s)
#           acc: 0.99994, fpr: 0.00004, fnr: 0.00033, rec: 0.99967, prc: 0.99900, f1: 0.99933, f1_macro: 0.99965
# epoch: 23, passed number of graphs: 288, train running loss: 0.00143 (passed time: 2h 41m 49s)
#           acc: 0.99984, fpr: 0.00015, fnr: 0.00033, rec: 0.99967, prc: 0.99651, f1: 0.99808, f1_macro: 0.99900
# epoch: 23, passed number of graphs: 384, train running loss: 0.00136 (passed time: 2h 42m 38s)
#           acc: 0.99981, fpr: 0.00019, fnr: 0.00033, rec: 0.99967, prc: 0.99591, f1: 0.99779, f1_macro: 0.99884
# epoch: 23, passed number of graphs: 480, train running loss: 0.00141 (passed time: 2h 43m 28s)
#           acc: 0.99974, fpr: 0.00025, fnr: 0.00050, rec: 0.99950, prc: 0.99438, f1: 0.99693, f1_macro: 0.99840
# epoch: 23, passed number of graphs: 576, train running loss: 0.00133 (passed time: 2h 44m 16s)
#           acc: 0.99961, fpr: 0.00038, fnr: 0.00049, rec: 0.99951, prc: 0.99136, f1: 0.99542, f1_macro: 0.99761
# epoch: 23, passed number of graphs: 672, train running loss: 0.00131 (passed time: 2h 45m 4s)
#           acc: 0.99905, fpr: 0.00098, fnr: 0.00033, rec: 0.99967, prc: 0.97796, f1: 0.98870, f1_macro: 0.99410
# epoch: 23, passed number of graphs: 768, train running loss: 0.00142 (passed time: 2h 45m 53s)
#           acc: 0.99988, fpr: 0.00012, fnr: 0.00017, rec: 0.99983, prc: 0.99735, f1: 0.99859, f1_macro: 0.99926
# Validation --- epoch: 23, loss: 0.00142
#           fnr: 0.00443, f1: 0.99437, rec: 0.99557, f1_macro: 0.99713, fpr: 0.00013, prc: 0.99438, acc: 0.99978
# Better model saved at ./saved_models/GIN_22: 0.9943708775515825.pt.
# epoch: 24, passed number of graphs: 96, train running loss: 0.00198 (passed time: 2h 47m 16s)
#           acc: 0.99996, fpr: 0.00004, fnr: 0.00000, rec: 1.00000, prc: 0.99903, f1: 0.99951, f1_macro: 0.99975
# epoch: 24, passed number of graphs: 192, train running loss: 0.00165 (passed time: 2h 48m 5s)
#           acc: 0.99994, fpr: 0.00004, fnr: 0.00033, rec: 0.99967, prc: 0.99900, f1: 0.99933, f1_macro: 0.99965
# epoch: 24, passed number of graphs: 288, train running loss: 0.00142 (passed time: 2h 48m 54s)
#           acc: 0.99984, fpr: 0.00015, fnr: 0.00033, rec: 0.99967, prc: 0.99651, f1: 0.99808, f1_macro: 0.99900
# epoch: 24, passed number of graphs: 384, train running loss: 0.00136 (passed time: 2h 49m 42s)
#           acc: 0.99981, fpr: 0.00019, fnr: 0.00033, rec: 0.99967, prc: 0.99591, f1: 0.99779, f1_macro: 0.99884
# epoch: 24, passed number of graphs: 480, train running loss: 0.00141 (passed time: 2h 50m 30s)
#           acc: 0.99974, fpr: 0.00025, fnr: 0.00050, rec: 0.99950, prc: 0.99438, f1: 0.99693, f1_macro: 0.99840
# epoch: 24, passed number of graphs: 576, train running loss: 0.00132 (passed time: 2h 51m 19s)
#           acc: 0.99960, fpr: 0.00038, fnr: 0.00066, rec: 0.99934, prc: 0.99136, f1: 0.99534, f1_macro: 0.99756
# epoch: 24, passed number of graphs: 672, train running loss: 0.00131 (passed time: 2h 52m 7s)
#           acc: 0.99905, fpr: 0.00098, fnr: 0.00033, rec: 0.99967, prc: 0.97796, f1: 0.98870, f1_macro: 0.99410
# epoch: 24, passed number of graphs: 768, train running loss: 0.00141 (passed time: 2h 52m 55s)
#           acc: 0.99988, fpr: 0.00012, fnr: 0.00017, rec: 0.99983, prc: 0.99735, f1: 0.99859, f1_macro: 0.99926
# Validation --- epoch: 24, loss: 0.00141
#           fnr: 0.00443, f1: 0.99442, rec: 0.99557, f1_macro: 0.99715, fpr: 0.00013, prc: 0.99447, acc: 0.99978
# Better model saved at ./saved_models/GIN_23: 0.9944201960188876.pt.
# epoch: 25, passed number of graphs: 96, train running loss: 0.00198 (passed time: 2h 54m 20s)
#           acc: 0.99996, fpr: 0.00004, fnr: 0.00000, rec: 1.00000, prc: 0.99903, f1: 0.99951, f1_macro: 0.99975
# epoch: 25, passed number of graphs: 192, train running loss: 0.00165 (passed time: 2h 55m 8s)
#           acc: 0.99994, fpr: 0.00004, fnr: 0.00033, rec: 0.99967, prc: 0.99900, f1: 0.99933, f1_macro: 0.99965
# epoch: 25, passed number of graphs: 288, train running loss: 0.00142 (passed time: 2h 55m 57s)
#           acc: 0.99984, fpr: 0.00015, fnr: 0.00033, rec: 0.99967, prc: 0.99651, f1: 0.99808, f1_macro: 0.99900
# epoch: 25, passed number of graphs: 384, train running loss: 0.00136 (passed time: 2h 56m 45s)
#           acc: 0.99981, fpr: 0.00019, fnr: 0.00033, rec: 0.99967, prc: 0.99591, f1: 0.99779, f1_macro: 0.99884
# epoch: 25, passed number of graphs: 480, train running loss: 0.00141 (passed time: 2h 57m 34s)
#           acc: 0.99974, fpr: 0.00025, fnr: 0.00050, rec: 0.99950, prc: 0.99438, f1: 0.99693, f1_macro: 0.99840
# epoch: 25, passed number of graphs: 576, train running loss: 0.00133 (passed time: 2h 58m 22s)
#           acc: 0.99961, fpr: 0.00038, fnr: 0.00066, rec: 0.99934, prc: 0.99152, f1: 0.99542, f1_macro: 0.99761
# epoch: 25, passed number of graphs: 672, train running loss: 0.00131 (passed time: 2h 59m 10s)
#           acc: 0.99906, fpr: 0.00097, fnr: 0.00033, rec: 0.99967, prc: 0.97827, f1: 0.98886, f1_macro: 0.99418
# epoch: 25, passed number of graphs: 768, train running loss: 0.00142 (passed time: 2h 59m 58s)
#           acc: 0.99988, fpr: 0.00012, fnr: 0.00017, rec: 0.99983, prc: 0.99735, f1: 0.99859, f1_macro: 0.99926
# Validation --- epoch: 25, loss: 0.00142
#           fnr: 0.00444, f1: 0.99441, rec: 0.99556, f1_macro: 0.99715, fpr: 0.00013, prc: 0.99446, acc: 0.99978
# epoch: 26, passed number of graphs: 96, train running loss: 0.00197 (passed time: 3h 1m 22s)
#           acc: 0.99996, fpr: 0.00004, fnr: 0.00000, rec: 1.00000, prc: 0.99903, f1: 0.99951, f1_macro: 0.99975
# epoch: 26, passed number of graphs: 192, train running loss: 0.00165 (passed time: 3h 2m 10s)
#           acc: 0.99994, fpr: 0.00004, fnr: 0.00033, rec: 0.99967, prc: 0.99900, f1: 0.99933, f1_macro: 0.99965
# epoch: 26, passed number of graphs: 288, train running loss: 0.00142 (passed time: 3h 2m 58s)
#           acc: 0.99984, fpr: 0.00015, fnr: 0.00033, rec: 0.99967, prc: 0.99651, f1: 0.99808, f1_macro: 0.99900
# epoch: 26, passed number of graphs: 384, train running loss: 0.00136 (passed time: 3h 3m 47s)
#           acc: 0.99981, fpr: 0.00019, fnr: 0.00033, rec: 0.99967, prc: 0.99591, f1: 0.99779, f1_macro: 0.99884
# epoch: 26, passed number of graphs: 480, train running loss: 0.00141 (passed time: 3h 4m 35s)
#           acc: 0.99974, fpr: 0.00025, fnr: 0.00050, rec: 0.99950, prc: 0.99438, f1: 0.99693, f1_macro: 0.99840
# epoch: 26, passed number of graphs: 576, train running loss: 0.00133 (passed time: 3h 5m 24s)
#           acc: 0.99962, fpr: 0.00037, fnr: 0.00066, rec: 0.99934, prc: 0.99168, f1: 0.99550, f1_macro: 0.99765
# epoch: 26, passed number of graphs: 672, train running loss: 0.00131 (passed time: 3h 6m 12s)
#           acc: 0.99907, fpr: 0.00096, fnr: 0.00033, rec: 0.99967, prc: 0.97843, f1: 0.98894, f1_macro: 0.99422
# epoch: 26, passed number of graphs: 768, train running loss: 0.00142 (passed time: 3h 7m 0s)
#           acc: 0.99988, fpr: 0.00012, fnr: 0.00017, rec: 0.99983, prc: 0.99735, f1: 0.99859, f1_macro: 0.99926
# Validation --- epoch: 26, loss: 0.00141
#           fnr: 0.00444, f1: 0.99442, rec: 0.99556, f1_macro: 0.99715, fpr: 0.00013, prc: 0.99447, acc: 0.99978
# epoch: 27, passed number of graphs: 96, train running loss: 0.00195 (passed time: 3h 8m 25s)
#           acc: 0.99996, fpr: 0.00004, fnr: 0.00000, rec: 1.00000, prc: 0.99903, f1: 0.99951, f1_macro: 0.99975
# epoch: 27, passed number of graphs: 192, train running loss: 0.00167 (passed time: 3h 9m 15s)
#           acc: 0.99994, fpr: 0.00004, fnr: 0.00033, rec: 0.99967, prc: 0.99900, f1: 0.99933, f1_macro: 0.99965
# epoch: 27, passed number of graphs: 288, train running loss: 0.00145 (passed time: 3h 10m 3s)
#           acc: 0.99984, fpr: 0.00015, fnr: 0.00033, rec: 0.99967, prc: 0.99651, f1: 0.99808, f1_macro: 0.99900
# epoch: 27, passed number of graphs: 384, train running loss: 0.00138 (passed time: 3h 10m 52s)
#           acc: 0.99981, fpr: 0.00019, fnr: 0.00033, rec: 0.99967, prc: 0.99591, f1: 0.99779, f1_macro: 0.99884
# epoch: 27, passed number of graphs: 480, train running loss: 0.00143 (passed time: 3h 11m 40s)
#           acc: 0.99974, fpr: 0.00025, fnr: 0.00050, rec: 0.99950, prc: 0.99438, f1: 0.99693, f1_macro: 0.99840
# epoch: 27, passed number of graphs: 576, train running loss: 0.00135 (passed time: 3h 12m 28s)
#           acc: 0.99957, fpr: 0.00044, fnr: 0.00033, rec: 0.99967, prc: 0.99023, f1: 0.99493, f1_macro: 0.99735
# epoch: 27, passed number of graphs: 672, train running loss: 0.00133 (passed time: 3h 13m 16s)
#           acc: 0.99904, fpr: 0.00099, fnr: 0.00033, rec: 0.99967, prc: 0.97780, f1: 0.98862, f1_macro: 0.99406
# epoch: 27, passed number of graphs: 768, train running loss: 0.00142 (passed time: 3h 14m 4s)
#           acc: 0.99988, fpr: 0.00012, fnr: 0.00017, rec: 0.99983, prc: 0.99735, f1: 0.99859, f1_macro: 0.99926
# Validation --- epoch: 27, loss: 0.00134
#           fnr: 0.00448, f1: 0.99460, rec: 0.99552, f1_macro: 0.99724, fpr: 0.00012, prc: 0.99485, acc: 0.99979
# Better model saved at ./saved_models/GIN_26: 0.9945965913475043.pt.
# epoch: 28, passed number of graphs: 96, train running loss: 0.00194 (passed time: 3h 15m 29s)
#           acc: 0.99996, fpr: 0.00004, fnr: 0.00000, rec: 1.00000, prc: 0.99903, f1: 0.99951, f1_macro: 0.99975
# epoch: 28, passed number of graphs: 192, train running loss: 0.00162 (passed time: 3h 16m 17s)
#           acc: 0.99994, fpr: 0.00004, fnr: 0.00033, rec: 0.99967, prc: 0.99900, f1: 0.99933, f1_macro: 0.99965
# epoch: 28, passed number of graphs: 288, train running loss: 0.00140 (passed time: 3h 17m 5s)
#           acc: 0.99984, fpr: 0.00015, fnr: 0.00033, rec: 0.99967, prc: 0.99651, f1: 0.99808, f1_macro: 0.99900
# epoch: 28, passed number of graphs: 384, train running loss: 0.00134 (passed time: 3h 17m 53s)
#           acc: 0.99981, fpr: 0.00019, fnr: 0.00033, rec: 0.99967, prc: 0.99591, f1: 0.99779, f1_macro: 0.99884
# epoch: 28, passed number of graphs: 480, train running loss: 0.00140 (passed time: 3h 18m 41s)
#           acc: 0.99974, fpr: 0.00025, fnr: 0.00050, rec: 0.99950, prc: 0.99438, f1: 0.99693, f1_macro: 0.99840
# epoch: 28, passed number of graphs: 576, train running loss: 0.00132 (passed time: 3h 19m 30s)
#           acc: 0.99958, fpr: 0.00041, fnr: 0.00049, rec: 0.99951, prc: 0.99072, f1: 0.99509, f1_macro: 0.99744
# epoch: 28, passed number of graphs: 672, train running loss: 0.00131 (passed time: 3h 20m 17s)
#           acc: 0.99905, fpr: 0.00098, fnr: 0.00033, rec: 0.99967, prc: 0.97796, f1: 0.98870, f1_macro: 0.99410
# epoch: 28, passed number of graphs: 768, train running loss: 0.00140 (passed time: 3h 21m 6s)
#           acc: 0.99988, fpr: 0.00012, fnr: 0.00017, rec: 0.99983, prc: 0.99735, f1: 0.99859, f1_macro: 0.99926
# Validation --- epoch: 28, loss: 0.00133
#           fnr: 0.00449, f1: 0.99462, rec: 0.99551, f1_macro: 0.99726, fpr: 0.00012, prc: 0.99490, acc: 0.99979
# Better model saved at ./saved_models/GIN_27: 0.9946208440106376.pt.
# epoch: 29, passed number of graphs: 96, train running loss: 0.00193 (passed time: 3h 22m 30s)
#           acc: 0.99996, fpr: 0.00004, fnr: 0.00000, rec: 1.00000, prc: 0.99903, f1: 0.99951, f1_macro: 0.99975
# epoch: 29, passed number of graphs: 192, train running loss: 0.00161 (passed time: 3h 23m 19s)
#           acc: 0.99994, fpr: 0.00004, fnr: 0.00033, rec: 0.99967, prc: 0.99900, f1: 0.99933, f1_macro: 0.99965
# epoch: 29, passed number of graphs: 288, train running loss: 0.00140 (passed time: 3h 24m 7s)
#           acc: 0.99984, fpr: 0.00015, fnr: 0.00033, rec: 0.99967, prc: 0.99651, f1: 0.99808, f1_macro: 0.99900
# epoch: 29, passed number of graphs: 384, train running loss: 0.00134 (passed time: 3h 24m 55s)
#           acc: 0.99981, fpr: 0.00019, fnr: 0.00033, rec: 0.99967, prc: 0.99591, f1: 0.99779, f1_macro: 0.99884
# epoch: 29, passed number of graphs: 480, train running loss: 0.00139 (passed time: 3h 25m 44s)
#           acc: 0.99974, fpr: 0.00025, fnr: 0.00050, rec: 0.99950, prc: 0.99438, f1: 0.99693, f1_macro: 0.99840
# epoch: 29, passed number of graphs: 576, train running loss: 0.00131 (passed time: 3h 26m 32s)
#           acc: 0.99958, fpr: 0.00042, fnr: 0.00049, rec: 0.99951, prc: 0.99056, f1: 0.99501, f1_macro: 0.99739
# epoch: 29, passed number of graphs: 672, train running loss: 0.00130 (passed time: 3h 27m 21s)
#           acc: 0.99905, fpr: 0.00098, fnr: 0.00033, rec: 0.99967, prc: 0.97796, f1: 0.98870, f1_macro: 0.99410
# epoch: 29, passed number of graphs: 768, train running loss: 0.00140 (passed time: 3h 28m 9s)
#           acc: 0.99988, fpr: 0.00012, fnr: 0.00017, rec: 0.99983, prc: 0.99735, f1: 0.99859, f1_macro: 0.99926
# Validation --- epoch: 29, loss: 0.00133
#           fnr: 0.00449, f1: 0.99463, rec: 0.99551, f1_macro: 0.99726, fpr: 0.00012, prc: 0.99492, acc: 0.99979
# Better model saved at ./saved_models/GIN_28: 0.994629747986313.pt.
# epoch: 30, passed number of graphs: 96, train running loss: 0.00193 (passed time: 3h 29m 34s)
#           acc: 0.99996, fpr: 0.00004, fnr: 0.00000, rec: 1.00000, prc: 0.99903, f1: 0.99951, f1_macro: 0.99975
# epoch: 30, passed number of graphs: 192, train running loss: 0.00161 (passed time: 3h 30m 22s)
#           acc: 0.99994, fpr: 0.00004, fnr: 0.00033, rec: 0.99967, prc: 0.99900, f1: 0.99933, f1_macro: 0.99965
# epoch: 30, passed number of graphs: 288, train running loss: 0.00139 (passed time: 3h 31m 10s)
#           acc: 0.99984, fpr: 0.00015, fnr: 0.00033, rec: 0.99967, prc: 0.99651, f1: 0.99808, f1_macro: 0.99900
# epoch: 30, passed number of graphs: 384, train running loss: 0.00134 (passed time: 3h 31m 59s)
#           acc: 0.99981, fpr: 0.00019, fnr: 0.00033, rec: 0.99967, prc: 0.99591, f1: 0.99779, f1_macro: 0.99884
# epoch: 30, passed number of graphs: 480, train running loss: 0.00139 (passed time: 3h 32m 47s)
#           acc: 0.99974, fpr: 0.00025, fnr: 0.00050, rec: 0.99950, prc: 0.99438, f1: 0.99693, f1_macro: 0.99840
# epoch: 30, passed number of graphs: 576, train running loss: 0.00131 (passed time: 3h 33m 36s)
#           acc: 0.99958, fpr: 0.00042, fnr: 0.00049, rec: 0.99951, prc: 0.99056, f1: 0.99501, f1_macro: 0.99739
# epoch: 30, passed number of graphs: 672, train running loss: 0.00130 (passed time: 3h 34m 23s)
#           acc: 0.99905, fpr: 0.00098, fnr: 0.00033, rec: 0.99967, prc: 0.97796, f1: 0.98870, f1_macro: 0.99410
# epoch: 30, passed number of graphs: 768, train running loss: 0.00140 (passed time: 3h 35m 12s)
#           acc: 0.99988, fpr: 0.00012, fnr: 0.00017, rec: 0.99983, prc: 0.99735, f1: 0.99859, f1_macro: 0.99926
# Validation --- epoch: 30, loss: 0.00133
#           fnr: 0.00449, f1: 0.99464, rec: 0.99551, f1_macro: 0.99726, fpr: 0.00012, prc: 0.99493, acc: 0.99979
# Better model saved at ./saved_models/GIN_29: 0.9946355208854137.pt.
# epoch: 31, passed number of graphs: 96, train running loss: 0.00193 (passed time: 3h 36m 36s)
#           acc: 0.99996, fpr: 0.00004, fnr: 0.00000, rec: 1.00000, prc: 0.99903, f1: 0.99951, f1_macro: 0.99975
# epoch: 31, passed number of graphs: 192, train running loss: 0.00161 (passed time: 3h 37m 24s)
#           acc: 0.99994, fpr: 0.00004, fnr: 0.00033, rec: 0.99967, prc: 0.99900, f1: 0.99933, f1_macro: 0.99965
# epoch: 31, passed number of graphs: 288, train running loss: 0.00139 (passed time: 3h 38m 13s)
#           acc: 0.99984, fpr: 0.00015, fnr: 0.00033, rec: 0.99967, prc: 0.99651, f1: 0.99808, f1_macro: 0.99900
# epoch: 31, passed number of graphs: 384, train running loss: 0.00134 (passed time: 3h 39m 1s)
#           acc: 0.99981, fpr: 0.00019, fnr: 0.00033, rec: 0.99967, prc: 0.99591, f1: 0.99779, f1_macro: 0.99884
# epoch: 31, passed number of graphs: 480, train running loss: 0.00139 (passed time: 3h 39m 50s)
#           acc: 0.99974, fpr: 0.00025, fnr: 0.00050, rec: 0.99950, prc: 0.99438, f1: 0.99693, f1_macro: 0.99840
# epoch: 31, passed number of graphs: 576, train running loss: 0.00131 (passed time: 3h 40m 38s)
#           acc: 0.99958, fpr: 0.00042, fnr: 0.00049, rec: 0.99951, prc: 0.99056, f1: 0.99501, f1_macro: 0.99739
# epoch: 31, passed number of graphs: 672, train running loss: 0.00130 (passed time: 3h 41m 26s)
#           acc: 0.99905, fpr: 0.00097, fnr: 0.00033, rec: 0.99967, prc: 0.97812, f1: 0.98878, f1_macro: 0.99414
# epoch: 31, passed number of graphs: 768, train running loss: 0.00140 (passed time: 3h 42m 14s)
#           acc: 0.99988, fpr: 0.00012, fnr: 0.00017, rec: 0.99983, prc: 0.99735, f1: 0.99859, f1_macro: 0.99926
# Validation --- epoch: 31, loss: 0.00133
#           fnr: 0.00450, f1: 0.99463, rec: 0.99550, f1_macro: 0.99726, fpr: 0.00011, prc: 0.99494, acc: 0.99979
# epoch: 32, passed number of graphs: 96, train running loss: 0.00192 (passed time: 3h 43m 39s)
#           acc: 0.99996, fpr: 0.00004, fnr: 0.00000, rec: 1.00000, prc: 0.99903, f1: 0.99951, f1_macro: 0.99975
# epoch: 32, passed number of graphs: 192, train running loss: 0.00161 (passed time: 3h 44m 27s)
#           acc: 0.99994, fpr: 0.00004, fnr: 0.00033, rec: 0.99967, prc: 0.99900, f1: 0.99933, f1_macro: 0.99965
# epoch: 32, passed number of graphs: 288, train running loss: 0.00139 (passed time: 3h 45m 15s)
#           acc: 0.99984, fpr: 0.00015, fnr: 0.00033, rec: 0.99967, prc: 0.99651, f1: 0.99808, f1_macro: 0.99900
# epoch: 32, passed number of graphs: 384, train running loss: 0.00134 (passed time: 3h 46m 4s)
#           acc: 0.99981, fpr: 0.00019, fnr: 0.00033, rec: 0.99967, prc: 0.99591, f1: 0.99779, f1_macro: 0.99884
# epoch: 32, passed number of graphs: 480, train running loss: 0.00139 (passed time: 3h 46m 53s)
#           acc: 0.99974, fpr: 0.00025, fnr: 0.00050, rec: 0.99950, prc: 0.99438, f1: 0.99693, f1_macro: 0.99840
# epoch: 32, passed number of graphs: 576, train running loss: 0.00131 (passed time: 3h 47m 41s)
#           acc: 0.99958, fpr: 0.00042, fnr: 0.00049, rec: 0.99951, prc: 0.99056, f1: 0.99501, f1_macro: 0.99739
# epoch: 32, passed number of graphs: 672, train running loss: 0.00130 (passed time: 3h 48m 29s)
#           acc: 0.99905, fpr: 0.00097, fnr: 0.00033, rec: 0.99967, prc: 0.97812, f1: 0.98878, f1_macro: 0.99414
# epoch: 32, passed number of graphs: 768, train running loss: 0.00140 (passed time: 3h 49m 17s)
#           acc: 0.99988, fpr: 0.00012, fnr: 0.00017, rec: 0.99983, prc: 0.99735, f1: 0.99859, f1_macro: 0.99926
# Validation --- epoch: 32, loss: 0.00133
#           fnr: 0.00450, f1: 0.99464, rec: 0.99550, f1_macro: 0.99726, fpr: 0.00011, prc: 0.99494, acc: 0.99979
# Better model saved at ./saved_models/GIN_31: 0.9946362326288253.pt.
# epoch: 33, passed number of graphs: 96, train running loss: 0.00192 (passed time: 3h 50m 42s)
#           acc: 0.99996, fpr: 0.00004, fnr: 0.00000, rec: 1.00000, prc: 0.99903, f1: 0.99951, f1_macro: 0.99975
# epoch: 33, passed number of graphs: 192, train running loss: 0.00161 (passed time: 3h 51m 31s)
#           acc: 0.99994, fpr: 0.00004, fnr: 0.00033, rec: 0.99967, prc: 0.99900, f1: 0.99933, f1_macro: 0.99965
# epoch: 33, passed number of graphs: 288, train running loss: 0.00139 (passed time: 3h 52m 19s)
#           acc: 0.99984, fpr: 0.00015, fnr: 0.00033, rec: 0.99967, prc: 0.99651, f1: 0.99808, f1_macro: 0.99900
# epoch: 33, passed number of graphs: 384, train running loss: 0.00134 (passed time: 3h 53m 8s)
#           acc: 0.99981, fpr: 0.00019, fnr: 0.00033, rec: 0.99967, prc: 0.99591, f1: 0.99779, f1_macro: 0.99884
# epoch: 33, passed number of graphs: 480, train running loss: 0.00139 (passed time: 3h 53m 57s)
#           acc: 0.99974, fpr: 0.00025, fnr: 0.00050, rec: 0.99950, prc: 0.99438, f1: 0.99693, f1_macro: 0.99840
# epoch: 33, passed number of graphs: 576, train running loss: 0.00131 (passed time: 3h 54m 45s)
#           acc: 0.99958, fpr: 0.00042, fnr: 0.00049, rec: 0.99951, prc: 0.99056, f1: 0.99501, f1_macro: 0.99739
# epoch: 33, passed number of graphs: 672, train running loss: 0.00130 (passed time: 3h 55m 33s)
#           acc: 0.99905, fpr: 0.00097, fnr: 0.00033, rec: 0.99967, prc: 0.97812, f1: 0.98878, f1_macro: 0.99414
# epoch: 33, passed number of graphs: 768, train running loss: 0.00140 (passed time: 3h 56m 21s)
#           acc: 0.99988, fpr: 0.00012, fnr: 0.00017, rec: 0.99983, prc: 0.99735, f1: 0.99859, f1_macro: 0.99926

# %%
# !zip -r /content/GATv2Conv_p2p_6k_feat_norm.zip /content/saved_models

# %%
from google.colab import files
files.download("/content/GATv2Conv_p2p_6k_feat_norm.zip")

# %%
from google.colab import runtime
runtime.unassign()
